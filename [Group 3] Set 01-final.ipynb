# %% [markdown]
# # One-Letter Words

# %%
# open the csv files
AP = open('AP.csv')
AC = open('AC.csv')
BPI = open('BPI.csv')
BLOOM = open('BLOOM.csv')
FGEN = open('FGEN.csv')
ICT = open('ICT.csv')
JGS = open('JGS.csv')
MEG = open('MEG.csv')
SMC = open('SMC.csv')
SCC = open('SCC.csv')

#initiFGENze the lists
Date_AP = []
ClosePrice_AP = []
Date_AC = []
ClosePrice_AC = []
Date_BPI = []
ClosePrice_BPI = []
Date_BLOOM = []
ClosePrice_BLOOM = []
Date_FGEN = []
ClosePrice_FGEN = []
Date_ICT = []
ClosePrice_ICT = []
Date_JGS = []
ClosePrice_JGS = []
Date_MEG = []
ClosePrice_MEG = []
Date_SMC = []
ClosePrice_SMC = []
Date_SCC = []
ClosePrice_SCC = []

#skip the header line
AP.readline()
AC.readline()
BPI.readline()
BLOOM.readline()
FGEN.readline()
ICT.readline()
JGS.readline()
MEG.readline()
SMC.readline()
SCC.readline()

#go through the files line by line
for line in AP:
    sline = line.strip().split(',')
    Date_AP.append(sline[0])
    ClosePrice_AP.append(float(sline[1]))
    
for line in AC:
    sline = line.strip().split(',')
    Date_AC.append(sline[0])
    ClosePrice_AC.append(float(sline[1]))
    
for line in BPI:
    sline = line.strip().split(',')
    Date_BPI.append(sline[0])
    ClosePrice_BPI.append(float(sline[1]))
    
for line in BLOOM:
    sline = line.strip().split(',')
    Date_BLOOM.append(sline[0])
    ClosePrice_BLOOM.append(float(sline[1]))
    
for line in FGEN:
    sline = line.strip().split(',')
    Date_FGEN.append(sline[0])
    ClosePrice_FGEN.append(float(sline[1]))
    
for line in ICT:
    sline = line.strip().split(',')
    Date_ICT.append(sline[0])
    ClosePrice_ICT.append(float(sline[1]))
    
for line in JGS:
    sline = line.strip().split(',')
    Date_JGS.append(sline[0])
    ClosePrice_JGS.append(float(sline[1]))
    
for line in MEG:
    sline = line.strip().split(',')
    Date_MEG.append(sline[0])
    ClosePrice_MEG.append(float(sline[1]))
    
for line in SMC:
    sline = line.strip().split(',')
    Date_SMC.append(sline[0])
    ClosePrice_SMC.append(float(sline[1]))
        
for line in SCC:
    sline = line.strip().split(',')
    Date_SCC.append(sline[0])
    ClosePrice_SCC.append(float(sline[1]))


#close files
AP.close()
AC.close()
BPI.close()
BLOOM.close()
FGEN.close()
ICT.close()
JGS.close()
MEG.close()
SMC.close()
SCC.close()

# %%
import numpy as np
import datetime

# %%
# convert dates into datetime structure
for n in range(len(Date_AP)):
    Date_AP[n] = datetime.datetime.strptime(Date_AP[n], '%m/%d/%y').date()

for n in range(len(Date_AC)):
    Date_AC[n] = datetime.datetime.strptime(Date_AC[n], '%m/%d/%y').date()
    
for n in range(len(Date_BPI)):
    Date_BPI[n] = datetime.datetime.strptime(Date_BPI[n], '%m/%d/%y').date()

for n in range(len(Date_BLOOM)):
    Date_BLOOM[n] = datetime.datetime.strptime(Date_BLOOM[n], '%m/%d/%y').date()
    
for n in range(len(Date_FGEN)):
    Date_FGEN[n] = datetime.datetime.strptime(Date_FGEN[n], '%m/%d/%y').date()

for n in range(len(Date_ICT)):
    Date_ICT[n] = datetime.datetime.strptime(Date_ICT[n], '%m/%d/%y').date()
    
for n in range(len(Date_JGS)):
    Date_JGS[n] = datetime.datetime.strptime(Date_JGS[n], '%m/%d/%y').date()

for n in range(len(Date_MEG)):
    Date_MEG[n] = datetime.datetime.strptime(Date_MEG[n], '%m/%d/%y').date()
    
for n in range(len(Date_SMC)):
    Date_SMC[n] = datetime.datetime.strptime(Date_SMC[n], '%m/%d/%y').date()

for n in range(len(Date_SCC)):
    Date_SCC[n] = datetime.datetime.strptime(Date_SCC[n], '%m/%d/%y').date()
    
# save Date and ClosePrice
np.save('APDate.npy', Date_AP)
np.save('APClosePrice.npy', ClosePrice_AP)
np.save('ACDate.npy', Date_AC)
np.save('ACClosePrice.npy', ClosePrice_AC)
np.save('BPIDate.npy', Date_BPI)
np.save('BPIClosePrice.npy', ClosePrice_BPI)
np.save('BLOOMDate.npy', Date_BLOOM)
np.save('BLOOMClosePrice.npy', ClosePrice_BLOOM)
np.save('FGENDate.npy', Date_FGEN)
np.save('FGENClosePrice.npy', ClosePrice_FGEN)
np.save('ICTDate.npy', Date_ICT)
np.save('ICTClosePrice.npy', ClosePrice_ICT)
np.save('JGSDate.npy', Date_JGS)
np.save('JGSClosePrice.npy', ClosePrice_JGS)
np.save('MEGDate.npy', Date_MEG)
np.save('MEGClosePrice.npy', ClosePrice_MEG)
np.save('SMCDate.npy', Date_SMC)
np.save('SMCClosePrice.npy', ClosePrice_SMC)
np.save('SCCDate.npy', Date_SCC)
np.save('SCCClosePrice.npy', ClosePrice_SCC)

# %% [markdown]
# # Five-letter Words

# %% [markdown]
# # 3.1 (B) AP - (D) AC - (F) BPI - (H) BLOOM - (J) FGEN

# %%
import numpy as np

# %%
#extract the overlapping dates

start_1 = max(min(Date_AP), min(Date_AC), min(Date_BPI), min(Date_BLOOM), min(Date_FGEN))
end_1 = min(max(Date_AP), max(Date_AC), max(Date_BPI), max(Date_BLOOM), max(Date_FGEN))

# %%
#shorten the closing prices
AP_1_1 = Date_AP.index(start_1)
AP_1_2 = Date_AP.index(end_1)

AC_1_1 = Date_AC.index(start_1)
AC_1_2 = Date_AC.index(end_1)

BPI_1_1 = Date_BPI.index(start_1)
BPI_1_2 = Date_BPI.index(end_1)

BLOOM_1_1 = Date_BLOOM.index(start_1)
BLOOM_1_2 = Date_BLOOM.index(end_1)

FGEN_1_1 = Date_FGEN.index(start_1)
FGEN_1_2 = Date_FGEN.index(end_1)

# %%
#save the shortened versions of closing prices
B1 = np.save('APshortPrices.npy', ClosePrice_AP[AP_1_1:AP_1_2])
D1 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_1_1:AC_1_2])
F1 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_1_1:BPI_1_2])
H1 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_1_1:BLOOM_1_2])
J1 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_1_1:FGEN_1_2])

# %%
# import prices
B1 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D1 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F1 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H1 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J1 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_1 = []
st_1 = []
n = 1
while n < len(B1):
    sc_1 = ''
    if B1[n] > B1[n-1]:
        sc_1 = sc_1 + 'B'
    if D1[n] > D1[n-1]:
        sc_1 = sc_1 + 'D'
    if F1[n] > F1[n-1]:
        sc_1 = sc_1 + 'F'
    if H1[n] > H1[n-1]:
        sc_1 = sc_1 + 'H'
    if J1[n] > J1[n-1]: 
        sc_1 = sc_1 + 'J'
    if len(sc_1) > 0:
        st_1.append(sc_1)
    else:
        STC_1.append(st_1)
        st_1 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_1 = STC_1.count([])
# keep only non-empty spatio-temporal sequences
STC_1 = [ st_1 for st_1 in STC_1 if len(st_1) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_1 = len(B1)
lmax_1 = 0
for st_1 in STC_1:
    if len(st_1) < lmin_1:
        lmin_1 = len(st_1)
    if len(st_1) > lmax_1:
        lmax_1 = len(st_1)
        
# restrict spatio-temporal sequences to length-5
STC5_1 = [ st_1 for st_1 in STC_1 if len(st_1) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_1 = []
for n in range(len(STC5_1)):
    tc_1 = [ u for u in STC5_1[n][0] ]
    for k in range(1, len(STC5_1[n])):
        tc_1 = [ u+v for u in tc_1 for v in STC5_1[n][k] ]
    TC5_1 = TC5_1 + tc_1
setTC5_1 = list(set(TC5_1))

# get empirical frequencies
fTC5_1 = [ TC5_1.count(setTC5_1[l]) for l in range(len(setTC5_1)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_1 = [ [] for l in range(len(setTC5_1)) ]
for s in range(100):
    STC5null_1 = [ list(st_1) for st_1 in STC5_1]
    for st_1 in STC5null_1:
        np.random.shuffle(st_1)
    TC5null_1= []
    for n in range(len(STC5null_1)):
        tc_1 = [ u for u in STC5null_1[n][0] ]
        for k in range(1, len(STC5null_1[n])):
            tc_1 = [ u+v for u in tc_1 for v in STC5null_1[n][k] ]
        TC5null_1= TC5null_1+ tc_1
    for l in range(len(setTC5_1)):
        if TC5null_1.count(setTC5_1[l]) > 0:
            fTC5null_1[l].append(TC5null_1.count(setTC5_1[l]))
        else:
            fTC5null_1[l].append(0)

# %%
print("List of Statistically Significant Sequences at α = 0.05")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_1)):
    if sum(freq >= fTC5_1[l] for freq in fTC5null_1[l]) < 5:
        print(setTC5_1[l], fTC5_1[l], sum(freq >= fTC5_1[l] for freq in fTC5null_1[l]))
#         print(setTC5_1[l])
# Out:
# List of Statistically Significant Sequences at α = 0.05
# BBDDB 3 0
# HJFHH 5 1
# FJBB 7 2
# DDDDH 4 2
# BJJDF 4 1
# FJFB 7 3
# DBDDH 4 3
# BJBHJ 3 1
# HFFDF 4 4
# BDDDJ 5 2
# FBFB 7 4
# HFFJJ 3 2
# HHDBJ 4 1
# FDDDH 6 1
# HFDHJ 4 1
# BHDBJ 4 0
# JJD 7 4
# HDJJ 5 3
# HHDBH 4 1
# BJDHJ 4 0
# HHBBD 4 1
# BDDDB 5 0
# BDJBJ 3 4
# BJFHJ 3 3
# BHDDH 4 4
# FFBD 8 1
# DDDH 5 1
# HFFHH 6 1
# HDFJ 6 1
# HJBJJ 3 1
# JJF 8 1
# HDJF 5 3
# BFFDD 6 3
# BJFHH 4 2
# HFFJH 3 3
# HBJJ 6 2
# BDDDF 7 2
# BJFDF 4 2
# FJDHH 4 1
# HFJJ 5 4
# HJDHJ 4 1
# FJDFH 3 2
# BJBJD 3 3
# BJDHH 4 3
# DHDBJ 4 1
# FJDHJ 3 4
# BJFHD 3 4
# BJJDJ 3 2
# BFDDJ 5 1
# BDFBJ 4 4
# HJBJD 4 1
# HFFBJ 3 3
# BFFHF 4 1
# BJDDF 5 3
# FFDHJ 3 4
# BJFBJ 3 4
# DJDHJ 3 3
# FBHB 6 2
# BFDDF 5 4
# BFFJJ 4 3
# FJDDH 4 2
# BFFDF 7 0
# DJDHH 4 1
# DHDH 4 4
# HDDF 6 3
# HFDHH 5 3
# FJBJ 9 0
# DJJHJ 2 4
# FBDDH 4 2
# HFBJ 6 0
# HJFJJ 2 3
# HFFDH 5 1
# BJDFF 4 4
# DHJFJ 3 3
# BJBBJ 3 2
# BJFDJ 5 0
# BFDBJ 5 0
# BDDDH 5 1
# BJDDD 5 1
# HBDJ 6 2
# ...

# %%
print("List of Statistically Significant Sequences at α = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_1)):
    if sum(freq >= fTC5_1[l] for freq in fTC5null_1[l]) < 1:
        print(setTC5_1[l], fTC5_1[l], sum(freq >= fTC5_1[l] for freq in fTC5null_1[l]))
#         print(setTC5_1[l])
# Out:
# List of Statistically Significant Sequences at α = 0.01
# BBDDB 3 0
# BHDBJ 4 0
# BJDHJ 4 0
# BDDDB 5 0
# BFFDF 7 0
# FJBJ 9 0
# HFBJ 6 0
# BJFDJ 5 0
# BFDBJ 5 0
# HJBHJ 4 0
# BFFDJ 6 0
# BJDDJ 5 0
# BDDBJ 5 0
# BJBDJ 4 0
# BFFBJ 5 0
# DJJHH 4 0

# %% [markdown]
# # 3.2 (B) AP - (D) AC - (F) BPI - (H) BLOOM - (M) ICT

# %%
#extract the overlapping dates

start_2 = max(min(Date_AP), min(Date_AC), min(Date_BPI), min(Date_BLOOM), min(Date_ICT))
end_2 = min(max(Date_AP), max(Date_AC), max(Date_BPI), max(Date_BLOOM), max(Date_ICT))

# %%
#shorten the closing prices
AP_2_1 = Date_AP.index(start_2)
AP_2_2 = Date_AP.index(end_2)

AC_2_1 = Date_AC.index(start_2)
AC_2_2 = Date_AC.index(end_2)

BPI_2_1 = Date_BPI.index(start_2)
BPI_2_2 = Date_BPI.index(end_2)

BLOOM_2_1 = Date_BLOOM.index(start_2)
BLOOM_2_2 = Date_BLOOM.index(end_2)

ICT_2_1 = Date_ICT.index(start_2)
ICT_2_2 = Date_ICT.index(end_2)

# %%
#save the shortened versions of closing prices
B2 = np.save('APshortPrices.npy', ClosePrice_AP[AP_2_1:AP_2_2])
D2 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_2_1:AC_2_2])
F2 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_2_1:BPI_2_2])
H2 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_2_1:BLOOM_2_2])
M2 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_2_1:ICT_2_2])

# %%
# import modules
import numpy as np
# import prices
B2 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D2 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F2 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H2 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M2 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_2 = []
st_2 = []
n = 1
while n < len(B2):
    sc_2 = ''
    if B2[n] > B2[n-1]:
        sc_2 = sc_2 + 'B'
    if D2[n] > D2[n-1]:
        sc_2 = sc_2 + 'D'
    if F2[n] > F2[n-1]:
        sc_2 = sc_2 + 'F'
    if H2[n] > H2[n-1]:
        sc_2 = sc_2 + 'H'
    if M2[n] > M2[n-1]:
        sc_2 = sc_2 + 'M'
    if len(sc_2) > 0:
        st_2.append(sc_2)
    else:
        STC_2.append(st_2)
        st_2 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_2 = STC_2.count([])
# keep only non-empty spatio-temporal sequences
STC_2 = [ st_2 for st_2 in STC_2 if len(st_2) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_2 = len(B2)
lmax_2 = 0
for st_2 in STC_2:
    if len(st_2) < lmin_2:
        lmin_2 = len(st_2)
    if len(st_2) > lmax_2:
        lmax_2 = len(st_2)
        
# restrict spatio-temporal sequences to length-5
STC5_2 = [ st_2 for st_2 in STC_2 if len(st_2) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_2 = []
for n in range(len(STC5_2)):
    tc_2 = [ u for u in STC5_2[n][0] ]
    for k in range(1, len(STC5_2[n])):
        tc_2 = [ u+v for u in tc_2 for v in STC5_2[n][k] ]
    TC5_2 = TC5_2 + tc_2
setTC5_2 = list(set(TC5_2))

# get empirical frequencies
fTC5_2 = [ TC5_2.count(setTC5_2[l]) for l in range(len(setTC5_2)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_2 = [ [] for l in range(len(setTC5_2)) ]
for s in range(100):
    STC5null_2 = [ list(st_2) for st_2 in STC5_2]
    for st_2 in STC5null_2:
        np.random.shuffle(st_2)
    TC5null_2= []
    for n in range(len(STC5null_2)):
        tc_2 = [ u for u in STC5null_2[n][0] ]
        for k in range(1, len(STC5null_2[n])):
            tc_2 = [ u+v for u in tc_2 for v in STC5null_2[n][k] ]
        TC5null_2= TC5null_2+ tc_2
    for l in range(len(setTC5_2)):
        if TC5null_2.count(setTC5_2[l]) > 0:
            fTC5null_2[l].append(TC5null_2.count(setTC5_2[l]))
        else:
            fTC5null_2[l].append(0)

# %%
print("List of Statistically Significant Sequences at α = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_2)):
    if sum(freq >= fTC5_2[l] for freq in fTC5null_2[l]) < 5:
        print(setTC5_2[l], fTC5_2[l], sum(freq >= fTC5_2[l] for freq in fTC5null_2[l]))
#         print(setTC5_2[l])
# Out:
# List of Statistically Significant Sequences at α = 0.05
# HFFDF 3 4
# MHFDD 5 1
# MHMMD 3 1
# BDHMD 5 0
# MHFMD 4 0
# DDBH 7 3
# MDFDD 6 3
# MDHMD 5 0
# FHMFF 3 2
# MBMMD 4 4
# MFFDH 3 4
# MMBM 10 3
# FMBH 8 0
# MHFBD 4 3
# FBHMM 3 4
# MFMBD 5 1
# HHFDD 5 1
# HFFDD 4 2
# BHHFH 3 1
# DDDH 6 3
# MBHMD 4 1
# BHHMB 4 0
# MDMMM 3 3
# DMBH 10 0
# BHMBD 4 2
# DHFMD 4 2
# MFHMD 3 3
# HFFBD 4 2
# HFFFD 3 4
# FBMBD 5 1
# MMBH 8 1
# FMFH 5 1
# MMFH 7 0
# HHMBF 4 2
# FMMMD 4 1
# DHFBD 5 1
# BDMBB 4 2
# BMFBD 5 1
# MMFM 8 0
# HHMBD 4 3
# BFFBB 3 2
# MFFDD 6 2
# FHM 7 3
# BHMMD 4 0
# FBHB 6 4
# FDMBD 6 2
# BHMBH 3 4
# DMBM 10 2
# HHDBD 4 4
# MHFH 5 4
# FBDDB 6 1
# DHFH 6 0
# DHBH 7 0
# DHDH 6 0
# HDDF 6 3
# FDMBB 5 3
# BHBH 5 3
# MDHFD 4 0
# FBDDH 4 4
# BHDBD 4 2
# HBFDF 4 4
# DFFBD 6 2
# HHMMD 3 3
# BHMBB 3 3
# DMFH 8 0
# FMHMD 3 0
# MDMBD 6 0
# DBFBD 6 2
# HDFF 4 4
# BHHMF 3 4
# HHFBD 5 0
# FMFF 4 4
# BHDMD 4 3
# HBMMD 3 3
# DBFH 6 1
# MFFBD 5 4
# BHMBF 3 2
# HHDDD 4 3
# MBFB 9 1
# HBFMF 3 4
# ...

# %%
print("List of Statistically Significant Sequences at α = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_2)):
    if sum(freq >= fTC5_2[l] for freq in fTC5null_2[l]) < 1:
        print(setTC5_2[l], fTC5_2[l], sum(freq >= fTC5_2[l] for freq in fTC5null_2[l]))
#                 print(setTC5_2[l])
# Out:
# List of Statistically Significant Sequences at α = 0.01
# BDHMD 5 0
# MHFMD 4 0
# MDHMD 5 0
# FMBH 8 0
# BHHMB 4 0
# DMBH 10 0
# MMFH 7 0
# MMFM 8 0
# BHMMD 4 0
# DHFH 6 0
# DHBH 7 0
# DHDH 6 0
# MDHFD 4 0
# DMFH 8 0
# FMHMD 3 0
# MDMBD 6 0
# HHFBD 5 0
# BHFBD 4 0
# BHFMD 5 0
# BHHMD 5 0
# MDMMD 5 0
# HHFBF 4 0
# HHFMD 4 0

# %% [markdown]
# # 3.2 (B) AP - (D) AC - (F) BPI - (H) BLOOM - (N) JGS

# %%
#extract overlapping dates
start_3= max(min(Date_AP), min(Date_AC), min(Date_BPI), min(Date_BLOOM), min(Date_JGS))
end_3 = min(max(Date_AP), max(Date_AC), max(Date_BPI), max(Date_BLOOM), max(Date_JGS))

# %%
#shorten the closing prices
AP_3_1 = Date_AP.index(start_3)
AP_3_2 = Date_AP.index(end_3)

AC_3_1 = Date_AC.index(start_3)
AC_3_2 = Date_AC.index(end_3)

BPI_3_1 = Date_BPI.index(start_3)
BPI_3_2 = Date_BPI.index(end_3)

BLOOM_3_1 = Date_BLOOM.index(start_3)
BLOOM_3_2 = Date_BLOOM.index(end_3)

JGS_3_1 = Date_JGS.index(start_3)
JGS_3_2 = Date_JGS.index(end_3)

# %%
#save the shortened versions of closing prices
B3 = np.save('APClosePrice.npy', ClosePrice_AP[AP_3_1:AP_3_2])
D3 = np.save('ACClosePrice.npy', ClosePrice_AC[AC_3_1:AC_3_2])
F3 = np.save('BPIClosePrice.npy', ClosePrice_BPI[BPI_3_1:BPI_3_2])
H3 = np.save('BLOOMClosePrice.npy', ClosePrice_BLOOM[BLOOM_3_1:BLOOM_3_2])
N3 = np.save('JGSClosePrice.npy', ClosePrice_JGS[JGS_3_1:JGS_3_2])

# %%
# import modules
import numpy as np
# import prices

B3 = np.load('APClosePrice.npy',  allow_pickle=True).tolist() 
D3 = np.load('ACClosePrice.npy',  allow_pickle=True).tolist() 
F3 = np.load('BPIClosePrice.npy',  allow_pickle=True).tolist() 
H3 = np.load('BLOOMClosePrice.npy',  allow_pickle=True).tolist() 
N3 = np.load('JGSClosePrice.npy',  allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_3 = []
st_3 = []
n = 1
while n < len(B3):
    sc_3 = ''
    if B3[n] > B3[n-1]:
        sc_3 = sc_3 + 'B'
    if D3[n] > D3[n-1]:
        sc_3 = sc_3 + 'D'
    if F3[n] > F3[n-1]:
        sc_3 = sc_3 + 'F'
    if H3[n] > H3[n-1]:
        sc_3 = sc_3 + 'H'
    if N3[n] > N3[n-1]:
        sc_3 = sc_3 + 'N'
    if len(sc_3) > 0:
        st_3.append(sc_3)
    else:
        STC_3.append(st_3)
        st_3 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_3 = STC_3.count([])
# keep only non-empty spatio-temporal sequences
STC_3 = [ st_3 for st_3 in STC_3 if len(st_3) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_3 = len(B3)
lmax_3 = 0
for st_3 in STC_3:
    if len(st_3) < lmin_3:
        lmin_3 = len(st_3)
    if len(st_3) > lmax_3:
        lmax_3 = len(st_3)
        
# restrict spatio-temporal sequences to length-5
STC5_3 = [ st_3 for st_3 in STC_3 if len(st_3) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_3 = []
for n in range(len(STC5_3)):
    tc_3 = [ u for u in STC5_3[n][0] ]
    for k in range(1, len(STC5_3[n])):
        tc_3 = [ u+v for u in tc_3 for v in STC5_3[n][k] ]
    TC5_3 = TC5_3 + tc_3
setTC5_3 = list(set(TC5_3))

# get empirical frequencies
fTC5_3 = [ TC5_3.count(setTC5_3[l]) for l in range(len(setTC5_3)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_3 = [ [] for l in range(len(setTC5_3)) ]
for s in range(100):
    STC5null_3 = [ list(st_3) for st_3 in STC5_3]
    for st_3 in STC5null_3:
        np.random.shuffle(st_3)
    TC5null_3= []
    for n in range(len(STC5null_3)):
        tc_3 = [ u for u in STC5null_3[n][0] ]
        for k in range(1, len(STC5null_3[n])):
            tc_3 = [ u+v for u in tc_3 for v in STC5null_3[n][k] ]
        TC5null_3= TC5null_3+ tc_3
    for l in range(len(setTC5_3)):
        if TC5null_3.count(setTC5_3[l]) > 0:
            fTC5null_3[l].append(TC5null_3.count(setTC5_3[l]))
        else:
            fTC5null_3[l].append(0)

# %%
print("List of Statistically Significant Sequences at α = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_3)):
     if sum(freq >= fTC5_3[l] for freq in fTC5null_3[l]) < 5:
        print(setTC5_3[l], fTC5_3[l], sum(freq >= fTC5_3[l] for freq in fTC5null_3[l]))
#         print(setTC5_3[l])
# Out:
# List of Statistically Significant Sequences at α = 0.05
# HHDBN 5 4
# HDDBH 4 4
# NHDBH 5 2
# FFFBD 5 2
# DBDDH 4 4
# HNBNN 4 1
# HNDBD 5 2
# NBBN 6 4
# DHFFD 4 1
# HBF 9 0
# HHFND 5 2
# NHFB 7 0
# FNDNH 5 3
# NBNN 6 3
# HHBBD 4 3
# HHDND 6 2
# DDDH 7 0
# NNFBH 4 2
# NFFBD 5 1
# HHDNN 5 3
# NDDBH 5 3
# NBFH 6 3
# HFFBD 4 3
# NBFB 8 2
# DNHHH 5 4
# DHFBH 4 4
# FFFBN 4 2
# FFFBH 3 4
# DHNH 6 2
# NHDB 7 2
# HBDB 6 2
# DHFBD 5 0
# NHFBD 5 0
# DNHNH 5 3
# FNNDH 6 0
# DBNB 8 3
# DBNDH 5 3
# NHFBH 5 0
# FBNBD 4 4
# HBFB 6 1
# NNFN 6 1
# NFFBH 4 0
# FBFBN 5 0
# HHDBD 6 0
# DHFND 5 1
# DHDH 6 1
# FNHNB 4 2
# BHDBD 5 1
# NNFH 7 0
# HBD 8 4
# DFFND 5 4
# HHFFD 4 3
# NNFNH 4 1
# NHFH 6 1
# NBDN 7 4
# HHFBD 5 0
# BNNDH 5 2
# FBFN 7 3
# NHBH 7 1
# FDFN 8 4
# NBFN 7 1
# NHBB 7 0
# FBDBN 4 4
# NFFND 6 0
# FNNDB 5 3
# DNDDN 6 3
# BHFBD 4 3
# FNNNH 5 1
# DNFH 7 1
# FBFBD 5 0
# NHDBD 5 2
# DBFBN 5 2
# FNFN 6 2
# DNDBD 6 4
# NHFNH 4 4
# HHDBB 4 0
# HNN 5 4
# DBBB 6 3
# HNFBD 4 3
# DHDBD 6 0
# FBNDH 4 3
# ...

# %%
print("List of Statistically Significant Sequences at α = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_3)):
    if sum(freq >= fTC5_3[l] for freq in fTC5null_3[l]) < 1:
        print(setTC5_3[l], fTC5_3[l], sum(freq >= fTC5_3[l] for freq in fTC5null_3[l]))
#         print(setTC5_3[l])
# Out:
# List of Statistically Significant Sequences at α = 0.01
# HBF 9 0
# NHFB 7 0
# DDDH 7 0
# DHFBD 5 0
# NHFBD 5 0
# FNNDH 6 0
# NHFBH 5 0
# NFFBH 4 0
# FBFBN 5 0
# HHDBD 6 0
# NNFH 7 0
# HHFBD 5 0
# NHBB 7 0
# NFFND 6 0
# FBFBD 5 0
# HHDBB 4 0
# DHDBD 6 0

# %% [markdown]
# # 3.4 (B) AP - (D) AC - (F) BPI - (H) BLOOM - (R) MEG

# %%
#extract overlapping dates
start_4 = max(min(Date_AP), min(Date_AC), min(Date_BPI), min(Date_BLOOM), min(Date_MEG))
end_4 = min(max(Date_AP), max(Date_AC), max(Date_BPI), max(Date_BLOOM), max(Date_MEG))

# %%
#shorten the closing prices
AP_4_1 = Date_AP.index(start_4)
AP_4_2 = Date_AP.index(end_4)

AC_4_1 = Date_AC.index(start_4)
AC_4_2 = Date_AC.index(end_4)

BPI_4_1 = Date_BPI.index(start_4)
BPI_4_2 = Date_BPI.index(end_4)

BLOOM_4_1 = Date_BLOOM.index(start_4)
BLOOM_4_2 = Date_BLOOM.index(end_4)

MEG_4_1 = Date_MEG.index(start_4)
MEG_4_2 = Date_MEG.index(end_4)

# %%
#save the shortened versions of closing prices
B4 = np.save('APshortPrices.npy', ClosePrice_AP[AP_4_1:AP_4_2])
D4 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_4_1:AC_4_2])
F4 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_4_1:BPI_4_2])
H4 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_4_1:BLOOM_4_2])
R4 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_4_1:MEG_4_2])

# %%
# import modules
import numpy as np
# import prices

B4 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D4 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F4 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H4 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
R4 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_4 = []
st_4 = []
n = 1
while n < len(B4):
    sc_4 = ''
    if B4[n] > B4[n-1]:
        sc_4 = sc_4 + 'B'
    if D4[n] > D4[n-1]:
        sc_4 = sc_4 + 'D'
    if F4[n] > F4[n-1]:
        sc_4 = sc_4 + 'F'
    if H4[n] > H4[n-1]:
        sc_4 = sc_4 + 'H'
    if R4[n] > R4[n-1]:
        sc_4 = sc_4 + 'R'
    if len(sc_4) > 0:
        st_4.append(sc_4)
    else:
        STC_4.append(st_4)
        st_4 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_4 = STC_4.count([])
# keep only non-empty spatio-temporal sequences
STC_4 = [ st_4 for st_4 in STC_4 if len(st_4) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_4 = len(B4)
lmax_4 = 0
for st_4 in STC_4:
    if len(st_4) < lmin_4:
        lmin_4 = len(st_4)
    if len(st_4) > lmax_4:
        lmax_4 = len(st_4)
        
# restrict spatio-temporal sequences to length-5
STC5_4 = [ st_4 for st_4 in STC_4 if len(st_4) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_4 = []
for n in range(len(STC5_4)):
    tc_4 = [ u for u in STC5_4[n][0] ]
    for k in range(1, len(STC5_4[n])):
        tc_4 = [ u+v for u in tc_4 for v in STC5_4[n][k] ]
    TC5_4 = TC5_4 + tc_4
setTC5_4 = list(set(TC5_4))

# get empirical frequencies
fTC5_4 = [ TC5_4.count(setTC5_4[l]) for l in range(len(setTC5_4)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_4 = [ [] for l in range(len(setTC5_4)) ]
for s in range(100):
    STC5null_4 = [ list(st_4) for st_4 in STC5_4]
    for st_4 in STC5null_4:
        np.random.shuffle(st_4)
    TC5null_4= []
    for n in range(len(STC5null_4)):
        tc_4 = [ u for u in STC5null_4[n][0] ]
        for k in range(1, len(STC5null_4[n])):
            tc_4 = [ u+v for u in tc_4 for v in STC5null_4[n][k] ]
        TC5null_4= TC5null_4+ tc_4
    for l in range(len(setTC5_4)):
        if TC5null_4.count(setTC5_4[l]) > 0:
            fTC5null_4[l].append(TC5null_4.count(setTC5_4[l]))
        else:
            fTC5null_4[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_4)):
     if sum(freq >= fTC5_4[l] for freq in fTC5null_4[l]) < 5:
        print(setTC5_4[l], fTC5_4[l], sum(freq >= fTC5_4[l] for freq in fTC5null_4[l]))
#         print(setTC5_4[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# BDDRH 5 3
# DDDDH 4 2
# BFDRH 5 4
# DDDRB 6 2
# HFFDF 4 2
# BHHRB 4 3
# RDDRB 6 4
# BRDDH 5 2
# DBDDR 6 3
# FBFB 6 0
# FDBH 7 1
# FFDBH 4 4
# BRRRH 4 2
# FRFD 7 2
# DDBH 7 2
# RFBBD 5 1
# BHDRD 6 3
# RFBBB 3 3
# DRBH 5 1
# BBFRF 5 3
# HDHFB 4 0
# HFFRH 6 2
# RRFH 5 0
# HHBBD 5 0
# HHFDD 5 3
# HFFDD 5 0
# FRDRB 6 4
# HBFBF 4 2
# DDDH 5 0
# BHFRB 4 4
# HHDBR 5 1
# BHDRF 5 3
# HFFBD 5 1
# HFFFD 3 4
# FDDRH 6 0
# DRFD 8 2
# BBDDR 4 3
# FBDRH 4 3
# FHBH 6 1
# HHHFB 4 2
# DHFBD 5 1
# FHFBH 4 4
# RFBHD 4 4
# BFFRH 5 3
# HDDRH 5 2
# RRDDH 6 3
# BHFRD 6 0
# HFFHD 4 4
# HRFRH 6 1
# HFFRD 6 1
# HRFRF 6 0
# RFFBD 6 2
# RHFBD 5 3
# FBHB 6 2
# RRRRH 5 3
# RHDRH 6 1
# HHDBD 6 0
# RHDBH 5 2
# HHDRF 6 2
# RFDBH 6 0
# RRFRH 6 1
# DHBH 6 0
# DHDH 5 0
# RFDBD 6 4
# BHBH 5 2
# RFFBH 5 2
# DRFR 7 2
# BFFRF 6 1
# BHDBD 5 1
# HBFDF 5 1
# RDDRF 7 4
# FHDF 5 1
# HFBBD 4 3
# FRBH 5 1
# BDDDH 4 4
# DRFB 8 3
# HHFBD 6 0
# HHDRD 7 0
# RRBBH 3 3
# ...

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_4)):
     if sum(freq >= fTC5_4[l] for freq in fTC5null_4[l]) < 1:
#         print(setTC5_4[l], fTC5_4[l], sum(freq >= fTC5_4[l] for freq in fTC5null_4[l]))
        print(setTC5_4[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# FBFB
# HDHFB
# RRFH
# HHBBD
# HFFDD
# DDDH
# FDDRH
# BHFRD
# HRFRF
# HHDBD
# RFDBH
# DHBH
# DHDH
# HHFBD
# HHDRD
# HFFRF
# HHFRD
# FRDRH
# FRFB

# %% [markdown]
# # 3.5 (B) AP - (D) AC - (F) BPI - (H) BLOOM - (Y) SMC

# %%
#extract overlapping dates
start_5 = max(min(Date_AP), min(Date_AC), min(Date_BPI), min(Date_BLOOM), min(Date_SMC))
end_5 = min(max(Date_AP), max(Date_AC), max(Date_BPI), max(Date_BLOOM), max(Date_SMC))

# %%
#shorten the closing prices
AP_5_1 = Date_AP.index(start_5)
AP_5_2 = Date_AP.index(end_5)

AC_5_1 = Date_AC.index(start_5)
AC_5_2 = Date_AC.index(end_5)

BPI_5_1 = Date_BPI.index(start_5)
BPI_5_2 = Date_BPI.index(end_5)

BLOOM_5_1 = Date_BLOOM.index(start_5)
BLOOM_5_2 = Date_BLOOM.index(end_5)

SMC_5_1 = Date_SMC.index(start_5)
SMC_5_2 = Date_SMC.index(end_5)

# %%
#save the shortened versions of closing prices
B5 = np.save('APshortPrices.npy', ClosePrice_AP[AP_5_1:AP_5_2])
D5 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_5_1:AC_5_2])
F5 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_5_1:BPI_5_2])
H5 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_5_1:BLOOM_5_2])
Y5 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_5_1:SMC_5_2])

# %%
# import modules
import numpy as np
# import prices

B5 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D5 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F5 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H5 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
Y5 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_5 = []
st_5 = []
n = 1
while n < len(B5):
    sc_5 = ''
    if B5[n] > B5[n-1]:
        sc_5 = sc_5 + 'B'
    if D5[n] > D5[n-1]:
        sc_5 = sc_5 + 'D'
    if F5[n] > F5[n-1]:
        sc_5 = sc_5 + 'F'
    if H5[n] > H5[n-1]:
        sc_5 = sc_5 + 'H'
    if Y5[n] > Y5[n-1]:
        sc_5 = sc_5 + 'R'
    if len(sc_5) > 0:
        st_5.append(sc_5)
    else:
        STC_5.append(st_5)
        st_5 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_5 = STC_5.count([])
# keep only non-empty spatio-temporal sequences
STC_5 = [ st_5 for st_5 in STC_5 if len(st_5) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_5 = len(B5)
lmax_5 = 0
for st_5 in STC_5:
    if len(st_5) < lmin_5:
        lmin_5 = len(st_5)
    if len(st_5) > lmax_5:
        lmax_5 = len(st_5)
        
# restrict spatio-temporal sequences to length-5
STC5_5 = [ st_5 for st_5 in STC_5 if len(st_5) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_5 = []
for n in range(len(STC5_5)):
    tc_5 = [ u for u in STC5_5[n][0] ]
    for k in range(1, len(STC5_5[n])):
        tc_5 = [ u+v for u in tc_5 for v in STC5_5[n][k] ]
    TC5_5 = TC5_5 + tc_5
setTC5_5 = list(set(TC5_5))

# get empirical frequencies
fTC5_5 = [ TC5_5.count(setTC5_5[l]) for l in range(len(setTC5_5)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_5 = [ [] for l in range(len(setTC5_5)) ]
for s in range(100):
    STC5null_5 = [ list(st_5) for st_5 in STC5_5]
    for st_5 in STC5null_5:
        np.random.shuffle(st_5)
    TC5null_5= []
    for n in range(len(STC5null_5)):
        tc_5 = [ u for u in STC5null_5[n][0] ]
        for k in range(1, len(STC5null_5[n])):
            tc_5 = [ u+v for u in tc_5 for v in STC5null_5[n][k] ]
        TC5null_5= TC5null_5+ tc_5
    for l in range(len(setTC5_5)):
        if TC5null_5.count(setTC5_5[l]) > 0:
            fTC5null_5[l].append(TC5null_5.count(setTC5_5[l]))
        else:
            fTC5null_5[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_5)):
     if sum(freq >= fTC5_5[l] for freq in fTC5null_5[l]) < 5:
        print(setTC5_5[l], fTC5_5[l], sum(freq >= fTC5_5[l] for freq in fTC5null_5[l]))
#         print(setTC5_5[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# BFRBD 4 0
# BBRHF 2 2
# HHRFD 3 3
# HBRBF 2 2
# RFFDR 4 4
# HDRFD 3 2
# HFDHR 3 1
# RDDDR 3 4
# RHBR 4 4
# RFRDF 4 2
# RRBDR 3 0
# HBFF 5 1
# DRDB 7 4
# HDHFB 3 4
# HHBBD 4 0
# BDDDB 4 3
# HHFDD 4 1
# HFFDD 4 1
# HBFBF 3 1
# DDDH 7 1
# HHDBR 3 3
# HFFBD 5 0
# HRDB 6 0
# RHRFF 2 2
# HFFFD 4 0
# RFBHR 2 3
# RDDDB 4 2
# HDRFB 3 1
# BDDDF 5 2
# HBDB 6 0
# HBRRF 2 0
# FFR 9 4
# FRRR 6 1
# HRFF 4 2
# HHDHR 3 1
# HFFHD 4 1
# FHBR 4 4
# FRBB 6 4
# HBFHF 3 4
# FRRB 6 0
# HHDBD 4 0
# HHBBR 3 0
# RFBBR 3 1
# HFBBR 2 1
# HBDF 6 2
# FRDB 8 1
# BDRDD 4 1
# DHDH 6 1
# BFDHR 3 1
# HDDF 6 3
# BHBH 5 4
# HHFBR 3 2
# RHRFD 3 1
# HFBBD 4 0
# BFBHR 2 2
# BFRDD 5 0
# BBRDD 3 4
# RHDDD 3 0
# BDDDH 3 3
# DBFBD 5 2
# RHFDD 3 1
# RHDBD 3 1
# HDFF 5 2
# HHFBD 5 1
# BHH 4 1
# HFRFD 3 3
# RFBDR 4 3
# HFDBD 4 1
# HRDF 5 3
# HHDDD 3 2
# HRBBD 2 3
# RHBH 6 1
# DFDHR 3 2
# RFDDR 5 0
# BFRBF 4 1
# RRDDR 3 1
# HHBBF 3 2
# HFDFD 4 2
# HHRFF 3 3
# FRFB 6 3
# ...

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_5)):
     if sum(freq >= fTC5_5[l] for freq in fTC5null_5[l]) < 1:
        print(setTC5_5[l], fTC5_5[l], sum(freq >= fTC5_5[l] for freq in fTC5null_5[l]))
#         print(setTC5_5[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# BFRBD 4 0
# RRBDR 3 0
# HHBBD 4 0
# HFFBD 5 0
# HRDB 6 0
# HFFFD 4 0
# HBDB 6 0
# HBRRF 2 0
# FRRB 6 0
# HHDBD 4 0
# HHBBR 3 0
# HFBBD 4 0
# BFRDD 5 0
# RHDDD 3 0
# RFDDR 5 0
# BFRDF 5 0
# FHBBB 2 0
# DHBBD 3 0

# %% [markdown]
# # 3.6 (B) AP - (D) AC - (F) BPI - (H) BLOOM - (α) SCC

# %%
#extract overlapping dates
start_6 = max(min(Date_AP), min(Date_AC), min(Date_BPI), min(Date_BLOOM), min(Date_SCC))
end_6 = min(max(Date_AP), max(Date_AC), max(Date_BPI), max(Date_BLOOM), max(Date_SCC))

# %%
#shorten the closing prices
AP_6_1 = Date_AP.index(start_6)
AP_6_2 = Date_AP.index(end_6)

AC_6_1 = Date_AC.index(start_6)
AC_6_2 = Date_AC.index(end_6)

BPI_6_1 = Date_BPI.index(start_6)
BPI_6_2 = Date_BPI.index(end_6)

BLOOM_6_1 = Date_BLOOM.index(start_6)
BLOOM_6_2 = Date_BLOOM.index(end_6)

SCC_6_1 = Date_SCC.index(start_6)
SCC_6_2 = Date_SCC.index(end_6)

# %%
#save the shortened versions of closing prices
B6 = np.save('APshortPrices.npy', ClosePrice_AP[AP_6_1:AP_6_2])
D6 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_6_1:AC_6_2])
F6 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_6_1:BPI_6_2])
H6 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_6_1:BLOOM_6_2])
α6 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_6_1:SCC_6_2])

# %%
# import modules
import numpy as np
# import prices

B6 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D6 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F6 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H6 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
α6 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_6 = []
st_6 = []
n = 1
while n < len(B6):
    sc_6 = ''
    if B6[n] > B6[n-1]:
        sc_6 = sc_6 + 'B'
    if D6[n] > D6[n-1]:
        sc_6 = sc_6 + 'D'
    if F6[n] > F6[n-1]:
        sc_6 = sc_6 + 'F'
    if H6[n] > H6[n-1]:
        sc_6 = sc_6 + 'H'
    if α6[n] > α6[n-1]:
        sc_6 = sc_6 + 'α'
    if len(sc_6) > 0:
        st_6.append(sc_6)
    else:
        STC_6.append(st_6)
        st_6 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_6 = STC_6.count([])
# keep only non-empty spatio-temporal sequences
STC_6 = [ st_6 for st_6 in STC_6 if len(st_6) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_6 = len(B6)
lmax_6 = 0
for st_6 in STC_6:
    if len(st_6) < lmin_6:
        lmin_6 = len(st_6)
    if len(st_6) > lmax_6:
        lmax_6 = len(st_6)
        
# restrict spatio-temporal sequences to length-5
STC5_6 = [ st_6 for st_6 in STC_6 if len(st_6) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_6 = []
for n in range(len(STC5_6)):
    tc_6 = [ u for u in STC5_6[n][0] ]
    for k in range(1, len(STC5_6[n])):
        tc_6 = [ u+v for u in tc_6 for v in STC5_6[n][k] ]
    TC5_6 = TC5_6 + tc_6
setTC5_6 = list(set(TC5_6))

# get empirical frequencies
fTC5_6 = [ TC5_6.count(setTC5_6[l]) for l in range(len(setTC5_6)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_6 = [ [] for l in range(len(setTC5_6)) ]
for s in range(100):
    STC5null_6 = [ list(st_6) for st_6 in STC5_6]
    for st_6 in STC5null_6:
        np.random.shuffle(st_6)
    TC5null_6= []
    for n in range(len(STC5null_6)):
        tc_6 = [ u for u in STC5null_6[n][0] ]
        for k in range(1, len(STC5null_6[n])):
            tc_6 = [ u+v for u in tc_6 for v in STC5null_6[n][k] ]
        TC5null_6= TC5null_6+ tc_6
    for l in range(len(setTC5_6)):
        if TC5null_6.count(setTC5_6[l]) > 0:
            fTC5null_6[l].append(TC5null_6.count(setTC5_6[l]))
        else:
            fTC5null_6[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_6)):
     if sum(freq >= fTC5_6[l] for freq in fTC5null_6[l]) < 5:
        print(setTC5_6[l], fTC5_6[l], sum(freq >= fTC5_6[l] for freq in fTC5null_6[l]))
#           print(setTC5_6[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# αFαBα 5 2
# αBαBα 5 0
# DDDDH 4 2
# HDFαα 4 2
# BFHα 5 4
# FαBα 7 4
# HFFDF 3 1
# HDHHD 4 1
# FDHBB 3 3
# FBFB 6 3
# Hαααα 3 3
# FFααB 4 0
# DDF 11 4
# FFBα 6 1
# HDHFα 4 4
# BHHHD 3 2
# BFBα 7 2
# FαHFD 4 1
# HBFBF 3 1
# FFBD 6 2
# HαHFα 4 4
# DαFBD 5 3
# FFBαα 4 3
# FFDαα 4 2
# FFααα 6 0
# FHBH 4 2
# HDHFD 4 4
# FBHα 6 1
# FBBα 8 1
# αFHα 5 4
# HHααα 4 1
# FBαBα 6 0
# FFαBα 5 0
# HBFHF 3 4
# HHFαα 5 1
# HαDFD 4 2
# FBHB 6 0
# ααDH 5 4
# HFFBF 3 0
# HαF 8 2
# HHFBα 4 4
# αFHD 5 3
# HDHαα 4 2
# HαHαD 4 1
# HDHαD 4 2
# FFDBα 4 3
# DHDH 4 0
# BHBH 4 3
# αFDBα 5 3
# HDDHα 4 3
# FDHFB 3 3
# αHDH 4 2
# FHDα 5 4
# BFFBF 3 4
# FHDH 4 1
# HHFBD 4 3
# FDHHD 4 2
# BDDBH 4 2
# HαααD 4 2
# HDHHα 4 2
# HBααα 3 3
# FFHD 4 3
# αHBH 4 3
# HDααα 4 3
# Bα 16 4
# FBααα 5 1
# FBDαα 4 4
# BFFαF 3 1
# FBFBD 5 2
# DBDF 8 2
# DBαBα 5 1
# FDDBH 4 1
# HDαD 5 3
# FBDB 8 3
# FFHα 5 0
# HHDαα 5 1
# HHFBF 3 3
# FHBα 5 2
# HHααB 3 3
# FBααB 4 1
# DHFBα 4 4
# ...

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_6)):
     if sum(freq >= fTC5_6[l] for freq in fTC5null_6[l]) < 1:
        print(setTC5_6[l], fTC5_6[l], sum(freq >= fTC5_6[l] for freq in fTC5null_6[l]))
#         print(setTC5_6[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# αBαBα 5 0
# FFααB 4 0
# FFααα 6 0
# FBαBα 6 0
# FFαBα 5 0
# FBHB 6 0
# HFFBF 3 0
# DHDH 4 0
# FFHα 5 0

# %% [markdown]
# # 3.7 (B) AP - (D) AC - (F) BPI - (J) FGEN - (M) ICT

# %%
#extract overlapping dates
start_7 = max(min(Date_AP), min(Date_AC), min(Date_BPI), min(Date_FGEN), min(Date_ICT))
end_7 = min(max(Date_AP), max(Date_AC), max(Date_BPI), max(Date_FGEN), max(Date_ICT))

# %%
#shorten the closing prices
AP_7_1 = Date_AP.index(start_7)
AP_7_2 = Date_AP.index(end_7)

AC_7_1 = Date_AC.index(start_7)
AC_7_2 = Date_AC.index(end_7)

BPI_7_1 = Date_BPI.index(start_7)
BPI_7_2 = Date_BPI.index(end_7)

FGEN_7_1 = Date_FGEN.index(start_7)
FGEN_7_2 = Date_FGEN.index(end_7)

ICT_7_1 = Date_ICT.index(start_7)
ICT_7_2 = Date_ICT.index(end_7)

# %%
#save the shortened versions of closing prices
B7 = np.save('APshortPrices.npy', ClosePrice_AP[AP_7_1:AP_7_2])
D7 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_7_1:AC_7_2])
F7 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_7_1:BPI_7_2])
J7 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_7_1:FGEN_7_2])
M7 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_7_1:ICT_7_2])

# %%
# import modules
import numpy as np
# import prices

B7 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D7 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F7 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J7 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M7 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_7 = []
st_7 = []
n = 1
while n < len(B7):
    sc_7 = ''
    if B7[n] > B7[n-1]:
        sc_7 = sc_7 + 'B'
    if D7[n] > D7[n-1]:
        sc_7 = sc_7 + 'D'
    if F7[n] > F7[n-1]:
        sc_7 = sc_7 + 'F'
    if J7[n] > J7[n-1]:
        sc_7 = sc_7 + 'J'
    if M7[n] > M7[n-1]:
        sc_7 = sc_7 + 'M'
    if len(sc_7) > 0:
        st_7.append(sc_7)
    else:
        STC_7.append(st_7)
        st_7 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_7 = STC_7.count([])
# keep only non-empty spatio-temporal sequences
STC_7 = [ st_7 for st_7 in STC_7 if len(st_7) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_7 = len(B7)
lmax_7 = 0
for st_7 in STC_7:
    if len(st_7) < lmin_7:
        lmin_7 = len(st_7)
    if len(st_7) > lmax_7:
        lmax_7 = len(st_7)
        
# restrict spatio-temporal sequences to length-5
STC5_7 = [ st_7 for st_7 in STC_7 if len(st_7) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_7 = []
for n in range(len(STC5_7)):
    tc_7 = [ u for u in STC5_7[n][0] ]
    for k in range(1, len(STC5_7[n])):
        tc_7 = [ u+v for u in tc_7 for v in STC5_7[n][k] ]
    TC5_7 = TC5_7 + tc_7
setTC5_7 = list(set(TC5_7))

# get empirical frequencies
fTC5_7 = [ TC5_7.count(setTC5_7[l]) for l in range(len(setTC5_7)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_7 = [ [] for l in range(len(setTC5_7)) ]
for s in range(100):
    STC5null_7 = [ list(st_7) for st_7 in STC5_7]
    for st_7 in STC5null_7:
        np.random.shuffle(st_7)
    TC5null_7= []
    for n in range(len(STC5null_7)):
        tc_7 = [ u for u in STC5null_7[n][0] ]
        for k in range(1, len(STC5null_7[n])):
            tc_7 = [ u+v for u in tc_7 for v in STC5null_7[n][k] ]
        TC5null_7= TC5null_7+ tc_7
    for l in range(len(setTC5_7)):
        if TC5null_7.count(setTC5_7[l]) > 0:
            fTC5null_7[l].append(TC5null_7.count(setTC5_7[l]))
        else:
            fTC5null_7[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_7)):
     if sum(freq >= fTC5_7[l] for freq in fTC5null_7[l]) < 5:
        print(setTC5_7[l], fTC5_7[l], sum(freq >= fTC5_7[l] for freq in fTC5null_7[l]))
#         print(setTC5_7[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FFDJD 4 4
# FJFB 5 1
# FDDJD 4 2
# FMBF 5 4
# MDDBB 6 0
# MFBJB 4 3
# FFBJD 5 0
# MFMDD 4 3
# DMDJ 8 3
# FBFB 6 1
# DBJMF 4 2
# MFMDB 4 2
# FFBJB 4 2
# DMFJ 8 0
# FFBMD 4 4
# MFMJB 4 2
# MDFDD 5 1
# FDBJJ 3 4
# MFFBB 4 4
# BFMBB 4 2
# BJDMM 4 3
# MDM 9 3
# MFMJF 5 0
# FFFJF 5 0
# MFMJD 4 3
# BDDDB 5 3
# MFMBD 5 1
# BDDDD 4 4
# DBJFJ 4 0
# MFFDB 5 1
# FFMDD 5 4
# MDDMB 5 1
# MBMJM 3 4
# BFFDD 5 3
# BBDMM 4 3
# MDDBD 5 4
# FFJJD 4 2
# DDFJ 6 2
# MDFDF 5 0
# MFMJM 4 1
# MMDB 8 3
# MFMBF 4 3
# JMBJ 8 0
# FFMJD 5 1
# BFFDB 5 0
# FDBJD 4 2
# MFFJF 4 1
# MMFJ 6 1
# BDFDD 5 3
# BJJDJ 3 4
# MMFM 7 3
# BFFBB 4 0
# FFMMD 4 4
# DMBJ 9 1
# MFFDD 5 2
# MMFB 8 0
# MMDJ 8 4
# MFBJD 4 3
# MDFBB 5 3
# FBF 10 4
# BFFDF 5 2
# DMFM 8 1
# FFMDF 5 2
# FFMBF 4 3
# JMFM 6 3
# MDDMD 4 4
# BBFMM 4 3
# FJBJ 6 1
# FBFJF 5 0
# DMDB 8 3
# BFMDF 5 2
# FFFDD 4 3
# BJJDD 3 4
# BFDBJ 4 0
# FJJJJ 2 4
# BDFBB 5 2
# DBFJF 4 4
# BFMDJ 4 4
# DMFB 8 1
# BBDBJ 4 1
# ...

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_7)):
     if sum(freq >= fTC5_7[l] for freq in fTC5null_7[l]) < 1:
        print(setTC5_7[l], fTC5_7[l], sum(freq >= fTC5_7[l] for freq in fTC5null_7[l]))
#         print(setTC5_7[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# MDDBB 6 0
# FFBJD 5 0
# DMFJ 8 0
# MFMJF 5 0
# FFFJF 5 0
# DBJFJ 4 0
# MDFDF 5 0
# JMBJ 8 0
# BFFDB 5 0
# BFFBB 4 0
# MMFB 8 0
# FBFJF 5 0
# BFDBJ 4 0
# FMFF 4 0
# BDDBB 5 0

# %% [markdown]
# # 3.8 (B) AP - (D) AC - (F) BPI - (J) FGEN - (N) JGS

# %%
#extract overlapping dates
start_8 = max(min(Date_AP), min(Date_AC), min(Date_BPI), min(Date_FGEN), min(Date_JGS))
end_8 = min(max(Date_AP), max(Date_AC), max(Date_BPI), max(Date_FGEN), max(Date_JGS))

# %%
#shorten the closing prices
AP_8_1 = Date_AP.index(start_8)
AP_8_2 = Date_AP.index(end_8)

AC_8_1 = Date_AC.index(start_8)
AC_8_2 = Date_AC.index(end_8)

BPI_8_1 = Date_BPI.index(start_8)
BPI_8_2 = Date_BPI.index(end_8)

FGEN_8_1 = Date_FGEN.index(start_8)
FGEN_8_2 = Date_FGEN.index(end_8)

JGS_8_1 = Date_JGS.index(start_8)
JGS_8_2 = Date_JGS.index(end_8)

# %%
#save the shortened versions of closing prices
B8 = np.save('APshortPrices.npy', ClosePrice_AP[AP_8_1:AP_8_2])
D8 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_8_1:AC_8_2])
F8 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_8_1:BPI_8_2])
J8 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_8_1:FGEN_8_2])
N8 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_8_1:JGS_8_2])

# %%
# import modules
import numpy as np
# import prices

B8 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D8 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F8 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J8 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N8 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_8 = []
st_8 = []
n = 1
while n < len(B8):
    sc_8 = ''
    if B8[n] > B8[n-1]:
        sc_8 = sc_8 + 'B'
    if D8[n] > D8[n-1]:
        sc_8 = sc_8 + 'D'
    if F8[n] > F8[n-1]:
        sc_8 = sc_8 + 'F'
    if J8[n] > J8[n-1]:
        sc_8 = sc_8 + 'J'
    if N8[n] > N8[n-1]:
        sc_8 = sc_8 + 'M'
    if len(sc_8) > 0:
        st_8.append(sc_8)
    else:
        STC_8.append(st_8)
        st_8 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_8 = STC_8.count([])
# keep only non-empty spatio-temporal sequences
STC_8 = [ st_8 for st_8 in STC_8 if len(st_8) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_8 = len(B8)
lmax_8 = 0
for st_8 in STC_8:
    if len(st_8) < lmin_8:
        lmin_8 = len(st_8)
    if len(st_8) > lmax_8:
        lmax_8 = len(st_8)
        
# restrict spatio-temporal sequences to length-5
STC5_8 = [ st_8 for st_8 in STC_8 if len(st_8) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_8 = []
for n in range(len(STC5_8)):
    tc_8 = [ u for u in STC5_8[n][0] ]
    for k in range(1, len(STC5_8[n])):
        tc_8 = [ u+v for u in tc_8 for v in STC5_8[n][k] ]
    TC5_8 = TC5_8 + tc_8
setTC5_8 = list(set(TC5_8))

# get empirical frequencies
fTC5_8 = [ TC5_8.count(setTC5_8[l]) for l in range(len(setTC5_8)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_8 = [ [] for l in range(len(setTC5_8)) ]
for s in range(100):
    STC5null_8 = [ list(st_8) for st_8 in STC5_8]
    for st_8 in STC5null_8:
        np.random.shuffle(st_8)
    TC5null_8= []
    for n in range(len(STC5null_8)):
        tc_8 = [ u for u in STC5null_8[n][0] ]
        for k in range(1, len(STC5null_8[n])):
            tc_8 = [ u+v for u in tc_8 for v in STC5null_8[n][k] ]
        TC5null_8= TC5null_8+ tc_8
    for l in range(len(setTC5_8)):
        if TC5null_8.count(setTC5_8[l]) > 0:
            fTC5null_8[l].append(TC5null_8.count(setTC5_8[l]))
        else:
            fTC5null_8[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_8)):
     if sum(freq >= fTC5_8[l] for freq in fTC5null_8[l]) < 5:
        print(setTC5_8[l], fTC5_8[l], sum(freq >= fTC5_8[l] for freq in fTC5null_8[l]))
#         print(setTC5_8[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FJBB 6 2
# MBDBJ 4 1
# BJJMJ 3 2
# BJJDF 4 0
# FJFB 6 3
# BDJBB 3 0
# FBFB 6 2
# JFMBM 4 2
# MJJMJ 3 2
# DMFJ 7 4
# FJDMB 4 3
# JBJB 6 1
# MBFM 7 0
# FJBMJ 3 4
# DDF 8 3
# MJ 23 4
# BDJDB 5 1
# JBFM 8 1
# MFDMJ 5 0
# BDDDB 6 1
# MBDM 7 2
# MFJMJ 4 3
# JJF 10 0
# JBMD 7 2
# JBMM 7 1
# DDDFB 5 2
# BDDFB 5 3
# FFDDM 5 3
# JDMDD 4 3
# MMFJ 6 2
# BJJDJ 4 0
# BFDBM 4 3
# MMFM 6 1
# BDFBJ 3 4
# DDMFB 5 4
# FMDDM 5 1
# MJJJJ 2 4
# BJDDF 4 3
# JBFD 8 1
# FJDFB 3 1
# JDMFM 5 1
# JMMDM 4 4
# MDJJJ 3 3
# FFMDF 5 0
# FJBJ 6 1
# DBJB 7 1
# BJJFB 3 0
# BJJDD 4 0
# BFDBB 4 3
# JDMBM 5 0
# BJDDD 4 0
# BDFBB 5 0
# JDMBB 3 4
# BJJDB 4 0
# BMJDB 4 4
# BDDBM 5 3
# JMMBD 4 1
# MBMM 6 3
# BDDBB 6 0
# BBJDJ 3 2
# JDMBD 4 2
# BJJDM 3 4
# JFMBD 4 3
# FFBMJ 5 0
# DDDM 7 3
# JDF 9 1
# DJJFB 3 0
# BJDDJ 4 1
# JFMFM 4 4
# MBFB 6 4
# FFMMF 4 0
# MFDBJ 4 4
# FJFM 5 4
# BJDDB 4 2
# DJF 8 4
# FFJMD 5 3
# MFFJ 6 1
# JJJM 5 4
# FFJMJ 5 1
# FDJJJ 3 0
# FMFM 5 3
# ...

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_8)):
     if sum(freq >= fTC5_8[l] for freq in fTC5null_8[l]) < 1:
        print(setTC5_8[l], fTC5_8[l], sum(freq >= fTC5_8[l] for freq in fTC5null_8[l]))
#         print(setTC5_8[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# BJJDF 4 0
# BDJBB 3 0
# MBFM 7 0
# MFDMJ 5 0
# JJF 10 0
# BJJDJ 4 0
# FFMDF 5 0
# BJJFB 3 0
# BJJDD 4 0
# JDMBM 5 0
# BJDDD 4 0
# BDFBB 5 0
# BJJDB 4 0
# BDDBB 6 0
# FFBMJ 5 0
# DJJFB 3 0
# FFMMF 4 0
# FDJJJ 3 0
# JMMBM 4 0
# FFDMJ 5 0
# JBDM 8 0
# DDDB 9 0

# %% [markdown]
# # 3.9 (B) AP - (D) AC - (F) BPI - (J) FGEN - (R) MEG

# %%
#extract overlapping dates
start_9 = max(min(Date_AP), min(Date_AC), min(Date_BPI), min(Date_FGEN), min(Date_MEG))
end_9 = min(max(Date_AP), max(Date_AC), max(Date_BPI), max(Date_FGEN), max(Date_MEG))

# %%
#shorten the closing prices
AP_9_1 = Date_AP.index(start_9)
AP_9_2 = Date_AP.index(end_9)

AC_9_1 = Date_AC.index(start_9)
AC_9_2 = Date_AC.index(end_9)

BPI_9_1 = Date_BPI.index(start_9)
BPI_9_2 = Date_BPI.index(end_9)

FGEN_9_1 = Date_FGEN.index(start_9)
FGEN_9_2 = Date_FGEN.index(end_9)

MEG_9_1 = Date_MEG.index(start_9)
MEG_9_2 = Date_MEG.index(end_9)

# %%
#save the shortened versions of closing prices
B9 = np.save('APshortPrices.npy', ClosePrice_AP[AP_9_1:AP_9_2])
D9 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_9_1:AC_9_2])
F9 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_9_1:BPI_9_2])
J9 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_9_1:FGEN_9_2])
R9 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_9_1:MEG_9_2])

# %%
# import modules
import numpy as np
# import prices

B9 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D9 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F9 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J9 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
R9 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_9 = []
st_9 = []
n = 1
while n < len(B9):
    sc_9 = ''
    if B9[n] > B9[n-1]:
        sc_9 = sc_9 + 'B'
    if D9[n] > D9[n-1]:
        sc_9 = sc_9 + 'D'
    if F9[n] > F9[n-1]:
        sc_9 = sc_9 + 'F'
    if J9[n] > J9[n-1]:
        sc_9 = sc_9 + 'J'
    if R9[n] > R9[n-1]:
        sc_9 = sc_9 + 'R'
    if len(sc_9) > 0:
        st_9.append(sc_9)
    else:
        STC_9.append(st_9)
        st_9 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_9 = STC_9.count([])
# keep only non-empty spatio-temporal sequences
STC_9 = [ st_9 for st_9 in STC_9 if len(st_9) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_9 = len(B9)
lmax_9 = 0
for st_9 in STC_9:
    if len(st_9) < lmin_9:
        lmin_9 = len(st_9)
    if len(st_9) > lmax_9:
        lmax_9 = len(st_9)
        
# restrict spatio-temporal sequences to length-5
STC5_9 = [ st_9 for st_9 in STC_9 if len(st_9) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_9 = []
for n in range(len(STC5_9)):
    tc_9 = [ u for u in STC5_9[n][0] ]
    for k in range(1, len(STC5_9[n])):
        tc_9 = [ u+v for u in tc_9 for v in STC5_9[n][k] ]
    TC5_9 = TC5_9 + tc_9
setTC5_9 = list(set(TC5_9))

# get empirical frequencies
fTC5_9 = [ TC5_9.count(setTC5_9[l]) for l in range(len(setTC5_9)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_9 = [ [] for l in range(len(setTC5_9)) ]
for s in range(100):
    STC5null_9 = [ list(st_9) for st_9 in STC5_9]
    for st_9 in STC5null_9:
        np.random.shuffle(st_9)
    TC5null_9= []
    for n in range(len(STC5null_9)):
        tc_9 = [ u for u in STC5null_9[n][0] ]
        for k in range(1, len(STC5null_9[n])):
            tc_9 = [ u+v for u in tc_9 for v in STC5null_9[n][k] ]
        TC5null_9= TC5null_9+ tc_9
    for l in range(len(setTC5_9)):
        if TC5null_9.count(setTC5_9[l]) > 0:
            fTC5null_9[l].append(TC5null_9.count(setTC5_9[l]))
        else:
            fTC5null_9[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_9)):
     if sum(freq >= fTC5_9[l] for freq in fTC5null_9[l]) < 5:
        print(setTC5_9[l], fTC5_9[l], sum(freq >= fTC5_9[l] for freq in fTC5null_9[l]))
#         print(setTC5_9[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# BJJDF 4 1
# RJJFD 4 3
# FJFB 8 0
# FJRB 7 1
# BJJRR 4 2
# RJD 10 1
# BDDDJ 4 4
# RDDRB 8 1
# BDDRB 7 0
# DBDDR 6 1
# FBFB 5 2
# RJJFJ 3 1
# DBJRF 4 2
# DRJB 8 1
# FJFJ 5 2
# RFBBD 5 3
# FRDJR 5 4
# FRBJR 5 0
# RDDFB 6 1
# RRFJ 6 4
# FDFB 7 1
# DBJDR 5 3
# RFBBB 4 0
# BBBDJ 3 4
# BBFRF 5 2
# BBJDR 5 0
# BDJDB 4 2
# BDDDB 6 0
# BFFRB 5 2
# BDDRF 6 3
# DBJFJ 4 0
# RDDBB 6 0
# BDDFB 5 2
# DRFD 8 1
# BBJFR 5 0
# DFFJ 6 3
# DBDFR 5 4
# BDDDF 6 3
# BBJRJ 4 2
# BJDRJ 4 4
# BJJFJ 3 1
# RDJRB 5 3
# RJJRR 4 1
# RRDB 6 4
# BJJDJ 4 1
# DBJFR 6 1
# RJJFR 4 1
# RJRB 6 4
# BJDDF 4 3
# BJFBJ 3 4
# FBRB 6 4
# RJJDR 4 2
# DJJFR 4 3
# BBDDF 5 2
# RDBBB 4 3
# BJJRJ 3 2
# BFFDF 5 4
# BJJFF 3 2
# RFDBD 6 3
# BBJFJ 3 1
# BJJFR 4 0
# DJJB 5 4
# RDFRB 7 3
# BFFRD 5 3
# BFFRF 7 0
# DFFD 5 4
# BBDRJ 4 3
# RJJFB 4 3
# BJJFB 3 3
# RDDRF 7 1
# RRJB 8 2
# BJFDJ 4 1
# RFFJ 6 3
# BFDBJ 4 4
# BDFRB 5 3
# BJDDD 4 1
# BDFBB 4 3
# DRFB 10 1
# BJJDB 3 4
# ...

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_9)):
     if sum(freq >= fTC5_9[l] for freq in fTC5null_9[l]) < 1:
        print(setTC5_9[l], fTC5_9[l], sum(freq >= fTC5_9[l] for freq in fTC5null_9[l]))
#         print(setTC5_9[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# FJFB 8 0
# BDDRB 7 0
# FRBJR 5 0
# RFBBB 4 0
# BBJDR 5 0
# BDDDB 6 0
# DBJFJ 4 0
# RDDBB 6 0
# BBJFR 5 0
# BJJFR 4 0
# BFFRF 7 0
# BBJDJ 4 0
# BJDDJ 5 0
# DBJRR 6 0
# BDDBJ 5 0
# FRFB 9 0
# BJBDJ 4 0
# BBJDF 4 0
# RRFB 10 0

# %% [markdown]
# # 3.10 (B) AP - (D) AC - (F) BPI - (J) FGEN - (Y) SMC

# %%
#extract overlapping dates
start_10 = max(min(Date_AP), min(Date_AC), min(Date_BPI), min(Date_FGEN), min(Date_SMC))
end_10 = min(max(Date_AP), max(Date_AC), max(Date_BPI), max(Date_FGEN), max(Date_SMC))

# %%
#shorten the closing prices
AP_10_1 = Date_AP.index(start_10)
AP_10_2 = Date_AP.index(end_10)

AC_10_1 = Date_AC.index(start_10)
AC_10_2 = Date_AC.index(end_10)

BPI_10_1 = Date_BPI.index(start_10)
BPI_10_2 = Date_BPI.index(end_10)

FGEN_10_1 = Date_FGEN.index(start_10)
FGEN_10_2 = Date_FGEN.index(end_10)

SMC_10_1 = Date_SMC.index(start_10)
SMC_10_2 = Date_SMC.index(end_10)

# %%
#save the shortened versions of closing prices
B10 = np.save('APshortPrices.npy', ClosePrice_AP[AP_10_1:AP_10_2])
D10 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_10_1:AC_10_2])
F10 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_10_1:BPI_10_2])
J10 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_10_1:FGEN_10_2])
Y10 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_10_1:SMC_10_2])

# %%
# import modules
import numpy as np
# import prices

B10 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D10 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F10 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J10 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
Y10 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_10 = []
st_10 = []
n = 1
while n < len(B10):
    sc_10 = ''
    if B10[n] > B10[n-1]:
        sc_10 = sc_10 + 'B'
    if D10[n] > D10[n-1]:
        sc_10 = sc_10 + 'D'
    if F10[n] > F10[n-1]:
        sc_10 = sc_10 + 'F'
    if J10[n] > J10[n-1]:
        sc_10 = sc_10 + 'J'
    if Y10[n] > Y10[n-1]:
        sc_10 = sc_10 + 'Y'
    if len(sc_10) > 0:
        st_10.append(sc_10)
    else:
        STC_10.append(st_10)
        st_10 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_10 = STC_10.count([])
# keep only non-empty spatio-temporal sequences
STC_10 = [ st_10 for st_10 in STC_10 if len(st_10) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_10 = len(B10)
lmax_10 = 0
for st_10 in STC_10:
    if len(st_10) < lmin_10:
        lmin_10 = len(st_10)
    if len(st_10) > lmax_10:
        lmax_10 = len(st_10)
        
# restrict spatio-temporal sequences to length-5
STC5_10 = [ st_10 for st_10 in STC_10 if len(st_10) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_10 = []
for n in range(len(STC5_10)):
    tc_10 = [ u for u in STC5_10[n][0] ]
    for k in range(1, len(STC5_10[n])):
        tc_10 = [ u+v for u in tc_10 for v in STC5_10[n][k] ]
    TC5_10 = TC5_10 + tc_10
setTC5_10 = list(set(TC5_10))

# get empirical frequencies
fTC5_10 = [ TC5_10.count(setTC5_10[l]) for l in range(len(setTC5_10)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_10 = [ [] for l in range(len(setTC5_10)) ]
for s in range(100):
    STC5null_10 = [ list(st_10) for st_10 in STC5_10]
    for st_10 in STC5null_10:
        np.random.shuffle(st_10)
    TC5null_10= []
    for n in range(len(STC5null_10)):
        tc_10 = [ u for u in STC5null_10[n][0] ]
        for k in range(1, len(STC5null_10[n])):
            tc_10 = [ u+v for u in tc_10 for v in STC5null_10[n][k] ]
        TC5null_10= TC5null_10+ tc_10
    for l in range(len(setTC5_10)):
        if TC5null_10.count(setTC5_10[l]) > 0:
            fTC5null_10[l].append(TC5null_10.count(setTC5_10[l]))
        else:
            fTC5null_10[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_10)):
     if sum(freq >= fTC5_10[l] for freq in fTC5null_10[l]) < 5:
        print(setTC5_10[l], fTC5_10[l], sum(freq >= fTC5_10[l] for freq in fTC5null_10[l]))
#         print(setTC5_10[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FJBB 6 2
# BJJDF 3 4
# FJFB 6 2
# FFBJD 3 4
# BJBDY 3 0
# BDDDJ 4 0
# FBYY 5 4
# YYBJ 8 2
# FBFB 6 0
# BJFBY 3 0
# DYBJ 6 4
# YYDDY 3 3
# YJFDY 3 1
# FDFB 6 2
# FYYB 6 1
# YDDJ 5 3
# FYJJD 3 1
# BDJDB 4 0
# JJD 8 3
# YFDDY 5 0
# YFFDY 4 0
# BDDDB 5 0
# BDJBJ 3 2
# FYYY 7 1
# DDDJ 6 2
# JBFJF 3 1
# FYBYD 3 4
# DBJFJ 3 2
# BDDFB 5 0
# FDYY 5 4
# BJDBY 3 1
# DYJJF 3 1
# FFJJD 3 3
# DDFJ 6 0
# BDDDF 5 0
# YBJFJ 2 3
# FYBB 6 2
# YJY 6 4
# BJJFJ 2 2
# BD 20 2
# DDDYJ 3 3
# FJYB 6 1
# BJJDJ 3 0
# DYJYB 3 1
# BFYBF 3 4
# YYJDF 3 3
# BDYDF 4 3
# BJFBJ 4 0
# YDDDY 3 4
# FJDFB 3 4
# BJDBJ 4 0
# BYJ 10 4
# DJBJ 6 3
# FYYJ 7 1
# FYDB 6 3
# BFFDF 4 1
# BDYDB 3 4
# YJDDY 3 2
# BJDDY 4 0
# DBJFB 3 4
# FJBJ 7 1
# DJJFD 2 4
# YFJJF 3 0
# FJYJ 7 4
# BJJFB 3 2
# YYBDB 3 2
# BJBBJ 4 0
# BJFDJ 4 0
# FBYJ 6 2
# DYYJ 5 4
# BJBBY 3 0
# YYBDY 3 0
# BFFBF 3 3
# BDFBB 3 4
# DBFJF 3 2
# BJJDB 4 0
# BFFDJ 3 4
# FDYB 6 2
# YFBJ 6 4
# BDDBB 3 0
# DBJFF 3 4
# ...

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_10)):
     if sum(freq >= fTC5_10[l] for freq in fTC5null_10[l]) < 1:
        print(setTC5_10[l], fTC5_10[l], sum(freq >= fTC5_10[l] for freq in fTC5null_10[l]))
#         print(setTC5_10[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# BJBDY 3 0
# BDDDJ 4 0
# FBFB 6 0
# BJFBY 3 0
# BDJDB 4 0
# YFDDY 5 0
# YFFDY 4 0
# BDDDB 5 0
# BDDFB 5 0
# DDFJ 6 0
# BDDDF 5 0
# BJJDJ 3 0
# BJFBJ 4 0
# BJDBJ 4 0
# BJDDY 4 0
# YFJJF 3 0
# BJBBJ 4 0
# BJFDJ 4 0
# BJBBY 3 0
# YYBDY 3 0
# BJJDB 4 0
# BDDBB 3 0
# YFBDY 4 0
# DJJFB 3 0
# BJDDJ 4 0
# YJDBY 3 0
# BJDDB 4 0
# BJJBJ 3 0
# FFJDD 3 0
# YJBBY 3 0
# BDDBJ 4 0

# %% [markdown]
# # 3.11 (B) AP - (D) AC - (F) BPI - (J) FGEN - (α) SCC

# %%
#extract overlapping dates
start_11 = max(min(Date_AP), min(Date_AC), min(Date_BPI), min(Date_FGEN), min(Date_SCC))
end_11 = min(max(Date_AP), max(Date_AC), max(Date_BPI), max(Date_FGEN), max(Date_SCC))

# %%
#shorten the closing prices
AP_11_1 = Date_AP.index(start_11)
AP_11_2 = Date_AP.index(end_11)

AC_11_1 = Date_AC.index(start_11)
AC_11_2 = Date_AC.index(end_11)

BPI_11_1 = Date_BPI.index(start_11)
BPI_11_2 = Date_BPI.index(end_11)

FGEN_11_1 = Date_FGEN.index(start_11)
FGEN_11_2 = Date_FGEN.index(end_11)

SCC_11_1 = Date_SCC.index(start_11)
SCC_11_2 = Date_SCC.index(end_11)

# %%
#save the shortened versions of closing prices
B11 = np.save('APshortPrices.npy', ClosePrice_AP[AP_11_1:AP_11_2])
D11 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_11_1:AC_11_2])
F11 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_11_1:BPI_11_2])
J11 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_11_1:FGEN_11_2])
α11 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_11_1:SCC_11_2])

# %%
# import modules
import numpy as np
# import prices

B11 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D11 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F11 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J11 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
α11 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_11 = []
st_11 = []
n = 1
while n < len(B11):
    sc_11 = ''
    if B11[n] > B11[n-1]:
        sc_11 = sc_11 + 'B'
    if D11[n] > D11[n-1]:
        sc_11 = sc_11 + 'D'
    if F11[n] > F11[n-1]:
        sc_11 = sc_11 + 'F'
    if J11[n] > J11[n-1]:
        sc_11 = sc_11 + 'J'
    if α11[n] > α11[n-1]:
        sc_11 = sc_11 + 'α'
    if len(sc_11) > 0:
        st_11.append(sc_11)
    else:
        STC_11.append(st_11)
        st_11 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_11 = STC_11.count([])
# keep only non-empty spatio-temporal sequences
STC_11 = [ st_11 for st_11 in STC_11 if len(st_11) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_11 = len(B11)
lmax_11 = 0
for st_11 in STC_11:
    if len(st_11) < lmin_11:
        lmin_11 = len(st_11)
    if len(st_11) > lmax_11:
        lmax_11 = len(st_11)
        
# restrict spatio-temporal sequences to length-5
STC5_11 = [ st_11 for st_11 in STC_11 if len(st_11) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_11 = []
for n in range(len(STC5_11)):
    tc_11 = [ u for u in STC5_11[n][0] ]
    for k in range(1, len(STC5_11[n])):
        tc_11 = [ u+v for u in tc_11 for v in STC5_11[n][k] ]
    TC5_11 = TC5_11 + tc_11
setTC5_11 = list(set(TC5_11))

# get empirical frequencies
fTC5_11 = [ TC5_11.count(setTC5_11[l]) for l in range(len(setTC5_11)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_11 = [ [] for l in range(len(setTC5_11)) ]
for s in range(100):
    STC5null_11 = [ list(st_11) for st_11 in STC5_11]
    for st_11 in STC5null_11:
        np.random.shuffle(st_11)
    TC5null_11= []
    for n in range(len(STC5null_11)):
        tc_11 = [ u for u in STC5null_11[n][0] ]
        for k in range(1, len(STC5null_11[n])):
            tc_11 = [ u+v for u in tc_11 for v in STC5null_11[n][k] ]
        TC5null_11= TC5null_11+ tc_11
    for l in range(len(setTC5_11)):
        if TC5null_11.count(setTC5_11[l]) > 0:
            fTC5null_11[l].append(TC5null_11.count(setTC5_11[l]))
        else:
            fTC5null_11[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_11)):
     if sum(freq >= fTC5_11[l] for freq in fTC5null_11[l]) < 5:
        print(setTC5_11[l], fTC5_11[l], sum(freq >= fTC5_11[l] for freq in fTC5null_11[l]))
#         print(setTC5_11[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# αFαBα 5 0
# αBαBα 4 1
# BJFαJ 2 3
# FJBB 8 0
# BJJDF 3 1
# FJFB 6 1
# αFJBα 3 0
# BJJαB 3 0
# BDDDJ 4 2
# ααFFJ 3 2
# FBFB 7 0
# αFαBJ 3 3
# BDDαJ 4 1
# αDDαJ 4 0
# FFααB 4 1
# αBBB 7 3
# FBFα 4 3
# FFBα 5 2
# αDJBα 3 2
# FJBα 7 0
# DαFJ 6 3
# BDJDB 4 0
# αDFFJ 2 3
# JJD 8 3
# JBD 9 4
# BDDDB 5 0
# BDJBJ 3 2
# FFDαB 3 4
# JBFJF 3 0
# JJF 8 0
# BJBαJ 3 2
# FJFα 4 0
# αDDFJ 3 3
# FFααα 4 2
# αDJBJ 3 1
# BJJFJ 2 2
# BJJαJ 2 3
# BαααJ 3 3
# JαFDD 3 4
# BJJDJ 3 0
# BααDJ 3 4
# FDα 11 4
# Fαα 11 4
# FDααB 4 3
# ααJB 9 0
# αFBJα 3 1
# BFFDF 3 1
# αDJFJ 3 1
# αDDBJ 5 1
# BDDαB 4 0
# BDαDB 4 2
# BBFαF 3 1
# FDαJD 3 2
# αDαBJ 4 0
# αFDBα 4 3
# BJJFB 3 3
# FαFDD 4 1
# αDDDJ 4 0
# BJFDJ 3 0
# BJJDD 3 4
# BFDBB 3 4
# αJJFJ 2 0
# BFDBJ 3 3
# αDαFJ 3 4
# αDαBα 5 0
# BFFBF 3 1
# BJJDB 4 0
# FFDBD 4 2
# DαJB 6 3
# αJFFJ 2 3
# JDF 9 2
# BJDDJ 3 3
# αBBJα 3 4
# BFFαF 3 1
# αJJDJ 2 3
# αFJBJ 2 4
# BJDDB 4 1
# JBF 9 2
# αDDBα 4 2
# DBBB 6 3
# ...

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_11)):
     if sum(freq >= fTC5_11[l] for freq in fTC5null_11[l]) < 1:
        print(setTC5_11[l], fTC5_11[l], sum(freq >= fTC5_11[l] for freq in fTC5null_11[l]))
#         print(setTC5_11[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# αFαBα 5 0
# FJBB 8 0
# αFJBα 3 0
# BJJαB 3 0
# FBFB 7 0
# αDDαJ 4 0
# FJBα 7 0
# BDJDB 4 0
# BDDDB 5 0
# JBFJF 3 0
# JJF 8 0
# FJFα 4 0
# BJJDJ 3 0
# ααJB 9 0
# BDDαB 4 0
# αDαBJ 4 0
# αDDDJ 4 0
# BJFDJ 3 0
# αJJFJ 2 0
# αDαBα 5 0
# BJJDB 4 0
# BDDBJ 5 0

# %% [markdown]
# # 3.12 (B) AP - (D) AC - (F) BPI - (M) ICT - (N) JGS

# %%
#extract overlapping dates
start_12 = max(min(Date_AP), min(Date_AC), min(Date_BPI), min(Date_ICT), min(Date_JGS))
end_12 = min(max(Date_AP), max(Date_AC), max(Date_BPI), max(Date_ICT), max(Date_JGS))

# %%
#shorten the closing prices
AP_12_1 = Date_AP.index(start_12)
AP_12_2 = Date_AP.index(end_12)

AC_12_1 = Date_AC.index(start_12)
AC_12_2 = Date_AC.index(end_12)

BPI_12_1 = Date_BPI.index(start_12)
BPI_12_2 = Date_BPI.index(end_12)

ICT_12_1 = Date_ICT.index(start_12)
ICT_12_2 = Date_ICT.index(end_12)

JGS_12_1 = Date_JGS.index(start_12)
JGS_12_2 = Date_JGS.index(end_12)

# %%
#save the shortened versions of closing prices
B12 = np.save('APshortPrices.npy', ClosePrice_AP[AP_12_1:AP_12_2])
D12 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_12_1:AC_12_2])
F12 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_12_1:BPI_12_2])
M12 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_12_1:ICT_12_2])
N12 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_12_1:JGS_12_2])

# %%
# import modules
import numpy as np
# import prices

B12 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D12 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F12 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
M12 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N12 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_12 = []
st_12 = []
n = 1
while n < len(B12):
    sc_12 = ''
    if B12[n] > B12[n-1]:
        sc_12 = sc_12 + 'B'
    if D12[n] > D12[n-1]:
        sc_12 = sc_12 + 'D'
    if F12[n] > F12[n-1]:
        sc_12 = sc_12 + 'F'
    if M12[n] > M12[n-1]:
        sc_12 = sc_12 + 'M'
    if N12[n] > N12[n-1]:
        sc_12 = sc_12 + 'N'
    if len(sc_12) > 0:
        st_12.append(sc_12)
    else:
        STC_12.append(st_12)
        st_12 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_12 = STC_12.count([])
# keep only non-empty spatio-temporal sequences
STC_12 = [ st_12 for st_12 in STC_12 if len(st_12) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_12 = len(B12)
lmax_12 = 0
for st_12 in STC_12:
    if len(st_12) < lmin_12:
        lmin_12 = len(st_12)
    if len(st_12) > lmax_12:
        lmax_12 = len(st_12)
        
# restrict spatio-temporal sequences to length-5
STC5_12 = [ st_12 for st_12 in STC_12 if len(st_12) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_12 = []
for n in range(len(STC5_12)):
    tc_12 = [ u for u in STC5_12[n][0] ]
    for k in range(1, len(STC5_12[n])):
        tc_12 = [ u+v for u in tc_12 for v in STC5_12[n][k] ]
    TC5_12 = TC5_12 + tc_12
setTC5_12 = list(set(TC5_12))

# get empirical frequencies
fTC5_12 = [ TC5_12.count(setTC5_12[l]) for l in range(len(setTC5_12)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_12 = [ [] for l in range(len(setTC5_12)) ]
for s in range(100):
    STC5null_12 = [ list(st_12) for st_12 in STC5_12]
    for st_12 in STC5null_12:
        np.random.shuffle(st_12)
    TC5null_12= []
    for n in range(len(STC5null_12)):
        tc_12 = [ u for u in STC5null_12[n][0] ]
        for k in range(1, len(STC5null_12[n])):
            tc_12 = [ u+v for u in tc_12 for v in STC5null_12[n][k] ]
        TC5null_12= TC5null_12+ tc_12
    for l in range(len(setTC5_12)):
        if TC5null_12.count(setTC5_12[l]) > 0:
            fTC5null_12[l].append(TC5null_12.count(setTC5_12[l]))
        else:
            fTC5null_12[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_12)):
     if sum(freq >= fTC5_12[l] for freq in fTC5null_12[l]) < 5:
        print(setTC5_12[l], fTC5_12[l], sum(freq >= fTC5_12[l] for freq in fTC5null_12[l]))
#         print(setTC5_12[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# DBMDN 7 2
# NBFM 7 2
# DBNMN 6 2
# DNMMN 6 2
# DDFM 7 1
# MDDM 7 4
# BDNBB 5 3
# BBFMN 4 4
# FDFMN 5 3
# MBFM 8 4
# DBMFN 6 4
# NBFMM 5 2
# DBFFN 6 2
# FBMFN 6 1
# DDNMN 6 2
# DNDMN 6 3
# NBNN 5 0
# DNN 9 0
# MBDM 9 0
# NBFFN 5 4
# FBMDN 6 3
# BBMDN 5 2
# MDDBN 6 4
# NBFB 8 0
# DFN 11 0
# BDFBN 5 4
# DNNMM 6 4
# DNMDN 7 3
# FNNDN 6 4
# DMNN 6 0
# DBNFM 5 4
# MMFM 7 4
# DBF 14 4
# FDDMN 5 4
# DBNB 8 0
# DBNN 6 1
# FNMDD 5 2
# FNMMD 5 3
# FNMMN 6 0
# FBFBN 5 3
# FBF 12 4
# BMMBF 4 3
# DBDB 8 3
# DMNB 8 3
# MBFD 7 4
# DDDMN 6 4
# NMFN 7 0
# DNNDB 8 4
# DBMMN 6 1
# FDNMN 6 0
# FNMDN 6 3
# FBNFM 4 4
# FMMFF 6 1
# BDFBB 4 4
# NMNN 4 4
# BMDBD 5 4
# DBFMN 8 0
# MMFN 7 2
# NBFMN 6 1
# DBFMM 6 0
# MBNB 10 0
# NBMFN 5 3
# NBFN 6 0
# NMBN 7 1
# DDDM 8 0
# FNBNB 5 3
# DBFN 6 2
# MBFB 9 0
# FNNDB 7 3
# NMFM 8 0
# FMBN 8 1
# FBFBD 5 3
# FMMMN 5 3
# NBFD 6 3
# FBFMN 5 3
# FBMFD 5 4
# FDMMD 5 1
# DBFDN 7 1
# FBMFM 5 1
# DNNMN 6 3
# DDNMB 6 2
# ...

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_12)):
     if sum(freq >= fTC5_12[l] for freq in fTC5null_12[l]) < 1:
        print(setTC5_12[l], fTC5_12[l], sum(freq >= fTC5_12[l] for freq in fTC5null_12[l]))
#         print(setTC5_12[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# NBNN 5 0
# DNN 9 0
# MBDM 9 0
# NBFB 8 0
# DFN 11 0
# DMNN 6 0
# DBNB 8 0
# FNMMN 6 0
# NMFN 7 0
# FDNMN 6 0
# DBFMN 8 0
# DBFMM 6 0
# MBNB 10 0
# NBFN 6 0
# DDDM 8 0
# MBFB 9 0
# NMFM 8 0
# MBDB 11 0
# FMFB 6 0
# DDDB 9 0

# %% [markdown]
# # 3.13 (B) AP - (D) AC - (F) BPI - (M) ICT - (R) MEG

# %%
#extract overlapping dates
start_13 = max(min(Date_AP), min(Date_AC), min(Date_BPI), min(Date_ICT), min(Date_MEG))
end_13 = min(max(Date_AP), max(Date_AC), max(Date_BPI), max(Date_ICT), max(Date_MEG))

# %%
#shorten the closing prices
AP_13_1 = Date_AP.index(start_13)
AP_13_2 = Date_AP.index(end_13)

AC_13_1 = Date_AC.index(start_13)
AC_13_2 = Date_AC.index(end_13)

BPI_13_1 = Date_BPI.index(start_13)
BPI_13_2 = Date_BPI.index(end_13)

ICT_13_1 = Date_ICT.index(start_13)
ICT_13_2 = Date_ICT.index(end_13)

MEG_13_1 = Date_MEG.index(start_13)
MEG_13_2 = Date_MEG.index(end_13)

# %%
#save the shortened versions of closing prices
B13 = np.save('APshortPrices.npy', ClosePrice_AP[AP_13_1:AP_13_2])
D13 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_13_1:AC_13_2])
F13 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_13_1:BPI_13_2])
M13 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_13_1:ICT_13_2])
R13 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_13_1:MEG_13_2])

# %%
# import modules
import numpy as np
# import prices

B13 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D13 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F13 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
M13 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R13 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_13 = []
st_13 = []
n = 1
while n < len(B13):
    sc_13 = ''
    if B13[n] > B13[n-1]:
        sc_13 = sc_13 + 'B'
    if D13[n] > D13[n-1]:
        sc_13 = sc_13 + 'D'
    if F13[n] > F13[n-1]:
        sc_13 = sc_13 + 'F'
    if M13[n] > M13[n-1]:
        sc_13 = sc_13 + 'M'
    if R13[n] > R13[n-1]:
        sc_13 = sc_13 + 'R'
    if len(sc_13) > 0:
        st_13.append(sc_13)
    else:
        STC_13.append(st_13)
        st_13 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_13 = STC_13.count([])
# keep only non-empty spatio-temporal sequences
STC_13 = [ st_13 for st_13 in STC_13 if len(st_13) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_13 = len(B13)
lmax_13 = 0
for st_13 in STC_13:
    if len(st_13) < lmin_13:
        lmin_13 = len(st_13)
    if len(st_13) > lmax_13:
        lmax_13 = len(st_13)
        
# restrict spatio-temporal sequences to length-5
STC5_13 = [ st_13 for st_13 in STC_13 if len(st_13) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_13 = []
for n in range(len(STC5_13)):
    tc_13 = [ u for u in STC5_13[n][0] ]
    for k in range(1, len(STC5_13[n])):
        tc_13 = [ u+v for u in tc_13 for v in STC5_13[n][k] ]
    TC5_13 = TC5_13 + tc_13
setTC5_13 = list(set(TC5_13))

# get empirical frequencies
fTC5_13 = [ TC5_13.count(setTC5_13[l]) for l in range(len(setTC5_13)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_13 = [ [] for l in range(len(setTC5_13)) ]
for s in range(100):
    STC5null_13 = [ list(st_13) for st_13 in STC5_13]
    for st_13 in STC5null_13:
        np.random.shuffle(st_13)
    TC5null_13= []
    for n in range(len(STC5null_13)):
        tc_13 = [ u for u in STC5null_13[n][0] ]
        for k in range(1, len(STC5null_13[n])):
            tc_13 = [ u+v for u in tc_13 for v in STC5null_13[n][k] ]
        TC5null_13= TC5null_13+ tc_13
    for l in range(len(setTC5_13)):
        if TC5null_13.count(setTC5_13[l]) > 0:
            fTC5null_13[l].append(TC5null_13.count(setTC5_13[l]))
        else:
            fTC5null_13[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_13)):
     if sum(freq >= fTC5_13[l] for freq in fTC5null_13[l]) < 5:
        print(setTC5_13[l], fTC5_13[l], sum(freq >= fTC5_13[l] for freq in fTC5null_13[l]))
#         print(setTC5_13[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# MFFRD 7 1
# RRBB 9 1
# MRFDB 5 4
# DRDRB 6 3
# DMBR 9 2
# MFMRD 6 0
# MRDRB 5 0
# FMBF 5 2
# MDDBB 5 2
# MDFMF 5 3
# MFMDD 5 2
# MBMMB 4 3
# RDFDF 6 4
# RDDRB 6 3
# MFFRF 6 2
# FBFMF 5 1
# BDDRB 5 4
# FBFB 6 0
# MDMBF 5 4
# MRFMR 5 1
# MBFDF 5 4
# MDFDD 5 1
# MBMMD 5 1
# DRF 14 1
# RFBBB 3 3
# MMBM 9 4
# RFMRF 7 2
# DBFRF 6 3
# MFMBD 6 0
# FRDRB 6 1
# RFFRB 6 2
# MRFRR 5 2
# BFFRB 5 2
# FBMMF 5 3
# MRDRR 5 0
# MRDDB 5 4
# MDDMB 5 1
# BFFDD 5 3
# RDDBB 5 2
# MRBMB 4 3
# MRFB 9 1
# MRMMM 4 2
# MDBBB 3 3
# RBMBB 3 2
# MBMBB 3 4
# DBRB 7 3
# DBMRF 5 2
# BRM 12 4
# FRF 12 2
# MRFDD 6 2
# RRDB 8 0
# DBFB 7 2
# MBMBD 4 2
# MMFM 7 3
# DBF 13 3
# MRFMD 5 4
# MBMMF 5 1
# DBFDF 6 2
# MDDRB 5 2
# FBMDD 5 3
# MFFDD 7 0
# RFMBD 6 2
# DMRM 8 1
# DMBM 10 0
# FBMDF 5 4
# DMFM 8 0
# FFMDF 6 2
# MDDMD 4 4
# DMFR 8 1
# MBMDF 4 4
# RDFRB 6 3
# BFFRD 6 2
# MDFBF 5 4
# RRMMM 3 4
# DMDB 9 0
# FMM 12 3
# RFMBB 5 3
# DMMR 9 3
# RDFMB 5 4
# RMMBM 4 1
# ...

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_13)):
     if sum(freq >= fTC5_13[l] for freq in fTC5null_13[l]) < 1:
        print(setTC5_13[l], fTC5_13[l], sum(freq >= fTC5_13[l] for freq in fTC5null_13[l]))
#         print(setTC5_13[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# MFMRD 6 0
# MRDRB 5 0
# FBFB 6 0
# MFMBD 6 0
# MRDRR 5 0
# RRDB 8 0
# MFFDD 7 0
# DMBM 10 0
# DMFM 8 0
# DMDB 9 0
# DRFB 8 0
# MRDMR 5 0
# RFFDD 7 0
# DMBB 9 0
# FFFDF 5 0
# FRFB 7 0
# RFFDF 7 0
# BBFRD 5 0
# MFFDF 6 0
# DMDM 10 0
# FMFB 6 0
# RRFB 9 0

# %% [markdown]
# # 3.14 (B) AP - (D) AC - (F) BPI - (M) ICT - (Y) SMC

# %%
#extract overlapping dates
start_14 = max(min(Date_AP), min(Date_AC), min(Date_BPI), min(Date_ICT), min(Date_SMC))
end_14 = min(max(Date_AP), max(Date_AC), max(Date_BPI), max(Date_ICT), max(Date_SMC))

# %%
#shorten the closing prices
AP_14_1 = Date_AP.index(start_14)
AP_14_2 = Date_AP.index(end_14)

AC_14_1 = Date_AC.index(start_14)
AC_14_2 = Date_AC.index(end_14)

BPI_14_1 = Date_BPI.index(start_14)
BPI_14_2 = Date_BPI.index(end_14)

ICT_14_1 = Date_ICT.index(start_14)
ICT_14_2 = Date_ICT.index(end_14)

SMC_14_1 = Date_SMC.index(start_14)
SMC_14_2 = Date_SMC.index(end_14)

# %%
#save the shortened versions of closing prices
B14 = np.save('APshortPrices.npy', ClosePrice_AP[AP_14_1:AP_14_2])
D14 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_14_1:AC_14_2])
F14 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_14_1:BPI_14_2])
M14 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_14_1:ICT_14_2])
Y14 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_14_1:SMC_14_2])

# %%
# import modules
import numpy as np
# import prices

B14 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D14 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F14 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
M14 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
Y14 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_14 = []
st_14 = []
n = 1
while n < len(B14):
    sc_14 = ''
    if B14[n] > B14[n-1]:
        sc_14 = sc_14 + 'B'
    if D14[n] > D14[n-1]:
        sc_14 = sc_14 + 'D'
    if F14[n] > F14[n-1]:
        sc_14 = sc_14 + 'F'
    if M14[n] > M14[n-1]:
        sc_14 = sc_14 + 'M'
    if Y14[n] > Y14[n-1]:
        sc_14 = sc_14 + 'Y'
    if len(sc_14) > 0:
        st_14.append(sc_14)
    else:
        STC_14.append(st_14)
        st_14 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_14 = STC_14.count([])
# keep only non-empty spatio-temporal sequences
STC_14 = [ st_14 for st_14 in STC_14 if len(st_14) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_14 = len(B14)
lmax_14 = 0
for st_14 in STC_14:
    if len(st_14) < lmin_14:
        lmin_14 = len(st_14)
    if len(st_14) > lmax_14:
        lmax_14 = len(st_14)
        
# restrict spatio-temporal sequences to length-5
STC5_14 = [ st_14 for st_14 in STC_14 if len(st_14) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_14 = []
for n in range(len(STC5_14)):
    tc_14 = [ u for u in STC5_14[n][0] ]
    for k in range(1, len(STC5_14[n])):
        tc_14 = [ u+v for u in tc_14 for v in STC5_14[n][k] ]
    TC5_14 = TC5_14 + tc_14
setTC5_14 = list(set(TC5_14))

# get empirical frequencies
fTC5_14 = [ TC5_14.count(setTC5_14[l]) for l in range(len(setTC5_14)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_14 = [ [] for l in range(len(setTC5_14)) ]
for s in range(100):
    STC5null_14 = [ list(st_14) for st_14 in STC5_14]
    for st_14 in STC5null_14:
        np.random.shuffle(st_14)
    TC5null_14= []
    for n in range(len(STC5null_14)):
        tc_14 = [ u for u in STC5null_14[n][0] ]
        for k in range(1, len(STC5null_14[n])):
            tc_14 = [ u+v for u in tc_14 for v in STC5null_14[n][k] ]
        TC5null_14= TC5null_14+ tc_14
    for l in range(len(setTC5_14)):
        if TC5null_14.count(setTC5_14[l]) > 0:
            fTC5null_14[l].append(TC5null_14.count(setTC5_14[l]))
        else:
            fTC5null_14[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_14)):
     if sum(freq >= fTC5_14[l] for freq in fTC5null_14[l]) < 5:
        print(setTC5_14[l], fTC5_14[l], sum(freq >= fTC5_14[l] for freq in fTC5null_14[l]))
#         print(setTC5_14[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# MYFB 6 4
# MYFYB 3 4
# YBYBD 3 4
# DDFM 7 2
# FBYM 6 3
# YFFFB 3 3
# MBFM 7 1
# YFYDF 4 3
# BFYDD 6 1
# MMBM 8 2
# FYYY 7 0
# MYFM 6 4
# BMMBM 3 2
# BFYBD 4 1
# YMBB 7 0
# YFYMF 3 4
# DYYY 5 4
# MBBM 7 4
# BFYDF 4 2
# FYBB 6 3
# YMFB 6 3
# YFDDF 4 2
# YFYDD 4 3
# MMFM 6 3
# MYBYB 3 1
# DBF 15 0
# YFFMB 3 4
# YFBDB 4 1
# MFDB 7 3
# YFDMF 5 1
# DMBM 9 4
# BMMBF 4 1
# DBDB 8 2
# FYDB 7 1
# YFMMF 4 4
# MYBMB 3 2
# DYBMB 4 0
# YYBDB 4 0
# FMYM 6 4
# YMDM 7 2
# MYBDB 4 1
# DYMBD 4 2
# DYBYB 3 0
# YFDMY 4 0
# DYBDB 4 2
# MYDB 9 0
# YDDDB 4 1
# YMBM 8 0
# YFBYB 2 4
# MFBYB 3 4
# MBFB 7 1
# FMYY 6 3
# BFDDD 4 4
# DYBB 6 3
# MMDM 8 1
# YFFFD 4 4
# MDFM 6 2
# YFDMD 4 4
# DYFMB 4 4
# DYB 11 2
# DMBB 7 4
# MBDB 10 0
# DBB 16 0
# BFYMD 4 0
# MDMMD 3 2
# MDDB 7 4
# DMDM 10 2
# YMFM 7 0
# YFDDD 4 1
# YBYDF 3 1
# BMMBD 4 1
# YFBFB 2 3
# DDDB 9 0
# YFDBD 4 2

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_14)):
     if sum(freq >= fTC5_14[l] for freq in fTC5null_14[l]) < 1:
        print(setTC5_14[l], fTC5_14[l], sum(freq >= fTC5_14[l] for freq in fTC5null_14[l]))
#         print(setTC5_14[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# FYYY 7 0
# YMBB 7 0
# DBF 15 0
# DYBMB 4 0
# YYBDB 4 0
# DYBYB 3 0
# YFDMY 4 0
# MYDB 9 0
# YMBM 8 0
# MBDB 10 0
# DBB 16 0
# BFYMD 4 0
# YMFM 7 0
# DDDB 9 0

# %% [markdown]
# # 3.15 (B) AP - (D) AC - (F) BPI - (M) ICT - (α) SCC

# %%
#extract overlapping dates
start_15 = max(min(Date_AP), min(Date_AC), min(Date_BPI), min(Date_ICT), min(Date_SCC))
end_15 = min(max(Date_AP), max(Date_AC), max(Date_BPI), max(Date_ICT), max(Date_SCC))

# %%
#shorten the closing prices
AP_15_1 = Date_AP.index(start_15)
AP_15_2 = Date_AP.index(end_15)

AC_15_1 = Date_AC.index(start_15)
AC_15_2 = Date_AC.index(end_15)

BPI_15_1 = Date_BPI.index(start_15)
BPI_15_2 = Date_BPI.index(end_15)

ICT_15_1 = Date_ICT.index(start_15)
ICT_15_2 = Date_ICT.index(end_15)

SCC_15_1 = Date_SCC.index(start_15)
SCC_15_2 = Date_SCC.index(end_15)

# %%
#save the shortened versions of closing prices
B15 = np.save('APshortPrices.npy', ClosePrice_AP[AP_15_1:AP_15_2])
D15 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_15_1:AC_15_2])
F15 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_15_1:BPI_15_2])
M15 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_15_1:ICT_15_2])
α15 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_15_1:SCC_15_2])

# %%
# import modules
import numpy as np
# import prices

B15 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D15 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F15 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
M15 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
α15 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_15 = []
st_15 = []
n = 1
while n < len(B15):
    sc_15 = ''
    if B15[n] > B15[n-1]:
        sc_15 = sc_15 + 'B'
    if D15[n] > D15[n-1]:
        sc_15 = sc_15 + 'D'
    if F15[n] > F15[n-1]:
        sc_15 = sc_15 + 'F'
    if M15[n] > M15[n-1]:
        sc_15 = sc_15 + 'M'
    if α15[n] > α15[n-1]:
        sc_15 = sc_15 + 'α'
    if len(sc_15) > 0:
        st_15.append(sc_15)
    else:
        STC_15.append(st_15)
        st_15 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_15 = STC_15.count([])
# keep only non-empty spatio-temporal sequences
STC_15 = [ st_15 for st_15 in STC_15 if len(st_15) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_15 = len(B15)
lmax_15 = 0
for st_15 in STC_15:
    if len(st_15) < lmin_15:
        lmin_15 = len(st_15)
    if len(st_15) > lmax_15:
        lmax_15 = len(st_15)
        
# restrict spatio-temporal sequences to length-5
STC5_15 = [ st_15 for st_15 in STC_15 if len(st_15) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_15 = []
for n in range(len(STC5_15)):
    tc_15 = [ u for u in STC5_15[n][0] ]
    for k in range(1, len(STC5_15[n])):
        tc_15 = [ u+v for u in tc_15 for v in STC5_15[n][k] ]
    TC5_15 = TC5_15 + tc_15
setTC5_15 = list(set(TC5_15))

# get empirical frequencies
fTC5_15 = [ TC5_15.count(setTC5_15[l]) for l in range(len(setTC5_15)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_15 = [ [] for l in range(len(setTC5_15)) ]
for s in range(100):
    STC5null_15 = [ list(st_15) for st_15 in STC5_15]
    for st_15 in STC5null_15:
        np.random.shuffle(st_15)
    TC5null_15= []
    for n in range(len(STC5null_15)):
        tc_15 = [ u for u in STC5null_15[n][0] ]
        for k in range(1, len(STC5null_15[n])):
            tc_15 = [ u+v for u in tc_15 for v in STC5null_15[n][k] ]
        TC5null_15= TC5null_15+ tc_15
    for l in range(len(setTC5_15)):
        if TC5null_15.count(setTC5_15[l]) > 0:
            fTC5null_15[l].append(TC5null_15.count(setTC5_15[l]))
        else:
            fTC5null_15[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_15)):
     if sum(freq >= fTC5_15[l] for freq in fTC5null_15[l]) < 5:
        print(setTC5_15[l], fTC5_15[l], sum(freq >= fTC5_15[l] for freq in fTC5null_15[l]))
#         print(setTC5_15[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# αFαBα 5 1
# αBαBα 4 1
# FFααD 4 1
# MFαBα 4 2
# FBFB 5 0
# MDDαα 4 1
# FFααB 4 1
# αBBB 7 0
# αMBB 7 0
# Mα 14 1
# FDBMB 4 4
# FDαMB 5 1
# FMαMB 4 1
# MFMBD 4 4
# MDMMM 3 4
# MBαBα 5 0
# FFBαα 4 4
# MDMαD 4 0
# αFMBα 4 4
# MDDBα 5 0
# αBDBα 4 3
# FFDαα 4 1
# FBMαD 5 1
# MαMFD 3 3
# FαMDD 4 2
# FFααα 6 0
# FMMMD 4 1
# FBMαM 4 4
# DBFB 6 4
# MMFM 5 4
# FBαBα 5 0
# FFαBα 5 0
# FFαMB 4 2
# Fαα 9 0
# FMMαM 4 0
# FBF 14 3
# ααBB 8 1
# αMDB 7 4
# DBDB 7 2
# DMFM 7 2
# FFDBα 4 2
# DαDB 7 0
# FFαMα 3 4
# FααDB 4 3
# MDBMD 4 2
# αFDBα 5 0
# DMDB 7 2
# FMMFF 5 1
# αMFB 6 4
# FαMBD 4 4
# FBMαα 4 3
# FDαDB 5 4
# αBMBD 4 2
# FαMαD 4 3
# MDMBD 5 0
# DαDM 7 4
# FBαDB 4 3
# FMDαM 4 1
# DMFB 7 1
# αFMBD 4 4
# Bα 13 0
# MBDBα 5 1
# FBααα 5 0
# FDMMF 4 0
# FBDαα 4 3
# MDDMα 3 3
# FDMMD 4 2
# αDDBα 4 2
# DBαBα 4 4
# FMBB 6 1
# FFBMB 3 3
# DBBB 5 0
# DMBB 7 0
# MBDB 6 3
# FMααM 5 0
# DBB 15 2
# FBDαB 4 3
# MDαBα 4 2
# MDMDD 4 1
# MDMMD 5 0
# ...

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_15)):
     if sum(freq >= fTC5_15[l] for freq in fTC5null_15[l]) < 1:
        print(setTC5_15[l], fTC5_15[l], sum(freq >= fTC5_15[l] for freq in fTC5null_15[l]))
#         print(setTC5_15[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# FBFB 5 0
# αBBB 7 0
# αMBB 7 0
# MBαBα 5 0
# MDMαD 4 0
# MDDBα 5 0
# FFααα 6 0
# FBαBα 5 0
# FFαBα 5 0
# Fαα 9 0
# FMMαM 4 0
# DαDB 7 0
# αFDBα 5 0
# MDMBD 5 0
# Bα 13 0
# FBααα 5 0
# FDMMF 4 0
# DBBB 5 0
# DMBB 7 0
# FMααM 5 0
# MDMMD 5 0
# FMFB 5 0
