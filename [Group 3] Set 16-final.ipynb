# %% [markdown]
# # One-Letter Words

# %%
# open the csv files
AP = open('AP.csv')
AC = open('AC.csv')
BPI = open('BPI.csv')
BLOOM = open('BLOOM.csv')
FGEN = open('FGEN.csv')
ICT = open('ICT.csv')
JGS = open('JGS.csv')
MEG = open('MEG.csv')
SMC = open('SMC.csv')
SCC = open('SCC.csv')

#initiFGENze the lists
Date_AP = []
ClosePrice_AP = []
Date_AC = []
ClosePrice_AC = []
Date_BPI = []
ClosePrice_BPI = []
Date_BLOOM = []
ClosePrice_BLOOM = []
Date_FGEN = []
ClosePrice_FGEN = []
Date_ICT = []
ClosePrice_ICT = []
Date_JGS = []
ClosePrice_JGS = []
Date_MEG = []
ClosePrice_MEG = []
Date_SMC = []
ClosePrice_SMC = []
Date_SCC = []
ClosePrice_SCC = []

#skip the header line
AP.readline()
AC.readline()
BPI.readline()
BLOOM.readline()
FGEN.readline()
ICT.readline()
JGS.readline()
MEG.readline()
SMC.readline()
SCC.readline()

#go through the files line by line
for line in AP:
    sline = line.strip().split(',')
    Date_AP.append(sline[0])
    ClosePrice_AP.append(float(sline[1]))
    
for line in AC:
    sline = line.strip().split(',')
    Date_AC.append(sline[0])
    ClosePrice_AC.append(float(sline[1]))
    
for line in BPI:
    sline = line.strip().split(',')
    Date_BPI.append(sline[0])
    ClosePrice_BPI.append(float(sline[1]))
    
for line in BLOOM:
    sline = line.strip().split(',')
    Date_BLOOM.append(sline[0])
    ClosePrice_BLOOM.append(float(sline[1]))
    
for line in FGEN:
    sline = line.strip().split(',')
    Date_FGEN.append(sline[0])
    ClosePrice_FGEN.append(float(sline[1]))
    
for line in ICT:
    sline = line.strip().split(',')
    Date_ICT.append(sline[0])
    ClosePrice_ICT.append(float(sline[1]))
    
for line in JGS:
    sline = line.strip().split(',')
    Date_JGS.append(sline[0])
    ClosePrice_JGS.append(float(sline[1]))
    
for line in MEG:
    sline = line.strip().split(',')
    Date_MEG.append(sline[0])
    ClosePrice_MEG.append(float(sline[1]))
    
for line in SMC:
    sline = line.strip().split(',')
    Date_SMC.append(sline[0])
    ClosePrice_SMC.append(float(sline[1]))
        
for line in SCC:
    sline = line.strip().split(',')
    Date_SCC.append(sline[0])
    ClosePrice_SCC.append(float(sline[1]))


#close files
AP.close()
AC.close()
BPI.close()
BLOOM.close()
FGEN.close()
ICT.close()
JGS.close()
MEG.close()
SMC.close()
SCC.close()# One-Letter Words

# %%
import numpy as np
import datetime

# %%
# convert dates into datetime structure
for n in range(len(Date_AP)):
    Date_AP[n] = datetime.datetime.strptime(Date_AP[n], '%m/%d/%y').date()

for n in range(len(Date_AC)):
    Date_AC[n] = datetime.datetime.strptime(Date_AC[n], '%m/%d/%y').date()
    
for n in range(len(Date_BPI)):
    Date_BPI[n] = datetime.datetime.strptime(Date_BPI[n], '%m/%d/%y').date()

for n in range(len(Date_BLOOM)):
    Date_BLOOM[n] = datetime.datetime.strptime(Date_BLOOM[n], '%m/%d/%y').date()
    
for n in range(len(Date_FGEN)):
    Date_FGEN[n] = datetime.datetime.strptime(Date_FGEN[n], '%m/%d/%y').date()

for n in range(len(Date_ICT)):
    Date_ICT[n] = datetime.datetime.strptime(Date_ICT[n], '%m/%d/%y').date()
    
for n in range(len(Date_JGS)):
    Date_JGS[n] = datetime.datetime.strptime(Date_JGS[n], '%m/%d/%y').date()

for n in range(len(Date_MEG)):
    Date_MEG[n] = datetime.datetime.strptime(Date_MEG[n], '%m/%d/%y').date()
    
for n in range(len(Date_SMC)):
    Date_SMC[n] = datetime.datetime.strptime(Date_SMC[n], '%m/%d/%y').date()

for n in range(len(Date_SCC)):
    Date_SCC[n] = datetime.datetime.strptime(Date_SCC[n], '%m/%d/%y').date()
    
# save Date and ClosePrice
np.save('APDate.npy', Date_AP)
np.save('APClosePrice.npy', ClosePrice_AP)
np.save('ACDate.npy', Date_AC)
np.save('ACClosePrice.npy', ClosePrice_AC)
np.save('BPIDate.npy', Date_BPI)
np.save('BPIClosePrice.npy', ClosePrice_BPI)
np.save('BLOOMDate.npy', Date_BLOOM)
np.save('BLOOMClosePrice.npy', ClosePrice_BLOOM)
np.save('FGENDate.npy', Date_FGEN)
np.save('FGENClosePrice.npy', ClosePrice_FGEN)
np.save('ICTDate.npy', Date_ICT)
np.save('ICTClosePrice.npy', ClosePrice_ICT)
np.save('JGSDate.npy', Date_JGS)
np.save('JGSClosePrice.npy', ClosePrice_JGS)
np.save('MEGDate.npy', Date_MEG)
np.save('MEGClosePrice.npy', ClosePrice_MEG)
np.save('SMCDate.npy', Date_SMC)
np.save('SMCClosePrice.npy', ClosePrice_SMC)
np.save('SCCDate.npy', Date_SCC)
np.save('SCCClosePrice.npy', ClosePrice_SCC)

# %% [markdown]
# # Five-letter Words

# %% [markdown]
#  # 3.226 (F) BPI - (J) FGEN- (R) MEG - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_226 = max(min(Date_BPI), min(Date_FGEN), min(Date_MEG), min(Date_SMC), min(Date_SCC))
end_226 = min(max(Date_BPI), max(Date_FGEN), max(Date_MEG), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
BPI_226_1 = Date_BPI.index(start_226)
BPI_226_2 = Date_BPI.index(end_226)

FGEN_226_1 = Date_FGEN.index(start_226)
FGEN_226_2 = Date_FGEN.index(end_226)

MEG_226_1 = Date_MEG.index(start_226)
MEG_226_2 = Date_MEG.index(end_226)

SMC_226_1 = Date_SMC.index(start_226)
SMC_226_2 = Date_SMC.index(end_226)

SCC_226_1 = Date_SCC.index(start_226)
SCC_226_2 = Date_SCC.index(end_226)

# %%
#save the shortened versions of closing prices
F226 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_226_1:BPI_226_2])
J226 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_226_1:FGEN_226_2])
R226 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_226_1:MEG_226_2])
Y226 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_226_1:SMC_226_2])
α226 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_226_1:SCC_226_2])

# %%
# import modules
import numpy as np
# import prices

F226 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J226 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
R226 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y226 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α226 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_226 = []
st_226 = []
n = 1
while n < len(F226):
    sc_226 = ''
    if F226[n] > F226[n-1]:
        sc_226 = sc_226 + 'F'
    if J226[n] > J226[n-1]:
        sc_226 = sc_226 + 'J'
    if R226[n] > R226[n-1]:
        sc_226 = sc_226 + 'R'
    if Y226[n] > Y226[n-1]:
        sc_226 = sc_226 + 'Y'
    if α226[n] > α226[n-1]:
        sc_226 = sc_226 + 'α'
    if len(sc_226) > 0:
        st_226.append(sc_226)
    else:
        STC_226.append(st_226)
        st_226 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_226 = STC_226.count([])
# keep only non-empty spatio-temporal sequences
STC_226 = [ st_226 for st_226 in STC_226 if len(st_226) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_226 = len(F226)
lmax_226 = 0
for st_226 in STC_226:
    if len(st_226) < lmin_226:
        lmin_226 = len(st_226)
    if len(st_226) > lmax_226:
        lmax_226 = len(st_226)
        
# restrict spatio-temporal sequences to length-5
STC5_226 = [ st_226 for st_226 in STC_226 if len(st_226) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_226 = []
for n in range(len(STC5_226)):
    tc_226 = [ u for u in STC5_226[n][0] ]
    for k in range(1, len(STC5_226[n])):
        tc_226 = [ u+v for u in tc_226 for v in STC5_226[n][k] ]
    TC5_226 = TC5_226 + tc_226
setTC5_226 = list(set(TC5_226))

# get empirical frequencies
fTC5_226 = [ TC5_226.count(setTC5_226[l]) for l in range(len(setTC5_226)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_226 = [ [] for l in range(len(setTC5_226)) ]
for s in range(100):
    STC5null_226 = [ list(st_226) for st_226 in STC5_226]
    for st_226 in STC5null_226:
        np.random.shuffle(st_226)
    TC5null_226= []
    for n in range(len(STC5null_226)):
        tc_226 = [ u for u in STC5null_226[n][0] ]
        for k in range(1, len(STC5null_226[n])):
            tc_226 = [ u+v for u in tc_226 for v in STC5null_226[n][k] ]
        TC5null_226= TC5null_226+ tc_226
    for l in range(len(setTC5_226)):
        if TC5null_226.count(setTC5_226[l]) > 0:
            fTC5null_226[l].append(TC5null_226.count(setTC5_226[l]))
        else:
            fTC5null_226[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_226)):
     if sum(freq >= fTC5_226[l] for freq in fTC5null_226[l]) < 5:
#         print(setTC5_226[l], fTC5_226[l], sum(freq >= fTC5_226[l] for freq in fTC5null_226[l]))
        print(setTC5_226[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FRRYR
# RRYαF
# RJαFJ
# JαRYY
# RJαJF
# FYαFR
# αYRYY
# FRF
# RJYY
# αJαFJ
# JRYαF
# ααJFY
# FRYαF
# FYαRJ
# FαYY
# RJαFF
# JJJJF
# RYFYY
# αRJYY
# FRRαR
# ααRR
# FJYY
# YYFYY
# FYααR
# αYFYJ
# RRF
# FYYY
# FYRRR
# RαYY
# αYFYY
# FRαRR
# JRαα
# FαYαF
# RJJJF
# ααRYY
# YRF
# FYαJR
# JJJα
# YYJJF
# FRααR
# FYαRR
# YYFYJ
# FJYαF
# FYαYR
# FRYY
# YRααF
# FRFR
# RRYY
# αYYYJ
# FYαYJ
# FYFYJ
# FYαJJ
# Fα
# JαFJ
# FRRRR
# RJRRα
# JFYαF
# αRRYY
# αJαFF
# FYRJR
# RαYαF
# YJJJF
# YRY
# FRFJ
# αααFY
# FYRYR
# RJJRJ
# RYJ

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_226)):
     if sum(freq >= fTC5_226[l] for freq in fTC5null_226[l]) < 1:
#         print(setTC5_226[l], fTC5_226[l], sum(freq >= fTC5_226[l] for freq in fTC5null_226[l]))
        print(setTC5_226[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# FYαFR
# FRF
# FRYαF
# YYFYY
# αYFYJ
# FYRRR
# RJJJF
# ααRYY
# FYαJR
# FYαRR
# YYFYJ
# FYFYJ
# JFYαF
# αRRYY
# YJJJF

# %% [markdown]
#  # 3.227 (F) BPI - (M) ICT - (N) JGS - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_227 = max(min(Date_BPI), min(Date_ICT), min(Date_JGS), min(Date_MEG), min(Date_SMC))
end_227 = min(max(Date_BPI), max(Date_ICT), max(Date_JGS), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
BPI_227_1 = Date_BPI.index(start_227)
BPI_227_2 = Date_BPI.index(end_227)

ICT_227_1 = Date_ICT.index(start_227)
ICT_227_2 = Date_ICT.index(end_227)

JGS_227_1 = Date_JGS.index(start_227)
JGS_227_2 = Date_JGS.index(end_227)

MEG_227_1 = Date_MEG.index(start_227)
MEG_227_2 = Date_MEG.index(end_227)

SMC_227_1 = Date_SMC.index(start_227)
SMC_227_2 = Date_SMC.index(end_227)

# %%
#save the shortened versions of closing prices
F227 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_227_1:BPI_227_2])
M227 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_227_1:ICT_227_2])
N227 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_227_1:JGS_227_2])
R227 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_227_1:MEG_227_2])
Y227 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_227_1:SMC_227_2])

# %%
# import modules
import numpy as np
# import prices

F227 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
M227 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N227 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R227 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y227 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_227 = []
st_227 = []
n = 1
while n < len(F227):
    sc_227 = ''
    if F227[n] > F227[n-1]:
        sc_227 = sc_227 + 'F'
    if M227[n] > M227[n-1]:
        sc_227 = sc_227 + 'M'
    if N227[n] > N227[n-1]:
        sc_227 = sc_227 + 'N'
    if R227[n] > R227[n-1]:
        sc_227 = sc_227 + 'R'
    if Y227[n] > Y227[n-1]:
        sc_227 = sc_227 + 'Y'
    if len(sc_227) > 0:
        st_227.append(sc_227)
    else:
        STC_227.append(st_227)
        st_227 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_227 = STC_227.count([])
# keep only non-empty spatio-temporal sequences
STC_227 = [ st_227 for st_227 in STC_227 if len(st_227) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_227 = len(F227)
lmax_227 = 0
for st_227 in STC_227:
    if len(st_227) < lmin_227:
        lmin_227 = len(st_227)
    if len(st_227) > lmax_227:
        lmax_227 = len(st_227)
        
# restrict spatio-temporal sequences to length-5
STC5_227 = [ st_227 for st_227 in STC_227 if len(st_227) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_227 = []
for n in range(len(STC5_227)):
    tc_227 = [ u for u in STC5_227[n][0] ]
    for k in range(1, len(STC5_227[n])):
        tc_227 = [ u+v for u in tc_227 for v in STC5_227[n][k] ]
    TC5_227 = TC5_227 + tc_227
setTC5_227 = list(set(TC5_227))

# get empirical frequencies
fTC5_227 = [ TC5_227.count(setTC5_227[l]) for l in range(len(setTC5_227)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_227 = [ [] for l in range(len(setTC5_227)) ]
for s in range(100):
    STC5null_227 = [ list(st_227) for st_227 in STC5_227]
    for st_227 in STC5null_227:
        np.random.shuffle(st_227)
    TC5null_227= []
    for n in range(len(STC5null_227)):
        tc_227 = [ u for u in STC5null_227[n][0] ]
        for k in range(1, len(STC5null_227[n])):
            tc_227 = [ u+v for u in tc_227 for v in STC5null_227[n][k] ]
        TC5null_227= TC5null_227+ tc_227
    for l in range(len(setTC5_227)):
        if TC5null_227.count(setTC5_227[l]) > 0:
            fTC5null_227[l].append(TC5null_227.count(setTC5_227[l]))
        else:
            fTC5null_227[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_227)):
     if sum(freq >= fTC5_227[l] for freq in fTC5null_227[l]) < 5:
#         print(setTC5_227[l], fTC5_227[l], sum(freq >= fTC5_227[l] for freq in fTC5null_227[l]))
        print(setTC5_227[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# MRFMR
# MNNFN
# RYNF
# NRMYM
# NYFFN
# YRFFY
# YYFFY
# MYFFN
# FRMF
# FRF
# MNYNR
# RRFFF
# FRYMF
# YRFFR
# MMRN
# YRYRN
# MRMYM
# NRFYM
# YRYMF
# MNNFR
# YFNFY
# YMRN
# RRMFF
# FYNF
# FRNRM
# MRMMM
# NRRYM
# YRMFY
# MFFFR
# MNFRR
# MRFFR
# MNFMR
# MNMFR
# MYFFR
# MNFFR
# YRNFY
# YNYMR
# NRNRM
# YYFMR
# MRMFN
# MRYMM
# FRN
# NMMYM
# YRNFN
# MYRFF
# MRYFN
# YRMFF
# FRFMN
# YFMN
# MRMFR
# MNRFR
# FYNMM
# MYMFN
# NMFR
# RYFFN
# YRRFN
# MYYMN
# FRNN
# RRF
# MRMFF
# MYF
# MYFFF
# FYYY
# MRYRN
# MYFMR
# YYYMN
# YRNRM
# YRMRN
# FMNYM
# NRFYR
# MYNFN
# FRFMR
# RRNF
# YRFMN
# MYYMR
# NRFFR
# FRNF
# FMNF
# MRFRR
# MNMYM
# RYYY
# MRFMN
# NNMFR
# YRMRF
# MRFNR
# MYYNN
# MYRFN
# FRNYM
# MNYMR
# YRRRF
# MMNR
# MNFMN
# YYFMN
# MNMFN
# MNRMN
# FMMYM
# YRYFN
# YRYRF
# MYYFN
# YRFFF
# YRNFF
# FRYY
# NYNFN
# FYFMR
# MMNN
# MYYNR
# YRFMF
# MRYMN
# NNFFR
# MMFN
# YYFMM
# NRRRR
# NNFRR
# YMMN
# MRMFY
# MNFFN
# MRNRM
# MRMFM
# YMNN
# MNYMN
# YRFFN
# NRFNR
# FMYN
# NNMYM
# YRNNN
# YRNFM
# FNYMM
# YRRRN
# MYN
# YYFFR
# FRNR
# YNYMN
# NNFR
# MMRR
# FYNFR
# MRMRR
# MNYNN
# RYMFN
# FNFMN
# RRMFN
# NRFRR
# YRYFF
# MNRRR
# MMMN
# RMF
# YNFFN
# MMMR
# YNYNN
# YRFMR
# FRNFY
# NRYYY
# YRMRY
# MYFNR
# MRRRR
# YFFFY
# MNFNR
# NRNYM
# YRMFN

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_227)):
     if sum(freq >= fTC5_227[l] for freq in fTC5null_227[l]) < 1:
#         print(setTC5_227[l], fTC5_227[l], sum(freq >= fTC5_227[l] for freq in fTC5null_227[l]))
        print(setTC5_227[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# YRFFY
# YYFFY
# YRFFR
# RRMFF
# FYNF
# MRMMM
# MNFRR
# MNFFR
# YRNFY
# FRN
# YRNFN
# YRMFF
# RRF
# FYYY
# MYYMR
# FRNF
# MRFRR
# MMNR
# FMMYM
# YRNFF
# YMMN
# MRMFY
# MNFFN
# MRMFM
# NRFNR
# FMYN
# MMRR
# MRMRR
# NRFRR
# YRYFF
# MMMN
# MRRRR
# MNFNR

# %% [markdown]
#  # 3.228 (F) BPI - (M) ICT - (N) JGS - (R) MEG - (α) SCC

# %%
#extract overlapping dates
start_228 = max(min(Date_BPI), min(Date_ICT), min(Date_JGS), min(Date_MEG), min(Date_SCC))
end_228 = min(max(Date_BPI), max(Date_ICT), max(Date_JGS), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
BPI_228_1 = Date_BPI.index(start_228)
BPI_228_2 = Date_BPI.index(end_228)

ICT_228_1 = Date_ICT.index(start_228)
ICT_228_2 = Date_ICT.index(end_228)

JGS_228_1 = Date_JGS.index(start_228)
JGS_228_2 = Date_JGS.index(end_228)

MEG_228_1 = Date_MEG.index(start_228)
MEG_228_2 = Date_MEG.index(end_228)

SCC_228_1 = Date_SCC.index(start_228)
SCC_228_2 = Date_SCC.index(end_228)

# %%
#save the shortened versions of closing prices
F228 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_228_1:BPI_228_2])
M228 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_228_1:ICT_228_2])
N228 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_228_1:JGS_228_2])
R228 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_228_1:MEG_228_2])
α228 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_228_1:SCC_228_2])

# %%
# import modules
import numpy as np
# import prices

F228 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
M228 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N228 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R228 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α228 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_228 = []
st_228 = []
n = 1
while n < len(F228):
    sc_228 = ''
    if F228[n] > F228[n-1]:
        sc_228 = sc_228 + 'F'
    if M228[n] > M228[n-1]:
        sc_228 = sc_228 + 'M'
    if N228[n] > N228[n-1]:
        sc_228 = sc_228 + 'N'
    if R228[n] > R228[n-1]:
        sc_228 = sc_228 + 'R'
    if α228[n] > α228[n-1]:
        sc_228 = sc_228 + 'α'
    if len(sc_228) > 0:
        st_228.append(sc_228)
    else:
        STC_228.append(st_228)
        st_228 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_228 = STC_228.count([])
# keep only non-empty spatio-temporal sequences
STC_228 = [ st_228 for st_228 in STC_228 if len(st_228) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_228 = len(F228)
lmax_228 = 0
for st_228 in STC_228:
    if len(st_228) < lmin_228:
        lmin_228 = len(st_228)
    if len(st_228) > lmax_228:
        lmax_228 = len(st_228)
        
# restrict spatio-temporal sequences to length-5
STC5_228 = [ st_228 for st_228 in STC_228 if len(st_228) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_228 = []
for n in range(len(STC5_228)):
    tc_228 = [ u for u in STC5_228[n][0] ]
    for k in range(1, len(STC5_228[n])):
        tc_228 = [ u+v for u in tc_228 for v in STC5_228[n][k] ]
    TC5_228 = TC5_228 + tc_228
setTC5_228 = list(set(TC5_228))

# get empirical frequencies
fTC5_228 = [ TC5_228.count(setTC5_228[l]) for l in range(len(setTC5_228)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_228 = [ [] for l in range(len(setTC5_228)) ]
for s in range(100):
    STC5null_228 = [ list(st_228) for st_228 in STC5_228]
    for st_228 in STC5null_228:
        np.random.shuffle(st_228)
    TC5null_228= []
    for n in range(len(STC5null_228)):
        tc_228 = [ u for u in STC5null_228[n][0] ]
        for k in range(1, len(STC5null_228[n])):
            tc_228 = [ u+v for u in tc_228 for v in STC5null_228[n][k] ]
        TC5null_228= TC5null_228+ tc_228
    for l in range(len(setTC5_228)):
        if TC5null_228.count(setTC5_228[l]) > 0:
            fTC5null_228[l].append(TC5null_228.count(setTC5_228[l]))
        else:
            fTC5null_228[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_228)):
     if sum(freq >= fTC5_228[l] for freq in fTC5null_228[l]) < 5:
#         print(setTC5_228[l], fTC5_228[l], sum(freq >= fTC5_228[l] for freq in fTC5null_228[l]))
        print(setTC5_228[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FαRR
# NMNR
# MαFR
# FMFN
# FαFR
# NαNR
# MRNFR
# MMFα
# NRRRM
# MRMMN
# FRF
# FααFα
# αNFFF
# αMFN
# NαFN
# MRNR
# MFMFN
# MNRFα
# MαMFR
# αMMR
# MNFRα
# MRMMM
# NFNRM
# MNRNR
# MRFFR
# MNMFR
# MNFFR
# MNαFα
# MRαMR
# NRNRM
# NNFRα
# MNαRα
# MRMFN
# MαFFR
# MRαMN
# FRN
# αMRR
# MαNR
# αNFRF
# RαFR
# MRMFR
# FRRαR
# ααRR
# RRMMF
# MRRFR
# FRNN
# RRF
# MαMαF
# RMMFN
# αMNR
# ααFN
# FαMFF
# ααMR
# RRNF
# NRFFR
# FRNF
# NNFFα
# MRFRR
# FM
# MRRR
# MαFMR
# FRNα
# NFFFα
# MMNR
# MNMFN
# MNRMN
# MFNRM
# αNFRα
# NNRFα
# FNNFN
# FMMFF
# MMNM
# RRM
# FRαMR
# MMFR
# MMNN
# FRFR
# NNFFR
# NRNR
# FNαFα
# MMFN
# NRRRR
# NNαFα
# αMFR
# FRNαR
# NRRFR
# MNFFN
# FMMN
# MRMFM
# RRNR
# FRRRR
# FααRα
# NMFN
# αNFMF
# RαMMF
# NFNFα
# NNNFα
# FRNR
# NNFR
# MMRR
# MRMRR
# NNαRα
# NNFFN
# RNMFN
# FNFFN
# MNMMN
# MMMN
# MRRRR
# FαMR
# FFαR

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_228)):
     if sum(freq >= fTC5_228[l] for freq in fTC5null_228[l]) < 1:
#         print(setTC5_228[l], fTC5_228[l], sum(freq >= fTC5_228[l] for freq in fTC5null_228[l]))
        print(setTC5_228[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# MRNR
# MNFRα
# MRMMM
# NFNRM
# MRFFR
# MNFFR
# NNFRα
# MRMFN
# FRN
# αMRR
# αNFRF
# MRMFR
# ααRR
# FαMFF
# FRNF
# MMNR
# NNRFα
# NRRRR
# RRNR
# NMFN
# MRRRR

# %% [markdown]
#  # 3.229 (F) BPI - (M) ICT - (N) JGS - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_229 = max(min(Date_BPI), min(Date_ICT), min(Date_JGS), min(Date_SMC), min(Date_SCC))
end_229 = min(max(Date_BPI), max(Date_ICT), max(Date_JGS), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
BPI_229_1 = Date_BPI.index(start_229)
BPI_229_2 = Date_BPI.index(end_229)

ICT_229_1 = Date_ICT.index(start_229)
ICT_229_2 = Date_ICT.index(end_229)

JGS_229_1 = Date_JGS.index(start_229)
JGS_229_2 = Date_JGS.index(end_229)

SMC_229_1 = Date_SMC.index(start_229)
SMC_229_2 = Date_SMC.index(end_229)

SCC_229_1 = Date_SCC.index(start_229)
SCC_229_2 = Date_SCC.index(end_229)

# %%
#save the shortened versions of closing prices
F229 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_229_1:BPI_229_2])
M229 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_229_1:ICT_229_2])
N229 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_229_1:JGS_229_2])
Y229 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_229_1:SMC_229_2])
α229 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_229_1:SCC_229_2])

# %%
# import modules
import numpy as np
# import prices

F229 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
M229 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N229 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y229 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α229 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_229 = []
st_229 = []
n = 1
while n < len(F229):
    sc_229 = ''
    if F229[n] > F229[n-1]:
        sc_229 = sc_229 + 'F'
    if M229[n] > M229[n-1]:
        sc_229 = sc_229 + 'M'
    if N229[n] > N229[n-1]:
        sc_229 = sc_229 + 'N'
    if Y229[n] > Y229[n-1]:
        sc_229 = sc_229 + 'Y'
    if α229[n] > α229[n-1]:
        sc_229 = sc_229 + 'α'
    if len(sc_229) > 0:
        st_229.append(sc_229)
    else:
        STC_229.append(st_229)
        st_229 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_229 = STC_229.count([])
# keep only non-empty spatio-temporal sequences
STC_229 = [ st_229 for st_229 in STC_229 if len(st_229) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_229 = len(F229)
lmax_229 = 0
for st_229 in STC_229:
    if len(st_229) < lmin_229:
        lmin_229 = len(st_229)
    if len(st_229) > lmax_229:
        lmax_229 = len(st_229)
        
# restrict spatio-temporal sequences to length-5
STC5_229 = [ st_229 for st_229 in STC_229 if len(st_229) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_229 = []
for n in range(len(STC5_229)):
    tc_229 = [ u for u in STC5_229[n][0] ]
    for k in range(1, len(STC5_229[n])):
        tc_229 = [ u+v for u in tc_229 for v in STC5_229[n][k] ]
    TC5_229 = TC5_229 + tc_229
setTC5_229 = list(set(TC5_229))

# get empirical frequencies
fTC5_229 = [ TC5_229.count(setTC5_229[l]) for l in range(len(setTC5_229)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_229 = [ [] for l in range(len(setTC5_229)) ]
for s in range(100):
    STC5null_229 = [ list(st_229) for st_229 in STC5_229]
    for st_229 in STC5null_229:
        np.random.shuffle(st_229)
    TC5null_229= []
    for n in range(len(STC5null_229)):
        tc_229 = [ u for u in STC5null_229[n][0] ]
        for k in range(1, len(STC5null_229[n])):
            tc_229 = [ u+v for u in tc_229 for v in STC5null_229[n][k] ]
        TC5null_229= TC5null_229+ tc_229
    for l in range(len(setTC5_229)):
        if TC5null_229.count(setTC5_229[l]) > 0:
            fTC5null_229[l].append(TC5null_229.count(setTC5_229[l]))
        else:
            fTC5null_229[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_229)):
     if sum(freq >= fTC5_229[l] for freq in fTC5null_229[l]) < 5:
#         print(setTC5_229[l], fTC5_229[l], sum(freq >= fTC5_229[l] for freq in fTC5null_229[l]))
        print(setTC5_229[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# MαYFN
# FYMFα
# FYαFα
# NYαMN
# YYMFN
# YYαNα
# NFMNα
# αN
# NYFFN
# MYFFN
# NYαYα
# NααNα
# FYYN
# FααNα
# FααFα
# NYFFα
# FMYY
# NYMFN
# MNαFα
# NFMNN
# YNYYN
# FFαF
# NYαYN
# NYαYF
# FFMN
# FYαYM
# FαM
# MMαN
# MNαNα
# NYαNN
# YFMN
# NYαFα
# FαF
# NαMFM
# FYαFN
# YFMNN
# NYMNα
# MFαNα
# NFFα
# NYNNN
# YYNNα
# FYYY
# FYαYN
# NαMYM
# YYYMN
# FYαF
# NααNM
# NMαYα
# FαMFF
# MYα
# YYNFα
# NFYN
# ααMYM
# FFYN
# Fαα
# NNFFα
# NNYα
# FYαFM
# FYαNα
# FαFY
# FMαYM
# NFFFα
# NFFNα
# MFMN
# FMNN
# NYαYM
# FYαNN
# YYNαα
# NFαFM
# NYMYα
# FMMYM
# NYNFN
# NαααM
# MMNN
# αYMFM
# YFMMN
# NFMNM
# NYNFα
# YYMMN
# NYαFN
# NFYα
# FNαFα
# MMFN
# FαN
# NNαFα
# NαFYM
# NNαNα
# NααFα
# YMMN
# YMNN
# NYFYα
# FMYN
# ααFFM
# NααYM
# FYαNM
# FαMFM
# NFYNN
# YYααα
# FFYY
# NFNFα
# NNNFα
# NFαFα
# NFαNα
# ααMFM
# NααY
# NFMN
# FYNNα
# NYαNα
# MMMN
# NYMFα
# FYNFα
# NFαNM
# NMMYα
# NNFα
# NYFYN
# MαMYM
# NααFM
# FαNFα
# αYMYM

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_229)):
     if sum(freq >= fTC5_229[l] for freq in fTC5null_229[l]) < 1:
#         print(setTC5_229[l], fTC5_229[l], sum(freq >= fTC5_229[l] for freq in fTC5null_229[l]))
        print(setTC5_229[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# FYαFα
# NYαMN
# NYFFN
# NααNα
# NYFFα
# NYαYN
# FYαYM
# FαM
# NYαNN
# NYαFα
# FYYY
# NαMYM
# YYYMN
# FαMFF
# FMαYM
# NYNFα
# NYαFN
# FαN
# NNαNα
# FFYY
# MMMN
# NFαNM
# NYFYN

# %% [markdown]
#  # 3.230 (F) BPI - (M) ICT - (R) MEG - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_230 = max(min(Date_BPI), min(Date_ICT), min(Date_MEG), min(Date_SMC), min(Date_SCC))
end_230 = min(max(Date_BPI), max(Date_ICT), max(Date_MEG), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
BPI_230_1 = Date_BPI.index(start_230)
BPI_230_2 = Date_BPI.index(end_230)

ICT_230_1 = Date_ICT.index(start_230)
ICT_230_2 = Date_ICT.index(end_230)

MEG_230_1 = Date_MEG.index(start_230)
MEG_230_2 = Date_MEG.index(end_230)

SMC_230_1 = Date_SMC.index(start_230)
SMC_230_2 = Date_SMC.index(end_230)

SCC_230_1 = Date_SCC.index(start_230)
SCC_230_2 = Date_SCC.index(end_230)

# %%
#save the shortened versions of closing prices
F230 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_230_1:BPI_230_2])
M230 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_230_1:ICT_230_2])
R230 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_230_1:MEG_230_2])
Y230 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_230_1:SMC_230_2])
α230 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_230_1:SCC_230_2])

# %%
# import modules
import numpy as np
# import prices

F230 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
M230 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R230 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y230 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α230 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_230 = []
st_230 = []
n = 1
while n < len(F230):
    sc_230 = ''
    if F230[n] > F230[n-1]:
        sc_230 = sc_230 + 'F'
    if M230[n] > M230[n-1]:
        sc_230 = sc_230 + 'M'
    if R230[n] > R230[n-1]:
        sc_230 = sc_230 + 'R'
    if Y230[n] > Y230[n-1]:
        sc_230 = sc_230 + 'Y'
    if α230[n] > α230[n-1]:
        sc_230 = sc_230 + 'α'
    if len(sc_230) > 0:
        st_230.append(sc_230)
    else:
        STC_230.append(st_230)
        st_230 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_230 = STC_230.count([])
# keep only non-empty spatio-temporal sequences
STC_230 = [ st_230 for st_230 in STC_230 if len(st_230) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_230 = len(F230)
lmax_230 = 0
for st_230 in STC_230:
    if len(st_230) < lmin_230:
        lmin_230 = len(st_230)
    if len(st_230) > lmax_230:
        lmax_230 = len(st_230)
        
# restrict spatio-temporal sequences to length-5
STC5_230 = [ st_230 for st_230 in STC_230 if len(st_230) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_230 = []
for n in range(len(STC5_230)):
    tc_230 = [ u for u in STC5_230[n][0] ]
    for k in range(1, len(STC5_230[n])):
        tc_230 = [ u+v for u in tc_230 for v in STC5_230[n][k] ]
    TC5_230 = TC5_230 + tc_230
setTC5_230 = list(set(TC5_230))

# get empirical frequencies
fTC5_230 = [ TC5_230.count(setTC5_230[l]) for l in range(len(setTC5_230)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_230 = [ [] for l in range(len(setTC5_230)) ]
for s in range(100):
    STC5null_230 = [ list(st_230) for st_230 in STC5_230]
    for st_230 in STC5null_230:
        np.random.shuffle(st_230)
    TC5null_230= []
    for n in range(len(STC5null_230)):
        tc_230 = [ u for u in STC5null_230[n][0] ]
        for k in range(1, len(STC5null_230[n])):
            tc_230 = [ u+v for u in tc_230 for v in STC5null_230[n][k] ]
        TC5null_230= TC5null_230+ tc_230
    for l in range(len(setTC5_230)):
        if TC5null_230.count(setTC5_230[l]) > 0:
            fTC5null_230[l].append(TC5null_230.count(setTC5_230[l]))
        else:
            fTC5null_230[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_230)):
     if sum(freq >= fTC5_230[l] for freq in fTC5null_230[l]) < 5:
#         print(setTC5_230[l], fTC5_230[l], sum(freq >= fTC5_230[l] for freq in fTC5null_230[l]))
        print(setTC5_230[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# MRFMR
# MYRRR
# FRααM
# MYααM
# αRFRR
# αRRRR
# FYααM
# RMMYα
# FYαFα
# RMRYα
# FYαFR
# YRFFY
# FRF
# MαFYR
# αMFY
# FRYMF
# FααFα
# RYYαR
# MαMYF
# MRMYM
# αYRαM
# MRααR
# ααMYR
# RRFMR
# FYYαR
# MRMMM
# FRYYY
# αMFM
# RααY
# YRFR
# MαYYF
# MRFFR
# MYFFR
# MRMMF
# αααY
# MRMαR
# αRMYM
# RRYαM
# MRFαR
# ααFY
# MRYMM
# MRFMM
# αMRR
# ααFR
# αRRαR
# αYααR
# ααYYY
# αRYYY
# RRYαR
# MFFMF
# FRRαR
# YMαR
# RFFMF
# RRMMF
# MYMRR
# MRRFR
# FαYYF
# FRMMM
# YαFR
# MαMYR
# FYααR
# αRRαM
# FααFY
# RRF
# MYF
# αYYYM
# MYFFF
# FYYY
# αYRRM
# FYRRR
# αRF
# FαMFF
# RαYYM
# MYα
# MYRαM
# YRMMR
# YYMMM
# FRFMF
# YRFMM
# MRFRR
# FαMYF
# FM
# RYYY
# YRMRF
# FRααR
# αRFMM
# FYαRR
# MRFFF
# MYRRM
# αRFαM
# YRFMY
# YRFFF
# MMFR
# MRRαM
# FYαRM
# FYRαR
# RYMR
# YMMR
# αMFR
# RαYYF
# FRRαM
# ααYYF
# αRMαR
# FRYαM
# MYFMM
# FRRRR
# FRYYF
# YMRR
# MRααM
# αRMYR
# YYFFR
# MMRR
# MRMRR
# MYRαR
# FYRαM
# FαYYM
# RRMMM
# αRααM
# FMααM
# YRY
# YαMR
# RRαY
# αRααR
# αRFFR
# αYααM
# MRαY
# FYRRM
# MRRRR
# MαMYM
# MRRαR
# MYYαR
# YMFR

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_230)):
     if sum(freq >= fTC5_230[l] for freq in fTC5null_230[l]) < 1:
#         print(setTC5_230[l], fTC5_230[l], sum(freq >= fTC5_230[l] for freq in fTC5null_230[l]))
        print(setTC5_230[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# MRFMR
# FYααM
# FYαFR
# FRF
# MαFYR
# RYYαR
# αYRαM
# FYYαR
# MRMMM
# MRFFR
# MRMMF
# αααY
# αMRR
# MFFMF
# RRF
# FYYY
# MYα
# MYRαM
# YRFMY
# αMFR
# FRRαM
# MRMRR
# αRααM
# RRαY
# αYααM
# MRRRR
# MαMYM
# MYYαR

# %% [markdown]
#  # 3.231 (F) BPI - (N) JGS - (R) MEG - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_231 = max(min(Date_BPI), min(Date_JGS), min(Date_MEG), min(Date_SMC), min(Date_SCC))
end_231 = min(max(Date_BPI), max(Date_JGS), max(Date_MEG), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
BPI_231_1 = Date_BPI.index(start_231)
BPI_231_2 = Date_BPI.index(end_231)

JGS_231_1 = Date_JGS.index(start_231)
JGS_231_2 = Date_JGS.index(end_231)

MEG_231_1 = Date_MEG.index(start_231)
MEG_231_2 = Date_MEG.index(end_231)

SMC_231_1 = Date_SMC.index(start_231)
SMC_231_2 = Date_SMC.index(end_231)

SCC_231_1 = Date_SCC.index(start_231)
SCC_231_2 = Date_SCC.index(end_231)

# %%
#save the shortened versions of closing prices
F231 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_231_1:BPI_231_2])
N231 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_231_1:JGS_231_2])
R231 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_231_1:MEG_231_2])
Y231 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_231_1:SMC_231_2])
α231 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_231_1:SCC_231_2])

# %%
# import modules
import numpy as np
# import prices

F231 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
N231 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R231 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y231 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α231 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_231 = []
st_231 = []
n = 1
while n < len(F231):
    sc_231 = ''
    if F231[n] > F231[n-1]:
        sc_231 = sc_231 + 'F'
    if N231[n] > N231[n-1]:
        sc_231 = sc_231 + 'M'
    if R231[n] > R231[n-1]:
        sc_231 = sc_231 + 'R'
    if Y231[n] > Y231[n-1]:
        sc_231 = sc_231 + 'Y'
    if α231[n] > α231[n-1]:
        sc_231 = sc_231 + 'α'
    if len(sc_231) > 0:
        st_231.append(sc_231)
    else:
        STC_231.append(st_231)
        st_231 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_231 = STC_231.count([])
# keep only non-empty spatio-temporal sequences
STC_231 = [ st_231 for st_231 in STC_231 if len(st_231) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_231 = len(F231)
lmax_231 = 0
for st_231 in STC_231:
    if len(st_231) < lmin_231:
        lmin_231 = len(st_231)
    if len(st_231) > lmax_231:
        lmax_231 = len(st_231)
        
# restrict spatio-temporal sequences to length-5
STC5_231 = [ st_231 for st_231 in STC_231 if len(st_231) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_231 = []
for n in range(len(STC5_231)):
    tc_231 = [ u for u in STC5_231[n][0] ]
    for k in range(1, len(STC5_231[n])):
        tc_231 = [ u+v for u in tc_231 for v in STC5_231[n][k] ]
    TC5_231 = TC5_231 + tc_231
setTC5_231 = list(set(TC5_231))

# get empirical frequencies
fTC5_231 = [ TC5_231.count(setTC5_231[l]) for l in range(len(setTC5_231)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_231 = [ [] for l in range(len(setTC5_231)) ]
for s in range(100):
    STC5null_231 = [ list(st_231) for st_231 in STC5_231]
    for st_231 in STC5null_231:
        np.random.shuffle(st_231)
    TC5null_231= []
    for n in range(len(STC5null_231)):
        tc_231 = [ u for u in STC5null_231[n][0] ]
        for k in range(1, len(STC5null_231[n])):
            tc_231 = [ u+v for u in tc_231 for v in STC5null_231[n][k] ]
        TC5null_231= TC5null_231+ tc_231
    for l in range(len(setTC5_231)):
        if TC5null_231.count(setTC5_231[l]) > 0:
            fTC5null_231[l].append(TC5null_231.count(setTC5_231[l]))
        else:
            fTC5null_231[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_231)):
     if sum(freq >= fTC5_231[l] for freq in fTC5null_231[l]) < 5:
#         print(setTC5_231[l], fTC5_231[l], sum(freq >= fTC5_231[l] for freq in fTC5null_231[l]))
        print(setTC5_231[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# MFRYα
# YMFFY
# FαFR
# FYαFα
# RYF
# RYYαα
# FYαFR
# RFFY
# MYMFα
# YRFFY
# MYRFα
# YYFFY
# RYMF
# FααFα
# FMYFF
# RYYαR
# MYRMα
# MYYY
# RMYYF
# RYαFα
# FFFR
# MααY
# RααY
# MFFFα
# MRFFR
# MMRMα
# MYαMM
# RαFM
# RααRY
# YMFFM
# FRYαF
# MFRFα
# MFFMα
# FαYY
# αM
# FαYFα
# ααFR
# RYαMα
# MMFFR
# MFRMα
# FαYFY
# RαFR
# RαFY
# MYαFα
# MMRFα
# RYFYR
# YMYYM
# FMαFα
# FYαMR
# MMαRα
# YαFR
# RYM
# YFFFM
# MYYFα
# RRF
# αYYYM
# FYYY
# FαFM
# RYYFα
# RαYY
# FαYαα
# MYαMα
# RMYαα
# MMαFα
# MRFRR
# RYYY
# FαFY
# RYRMα
# RMYαF
# FYαRR
# MMMFα
# YFFYM
# MRMY
# RYYαF
# MYRRM
# MMFFα
# RMYFα
# FYRMR
# FRYY
# RRM
# MαFY
# RRMF
# FRFR
# RRYαα
# MFMFα
# MYMFM
# FMYαF
# RYFYα
# FαMFα
# MMFM
# MRFY
# MαYY
# RYMFα
# MMαMα
# YYFFR
# RMαFα
# RMYYα
# RRMY
# MMRRα
# MYYαF
# RRFY
# MαFM
# RRαY
# MYαY
# αRFFR
# MFRRR
# RMYYM
# MRαY
# MRRRR
# YFFFY
# RYFFM
# MYMMα
# YYFYM
# MYFFα

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_231)):
     if sum(freq >= fTC5_231[l] for freq in fTC5null_231[l]) < 1:
#         print(setTC5_231[l], fTC5_231[l], sum(freq >= fTC5_231[l] for freq in fTC5null_231[l]))
        print(setTC5_231[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# FαFR
# MYMFα
# RYYαR
# MααY
# MFFFα
# MYαMM
# YMFFM
# MFRFα
# MMRFα
# YMYYM
# FYαMR
# RYM
# RRF
# FYYY
# MYαMα
# RMYαα
# RMYαF
# FRYY
# RRM
# RRMF
# FRFR
# MMαMα
# RRFY
# MαFM
# MYαY
# RMYYM
# MRαY
# YYFYM

# %% [markdown]
#  # 3.232 (H) BLOOM - (J) FGEN - (M) ICT - (N) JGS - (R) MEG

# %%
#extract overlapping dates
start_232 = max(min(Date_BLOOM), min(Date_FGEN), min(Date_ICT), min(Date_JGS), min(Date_MEG))
end_232 = min(max(Date_BLOOM), max(Date_FGEN), max(Date_ICT), max(Date_JGS), max(Date_MEG))

# %%
#shorten the closing prices
BLOOM_232_1 = Date_BLOOM.index(start_232)
BLOOM_232_2 = Date_BLOOM.index(end_232)

FGEN_232_1 = Date_FGEN.index(start_232)
FGEN_232_2 = Date_FGEN.index(end_232)

ICT_232_1 = Date_ICT.index(start_232)
ICT_232_2 = Date_ICT.index(end_232)

JGS_232_1 = Date_JGS.index(start_232)
JGS_232_2 = Date_JGS.index(end_232)

MEG_232_1 = Date_MEG.index(start_232)
MEG_232_2 = Date_MEG.index(end_232)

# %%
#save the shortened versions of closing prices
H232 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_232_1:BLOOM_232_2])
J232 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_232_1:FGEN_232_2])
M232 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_232_1:ICT_232_2])
N232 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_232_1:JGS_232_2])
R232 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_232_1:MEG_232_2])

# %%
# import modules
import numpy as np
# import prices

H232 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J232 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M232 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N232 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R232 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_232 = []
st_232 = []
n = 1
while n < len(H232):
    sc_232 = ''
    if H232[n] > H232[n-1]:
        sc_232 = sc_232 + 'H'
    if J232[n] > J232[n-1]:
        sc_232 = sc_232 + 'J'
    if M232[n] > M232[n-1]:
        sc_232 = sc_232 + 'M'
    if N232[n] > N232[n-1]:
        sc_232 = sc_232 + 'N'
    if R232[n] > R232[n-1]:
        sc_232 = sc_232 + 'R'
    if len(sc_232) > 0:
        st_232.append(sc_232)
    else:
        STC_232.append(st_232)
        st_232 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[56], line 11
#       9 if J232[n] > J232[n-1]:
#      10     sc_232 = sc_232 + 'J'
# ---> 11 if M232[n] > M232[n-1]:
#      12     sc_232 = sc_232 + 'M'
#      13 if N232[n] > N232[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_232 = STC_232.count([])
# keep only non-empty spatio-temporal sequences
STC_232 = [ st_232 for st_232 in STC_232 if len(st_232) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_232 = len(H232)
lmax_232 = 0
for st_232 in STC_232:
    if len(st_232) < lmin_232:
        lmin_232 = len(st_232)
    if len(st_232) > lmax_232:
        lmax_232 = len(st_232)
        
# restrict spatio-temporal sequences to length-5
STC5_232 = [ st_232 for st_232 in STC_232 if len(st_232) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_232 = []
for n in range(len(STC5_232)):
    tc_232 = [ u for u in STC5_232[n][0] ]
    for k in range(1, len(STC5_232[n])):
        tc_232 = [ u+v for u in tc_232 for v in STC5_232[n][k] ]
    TC5_232 = TC5_232 + tc_232
setTC5_232 = list(set(TC5_232))

# get empirical frequencies
fTC5_232 = [ TC5_232.count(setTC5_232[l]) for l in range(len(setTC5_232)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_232 = [ [] for l in range(len(setTC5_232)) ]
for s in range(100):
    STC5null_232 = [ list(st_232) for st_232 in STC5_232]
    for st_232 in STC5null_232:
        np.random.shuffle(st_232)
    TC5null_232= []
    for n in range(len(STC5null_232)):
        tc_232 = [ u for u in STC5null_232[n][0] ]
        for k in range(1, len(STC5null_232[n])):
            tc_232 = [ u+v for u in tc_232 for v in STC5null_232[n][k] ]
        TC5null_232= TC5null_232+ tc_232
    for l in range(len(setTC5_232)):
        if TC5null_232.count(setTC5_232[l]) > 0:
            fTC5null_232[l].append(TC5null_232.count(setTC5_232[l]))
        else:
            fTC5null_232[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_232)):
     if sum(freq >= fTC5_232[l] for freq in fTC5null_232[l]) < 5:
#         print(setTC5_232[l], fTC5_232[l], sum(freq >= fTC5_232[l] for freq in fTC5null_232[l]))
        print(setTC5_232[l])

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_232)):
     if sum(freq >= fTC5_232[l] for freq in fTC5null_232[l]) < 1:
#         print(setTC5_232[l], fTC5_232[l], sum(freq >= fTC5_232[l] for freq in fTC5null_232[l]))
        print(setTC5_232[l])

# %% [markdown]
#  # 3.233 (H) BLOOM - (J) FGEN - (M) ICT - (N) JGS - (Y) SMC

# %%
#extract overlapping dates
start_233 = max(min(Date_BLOOM), min(Date_FGEN), min(Date_ICT), min(Date_JGS), min(Date_SMC))
end_233 = min(max(Date_BLOOM), max(Date_FGEN), max(Date_ICT), max(Date_JGS), max(Date_SMC))

# %%
#shorten the closing prices
BLOOM_233_1 = Date_BLOOM.index(start_233)
BLOOM_233_2 = Date_BLOOM.index(end_233)

FGEN_233_1 = Date_FGEN.index(start_233)
FGEN_233_2 = Date_FGEN.index(end_233)

ICT_233_1 = Date_ICT.index(start_233)
ICT_233_2 = Date_ICT.index(end_233)

JGS_233_1 = Date_JGS.index(start_233)
JGS_233_2 = Date_JGS.index(end_233)

SMC_233_1 = Date_SMC.index(start_233)
SMC_233_2 = Date_SMC.index(end_233)

# %%
#save the shortened versions of closing prices
H233 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_233_1:BLOOM_233_2])
J233 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_233_1:FGEN_233_2])
M233 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_233_1:ICT_233_2])
N233 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_233_1:JGS_233_2])
Y233 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_233_1:SMC_233_2])

# %%
# import modules
import numpy as np
# import prices

H233 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J233 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M233 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N233 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y233 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_233 = []
st_233 = []
n = 1
while n < len(H233):
    sc_233 = ''
    if H233[n] > H233[n-1]:
        sc_233 = sc_233 + 'H'
    if J233[n] > J233[n-1]:
        sc_233 = sc_233 + 'J'
    if M233[n] > M233[n-1]:
        sc_233 = sc_233 + 'M'
    if N233[n] > N233[n-1]:
        sc_233 = sc_233 + 'N'
    if Y233[n] > Y233[n-1]:
        sc_233 = sc_233 + 'Y'
    if len(sc_233) > 0:
        st_233.append(sc_233)
    else:
        STC_233.append(st_233)
        st_233 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[61], line 11
#       9 if J233[n] > J233[n-1]:
#      10     sc_233 = sc_233 + 'J'
# ---> 11 if M233[n] > M233[n-1]:
#      12     sc_233 = sc_233 + 'M'
#      13 if N233[n] > N233[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_233 = STC_233.count([])
# keep only non-empty spatio-temporal sequences
STC_233 = [ st_233 for st_233 in STC_233 if len(st_233) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_233 = len(H233)
lmax_233 = 0
for st_233 in STC_233:
    if len(st_233) < lmin_233:
        lmin_233 = len(st_233)
    if len(st_233) > lmax_233:
        lmax_233 = len(st_233)
        
# restrict spatio-temporal sequences to length-5
STC5_233 = [ st_233 for st_233 in STC_233 if len(st_233) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_233 = []
for n in range(len(STC5_233)):
    tc_233 = [ u for u in STC5_233[n][0] ]
    for k in range(1, len(STC5_233[n])):
        tc_233 = [ u+v for u in tc_233 for v in STC5_233[n][k] ]
    TC5_233 = TC5_233 + tc_233
setTC5_233 = list(set(TC5_233))

# get empirical frequencies
fTC5_233 = [ TC5_233.count(setTC5_233[l]) for l in range(len(setTC5_233)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_233 = [ [] for l in range(len(setTC5_233)) ]
for s in range(100):
    STC5null_233 = [ list(st_233) for st_233 in STC5_233]
    for st_233 in STC5null_233:
        np.random.shuffle(st_233)
    TC5null_233= []
    for n in range(len(STC5null_233)):
        tc_233 = [ u for u in STC5null_233[n][0] ]
        for k in range(1, len(STC5null_233[n])):
            tc_233 = [ u+v for u in tc_233 for v in STC5null_233[n][k] ]
        TC5null_233= TC5null_233+ tc_233
    for l in range(len(setTC5_233)):
        if TC5null_233.count(setTC5_233[l]) > 0:
            fTC5null_233[l].append(TC5null_233.count(setTC5_233[l]))
        else:
            fTC5null_233[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_233)):
     if sum(freq >= fTC5_233[l] for freq in fTC5null_233[l]) < 5:
#         print(setTC5_233[l], fTC5_233[l], sum(freq >= fTC5_233[l] for freq in fTC5null_233[l]))
        print(setTC5_233[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# YYNHY
# YMNHY
# YMJHM
# NYJN
# YYJMY
# HHJHJ
# HHYMY
# HHYJN
# YMJHJ
# NMNMJ
# YYJHJ
# NMNHY
# HHYMN
# YYJHM
# NHJMN
# NJMNN
# HHJMY
# JYHHJ
# YMJJM
# NYJM
# HHJHY
# NNMM
# HHJJJ
# HYNHJ
# YHJMY
# NYNMY
# YHJMJ
# YYJYY
# YMYYM
# YYJNN
# MMYJM
# YYNMY
# NNYM
# JYJNJ
# MNYM
# YMNMJ
# MMYNN
# YYJNJ
# NMNMY
# NMHHY
# HYJMM
# HYJMN
# YMYJM
# HNYH
# NJMM
# YJJJN
# HHYMJ
# YMJYM
# YMYMJ
# NNJM
# MMHHJ
# NYNHY
# NJMJN
# YJMJM
# JJMJM
# HHYJJ

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_233)):
     if sum(freq >= fTC5_233[l] for freq in fTC5null_233[l]) < 1:
#         print(setTC5_233[l], fTC5_233[l], sum(freq >= fTC5_233[l] for freq in fTC5null_233[l]))
        print(setTC5_233[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# YYNHY
# YYJHJ
# NYNMY
# JJMJM

# %% [markdown]
#  # 3.234 (H) BLOOM - (J) FGEN - (M) ICT - (N) JGS - (α) SCC

# %%
#extract overlapping dates
start_234 = max(min(Date_BLOOM), min(Date_FGEN), min(Date_ICT), min(Date_JGS), min(Date_SCC))
end_234 = min(max(Date_BLOOM), max(Date_FGEN), max(Date_ICT), max(Date_JGS), max(Date_SCC))

# %%
#shorten the closing prices
BLOOM_234_1 = Date_BLOOM.index(start_234)
BLOOM_234_2 = Date_BLOOM.index(end_234)

FGEN_234_1 = Date_FGEN.index(start_234)
FGEN_234_2 = Date_FGEN.index(end_234)

ICT_234_1 = Date_ICT.index(start_234)
ICT_234_2 = Date_ICT.index(end_234)

JGS_234_1 = Date_JGS.index(start_234)
JGS_234_2 = Date_JGS.index(end_234)

SCC_234_1 = Date_SCC.index(start_234)
SCC_234_2 = Date_SCC.index(end_234)

# %%
#save the shortened versions of closing prices
H234 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_234_1:BLOOM_234_2])
J234 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_234_1:FGEN_234_2])
M234 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_234_1:ICT_234_2])
N234 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_234_1:JGS_234_2])
α234 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_234_1:SCC_234_2])

# %%
# import modules
import numpy as np
# import prices

H234 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J234 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M234 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N234 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
α234 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_234 = []
st_234 = []
n = 1
while n < len(H234):
    sc_234 = ''
    if H234[n] > H234[n-1]:
        sc_234 = sc_234 + 'H'
    if J234[n] > J234[n-1]:
        sc_234 = sc_234 + 'J'
    if M234[n] > M234[n-1]:
        sc_234 = sc_234 + 'M'
    if N234[n] > N234[n-1]:
        sc_234 = sc_234 + 'N'
    if α234[n] > α234[n-1]:
        sc_234 = sc_234 + 'α'
    if len(sc_234) > 0:
        st_234.append(sc_234)
    else:
        STC_234.append(st_234)
        st_234 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[69], line 11
#       9 if J234[n] > J234[n-1]:
#      10     sc_234 = sc_234 + 'J'
# ---> 11 if M234[n] > M234[n-1]:
#      12     sc_234 = sc_234 + 'M'
#      13 if N234[n] > N234[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_234 = STC_234.count([])
# keep only non-empty spatio-temporal sequences
STC_234 = [ st_234 for st_234 in STC_234 if len(st_234) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_234 = len(H234)
lmax_234 = 0
for st_234 in STC_234:
    if len(st_234) < lmin_234:
        lmin_234 = len(st_234)
    if len(st_234) > lmax_234:
        lmax_234 = len(st_234)
        
# restrict spatio-temporal sequences to length-5
STC5_234 = [ st_234 for st_234 in STC_234 if len(st_234) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_234 = []
for n in range(len(STC5_234)):
    tc_234 = [ u for u in STC5_234[n][0] ]
    for k in range(1, len(STC5_234[n])):
        tc_234 = [ u+v for u in tc_234 for v in STC5_234[n][k] ]
    TC5_234 = TC5_234 + tc_234
setTC5_234 = list(set(TC5_234))

# get empirical frequencies
fTC5_234 = [ TC5_234.count(setTC5_234[l]) for l in range(len(setTC5_234)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_234 = [ [] for l in range(len(setTC5_234)) ]
for s in range(100):
    STC5null_234 = [ list(st_234) for st_234 in STC5_234]
    for st_234 in STC5null_234:
        np.random.shuffle(st_234)
    TC5null_234= []
    for n in range(len(STC5null_234)):
        tc_234 = [ u for u in STC5null_234[n][0] ]
        for k in range(1, len(STC5null_234[n])):
            tc_234 = [ u+v for u in tc_234 for v in STC5null_234[n][k] ]
        TC5null_234= TC5null_234+ tc_234
    for l in range(len(setTC5_234)):
        if TC5null_234.count(setTC5_234[l]) > 0:
            fTC5null_234[l].append(TC5null_234.count(setTC5_234[l]))
        else:
            fTC5null_234[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_234)):
     if sum(freq >= fTC5_234[l] for freq in fTC5null_234[l]) < 5:
#         print(setTC5_234[l], fTC5_234[l], sum(freq >= fTC5_234[l] for freq in fTC5null_234[l]))
        print(setTC5_234[l])

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_234)):
     if sum(freq >= fTC5_234[l] for freq in fTC5null_234[l]) < 1:
#         print(setTC5_234[l], fTC5_234[l], sum(freq >= fTC5_234[l] for freq in fTC5null_234[l]))
        print(setTC5_234[l])

# %% [markdown]
#  # 3.235 (H) BLOOM - (J) FGEN - (M) ICT - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_235 = max(min(Date_BLOOM), min(Date_FGEN), min(Date_ICT), min(Date_MEG), min(Date_SMC))
end_235 = min(max(Date_BLOOM), max(Date_FGEN), max(Date_ICT), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
BLOOM_235_1 = Date_BLOOM.index(start_235)
BLOOM_235_2 = Date_BLOOM.index(end_235)

FGEN_235_1 = Date_FGEN.index(start_235)
FGEN_235_2 = Date_FGEN.index(end_235)

ICT_235_1 = Date_ICT.index(start_235)
ICT_235_2 = Date_ICT.index(end_235)

MEG_235_1 = Date_MEG.index(start_235)
MEG_235_2 = Date_MEG.index(end_235)

SMC_235_1 = Date_SMC.index(start_235)
SMC_235_2 = Date_SMC.index(end_235)

# %%
#save the shortened versions of closing prices
H235 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_235_1:BLOOM_235_2])
J235 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_235_1:FGEN_235_2])
M235 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_235_1:ICT_235_2])
R235 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_235_1:MEG_235_2])
Y235 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_235_1:SMC_235_2])

# %%
# import modules
import numpy as np
# import prices

H235 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J235 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M235 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R235 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y235 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_235 = []
st_235 = []
n = 1
while n < len(H235):
    sc_235 = ''
    if H235[n] > H235[n-1]:
        sc_235 = sc_235 + 'H'
    if J235[n] > J235[n-1]:
        sc_235 = sc_235 + 'J'
    if M235[n] > M235[n-1]:
        sc_235 = sc_235 + 'M'
    if R235[n] > R235[n-1]:
        sc_235 = sc_235 + 'R'
    if Y235[n] > Y235[n-1]:
        sc_235 = sc_235 + 'Y'
    if len(sc_235) > 0:
        st_235.append(sc_235)
    else:
        STC_235.append(st_235)
        st_235 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[74], line 11
#       9 if J235[n] > J235[n-1]:
#      10     sc_235 = sc_235 + 'J'
# ---> 11 if M235[n] > M235[n-1]:
#      12     sc_235 = sc_235 + 'M'
#      13 if R235[n] > R235[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_235 = STC_235.count([])
# keep only non-empty spatio-temporal sequences
STC_235 = [ st_235 for st_235 in STC_235 if len(st_235) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_235 = len(H235)
lmax_235 = 0
for st_235 in STC_235:
    if len(st_235) < lmin_235:
        lmin_235 = len(st_235)
    if len(st_235) > lmax_235:
        lmax_235 = len(st_235)
        
# restrict spatio-temporal sequences to length-5
STC5_235 = [ st_235 for st_235 in STC_235 if len(st_235) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_235 = []
for n in range(len(STC5_235)):
    tc_235 = [ u for u in STC5_235[n][0] ]
    for k in range(1, len(STC5_235[n])):
        tc_235 = [ u+v for u in tc_235 for v in STC5_235[n][k] ]
    TC5_235 = TC5_235 + tc_235
setTC5_235 = list(set(TC5_235))

# get empirical frequencies
fTC5_235 = [ TC5_235.count(setTC5_235[l]) for l in range(len(setTC5_235)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_235 = [ [] for l in range(len(setTC5_235)) ]
for s in range(100):
    STC5null_235 = [ list(st_235) for st_235 in STC5_235]
    for st_235 in STC5null_235:
        np.random.shuffle(st_235)
    TC5null_235= []
    for n in range(len(STC5null_235)):
        tc_235 = [ u for u in STC5null_235[n][0] ]
        for k in range(1, len(STC5null_235[n])):
            tc_235 = [ u+v for u in tc_235 for v in STC5null_235[n][k] ]
        TC5null_235= TC5null_235+ tc_235
    for l in range(len(setTC5_235)):
        if TC5null_235.count(setTC5_235[l]) > 0:
            fTC5null_235[l].append(TC5null_235.count(setTC5_235[l]))
        else:
            fTC5null_235[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_235)):
     if sum(freq >= fTC5_235[l] for freq in fTC5null_235[l]) < 5:
#         print(setTC5_235[l], fTC5_235[l], sum(freq >= fTC5_235[l] for freq in fTC5null_235[l]))
        print(setTC5_235[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# MMJJM
# YMYH
# RJMJM
# JHJM
# RMYRM
# MYJJY
# RJRM
# HHYRJ
# RJRY
# RYHY
# HJRJ
# YHYJJ
# RMJYJ
# YHJM
# RJJM
# RJJYR
# HHYJY
# YMYRM
# YMRM
# HHYRY
# MRMJM
# YMYJM
# RJJHJ
# HHYJR
# HMMHR
# YJMJM
# YMRH
# MMHHY
# MYRJY
# RJMRM
# MMYJM
# HHYRR
# RJJHR
# RMYJH
# HMMRR
# YJMJR
# HJRM
# RJMM
# MRJJY
# HHYJJ
# MMRJM
# MJMJM

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_235)):
     if sum(freq >= fTC5_235[l] for freq in fTC5null_235[l]) < 1:
#         print(setTC5_235[l], fTC5_235[l], sum(freq >= fTC5_235[l] for freq in fTC5null_235[l]))
        print(setTC5_235[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# MMJJM
# RJRM
# RJRY
# HMMHR
# YJMJM
# MMYJM
# HMMRR
# RJMM
# MMRJM

# %% [markdown]
#  # 3.236 (H) BLOOM - (J) FGEN - (M) ICT - (R) MEG - (α) SCC

# %%
#extract overlapping dates
start_236 = max(min(Date_BLOOM), min(Date_FGEN), min(Date_ICT), min(Date_MEG), min(Date_SCC))
end_236 = min(max(Date_BLOOM), max(Date_FGEN), max(Date_ICT), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
BLOOM_236_1 = Date_BLOOM.index(start_236)
BLOOM_236_2 = Date_BLOOM.index(end_236)

FGEN_236_1 = Date_FGEN.index(start_236)
FGEN_236_2 = Date_FGEN.index(end_236)

ICT_236_1 = Date_ICT.index(start_236)
ICT_236_2 = Date_ICT.index(end_236)

MEG_236_1 = Date_MEG.index(start_236)
MEG_236_2 = Date_MEG.index(end_236)

SCC_236_1 = Date_SCC.index(start_236)
SCC_236_2 = Date_SCC.index(end_236)

# %%
#save the shortened versions of closing prices
H236 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_236_1:BLOOM_236_2])
J236 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_236_1:FGEN_236_2])
M236 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_236_1:ICT_236_2])
R236 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_236_1:MEG_236_2])
α236 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_236_1:SCC_236_2])

# %%
# import modules
import numpy as np
# import prices

H236 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J236 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M236 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R236 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α236 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_236 = []
st_236 = []
n = 1
while n < len(H236):
    sc_236 = ''
    if H236[n] > H236[n-1]:
        sc_236 = sc_236 + 'H'
    if J236[n] > J236[n-1]:
        sc_236 = sc_236 + 'J'
    if M236[n] > M236[n-1]:
        sc_236 = sc_236 + 'M'
    if R236[n] > R236[n-1]:
        sc_236 = sc_236 + 'R'
    if α236[n] > α236[n-1]:
        sc_236 = sc_236 + 'α'
    if len(sc_236) > 0:
        st_236.append(sc_236)
    else:
        STC_236.append(st_236)
        st_236 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[82], line 11
#       9 if J236[n] > J236[n-1]:
#      10     sc_236 = sc_236 + 'J'
# ---> 11 if M236[n] > M236[n-1]:
#      12     sc_236 = sc_236 + 'M'
#      13 if R236[n] > R236[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_236 = STC_236.count([])
# keep only non-empty spatio-temporal sequences
STC_236 = [ st_236 for st_236 in STC_236 if len(st_236) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_236 = len(H236)
lmax_236 = 0
for st_236 in STC_236:
    if len(st_236) < lmin_236:
        lmin_236 = len(st_236)
    if len(st_236) > lmax_236:
        lmax_236 = len(st_236)
        
# restrict spatio-temporal sequences to length-5
STC5_236 = [ st_236 for st_236 in STC_236 if len(st_236) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_236 = []
for n in range(len(STC5_236)):
    tc_236 = [ u for u in STC5_236[n][0] ]
    for k in range(1, len(STC5_236[n])):
        tc_236 = [ u+v for u in tc_236 for v in STC5_236[n][k] ]
    TC5_236 = TC5_236 + tc_236
setTC5_236 = list(set(TC5_236))

# get empirical frequencies
fTC5_236 = [ TC5_236.count(setTC5_236[l]) for l in range(len(setTC5_236)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_236 = [ [] for l in range(len(setTC5_236)) ]
for s in range(100):
    STC5null_236 = [ list(st_236) for st_236 in STC5_236]
    for st_236 in STC5null_236:
        np.random.shuffle(st_236)
    TC5null_236= []
    for n in range(len(STC5null_236)):
        tc_236 = [ u for u in STC5null_236[n][0] ]
        for k in range(1, len(STC5null_236[n])):
            tc_236 = [ u+v for u in tc_236 for v in STC5null_236[n][k] ]
        TC5null_236= TC5null_236+ tc_236
    for l in range(len(setTC5_236)):
        if TC5null_236.count(setTC5_236[l]) > 0:
            fTC5null_236[l].append(TC5null_236.count(setTC5_236[l]))
        else:
            fTC5null_236[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_236)):
     if sum(freq >= fTC5_236[l] for freq in fTC5null_236[l]) < 5:
#         print(setTC5_236[l], fTC5_236[l], sum(freq >= fTC5_236[l] for freq in fTC5null_236[l]))
        print(setTC5_236[l])

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_236)):
     if sum(freq >= fTC5_236[l] for freq in fTC5null_236[l]) < 1:
#         print(setTC5_236[l], fTC5_236[l], sum(freq >= fTC5_236[l] for freq in fTC5null_236[l]))
        print(setTC5_236[l])

# %% [markdown]
#  # 3.237 (H) BLOOM - (J) FGEN - (M) ICT - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_237 = max(min(Date_BLOOM), min(Date_FGEN), min(Date_ICT), min(Date_SMC), min(Date_SCC))
end_237 = min(max(Date_BLOOM), max(Date_FGEN), max(Date_ICT), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
BLOOM_237_1 = Date_BLOOM.index(start_237)
BLOOM_237_2 = Date_BLOOM.index(end_237)

FGEN_237_1 = Date_FGEN.index(start_237)
FGEN_237_2 = Date_FGEN.index(end_237)

ICT_237_1 = Date_ICT.index(start_237)
ICT_237_2 = Date_ICT.index(end_237)

SMC_237_1 = Date_SMC.index(start_237)
SMC_237_2 = Date_SMC.index(end_237)

SCC_237_1 = Date_SCC.index(start_237)
SCC_237_2 = Date_SCC.index(end_237)

# %%
#save the shortened versions of closing prices
H237 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_237_1:BLOOM_237_2])
J237 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_237_1:FGEN_237_2])
M237 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_237_1:ICT_237_2])
Y237 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_237_1:SMC_237_2])
α237 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_237_1:SCC_237_2])

# %%
# import modules
import numpy as np
# import prices

H237 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J237 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M237 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
Y237 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α237 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_237 = []
st_237 = []
n = 1
while n < len(H237):
    sc_237 = ''
    if H237[n] > H237[n-1]:
        sc_237 = sc_237 + 'H'
    if J237[n] > J237[n-1]:
        sc_237 = sc_237 + 'J'
    if M237[n] > M237[n-1]:
        sc_237 = sc_237 + 'M'
    if Y237[n] > Y237[n-1]:
        sc_237 = sc_237 + 'R'
    if α237[n] > α237[n-1]:
        sc_237 = sc_237 + 'α'
    if len(sc_237) > 0:
        st_237.append(sc_237)
    else:
        STC_237.append(st_237)
        st_237 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[87], line 11
#       9 if J237[n] > J237[n-1]:
#      10     sc_237 = sc_237 + 'J'
# ---> 11 if M237[n] > M237[n-1]:
#      12     sc_237 = sc_237 + 'M'
#      13 if Y237[n] > Y237[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_237 = STC_237.count([])
# keep only non-empty spatio-temporal sequences
STC_237 = [ st_237 for st_237 in STC_237 if len(st_237) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_237 = len(H237)
lmax_237 = 0
for st_237 in STC_237:
    if len(st_237) < lmin_237:
        lmin_237 = len(st_237)
    if len(st_237) > lmax_237:
        lmax_237 = len(st_237)
        
# restrict spatio-temporal sequences to length-5
STC5_237 = [ st_237 for st_237 in STC_237 if len(st_237) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_237 = []
for n in range(len(STC5_237)):
    tc_237 = [ u for u in STC5_237[n][0] ]
    for k in range(1, len(STC5_237[n])):
        tc_237 = [ u+v for u in tc_237 for v in STC5_237[n][k] ]
    TC5_237 = TC5_237 + tc_237
setTC5_237 = list(set(TC5_237))

# get empirical frequencies
fTC5_237 = [ TC5_237.count(setTC5_237[l]) for l in range(len(setTC5_237)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_237 = [ [] for l in range(len(setTC5_237)) ]
for s in range(100):
    STC5null_237 = [ list(st_237) for st_237 in STC5_237]
    for st_237 in STC5null_237:
        np.random.shuffle(st_237)
    TC5null_237= []
    for n in range(len(STC5null_237)):
        tc_237 = [ u for u in STC5null_237[n][0] ]
        for k in range(1, len(STC5null_237[n])):
            tc_237 = [ u+v for u in tc_237 for v in STC5null_237[n][k] ]
        TC5null_237= TC5null_237+ tc_237
    for l in range(len(setTC5_237)):
        if TC5null_237.count(setTC5_237[l]) > 0:
            fTC5null_237[l].append(TC5null_237.count(setTC5_237[l]))
        else:
            fTC5null_237[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_237)):
     if sum(freq >= fTC5_237[l] for freq in fTC5null_237[l]) < 5:
#         print(setTC5_237[l], fTC5_237[l], sum(freq >= fTC5_237[l] for freq in fTC5null_237[l]))
        print(setTC5_237[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# MMRHα
# RJMJM
# JMHRα
# JααHR
# JMRRα
# RJααH
# RMJJM
# RMMM
# JMRHα
# MααJ
# JMMα
# αHHJ
# MRJJR
# JJRα
# JHHR
# MMRRα
# HαRJ
# αHHα
# αHHR
# RRαMR
# JMMJ
# JJMα
# αααR
# RMRJM
# RJJJM
# JRααR
# MHHHα
# RRαMα
# HJMαM
# JMHHα
# JRαMR
# MMHHα
# JHHJ
# HMMα
# JRαHR
# MMHRα
# αRαMR
# MJMJM

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_237)):
     if sum(freq >= fTC5_237[l] for freq in fTC5null_237[l]) < 1:
#         print(setTC5_237[l], fTC5_237[l], sum(freq >= fTC5_237[l] for freq in fTC5null_237[l]))
        print(setTC5_237[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# MMRHα
# RMMM
# JMMα
# αHHJ
# αHHR
# RRαMR
# αααR
# RMRJM
# JMHHα
# JRαMR
# MMHHα
# HMMα
# αRαMR

# %% [markdown]
#  # 3.238 (H) BLOOM - (J) FGEN - (N) JGS - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_238 = max(min(Date_BLOOM), min(Date_FGEN), min(Date_JGS), min(Date_MEG), min(Date_SMC))
end_238 = min(max(Date_BLOOM), max(Date_FGEN), max(Date_JGS), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
BLOOM_238_1 = Date_BLOOM.index(start_238)
BLOOM_238_2 = Date_BLOOM.index(end_238)

FGEN_238_1 = Date_FGEN.index(start_238)
FGEN_238_2 = Date_FGEN.index(end_238)

JGS_238_1 = Date_JGS.index(start_238)
JGS_238_2 = Date_JGS.index(end_238)

MEG_238_1 = Date_MEG.index(start_238)
MEG_238_2 = Date_MEG.index(end_238)

SMC_238_1 = Date_SMC.index(start_238)
SMC_238_2 = Date_SMC.index(end_238)

# %%
#save the shortened versions of closing prices
H238 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_238_1:BLOOM_238_2])
J238 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_238_1:FGEN_238_2])
N238 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_238_1:JGS_238_2])
R238 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_238_1:MEG_238_2])
Y238 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_238_1:SMC_238_2])

# %%
# import modules
import numpy as np
# import prices

H238 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J238 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N238 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R238 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y238 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_238 = []
st_238 = []
n = 1
while n < len(H238):
    sc_238 = ''
    if H238[n] > H238[n-1]:
        sc_238 = sc_238 + 'H'
    if J238[n] > J238[n-1]:
        sc_238 = sc_238 + 'J'
    if N238[n] > N238[n-1]:
        sc_238 = sc_238 + 'N'
    if R238[n] > R238[n-1]:
        sc_238 = sc_238 + 'R'
    if Y238[n] > Y238[n-1]:
        sc_238 = sc_238 + 'Y'
    if len(sc_238) > 0:
        st_238.append(sc_238)
    else:
        STC_238.append(st_238)
        st_238 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_238 = STC_238.count([])
# keep only non-empty spatio-temporal sequences
STC_238 = [ st_238 for st_238 in STC_238 if len(st_238) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_238 = len(H238)
lmax_238 = 0
for st_238 in STC_238:
    if len(st_238) < lmin_238:
        lmin_238 = len(st_238)
    if len(st_238) > lmax_238:
        lmax_238 = len(st_238)
        
# restrict spatio-temporal sequences to length-5
STC5_238 = [ st_238 for st_238 in STC_238 if len(st_238) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_238 = []
for n in range(len(STC5_238)):
    tc_238 = [ u for u in STC5_238[n][0] ]
    for k in range(1, len(STC5_238[n])):
        tc_238 = [ u+v for u in tc_238 for v in STC5_238[n][k] ]
    TC5_238 = TC5_238 + tc_238
setTC5_238 = list(set(TC5_238))

# get empirical frequencies
fTC5_238 = [ TC5_238.count(setTC5_238[l]) for l in range(len(setTC5_238)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_238 = [ [] for l in range(len(setTC5_238)) ]
for s in range(100):
    STC5null_238 = [ list(st_238) for st_238 in STC5_238]
    for st_238 in STC5null_238:
        np.random.shuffle(st_238)
    TC5null_238= []
    for n in range(len(STC5null_238)):
        tc_238 = [ u for u in STC5null_238[n][0] ]
        for k in range(1, len(STC5null_238[n])):
            tc_238 = [ u+v for u in tc_238 for v in STC5null_238[n][k] ]
        TC5null_238= TC5null_238+ tc_238
    for l in range(len(setTC5_238)):
        if TC5null_238.count(setTC5_238[l]) > 0:
            fTC5null_238[l].append(TC5null_238.count(setTC5_238[l]))
        else:
            fTC5null_238[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_238)):
     if sum(freq >= fTC5_238[l] for freq in fTC5null_238[l]) < 5:
#         print(setTC5_238[l], fTC5_238[l], sum(freq >= fTC5_238[l] for freq in fTC5null_238[l]))
        print(setTC5_238[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# RHYYJ
# RRYYJ
# RHHNH
# NHJH
# HHHNJ
# NYJRR
# NYNH
# RJHNY
# RJHJY
# RNHNH
# NYRRN
# YYYRN
# NNJH
# RYRRN
# YRYRN
# RRRYN
# RJHNN
# NJHRJ
# JNY
# NJHNY
# RJJNY
# RNHHH
# HJHNJ
# NJHNJ
# RJHYJ
# NJHJJ
# YYRRN
# JNNH
# RJJJY
# JRJN
# RJJRN
# RNHRH
# RYRJN
# RJHYN
# RNNJN
# RJHNH
# NJHRN
# HRYRN
# RJHJH
# YRJRN
# JNJH
# YNNH
# RJJHJ
# RYRYR
# RJHYH
# RHHNY
# RYRYN
# NJJNJ
# NYRJN
# RHHJH
# RNHNY
# RJJYN
# NJHJN
# YYRYN
# RYRRH
# NYJH
# NYHH
# RJJJJ
# RRHNJ
# RJHNJ
# RJHRJ
# YJRJ
# RJHRN
# YHRR
# RNHNJ
# RHHNJ
# RNHJH
# RJJJN
# JRJH
# RJHHY
# YNRH
# HHHNH
# RYRYH
# JRNY
# NYRRJ
# RJHRH
# RJHJJ
# RJHHH
# RNJHJ
# YRRRN
# NYNRN
# RRYYN
# HHYNN
# HJHNH
# RJYYN
# RJYRH
# NJYJN
# NJJJN
# NJJJJ
# YYRJN
# NYNYN
# RJJNJ
# NNNH
# NRNRN
# HNHNJ

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_238)):
     if sum(freq >= fTC5_238[l] for freq in fTC5null_238[l]) < 1:
#         print(setTC5_238[l], fTC5_238[l], sum(freq >= fTC5_238[l] for freq in fTC5null_238[l]))
        print(setTC5_238[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# RJHNY
# NJHNY
# YYRRN
# RJJJY
# RJJRN
# RJHNH
# RJHJH
# JNJH
# RJJHJ
# RYRYN
# YYRYN
# NYJH
# RJHNJ
# RNHNJ
# RNHJH
# RJJJN
# RJHHH
# NJJJN
# YYRJN
# RJJNJ

# %% [markdown]
#  # 3.239 (H) BLOOM - (J) FGEN - (N) JGS - (R) MEG - (α) SCC

# %%
#extract overlapping dates
start_239 = max(min(Date_BLOOM), min(Date_FGEN), min(Date_JGS), min(Date_MEG), min(Date_SCC))
end_239 = min(max(Date_BLOOM), max(Date_FGEN), max(Date_JGS), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
BLOOM_239_1 = Date_BLOOM.index(start_239)
BLOOM_239_2 = Date_BLOOM.index(end_239)

FGEN_239_1 = Date_FGEN.index(start_239)
FGEN_239_2 = Date_FGEN.index(end_239)

JGS_239_1 = Date_JGS.index(start_239)
JGS_239_2 = Date_JGS.index(end_239)

MEG_239_1 = Date_MEG.index(start_239)
MEG_239_2 = Date_MEG.index(end_239)

SCC_239_1 = Date_SCC.index(start_239)
SCC_239_2 = Date_SCC.index(end_239)

# %%
#save the shortened versions of closing prices
H239 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_239_1:BLOOM_239_2])
J239 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_239_1:FGEN_239_2])
N239 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_239_1:JGS_239_2])
R239 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_239_1:MEG_239_2])
α239 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_239_1:SCC_239_2])

# %%
# import modules
import numpy as np
# import prices

H239 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J239 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N239 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R239 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α239 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_239 = []
st_239 = []
n = 1
while n < len(H239):
    sc_239 = ''
    if H239[n] > H239[n-1]:
        sc_239 = sc_239 + 'H'
    if J239[n] > J239[n-1]:
        sc_239 = sc_239 + 'J'
    if N239[n] > N239[n-1]:
        sc_239 = sc_239 + 'N'
    if R239[n] > R239[n-1]:
        sc_239 = sc_239 + 'R'
    if α239[n] > α239[n-1]:
        sc_239 = sc_239 + 'α'
    if len(sc_239) > 0:
        st_239.append(sc_239)
    else:
        STC_239.append(st_239)
        st_239 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_239 = STC_239.count([])
# keep only non-empty spatio-temporal sequences
STC_239 = [ st_239 for st_239 in STC_239 if len(st_239) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_239 = len(H239)
lmax_239 = 0
for st_239 in STC_239:
    if len(st_239) < lmin_239:
        lmin_239 = len(st_239)
    if len(st_239) > lmax_239:
        lmax_239 = len(st_239)
        
# restrict spatio-temporal sequences to length-5
STC5_239 = [ st_239 for st_239 in STC_239 if len(st_239) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_239 = []
for n in range(len(STC5_239)):
    tc_239 = [ u for u in STC5_239[n][0] ]
    for k in range(1, len(STC5_239[n])):
        tc_239 = [ u+v for u in tc_239 for v in STC5_239[n][k] ]
    TC5_239 = TC5_239 + tc_239
setTC5_239 = list(set(TC5_239))

# get empirical frequencies
fTC5_239 = [ TC5_239.count(setTC5_239[l]) for l in range(len(setTC5_239)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_239 = [ [] for l in range(len(setTC5_239)) ]
for s in range(100):
    STC5null_239 = [ list(st_239) for st_239 in STC5_239]
    for st_239 in STC5null_239:
        np.random.shuffle(st_239)
    TC5null_239= []
    for n in range(len(STC5null_239)):
        tc_239 = [ u for u in STC5null_239[n][0] ]
        for k in range(1, len(STC5null_239[n])):
            tc_239 = [ u+v for u in tc_239 for v in STC5null_239[n][k] ]
        TC5null_239= TC5null_239+ tc_239
    for l in range(len(setTC5_239)):
        if TC5null_239.count(setTC5_239[l]) > 0:
            fTC5null_239[l].append(TC5null_239.count(setTC5_239[l]))
        else:
            fTC5null_239[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_239)):
     if sum(freq >= fTC5_239[l] for freq in fTC5null_239[l]) < 5:
#         print(setTC5_239[l], fTC5_239[l], sum(freq >= fTC5_239[l] for freq in fTC5null_239[l]))
        print(setTC5_239[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# JJJN
# HHHNJ
# NαNα
# RRJRN
# NαJα
# JαNH
# NNJH
# RRJJN
# JαRH
# αJJJN
# JRαH
# JNαH
# JNNH
# HHHNN
# ααJRJ
# αNNαH
# NNNαH
# NRNRα
# HHRNJ
# αJJHR
# HHJJJ
# αHαRJ
# RHαRJ
# JNJH
# HHαRH
# αRJJN
# RJHαN
# αJJαα
# αHJJJ
# αJJRR
# RNNαN
# RJJαα
# αHJNJ
# RJJHJ
# NαRH
# HHαRJ
# RJHαJ
# αRJRN
# RRHRα
# RHHNN
# RJHRα
# JJJα
# JJRα
# RJHαα
# RJJJJ
# RRHNJ
# HααRJ
# RJHNJ
# JRJα
# ααRH
# RNNαJ
# RααR
# αNHαJ
# αJJRN
# RNHNJ
# RRJRα
# NRNH
# HHαRα
# RHHNJ
# RJJJN
# JRJH
# RHJNJ
# JαJH
# RHJJJ
# HHHNH
# ααNRJ
# NαJH
# JRNH
# RNNαH
# αHααJ
# NRJJN
# NJJRα
# NRJJR
# NRJRN
# NJJRN
# HHαRN
# NRJRα
# NJJJN
# HHJNJ
# HHHαJ
# NαNH
# RJJNJ
# NNNH
# NRNRN

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_239)):
     if sum(freq >= fTC5_239[l] for freq in fTC5null_239[l]) < 1:
#         print(setTC5_239[l], fTC5_239[l], sum(freq >= fTC5_239[l] for freq in fTC5null_239[l]))
        print(setTC5_239[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# HHHNJ
# JαRH
# αJJJN
# JNαH
# HHHNN
# JNJH
# RJHαN
# αHJJJ
# RJJHJ
# NαRH
# JJJα
# RJJJN
# NRJJN
# NRJRN
# NJJJN
# HHJNJ

# %% [markdown]
#  # 3.240 (H) BLOOM - (J) FGEN - (N) JGS - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_240 = max(min(Date_BLOOM), min(Date_FGEN), min(Date_JGS), min(Date_SMC), min(Date_SCC))
end_240 = min(max(Date_BLOOM), max(Date_FGEN), max(Date_JGS), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
BLOOM_240_1 = Date_BLOOM.index(start_240)
BLOOM_240_2 = Date_BLOOM.index(end_240)

FGEN_240_1 = Date_FGEN.index(start_240)
FGEN_240_2 = Date_FGEN.index(end_240)

JGS_240_1 = Date_JGS.index(start_240)
JGS_240_2 = Date_JGS.index(end_240)

SMC_240_1 = Date_SMC.index(start_240)
SMC_240_2 = Date_SMC.index(end_240)

SCC_240_1 = Date_SCC.index(start_240)
SCC_240_2 = Date_SCC.index(end_240)

# %%
#save the shortened versions of closing prices
H240 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_240_1:BLOOM_240_2])
J240 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_240_1:FGEN_240_2])
N240 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_240_1:JGS_240_2])
Y240 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_240_1:SMC_240_2])
α240 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_240_1:SCC_240_2])

# %%
# import modules
import numpy as np
# import prices

H240 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J240 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N240 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y240 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α240 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_240 = []
st_240 = []
n = 1
while n < len(H240):
    sc_240 = ''
    if H240[n] > H240[n-1]:
        sc_240 = sc_240 + 'H'
    if J240[n] > J240[n-1]:
        sc_240 = sc_240 + 'J'
    if N240[n] > N240[n-1]:
        sc_240 = sc_240 + 'N'
    if Y240[n] > Y240[n-1]:
        sc_240 = sc_240 + 'Y'
    if α240[n] > α240[n-1]:
        sc_240 = sc_240 + 'α'
    if len(sc_240) > 0:
        st_240.append(sc_240)
    else:
        STC_240.append(st_240)
        st_240 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_240 = STC_240.count([])
# keep only non-empty spatio-temporal sequences
STC_240 = [ st_240 for st_240 in STC_240 if len(st_240) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_240 = len(H240)
lmax_240 = 0
for st_240 in STC_240:
    if len(st_240) < lmin_240:
        lmin_240 = len(st_240)
    if len(st_240) > lmax_240:
        lmax_240 = len(st_240)
        
# restrict spatio-temporal sequences to length-5
STC5_240 = [ st_240 for st_240 in STC_240 if len(st_240) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_240 = []
for n in range(len(STC5_240)):
    tc_240 = [ u for u in STC5_240[n][0] ]
    for k in range(1, len(STC5_240[n])):
        tc_240 = [ u+v for u in tc_240 for v in STC5_240[n][k] ]
    TC5_240 = TC5_240 + tc_240
setTC5_240 = list(set(TC5_240))

# get empirical frequencies
fTC5_240 = [ TC5_240.count(setTC5_240[l]) for l in range(len(setTC5_240)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_240 = [ [] for l in range(len(setTC5_240)) ]
for s in range(100):
    STC5null_240 = [ list(st_240) for st_240 in STC5_240]
    for st_240 in STC5null_240:
        np.random.shuffle(st_240)
    TC5null_240= []
    for n in range(len(STC5null_240)):
        tc_240 = [ u for u in STC5null_240[n][0] ]
        for k in range(1, len(STC5null_240[n])):
            tc_240 = [ u+v for u in tc_240 for v in STC5null_240[n][k] ]
        TC5null_240= TC5null_240+ tc_240
    for l in range(len(setTC5_240)):
        if TC5null_240.count(setTC5_240[l]) > 0:
            fTC5null_240[l].append(TC5null_240.count(setTC5_240[l]))
        else:
            fTC5null_240[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_240)):
     if sum(freq >= fTC5_240[l] for freq in fTC5null_240[l]) < 5:
#         print(setTC5_240[l], fTC5_240[l], sum(freq >= fTC5_240[l] for freq in fTC5null_240[l]))
        print(setTC5_240[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# HNN
# αJNαH
# NJNJH
# NHJH
# NNHH
# ααJJY
# αHHαY
# YYαNα
# ααYJJ
# NYJNN
# YHααY
# JYαHY
# αYYNN
# NαNα
# NYNH
# NNJH
# ααNJH
# ααNNJ
# NHYHJ
# JNαH
# JNNH
# NαNαJ
# HJJYY
# αJNNH
# NNαH
# JNJH
# HJHαN
# αHJJJ
# JNYH
# YαJH
# NYαNN
# αHYHJ
# αHJNJ
# ααNαJ
# αHNαH
# JYYN
# ααNHJ
# JYNN
# NαHH
# ααJHY
# JJYα
# YHαNY
# αHαNN
# αHJNN
# NYJH
# YYYα
# αJJJY
# JJJα
# αHY
# αNHαJ
# NHJNN
# αJNJH
# JYYα
# YYNN
# YαHH
# JαJH
# ααYHJ
# NαJH
# HHYNα
# αNJJY
# αHHαJ
# JYJN
# YYJα
# HNJYY
# HHJαY
# HHYNN
# NJJJN
# YNJH
# YYJN
# αHNαJ
# NNNH

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_240)):
     if sum(freq >= fTC5_240[l] for freq in fTC5null_240[l]) < 1:
#         print(setTC5_240[l], fTC5_240[l], sum(freq >= fTC5_240[l] for freq in fTC5null_240[l]))
        print(setTC5_240[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# NNJH
# NHYHJ
# JNαH
# JNNH
# JNJH
# JNYH
# NYαNN
# αHYHJ
# ααNαJ
# JJJα
# NαJH
# αNJJY
# HNJYY
# NJJJN
# YYJN
# NNNH
