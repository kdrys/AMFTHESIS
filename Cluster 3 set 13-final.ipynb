# %% [markdown]
# # One-Letter Words

# %%
# open the csv files
AP = open('AP.csv')
AC = open('AC.csv')
BPI = open('BPI.csv')
BLOOM = open('BLOOM.csv')
FGEN = open('FGEN.csv')
ICT = open('ICT.csv')
JGS = open('JGS.csv')
MEG = open('MEG.csv')
SMC = open('SMC.csv')
SCC = open('SCC.csv')

#initiFGENze the lists
Date_AP = []
ClosePrice_AP = []
Date_AC = []
ClosePrice_AC = []
Date_BPI = []
ClosePrice_BPI = []
Date_BLOOM = []
ClosePrice_BLOOM = []
Date_FGEN = []
ClosePrice_FGEN = []
Date_ICT = []
ClosePrice_ICT = []
Date_JGS = []
ClosePrice_JGS = []
Date_MEG = []
ClosePrice_MEG = []
Date_SMC = []
ClosePrice_SMC = []
Date_SCC = []
ClosePrice_SCC = []

#skip the header line
AP.readline()
AC.readline()
BPI.readline()
BLOOM.readline()
FGEN.readline()
ICT.readline()
JGS.readline()
MEG.readline()
SMC.readline()
SCC.readline()

#go through the files line by line
for line in AP:
    sline = line.strip().split(',')
    Date_AP.append(sline[0])
    ClosePrice_AP.append(float(sline[1]))
    
for line in AC:
    sline = line.strip().split(',')
    Date_AC.append(sline[0])
    ClosePrice_AC.append(float(sline[1]))
    
for line in BPI:
    sline = line.strip().split(',')
    Date_BPI.append(sline[0])
    ClosePrice_BPI.append(float(sline[1]))
    
for line in BLOOM:
    sline = line.strip().split(',')
    Date_BLOOM.append(sline[0])
    ClosePrice_BLOOM.append(float(sline[1]))
    
for line in FGEN:
    sline = line.strip().split(',')
    Date_FGEN.append(sline[0])
    ClosePrice_FGEN.append(float(sline[1]))
    
for line in ICT:
    sline = line.strip().split(',')
    Date_ICT.append(sline[0])
    ClosePrice_ICT.append(float(sline[1]))
    
for line in JGS:
    sline = line.strip().split(',')
    Date_JGS.append(sline[0])
    ClosePrice_JGS.append(float(sline[1]))
    
for line in MEG:
    sline = line.strip().split(',')
    Date_MEG.append(sline[0])
    ClosePrice_MEG.append(float(sline[1]))
    
for line in SMC:
    sline = line.strip().split(',')
    Date_SMC.append(sline[0])
    ClosePrice_SMC.append(float(sline[1]))
        
for line in SCC:
    sline = line.strip().split(',')
    Date_SCC.append(sline[0])
    ClosePrice_SCC.append(float(sline[1]))


#close files
AP.close()
AC.close()
BPI.close()
BLOOM.close()
FGEN.close()
ICT.close()
JGS.close()
MEG.close()
SMC.close()
SCC.close()# One-Letter Words

# %%
import numpy as np
import datetime

# %%
# convert dates into datetime structure
for n in range(len(Date_AP)):
    Date_AP[n] = datetime.datetime.strptime(Date_AP[n], '%m/%d/%y').date()

for n in range(len(Date_AC)):
    Date_AC[n] = datetime.datetime.strptime(Date_AC[n], '%m/%d/%y').date()
    
for n in range(len(Date_BPI)):
    Date_BPI[n] = datetime.datetime.strptime(Date_BPI[n], '%m/%d/%y').date()

for n in range(len(Date_BLOOM)):
    Date_BLOOM[n] = datetime.datetime.strptime(Date_BLOOM[n], '%m/%d/%y').date()
    
for n in range(len(Date_FGEN)):
    Date_FGEN[n] = datetime.datetime.strptime(Date_FGEN[n], '%m/%d/%y').date()

for n in range(len(Date_ICT)):
    Date_ICT[n] = datetime.datetime.strptime(Date_ICT[n], '%m/%d/%y').date()
    
for n in range(len(Date_JGS)):
    Date_JGS[n] = datetime.datetime.strptime(Date_JGS[n], '%m/%d/%y').date()

for n in range(len(Date_MEG)):
    Date_MEG[n] = datetime.datetime.strptime(Date_MEG[n], '%m/%d/%y').date()
    
for n in range(len(Date_SMC)):
    Date_SMC[n] = datetime.datetime.strptime(Date_SMC[n], '%m/%d/%y').date()

for n in range(len(Date_SCC)):
    Date_SCC[n] = datetime.datetime.strptime(Date_SCC[n], '%m/%d/%y').date()
    
# save Date and ClosePrice
np.save('APDate.npy', Date_AP)
np.save('APClosePrice.npy', ClosePrice_AP)
np.save('ACDate.npy', Date_AC)
np.save('ACClosePrice.npy', ClosePrice_AC)
np.save('BPIDate.npy', Date_BPI)
np.save('BPIClosePrice.npy', ClosePrice_BPI)
np.save('BLOOMDate.npy', Date_BLOOM)
np.save('BLOOMClosePrice.npy', ClosePrice_BLOOM)
np.save('FGENDate.npy', Date_FGEN)
np.save('FGENClosePrice.npy', ClosePrice_FGEN)
np.save('ICTDate.npy', Date_ICT)
np.save('ICTClosePrice.npy', ClosePrice_ICT)
np.save('JGSDate.npy', Date_JGS)
np.save('JGSClosePrice.npy', ClosePrice_JGS)
np.save('MEGDate.npy', Date_MEG)
np.save('MEGClosePrice.npy', ClosePrice_MEG)
np.save('SMCDate.npy', Date_SMC)
np.save('SMCClosePrice.npy', ClosePrice_SMC)
np.save('SCCDate.npy', Date_SCC)
np.save('SCCClosePrice.npy', ClosePrice_SCC)

# %% [markdown]
# # Five-letter Words

# %% [markdown]
# # 3.181 (D) AC - (H) BLOOM - (R) MEG - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_181 = max(min(Date_AC), min(Date_BLOOM), min(Date_MEG), min(Date_SMC), min(Date_SCC))
end_181 = min(max(Date_AC), max(Date_BLOOM), max(Date_MEG), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
AC_181_1 = Date_AC.index(start_181)
AC_181_2 = Date_AC.index(end_181)

BLOOM_181_1 = Date_BLOOM.index(start_181)
BLOOM_181_2 = Date_BLOOM.index(end_181)

MEG_181_1 = Date_MEG.index(start_181)
MEG_181_2 = Date_MEG.index(end_181)

SMC_181_1 = Date_SMC.index(start_181)
SMC_181_2 = Date_SMC.index(end_181)

SCC_181_1 = Date_SCC.index(start_181)
SCC_181_2 = Date_SCC.index(end_181)

# %%
#save the shortened versions of closing prices
D181 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_181_1:AC_181_2])
H181 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_181_1:BLOOM_181_2])
R181 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_181_1:MEG_181_2])
Y181 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_181_1:SMC_181_2])
α181 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_181_1:SCC_181_2])

# %%
# import modules
import numpy as np
# import prices

D181 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H181 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
R181 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y181 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α181 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_181 = []
st_181 = []
n = 1
while n < len(D181):
    sc_181 = ''
    if D181[n] > D181[n-1]:
        sc_181 = sc_181 + 'D'
    if H181[n] > H181[n-1]:
        sc_181 = sc_181 + 'H'
    if R181[n] > R181[n-1]:
        sc_181 = sc_181 + 'R'
    if Y181[n] > Y181[n-1]:
        sc_181 = sc_181 + 'Y'
    if α181[n] > α181[n-1]:
        sc_181 = sc_181 + 'α'
    if len(sc_181) > 0:
        st_181.append(sc_181)
    else:
        STC_181.append(st_181)
        st_181 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_181 = STC_181.count([])
# keep only non-empty spatio-temporal sequences
STC_181 = [ st_181 for st_181 in STC_181 if len(st_181) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_181 = len(D181)
lmax_181 = 0
for st_181 in STC_181:
    if len(st_181) < lmin_181:
        lmin_181 = len(st_181)
    if len(st_181) > lmax_181:
        lmax_181 = len(st_181)
        
# restrict spatio-temporal sequences to length-5
STC5_181 = [ st_181 for st_181 in STC_181 if len(st_181) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_181 = []
for n in range(len(STC5_181)):
    tc_181 = [ u for u in STC5_181[n][0] ]
    for k in range(1, len(STC5_181[n])):
        tc_181 = [ u+v for u in tc_181 for v in STC5_181[n][k] ]
    TC5_181 = TC5_181 + tc_181
setTC5_181 = list(set(TC5_181))

# get empirical frequencies
fTC5_181 = [ TC5_181.count(setTC5_181[l]) for l in range(len(setTC5_181)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_181 = [ [] for l in range(len(setTC5_181)) ]
for s in range(100):
    STC5null_181 = [ list(st_181) for st_181 in STC5_181]
    for st_181 in STC5null_181:
        np.random.shuffle(st_181)
    TC5null_181= []
    for n in range(len(STC5null_181)):
        tc_181 = [ u for u in STC5null_181[n][0] ]
        for k in range(1, len(STC5null_181[n])):
            tc_181 = [ u+v for u in tc_181 for v in STC5null_181[n][k] ]
        TC5null_181= TC5null_181+ tc_181
    for l in range(len(setTC5_181)):
        if TC5null_181.count(setTC5_181[l]) > 0:
            fTC5null_181[l].append(TC5null_181.count(setTC5_181[l]))
        else:
            fTC5null_181[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_181)):
     if sum(freq >= fTC5_181[l] for freq in fTC5null_181[l]) < 5:
#         print(setTC5_181[l], fTC5_181[l], sum(freq >= fTC5_181[l] for freq in fTC5null_181[l]))
        print(setTC5_181[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# YαDR
# YYYαR
# DYYαR
# DDαHH
# DDDYH
# DDRDH
# αDRR
# DYDαR
# DRαYR
# DRYHR
# HDD
# DRDαR
# DRααR
# YαDD
# DYRαH
# DDRDα
# HDYRα
# DRRHR
# αHDR
# DDαRH
# DYYY
# DDRRα
# DYααH
# DYRαR
# DRRHH
# YHDR
# DYDD
# DRRRH
# DDαHR
# YHYD
# YDDR
# αHααY
# HDαY
# HDYHα
# RDαY
# DDαDR
# αDDR
# αRYYY
# αDRH
# DYDHH
# DYαYR
# HDYαα
# YHHD
# HYYRR
# DDαHα
# HHRD
# DYRRH
# DRαRH
# HRαY
# DRRRR
# RαHα
# DDαDY
# DRRDα
# DYDαH
# YYDRR
# DDαRα
# HDYαD
# DDRDR
# DYαRR
# DDRH
# DDαDH
# YYDαR
# DYαYD
# YRYαH
# DYRYR
# DRαDR
# YDRR
# DYRRR
# YHRD
# DRRRα
# αRRDα
# DDRRD
# HRDHH
# YRαR
# YααR
# YRDαR
# DRαRR
# DDαDα
# HαDHH
# YRYYY
# HαD
# YDαR
# DDRDD
# DRαHR
# DDRRR
# DDαRR
# DYααR
# YHRR
# Rαα
# RYD
# DRYαR
# DDRRH
# DRαHH
# DDαHY
# DRRαR
# HαHH
# αRRRR

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_181)):
     if sum(freq >= fTC5_181[l] for freq in fTC5null_181[l]) < 1:
#         print(setTC5_181[l], fTC5_181[l], sum(freq >= fTC5_181[l] for freq in fTC5null_181[l]))
        print(setTC5_181[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# DRααR
# DYYY
# αRYYY
# DYαYR
# DRRRR
# DYRRR
# DRαRR
# DRαHR
# DDRRR
# DYααR
# αRRRR

# %% [markdown]
# # 3.182 (D) AC - (J) FGEN - (M) ICT - (N) JGS - (R) MEG

# %%
#extract overlapping dates
start_182 = max(min(Date_AC), min(Date_FGEN), min(Date_ICT), min(Date_JGS), min(Date_MEG))
end_182 = min(max(Date_AC), max(Date_FGEN), max(Date_ICT), max(Date_JGS), max(Date_MEG))

# %%
#shorten the closing prices
AC_182_1 = Date_AC.index(start_182)
AC_182_2 = Date_AC.index(end_182)

FGEN_182_1 = Date_FGEN.index(start_182)
FGEN_182_2 = Date_FGEN.index(end_182)

ICT_182_1 = Date_ICT.index(start_182)
ICT_182_2 = Date_ICT.index(end_182)

JGS_182_1 = Date_JGS.index(start_182)
JGS_182_2 = Date_JGS.index(end_182)

MEG_182_1 = Date_MEG.index(start_182)
MEG_182_2 = Date_MEG.index(end_182)

# %%
#save the shortened versions of closing prices
D182 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_182_1:AC_182_2])
J182 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_182_1:FGEN_182_2])
M182 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_182_1:ICT_182_2])
N182 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_182_1:JGS_182_2])
R182 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_182_1:MEG_182_2])

# %%
# import modules
import numpy as np
# import prices

D182 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
J182 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M182 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N182 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R182 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_182 = []
st_182 = []
n = 1
while n < len(D182):
    sc_182 = ''
    if D182[n] > D182[n-1]:
        sc_182 = sc_182 + 'D'
    if J182[n] > J182[n-1]:
        sc_182 = sc_182 + 'J'
    if M182[n] > M182[n-1]:
        sc_182 = sc_182 + 'M'
    if N182[n] > N182[n-1]:
        sc_182 = sc_182 + 'N'
    if R182[n] > R182[n-1]:
        sc_182 = sc_182 + 'R'
    if len(sc_182) > 0:
        st_182.append(sc_182)
    else:
        STC_182.append(st_182)
        st_182 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 11
#       9 if J182[n] > J182[n-1]:
#      10     sc_182 = sc_182 + 'J'
# ---> 11 if M182[n] > M182[n-1]:
#      12     sc_182 = sc_182 + 'M'
#      13 if N182[n] > N182[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_182 = STC_182.count([])
# keep only non-empty spatio-temporal sequences
STC_182 = [ st_182 for st_182 in STC_182 if len(st_182) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_182 = len(D182)
lmax_182 = 0
for st_182 in STC_182:
    if len(st_182) < lmin_182:
        lmin_182 = len(st_182)
    if len(st_182) > lmax_182:
        lmax_182 = len(st_182)
        
# restrict spatio-temporal sequences to length-5
STC5_182 = [ st_182 for st_182 in STC_182 if len(st_182) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_182 = []
for n in range(len(STC5_182)):
    tc_182 = [ u for u in STC5_182[n][0] ]
    for k in range(1, len(STC5_182[n])):
        tc_182 = [ u+v for u in tc_182 for v in STC5_182[n][k] ]
    TC5_182 = TC5_182 + tc_182
setTC5_182 = list(set(TC5_182))

# get empirical frequencies
fTC5_182 = [ TC5_182.count(setTC5_182[l]) for l in range(len(setTC5_182)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_182 = [ [] for l in range(len(setTC5_182)) ]
for s in range(100):
    STC5null_182 = [ list(st_182) for st_182 in STC5_182]
    for st_182 in STC5null_182:
        np.random.shuffle(st_182)
    TC5null_182= []
    for n in range(len(STC5null_182)):
        tc_182 = [ u for u in STC5null_182[n][0] ]
        for k in range(1, len(STC5null_182[n])):
            tc_182 = [ u+v for u in tc_182 for v in STC5null_182[n][k] ]
        TC5null_182= TC5null_182+ tc_182
    for l in range(len(setTC5_182)):
        if TC5null_182.count(setTC5_182[l]) > 0:
            fTC5null_182[l].append(TC5null_182.count(setTC5_182[l]))
        else:
            fTC5null_182[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_182)):
     if sum(freq >= fTC5_182[l] for freq in fTC5null_182[l]) < 5:
#         print(setTC5_182[l], fTC5_182[l], sum(freq >= fTC5_182[l] for freq in fTC5null_182[l]))
        print(setTC5_182[l])

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_182)):
     if sum(freq >= fTC5_182[l] for freq in fTC5null_182[l]) < 1:
#         print(setTC5_182[l], fTC5_182[l], sum(freq >= fTC5_182[l] for freq in fTC5null_182[l]))
        print(setTC5_182[l])

# %% [markdown]
# # 3.183 (D) AC - (J) FGEN - (M) ICT - (N) JGS - (Y) SMC

# %%
#extract overlapping dates
start_183 = max(min(Date_AC), min(Date_FGEN), min(Date_ICT), min(Date_JGS), min(Date_SMC))
end_183 = min(max(Date_AC), max(Date_FGEN), max(Date_ICT), max(Date_JGS), max(Date_SMC))

# %%
#shorten the closing prices
AC_183_1 = Date_AC.index(start_183)
AC_183_2 = Date_AC.index(end_183)

FGEN_183_1 = Date_FGEN.index(start_183)
FGEN_183_2 = Date_FGEN.index(end_183)

ICT_183_1 = Date_ICT.index(start_183)
ICT_183_2 = Date_ICT.index(end_183)

JGS_183_1 = Date_JGS.index(start_183)
JGS_183_2 = Date_JGS.index(end_183)

SMC_183_1 = Date_SMC.index(start_183)
SMC_183_2 = Date_SMC.index(end_183)

# %%
#save the shortened versions of closing prices
D183 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_183_1:AC_183_2])
J183 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_183_1:FGEN_183_2])
M183 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_183_1:ICT_183_2])
N183 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_183_1:JGS_183_2])
Y183 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_183_1:SMC_183_2])

# %%
# import modules
import numpy as np
# import prices

D183 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
J183 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M183 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N183 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y183 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_183 = []
st_183 = []
n = 1
while n < len(D183):
    sc_183 = ''
    if D183[n] > D183[n-1]:
        sc_183 = sc_183 + 'D'
    if J183[n] > J183[n-1]:
        sc_183 = sc_183 + 'J'
    if M183[n] > M183[n-1]:
        sc_183 = sc_183 + 'M'
    if N183[n] > N183[n-1]:
        sc_183 = sc_183 + 'N'
    if Y183[n] > Y183[n-1]:
        sc_183 = sc_183 + 'Y'
    if len(sc_183) > 0:
        st_183.append(sc_183)
    else:
        STC_183.append(st_183)
        st_183 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 11
#       9 if J183[n] > J183[n-1]:
#      10     sc_183 = sc_183 + 'J'
# ---> 11 if M183[n] > M183[n-1]:
#      12     sc_183 = sc_183 + 'M'
#      13 if N183[n] > N183[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_183 = STC_183.count([])
# keep only non-empty spatio-temporal sequences
STC_183 = [ st_183 for st_183 in STC_183 if len(st_183) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_183 = len(D183)
lmax_183 = 0
for st_183 in STC_183:
    if len(st_183) < lmin_183:
        lmin_183 = len(st_183)
    if len(st_183) > lmax_183:
        lmax_183 = len(st_183)
        
# restrict spatio-temporal sequences to length-5
STC5_183 = [ st_183 for st_183 in STC_183 if len(st_183) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_183 = []
for n in range(len(STC5_183)):
    tc_183 = [ u for u in STC5_183[n][0] ]
    for k in range(1, len(STC5_183[n])):
        tc_183 = [ u+v for u in tc_183 for v in STC5_183[n][k] ]
    TC5_183 = TC5_183 + tc_183
setTC5_183 = list(set(TC5_183))

# get empirical frequencies
fTC5_183 = [ TC5_183.count(setTC5_183[l]) for l in range(len(setTC5_183)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_183 = [ [] for l in range(len(setTC5_183)) ]
for s in range(100):
    STC5null_183 = [ list(st_183) for st_183 in STC5_183]
    for st_183 in STC5null_183:
        np.random.shuffle(st_183)
    TC5null_183= []
    for n in range(len(STC5null_183)):
        tc_183 = [ u for u in STC5null_183[n][0] ]
        for k in range(1, len(STC5null_183[n])):
            tc_183 = [ u+v for u in tc_183 for v in STC5null_183[n][k] ]
        TC5null_183= TC5null_183+ tc_183
    for l in range(len(setTC5_183)):
        if TC5null_183.count(setTC5_183[l]) > 0:
            fTC5null_183[l].append(TC5null_183.count(setTC5_183[l]))
        else:
            fTC5null_183[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_183)):
     if sum(freq >= fTC5_183[l] for freq in fTC5null_183[l]) < 5:
#         print(setTC5_183[l], fTC5_183[l], sum(freq >= fTC5_183[l] for freq in fTC5null_183[l]))
        print(setTC5_183[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# DNMNM
# YNNJD
# YNMJD
# DYMDM
# YYDM
# NJDJ
# YNJNM
# MMYNN
# NMJNM
# YMJMD
# YNNDD
# YMD
# YYJDN
# YYJNN
# YYJND
# YYJJD
# DNMYM
# NYYM
# YYDDY
# NJYM
# YYJJN
# YYJYN
# JYYJ
# YNMDN
# NJDM
# YYDYY
# YMJJM
# YNJND
# YYJDD
# JJDJ
# JMD
# NJYJ
# NDDD
# YDJND
# DYMNM
# YYJYY
# YNMJN
# DYJDD
# MMYDN
# YNJNN
# YNNJN
# YNMDD
# JMJMD
# YYJNM
# YYJYD
# YYDMY
# YDJDD
# MNMDY
# YNNDN

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_183)):
     if sum(freq >= fTC5_183[l] for freq in fTC5null_183[l]) < 1:
#         print(setTC5_183[l], fTC5_183[l], sum(freq >= fTC5_183[l] for freq in fTC5null_183[l]))
        print(setTC5_183[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# YNJNM
# MMYNN
# YNNDD
# YYJNN
# YYJND
# YYJJD
# YYJJN
# YYJYN
# YMJJM
# YYJDD
# JJDJ
# JMD
# YYJYD

# %% [markdown]
# # 3.184 (D) AC - (J) FGEN - (M) ICT - (N) JGS - (α) SCC

# %%
#extract overlapping dates
start_184 = max(min(Date_AC), min(Date_FGEN), min(Date_ICT), min(Date_JGS), min(Date_SCC))
end_184 = min(max(Date_AC), max(Date_FGEN), max(Date_ICT), max(Date_JGS), max(Date_SCC))

# %%
#shorten the closing prices
AC_184_1 = Date_AC.index(start_184)
AC_184_2 = Date_AC.index(end_184)

FGEN_184_1 = Date_FGEN.index(start_184)
FGEN_184_2 = Date_FGEN.index(end_184)

ICT_184_1 = Date_ICT.index(start_184)
ICT_184_2 = Date_ICT.index(end_184)

JGS_184_1 = Date_JGS.index(start_184)
JGS_184_2 = Date_JGS.index(end_184)

SCC_184_1 = Date_SCC.index(start_184)
SCC_184_2 = Date_SCC.index(end_184)

# %%
#save the shortened versions of closing prices
D184 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_184_1:AC_184_2])
J184 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_184_1:FGEN_184_2])
M184 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_184_1:ICT_184_2])
N184 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_184_1:JGS_184_2])
α184 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_184_1:SCC_184_2])

# %%
# import modules
import numpy as np
# import prices

D184 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
J184 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M184 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N184 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
α184 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_184 = []
st_184 = []
n = 1
while n < len(D184):
    sc_184 = ''
    if D184[n] > D184[n-1]:
        sc_184 = sc_184 + 'D'
    if J184[n] > J184[n-1]:
        sc_184 = sc_184 + 'J'
    if M184[n] > M184[n-1]:
        sc_184 = sc_184 + 'M'
    if N184[n] > N184[n-1]:
        sc_184 = sc_184 + 'N'
    if α184[n] > α184[n-1]:
        sc_184 = sc_184 + 'α'
    if len(sc_184) > 0:
        st_184.append(sc_184)
    else:
        STC_184.append(st_184)
        st_184 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 11
#       9 if J184[n] > J184[n-1]:
#      10     sc_184 = sc_184 + 'J'
# ---> 11 if M184[n] > M184[n-1]:
#      12     sc_184 = sc_184 + 'M'
#      13 if N184[n] > N184[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_184 = STC_184.count([])
# keep only non-empty spatio-temporal sequences
STC_184 = [ st_184 for st_184 in STC_184 if len(st_184) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_184 = len(D184)
lmax_184 = 0
for st_184 in STC_184:
    if len(st_184) < lmin_184:
        lmin_184 = len(st_184)
    if len(st_184) > lmax_184:
        lmax_184 = len(st_184)
        
# restrict spatio-temporal sequences to length-5
STC5_184 = [ st_184 for st_184 in STC_184 if len(st_184) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_184 = []
for n in range(len(STC5_184)):
    tc_184 = [ u for u in STC5_184[n][0] ]
    for k in range(1, len(STC5_184[n])):
        tc_184 = [ u+v for u in tc_184 for v in STC5_184[n][k] ]
    TC5_184 = TC5_184 + tc_184
setTC5_184 = list(set(TC5_184))

# get empirical frequencies
fTC5_184 = [ TC5_184.count(setTC5_184[l]) for l in range(len(setTC5_184)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_184 = [ [] for l in range(len(setTC5_184)) ]
for s in range(100):
    STC5null_184 = [ list(st_184) for st_184 in STC5_184]
    for st_184 in STC5null_184:
        np.random.shuffle(st_184)
    TC5null_184= []
    for n in range(len(STC5null_184)):
        tc_184 = [ u for u in STC5null_184[n][0] ]
        for k in range(1, len(STC5null_184[n])):
            tc_184 = [ u+v for u in tc_184 for v in STC5null_184[n][k] ]
        TC5null_184= TC5null_184+ tc_184
    for l in range(len(setTC5_184)):
        if TC5null_184.count(setTC5_184[l]) > 0:
            fTC5null_184[l].append(TC5null_184.count(setTC5_184[l]))
        else:
            fTC5null_184[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_184)):
     if sum(freq >= fTC5_184[l] for freq in fTC5null_184[l]) < 5:
#         print(setTC5_184[l], fTC5_184[l], sum(freq >= fTC5_184[l] for freq in fTC5null_184[l]))
        print(setTC5_184[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# JNNα
# MDJMM
# DNJJN
# MJJDN
# αMαDN
# MJDJN
# MJJαM
# NMJαα
# MNJMD
# MJJαN
# NMDαM
# αMDαα
# DNααJ
# MNJMM
# JJJαα
# DNαDN
# αJαDN
# NJJMN
# DMααN
# JMDαα
# αNJJJ
# NαNαN
# DMDDN
# DMαDN
# NJJαα
# DJJαα
# MMαJM
# MαJD
# JMMαD
# MNαJN
# NDNαN
# DMNαα
# NNNαN
# αNDDD
# JMαDN
# DNααN
# NJJαN
# αDαDN
# MJJJN
# DJJαN
# JJMα
# JNDα
# DNDDN
# αNJMN
# MMαDM
# αNJDN
# DNJαJ
# MDNM
# JαDα
# MMααN
# αMDDN
# αNDDN
# NMNαN
# JNJα
# αNJMM
# DNJJJ
# NNNDN
# MMαDN
# NDNαα
# NMNMN
# JNαα
# MNNM
# αJJαα
# JαNα
# DNαJN
# DNJDN
# JNNM
# DMDαα
# αNNDN
# JMDDN
# NMNαα

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_184)):
     if sum(freq >= fTC5_184[l] for freq in fTC5null_184[l]) < 1:
#         print(setTC5_184[l], fTC5_184[l], sum(freq >= fTC5_184[l] for freq in fTC5null_184[l]))
        print(setTC5_184[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# JNNα
# MDJMM
# MJJαM
# MNJMD
# MJJαN
# NαNαN
# NJJαα
# DJJαα
# MMαJM
# αNDDD
# NJJαN
# MJJJN
# JJMα
# DNJαJ
# JNαα
# NMNαα

# %% [markdown]
# # 3.185 (D) AC - (J) FGEN - (M) ICT - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_185 = max(min(Date_AC), min(Date_FGEN), min(Date_ICT), min(Date_MEG), min(Date_SMC))
end_185 = min(max(Date_AC), max(Date_FGEN), max(Date_ICT), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
AC_185_1 = Date_AC.index(start_185)
AC_185_2 = Date_AC.index(end_185)

FGEN_185_1 = Date_FGEN.index(start_185)
FGEN_185_2 = Date_FGEN.index(end_185)

ICT_185_1 = Date_ICT.index(start_185)
ICT_185_2 = Date_ICT.index(end_185)

MEG_185_1 = Date_MEG.index(start_185)
MEG_185_2 = Date_MEG.index(end_185)

SMC_185_1 = Date_SMC.index(start_185)
SMC_185_2 = Date_SMC.index(end_185)

# %%
#save the shortened versions of closing prices
D185 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_185_1:AC_185_2])
J185 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_185_1:FGEN_185_2])
M185 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_185_1:ICT_185_2])
R185 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_185_1:MEG_185_2])
Y185 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_185_1:SMC_185_2])

# %%
# import modules
import numpy as np
# import prices

D185 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
J185 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M185 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R185 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y185 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_185 = []
st_185 = []
n = 1
while n < len(D185):
    sc_185 = ''
    if D185[n] > D185[n-1]:
        sc_185 = sc_185 + 'D'
    if J185[n] > J185[n-1]:
        sc_185 = sc_185 + 'J'
    if M185[n] > M185[n-1]:
        sc_185 = sc_185 + 'M'
    if R185[n] > R185[n-1]:
        sc_185 = sc_185 + 'R'
    if Y185[n] > Y185[n-1]:
        sc_185 = sc_185 + 'Y'
    if len(sc_185) > 0:
        st_185.append(sc_185)
    else:
        STC_185.append(st_185)
        st_185 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 11
#       9 if J185[n] > J185[n-1]:
#      10     sc_185 = sc_185 + 'J'
# ---> 11 if M185[n] > M185[n-1]:
#      12     sc_185 = sc_185 + 'M'
#      13 if R185[n] > R185[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_185 = STC_185.count([])
# keep only non-empty spatio-temporal sequences
STC_185 = [ st_185 for st_185 in STC_185 if len(st_185) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_185 = len(D185)
lmax_185 = 0
for st_185 in STC_185:
    if len(st_185) < lmin_185:
        lmin_185 = len(st_185)
    if len(st_185) > lmax_185:
        lmax_185 = len(st_185)
        
# restrict spatio-temporal sequences to length-5
STC5_185 = [ st_185 for st_185 in STC_185 if len(st_185) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_185 = []
for n in range(len(STC5_185)):
    tc_185 = [ u for u in STC5_185[n][0] ]
    for k in range(1, len(STC5_185[n])):
        tc_185 = [ u+v for u in tc_185 for v in STC5_185[n][k] ]
    TC5_185 = TC5_185 + tc_185
setTC5_185 = list(set(TC5_185))

# get empirical frequencies
fTC5_185 = [ TC5_185.count(setTC5_185[l]) for l in range(len(setTC5_185)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_185 = [ [] for l in range(len(setTC5_185)) ]
for s in range(100):
    STC5null_185 = [ list(st_185) for st_185 in STC5_185]
    for st_185 in STC5null_185:
        np.random.shuffle(st_185)
    TC5null_185= []
    for n in range(len(STC5null_185)):
        tc_185 = [ u for u in STC5null_185[n][0] ]
        for k in range(1, len(STC5null_185[n])):
            tc_185 = [ u+v for u in tc_185 for v in STC5null_185[n][k] ]
        TC5null_185= TC5null_185+ tc_185
    for l in range(len(setTC5_185)):
        if TC5null_185.count(setTC5_185[l]) > 0:
            fTC5null_185[l].append(TC5null_185.count(setTC5_185[l]))
        else:
            fTC5null_185[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_185)):
     if sum(freq >= fTC5_185[l] for freq in fTC5null_185[l]) < 5:
#         print(setTC5_185[l], fTC5_185[l], sum(freq >= fTC5_185[l] for freq in fTC5null_185[l]))
        print(setTC5_185[l])

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_185)):
     if sum(freq >= fTC5_185[l] for freq in fTC5null_185[l]) < 1:
#         print(setTC5_185[l], fTC5_185[l], sum(freq >= fTC5_185[l] for freq in fTC5null_185[l]))
        print(setTC5_185[l])

# %% [markdown]
# # 3.186 (D) AC - (J) FGEN - (M) ICT - (R) MEG - (α) SCC

# %%
#extract overlapping dates
start_186 = max(min(Date_AC), min(Date_FGEN), min(Date_ICT), min(Date_MEG), min(Date_SCC))
end_186 = min(max(Date_AC), max(Date_FGEN), max(Date_ICT), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
AC_186_1 = Date_AC.index(start_186)
AC_186_2 = Date_AC.index(end_186)

FGEN_186_1 = Date_FGEN.index(start_186)
FGEN_186_2 = Date_FGEN.index(end_186)

ICT_186_1 = Date_ICT.index(start_186)
ICT_186_2 = Date_ICT.index(end_186)

MEG_186_1 = Date_MEG.index(start_186)
MEG_186_2 = Date_MEG.index(end_186)

SCC_186_1 = Date_SCC.index(start_186)
SCC_186_2 = Date_SCC.index(end_186)

# %%
#save the shortened versions of closing prices
D186 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_186_1:AC_186_2])
J186 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_186_1:FGEN_186_2])
M186 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_186_1:ICT_186_2])
R186 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_186_1:MEG_186_2])
α186 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_186_1:SCC_186_2])

# %%
# import modules
import numpy as np
# import prices

D186 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
J186 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M186 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R186 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α186 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_186 = []
st_186 = []
n = 1
while n < len(D186):
    sc_186 = ''
    if D186[n] > D186[n-1]:
        sc_186 = sc_186 + 'D'
    if J186[n] > J186[n-1]:
        sc_186 = sc_186 + 'J'
    if M186[n] > M186[n-1]:
        sc_186 = sc_186 + 'M'
    if R186[n] > R186[n-1]:
        sc_186 = sc_186 + 'R'
    if α186[n] > α186[n-1]:
        sc_186 = sc_186 + 'α'
    if len(sc_186) > 0:
        st_186.append(sc_186)
    else:
        STC_186.append(st_186)
        st_186 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[42], line 11
#       9 if J186[n] > J186[n-1]:
#      10     sc_186 = sc_186 + 'J'
# ---> 11 if M186[n] > M186[n-1]:
#      12     sc_186 = sc_186 + 'M'
#      13 if R186[n] > R186[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_186 = STC_186.count([])
# keep only non-empty spatio-temporal sequences
STC_186 = [ st_186 for st_186 in STC_186 if len(st_186) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_186 = len(D186)
lmax_186 = 0
for st_186 in STC_186:
    if len(st_186) < lmin_186:
        lmin_186 = len(st_186)
    if len(st_186) > lmax_186:
        lmax_186 = len(st_186)
        
# restrict spatio-temporal sequences to length-5
STC5_186 = [ st_186 for st_186 in STC_186 if len(st_186) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_186 = []
for n in range(len(STC5_186)):
    tc_186 = [ u for u in STC5_186[n][0] ]
    for k in range(1, len(STC5_186[n])):
        tc_186 = [ u+v for u in tc_186 for v in STC5_186[n][k] ]
    TC5_186 = TC5_186 + tc_186
setTC5_186 = list(set(TC5_186))

# get empirical frequencies
fTC5_186 = [ TC5_186.count(setTC5_186[l]) for l in range(len(setTC5_186)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_186 = [ [] for l in range(len(setTC5_186)) ]
for s in range(100):
    STC5null_186 = [ list(st_186) for st_186 in STC5_186]
    for st_186 in STC5null_186:
        np.random.shuffle(st_186)
    TC5null_186= []
    for n in range(len(STC5null_186)):
        tc_186 = [ u for u in STC5null_186[n][0] ]
        for k in range(1, len(STC5null_186[n])):
            tc_186 = [ u+v for u in tc_186 for v in STC5null_186[n][k] ]
        TC5null_186= TC5null_186+ tc_186
    for l in range(len(setTC5_186)):
        if TC5null_186.count(setTC5_186[l]) > 0:
            fTC5null_186[l].append(TC5null_186.count(setTC5_186[l]))
        else:
            fTC5null_186[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_186)):
     if sum(freq >= fTC5_186[l] for freq in fTC5null_186[l]) < 5:
#         print(setTC5_186[l], fTC5_186[l], sum(freq >= fTC5_186[l] for freq in fTC5null_186[l]))
        print(setTC5_186[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# RDααD
# RJααR
# MJJD
# RααRM
# RMD
# MJJM
# RDααJ
# αMααJ
# RDDαJ
# RJααD
# DJDJJ
# RJJRD
# αJαJJ
# RMααJ
# RDMαJ
# RD
# MαJD
# RRMαR
# RMDDD
# MαMD
# RJDJD
# RRααJ
# RαD
# RRααR
# RMDαJ
# DαMM
# MJαJJ
# RMαRJ
# RJDJR
# RMM
# RMαRD
# DJαJJ
# RMαRM
# JDαJ
# RDαRM
# JRRα
# RJα
# RRD
# Mα
# RRαRM
# MαJM
# RMDRM
# RJD
# MDRM
# RMRJD
# DDααD
# DαααJ
# RRααD
# ααJR
# RJααM
# αMMαR
# RRααM
# JRJα
# RMMαR
# ααMR
# RJαRM
# ααRR
# RJMαR
# JMRαD
# JRαα
# MJJRD

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_186)):
     if sum(freq >= fTC5_186[l] for freq in fTC5null_186[l]) < 1:
#         print(setTC5_186[l], fTC5_186[l], sum(freq >= fTC5_186[l] for freq in fTC5null_186[l]))
        print(setTC5_186[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# RDααD
# RMD
# RMαRM
# RDαRM
# RJD
# RRααD

# %% [markdown]
# # 3.187 (D) AC - (J) FGEN - (M) ICT - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_187 = max(min(Date_AC), min(Date_FGEN), min(Date_ICT), min(Date_SMC), min(Date_SCC))
end_187 = min(max(Date_AC), max(Date_FGEN), max(Date_ICT), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
AC_187_1 = Date_AC.index(start_187)
AC_187_2 = Date_AC.index(end_187)

FGEN_187_1 = Date_FGEN.index(start_187)
FGEN_187_2 = Date_FGEN.index(end_187)

ICT_187_1 = Date_ICT.index(start_187)
ICT_187_2 = Date_ICT.index(end_187)

SMC_187_1 = Date_SMC.index(start_187)
SMC_187_2 = Date_SMC.index(end_187)

SCC_187_1 = Date_SCC.index(start_187)
SCC_187_2 = Date_SCC.index(end_187)

# %%
#save the shortened versions of closing prices
D187 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_187_1:AC_187_2])
J187 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_187_1:FGEN_187_2])
M187 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_187_1:ICT_187_2])
Y187 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_187_1:SMC_187_2])
α187 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_187_1:SCC_187_2])

# %%
# import modules
import numpy as np
# import prices

D187 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
J187 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M187 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
Y187 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α187 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_187 = []
st_187 = []
n = 1
while n < len(D187):
    sc_187 = ''
    if D187[n] > D187[n-1]:
        sc_187 = sc_187 + 'D'
    if J187[n] > J187[n-1]:
        sc_187 = sc_187 + 'J'
    if M187[n] > M187[n-1]:
        sc_187 = sc_187 + 'M'
    if Y187[n] > Y187[n-1]:
        sc_187 = sc_187 + 'Y'
    if α187[n] > α187[n-1]:
        sc_187 = sc_187 + 'α'
    if len(sc_187) > 0:
        st_187.append(sc_187)
    else:
        STC_187.append(st_187)
        st_187 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[50], line 11
#       9 if J187[n] > J187[n-1]:
#      10     sc_187 = sc_187 + 'J'
# ---> 11 if M187[n] > M187[n-1]:
#      12     sc_187 = sc_187 + 'M'
#      13 if Y187[n] > Y187[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_187 = STC_187.count([])
# keep only non-empty spatio-temporal sequences
STC_187 = [ st_187 for st_187 in STC_187 if len(st_187) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_187 = len(D187)
lmax_187 = 0
for st_187 in STC_187:
    if len(st_187) < lmin_187:
        lmin_187 = len(st_187)
    if len(st_187) > lmax_187:
        lmax_187 = len(st_187)
        
# restrict spatio-temporal sequences to length-5
STC5_187 = [ st_187 for st_187 in STC_187 if len(st_187) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_187 = []
for n in range(len(STC5_187)):
    tc_187 = [ u for u in STC5_187[n][0] ]
    for k in range(1, len(STC5_187[n])):
        tc_187 = [ u+v for u in tc_187 for v in STC5_187[n][k] ]
    TC5_187 = TC5_187 + tc_187
setTC5_187 = list(set(TC5_187))

# get empirical frequencies
fTC5_187 = [ TC5_187.count(setTC5_187[l]) for l in range(len(setTC5_187)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_187 = [ [] for l in range(len(setTC5_187)) ]
for s in range(100):
    STC5null_187 = [ list(st_187) for st_187 in STC5_187]
    for st_187 in STC5null_187:
        np.random.shuffle(st_187)
    TC5null_187= []
    for n in range(len(STC5null_187)):
        tc_187 = [ u for u in STC5null_187[n][0] ]
        for k in range(1, len(STC5null_187[n])):
            tc_187 = [ u+v for u in tc_187 for v in STC5null_187[n][k] ]
        TC5null_187= TC5null_187+ tc_187
    for l in range(len(setTC5_187)):
        if TC5null_187.count(setTC5_187[l]) > 0:
            fTC5null_187[l].append(TC5null_187.count(setTC5_187[l]))
        else:
            fTC5null_187[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_187)):
     if sum(freq >= fTC5_187[l] for freq in fTC5null_187[l]) < 5:
#         print(setTC5_187[l], fTC5_187[l], sum(freq >= fTC5_187[l] for freq in fTC5null_187[l]))
        print(setTC5_187[l])

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_187)):
     if sum(freq >= fTC5_187[l] for freq in fTC5null_187[l]) < 1:
#         print(setTC5_187[l], fTC5_187[l], sum(freq >= fTC5_187[l] for freq in fTC5null_187[l]))
        print(setTC5_187[l])

# %% [markdown]
# # 3.188 (D) AC - (J) FGEN - (N) JGS - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_188 = max(min(Date_AC), min(Date_FGEN), min(Date_JGS), min(Date_MEG), min(Date_SMC))
end_188 = min(max(Date_AC), max(Date_FGEN), max(Date_JGS), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
AC_188_1 = Date_AC.index(start_188)
AC_188_2 = Date_AC.index(end_188)

FGEN_188_1 = Date_FGEN.index(start_188)
FGEN_188_2 = Date_FGEN.index(end_188)

JGS_188_1 = Date_JGS.index(start_188)
JGS_188_2 = Date_JGS.index(end_188)

MEG_188_1 = Date_MEG.index(start_188)
MEG_188_2 = Date_MEG.index(end_188)

SMC_188_1 = Date_SMC.index(start_188)
SMC_188_2 = Date_SMC.index(end_188)

# %%
#save the shortened versions of closing prices
D188 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_188_1:AC_188_2])
J188 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_188_1:FGEN_188_2])
N188 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_188_1:JGS_188_2])
R188 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_188_1:MEG_188_2])
Y188 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_188_1:SMC_188_2])

# %%
# import modules
import numpy as np
# import prices

D188 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
J188 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N188 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R188 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y188 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_188 = []
st_188 = []
n = 1
while n < len(D188):
    sc_188 = ''
    if D188[n] > D188[n-1]:
        sc_188 = sc_188 + 'D'
    if J188[n] > J188[n-1]:
        sc_188 = sc_188 + 'J'
    if N188[n] > N188[n-1]:
        sc_188 = sc_188 + 'N'
    if R188[n] > R188[n-1]:
        sc_188 = sc_188 + 'R'
    if Y188[n] > Y188[n-1]:
        sc_188 = sc_188 + 'Y'
    if len(sc_188) > 0:
        st_188.append(sc_188)
    else:
        STC_188.append(st_188)
        st_188 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_188 = STC_188.count([])
# keep only non-empty spatio-temporal sequences
STC_188 = [ st_188 for st_188 in STC_188 if len(st_188) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_188 = len(D188)
lmax_188 = 0
for st_188 in STC_188:
    if len(st_188) < lmin_188:
        lmin_188 = len(st_188)
    if len(st_188) > lmax_188:
        lmax_188 = len(st_188)
        
# restrict spatio-temporal sequences to length-5
STC5_188 = [ st_188 for st_188 in STC_188 if len(st_188) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_188 = []
for n in range(len(STC5_188)):
    tc_188 = [ u for u in STC5_188[n][0] ]
    for k in range(1, len(STC5_188[n])):
        tc_188 = [ u+v for u in tc_188 for v in STC5_188[n][k] ]
    TC5_188 = TC5_188 + tc_188
setTC5_188 = list(set(TC5_188))

# get empirical frequencies
fTC5_188 = [ TC5_188.count(setTC5_188[l]) for l in range(len(setTC5_188)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_188 = [ [] for l in range(len(setTC5_188)) ]
for s in range(100):
    STC5null_188 = [ list(st_188) for st_188 in STC5_188]
    for st_188 in STC5null_188:
        np.random.shuffle(st_188)
    TC5null_188= []
    for n in range(len(STC5null_188)):
        tc_188 = [ u for u in STC5null_188[n][0] ]
        for k in range(1, len(STC5null_188[n])):
            tc_188 = [ u+v for u in tc_188 for v in STC5null_188[n][k] ]
        TC5null_188= TC5null_188+ tc_188
    for l in range(len(setTC5_188)):
        if TC5null_188.count(setTC5_188[l]) > 0:
            fTC5null_188[l].append(TC5null_188.count(setTC5_188[l]))
        else:
            fTC5null_188[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_188)):
     if sum(freq >= fTC5_188[l] for freq in fTC5null_188[l]) < 5:
#         print(setTC5_188[l], fTC5_188[l], sum(freq >= fTC5_188[l] for freq in fTC5null_188[l]))
        print(setTC5_188[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# YYRRN
# NDNJ
# DYJN
# DRJNR
# DDDNR
# YDNJ
# JJYJJ
# JYNJ
# JDYNJ
# NYNRJ
# DNYJY
# YDDR
# DYNRN
# YDJYY
# RNDRJ
# RDYNN
# YYRDN
# JDYJY
# DYNYR
# YYYRN
# YDYDN
# YDRRN
# NYNRN
# YYRYN
# NDRR
# YYDYN
# RJJNY
# DYJYN
# JDYDJ
# DYNRR
# YDRR
# DYRRR
# JRYJJ
# DYJDR
# DNYDD
# DRJYR
# DJJDD
# YDRDN
# DYJNR
# JDYJN
# RDYJN
# DYJDD
# NDDR
# DYNYN
# DYJYR
# YDNR
# NDRJ
# JDJR
# RDYRN
# NYNYN
# JDYJJ
# DDRRR
# NDDYJ
# DYDN
# DDJR
# YDJR
# NJJJD
# YDRJ

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_188)):
     if sum(freq >= fTC5_188[l] for freq in fTC5null_188[l]) < 1:
#         print(setTC5_188[l], fTC5_188[l], sum(freq >= fTC5_188[l] for freq in fTC5null_188[l]))
        print(setTC5_188[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# YDDR
# NDRR
# DYJDR
# DRJYR
# DYJYR
# JDYJJ

# %% [markdown]
# # 3.189 (D) AC - (J) FGEN - (N) JGS - (R) MEG - (α) SCC

# %%
#extract overlapping dates
start_189 = max(min(Date_AC), min(Date_FGEN), min(Date_JGS), min(Date_MEG), min(Date_SCC))
end_189 = min(max(Date_AC), max(Date_FGEN), max(Date_JGS), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
AC_189_1 = Date_AC.index(start_189)
AC_189_2 = Date_AC.index(end_189)

FGEN_189_1 = Date_FGEN.index(start_189)
FGEN_189_2 = Date_FGEN.index(end_189)

JGS_189_1 = Date_JGS.index(start_189)
JGS_189_2 = Date_JGS.index(end_189)

MEG_189_1 = Date_MEG.index(start_189)
MEG_189_2 = Date_MEG.index(end_189)

SCC_189_1 = Date_SCC.index(start_189)
SCC_189_2 = Date_SCC.index(end_189)

# %%
#save the shortened versions of closing prices
D189 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_189_1:AC_189_2])
J189 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_189_1:FGEN_189_2])
N189 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_189_1:JGS_189_2])
R189 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_189_1:MEG_189_2])
α189 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_189_1:SCC_189_2])

# %%
# import modules
import numpy as np
# import prices

D189 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
J189 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N189 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R189 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α189 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_189 = []
st_189 = []
n = 1
while n < len(D189):
    sc_189 = ''
    if D189[n] > D189[n-1]:
        sc_189 = sc_189 + 'D'
    if J189[n] > J189[n-1]:
        sc_189 = sc_189 + 'J'
    if N189[n] > N189[n-1]:
        sc_189 = sc_189 + 'N'
    if R189[n] > R189[n-1]:
        sc_189 = sc_189 + 'R'
    if α189[n] > α189[n-1]:
        sc_189 = sc_189 + 'α'
    if len(sc_189) > 0:
        st_189.append(sc_189)
    else:
        STC_189.append(st_189)
        st_189 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_189 = STC_189.count([])
# keep only non-empty spatio-temporal sequences
STC_189 = [ st_189 for st_189 in STC_189 if len(st_189) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_189 = len(D189)
lmax_189 = 0
for st_189 in STC_189:
    if len(st_189) < lmin_189:
        lmin_189 = len(st_189)
    if len(st_189) > lmax_189:
        lmax_189 = len(st_189)
        
# restrict spatio-temporal sequences to length-5
STC5_189 = [ st_189 for st_189 in STC_189 if len(st_189) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_189 = []
for n in range(len(STC5_189)):
    tc_189 = [ u for u in STC5_189[n][0] ]
    for k in range(1, len(STC5_189[n])):
        tc_189 = [ u+v for u in tc_189 for v in STC5_189[n][k] ]
    TC5_189 = TC5_189 + tc_189
setTC5_189 = list(set(TC5_189))

# get empirical frequencies
fTC5_189 = [ TC5_189.count(setTC5_189[l]) for l in range(len(setTC5_189)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_189 = [ [] for l in range(len(setTC5_189)) ]
for s in range(100):
    STC5null_189 = [ list(st_189) for st_189 in STC5_189]
    for st_189 in STC5null_189:
        np.random.shuffle(st_189)
    TC5null_189= []
    for n in range(len(STC5null_189)):
        tc_189 = [ u for u in STC5null_189[n][0] ]
        for k in range(1, len(STC5null_189[n])):
            tc_189 = [ u+v for u in tc_189 for v in STC5null_189[n][k] ]
        TC5null_189= TC5null_189+ tc_189
    for l in range(len(setTC5_189)):
        if TC5null_189.count(setTC5_189[l]) > 0:
            fTC5null_189[l].append(TC5null_189.count(setTC5_189[l]))
        else:
            fTC5null_189[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_189)):
     if sum(freq >= fTC5_189[l] for freq in fTC5null_189[l]) < 5:
#         print(setTC5_189[l], fTC5_189[l], sum(freq >= fTC5_189[l] for freq in fTC5null_189[l]))
        print(setTC5_189[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# DNNRD
# RJJRN
# αJJRJ
# αJJDJ
# αDRR
# DJJRα
# NJJJN
# RRαRN
# NNNDα
# NDJJN
# αJJJJ
# DNααJ
# DNαDN
# αNJJJ
# DJJDR
# DDJJN
# αDDJ
# RNαRD
# NJJRα
# αDDN
# RJJDR
# DRNRN
# DDααα
# αDDR
# NJJRN
# αJJDN
# NDRJN
# NαNα
# DNααN
# αNαDJ
# RJ
# NDRR
# RRαNR
# RJJRR
# DααRJ
# αDRN
# αJJNJ
# DJJDN
# RRD
# DRJJN
# αNJDN
# DJJJN
# RN
# DJJJJ
# DJJDJ
# DNJRN
# NNJJN
# αJJDR
# JDRR
# RRαRα
# DDαRD
# ααJR
# DNJJJ
# NRJJN
# DJJRN
# JJJα
# NJNRN
# DDαRJ
# JNNDN
# αJJRN
# DJJRJ
# αNJRN
# JDJR
# JRJα
# DDαRR
# αNααJ
# NRNRN
# αJJRR
# ααRR
# JNNRN
# DDJR
# DJJRR

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_189)):
     if sum(freq >= fTC5_189[l] for freq in fTC5null_189[l]) < 1:
#         print(setTC5_189[l], fTC5_189[l], sum(freq >= fTC5_189[l] for freq in fTC5null_189[l]))
        print(setTC5_189[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# αDRR
# NJJRα
# αDDR
# NJJRN
# DJJJJ
# DJJDJ
# DDαRD
# DNJJJ
# DJJRN
# αJJRN
# ααRR
# JNNRN

# %% [markdown]
# # 3.190 (D) AC - (J) FGEN - (N) JGS - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_190 = max(min(Date_AC), min(Date_FGEN), min(Date_JGS), min(Date_SMC), min(Date_SCC))
end_190 = min(max(Date_AC), max(Date_FGEN), max(Date_JGS), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
AC_190_1 = Date_AC.index(start_190)
AC_190_2 = Date_AC.index(end_190)

FGEN_190_1 = Date_FGEN.index(start_190)
FGEN_190_2 = Date_FGEN.index(end_190)

JGS_190_1 = Date_JGS.index(start_190)
JGS_190_2 = Date_JGS.index(end_190)

SMC_190_1 = Date_SMC.index(start_190)
SMC_190_2 = Date_SMC.index(end_190)

SCC_190_1 = Date_SCC.index(start_190)
SCC_190_2 = Date_SCC.index(end_190)

# %%
#save the shortened versions of closing prices
D190 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_190_1:AC_190_2])
J190 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_190_1:FGEN_190_2])
N190 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_190_1:JGS_190_2])
Y190 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_190_1:SMC_190_2])
α190 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_190_1:SCC_190_2])

# %%
# import modules
import numpy as np
# import prices

D190 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
J190 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N190 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y190 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α190 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_190 = []
st_190 = []
n = 1
while n < len(D190):
    sc_190 = ''
    if D190[n] > D190[n-1]:
        sc_190 = sc_190 + 'D'
    if J190[n] > J190[n-1]:
        sc_190 = sc_190 + 'J'
    if N190[n] > N190[n-1]:
        sc_190 = sc_190 + 'N'
    if Y190[n] > Y190[n-1]:
        sc_190 = sc_190 + 'Y'
    if α190[n] > α190[n-1]:
        sc_190 = sc_190 + 'α'
    if len(sc_190) > 0:
        st_190.append(sc_190)
    else:
        STC_190.append(st_190)
        st_190 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_190 = STC_190.count([])
# keep only non-empty spatio-temporal sequences
STC_190 = [ st_190 for st_190 in STC_190 if len(st_190) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_190 = len(D190)
lmax_190 = 0
for st_190 in STC_190:
    if len(st_190) < lmin_190:
        lmin_190 = len(st_190)
    if len(st_190) > lmax_190:
        lmax_190 = len(st_190)
        
# restrict spatio-temporal sequences to length-5
STC5_190 = [ st_190 for st_190 in STC_190 if len(st_190) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_190 = []
for n in range(len(STC5_190)):
    tc_190 = [ u for u in STC5_190[n][0] ]
    for k in range(1, len(STC5_190[n])):
        tc_190 = [ u+v for u in tc_190 for v in STC5_190[n][k] ]
    TC5_190 = TC5_190 + tc_190
setTC5_190 = list(set(TC5_190))

# get empirical frequencies
fTC5_190 = [ TC5_190.count(setTC5_190[l]) for l in range(len(setTC5_190)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_190 = [ [] for l in range(len(setTC5_190)) ]
for s in range(100):
    STC5null_190 = [ list(st_190) for st_190 in STC5_190]
    for st_190 in STC5null_190:
        np.random.shuffle(st_190)
    TC5null_190= []
    for n in range(len(STC5null_190)):
        tc_190 = [ u for u in STC5null_190[n][0] ]
        for k in range(1, len(STC5null_190[n])):
            tc_190 = [ u+v for u in tc_190 for v in STC5null_190[n][k] ]
        TC5null_190= TC5null_190+ tc_190
    for l in range(len(setTC5_190)):
        if TC5null_190.count(setTC5_190[l]) > 0:
            fTC5null_190[l].append(TC5null_190.count(setTC5_190[l]))
        else:
            fTC5null_190[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_190)):
     if sum(freq >= fTC5_190[l] for freq in fTC5null_190[l]) < 5:
#         print(setTC5_190[l], fTC5_190[l], sum(freq >= fTC5_190[l] for freq in fTC5null_190[l]))
        print(setTC5_190[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# DJJDα
# JYDJ
# NYαYJ
# NJJDα
# DNJDα
# NJDJ
# ααDDY
# αNααα
# αNJDD
# NYNαJ
# DDαD
# αDααα
# DNJDD
# NDNDJ
# NYJYN
# NYαYD
# NαYYJ
# YYJN
# NYJYD
# NNJDN
# ααJDY
# NDαYJ
# αNαDJ
# NDαYD
# ND
# YαYYJ
# NJYN
# DYJYN
# ααJJY
# ααDNY
# NDNYJ
# DYYN
# YDYYJ
# αNJDN
# NDYYJ
# JYYJ
# NYNYJ
# NNNαD
# JJDJ
# NYDYJ
# ααJNY
# DYNN
# DJJDD
# NNJDα
# ααYYJ
# DYNYN
# JαYYJ
# NYNYN
# NαDDY
# JDYJJ
# αDYYJ
# NDNNJ
# DYDN
# αNααJ
# DYαN
# NYNYD

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_190)):
     if sum(freq >= fTC5_190[l] for freq in fTC5null_190[l]) < 1:
#         print(setTC5_190[l], fTC5_190[l], sum(freq >= fTC5_190[l] for freq in fTC5null_190[l]))
        print(setTC5_190[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# NYαYJ
# ααDDY
# αDααα
# NYJYN
# NDαYJ
# YαYYJ
# NDNYJ
# NYNYJ
# αNααJ

# %% [markdown]
# # 3.191 (D) AC - (J) FGEN - (R) MEG - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_191 = max(min(Date_AC), min(Date_FGEN), min(Date_MEG), min(Date_SMC), min(Date_SCC))
end_191 = min(max(Date_AC), max(Date_FGEN), max(Date_MEG), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
AC_191_1 = Date_AC.index(start_191)
AC_191_2 = Date_AC.index(end_191)

FGEN_191_1 = Date_FGEN.index(start_191)
FGEN_191_2 = Date_FGEN.index(end_191)

MEG_191_1 = Date_MEG.index(start_191)
MEG_191_2 = Date_MEG.index(end_191)

SMC_191_1 = Date_SMC.index(start_191)
SMC_191_2 = Date_SMC.index(end_191)

SCC_191_1 = Date_SCC.index(start_191)
SCC_191_2 = Date_SCC.index(end_191)

# %%
#save the shortened versions of closing prices
D191 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_191_1:AC_191_2])
J191 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_191_1:FGEN_191_2])
R191 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_191_1:MEG_191_2])
Y191 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_191_1:SMC_191_2])
α191 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_191_1:SCC_191_2])

# %%
# import modules
import numpy as np
# import prices

D191 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
J191 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
R191 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y191 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α191 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_191 = []
st_191 = []
n = 1
while n < len(D191):
    sc_191 = ''
    if D191[n] > D191[n-1]:
        sc_191 = sc_191 + 'D'
    if J191[n] > J191[n-1]:
        sc_191 = sc_191 + 'J'
    if R191[n] > R191[n-1]:
        sc_191 = sc_191 + 'R'
    if Y191[n] > Y191[n-1]:
        sc_191 = sc_191 + 'Y'
    if α191[n] > α191[n-1]:
        sc_191 = sc_191 + 'α'
    if len(sc_191) > 0:
        st_191.append(sc_191)
    else:
        STC_191.append(st_191)
        st_191 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_191 = STC_191.count([])
# keep only non-empty spatio-temporal sequences
STC_191 = [ st_191 for st_191 in STC_191 if len(st_191) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_191 = len(D191)
lmax_191 = 0
for st_191 in STC_191:
    if len(st_191) < lmin_191:
        lmin_191 = len(st_191)
    if len(st_191) > lmax_191:
        lmax_191 = len(st_191)
        
# restrict spatio-temporal sequences to length-5
STC5_191 = [ st_191 for st_191 in STC_191 if len(st_191) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_191 = []
for n in range(len(STC5_191)):
    tc_191 = [ u for u in STC5_191[n][0] ]
    for k in range(1, len(STC5_191[n])):
        tc_191 = [ u+v for u in tc_191 for v in STC5_191[n][k] ]
    TC5_191 = TC5_191 + tc_191
setTC5_191 = list(set(TC5_191))

# get empirical frequencies
fTC5_191 = [ TC5_191.count(setTC5_191[l]) for l in range(len(setTC5_191)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_191 = [ [] for l in range(len(setTC5_191)) ]
for s in range(100):
    STC5null_191 = [ list(st_191) for st_191 in STC5_191]
    for st_191 in STC5null_191:
        np.random.shuffle(st_191)
    TC5null_191= []
    for n in range(len(STC5null_191)):
        tc_191 = [ u for u in STC5null_191[n][0] ]
        for k in range(1, len(STC5null_191[n])):
            tc_191 = [ u+v for u in tc_191 for v in STC5null_191[n][k] ]
        TC5null_191= TC5null_191+ tc_191
    for l in range(len(setTC5_191)):
        if TC5null_191.count(setTC5_191[l]) > 0:
            fTC5null_191[l].append(TC5null_191.count(setTC5_191[l]))
        else:
            fTC5null_191[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_191)):
     if sum(freq >= fTC5_191[l] for freq in fTC5null_191[l]) < 5:
#         print(setTC5_191[l], fTC5_191[l], sum(freq >= fTC5_191[l] for freq in fTC5null_191[l]))
        print(setTC5_191[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# αααYD
# JJYJR
# DJJDα
# DDαJR
# DJαYD
# αDRR
# DYJRR
# DRαYR
# αYYYJ
# DRDαR
# DRααR
# DDαYR
# αRααR
# RDDαJ
# DJαRR
# RJαRR
# RYJ
# DYYY
# RJJRD
# DJαYR
# DαααR
# DRRYR
# DRααD
# αααYY
# DRαYD
# αYJYD
# DYJYD
# αJαYR
# αRRYY
# DDαDR
# RRYY
# αDDR
# αRYYY
# αJαJD
# αRαYY
# αRαYD
# DαYJY
# YαJD
# DYαYR
# αYYYD
# RαααY
# DJααD
# DRRRR
# DJααR
# RJααJ
# αJααY
# αααYJ
# DYαRR
# DRαYY
# ααYJY
# αRαYJ
# DYαYD
# DYRYR
# YDRR
# αRJYD
# αRYYJ
# DYRRR
# JRYJR
# YαJR
# DJJDD
# αDJR
# RJααY
# DDααR
# DDαRD
# ααJR
# RJJJY
# DYJYR
# αRYYD
# ααRYY
# RαYY
# DJαDR
# DααYY
# αYαYD
# DαRYY
# αJααJ
# JDJR
# RαDαJ
# DDRRR
# DDαRR
# JαRYY
# RYD
# RαDαY
# RRRYY
# ααRR
# αRααD
# DDJR
# DRRαR
# YDJR
# αRαYR
# DJYJR

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_191)):
     if sum(freq >= fTC5_191[l] for freq in fTC5null_191[l]) < 1:
#         print(setTC5_191[l], fTC5_191[l], sum(freq >= fTC5_191[l] for freq in fTC5null_191[l]))
        print(setTC5_191[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# αDRR
# DRαYR
# RYJ
# DRααD
# αααYY
# DDαDR
# DJααR
# αααYJ
# DRαYY
# RαYY
# DJαDR
# DRRαR

# %% [markdown]
# # 3.192 (D) AC - (M) ICT - (N) JGS - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_192 = max(min(Date_AC), min(Date_ICT), min(Date_JGS), min(Date_MEG), min(Date_SMC))
end_192 = min(max(Date_AC), max(Date_ICT), max(Date_JGS), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
AC_192_1 = Date_AC.index(start_192)
AC_192_2 = Date_AC.index(end_192)

ICT_192_1 = Date_ICT.index(start_192)
ICT_192_2 = Date_ICT.index(end_192)

JGS_192_1 = Date_JGS.index(start_192)
JGS_192_2 = Date_JGS.index(end_192)

MEG_192_1 = Date_MEG.index(start_192)
MEG_192_2 = Date_MEG.index(end_192)

SMC_192_1 = Date_SMC.index(start_192)
SMC_192_2 = Date_SMC.index(end_192)

# %%
#save the shortened versions of closing prices
D192 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_192_1:AC_192_2])
M192 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_192_1:ICT_192_2])
N192 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_192_1:JGS_192_2])
R192 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_192_1:MEG_192_2])
Y192 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_192_1:SMC_192_2])

# %%
# import modules
import numpy as np
# import prices

D192 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
M192 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N192 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R192 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y192 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_192 = []
st_192 = []
n = 1
while n < len(D192):
    sc_192 = ''
    if D192[n] > D192[n-1]:
        sc_192 = sc_192 + 'D'
    if M192[n] > M192[n-1]:
        sc_192 = sc_192 + 'M'
    if N192[n] > N192[n-1]:
        sc_192 = sc_192 + 'N'
    if R192[n] > R192[n-1]:
        sc_192 = sc_192 + 'R'
    if Y192[n] > Y192[n-1]:
        sc_192 = sc_192 + 'Y'
    if len(sc_192) > 0:
        st_192.append(sc_192)
    else:
        STC_192.append(st_192)
        st_192 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_192 = STC_192.count([])
# keep only non-empty spatio-temporal sequences
STC_192 = [ st_192 for st_192 in STC_192 if len(st_192) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_192 = len(D192)
lmax_192 = 0
for st_192 in STC_192:
    if len(st_192) < lmin_192:
        lmin_192 = len(st_192)
    if len(st_192) > lmax_192:
        lmax_192 = len(st_192)
        
# restrict spatio-temporal sequences to length-5
STC5_192 = [ st_192 for st_192 in STC_192 if len(st_192) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_192 = []
for n in range(len(STC5_192)):
    tc_192 = [ u for u in STC5_192[n][0] ]
    for k in range(1, len(STC5_192[n])):
        tc_192 = [ u+v for u in tc_192 for v in STC5_192[n][k] ]
    TC5_192 = TC5_192 + tc_192
setTC5_192 = list(set(TC5_192))

# get empirical frequencies
fTC5_192 = [ TC5_192.count(setTC5_192[l]) for l in range(len(setTC5_192)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_192 = [ [] for l in range(len(setTC5_192)) ]
for s in range(100):
    STC5null_192 = [ list(st_192) for st_192 in STC5_192]
    for st_192 in STC5null_192:
        np.random.shuffle(st_192)
    TC5null_192= []
    for n in range(len(STC5null_192)):
        tc_192 = [ u for u in STC5null_192[n][0] ]
        for k in range(1, len(STC5null_192[n])):
            tc_192 = [ u+v for u in tc_192 for v in STC5null_192[n][k] ]
        TC5null_192= TC5null_192+ tc_192
    for l in range(len(setTC5_192)):
        if TC5null_192.count(setTC5_192[l]) > 0:
            fTC5null_192[l].append(TC5null_192.count(setTC5_192[l]))
        else:
            fTC5null_192[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_192)):
     if sum(freq >= fTC5_192[l] for freq in fTC5null_192[l]) < 5:
#         print(setTC5_192[l], fTC5_192[l], sum(freq >= fTC5_192[l] for freq in fTC5null_192[l]))
        print(setTC5_192[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# MDMDN
# MMN
# MYY
# MMRR
# MDDR
# YMDD
# RYMR
# YNYRN
# RRMMM
# DMNR
# RDMMD
# DYYY
# MDDMN
# YYMN
# YYDD
# YRDDD
# RRMMN
# YYDMM
# YDDR
# YDDMY
# DYDNR
# DYDR
# YRDRN
# YYDN
# YMRD
# MDNR
# YRDDN
# DNY
# RMN
# RMMYD
# NRDNR
# YYRN
# YMMN
# YRMDR
# MMYYD
# NMDYD
# YNYDR
# MDRDD
# YNYDN
# MRDMR
# YRDDR
# YYMD
# MDMMD
# YNYNR
# YYRD
# YMMD
# MNMDN
# MNRNR
# MMND
# YMDN
# YNYNN
# MMYNM
# YDRR
# YNYMR
# DYDNM
# YDMR
# MRYYD
# NMMYD
# MMNR
# YDRDN
# YDDDD
# MDRDN
# MMDR
# MNMNN
# YMRN
# NDDR
# NDNR
# MNYNN
# RNDMD
# MNRDN
# DMN
# DRDNR
# MDMYD
# NMMYM
# MDMMN
# MRMYD
# YRRRN
# RNYND
# MYYNN
# MNYNR
# MNYND
# MNRMD
# YMMR
# YNNDN
# DNN

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_192)):
     if sum(freq >= fTC5_192[l] for freq in fTC5null_192[l]) < 1:
#         print(setTC5_192[l], fTC5_192[l], sum(freq >= fTC5_192[l] for freq in fTC5null_192[l]))
        print(setTC5_192[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# RDMMD
# YYDD
# DYDR
# MDNR
# DNY
# YMMN
# MMYYD
# YDMR
# MRYYD
# MMNR
# YMRN

# %% [markdown]
# # 3.193 (D) AC - (M) ICT - (N) JGS - (R) MEG - (α) SCC

# %%
#extract overlapping dates
start_193 = max(min(Date_AC), min(Date_ICT), min(Date_JGS), min(Date_MEG), min(Date_SCC))
end_193 = min(max(Date_AC), max(Date_ICT), max(Date_JGS), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
AC_193_1 = Date_AC.index(start_193)
AC_193_2 = Date_AC.index(end_193)

ICT_193_1 = Date_ICT.index(start_193)
ICT_193_2 = Date_ICT.index(end_193)

JGS_193_1 = Date_JGS.index(start_193)
JGS_193_2 = Date_JGS.index(end_193)

MEG_193_1 = Date_MEG.index(start_193)
MEG_193_2 = Date_MEG.index(end_193)

SCC_193_1 = Date_SCC.index(start_193)
SCC_193_2 = Date_SCC.index(end_193)

# %%
#save the shortened versions of closing prices
D193 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_193_1:AC_193_2])
M193 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_193_1:ICT_193_2])
N193 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_193_1:JGS_193_2])
R193 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_193_1:MEG_193_2])
α193 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_193_1:SCC_193_2])

# %%
# import modules
import numpy as np
# import prices

D193 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
M193 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N193 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R193 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α193 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_193 = []
st_193 = []
n = 1
while n < len(D193):
    sc_193 = ''
    if D193[n] > D193[n-1]:
        sc_193 = sc_193 + 'D'
    if M193[n] > M193[n-1]:
        sc_193 = sc_193 + 'M'
    if N193[n] > N193[n-1]:
        sc_193 = sc_193 + 'N'
    if R193[n] > R193[n-1]:
        sc_193 = sc_193 + 'R'
    if α193[n] > α193[n-1]:
        sc_193 = sc_193 + 'α'
    if len(sc_193) > 0:
        st_193.append(sc_193)
    else:
        STC_193.append(st_193)
        st_193 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_193 = STC_193.count([])
# keep only non-empty spatio-temporal sequences
STC_193 = [ st_193 for st_193 in STC_193 if len(st_193) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_193 = len(D193)
lmax_193 = 0
for st_193 in STC_193:
    if len(st_193) < lmin_193:
        lmin_193 = len(st_193)
    if len(st_193) > lmax_193:
        lmax_193 = len(st_193)
        
# restrict spatio-temporal sequences to length-5
STC5_193 = [ st_193 for st_193 in STC_193 if len(st_193) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_193 = []
for n in range(len(STC5_193)):
    tc_193 = [ u for u in STC5_193[n][0] ]
    for k in range(1, len(STC5_193[n])):
        tc_193 = [ u+v for u in tc_193 for v in STC5_193[n][k] ]
    TC5_193 = TC5_193 + tc_193
setTC5_193 = list(set(TC5_193))

# get empirical frequencies
fTC5_193 = [ TC5_193.count(setTC5_193[l]) for l in range(len(setTC5_193)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_193 = [ [] for l in range(len(setTC5_193)) ]
for s in range(100):
    STC5null_193 = [ list(st_193) for st_193 in STC5_193]
    for st_193 in STC5null_193:
        np.random.shuffle(st_193)
    TC5null_193= []
    for n in range(len(STC5null_193)):
        tc_193 = [ u for u in STC5null_193[n][0] ]
        for k in range(1, len(STC5null_193[n])):
            tc_193 = [ u+v for u in tc_193 for v in STC5null_193[n][k] ]
        TC5null_193= TC5null_193+ tc_193
    for l in range(len(setTC5_193)):
        if TC5null_193.count(setTC5_193[l]) > 0:
            fTC5null_193[l].append(TC5null_193.count(setTC5_193[l]))
        else:
            fTC5null_193[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_193)):
     if sum(freq >= fTC5_193[l] for freq in fTC5null_193[l]) < 5:
#         print(setTC5_193[l], fTC5_193[l], sum(freq >= fTC5_193[l] for freq in fTC5null_193[l]))
        print(setTC5_193[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# RRNR
# MDMDN
# RRMMα
# MRNαα
# RDαRN
# MRDαα
# RMMαα
# DMND
# MRDDN
# RDMMα
# RRMMD
# RRMMM
# MNMαα
# MNMNα
# DMNR
# DNMDN
# RDMMD
# RRαMR
# MRMαα
# DNNDN
# αNααα
# RDαRα
# αMRR
# ααDα
# RRαMN
# MDDMN
# DDMDN
# MNDα
# RDMαN
# MRαMN
# NαRR
# MNMαD
# RDααα
# RRM
# DRααD
# RRMMN
# NMNR
# RRααα
# MRMαD
# RNMDN
# RRND
# αRααα
# RD
# MRMαN
# αRDαα
# MRMNα
# RRMαN
# MDMαD
# αMNR
# RαN
# MRMMN
# MDMαN
# MRDRN
# MDMαα
# RDMαα
# RRMαα
# MDMMD
# DNDα
# MRαMD
# MNMDN
# MDMNα
# RDMDN
# MRαMR
# MRMDN
# RN
# MNMMN
# NRRRR
# αNMαα
# MαMαN
# RMMαD
# DDNDN
# MRMMD
# MMNR
# RDααN
# MNMαN
# MRNαN
# αRMαα
# NαRα
# MRMRN
# RMMD
# MNMNN
# MRααD
# DRNDN
# NRRDR
# MRααα
# αRRDR
# MDMMN
# RDαMN
# MRRR
# MNαMM
# NMMαα
# MNRMD
# RRMαD
# MDDα
# MNDαα
# DRαMR
# NMNαα

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_193)):
     if sum(freq >= fTC5_193[l] for freq in fTC5null_193[l]) < 1:
#         print(setTC5_193[l], fTC5_193[l], sum(freq >= fTC5_193[l] for freq in fTC5null_193[l]))
        print(setTC5_193[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# MDMDN
# RRMMα
# RMMαα
# RDMMD
# MRMαα
# MNDα
# MRMαD
# RD
# RDMαα
# RRMαα
# MDMMD
# MNMDN
# MRMDN
# MMNR
# MRMRN

# %% [markdown]
# # 3.194 (D) AC - (M) ICT - (N) JGS - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_194 = max(min(Date_AC), min(Date_ICT), min(Date_JGS), min(Date_SMC), min(Date_SCC))
end_194 = min(max(Date_AC), max(Date_ICT), max(Date_JGS), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
AC_194_1 = Date_AC.index(start_194)
AC_194_2 = Date_AC.index(end_194)

ICT_194_1 = Date_ICT.index(start_194)
ICT_194_2 = Date_ICT.index(end_194)

JGS_194_1 = Date_JGS.index(start_194)
JGS_194_2 = Date_JGS.index(end_194)

SMC_194_1 = Date_SMC.index(start_194)
SMC_194_2 = Date_SMC.index(end_194)

SCC_194_1 = Date_SCC.index(start_194)
SCC_194_2 = Date_SCC.index(end_194)

# %%
#save the shortened versions of closing prices
D194 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_194_1:AC_194_2])
M194 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_194_1:ICT_194_2])
N194 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_194_1:JGS_194_2])
Y194 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_194_1:SMC_194_2])
α194 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_194_1:SCC_194_2])

# %%
# import modules
import numpy as np
# import prices

D194 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
M194 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N194 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y194 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α194 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_194 = []
st_194 = []
n = 1
while n < len(D194):
    sc_194 = ''
    if D194[n] > D194[n-1]:
        sc_194 = sc_194 + 'D'
    if M194[n] > M194[n-1]:
        sc_194 = sc_194 + 'M'
    if N194[n] > N194[n-1]:
        sc_194 = sc_194 + 'N'
    if Y194[n] > Y194[n-1]:
        sc_194 = sc_194 + 'Y'
    if α194[n] > α194[n-1]:
        sc_194 = sc_194 + 'α'
    if len(sc_194) > 0:
        st_194.append(sc_194)
    else:
        STC_194.append(st_194)
        st_194 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_194 = STC_194.count([])
# keep only non-empty spatio-temporal sequences
STC_194 = [ st_194 for st_194 in STC_194 if len(st_194) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_194 = len(D194)
lmax_194 = 0
for st_194 in STC_194:
    if len(st_194) < lmin_194:
        lmin_194 = len(st_194)
    if len(st_194) > lmax_194:
        lmax_194 = len(st_194)
        
# restrict spatio-temporal sequences to length-5
STC5_194 = [ st_194 for st_194 in STC_194 if len(st_194) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_194 = []
for n in range(len(STC5_194)):
    tc_194 = [ u for u in STC5_194[n][0] ]
    for k in range(1, len(STC5_194[n])):
        tc_194 = [ u+v for u in tc_194 for v in STC5_194[n][k] ]
    TC5_194 = TC5_194 + tc_194
setTC5_194 = list(set(TC5_194))

# get empirical frequencies
fTC5_194 = [ TC5_194.count(setTC5_194[l]) for l in range(len(setTC5_194)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_194 = [ [] for l in range(len(setTC5_194)) ]
for s in range(100):
    STC5null_194 = [ list(st_194) for st_194 in STC5_194]
    for st_194 in STC5null_194:
        np.random.shuffle(st_194)
    TC5null_194= []
    for n in range(len(STC5null_194)):
        tc_194 = [ u for u in STC5null_194[n][0] ]
        for k in range(1, len(STC5null_194[n])):
            tc_194 = [ u+v for u in tc_194 for v in STC5null_194[n][k] ]
        TC5null_194= TC5null_194+ tc_194
    for l in range(len(setTC5_194)):
        if TC5null_194.count(setTC5_194[l]) > 0:
            fTC5null_194[l].append(TC5null_194.count(setTC5_194[l]))
        else:
            fTC5null_194[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_194)):
     if sum(freq >= fTC5_194[l] for freq in fTC5null_194[l]) < 5:
#         print(setTC5_194[l], fTC5_194[l], sum(freq >= fTC5_194[l] for freq in fTC5null_194[l]))
        print(setTC5_194[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# MDMDN
# YYαNα
# MYY
# YYYMN
# YYDNα
# YαNNN
# YYMNN
# YYααα
# NYDNM
# MDDMM
# DαN
# MMYαα
# DYαNM
# NDNN
# YYYNN
# YαMN
# YαDD
# DαM
# MYDMM
# NYDNα
# DNNDN
# DYYY
# YYNNα
# ααDα
# αMDαα
# MMαM
# MDDMN
# DYDMM
# MMYYα
# DYYND
# MαMYD
# NYMNα
# DYαND
# YDαNα
# DYαMM
# MNDMN
# NYDNN
# YYDN
# DYNNM
# NYNNα
# NNαMM
# MDYαα
# DαY
# DNDMM
# YαDNN
# YMMN
# YααD
# MαMMM
# DYNYM
# MαYYα
# MαMMN
# YYMNM
# DYDNN
# MDYYα
# MDMMD
# YYNαα
# MαYYD
# NMDYα
# MNMDN
# MαYMM
# MαYYM
# YYDαα
# YαMNN
# MαMYN
# MNMMN
# MαDMN
# YαDN
# DYYMD
# DYDNM
# DDDNN
# YαMα
# MNDMM
# NYαNα
# DYDND
# DαNMN
# MαYMN
# NαDα
# DYNMM
# MNMNN
# YDDαα
# MαMYM
# NDDα
# MNYNN
# MαYMD
# DYMNN
# MYYMM
# NMDαα
# MDMYD
# NYαNN
# NαMN
# MDMMN
# MαDMM
# YYDNN
# MαYMα
# DYYMN
# DYαNN
# MαYYN
# DYYNN
# ααMα
# YYMMM
# DNN
# YYDNM
# NMNαα

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_194)):
     if sum(freq >= fTC5_194[l] for freq in fTC5null_194[l]) < 1:
#         print(setTC5_194[l], fTC5_194[l], sum(freq >= fTC5_194[l] for freq in fTC5null_194[l]))
        print(setTC5_194[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# YαMN
# NYDNα
# DYDMM
# NYMNα
# DYDNN
# MDMMD
# MαYYM
# YYDαα
# MNMMN
# MαDMN
# DYDNM
# MNDMM
# MαYMN
# MNMNN
# MαMYM
# NMDαα
# DYYNN
# DNN

# %% [markdown]
# # 3.195 (D) AC - (M) ICT - (R) JGS - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_195 = max(min(Date_AC), min(Date_ICT), min(Date_MEG), min(Date_SMC), min(Date_SCC))
end_195 = min(max(Date_AC), max(Date_ICT), max(Date_MEG), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
AC_195_1 = Date_AC.index(start_195)
AC_195_2 = Date_AC.index(end_195)

ICT_195_1 = Date_ICT.index(start_195)
ICT_195_2 = Date_ICT.index(end_195)

MEG_195_1 = Date_MEG.index(start_195)
MEG_195_2 = Date_MEG.index(end_195)

SMC_195_1 = Date_SMC.index(start_195)
SMC_195_2 = Date_SMC.index(end_195)

SCC_195_1 = Date_SCC.index(start_195)
SCC_195_2 = Date_SCC.index(end_195)

# %%
#save the shortened versions of closing prices
D195 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_195_1:AC_195_2])
M195 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_195_1:ICT_195_2])
R195 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_195_1:MEG_195_2])
Y195 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_195_1:SMC_195_2])
α195 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_195_1:SCC_195_2])

# %%
# import modules
import numpy as np
# import prices

D195 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
M195 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R195 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y195 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α195 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_195 = []
st_195 = []
n = 1
while n < len(D195):
    sc_195 = ''
    if D195[n] > D195[n-1]:
        sc_195 = sc_195 + 'D'
    if M195[n] > M195[n-1]:
        sc_195 = sc_195 + 'M'
    if R195[n] > R195[n-1]:
        sc_195 = sc_195 + 'R'
    if Y195[n] > Y195[n-1]:
        sc_195 = sc_195 + 'Y'
    if α195[n] > α195[n-1]:
        sc_195 = sc_195 + 'α'
    if len(sc_195) > 0:
        st_195.append(sc_195)
    else:
        STC_195.append(st_195)
        st_195 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_195 = STC_195.count([])
# keep only non-empty spatio-temporal sequences
STC_195 = [ st_195 for st_195 in STC_195 if len(st_195) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_195 = len(D195)
lmax_195 = 0
for st_195 in STC_195:
    if len(st_195) < lmin_195:
        lmin_195 = len(st_195)
    if len(st_195) > lmax_195:
        lmax_195 = len(st_195)
        
# restrict spatio-temporal sequences to length-5
STC5_195 = [ st_195 for st_195 in STC_195 if len(st_195) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_195 = []
for n in range(len(STC5_195)):
    tc_195 = [ u for u in STC5_195[n][0] ]
    for k in range(1, len(STC5_195[n])):
        tc_195 = [ u+v for u in tc_195 for v in STC5_195[n][k] ]
    TC5_195 = TC5_195 + tc_195
setTC5_195 = list(set(TC5_195))

# get empirical frequencies
fTC5_195 = [ TC5_195.count(setTC5_195[l]) for l in range(len(setTC5_195)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_195 = [ [] for l in range(len(setTC5_195)) ]
for s in range(100):
    STC5null_195 = [ list(st_195) for st_195 in STC5_195]
    for st_195 in STC5null_195:
        np.random.shuffle(st_195)
    TC5null_195= []
    for n in range(len(STC5null_195)):
        tc_195 = [ u for u in STC5null_195[n][0] ]
        for k in range(1, len(STC5null_195[n])):
            tc_195 = [ u+v for u in tc_195 for v in STC5null_195[n][k] ]
        TC5null_195= TC5null_195+ tc_195
    for l in range(len(setTC5_195)):
        if TC5null_195.count(setTC5_195[l]) > 0:
            fTC5null_195[l].append(TC5null_195.count(setTC5_195[l]))
        else:
            fTC5null_195[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_195)):
     if sum(freq >= fTC5_195[l] for freq in fTC5null_195[l]) < 5:
#         print(setTC5_195[l], fTC5_195[l], sum(freq >= fTC5_195[l] for freq in fTC5null_195[l]))
        print(setTC5_195[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# YαDR
# MYαD
# RRMMα
# αααYD
# RYR
# αMαYY
# RDMMα
# RMMYα
# YMDD
# RYMR
# RαDMM
# RRMMD
# RRMMM
# MDDMM
# DMαYR
# DYDαR
# RMDYα
# DRαYR
# αRαMY
# αDαMD
# YαDD
# RDMMD
# RRαMR
# RYMRR
# YRMRR
# DDαYR
# RDαMR
# αRααR
# RYYαR
# RDMRD
# MααYM
# DYYY
# RαDMD
# αMαYD
# DRYYY
# RDααα
# DDαMD
# YYDD
# αααYY
# MYMRR
# DRαMD
# MαMYD
# DRαYD
# YYDMM
# DYDRM
# DMMD
# YDDMY
# YYDRM
# YDαYD
# YMDR
# DYαMM
# RRMαR
# RDαY
# DYDR
# RYMD
# YMRD
# MYMYD
# αRαYY
# MαMD
# DRαMM
# YYMRR
# YDDRM
# ααMD
# RYDαR
# RMMYD
# MRMMM
# YRMαR
# DYαYR
# DααYR
# DDαMM
# YRMDR
# DDαMR
# YααD
# DDαYD
# DYαMR
# MRRYY
# YDDαM
# RDMαα
# DRRRR
# RRMαα
# DRαRM
# DDαDY
# DDαMY
# YYMD
# MDMMD
# YRMMR
# DYαRM
# MYDαR
# YMMD
# DRRYY
# MααYY
# YYRRM
# DRαYY
# RRMRR
# RDDMD
# MααYD
# RRMαM
# MDYYD
# αYααR
# DMαYD
# YRMMY
# αYMαR
# DYRRR
# DRRDR
# αRMαR
# MYDRR
# YDMR
# DMRYY
# αRMYD
# RαMD
# αMMYD
# YαMR
# RMMD
# αMααD
# RRMMR
# DYRRM
# DRαYM
# DYRDM
# RMRYα
# MDMYD
# DααYY
# DMαMM
# DαRYY
# YRMD
# αYMYD
# YYMα
# MRMYD
# RRαMM
# YYMRM
# DYααR
# DMαYM
# RYRRM
# αRααD
# αRRαR
# DYRMM
# YMMR
# αRRRR
# YRDMM
# YαMD
# DRαMR
# ααMα
# YYMMM
# αRRMR
# YYRMM

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_195)):
     if sum(freq >= fTC5_195[l] for freq in fTC5null_195[l]) < 1:
#         print(setTC5_195[l], fTC5_195[l], sum(freq >= fTC5_195[l] for freq in fTC5null_195[l]))
        print(setTC5_195[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# YαDR
# YMDD
# RYMR
# DRαYR
# RDMMD
# RDααα
# DDαMD
# MYMRR
# RYMD
# ααMD
# DDαMM
# DDαMR
# MYDαR
# YMMD
# DRαYY
# MDYYD
# αRMαR
# RαMD
# YαMR
# RMMD
# DYRRM
# DRαYM
# MDMYD
# DααYY
# YYMRM
# YMMR
# YαMD
# DRαMR
# ααMα
# YYMMM
# YYRMM
