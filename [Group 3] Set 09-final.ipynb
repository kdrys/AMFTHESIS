# %% [markdown]
# # One-Letter Words

# %%
# open the csv files
AP = open('AP.csv')
AC = open('AC.csv')
BPI = open('BPI.csv')
BLOOM = open('BLOOM.csv')
FGEN = open('FGEN.csv')
ICT = open('ICT.csv')
JGS = open('JGS.csv')
MEG = open('MEG.csv')
SMC = open('SMC.csv')
SCC = open('SCC.csv')

#initiFGENze the lists
Date_AP = []
ClosePrice_AP = []
Date_AC = []
ClosePrice_AC = []
Date_BPI = []
ClosePrice_BPI = []
Date_BLOOM = []
ClosePrice_BLOOM = []
Date_FGEN = []
ClosePrice_FGEN = []
Date_ICT = []
ClosePrice_ICT = []
Date_JGS = []
ClosePrice_JGS = []
Date_MEG = []
ClosePrice_MEG = []
Date_SMC = []
ClosePrice_SMC = []
Date_SCC = []
ClosePrice_SCC = []

#skip the header line
AP.readline()
AC.readline()
BPI.readline()
BLOOM.readline()
FGEN.readline()
ICT.readline()
JGS.readline()
MEG.readline()
SMC.readline()
SCC.readline()

#go through the files line by line
for line in AP:
    sline = line.strip().split(',')
    Date_AP.append(sline[0])
    ClosePrice_AP.append(float(sline[1]))
    
for line in AC:
    sline = line.strip().split(',')
    Date_AC.append(sline[0])
    ClosePrice_AC.append(float(sline[1]))
    
for line in BPI:
    sline = line.strip().split(',')
    Date_BPI.append(sline[0])
    ClosePrice_BPI.append(float(sline[1]))
    
for line in BLOOM:
    sline = line.strip().split(',')
    Date_BLOOM.append(sline[0])
    ClosePrice_BLOOM.append(float(sline[1]))
    
for line in FGEN:
    sline = line.strip().split(',')
    Date_FGEN.append(sline[0])
    ClosePrice_FGEN.append(float(sline[1]))
    
for line in ICT:
    sline = line.strip().split(',')
    Date_ICT.append(sline[0])
    ClosePrice_ICT.append(float(sline[1]))
    
for line in JGS:
    sline = line.strip().split(',')
    Date_JGS.append(sline[0])
    ClosePrice_JGS.append(float(sline[1]))
    
for line in MEG:
    sline = line.strip().split(',')
    Date_MEG.append(sline[0])
    ClosePrice_MEG.append(float(sline[1]))
    
for line in SMC:
    sline = line.strip().split(',')
    Date_SMC.append(sline[0])
    ClosePrice_SMC.append(float(sline[1]))
        
for line in SCC:
    sline = line.strip().split(',')
    Date_SCC.append(sline[0])
    ClosePrice_SCC.append(float(sline[1]))


#close files
AP.close()
AC.close()
BPI.close()
BLOOM.close()
FGEN.close()
ICT.close()
JGS.close()
MEG.close()
SMC.close()
SCC.close()# One-Letter Words

# %%
import numpy as np
import datetime

# %%
# convert dates into datetime structure
for n in range(len(Date_AP)):
    Date_AP[n] = datetime.datetime.strptime(Date_AP[n], '%m/%d/%y').date()

for n in range(len(Date_AC)):
    Date_AC[n] = datetime.datetime.strptime(Date_AC[n], '%m/%d/%y').date()
    
for n in range(len(Date_BPI)):
    Date_BPI[n] = datetime.datetime.strptime(Date_BPI[n], '%m/%d/%y').date()

for n in range(len(Date_BLOOM)):
    Date_BLOOM[n] = datetime.datetime.strptime(Date_BLOOM[n], '%m/%d/%y').date()
    
for n in range(len(Date_FGEN)):
    Date_FGEN[n] = datetime.datetime.strptime(Date_FGEN[n], '%m/%d/%y').date()

for n in range(len(Date_ICT)):
    Date_ICT[n] = datetime.datetime.strptime(Date_ICT[n], '%m/%d/%y').date()
    
for n in range(len(Date_JGS)):
    Date_JGS[n] = datetime.datetime.strptime(Date_JGS[n], '%m/%d/%y').date()

for n in range(len(Date_MEG)):
    Date_MEG[n] = datetime.datetime.strptime(Date_MEG[n], '%m/%d/%y').date()
    
for n in range(len(Date_SMC)):
    Date_SMC[n] = datetime.datetime.strptime(Date_SMC[n], '%m/%d/%y').date()

for n in range(len(Date_SCC)):
    Date_SCC[n] = datetime.datetime.strptime(Date_SCC[n], '%m/%d/%y').date()
    
# save Date and ClosePrice
np.save('APDate.npy', Date_AP)
np.save('APClosePrice.npy', ClosePrice_AP)
np.save('ACDate.npy', Date_AC)
np.save('ACClosePrice.npy', ClosePrice_AC)
np.save('BPIDate.npy', Date_BPI)
np.save('BPIClosePrice.npy', ClosePrice_BPI)
np.save('BLOOMDate.npy', Date_BLOOM)
np.save('BLOOMClosePrice.npy', ClosePrice_BLOOM)
np.save('FGENDate.npy', Date_FGEN)
np.save('FGENClosePrice.npy', ClosePrice_FGEN)
np.save('ICTDate.npy', Date_ICT)
np.save('ICTClosePrice.npy', ClosePrice_ICT)
np.save('JGSDate.npy', Date_JGS)
np.save('JGSClosePrice.npy', ClosePrice_JGS)
np.save('MEGDate.npy', Date_MEG)
np.save('MEGClosePrice.npy', ClosePrice_MEG)
np.save('SMCDate.npy', Date_SMC)
np.save('SMCClosePrice.npy', ClosePrice_SMC)
np.save('SCCDate.npy', Date_SCC)
np.save('SCCClosePrice.npy', ClosePrice_SCC)

# %% [markdown]
# # Five-letter Words

# %% [markdown]
# # 3.121 (B) AP - (J) FGEN - (R) MEG - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_121 = max(min(Date_AP), min(Date_FGEN), min(Date_MEG), min(Date_SMC), min(Date_SCC))
end_121 = min(max(Date_AP), max(Date_FGEN), max(Date_MEG), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
AP_121_1 = Date_AP.index(start_121)
AP_121_2 = Date_AP.index(end_121)

FGEN_121_1 = Date_FGEN.index(start_121)
FGEN_121_2 = Date_FGEN.index(end_121)

MEG_121_1 = Date_MEG.index(start_121)
MEG_121_2 = Date_MEG.index(end_121)

SMC_121_1 = Date_SMC.index(start_121)
SMC_121_2 = Date_SMC.index(end_121)

SCC_121_1 = Date_SCC.index(start_121)
SCC_121_2 = Date_SCC.index(end_121)

# %%
#save the shortened versions of closing prices
B121 = np.save('APshortPrices.npy', ClosePrice_AP[AP_121_1:AP_121_2])
J121 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_121_1:FGEN_121_2])
R121 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_121_1:MEG_121_2])
Y121 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_121_1:SMC_121_2])
α121 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_121_1:SCC_121_2])

# %%
# import modules
import numpy as np
# import prices

B121 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
J121 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
R121 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y121 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α121 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_121 = []
st_121 = []
n = 1
while n < len(B121):
    sc_121 = ''
    if B121[n] > B121[n-1]:
        sc_121 = sc_121 + 'B'
    if J121[n] > J121[n-1]:
        sc_121 = sc_121 + 'J'
    if R121[n] > R121[n-1]:
        sc_121 = sc_121 + 'R'
    if Y121[n] > Y121[n-1]:
        sc_121 = sc_121 + 'Y'
    if α121[n] > α121[n-1]:
        sc_121 = sc_121 + 'α'
    if len(sc_121) > 0:
        st_121.append(sc_121)
    else:
        STC_121.append(st_121)
        st_121 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_121 = STC_121.count([])
# keep only non-empty spatio-temporal sequences
STC_121 = [ st_121 for st_121 in STC_121 if len(st_121) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_121 = len(B121)
lmax_121 = 0
for st_121 in STC_121:
    if len(st_121) < lmin_121:
        lmin_121 = len(st_121)
    if len(st_121) > lmax_121:
        lmax_121 = len(st_121)
        
# restrict spatio-temporal sequences to length-5
STC5_121 = [ st_121 for st_121 in STC_121 if len(st_121) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_121 = []
for n in range(len(STC5_121)):
    tc_121 = [ u for u in STC5_121[n][0] ]
    for k in range(1, len(STC5_121[n])):
        tc_121 = [ u+v for u in tc_121 for v in STC5_121[n][k] ]
    TC5_121 = TC5_121 + tc_121
setTC5_121 = list(set(TC5_121))

# get empirical frequencies
fTC5_121 = [ TC5_121.count(setTC5_121[l]) for l in range(len(setTC5_121)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_121 = [ [] for l in range(len(setTC5_121)) ]
for s in range(100):
    STC5null_121 = [ list(st_121) for st_121 in STC5_121]
    for st_121 in STC5null_121:
        np.random.shuffle(st_121)
    TC5null_121= []
    for n in range(len(STC5null_121)):
        tc_121 = [ u for u in STC5null_121[n][0] ]
        for k in range(1, len(STC5null_121[n])):
            tc_121 = [ u+v for u in tc_121 for v in STC5null_121[n][k] ]
        TC5null_121= TC5null_121+ tc_121
    for l in range(len(setTC5_121)):
        if TC5null_121.count(setTC5_121[l]) > 0:
            fTC5null_121[l].append(TC5null_121.count(setTC5_121[l]))
        else:
            fTC5null_121[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_121)):
     if sum(freq >= fTC5_121[l] for freq in fTC5null_121[l]) < 5:
#         print(setTC5_121[l], fTC5_121[l], sum(freq >= fTC5_121[l] for freq in fTC5null_121[l]))
        print(setTC5_121[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# ααJR
# JBα
# YJYBα
# YαYαα
# αYJR
# RRYαα
# YJRJB
# αYBR
# JRYα
# RJαRB
# αRBB
# αBBR
# RYBYR
# YJYJB
# JαYY
# JYJ
# RαJR
# YαYαB
# RRB
# RJJRR
# JαJJJ
# RJαRα
# BBαYB
# αBBB
# RYJ
# BBRRB
# BαYYB
# RYRYY
# BYαYB
# BBαRB
# YYJB
# YYRYR
# ααYY
# RαYαα
# YαYJB
# RJYαα
# RJYαJ
# YYRYY
# YαBR
# JBJJJ
# JαBB
# JαJR
# RJαRJ
# RJJJY
# RYB
# αYBB
# YYBJR
# RαYY
# αRBR
# YαRB
# JYBB
# ααJB
# αYJ
# RJαBB
# YJYJα
# YαJB
# YYRαY
# RααRB
# BRαYR
# JαJB
# BRαYB
# ααBB
# αYJB
# BJαRB
# RJBRα
# ααBR
# JYBY
# JBBR
# RYRYR
# ααJJJ
# RRJJY
# αYBYR
# RααRJ
# RJJBY
# YYBYR
# JYYY
# BαBαJ
# αYαYB
# YαBB
# ααJαJ
# JYBR
# RJααα
# YαJR
# JαBR
# αJBYR
# JRBR
# RBαRB

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_121)):
     if sum(freq >= fTC5_121[l] for freq in fTC5null_121[l]) < 1:
#         print(setTC5_121[l], fTC5_121[l], sum(freq >= fTC5_121[l] for freq in fTC5null_121[l]))
        print(setTC5_121[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# αYBR
# RJαRB
# RYBYR
# YJYJB
# RαYαα
# JBJJJ
# RJJJY
# RYB
# RαYY
# YαJB
# ααBB
# BJαRB
# JBBR
# RYRYR
# JYBR

# %% [markdown]
# # 3.122 (B) AP - (M) ICT - (N) JGS - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_122 = max(min(Date_AP), min(Date_ICT), min(Date_JGS), min(Date_MEG), min(Date_SMC))
end_122 = min(max(Date_AP), max(Date_ICT), max(Date_JGS), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
AP_122_1 = Date_AP.index(start_122)
AP_122_2 = Date_AP.index(end_122)

ICT_122_1 = Date_ICT.index(start_122)
ICT_122_2 = Date_ICT.index(end_122)

JGS_122_1 = Date_JGS.index(start_122)
JGS_122_2 = Date_JGS.index(end_122)

MEG_122_1 = Date_MEG.index(start_122)
MEG_122_2 = Date_MEG.index(end_122)

SMC_122_1 = Date_SMC.index(start_122)
SMC_122_2 = Date_SMC.index(end_122)

# %%
#save the shortened versions of closing prices
B122 = np.save('APshortPrices.npy', ClosePrice_AP[AP_122_1:AP_122_2])
M122 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_122_1:ICT_122_2])
N122 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_122_1:JGS_122_2])
R122 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_122_1:MEG_122_2])
Y122 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_122_1:SMC_122_2])

# %%
# import modules
import numpy as np
# import prices

B122 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
M122 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N122 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R122 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y122 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_122 = []
st_122 = []
n = 1
while n < len(B122):
    sc_122 = ''
    if B122[n] > B122[n-1]:
        sc_122 = sc_122 + 'B'
    if M122[n] > M122[n-1]:
        sc_122 = sc_122 + 'M'
    if N122[n] > N122[n-1]:
        sc_122 = sc_122 + 'N'
    if R122[n] > R122[n-1]:
        sc_122 = sc_122 + 'R'
    if Y122[n] > Y122[n-1]:
        sc_122 = sc_122 + 'Y'
    if len(sc_122) > 0:
        st_122.append(sc_122)
    else:
        STC_122.append(st_122)
        st_122 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_122 = STC_122.count([])
# keep only non-empty spatio-temporal sequences
STC_122 = [ st_122 for st_122 in STC_122 if len(st_122) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_122 = len(B122)
lmax_122 = 0
for st_122 in STC_122:
    if len(st_122) < lmin_122:
        lmin_122 = len(st_122)
    if len(st_122) > lmax_122:
        lmax_122 = len(st_122)
        
# restrict spatio-temporal sequences to length-5
STC5_122 = [ st_122 for st_122 in STC_122 if len(st_122) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_122 = []
for n in range(len(STC5_122)):
    tc_122 = [ u for u in STC5_122[n][0] ]
    for k in range(1, len(STC5_122[n])):
        tc_122 = [ u+v for u in tc_122 for v in STC5_122[n][k] ]
    TC5_122 = TC5_122 + tc_122
setTC5_122 = list(set(TC5_122))

# get empirical frequencies
fTC5_122 = [ TC5_122.count(setTC5_122[l]) for l in range(len(setTC5_122)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_122 = [ [] for l in range(len(setTC5_122)) ]
for s in range(100):
    STC5null_122 = [ list(st_122) for st_122 in STC5_122]
    for st_122 in STC5null_122:
        np.random.shuffle(st_122)
    TC5null_122= []
    for n in range(len(STC5null_122)):
        tc_122 = [ u for u in STC5null_122[n][0] ]
        for k in range(1, len(STC5null_122[n])):
            tc_122 = [ u+v for u in tc_122 for v in STC5null_122[n][k] ]
        TC5null_122= TC5null_122+ tc_122
    for l in range(len(setTC5_122)):
        if TC5null_122.count(setTC5_122[l]) > 0:
            fTC5null_122[l].append(TC5null_122.count(setTC5_122[l]))
        else:
            fTC5null_122[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_122)):
     if sum(freq >= fTC5_122[l] for freq in fTC5null_122[l]) < 5:
#         print(setTC5_122[l], fTC5_122[l], sum(freq >= fTC5_122[l] for freq in fTC5null_122[l]))
        print(setTC5_122[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# YYYMN
# RYN
# MYBBN
# YNYNR
# BNNMB
# MYMN
# NBBN
# YRYNM
# MNYMB
# NRBNR
# MYRB
# YRRRN
# YMBB
# RYMR
# BNRMB
# MNYMN
# NYBRN
# YYRN
# YBRYN
# YBBN
# NYBNN
# YRYMR
# YYRB
# YBMYN
# YBYMN
# YNRNM
# YNYBR
# YNYRM
# YNYNN
# BYRMB
# MMNM
# BYNMB
# YBRMN
# YNNMR
# MMNB
# YNYMB
# YRYNN
# YNRMM
# YNNRM
# MNYRR
# YBBB
# RRMMB
# YNRRN
# YYBN
# MMRR
# BNNMM
# RBB
# YNYMN
# BBNRB
# RBRN
# MYBN
# MNYNB
# MYBRN
# YRBMB
# YNRNN
# NBBY
# BRNMB
# YBRMR
# MNNNN
# MYRR
# MMNR
# YNNMM
# YNYNM
# MYRN
# MMRB
# YRRRM
# YNBMR
# YRYNR
# YNRMR
# MBNBN
# YNYMM
# MMN
# MBNB
# YRMYN
# YNYRR
# MBRB
# YNYRN
# YYBB
# RRNY
# YBRN
# RBRB
# YNYMR
# YNRRM
# YRYRN

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_122)):
     if sum(freq >= fTC5_122[l] for freq in fTC5null_122[l]) < 1:
#         print(setTC5_122[l], fTC5_122[l], sum(freq >= fTC5_122[l] for freq in fTC5null_122[l]))
        print(setTC5_122[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# YNYNR
# MNYMB
# YYRN
# NYBNN
# YNYNN
# BYNMB
# YNYMN
# YNYNM
# MYRN
# MMRB
# YRRRM
# YNYRR
# YYBB
# YBRN
# RBRB
# YNYMR

# %% [markdown]
# # 3.123 (B) AP - (M) ICT - (N) JGS - (R) MEG - (α) SCC

# %%
#extract overlapping dates
start_123 = max(min(Date_AP), min(Date_ICT), min(Date_JGS), min(Date_MEG), min(Date_SCC))
end_123 = min(max(Date_AP), max(Date_ICT), max(Date_JGS), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
AP_123_1 = Date_AP.index(start_123)
AP_123_2 = Date_AP.index(end_123)

ICT_123_1 = Date_ICT.index(start_123)
ICT_123_2 = Date_ICT.index(end_123)

JGS_123_1 = Date_JGS.index(start_123)
JGS_123_2 = Date_JGS.index(end_123)

MEG_123_1 = Date_MEG.index(start_123)
MEG_123_2 = Date_MEG.index(end_123)

SCC_123_1 = Date_SCC.index(start_123)
SCC_123_2 = Date_SCC.index(end_123)

# %%
#save the shortened versions of closing prices
B123 = np.save('APshortPrices.npy', ClosePrice_AP[AP_123_1:AP_123_2])
M123 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_123_1:ICT_123_2])
N123 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_123_1:JGS_123_2])
R123 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_123_1:MEG_123_2])
α123 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_123_1:SCC_123_2])

# %%
# import modules
import numpy as np
# import prices

B123 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
M123 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N123 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R123 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α123 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_123 = []
st_123 = []
n = 1
while n < len(B123):
    sc_123 = ''
    if B123[n] > B123[n-1]:
        sc_123 = sc_123 + 'B'
    if M123[n] > M123[n-1]:
        sc_123 = sc_123 + 'M'
    if N123[n] > N123[n-1]:
        sc_123 = sc_123 + 'N'
    if R123[n] > R123[n-1]:
        sc_123 = sc_123 + 'R'
    if α123[n] > α123[n-1]:
        sc_123 = sc_123 + 'α'
    if len(sc_123) > 0:
        st_123.append(sc_123)
    else:
        STC_123.append(st_123)
        st_123 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_123 = STC_123.count([])
# keep only non-empty spatio-temporal sequences
STC_123 = [ st_123 for st_123 in STC_123 if len(st_123) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_123 = len(B123)
lmax_123 = 0
for st_123 in STC_123:
    if len(st_123) < lmin_123:
        lmin_123 = len(st_123)
    if len(st_123) > lmax_123:
        lmax_123 = len(st_123)
        
# restrict spatio-temporal sequences to length-5
STC5_123 = [ st_123 for st_123 in STC_123 if len(st_123) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_123 = []
for n in range(len(STC5_123)):
    tc_123 = [ u for u in STC5_123[n][0] ]
    for k in range(1, len(STC5_123[n])):
        tc_123 = [ u+v for u in tc_123 for v in STC5_123[n][k] ]
    TC5_123 = TC5_123 + tc_123
setTC5_123 = list(set(TC5_123))

# get empirical frequencies
fTC5_123 = [ TC5_123.count(setTC5_123[l]) for l in range(len(setTC5_123)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_123 = [ [] for l in range(len(setTC5_123)) ]
for s in range(100):
    STC5null_123 = [ list(st_123) for st_123 in STC5_123]
    for st_123 in STC5null_123:
        np.random.shuffle(st_123)
    TC5null_123= []
    for n in range(len(STC5null_123)):
        tc_123 = [ u for u in STC5null_123[n][0] ]
        for k in range(1, len(STC5null_123[n])):
            tc_123 = [ u+v for u in tc_123 for v in STC5null_123[n][k] ]
        TC5null_123= TC5null_123+ tc_123
    for l in range(len(setTC5_123)):
        if TC5null_123.count(setTC5_123[l]) > 0:
            fTC5null_123[l].append(TC5null_123.count(setTC5_123[l]))
        else:
            fTC5null_123[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_123)):
     if sum(freq >= fTC5_123[l] for freq in fTC5null_123[l]) < 5:
#         print(setTC5_123[l], fTC5_123[l], sum(freq >= fTC5_123[l] for freq in fTC5null_123[l]))
        print(setTC5_123[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# MNMαα
# RNMαN
# RRMMM
# RBMRN
# RBMBα
# αRααα
# RBMRα
# Rα
# BRM
# RMMNN
# NBMαα
# MRN
# NBBN
# RMMBα
# BαN
# αBBB
# RMMMN
# BBRRB
# αMRR
# NMMαα
# αNRMM
# RNBBα
# NBααα
# RBαBα
# MRNαα
# NαBα
# RRMBN
# RMMαα
# RMNαα
# MαNB
# BBMBα
# MNαBα
# NMBBα
# BMMαα
# MMNM
# RBRNα
# NMRB
# MMNB
# MRRMN
# RRMαα
# RNMNM
# NRNαα
# RRααα
# NMααα
# RNMαB
# RRMMB
# αBBN
# RBMαM
# αMRB
# RNMRα
# RRαMB
# RRαRB
# RMMMα
# RBNB
# ααRB
# BBNRB
# RMNB
# RRMRα
# RRααN
# NRαRN
# NRBα
# ααBB
# RBααN
# RBMαN
# RBMαα
# RRMBα
# NαNα
# RBααα
# MBMαα
# RBMNα
# ααBR
# RBBNα
# RRMMN
# RMMNα
# RMRB
# RNMBα
# αRNRN
# RMMαN
# RRMRB
# MMRB
# NMNαα
# αBRB
# BNMBα
# RRMBB
# NRααα
# RMMαM
# BRNαB
# BαM
# RNMαα
# MBNB
# NMBαα
# RMMMB
# BNMRα
# MRMαα
# MRMMN
# MBRB
# BMBBM
# RMααα
# RBRB
# RNMNα

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_123)):
     if sum(freq >= fTC5_123[l] for freq in fTC5null_123[l]) < 1:
#         print(setTC5_123[l], fTC5_123[l], sum(freq >= fTC5_123[l] for freq in fTC5null_123[l]))
        print(setTC5_123[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# RBMRα
# RMMNN
# αBBB
# αMRR
# RMMαα
# RRααα
# αMRB
# RBααN
# RBMαα
# RRMBα
# RBααα
# RMMNα
# RNMBα
# RMMαN
# RRMRB
# MMRB
# αBRB
# RMMαM
# MRMαα
# MBRB
# RBRB

# %% [markdown]
# # 3.124 (B) AP - (M) ICT - (N) JGS - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_124 = max(min(Date_AP), min(Date_ICT), min(Date_JGS), min(Date_SMC), min(Date_SCC))
end_124 = min(max(Date_AP), max(Date_ICT), max(Date_JGS), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
AP_124_1 = Date_AP.index(start_124)
AP_124_2 = Date_AP.index(end_124)

ICT_124_1 = Date_ICT.index(start_124)
ICT_124_2 = Date_ICT.index(end_124)

JGS_124_1 = Date_JGS.index(start_124)
JGS_124_2 = Date_JGS.index(end_124)

SMC_124_1 = Date_SMC.index(start_124)
SMC_124_2 = Date_SMC.index(end_124)

SCC_124_1 = Date_SCC.index(start_124)
SCC_124_2 = Date_SCC.index(end_124)

# %%
#save the shortened versions of closing prices
B124 = np.save('APshortPrices.npy', ClosePrice_AP[AP_124_1:AP_124_2])
M124 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_124_1:ICT_124_2])
N124 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_124_1:JGS_124_2])
Y124 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_124_1:SMC_124_2])
α124 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_124_1:SCC_124_2])

# %%
# import modules
import numpy as np
# import prices

B124 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
M124 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N124 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y124 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α124 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_124 = []
st_124 = []
n = 1
while n < len(B124):
    sc_124 = ''
    if B124[n] > B124[n-1]:
        sc_124 = sc_124 + 'B'
    if M124[n] > M124[n-1]:
        sc_124 = sc_124 + 'M'
    if N124[n] > N124[n-1]:
        sc_124 = sc_124 + 'N'
    if Y124[n] > Y124[n-1]:
        sc_124 = sc_124 + 'Y'
    if α124[n] > α124[n-1]:
        sc_124 = sc_124 + 'α'
    if len(sc_124) > 0:
        st_124.append(sc_124)
    else:
        STC_124.append(st_124)
        st_124 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_124 = STC_124.count([])
# keep only non-empty spatio-temporal sequences
STC_124 = [ st_124 for st_124 in STC_124 if len(st_124) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_124 = len(B124)
lmax_124 = 0
for st_124 in STC_124:
    if len(st_124) < lmin_124:
        lmin_124 = len(st_124)
    if len(st_124) > lmax_124:
        lmax_124 = len(st_124)
        
# restrict spatio-temporal sequences to length-5
STC5_124 = [ st_124 for st_124 in STC_124 if len(st_124) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_124 = []
for n in range(len(STC5_124)):
    tc_124 = [ u for u in STC5_124[n][0] ]
    for k in range(1, len(STC5_124[n])):
        tc_124 = [ u+v for u in tc_124 for v in STC5_124[n][k] ]
    TC5_124 = TC5_124 + tc_124
setTC5_124 = list(set(TC5_124))

# get empirical frequencies
fTC5_124 = [ TC5_124.count(setTC5_124[l]) for l in range(len(setTC5_124)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_124 = [ [] for l in range(len(setTC5_124)) ]
for s in range(100):
    STC5null_124 = [ list(st_124) for st_124 in STC5_124]
    for st_124 in STC5null_124:
        np.random.shuffle(st_124)
    TC5null_124= []
    for n in range(len(STC5null_124)):
        tc_124 = [ u for u in STC5null_124[n][0] ]
        for k in range(1, len(STC5null_124[n])):
            tc_124 = [ u+v for u in tc_124 for v in STC5null_124[n][k] ]
        TC5null_124= TC5null_124+ tc_124
    for l in range(len(setTC5_124)):
        if TC5null_124.count(setTC5_124[l]) > 0:
            fTC5null_124[l].append(TC5null_124.count(setTC5_124[l]))
        else:
            fTC5null_124[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_124)):
     if sum(freq >= fTC5_124[l] for freq in fTC5null_124[l]) < 5:
#         print(setTC5_124[l], fTC5_124[l], sum(freq >= fTC5_124[l] for freq in fTC5null_124[l]))
        print(setTC5_124[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# MBMNα
# MBYMα
# NYBNα
# YYMNα
# YBNBN
# MBYMN
# NαBNα
# YYYBM
# MBMYM
# ααBN
# NBBN
# YYBNα
# MαNMα
# YYYYB
# YBNNα
# ααYBN
# αBBB
# MMYYB
# NαNNN
# YBMNα
# YYααα
# NBNNα
# αBNMM
# YBNαα
# NαNNα
# YBMBM
# YBNBM
# MαMMα
# αBYBα
# αYYYB
# αBYBN
# NYBNN
# NYNNN
# MYBMN
# MYYN
# NαBα
# αBNMB
# MαMMM
# NBBNα
# BBBNα
# MαYM
# MαMYN
# NBNNN
# ααYBM
# NYαNN
# YαYBN
# MBBN
# BNN
# YYYBα
# YBαNα
# MBBNN
# YBYBM
# αBYBB
# MBMYN
# MMNB
# YYNYN
# YBααα
# YBBNα
# MBYYα
# YBBαα
# YYBN
# YαYBM
# αBBN
# NBMNα
# αBYBM
# MαNMN
# YBYBN
# YαNB
# YαNBM
# NBαNα
# BNM
# MYBN
# YYαNα
# MαMMN
# MαYMα
# NYBN
# ααBB
# BBNMM
# NBBNN
# MαBMα
# MαMYM
# MαNM
# NYαNα
# MMYαB
# MαMYB
# MBMNN
# αBYMB
# MαYYM
# MαBMN
# MBMNM
# αBYMN
# YYNαα
# YYNNα
# MBNB
# YBMBα
# ααYBB
# MαYYα
# MMYYα
# YαYBB
# BMBBM
# YαNBN
# YYBB
# NBMNN
# MBYM
# MαYMN
# YBYBB
# YαYMB

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_124)):
     if sum(freq >= fTC5_124[l] for freq in fTC5null_124[l]) < 1:
#         print(setTC5_124[l], fTC5_124[l], sum(freq >= fTC5_124[l] for freq in fTC5null_124[l]))
        print(setTC5_124[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# MBMYM
# NBBN
# YYBNα
# MMYYB
# YBMNα
# YBMBM
# YBNBM
# αBYBα
# αBYBN
# NYBNN
# BBBNα
# ααYBM
# NYαNN
# BNN
# YBYBM
# αBYBB
# YBBNα
# YYBN
# YαYBM
# αBYBM
# MYBN
# YYαNα
# NBBNN
# MBMNN
# YYNαα

# %% [markdown]
# # 3.125 (B) AP - (M) ICT - (R) MEG - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_125 = max(min(Date_AP), min(Date_ICT), min(Date_MEG), min(Date_SMC), min(Date_SCC))
end_125 = min(max(Date_AP), max(Date_ICT), max(Date_MEG), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
AP_125_1 = Date_AP.index(start_125)
AP_125_2 = Date_AP.index(end_125)

ICT_125_1 = Date_ICT.index(start_125)
ICT_125_2 = Date_ICT.index(end_125)

MEG_125_1 = Date_MEG.index(start_125)
MEG_125_2 = Date_MEG.index(end_125)

SMC_125_1 = Date_SMC.index(start_125)
SMC_125_2 = Date_SMC.index(end_125)

SCC_125_1 = Date_SCC.index(start_125)
SCC_125_2 = Date_SCC.index(end_125)

# %%
#save the shortened versions of closing prices
B125 = np.save('APshortPrices.npy', ClosePrice_AP[AP_125_1:AP_125_2])
M125 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_125_1:ICT_125_2])
R125 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_125_1:MEG_125_2])
Y125 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_125_1:SMC_125_2])
α125 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_125_1:SCC_125_2])

# %%
# import modules
import numpy as np
# import prices

B125 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
M125 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R125 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y125 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α125 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_125 = []
st_125 = []
n = 1
while n < len(B125):
    sc_125 = ''
    if B125[n] > B125[n-1]:
        sc_125 = sc_125 + 'B'
    if M125[n] > M125[n-1]:
        sc_125 = sc_125 + 'M'
    if R125[n] > R125[n-1]:
        sc_125 = sc_125 + 'R'
    if Y125[n] > Y125[n-1]:
        sc_125 = sc_125 + 'Y'
    if α125[n] > α125[n-1]:
        sc_125 = sc_125 + 'α'
    if len(sc_125) > 0:
        st_125.append(sc_125)
    else:
        STC_125.append(st_125)
        st_125 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_125 = STC_125.count([])
# keep only non-empty spatio-temporal sequences
STC_125 = [ st_125 for st_125 in STC_125 if len(st_125) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_125 = len(B125)
lmax_125 = 0
for st_125 in STC_125:
    if len(st_125) < lmin_125:
        lmin_125 = len(st_125)
    if len(st_125) > lmax_125:
        lmax_125 = len(st_125)
        
# restrict spatio-temporal sequences to length-5
STC5_125 = [ st_125 for st_125 in STC_125 if len(st_125) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_125 = []
for n in range(len(STC5_125)):
    tc_125 = [ u for u in STC5_125[n][0] ]
    for k in range(1, len(STC5_125[n])):
        tc_125 = [ u+v for u in tc_125 for v in STC5_125[n][k] ]
    TC5_125 = TC5_125 + tc_125
setTC5_125 = list(set(TC5_125))

# get empirical frequencies
fTC5_125 = [ TC5_125.count(setTC5_125[l]) for l in range(len(setTC5_125)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_125 = [ [] for l in range(len(setTC5_125)) ]
for s in range(100):
    STC5null_125 = [ list(st_125) for st_125 in STC5_125]
    for st_125 in STC5null_125:
        np.random.shuffle(st_125)
    TC5null_125= []
    for n in range(len(STC5null_125)):
        tc_125 = [ u for u in STC5null_125[n][0] ]
        for k in range(1, len(STC5null_125[n])):
            tc_125 = [ u+v for u in tc_125 for v in STC5null_125[n][k] ]
        TC5null_125= TC5null_125+ tc_125
    for l in range(len(setTC5_125)):
        if TC5null_125.count(setTC5_125[l]) > 0:
            fTC5null_125[l].append(TC5null_125.count(setTC5_125[l]))
        else:
            fTC5null_125[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_125)):
     if sum(freq >= fTC5_125[l] for freq in fTC5null_125[l]) < 5:
#         print(setTC5_125[l], fTC5_125[l], sum(freq >= fTC5_125[l] for freq in fTC5null_125[l]))
        print(setTC5_125[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# YBαBY
# RRMMM
# MαBBB
# RRYαα
# MRMYB
# αYBR
# RBMRα
# αBBR
# MααYB
# YRMBα
# RαMM
# YαYMY
# MYRB
# RBBB
# RYYαR
# RBMRR
# BαYYB
# RMMYα
# αMRR
# MRY
# YMBB
# RYMR
# MRYYB
# RYBB
# YBBBY
# RMMαα
# YαMα
# YMαRB
# MRBBB
# YαBR
# MYYαR
# BαBYR
# YαMR
# RRMαα
# αMBB
# αYBB
# BMRαM
# BαYYR
# RRMMB
# RRMRR
# RαYMB
# MRBBR
# αMRB
# YαMM
# MRYYα
# BRαYR
# YαMB
# MRRYR
# RRMRα
# YBαRY
# MBY
# MRBBM
# BRαYB
# ααBB
# MRMMM
# αMBR
# RBMαα
# MαMYM
# RRMBα
# MYRR
# αYRB
# MαMYB
# RMRαα
# RMRαM
# MMY
# αBRB
# MαYYM
# YMBR
# RMMαM
# YBMBα
# RBMYα
# MRBBY
# MαYYR
# MαYYB
# MBRB
# BMBBM
# RMYMB
# RBRB

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_125)):
     if sum(freq >= fTC5_125[l] for freq in fTC5null_125[l]) < 1:
#         print(setTC5_125[l], fTC5_125[l], sum(freq >= fTC5_125[l] for freq in fTC5null_125[l]))
        print(setTC5_125[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# YBαBY
# αYBR
# MααYB
# MYRB
# RMMYα
# αMRR
# MRBBB
# YαBR
# RBMαα
# MYRR
# MαMYB
# RMRαα
# YMBR

# %% [markdown]
# # 3.126 (B) AP - (N) JGS - (R) MEG - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_126 = max(min(Date_AP), min(Date_JGS), min(Date_MEG), min(Date_SMC), min(Date_SCC))
end_126 = min(max(Date_AP), max(Date_JGS), max(Date_MEG), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
AP_126_1 = Date_AP.index(start_126)
AP_126_2 = Date_AP.index(end_126)

JGS_126_1 = Date_JGS.index(start_126)
JGS_126_2 = Date_JGS.index(end_126)

MEG_126_1 = Date_MEG.index(start_126)
MEG_126_2 = Date_MEG.index(end_126)

SMC_126_1 = Date_SMC.index(start_126)
SMC_126_2 = Date_SMC.index(end_126)

SCC_126_1 = Date_SCC.index(start_126)
SCC_126_2 = Date_SCC.index(end_126)

# %%
#save the shortened versions of closing prices
B126 = np.save('APshortPrices.npy', ClosePrice_AP[AP_126_1:AP_126_2])
N126 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_126_1:JGS_126_2])
R126 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_126_1:MEG_126_2])
Y126 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_126_1:SMC_126_2])
α126 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_126_1:SCC_126_2])

# %%
# import modules
import numpy as np
# import prices

B126 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
N126 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R126 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y126 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α126 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_126 = []
st_126 = []
n = 1
while n < len(B126):
    sc_126 = ''
    if B126[n] > B126[n-1]:
        sc_126 = sc_126 + 'B'
    if N126[n] > N126[n-1]:
        sc_126 = sc_126 + 'N'
    if R126[n] > R126[n-1]:
        sc_126 = sc_126 + 'R'
    if Y126[n] > Y126[n-1]:
        sc_126 = sc_126 + 'Y'
    if α126[n] > α126[n-1]:
        sc_126 = sc_126 + 'α'
    if len(sc_126) > 0:
        st_126.append(sc_126)
    else:
        STC_126.append(st_126)
        st_126 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_126 = STC_126.count([])
# keep only non-empty spatio-temporal sequences
STC_126 = [ st_126 for st_126 in STC_126 if len(st_126) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_126 = len(B126)
lmax_126 = 0
for st_126 in STC_126:
    if len(st_126) < lmin_126:
        lmin_126 = len(st_126)
    if len(st_126) > lmax_126:
        lmax_126 = len(st_126)
        
# restrict spatio-temporal sequences to length-5
STC5_126 = [ st_126 for st_126 in STC_126 if len(st_126) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_126 = []
for n in range(len(STC5_126)):
    tc_126 = [ u for u in STC5_126[n][0] ]
    for k in range(1, len(STC5_126[n])):
        tc_126 = [ u+v for u in tc_126 for v in STC5_126[n][k] ]
    TC5_126 = TC5_126 + tc_126
setTC5_126 = list(set(TC5_126))

# get empirical frequencies
fTC5_126 = [ TC5_126.count(setTC5_126[l]) for l in range(len(setTC5_126)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_126 = [ [] for l in range(len(setTC5_126)) ]
for s in range(100):
    STC5null_126 = [ list(st_126) for st_126 in STC5_126]
    for st_126 in STC5null_126:
        np.random.shuffle(st_126)
    TC5null_126= []
    for n in range(len(STC5null_126)):
        tc_126 = [ u for u in STC5null_126[n][0] ]
        for k in range(1, len(STC5null_126[n])):
            tc_126 = [ u+v for u in tc_126 for v in STC5null_126[n][k] ]
        TC5null_126= TC5null_126+ tc_126
    for l in range(len(setTC5_126)):
        if TC5null_126.count(setTC5_126[l]) > 0:
            fTC5null_126[l].append(TC5null_126.count(setTC5_126[l]))
        else:
            fTC5null_126[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_126)):
     if sum(freq >= fTC5_126[l] for freq in fTC5null_126[l]) < 5:
#         print(setTC5_126[l], fTC5_126[l], sum(freq >= fTC5_126[l] for freq in fTC5null_126[l]))
        print(setTC5_126[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# NRαα
# NYBYα
# NYBNα
# αBBR
# RBBYα
# RYBYR
# RNNRα
# ααBN
# NBBN
# RBRRα
# RRB
# BBBYR
# RYBNα
# NYαYN
# RBαRα
# RRαRα
# RNBNα
# αBBB
# NYNYN
# RNNNα
# RYYαR
# BBRRB
# RYBYα
# RNYαB
# BYαYB
# RBRNR
# NYBRN
# YYRN
# NYNNα
# NYαY
# NYBB
# RNNBα
# RαYαα
# RNBBα
# NYBNN
# NYNNN
# RαNRα
# YYRB
# RNYαα
# YRαRB
# NYαNN
# NαBB
# YαBR
# RYBYN
# RNBNY
# RBRNα
# BNBNY
# RBRNN
# NNBN
# RBRYα
# RYNRα
# RYRYN
# RYB
# αYBB
# RBBNR
# RYBBN
# YαRB
# YYBN
# RαNNα
# YααRB
# NBBB
# RNRNα
# RRBα
# BNBNα
# NαRα
# NRNY
# YαNB
# BBRNα
# RααRB
# YYRYN
# BBRNR
# NYBYR
# RNαRα
# NRBB
# YαYRB
# NRBα
# NYBN
# BRαYB
# RYBNN
# ααBB
# YYBYN
# RαBBα
# NYBY
# NRBY
# NαNα
# RααNα
# NRBN
# RYRNα
# NαRB
# RBBNα
# RYRYR
# RYRRα
# NBBα
# RNBRα
# RαYRB
# RNYYα
# YαBB
# YBRNα
# BBRRα
# αBBYR
# NRBR
# RYNBα
# YYBB
# RRNY
# RYαRα
# RαNBα
# RBRB
# RYNYα
# NYBYN

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_126)):
     if sum(freq >= fTC5_126[l] for freq in fTC5null_126[l]) < 1:
#         print(setTC5_126[l], fTC5_126[l], sum(freq >= fTC5_126[l] for freq in fTC5null_126[l]))
        print(setTC5_126[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# RYBYR
# RNNRα
# NBBN
# αBBB
# RYYαR
# BBRRB
# RNNBα
# NYBNN
# RαNRα
# RNYαα
# YαBR
# RYBYN
# RBRNα
# RYRYN
# RBBNR
# RαNNα
# RRBα
# RααRB
# YYRYN
# NRBB
# ααBB
# RBBNα
# RYRYR
# YαBB

# %% [markdown]
# # 3.127 (D) AC - (F) BPI - (H) BLOOM - (J) FGEN - (M) ICT

# %%
#extract overlapping dates
start_127 = max(min(Date_AC), min(Date_BPI), min(Date_BLOOM), min(Date_FGEN), min(Date_ICT))
end_127 = min(max(Date_AC), max(Date_BPI), max(Date_BLOOM), max(Date_FGEN), max(Date_ICT))

# %%
#shorten the closing prices
AC_127_1 = Date_AC.index(start_127)
AC_127_2 = Date_AC.index(end_127)

BPI_127_1 = Date_BPI.index(start_127)
BPI_127_2 = Date_BPI.index(end_127)

BLOOM_127_1 = Date_BLOOM.index(start_127)
BLOOM_127_2 = Date_BLOOM.index(end_127)

FGEN_127_1 = Date_FGEN.index(start_127)
FGEN_127_2 = Date_FGEN.index(end_127)

ICT_127_1 = Date_ICT.index(start_127)
ICT_127_2 = Date_ICT.index(end_127)

# %%
#save the shortened versions of closing prices
D127 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_127_1:AC_127_2])
F127 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_127_1:BPI_127_2])
H127 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_127_1:BLOOM_127_2])
J127 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_127_1:FGEN_127_2])
M127 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_127_1:ICT_127_2])

# %%
# import modules
import numpy as np
# import prices

D127 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F127 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H127 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J127 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M127 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_127 = []
st_127 = []
n = 1
while n < len(D127):
    sc_127 = ''
    if D127[n] > D127[n-1]:
        sc_127 = sc_127 + 'D'
    if F127[n] > F127[n-1]:
        sc_127 = sc_127 + 'F'
    if H127[n] > H127[n-1]:
        sc_127 = sc_127 + 'H'
    if J127[n] > J127[n-1]:
        sc_127 = sc_127 + 'J'
    if M127[n] > M127[n-1]:
        sc_127 = sc_127 + 'M'
    if len(sc_127) > 0:
        st_127.append(sc_127)
    else:
        STC_127.append(st_127)
        st_127 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[56], line 15
#      13 if J127[n] > J127[n-1]:
#      14     sc_127 = sc_127 + 'J'
# ---> 15 if M127[n] > M127[n-1]:
#      16     sc_127 = sc_127 + 'M'
#      17 if len(sc_127) > 0:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_127 = STC_127.count([])
# keep only non-empty spatio-temporal sequences
STC_127 = [ st_127 for st_127 in STC_127 if len(st_127) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_127 = len(D127)
lmax_127 = 0
for st_127 in STC_127:
    if len(st_127) < lmin_127:
        lmin_127 = len(st_127)
    if len(st_127) > lmax_127:
        lmax_127 = len(st_127)
        
# restrict spatio-temporal sequences to length-5
STC5_127 = [ st_127 for st_127 in STC_127 if len(st_127) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_127 = []
for n in range(len(STC5_127)):
    tc_127 = [ u for u in STC5_127[n][0] ]
    for k in range(1, len(STC5_127[n])):
        tc_127 = [ u+v for u in tc_127 for v in STC5_127[n][k] ]
    TC5_127 = TC5_127 + tc_127
setTC5_127 = list(set(TC5_127))

# get empirical frequencies
fTC5_127 = [ TC5_127.count(setTC5_127[l]) for l in range(len(setTC5_127)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_127 = [ [] for l in range(len(setTC5_127)) ]
for s in range(100):
    STC5null_127 = [ list(st_127) for st_127 in STC5_127]
    for st_127 in STC5null_127:
        np.random.shuffle(st_127)
    TC5null_127= []
    for n in range(len(STC5null_127)):
        tc_127 = [ u for u in STC5null_127[n][0] ]
        for k in range(1, len(STC5null_127[n])):
            tc_127 = [ u+v for u in tc_127 for v in STC5null_127[n][k] ]
        TC5null_127= TC5null_127+ tc_127
    for l in range(len(setTC5_127)):
        if TC5null_127.count(setTC5_127[l]) > 0:
            fTC5null_127[l].append(TC5null_127.count(setTC5_127[l]))
        else:
            fTC5null_127[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_127)):
     if sum(freq >= fTC5_127[l] for freq in fTC5null_127[l]) < 5:
#         print(setTC5_127[l], fTC5_127[l], sum(freq >= fTC5_127[l] for freq in fTC5null_127[l]))
        print(setTC5_127[l])

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_127)):
     if sum(freq >= fTC5_127[l] for freq in fTC5null_127[l]) < 1:
#         print(setTC5_127[l], fTC5_127[l], sum(freq >= fTC5_127[l] for freq in fTC5null_127[l]))
        print(setTC5_127[l])

# %% [markdown]
# # 3.128 (D) AC - (F) BPI - (H) BLOOM - (J) FGEN - (N) JGS

# %%
#extract overlapping dates
start_128 = max(min(Date_AC), min(Date_BPI), min(Date_BLOOM), min(Date_FGEN), min(Date_JGS))
end_128 = min(max(Date_AC), max(Date_BPI), max(Date_BLOOM), max(Date_FGEN), max(Date_JGS))

# %%
#shorten the closing prices
AC_128_1 = Date_AC.index(start_128)
AC_128_2 = Date_AC.index(end_128)

BPI_128_1 = Date_BPI.index(start_128)
BPI_128_2 = Date_BPI.index(end_128)

BLOOM_128_1 = Date_BLOOM.index(start_128)
BLOOM_128_2 = Date_BLOOM.index(end_128)

FGEN_128_1 = Date_FGEN.index(start_128)
FGEN_128_2 = Date_FGEN.index(end_128)

JGS_128_1 = Date_JGS.index(start_128)
JGS_128_2 = Date_JGS.index(end_128)

# %%
#save the shortened versions of closing prices
D128 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_128_1:AC_128_2])
F128 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_128_1:BPI_128_2])
H128 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_128_1:BLOOM_128_2])
J128 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_128_1:FGEN_128_2])
N128 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_128_1:JGS_128_2])

# %%
# import modules
import numpy as np
# import prices

D128 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F128 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H128 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J128 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N128 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_128 = []
st_128 = []
n = 1
while n < len(D128):
    sc_128 = ''
    if D128[n] > D128[n-1]:
        sc_128 = sc_128 + 'D'
    if F128[n] > F128[n-1]:
        sc_128 = sc_128 + 'F'
    if H128[n] > H128[n-1]:
        sc_128 = sc_128 + 'H'
    if J128[n] > J128[n-1]:
        sc_128 = sc_128 + 'J'
    if N128[n] > N128[n-1]:
        sc_128 = sc_128 + 'N'
    if len(sc_128) > 0:
        st_128.append(sc_128)
    else:
        STC_128.append(st_128)
        st_128 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_128 = STC_128.count([])
# keep only non-empty spatio-temporal sequences
STC_128 = [ st_128 for st_128 in STC_128 if len(st_128) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_128 = len(D128)
lmax_128 = 0
for st_128 in STC_128:
    if len(st_128) < lmin_128:
        lmin_128 = len(st_128)
    if len(st_128) > lmax_128:
        lmax_128 = len(st_128)
        
# restrict spatio-temporal sequences to length-5
STC5_128 = [ st_128 for st_128 in STC_128 if len(st_128) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_128 = []
for n in range(len(STC5_128)):
    tc_128 = [ u for u in STC5_128[n][0] ]
    for k in range(1, len(STC5_128[n])):
        tc_128 = [ u+v for u in tc_128 for v in STC5_128[n][k] ]
    TC5_128 = TC5_128 + tc_128
setTC5_128 = list(set(TC5_128))

# get empirical frequencies
fTC5_128 = [ TC5_128.count(setTC5_128[l]) for l in range(len(setTC5_128)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_128 = [ [] for l in range(len(setTC5_128)) ]
for s in range(100):
    STC5null_128 = [ list(st_128) for st_128 in STC5_128]
    for st_128 in STC5null_128:
        np.random.shuffle(st_128)
    TC5null_128= []
    for n in range(len(STC5null_128)):
        tc_128 = [ u for u in STC5null_128[n][0] ]
        for k in range(1, len(STC5null_128[n])):
            tc_128 = [ u+v for u in tc_128 for v in STC5null_128[n][k] ]
        TC5null_128= TC5null_128+ tc_128
    for l in range(len(setTC5_128)):
        if TC5null_128.count(setTC5_128[l]) > 0:
            fTC5null_128[l].append(TC5null_128.count(setTC5_128[l]))
        else:
            fTC5null_128[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_128)):
     if sum(freq >= fTC5_128[l] for freq in fTC5null_128[l]) < 5:
#         print(setTC5_128[l], fTC5_128[l], sum(freq >= fTC5_128[l] for freq in fTC5null_128[l]))
        print(setTC5_128[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# DJJDF
# DDNDH
# NJFNJ
# DJFFH
# FFFNH
# FJDDH
# NFFJJ
# FJFNH
# DDDH
# DJJFJ
# NJFNH
# DFFDH
# NHDN
# HHJNJ
# DJDN
# FJJNH
# DJNNH
# HJHNH
# DJFNJ
# DJFDH
# FJDJ
# FDDN
# JJFDH
# DDFDH
# DJJHH
# DJFNH
# FNNDN
# DJJDH
# DHDNJ
# NNDN
# NJFDH
# DJJNH
# DDDN
# NFNDH
# DHHNH
# FJHNH
# JJFNH
# HJFH
# DJJFF
# FJN
# FNDNH
# FDDDH
# DJHNH
# NJDNH
# NFJND
# DJDHH
# FFDJN
# FJNNH
# DJDDH
# JJF
# HJFN
# HJFD
# HJFJ
# DJHHH
# HHFNJ
# NNFH
# DHNNH
# DHJNH
# DHJNJ
# FJDNH
# HJFNH
# DJNFH
# FFDHJ
# DJJFH
# FDNDH
# FJDHJ
# DNFDH
# FNDN
# NFJJF
# NFFNH
# FNNDH
# FJHNJ
# FDDF
# HHHNH
# DJDHJ
# FJNDH
# FJHHH
# DJNDH
# JFDN
# FFDNH
# DJDNH
# NHFNH
# FJFHH
# DFDHJ
# FFNNH
# NHFJ
# HNFH
# NJDHJ
# DHFNH
# FJJHH
# DNNDH
# DHFNJ
# NJFJH
# FNNNH
# NNFNH
# NJJNH
# NFFNJ
# DJF
# DJNHH
# FNDDH
# NJNDH
# NFFDH
# FJDHH
# DHHHH
# DJFHH
# DDDDH

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_128)):
     if sum(freq >= fTC5_128[l] for freq in fTC5null_128[l]) < 1:
#         print(setTC5_128[l], fTC5_128[l], sum(freq >= fTC5_128[l] for freq in fTC5null_128[l]))
        print(setTC5_128[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# FJFNH
# NJFNH
# DJNNH
# DJFDH
# FJDJ
# DJJDH
# DJJNH
# DHHNH
# FJHNH
# DJHNH
# DJDHH
# FJNNH
# DJDDH
# JJF
# HJFD
# DJHHH
# NNFH
# FJDNH
# DJJFH
# FJNDH
# DJNDH
# DJDNH
# FJDHH
# DDDDH

# %% [markdown]
# # 3.129 (D) AC - (F) BPI - (H) BLOOM - (J) FGEN - (R) MEG

# %%
#extract overlapping dates
start_129 = max(min(Date_AC), min(Date_BPI), min(Date_BLOOM), min(Date_FGEN), min(Date_MEG))
end_129 = min(max(Date_AC), max(Date_BPI), max(Date_BLOOM), max(Date_FGEN), max(Date_MEG))

# %%
#shorten the closing prices
AC_129_1 = Date_AC.index(start_129)
AC_129_2 = Date_AC.index(end_129)

BPI_129_1 = Date_BPI.index(start_129)
BPI_129_2 = Date_BPI.index(end_129)

BLOOM_129_1 = Date_BLOOM.index(start_129)
BLOOM_129_2 = Date_BLOOM.index(end_129)

FGEN_129_1 = Date_FGEN.index(start_129)
FGEN_129_2 = Date_FGEN.index(end_129)

MEG_129_1 = Date_MEG.index(start_129)
MEG_129_2 = Date_MEG.index(end_129)

# %%
#save the shortened versions of closing prices
D129 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_129_1:AC_129_2])
F129 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_129_1:BPI_129_2])
H129 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_129_1:BLOOM_129_2])
J129 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_129_1:FGEN_129_2])
R129 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_129_1:MEG_129_2])

# %%
# import modules
import numpy as np
# import prices

D129 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F129 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H129 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J129 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
R129 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_129 = []
st_129 = []
n = 1
while n < len(D129):
    sc_129 = ''
    if D129[n] > D129[n-1]:
        sc_129 = sc_129 + 'D'
    if F129[n] > F129[n-1]:
        sc_129 = sc_129 + 'F'
    if H129[n] > H129[n-1]:
        sc_129 = sc_129 + 'H'
    if J129[n] > J129[n-1]:
        sc_129 = sc_129 + 'J'
    if R129[n] > R129[n-1]:
        sc_129 = sc_129 + 'R'
    if len(sc_129) > 0:
        st_129.append(sc_129)
    else:
        STC_129.append(st_129)
        st_129 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_129 = STC_129.count([])
# keep only non-empty spatio-temporal sequences
STC_129 = [ st_129 for st_129 in STC_129 if len(st_129) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_129 = len(D129)
lmax_129 = 0
for st_129 in STC_129:
    if len(st_129) < lmin_129:
        lmin_129 = len(st_129)
    if len(st_129) > lmax_129:
        lmax_129 = len(st_129)
        
# restrict spatio-temporal sequences to length-5
STC5_129 = [ st_129 for st_129 in STC_129 if len(st_129) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_129 = []
for n in range(len(STC5_129)):
    tc_129 = [ u for u in STC5_129[n][0] ]
    for k in range(1, len(STC5_129[n])):
        tc_129 = [ u+v for u in tc_129 for v in STC5_129[n][k] ]
    TC5_129 = TC5_129 + tc_129
setTC5_129 = list(set(TC5_129))

# get empirical frequencies
fTC5_129 = [ TC5_129.count(setTC5_129[l]) for l in range(len(setTC5_129)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_129 = [ [] for l in range(len(setTC5_129)) ]
for s in range(100):
    STC5null_129 = [ list(st_129) for st_129 in STC5_129]
    for st_129 in STC5null_129:
        np.random.shuffle(st_129)
    TC5null_129= []
    for n in range(len(STC5null_129)):
        tc_129 = [ u for u in STC5null_129[n][0] ]
        for k in range(1, len(STC5null_129[n])):
            tc_129 = [ u+v for u in tc_129 for v in STC5null_129[n][k] ]
        TC5null_129= TC5null_129+ tc_129
    for l in range(len(setTC5_129)):
        if TC5null_129.count(setTC5_129[l]) > 0:
            fTC5null_129[l].append(TC5null_129.count(setTC5_129[l]))
        else:
            fTC5null_129[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_129)):
     if sum(freq >= fTC5_129[l] for freq in fTC5null_129[l]) < 5:
#         print(setTC5_129[l], fTC5_129[l], sum(freq >= fTC5_129[l] for freq in fTC5null_129[l]))
        print(setTC5_129[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# DRRRR
# HRFRH
# FJDDH
# RJDHH
# HJRRH
# DJJFJ
# RDDDH
# DFFDH
# HHDRH
# RHFRH
# HJFRH
# FHR
# RJFDH
# HRDRH
# RFFHH
# RRRRH
# HFDDH
# RHDRJ
# RFDDH
# RRHFJ
# RJDDH
# RFFDH
# RHDRD
# DJFRH
# RD
# HFFRJ
# DJJDR
# DJJHH
# HHFRJ
# DJRRR
# DJJDH
# HHFRH
# RJFRH
# DHDRJ
# HFFDH
# HHRJJ
# RHFRJ
# FJDHR
# HDFRH
# RRFJ
# HHDDH
# HHDRJ
# RFDHH
# DJDFR
# DFDJR
# DRFRH
# RHDDH
# FDDRH
# FDDDH
# DJJRR
# HFFDJ
# RJFHR
# DJDHH
# DJDDH
# FFFHJ
# DJJFR
# HJFHH
# DJHHH
# HHDJ
# HFFRH
# HFFRF
# DHDH
# RRFRH
# DJRHH
# HRFRJ
# DRRRH
# HJRJJ
# HRFRF
# DJJFH
# HRDRJ
# HHFJJ
# RRDDH
# HFFHH
# RFRRH
# HHFDH
# HJDHH
# HFRJJ
# FRFJ
# DJJRH
# DJFHR
# HFFJJ
# DJRDH
# DHJFJ
# RFHFJ
# RJJFR
# RJFHH
# HHR
# DJRJJ
# RJFHJ
# RDFRH
# HRFD
# DJRRH
# RJDHD
# RDDRH
# HHFJ
# DDDRH
# HFDHH
# HHFRF
# RHFRD
# RHDRH
# HFRRH
# RFFRH
# RRDRH
# DDJRR
# HFDRH
# JDDDH
# HRFJJ
# DFFRH
# FJDHH
# HJFJJ
# DJJHR
# DJFHH
# DDDDH

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_129)):
     if sum(freq >= fTC5_129[l] for freq in fTC5null_129[l]) < 1:
#         print(setTC5_129[l], fTC5_129[l], sum(freq >= fTC5_129[l] for freq in fTC5null_129[l]))
        print(setTC5_129[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# RJDHH
# RDDDH
# HHDRH
# RHFRH
# RFFHH
# RFDDH
# RJDDH
# HHFRJ
# DJJDH
# HHFRH
# HHDDH
# HHDRJ
# DRFRH
# RHDDH
# DJDHH
# DJJFR
# HJFHH
# HFFRF
# RRFRH
# DJJFH
# HFFHH
# HHFDH
# RJFHH
# DJRRH
# RHDRH
# RFFRH
# FJDHH

# %% [markdown]
# # 3.130 (D) AC - (F) BPI - (H) BLOOM - (J) FGEN - (Y) SMC

# %%
#extract overlapping dates
start_130 = max(min(Date_AC), min(Date_BPI), min(Date_BLOOM), min(Date_FGEN), min(Date_SMC))
end_130 = min(max(Date_AC), max(Date_BPI), max(Date_BLOOM), max(Date_FGEN), max(Date_SMC))

# %%
#shorten the closing prices
AC_130_1 = Date_AC.index(start_130)
AC_130_2 = Date_AC.index(end_130)

BPI_130_1 = Date_BPI.index(start_130)
BPI_130_2 = Date_BPI.index(end_130)

BLOOM_130_1 = Date_BLOOM.index(start_130)
BLOOM_130_2 = Date_BLOOM.index(end_130)

FGEN_130_1 = Date_FGEN.index(start_130)
FGEN_130_2 = Date_FGEN.index(end_130)

SMC_130_1 = Date_SMC.index(start_130)
SMC_130_2 = Date_SMC.index(end_130)

# %%
#save the shortened versions of closing prices
D130 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_130_1:AC_130_2])
F130 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_130_1:BPI_130_2])
H130 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_130_1:BLOOM_130_2])
J130 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_130_1:FGEN_130_2])
Y130 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_130_1:SMC_130_2])

# %%
# import modules
import numpy as np
# import prices

D130 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F130 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H130 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J130 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
Y130 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_130 = []
st_130 = []
n = 1
while n < len(D130):
    sc_130 = ''
    if D130[n] > D130[n-1]:
        sc_130 = sc_130 + 'D'
    if F130[n] > F130[n-1]:
        sc_130 = sc_130 + 'F'
    if H130[n] > H130[n-1]:
        sc_130 = sc_130 + 'H'
    if J130[n] > J130[n-1]:
        sc_130 = sc_130 + 'J'
    if Y130[n] > Y130[n-1]:
        sc_130 = sc_130 + 'Y'
    if len(sc_130) > 0:
        st_130.append(sc_130)
    else:
        STC_130.append(st_130)
        st_130 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_130 = STC_130.count([])
# keep only non-empty spatio-temporal sequences
STC_130 = [ st_130 for st_130 in STC_130 if len(st_130) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_130 = len(D130)
lmax_130 = 0
for st_130 in STC_130:
    if len(st_130) < lmin_130:
        lmin_130 = len(st_130)
    if len(st_130) > lmax_130:
        lmax_130 = len(st_130)
        
# restrict spatio-temporal sequences to length-5
STC5_130 = [ st_130 for st_130 in STC_130 if len(st_130) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_130 = []
for n in range(len(STC5_130)):
    tc_130 = [ u for u in STC5_130[n][0] ]
    for k in range(1, len(STC5_130[n])):
        tc_130 = [ u+v for u in tc_130 for v in STC5_130[n][k] ]
    TC5_130 = TC5_130 + tc_130
setTC5_130 = list(set(TC5_130))

# get empirical frequencies
fTC5_130 = [ TC5_130.count(setTC5_130[l]) for l in range(len(setTC5_130)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_130 = [ [] for l in range(len(setTC5_130)) ]
for s in range(100):
    STC5null_130 = [ list(st_130) for st_130 in STC5_130]
    for st_130 in STC5null_130:
        np.random.shuffle(st_130)
    TC5null_130= []
    for n in range(len(STC5null_130)):
        tc_130 = [ u for u in STC5null_130[n][0] ]
        for k in range(1, len(STC5null_130[n])):
            tc_130 = [ u+v for u in tc_130 for v in STC5null_130[n][k] ]
        TC5null_130= TC5null_130+ tc_130
    for l in range(len(setTC5_130)):
        if TC5null_130.count(setTC5_130[l]) > 0:
            fTC5null_130[l].append(TC5null_130.count(setTC5_130[l]))
        else:
            fTC5null_130[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_130)):
     if sum(freq >= fTC5_130[l] for freq in fTC5null_130[l]) < 5:
#         print(setTC5_130[l], fTC5_130[l], sum(freq >= fTC5_130[l] for freq in fTC5null_130[l]))
        print(setTC5_130[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FJYF
# HFDYY
# YYDYY
# FHDYJ
# FYYJ
# FJDDH
# YYDYD
# DHDYJ
# DDDH
# DFFJJ
# DJYH
# YYJFD
# HDYD
# HDDJ
# YFDDH
# HDDYJ
# HFDDH
# YYDJH
# YHDJJ
# HFFHJ
# YJDJH
# HDFF
# YJDFF
# FJYY
# HYFJ
# YDJFD
# YFFDJ
# HHDHJ
# HDYJ
# FYFD
# FHD
# HFDFH
# YJDDH
# HYFY
# YJDJJ
# DDDHJ
# YJHJJ
# HDYF
# HFJJ
# FDDDH
# YJDYH
# YFDYH
# YFDFY
# FYYY
# HJHYJ
# YFHFJ
# HHDY
# HJFD
# HJFJ
# DYYY
# YFDFF
# DDDJ
# FJYJ
# HJYD
# HHDJJ
# FFDHJ
# FJDHJ
# HJHHJ
# DDDYJ
# HHFJJ
# YFFDY
# YYDYH
# HDFJ
# HJYJ
# HJDYH
# YFJFD
# HYFD
# DJDHJ
# YFHFD
# JFYYH
# HJDYJ
# HFFJJ
# FFYYH
# FD
# FFHHJ
# YFDFH
# HFDHJ
# YYDDH
# YJDJD
# FYDDH
# YJDDY
# HJHHH
# HDDF
# FDDHJ
# HDFD
# YJY
# HYFF
# HFDYF
# YDDDH
# DFDHJ
# YFHFH
# FDDYJ
# FJYJH
# JYHHJ
# FJDYH
# HJYJH
# HJFHJ
# HJDHJ
# HDDHJ
# HFDHH
# DYFJJ
# YFDDY
# HJYF
# YFYDH
# FJ
# YYDDY
# DDDYH
# FYDJ
# HJFJJ
# YYDFF
# YFDJH
# YFDDF

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_130)):
     if sum(freq >= fTC5_130[l] for freq in fTC5null_130[l]) < 1:
#         print(setTC5_130[l], fTC5_130[l], sum(freq >= fTC5_130[l] for freq in fTC5null_130[l]))
        print(setTC5_130[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# HDYD
# YFDDH
# YHDJJ
# YJDJH
# YDJFD
# YJDDH
# HYFY
# YJDJJ
# YJDYH
# FYYY
# YFHFJ
# FJYJ
# HJYD
# YFHFD
# HFDHJ
# YJDDY
# HDFD
# HJDHJ
# YFDDY
# YYDFF
# YFDJH

# %% [markdown]
# # 3.131 (D) AC - (F) BPI - (H) BLOOM - (J) FGEN - (α) SCC

# %%
#extract overlapping dates
start_131 = max(min(Date_AC), min(Date_BPI), min(Date_BLOOM), min(Date_FGEN), min(Date_SCC))
end_131 = min(max(Date_AC), max(Date_BPI), max(Date_BLOOM), max(Date_FGEN), max(Date_SCC))

# %%
#shorten the closing prices
AC_131_1 = Date_AC.index(start_131)
AC_131_2 = Date_AC.index(end_131)

BPI_131_1 = Date_BPI.index(start_131)
BPI_131_2 = Date_BPI.index(end_131)

BLOOM_131_1 = Date_BLOOM.index(start_131)
BLOOM_131_2 = Date_BLOOM.index(end_131)

FGEN_131_1 = Date_FGEN.index(start_131)
FGEN_131_2 = Date_FGEN.index(end_131)

SCC_131_1 = Date_SCC.index(start_131)
SCC_131_2 = Date_SCC.index(end_131)

# %%
#save the shortened versions of closing prices
D131 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_131_1:AC_131_2])
F131 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_131_1:BPI_131_2])
H131 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_131_1:BLOOM_131_2])
J131 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_131_1:FGEN_131_2])
α131 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_131_1:SCC_131_2])

# %%
# import modules
import numpy as np
# import prices

D131 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F131 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H131 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J131 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
α131 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_131 = []
st_131 = []
n = 1
while n < len(D131):
    sc_131 = ''
    if D131[n] > D131[n-1]:
        sc_131 = sc_131 + 'D'
    if F131[n] > F131[n-1]:
        sc_131 = sc_131 + 'F'
    if H131[n] > H131[n-1]:
        sc_131 = sc_131 + 'H'
    if J131[n] > J131[n-1]:
        sc_131 = sc_131 + 'J'
    if α131[n] > α131[n-1]:
        sc_131 = sc_131 + 'α'
    if len(sc_131) > 0:
        st_131.append(sc_131)
    else:
        STC_131.append(st_131)
        st_131 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_131 = STC_131.count([])
# keep only non-empty spatio-temporal sequences
STC_131 = [ st_131 for st_131 in STC_131 if len(st_131) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_131 = len(D131)
lmax_131 = 0
for st_131 in STC_131:
    if len(st_131) < lmin_131:
        lmin_131 = len(st_131)
    if len(st_131) > lmax_131:
        lmax_131 = len(st_131)
        
# restrict spatio-temporal sequences to length-5
STC5_131 = [ st_131 for st_131 in STC_131 if len(st_131) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_131 = []
for n in range(len(STC5_131)):
    tc_131 = [ u for u in STC5_131[n][0] ]
    for k in range(1, len(STC5_131[n])):
        tc_131 = [ u+v for u in tc_131 for v in STC5_131[n][k] ]
    TC5_131 = TC5_131 + tc_131
setTC5_131 = list(set(TC5_131))

# get empirical frequencies
fTC5_131 = [ TC5_131.count(setTC5_131[l]) for l in range(len(setTC5_131)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_131 = [ [] for l in range(len(setTC5_131)) ]
for s in range(100):
    STC5null_131 = [ list(st_131) for st_131 in STC5_131]
    for st_131 in STC5null_131:
        np.random.shuffle(st_131)
    TC5null_131= []
    for n in range(len(STC5null_131)):
        tc_131 = [ u for u in STC5null_131[n][0] ]
        for k in range(1, len(STC5null_131[n])):
            tc_131 = [ u+v for u in tc_131 for v in STC5null_131[n][k] ]
        TC5null_131= TC5null_131+ tc_131
    for l in range(len(setTC5_131)):
        if TC5null_131.count(setTC5_131[l]) > 0:
            fTC5null_131[l].append(TC5null_131.count(setTC5_131[l]))
        else:
            fTC5null_131[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_131)):
     if sum(freq >= fTC5_131[l] for freq in fTC5null_131[l]) < 5:
#         print(setTC5_131[l], fTC5_131[l], sum(freq >= fTC5_131[l] for freq in fTC5null_131[l]))
        print(setTC5_131[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# ααDD
# DJFFH
# FDαJD
# HHHαD
# HHHFD
# DJJFJ
# αJJFF
# DJJFD
# FJHαJ
# JFJαα
# FFααα
# FDDαH
# JDHαα
# FJDJ
# HHHαJ
# DJJJJ
# FFHD
# αFHD
# JDααD
# αJDα
# DJJHH
# JDHαD
# DJJDH
# αFHFJ
# DαααD
# FFHα
# FJαJ
# αJJFH
# FDα
# ααJFH
# αHHα
# JFJαD
# HHααJ
# DHααD
# HJFH
# DJJFF
# DHJFH
# FDααD
# DHαFH
# DJDHH
# HHHFF
# DHααJ
# DJJDJ
# αHDDH
# JDJαD
# FDJαD
# DJJFH
# αHDαH
# αJJα
# DJJαH
# DHJFα
# DJαFH
# HJJα
# HDFD
# HαFD
# FFααD
# FDHαD
# ααHα
# FHHαJ
# αFJFH
# JFHFJ
# JFHαα
# αFαFJ
# JFHDα
# HHHFα
# HHHFJ

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_131)):
     if sum(freq >= fTC5_131[l] for freq in fTC5null_131[l]) < 1:
#         print(setTC5_131[l], fTC5_131[l], sum(freq >= fTC5_131[l] for freq in fTC5null_131[l]))
        print(setTC5_131[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# DJFFH
# FFHD
# DJJHH
# DαααD
# FFHα
# FDα
# DJJFF
# FDααD
# DJJFH
# HJJα
# HαFD
# FFααD

# %% [markdown]
# # 3.132 (D) AC - (F) BPI - (H) BLOOM - (M) ICT - (N) JGS

# %%
#extract overlapping dates
start_132 = max(min(Date_AC), min(Date_BPI), min(Date_BLOOM), min(Date_ICT), min(Date_JGS))
end_132 = min(max(Date_AC), max(Date_BPI), max(Date_BLOOM), max(Date_ICT), max(Date_JGS))

# %%
#shorten the closing prices
AC_132_1 = Date_AC.index(start_132)
AC_132_2 = Date_AC.index(end_132)

BPI_132_1 = Date_BPI.index(start_132)
BPI_132_2 = Date_BPI.index(end_132)

BLOOM_132_1 = Date_BLOOM.index(start_132)
BLOOM_132_2 = Date_BLOOM.index(end_132)

ICT_132_1 = Date_ICT.index(start_132)
ICT_132_2 = Date_ICT.index(end_132)

JGS_132_1 = Date_JGS.index(start_132)
JGS_132_2 = Date_JGS.index(end_132)

# %%
#save the shortened versions of closing prices
D132 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_132_1:AC_132_2])
F132 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_132_1:BPI_132_2])
H132 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_132_1:BLOOM_132_2])
M132 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_132_1:ICT_132_2])
N132 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_132_1:JGS_132_2])

# %%
# import modules
import numpy as np
# import prices

D132 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F132 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H132 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M132 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N132 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_132 = []
st_132 = []
n = 1
while n < len(D132):
    sc_132 = ''
    if D132[n] > D132[n-1]:
        sc_132 = sc_132 + 'D'
    if F132[n] > F132[n-1]:
        sc_132 = sc_132 + 'F'
    if H132[n] > H132[n-1]:
        sc_132 = sc_132 + 'H'
    if M132[n] > M132[n-1]:
        sc_132 = sc_132 + 'M'
    if N132[n] > N132[n-1]:
        sc_132 = sc_132 + 'N'
    if len(sc_132) > 0:
        st_132.append(sc_132)
    else:
        STC_132.append(st_132)
        st_132 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_132 = STC_132.count([])
# keep only non-empty spatio-temporal sequences
STC_132 = [ st_132 for st_132 in STC_132 if len(st_132) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_132 = len(D132)
lmax_132 = 0
for st_132 in STC_132:
    if len(st_132) < lmin_132:
        lmin_132 = len(st_132)
    if len(st_132) > lmax_132:
        lmax_132 = len(st_132)
        
# restrict spatio-temporal sequences to length-5
STC5_132 = [ st_132 for st_132 in STC_132 if len(st_132) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_132 = []
for n in range(len(STC5_132)):
    tc_132 = [ u for u in STC5_132[n][0] ]
    for k in range(1, len(STC5_132[n])):
        tc_132 = [ u+v for u in tc_132 for v in STC5_132[n][k] ]
    TC5_132 = TC5_132 + tc_132
setTC5_132 = list(set(TC5_132))

# get empirical frequencies
fTC5_132 = [ TC5_132.count(setTC5_132[l]) for l in range(len(setTC5_132)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_132 = [ [] for l in range(len(setTC5_132)) ]
for s in range(100):
    STC5null_132 = [ list(st_132) for st_132 in STC5_132]
    for st_132 in STC5null_132:
        np.random.shuffle(st_132)
    TC5null_132= []
    for n in range(len(STC5null_132)):
        tc_132 = [ u for u in STC5null_132[n][0] ]
        for k in range(1, len(STC5null_132[n])):
            tc_132 = [ u+v for u in tc_132 for v in STC5null_132[n][k] ]
        TC5null_132= TC5null_132+ tc_132
    for l in range(len(setTC5_132)):
        if TC5null_132.count(setTC5_132[l]) > 0:
            fTC5null_132[l].append(TC5null_132.count(setTC5_132[l]))
        else:
            fTC5null_132[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_132)):
     if sum(freq >= fTC5_132[l] for freq in fTC5null_132[l]) < 5:
#         print(setTC5_132[l], fTC5_132[l], sum(freq >= fTC5_132[l] for freq in fTC5null_132[l]))
        print(setTC5_132[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# HNMNF
# FMMMF
# DMND
# HHMDN
# NFMNM
# MMFN
# FMN
# DDDH
# FNMDN
# HHHFD
# HMMMD
# HNMDN
# FMDF
# HNMNM
# HHMFD
# HHHNN
# FDNMH
# HDMMN
# HHMNM
# FMF
# FMH
# MDHFN
# HDFMD
# HFFMD
# DMDH
# FFMFN
# MNMDN
# HHMFN
# MDHMD
# FDNMN
# MDMFN
# HHHFN
# NNDN
# HMMMF
# FNDMN
# NHFH
# MNMFN
# HDMFN
# NNMDN
# DDMDN
# HHMMD
# HHMDF
# FMNF
# FNNMN
# FMHFF
# MHFH
# FMFH
# MMFH
# MDFDN
# HHHMN
# DMN
# HDMMD
# HNMNN
# MHDM
# MMFM
# NMFH
# MMMN
# HHHFF
# FNHFF
# HNMMN
# DHFH
# FDHFF
# MMDF
# FMMMN
# FNMMN
# DHDH
# MNDMN
# NNFH
# FNDF
# FFMDN
# MMFD
# MFMDN
# NFMNN
# HHMMN
# FDNDH
# HNHFF
# HNMFN
# FHMFF
# FNNDH
# MHFM
# HNFMD
# MDMMN
# HHMNF
# NHDM
# MMND
# FDNNH
# MDMDN
# DMNH
# NHD
# HNMND
# DNMDN
# HHMDH
# FMMMD
# DHNH
# HHHMD
# MDHFD
# NMFM
# HNHNN
# HHMNN
# DNNDH
# FNMFN
# FDMFN
# HNDMD
# HHMFF
# NMNN
# NDMDN
# FNNNH
# FMNMD
# FHHFF
# NHNH
# MMNH
# NMFN
# MNMMN
# DMFH
# HHDDN
# FNMMD
# HHMND
# MDHMN
# MDDDN
# MDDFN

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_132)):
     if sum(freq >= fTC5_132[l] for freq in fTC5null_132[l]) < 1:
#         print(setTC5_132[l], fTC5_132[l], sum(freq >= fTC5_132[l] for freq in fTC5null_132[l]))
        print(setTC5_132[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# FMMMF
# HHMDN
# HNMDN
# HNMNM
# HFFMD
# HHMFN
# MDMFN
# HHMMD
# MMFH
# HNMNN
# FNHFF
# DHFH
# FDHFF
# FNMMN
# DHDH
# NNFH
# MMFD
# FDNDH
# FNNDH
# HNFMD
# MDMDN
# DMNH
# DNMDN
# DHNH
# HNHNN
# HHMNN
# FNNNH
# FHHFF
# MMNH
# NMFN
# DMFH
# FNMMD
# MDDDN

# %% [markdown]
# # 3.133 (D) AC - (F) BPI - (H) BLOOM - (M) ICT - (R) MEG

# %%
#extract overlapping dates
start_133 = max(min(Date_AC), min(Date_BPI), min(Date_BLOOM), min(Date_ICT), min(Date_MEG))
end_133 = min(max(Date_AC), max(Date_BPI), max(Date_BLOOM), max(Date_ICT), max(Date_MEG))

# %%
#shorten the closing prices
AC_133_1 = Date_AC.index(start_133)
AC_133_2 = Date_AC.index(end_133)

BPI_133_1 = Date_BPI.index(start_133)
BPI_133_2 = Date_BPI.index(end_133)

BLOOM_133_1 = Date_BLOOM.index(start_133)
BLOOM_133_2 = Date_BLOOM.index(end_133)

ICT_133_1 = Date_ICT.index(start_133)
ICT_133_2 = Date_ICT.index(end_133)

MEG_133_1 = Date_MEG.index(start_133)
MEG_133_2 = Date_MEG.index(end_133)

# %%
#save the shortened versions of closing prices
D133 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_133_1:AC_133_2])
F133 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_133_1:BPI_133_2])
H133 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_133_1:BLOOM_133_2])
M133 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_133_1:ICT_133_2])
R133 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_133_1:MEG_133_2])

# %%
# import modules
import numpy as np
# import prices

D133 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F133 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H133 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M133 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R133 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_133 = []
st_133 = []
n = 1
while n < len(D133):
    sc_133 = ''
    if D133[n] > D133[n-1]:
        sc_133 = sc_133 + 'D'
    if F133[n] > F133[n-1]:
        sc_133 = sc_133 + 'F'
    if H133[n] > H133[n-1]:
        sc_133 = sc_133 + 'H'
    if M133[n] > M133[n-1]:
        sc_133 = sc_133 + 'M'
    if R133[n] > R133[n-1]:
        sc_133 = sc_133 + 'R'
    if len(sc_133) > 0:
        st_133.append(sc_133)
    else:
        STC_133.append(st_133)
        st_133 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_133 = STC_133.count([])
# keep only non-empty spatio-temporal sequences
STC_133 = [ st_133 for st_133 in STC_133 if len(st_133) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_133 = len(D133)
lmax_133 = 0
for st_133 in STC_133:
    if len(st_133) < lmin_133:
        lmin_133 = len(st_133)
    if len(st_133) > lmax_133:
        lmax_133 = len(st_133)
        
# restrict spatio-temporal sequences to length-5
STC5_133 = [ st_133 for st_133 in STC_133 if len(st_133) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_133 = []
for n in range(len(STC5_133)):
    tc_133 = [ u for u in STC5_133[n][0] ]
    for k in range(1, len(STC5_133[n])):
        tc_133 = [ u+v for u in tc_133 for v in STC5_133[n][k] ]
    TC5_133 = TC5_133 + tc_133
setTC5_133 = list(set(TC5_133))

# get empirical frequencies
fTC5_133 = [ TC5_133.count(setTC5_133[l]) for l in range(len(setTC5_133)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_133 = [ [] for l in range(len(setTC5_133)) ]
for s in range(100):
    STC5null_133 = [ list(st_133) for st_133 in STC5_133]
    for st_133 in STC5null_133:
        np.random.shuffle(st_133)
    TC5null_133= []
    for n in range(len(STC5null_133)):
        tc_133 = [ u for u in STC5null_133[n][0] ]
        for k in range(1, len(STC5null_133[n])):
            tc_133 = [ u+v for u in tc_133 for v in STC5null_133[n][k] ]
        TC5null_133= TC5null_133+ tc_133
    for l in range(len(setTC5_133)):
        if TC5null_133.count(setTC5_133[l]) > 0:
            fTC5null_133[l].append(TC5null_133.count(setTC5_133[l]))
        else:
            fTC5null_133[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_133)):
     if sum(freq >= fTC5_133[l] for freq in fTC5null_133[l]) < 1:
#         print(setTC5_133[l], fTC5_133[l], sum(freq >= fTC5_133[l] for freq in fTC5null_133[l]))
        print(setTC5_133[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# HHRRF
# DRRRR
# DHFRD
# MFFMF
# RM
# HHFRD
# MFFMD
# FHR
# HFFMD
# DMDH
# FMFD
# RFMMD
# HFFMF
# MDRMD
# FMFH
# MMFH
# RHFMD
# FRRRR
# RFFMD
# HFFRF
# HHDDD
# RDMMF
# DMRH
# FHM
# MRFH
# MDMMD
# DRFH
# DMFD
# RDMMD
# FDMMD
# RFMMF
# HHFRF
# RDFMD
# RHFRD
# MHFRD
# DMFH

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_133)):
     if sum(freq >= fTC5_133[l] for freq in fTC5null_133[l]) < 1:
#         print(setTC5_133[l], fTC5_133[l], sum(freq >= fTC5_133[l] for freq in fTC5null_133[l]))
        print(setTC5_133[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# HHRRF
# DRRRR
# DHFRD
# MFFMF
# RM
# HHFRD
# MFFMD
# FHR
# HFFMD
# DMDH
# FMFD
# RFMMD
# HFFMF
# MDRMD
# FMFH
# MMFH
# RHFMD
# FRRRR
# RFFMD
# HFFRF
# HHDDD
# RDMMF
# DMRH
# FHM
# MRFH
# MDMMD
# DRFH
# DMFD
# RDMMD
# FDMMD
# RFMMF
# HHFRF
# RDFMD
# RHFRD
# MHFRD
# DMFH

# %% [markdown]
# # 3.134 (D) AC - (F) BPI - (H) BLOOM - (M) ICT - (Y) SMC

# %%
#extract overlapping dates
start_134 = max(min(Date_AC), min(Date_BPI), min(Date_BLOOM), min(Date_ICT), min(Date_SMC))
end_134 = min(max(Date_AC), max(Date_BPI), max(Date_BLOOM), max(Date_ICT), max(Date_SMC))

# %%
#shorten the closing prices
AC_134_1 = Date_AC.index(start_134)
AC_134_2 = Date_AC.index(end_134)

BPI_134_1 = Date_BPI.index(start_134)
BPI_134_2 = Date_BPI.index(end_134)

BLOOM_134_1 = Date_BLOOM.index(start_134)
BLOOM_134_2 = Date_BLOOM.index(end_134)

ICT_134_1 = Date_ICT.index(start_134)
ICT_134_2 = Date_ICT.index(end_134)

SMC_134_1 = Date_SMC.index(start_134)
SMC_134_2 = Date_SMC.index(end_134)

# %%
#save the shortened versions of closing prices
D134 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_134_1:AC_134_2])
F134 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_134_1:BPI_134_2])
H134 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_134_1:BLOOM_134_2])
M134 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_134_1:ICT_134_2])
Y134 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_134_1:SMC_134_2])

# %%
# import modules
import numpy as np
# import prices

D134 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F134 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H134 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M134 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
Y134 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_134 = []
st_134 = []
n = 1
while n < len(D134):
    sc_134 = ''
    if D134[n] > D134[n-1]:
        sc_134 = sc_134 + 'D'
    if F134[n] > F134[n-1]:
        sc_134 = sc_134 + 'F'
    if H134[n] > H134[n-1]:
        sc_134 = sc_134 + 'H'
    if M134[n] > M134[n-1]:
        sc_134 = sc_134 + 'M'
    if Y134[n] > Y134[n-1]:
        sc_134 = sc_134 + 'Y'
    if len(sc_134) > 0:
        st_134.append(sc_134)
    else:
        STC_134.append(st_134)
        st_134 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_134 = STC_134.count([])
# keep only non-empty spatio-temporal sequences
STC_134 = [ st_134 for st_134 in STC_134 if len(st_134) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_134 = len(D134)
lmax_134 = 0
for st_134 in STC_134:
    if len(st_134) < lmin_134:
        lmin_134 = len(st_134)
    if len(st_134) > lmax_134:
        lmax_134 = len(st_134)
        
# restrict spatio-temporal sequences to length-5
STC5_134 = [ st_134 for st_134 in STC_134 if len(st_134) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_134 = []
for n in range(len(STC5_134)):
    tc_134 = [ u for u in STC5_134[n][0] ]
    for k in range(1, len(STC5_134[n])):
        tc_134 = [ u+v for u in tc_134 for v in STC5_134[n][k] ]
    TC5_134 = TC5_134 + tc_134
setTC5_134 = list(set(TC5_134))

# get empirical frequencies
fTC5_134 = [ TC5_134.count(setTC5_134[l]) for l in range(len(setTC5_134)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_134 = [ [] for l in range(len(setTC5_134)) ]
for s in range(100):
    STC5null_134 = [ list(st_134) for st_134 in STC5_134]
    for st_134 in STC5null_134:
        np.random.shuffle(st_134)
    TC5null_134= []
    for n in range(len(STC5null_134)):
        tc_134 = [ u for u in STC5null_134[n][0] ]
        for k in range(1, len(STC5null_134[n])):
            tc_134 = [ u+v for u in tc_134 for v in STC5null_134[n][k] ]
        TC5null_134= TC5null_134+ tc_134
    for l in range(len(setTC5_134)):
        if TC5null_134.count(setTC5_134[l]) > 0:
            fTC5null_134[l].append(TC5null_134.count(setTC5_134[l]))
        else:
            fTC5null_134[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_134)):
     if sum(freq >= fTC5_134[l] for freq in fTC5null_134[l]) < 5:
#         print(setTC5_134[l], fTC5_134[l], sum(freq >= fTC5_134[l] for freq in fTC5null_134[l]))
        print(setTC5_134[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# YYDYY
# MFYFD
# HFYFY
# YHDFD
# HMHYF
# MFFMF
# HHYFD
# YYDYD
# FDDYM
# FDDMM
# MFFMD
# HFDMD
# YYDMY
# FMDYM
# YYDYM
# HHFMD
# YHFDF
# FYDYH
# YFDMF
# MHYMD
# YFDDH
# YDDDY
# HDFMD
# HMHYM
# HFFMD
# FYDMM
# MYDMM
# HHYFM
# YDDDF
# HDYFD
# FMFD
# MDHMD
# MFDMM
# YHYFD
# YHFFF
# YHFMH
# HYDF
# HDHDH
# YDDDD
# HHYMD
# HYYMH
# MMFF
# FHD
# MFDMD
# MHFDD
# MFDFD
# HYFY
# MYDD
# YHDMH
# MHD
# HDMMD
# YDDFF
# FYDMH
# YYYMH
# HYFM
# YHDDF
# MDFMD
# FYYY
# MHDM
# MFMDF
# YDHFH
# HMFF
# DYYY
# HHHFF
# YFDFF
# YYFYM
# DHDH
# HDFMF
# MMFD
# MHMD
# MHMMF
# YMDH
# FYFF
# YYDYH
# YYDMD
# MHFM
# HFDFF
# YFHFD
# HMHFM
# MHFMD
# YFDFH
# YHFMD
# HFYFD
# YFDFD
# FMDYH
# MFDMF
# YYDDH
# FYDDH
# YMDDD
# HYFF
# YFYMH
# MFYDD
# MDDMD
# FYDYM
# YYFMH
# YDDDH
# DFFDF
# FMFYM
# HHYFF
# HDMMF
# HHFDD
# MFFDF
# YYHHH
# HMDF
# YHYMD
# HHFDF
# HMDD
# YFFMF
# MHMMD
# YYDMH
# YHDMD
# HDHFF
# YFDDD
# YFDMH
# YYDMM
# YFDDF
# YHDDD
# YYFMM

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_134)):
     if sum(freq >= fTC5_134[l] for freq in fTC5null_134[l]) < 1:
#         print(setTC5_134[l], fTC5_134[l], sum(freq >= fTC5_134[l] for freq in fTC5null_134[l]))
        print(setTC5_134[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# YYDYM
# YFDDH
# HDFMD
# HFFMD
# YDDDD
# MHD
# YYYMH
# DYYY
# HHHFF
# DHDH
# FYFF
# FYDDH
# HYFF
# HMDF
# YHYMD
# HMDD
# YYDMH
# YHDMD
# YFDDD
# YFDMH
# YYDMM
# YHDDD

# %% [markdown]
# # 3.135 (D) AC - (F) BPI - (H) BLOOM - (M) ICT - (α) SCC

# %%
#extract overlapping dates
start_135 = max(min(Date_AC), min(Date_BPI), min(Date_BLOOM), min(Date_ICT), min(Date_SCC))
end_135 = min(max(Date_AC), max(Date_BPI), max(Date_BLOOM), max(Date_ICT), max(Date_SCC))

# %%
#shorten the closing prices
AC_135_1 = Date_AC.index(start_135)
AC_135_2 = Date_AC.index(end_135)

BPI_135_1 = Date_BPI.index(start_135)
BPI_135_2 = Date_BPI.index(end_135)

BLOOM_135_1 = Date_BLOOM.index(start_135)
BLOOM_135_2 = Date_BLOOM.index(end_135)

ICT_135_1 = Date_ICT.index(start_135)
ICT_135_2 = Date_ICT.index(end_135)

SCC_135_1 = Date_SCC.index(start_135)
SCC_135_2 = Date_SCC.index(end_135)

# %%
#save the shortened versions of closing prices
D135 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_135_1:AC_135_2])
F135 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_135_1:BPI_135_2])
H135 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_135_1:BLOOM_135_2])
M135 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_135_1:ICT_135_2])
α135 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_135_1:SCC_135_2])

# %%
# import modules
import numpy as np
# import prices

D135 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F135 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H135 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M135 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
α135 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_135 = []
st_135 = []
n = 1
while n < len(D135):
    sc_135 = ''
    if D135[n] > D135[n-1]:
        sc_135 = sc_135 + 'D'
    if F135[n] > F135[n-1]:
        sc_135 = sc_135 + 'F'
    if H135[n] > H135[n-1]:
        sc_135 = sc_135 + 'H'
    if M135[n] > M135[n-1]:
        sc_135 = sc_135 + 'M'
    if α135[n] > α135[n-1]:
        sc_135 = sc_135 + 'α'
    if len(sc_135) > 0:
        st_135.append(sc_135)
    else:
        STC_135.append(st_135)
        st_135 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_135 = STC_135.count([])
# keep only non-empty spatio-temporal sequences
STC_135 = [ st_135 for st_135 in STC_135 if len(st_135) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_135 = len(D135)
lmax_135 = 0
for st_135 in STC_135:
    if len(st_135) < lmin_135:
        lmin_135 = len(st_135)
    if len(st_135) > lmax_135:
        lmax_135 = len(st_135)
        
# restrict spatio-temporal sequences to length-5
STC5_135 = [ st_135 for st_135 in STC_135 if len(st_135) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_135 = []
for n in range(len(STC5_135)):
    tc_135 = [ u for u in STC5_135[n][0] ]
    for k in range(1, len(STC5_135[n])):
        tc_135 = [ u+v for u in tc_135 for v in STC5_135[n][k] ]
    TC5_135 = TC5_135 + tc_135
setTC5_135 = list(set(TC5_135))

# get empirical frequencies
fTC5_135 = [ TC5_135.count(setTC5_135[l]) for l in range(len(setTC5_135)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_135 = [ [] for l in range(len(setTC5_135)) ]
for s in range(100):
    STC5null_135 = [ list(st_135) for st_135 in STC5_135]
    for st_135 in STC5null_135:
        np.random.shuffle(st_135)
    TC5null_135= []
    for n in range(len(STC5null_135)):
        tc_135 = [ u for u in STC5null_135[n][0] ]
        for k in range(1, len(STC5null_135[n])):
            tc_135 = [ u+v for u in tc_135 for v in STC5null_135[n][k] ]
        TC5null_135= TC5null_135+ tc_135
    for l in range(len(setTC5_135)):
        if TC5null_135.count(setTC5_135[l]) > 0:
            fTC5null_135[l].append(TC5null_135.count(setTC5_135[l]))
        else:
            fTC5null_135[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_135)):
     if sum(freq >= fTC5_135[l] for freq in fTC5null_135[l]) < 5:
#         print(setTC5_135[l], fTC5_135[l], sum(freq >= fTC5_135[l] for freq in fTC5null_135[l]))
        print(setTC5_135[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# HαF
# FMMMF
# HαMαD
# MFFMF
# HHMαD
# FMHαD
# HHHαD
# HHFαα
# MFFMD
# DFFDH
# DMDαM
# HMMαM
# DHFMD
# DHMHD
# FMHαM
# FFααα
# HDFMD
# HαMFD
# HFFMD
# HαααD
# MDHMD
# HHDαα
# MFDMM
# HHMD
# FDαDH
# HFFMF
# DαααD
# FFHα
# HMMαD
# FHD
# HHMMD
# MFDMD
# FMHHD
# MMFH
# αFDFM
# HDMMD
# HHMαH
# MDFMD
# MFMDF
# αMDFM
# HHHFF
# HαHαα
# FFαMD
# FαHH
# MMFD
# MHMD
# HαHαM
# αFMαα
# HDMαD
# HHMDD
# HαMαα
# DαMαD
# MFαMM
# HαHαD
# MDMMD
# FHMFD
# DMFD
# HHMMα
# FMMMD
# MαDH
# DHMαD
# DMMD
# FMααM
# MDDMD
# FαHFF
# HHHMD
# HHMαF
# MDHMα
# FDαMD
# MMMD
# MFFDF
# FHHFF
# HαHFα
# DHFDH
# MHMMD
# αFαFM
# DHFαH
# αMαFM
# DMFH
# HHMαα
# HHMMF
# αFααα
# FαDH
# HHHFα
# HHααα
# FMDαM
# DMααM
# DHMMD
# DFFFα

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_135)):
     if sum(freq >= fTC5_135[l] for freq in fTC5null_135[l]) < 1:
#         print(setTC5_135[l], fTC5_135[l], sum(freq >= fTC5_135[l] for freq in fTC5null_135[l]))
        print(setTC5_135[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# HHMαD
# FFααα
# MFDMM
# HHMMD
# HDMMD
# HαMαα
# HαHαD
# DMMD
# FMααM
# FHHFF
