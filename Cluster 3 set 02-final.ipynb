# %% [markdown]
# # One-Letter Words

# %%
# open the csv files
AP = open('AP.csv')
AC = open('AC.csv')
BPI = open('BPI.csv')
BLOOM = open('BLOOM.csv')
FGEN = open('FGEN.csv')
ICT = open('ICT.csv')
JGS = open('JGS.csv')
MEG = open('MEG.csv')
SMC = open('SMC.csv')
SCC = open('SCC.csv')

#initiFGENze the lists
Date_AP = []
ClosePrice_AP = []
Date_AC = []
ClosePrice_AC = []
Date_BPI = []
ClosePrice_BPI = []
Date_BLOOM = []
ClosePrice_BLOOM = []
Date_FGEN = []
ClosePrice_FGEN = []
Date_ICT = []
ClosePrice_ICT = []
Date_JGS = []
ClosePrice_JGS = []
Date_MEG = []
ClosePrice_MEG = []
Date_SMC = []
ClosePrice_SMC = []
Date_SCC = []
ClosePrice_SCC = []

#skip the header line
AP.readline()
AC.readline()
BPI.readline()
BLOOM.readline()
FGEN.readline()
ICT.readline()
JGS.readline()
MEG.readline()
SMC.readline()
SCC.readline()

#go through the files line by line
for line in AP:
    sline = line.strip().split(',')
    Date_AP.append(sline[0])
    ClosePrice_AP.append(float(sline[1]))
    
for line in AC:
    sline = line.strip().split(',')
    Date_AC.append(sline[0])
    ClosePrice_AC.append(float(sline[1]))
    
for line in BPI:
    sline = line.strip().split(',')
    Date_BPI.append(sline[0])
    ClosePrice_BPI.append(float(sline[1]))
    
for line in BLOOM:
    sline = line.strip().split(',')
    Date_BLOOM.append(sline[0])
    ClosePrice_BLOOM.append(float(sline[1]))
    
for line in FGEN:
    sline = line.strip().split(',')
    Date_FGEN.append(sline[0])
    ClosePrice_FGEN.append(float(sline[1]))
    
for line in ICT:
    sline = line.strip().split(',')
    Date_ICT.append(sline[0])
    ClosePrice_ICT.append(float(sline[1]))
    
for line in JGS:
    sline = line.strip().split(',')
    Date_JGS.append(sline[0])
    ClosePrice_JGS.append(float(sline[1]))
    
for line in MEG:
    sline = line.strip().split(',')
    Date_MEG.append(sline[0])
    ClosePrice_MEG.append(float(sline[1]))
    
for line in SMC:
    sline = line.strip().split(',')
    Date_SMC.append(sline[0])
    ClosePrice_SMC.append(float(sline[1]))
        
for line in SCC:
    sline = line.strip().split(',')
    Date_SCC.append(sline[0])
    ClosePrice_SCC.append(float(sline[1]))


#close files
AP.close()
AC.close()
BPI.close()
BLOOM.close()
FGEN.close()
ICT.close()
JGS.close()
MEG.close()
SMC.close()
SCC.close()

# %%
import numpy as np
import datetime

# %%
# convert dates into datetime structure
for n in range(len(Date_AP)):
    Date_AP[n] = datetime.datetime.strptime(Date_AP[n], '%m/%d/%y').date()

for n in range(len(Date_AC)):
    Date_AC[n] = datetime.datetime.strptime(Date_AC[n], '%m/%d/%y').date()
    
for n in range(len(Date_BPI)):
    Date_BPI[n] = datetime.datetime.strptime(Date_BPI[n], '%m/%d/%y').date()

for n in range(len(Date_BLOOM)):
    Date_BLOOM[n] = datetime.datetime.strptime(Date_BLOOM[n], '%m/%d/%y').date()
    
for n in range(len(Date_FGEN)):
    Date_FGEN[n] = datetime.datetime.strptime(Date_FGEN[n], '%m/%d/%y').date()

for n in range(len(Date_ICT)):
    Date_ICT[n] = datetime.datetime.strptime(Date_ICT[n], '%m/%d/%y').date()
    
for n in range(len(Date_JGS)):
    Date_JGS[n] = datetime.datetime.strptime(Date_JGS[n], '%m/%d/%y').date()

for n in range(len(Date_MEG)):
    Date_MEG[n] = datetime.datetime.strptime(Date_MEG[n], '%m/%d/%y').date()
    
for n in range(len(Date_SMC)):
    Date_SMC[n] = datetime.datetime.strptime(Date_SMC[n], '%m/%d/%y').date()

for n in range(len(Date_SCC)):
    Date_SCC[n] = datetime.datetime.strptime(Date_SCC[n], '%m/%d/%y').date()
    
# save Date and ClosePrice
np.save('APDate.npy', Date_AP)
np.save('APClosePrice.npy', ClosePrice_AP)
np.save('ACDate.npy', Date_AC)
np.save('ACClosePrice.npy', ClosePrice_AC)
np.save('BPIDate.npy', Date_BPI)
np.save('BPIClosePrice.npy', ClosePrice_BPI)
np.save('BLOOMDate.npy', Date_BLOOM)
np.save('BLOOMClosePrice.npy', ClosePrice_BLOOM)
np.save('FGENDate.npy', Date_FGEN)
np.save('FGENClosePrice.npy', ClosePrice_FGEN)
np.save('ICTDate.npy', Date_ICT)
np.save('ICTClosePrice.npy', ClosePrice_ICT)
np.save('JGSDate.npy', Date_JGS)
np.save('JGSClosePrice.npy', ClosePrice_JGS)
np.save('MEGDate.npy', Date_MEG)
np.save('MEGClosePrice.npy', ClosePrice_MEG)
np.save('SMCDate.npy', Date_SMC)
np.save('SMCClosePrice.npy', ClosePrice_SMC)
np.save('SCCDate.npy', Date_SCC)
np.save('SCCClosePrice.npy', ClosePrice_SCC)

# %% [markdown]
# # Five-letter Words

# %% [markdown]
# # 3.16 (B) AP - (D) AC - (F) BPI - (N) JGS - (R) MEG

# %%
#extract overlapping dates
start_16 = max(min(Date_AP), min(Date_AC), min(Date_BPI), min(Date_JGS), min(Date_MEG))
end_16 = min(max(Date_AP), max(Date_AC), max(Date_BPI), max(Date_JGS), max(Date_MEG))

# %%
#shorten the closing prices
AP_16_1 = Date_AP.index(start_16)
AP_16_2 = Date_AP.index(end_16)

AC_16_1 = Date_AC.index(start_16)
AC_16_2 = Date_AC.index(end_16)

BPI_16_1 = Date_BPI.index(start_16)
BPI_16_2 = Date_BPI.index(end_16)

JGS_16_1 = Date_JGS.index(start_16)
JGS_16_2 = Date_JGS.index(end_16)

MEG_16_1 = Date_MEG.index(start_16)
MEG_16_2 = Date_MEG.index(end_16)

# %%
#save the shortened versions of closing prices
B16 = np.save('APshortPrices.npy', ClosePrice_AP[AP_16_1:AP_16_2])
D16 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_16_1:AC_16_2])
F16 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_16_1:BPI_16_2])
N16 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_16_1:JGS_16_2])
R16 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_16_1:MEG_16_2])

# %%
# import modules
import numpy as np
# import prices

B16 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D16 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F16 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
N16 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R16 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_16 = []
st_16 = []
n = 1
while n < len(B16):
    sc_16 = ''
    if B16[n] > B16[n-1]:
        sc_16 = sc_16 + 'B'
    if D16[n] > D16[n-1]:
        sc_16 = sc_16 + 'D'
    if F16[n] > F16[n-1]:
        sc_16 = sc_16 + 'F'
    if N16[n] > N16[n-1]:
        sc_16 = sc_16 + 'N'
    if R16[n] > R16[n-1]:
        sc_16 = sc_16 + 'α'
    if len(sc_16) > 0:
        st_16.append(sc_16)
    else:
        STC_16.append(st_16)
        st_16 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_16 = STC_16.count([])
# keep only non-empty spatio-temporal sequences
STC_16 = [ st_16 for st_16 in STC_16 if len(st_16) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_16 = len(B16)
lmax_16 = 0
for st_16 in STC_16:
    if len(st_16) < lmin_16:
        lmin_16 = len(st_16)
    if len(st_16) > lmax_16:
        lmax_16 = len(st_16)
        
# restrict spatio-temporal sequences to length-5
STC5_16 = [ st_16 for st_16 in STC_16 if len(st_16) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_16 = []
for n in range(len(STC5_16)):
    tc_16 = [ u for u in STC5_16[n][0] ]
    for k in range(1, len(STC5_16[n])):
        tc_16 = [ u+v for u in tc_16 for v in STC5_16[n][k] ]
    TC5_16 = TC5_16 + tc_16
setTC5_16 = list(set(TC5_16))

# get empirical frequencies
fTC5_16 = [ TC5_16.count(setTC5_16[l]) for l in range(len(setTC5_16)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_16 = [ [] for l in range(len(setTC5_16)) ]
for s in range(100):
    STC5null_16 = [ list(st_16) for st_16 in STC5_16]
    for st_16 in STC5null_16:
        np.random.shuffle(st_16)
    TC5null_16= []
    for n in range(len(STC5null_16)):
        tc_16 = [ u for u in STC5null_16[n][0] ]
        for k in range(1, len(STC5null_16[n])):
            tc_16 = [ u+v for u in tc_16 for v in STC5null_16[n][k] ]
        TC5null_16= TC5null_16+ tc_16
    for l in range(len(setTC5_16)):
        if TC5null_16.count(setTC5_16[l]) > 0:
            fTC5null_16[l].append(TC5null_16.count(setTC5_16[l]))
        else:
            fTC5null_16[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_16)):
     if sum(freq >= fTC5_16[l] for freq in fTC5null_16[l]) < 5:
        print(setTC5_16[l], fTC5_16[l], sum(freq >= fTC5_16[l] for freq in fTC5null_16[l]))
#         print(setTC5_16[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# BαDDB
# DBFFF
# αNFBα
# αBBB
# FDDαB
# ααFB
# DαN
# DααNα
# BαNαB
# αDDDB
# DαNNα
# NαND
# FαFαF
# αNDBD
# BDDDB
# FNNDF
# FαDDB
# αNDBB
# αNFN
# BNDDD
# αFDBD
# DDDαB
# FBBNN
# BNDBB
# αDDαB
# BNDαD
# DDNαB
# BNDαB
# FNDDN
# ααDNα
# FαDDD
# BNDDB
# FαDαD
# NBFFF
# NαFNα
# BBFαD
# FNFDN
# NBFBD
# DNF
# FαBNα
# FαDαB
# NαNNN
# ααBB
# αααB
# NBFB
# αNDDD
# FαDNα
# NαFB
# αDFFB
# FαNDD
# αDFBB
# NDDN
# DDDB
# DαF
# αDDBB
# DBDDα
# ααDB
# αNFBB
# FBFB
# BDNαB
# BDFαB
# FαNαD
# αDNαB
# FNFDF
# ααFαF
# ααND
# FBBB
# DNN
# FαNND
# NDDB
# αDFαF
# DNDNα
# DαDNα
# NαBB
# FNDDD
# αDFαB
# αBαB
# αDDFB
# BDDαB
# NBFN
# FαNNα
# ααNB
# BDFBB
# FαDDN
# αDBBB
# FNNDD
# NFFBD
# FNFDD
# αFDBB
# αNDBα
# ααFD
# DDFαB
# NαDNα
# NNFN
# FααNα
# αDFDB
# αDNBB
# NFFNα
# DαDαB
# NFDBα
# BBNαB

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_16)):
     if sum(freq >= fTC5_16[l] for freq in fTC5null_16[l]) < 1:
        print(setTC5_16[l], fTC5_16[l], sum(freq >= fTC5_16[l] for freq in fTC5null_16[l]))
#         print(setTC5_16[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# BαNαB
# αNDBB
# DDDαB
# αDDαB
# FNDDN
# FαDαD
# FαDαB
# ααBB
# NBFB
# FαDNα
# αDFFB
# αDFBB
# DαF
# αNFBB
# FBFB
# FNFDF
# DNN
# αDFαB
# NNFN

# %% [markdown]
# # 3.17 (B) AP - (D) AC - (F) BPI - (N) JGS - (Y) SMC

# %%
#extract overlapping dates
start_17 = max(min(Date_AP), min(Date_AC), min(Date_BPI), min(Date_JGS), min(Date_SMC))
end_17 = min(max(Date_AP), max(Date_AC), max(Date_BPI), max(Date_JGS), max(Date_SMC))

# %%
#shorten the closing prices
AP_17_1 = Date_AP.index(start_17)
AP_17_2 = Date_AP.index(end_17)

AC_17_1 = Date_AC.index(start_17)
AC_17_2 = Date_AC.index(end_17)

BPI_17_1 = Date_BPI.index(start_17)
BPI_17_2 = Date_BPI.index(end_17)

JGS_17_1 = Date_JGS.index(start_17)
JGS_17_2 = Date_JGS.index(end_17)

SMC_17_1 = Date_SMC.index(start_17)
SMC_17_2 = Date_SMC.index(end_17)

# %%
#save the shortened versions of closing prices
B17 = np.save('APshortPrices.npy', ClosePrice_AP[AP_17_1:AP_17_2])
D17 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_17_1:AC_17_2])
F17 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_17_1:BPI_17_2])
N17 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_17_1:JGS_17_2])
Y17 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_17_1:SMC_17_2])

# %%
# import modules
import numpy as np
# import prices

B17 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D17 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F17 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
N17 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y17 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_17 = []
st_17 = []
n = 1
while n < len(B17):
    sc_17 = ''
    if B17[n] > B17[n-1]:
        sc_17 = sc_17 + 'B'
    if D17[n] > D17[n-1]:
        sc_17 = sc_17 + 'D'
    if F17[n] > F17[n-1]:
        sc_17 = sc_17 + 'F'
    if N17[n] > N17[n-1]:
        sc_17 = sc_17 + 'N'
    if Y17[n] > Y17[n-1]:
        sc_17 = sc_17 + 'Y'
    if len(sc_17) > 0:
        st_17.append(sc_17)
    else:
        STC_17.append(st_17)
        st_17 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_17 = STC_17.count([])
# keep only non-empty spatio-temporal sequences
STC_17 = [ st_17 for st_17 in STC_17 if len(st_17) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_17 = len(B17)
lmax_17 = 0
for st_17 in STC_17:
    if len(st_17) < lmin_17:
        lmin_17 = len(st_17)
    if len(st_17) > lmax_17:
        lmax_17 = len(st_17)
        
# restrict spatio-temporal sequences to length-5
STC5_17 = [ st_17 for st_17 in STC_17 if len(st_17) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_17 = []
for n in range(len(STC5_17)):
    tc_17 = [ u for u in STC5_17[n][0] ]
    for k in range(1, len(STC5_17[n])):
        tc_17 = [ u+v for u in tc_17 for v in STC5_17[n][k] ]
    TC5_17 = TC5_17 + tc_17
setTC5_17 = list(set(TC5_17))

# get empirical frequencies
fTC5_17 = [ TC5_17.count(setTC5_17[l]) for l in range(len(setTC5_17)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_17 = [ [] for l in range(len(setTC5_17)) ]
for s in range(100):
    STC5null_17 = [ list(st_17) for st_17 in STC5_17]
    for st_17 in STC5null_17:
        np.random.shuffle(st_17)
    TC5null_17= []
    for n in range(len(STC5null_17)):
        tc_17 = [ u for u in STC5null_17[n][0] ]
        for k in range(1, len(STC5null_17[n])):
            tc_17 = [ u+v for u in tc_17 for v in STC5null_17[n][k] ]
        TC5null_17= TC5null_17+ tc_17
    for l in range(len(setTC5_17)):
        if TC5null_17.count(setTC5_17[l]) > 0:
            fTC5null_17[l].append(TC5null_17.count(setTC5_17[l]))
        else:
            fTC5null_17[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_17)):
     if sum(freq >= fTC5_17[l] for freq in fTC5null_17[l]) < 5:
        print(setTC5_17[l], fTC5_17[l], sum(freq >= fTC5_17[l] for freq in fTC5null_17[l]))
#         print(setTC5_17[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FBYNF
# NFBND
# FNBNB
# YYDB
# FFFFB
# DYNDB
# NFFNN
# FFBFB
# NYFN
# NFFND
# DBBB
# DNNDY
# FYFB
# DDDFB
# FFFNF
# NYFNN
# YYBYN
# FBYN
# DYBB
# DNNDB
# BDDDB
# FYDN
# NFFYD
# FYBNB
# NBYN
# DFDND
# YNBNB
# FDYFB
# NFDND
# DYDB
# NBNN
# DFDB
# FYYY
# BFYBD
# FFBDB
# YYFNN
# YBFNN
# FYFN
# FYNNB
# NYDNN
# YYDN
# DYBDN
# DNF
# YYDNN
# FDNNB
# NBFB
# NYFYB
# NBFYN
# FNNNB
# DYBNN
# DYYY
# DDDB
# YFBDB
# FFBNB
# FBFB
# DYYDY
# NYBNN
# DYNDY
# NYBB
# NYDB
# DNYDB
# DNN
# DNY
# YYBB
# NDDB
# YFFYN
# FFFND
# YYBNB
# DYNYB
# DDF
# NFDNN
# DBDB
# BBYBN
# FYBB
# FYNYB
# BFYBN
# DYDNN
# FYNY
# FYFY
# DFFND
# YYBDB
# FYYB
# DFBND
# FYYN
# NYDN
# NFDBD
# NFFBD
# BNN
# FFFNB
# FYBNN
# NFFYN
# FYBY
# YBFYN
# NFNNN
# FYDNB
# FFBND
# YYBNN
# NYFB
# FYDB

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_17)):
     if sum(freq >= fTC5_17[l] for freq in fTC5null_17[l]) < 1:
        print(setTC5_17[l], fTC5_17[l], sum(freq >= fTC5_17[l] for freq in fTC5null_17[l]))
#         print(setTC5_17[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# FNBNB
# NFFNN
# NFFND
# FYFB
# FFFNF
# FBYN
# DYBB
# FYBNB
# NFDND
# DYDB
# FYYY
# BFYBD
# NYDNN
# NBFYN
# DDDB
# YFBDB
# FFBNB
# FBFB
# NYBB
# NYDB
# DNY
# NDDB
# FFFND
# FYBB
# FYBNN
# NFFYN
# FFBND
# YYBNN
# NYFB
# FYDB

# %% [markdown]
# # 3.18 (B) AP - (D) AC - (F) BPI - (N) JGS - (α) SCC

# %%
#extract overlapping dates
start_18 = max(min(Date_AP), min(Date_AC), min(Date_BPI), min(Date_JGS), min(Date_SCC))
end_18 = min(max(Date_AP), max(Date_AC), max(Date_BPI), max(Date_JGS), max(Date_SCC))

# %%
#shorten the closing prices
AP_18_1 = Date_AP.index(start_18)
AP_18_2 = Date_AP.index(end_18)

AC_18_1 = Date_AC.index(start_18)
AC_18_2 = Date_AC.index(end_18)

BPI_18_1 = Date_BPI.index(start_18)
BPI_18_2 = Date_BPI.index(end_18)

JGS_18_1 = Date_JGS.index(start_18)
JGS_18_2 = Date_JGS.index(end_18)

SCC_18_1 = Date_SCC.index(start_18)
SCC_18_2 = Date_SCC.index(end_18)

# %%
#save the shortened versions of closing prices
B18 = np.save('APshortPrices.npy', ClosePrice_AP[AP_18_1:AP_18_2])
D18 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_18_1:AC_18_2])
F18 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_18_1:BPI_18_2])
N18 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_18_1:JGS_18_2])
α18 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_18_1:SCC_18_2])

# %%
# import modules
import numpy as np
# import prices

B18 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D18 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F18 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
N18 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
α18 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_18 = []
st_18 = []
n = 1
while n < len(B18):
    sc_18 = ''
    if B18[n] > B18[n-1]:
        sc_18 = sc_18 + 'B'
    if D18[n] > D18[n-1]:
        sc_18 = sc_18 + 'D'
    if F18[n] > F18[n-1]:
        sc_18 = sc_18 + 'F'
    if N18[n] > N18[n-1]:
        sc_18 = sc_18 + 'N'
    if α18[n] > α18[n-1]:
        sc_18 = sc_18 + 'α'
    if len(sc_18) > 0:
        st_18.append(sc_18)
    else:
        STC_18.append(st_18)
        st_18 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_18 = STC_18.count([])
# keep only non-empty spatio-temporal sequences
STC_18 = [ st_18 for st_18 in STC_18 if len(st_18) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_18 = len(B18)
lmax_18 = 0
for st_18 in STC_18:
    if len(st_18) < lmin_18:
        lmin_18 = len(st_18)
    if len(st_18) > lmax_18:
        lmax_18 = len(st_18)
        
# restrict spatio-temporal sequences to length-5
STC5_18 = [ st_18 for st_18 in STC_18 if len(st_18) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_18 = []
for n in range(len(STC5_18)):
    tc_18 = [ u for u in STC5_18[n][0] ]
    for k in range(1, len(STC5_18[n])):
        tc_18 = [ u+v for u in tc_18 for v in STC5_18[n][k] ]
    TC5_18 = TC5_18 + tc_18
setTC5_18 = list(set(TC5_18))

# get empirical frequencies
fTC5_18 = [ TC5_18.count(setTC5_18[l]) for l in range(len(setTC5_18)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_18 = [ [] for l in range(len(setTC5_18)) ]
for s in range(100):
    STC5null_18 = [ list(st_18) for st_18 in STC5_18]
    for st_18 in STC5null_18:
        np.random.shuffle(st_18)
    TC5null_18= []
    for n in range(len(STC5null_18)):
        tc_18 = [ u for u in STC5null_18[n][0] ]
        for k in range(1, len(STC5null_18[n])):
            tc_18 = [ u+v for u in tc_18 for v in STC5null_18[n][k] ]
        TC5null_18= TC5null_18+ tc_18
    for l in range(len(setTC5_18)):
        if TC5null_18.count(setTC5_18[l]) > 0:
            fTC5null_18[l].append(TC5null_18.count(setTC5_18[l]))
        else:
            fTC5null_18[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_18)):
     if sum(freq >= fTC5_18[l] for freq in fTC5null_18[l]) < 5:
        print(setTC5_18[l], fTC5_18[l], sum(freq >= fTC5_18[l] for freq in fTC5null_18[l]))
#         print(setTC5_18[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# BNαDB
# αBBB
# ααDα
# DBBB
# FBNαα
# FBFN
# NBααα
# DBααα
# FFNBα
# DDDFB
# BDαDB
# DBNB
# FFNBN
# FBFBN
# BNαDF
# FFFFN
# NNFDα
# BDDDB
# FNNDF
# DDFBα
# BNDDD
# FFBα
# FFBD
# NFααα
# DDαNB
# BNDDB
# FFFBN
# DαNB
# FαDα
# DBFN
# αFNBα
# DBND
# FαBα
# DFND
# FDNNB
# NBFB
# ααNα
# FFNBD
# NDDN
# DDDB
# BNNDB
# FBFB
# FDDB
# DFNBα
# FNFDF
# DNN
# NDDB
# NBFBN
# BDααB
# Bα
# DBDB
# DFN
# NBFαα
# FFααα
# FFNNα
# BDDαB
# FBDαα
# BDBBB
# FBDB
# NBFN
# NBDN
# FFDBD
# FBFαD
# FαNα
# FBααα
# αDDB
# ααNB
# NαNα
# DDNFB
# FNNDD
# FBBαα
# BNαDD
# BNN
# FNFDD
# αBBN
# NFαNα
# NBαBα
# BNαFB
# FDαDB
# NBBN
# FFDBN
# αDDα
# FFDDB

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_18)):
     if sum(freq >= fTC5_18[l] for freq in fTC5null_18[l]) < 1:
        print(setTC5_18[l], fTC5_18[l], sum(freq >= fTC5_18[l] for freq in fTC5null_18[l]))
#         print(setTC5_18[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# BNαDB
# αBBB
# DBBB
# BDαDB
# NBFB
# DNN
# DBDB
# NBFN
# NBDN
# NBBN

# %% [markdown]
# # 3.19 (B) AP - (D) AC - (F) BPI - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_19 = max(min(Date_AP), min(Date_AC), min(Date_BPI), min(Date_MEG), min(Date_SMC))
end_19 = min(max(Date_AP), max(Date_AC), max(Date_BPI), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
AP_19_1 = Date_AP.index(start_19)
AP_19_2 = Date_AP.index(end_19)

AC_19_1 = Date_AC.index(start_19)
AC_19_2 = Date_AC.index(end_19)

BPI_19_1 = Date_BPI.index(start_19)
BPI_19_2 = Date_BPI.index(end_19)

MEG_19_1 = Date_MEG.index(start_19)
MEG_19_2 = Date_MEG.index(end_19)

SMC_19_1 = Date_SMC.index(start_19)
SMC_19_2 = Date_SMC.index(end_19)

# %%
#save the shortened versions of closing prices
B19 = np.save('APshortPrices.npy', ClosePrice_AP[AP_19_1:AP_19_2])
D19 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_19_1:AC_19_2])
F19 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_19_1:BPI_19_2])
R19 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_19_1:MEG_19_2])
Y19 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_19_1:SMC_19_2])

# %%
# import modules
import numpy as np
# import prices

B19 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D19 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F19 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
R19 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y19 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_19 = []
st_19 = []
n = 1
while n < len(B19):
    sc_19 = ''
    if B19[n] > B19[n-1]:
        sc_19 = sc_19 + 'B'
    if D19[n] > D19[n-1]:
        sc_19 = sc_19 + 'D'
    if F19[n] > F19[n-1]:
        sc_19 = sc_19 + 'F'
    if R19[n] > R19[n-1]:
        sc_19 = sc_19 + 'R'
    if Y19[n] > Y19[n-1]:
        sc_19 = sc_19 + 'Y'
    if len(sc_19) > 0:
        st_19.append(sc_19)
    else:
        STC_19.append(st_19)
        st_19 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_19 = STC_19.count([])
# keep only non-empty spatio-temporal sequences
STC_19 = [ st_19 for st_19 in STC_19 if len(st_19) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_19 = len(B19)
lmax_19 = 0
for st_19 in STC_19:
    if len(st_19) < lmin_19:
        lmin_19 = len(st_19)
    if len(st_19) > lmax_19:
        lmax_19 = len(st_19)
        
# restrict spatio-temporal sequences to length-5
STC5_19 = [ st_19 for st_19 in STC_19 if len(st_19) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_19 = []
for n in range(len(STC5_19)):
    tc_19 = [ u for u in STC5_19[n][0] ]
    for k in range(1, len(STC5_19[n])):
        tc_19 = [ u+v for u in tc_19 for v in STC5_19[n][k] ]
    TC5_19 = TC5_19 + tc_19
setTC5_19 = list(set(TC5_19))

# get empirical frequencies
fTC5_19 = [ TC5_19.count(setTC5_19[l]) for l in range(len(setTC5_19)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_19 = [ [] for l in range(len(setTC5_19)) ]
for s in range(100):
    STC5null_19 = [ list(st_19) for st_19 in STC5_19]
    for st_19 in STC5null_19:
        np.random.shuffle(st_19)
    TC5null_19= []
    for n in range(len(STC5null_19)):
        tc_19 = [ u for u in STC5null_19[n][0] ]
        for k in range(1, len(STC5null_19[n])):
            tc_19 = [ u+v for u in tc_19 for v in STC5null_19[n][k] ]
        TC5null_19= TC5null_19+ tc_19
    for l in range(len(setTC5_19)):
        if TC5null_19.count(setTC5_19[l]) > 0:
            fTC5null_19[l].append(TC5null_19.count(setTC5_19[l]))
        else:
            fTC5null_19[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_19)):
     if sum(freq >= fTC5_19[l] for freq in fTC5null_19[l]) < 5:
        print(setTC5_19[l], fTC5_19[l], sum(freq >= fTC5_19[l] for freq in fTC5null_19[l]))
#         print(setTC5_19[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# YFFDF
# FDDRB
# RRDB
# YFDDD
# YRBFF
# RDDDF
# YRFD
# FRDB
# RDYFB
# YFBBY
# FDBB
# FYFB
# BFFRF
# BR
# RYRB
# DDDFB
# RDDRB
# YYFFF
# DDYFB
# BDDDF
# YYFFY
# BDDDB
# RFFRD
# FBRB
# YDDB
# YRDDR
# RFFFB
# RRBB
# FDYFB
# BFDDD
# RYBY
# YRBB
# RDFRF
# BBYDF
# RFDDD
# FDBR
# FRFB
# YYYDR
# BRBBR
# FYYY
# RFFDD
# YYBFY
# BDDFB
# YDDDF
# YFFFF
# DDYFF
# RFFFD
# RFFDF
# FRBB
# YFFDY
# YFRDY
# RYRR
# YRFRR
# DYYY
# FBFB
# FDDB
# RDYDB
# YYFDR
# DBF
# YFDRD
# DDYRB
# RFDFD
# RDDRF
# RDYRB
# RFFBD
# YRFFF
# RFFRF
# YFDDY
# FYRB
# FYBB
# RDFRB
# YFDRY
# RDDDB
# YRBDB
# RFDBD
# FBDB
# BDFRB
# FDYB
# BDDRB
# YFDFF
# FYYB
# DBYFF
# RDYRF
# RDFFB
# YFFRF
# FYBY
# YYBDR
# BBYRF
# DDDRB
# DRF
# YRDDF
# RDYFF
# YDBB
# RDDFB
# YRBD
# FYDB
# RYBB
# RYDB
# RDFDF
# RDFFF

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_19)):
     if sum(freq >= fTC5_19[l] for freq in fTC5null_19[l]) < 1:
        print(setTC5_19[l], fTC5_19[l], sum(freq >= fTC5_19[l] for freq in fTC5null_19[l]))
#         print(setTC5_19[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# RRDB
# RDYFB
# FYFB
# YRBB
# RDFRF
# RFFDD
# BDDFB
# FBFB
# FDDB
# RFFRF
# FYBB
# BDDRB
# FYYB
# FYDB

# %% [markdown]
# # 3.20 (B) AP - (D) AC - (F) BPI - (R) MEG - (α) SCC

# %%
#extract overlapping dates
start_20 = max(min(Date_AP), min(Date_AC), min(Date_BPI), min(Date_MEG), min(Date_SCC))
end_20 = min(max(Date_AP), max(Date_AC), max(Date_BPI), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
AP_20_1 = Date_AP.index(start_20)
AP_20_2 = Date_AP.index(end_20)

AC_20_1 = Date_AC.index(start_20)
AC_20_2 = Date_AC.index(end_20)

BPI_20_1 = Date_BPI.index(start_20)
BPI_20_2 = Date_BPI.index(end_20)

MEG_20_1 = Date_MEG.index(start_20)
MEG_20_2 = Date_MEG.index(end_20)

SCC_20_1 = Date_SCC.index(start_20)
SCC_20_2 = Date_SCC.index(end_20)

# %%
#save the shortened versions of closing prices
B20 = np.save('APshortPrices.npy', ClosePrice_AP[AP_20_1:AP_20_2])
D20 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_20_1:AC_20_2])
F20 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_20_1:BPI_20_2])
R20 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_20_1:MEG_20_2])
α20 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_20_1:SCC_20_2])

# %%
# import modules
import numpy as np
# import prices

B20 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D20 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F20 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
R20 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α20 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_20 = []
st_20 = []
n = 1
while n < len(B20):
    sc_20 = ''
    if B20[n] > B20[n-1]:
        sc_20 = sc_20 + 'B'
    if D20[n] > D20[n-1]:
        sc_20 = sc_20 + 'D'
    if F20[n] > F20[n-1]:
        sc_20 = sc_20 + 'F'
    if R20[n] > R20[n-1]:
        sc_20 = sc_20 + 'R'
    if α20[n] > α20[n-1]:
        sc_20 = sc_20 + 'α'
    if len(sc_20) > 0:
        st_20.append(sc_20)
    else:
        STC_20.append(st_20)
        st_20 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_20 = STC_20.count([])
# keep only non-empty spatio-temporal sequences
STC_20 = [ st_20 for st_20 in STC_20 if len(st_20) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_20 = len(B20)
lmax_20 = 0
for st_20 in STC_20:
    if len(st_20) < lmin_20:
        lmin_20 = len(st_20)
    if len(st_20) > lmax_20:
        lmax_20 = len(st_20)
        
# restrict spatio-temporal sequences to length-5
STC5_20 = [ st_20 for st_20 in STC_20 if len(st_20) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_20 = []
for n in range(len(STC5_20)):
    tc_20 = [ u for u in STC5_20[n][0] ]
    for k in range(1, len(STC5_20[n])):
        tc_20 = [ u+v for u in tc_20 for v in STC5_20[n][k] ]
    TC5_20 = TC5_20 + tc_20
setTC5_20 = list(set(TC5_20))

# get empirical frequencies
fTC5_20 = [ TC5_20.count(setTC5_20[l]) for l in range(len(setTC5_20)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_20 = [ [] for l in range(len(setTC5_20)) ]
for s in range(100):
    STC5null_20 = [ list(st_20) for st_20 in STC5_20]
    for st_20 in STC5null_20:
        np.random.shuffle(st_20)
    TC5null_20= []
    for n in range(len(STC5null_20)):
        tc_20 = [ u for u in STC5null_20[n][0] ]
        for k in range(1, len(STC5null_20[n])):
            tc_20 = [ u+v for u in tc_20 for v in STC5null_20[n][k] ]
        TC5null_20= TC5null_20+ tc_20
    for l in range(len(setTC5_20)):
        if TC5null_20.count(setTC5_20[l]) > 0:
            fTC5null_20[l].append(TC5null_20.count(setTC5_20[l]))
        else:
            fTC5null_20[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_20)):
     if sum(freq >= fTC5_20[l] for freq in fTC5null_20[l]) < 5:
        print(setTC5_20[l], fTC5_20[l], sum(freq >= fTC5_20[l] for freq in fTC5null_20[l]))
#         print(setTC5_20[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FDDF
# BRαRα
# αFDBα
# RRDB
# RDFαB
# FDDα
# DBFRF
# αBBB
# FFFRF
# αBFRF
# RRαDα
# αDDR
# ααRB
# ααFRD
# αDαBα
# BBFRF
# DDαDB
# RαFRB
# RBFRF
# ααFRB
# FRFRD
# RDDRB
# FBFBD
# FRαα
# FαFDD
# ααBR
# FBRB
# RDαRB
# BBFαF
# RDBαα
# RRBB
# αRFB
# αDBB
# αDDBα
# RDFRF
# BRDDD
# αFDBD
# FRFB
# DBFRD
# ααFR
# αDDαB
# DRαRB
# RααRB
# DRDRB
# RDFBB
# αDRR
# αDααB
# FRFDα
# RDDαα
# DDFRF
# αDαRB
# ααBB
# αDRB
# FDDRF
# FRBα
# ααRR
# αDDBB
# ααDB
# RDDBB
# αRαRD
# FBFB
# RDααα
# FDDB
# FRDRD
# BDαRB
# αDBR
# RFDBα
# RFDBB
# FDFRF
# FDα
# αBFRD
# RFααα
# BDααB
# FBDF
# RFDαα
# FRDRB
# BBFRD
# RRαRα
# αRαRB
# DDαRB
# ααFFB
# αBRR
# RRFDα
# RDFRB
# αααRB
# BDDαB
# DDFRB
# FRBBR
# RRFB
# FBDB
# αDαBB
# αBFB
# RRαFα
# RDFαα
# DBRB
# FDDBα
# αDDB
# BBFDF
# RFαBα
# Rα
# RRF
# FRDαR
# αDFR
# FRFRF
# RDFFB
# αFDBB
# αRRRB
# BRDDB
# RRD
# DDDRB
# αBRB
# αDFRD
# FRαRB
# αBFDD
# RDDFB
# αFαBα
# αDDα

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_20)):
     if sum(freq >= fTC5_20[l] for freq in fTC5null_20[l]) < 1:
        print(setTC5_20[l], fTC5_20[l], sum(freq >= fTC5_20[l] for freq in fTC5null_20[l]))
#         print(setTC5_20[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# FDDF
# αBFRF
# RRαDα
# αDDR
# BBFRF
# RDDαα
# DDFRF
# ααBB
# FBFB
# RDααα
# αBFRD
# DDαRB
# Rα
# RRF
# αFDBB

# %% [markdown]
# # 3.21 (B) AP - (D) AC - (F) BPI - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_21 = max(min(Date_AP), min(Date_AC), min(Date_BPI), min(Date_SMC), min(Date_SCC))
end_21 = min(max(Date_AP), max(Date_AC), max(Date_BPI), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
AP_21_1 = Date_AP.index(start_21)
AP_21_2 = Date_AP.index(end_21)

AC_21_1 = Date_AC.index(start_21)
AC_21_2 = Date_AC.index(end_21)

BPI_21_1 = Date_BPI.index(start_21)
BPI_21_2 = Date_BPI.index(end_21)

SMC_21_1 = Date_SMC.index(start_21)
SMC_21_2 = Date_SMC.index(end_21)

SCC_21_1 = Date_SCC.index(start_21)
SCC_21_2 = Date_SCC.index(end_21)

# %%
#save the shortened versions of closing prices
B21 = np.save('APshortPrices.npy', ClosePrice_AP[AP_21_1:AP_21_2])
D21 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_21_1:AC_21_2])
F21 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_21_1:BPI_21_2])
Y21 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_21_1:SMC_21_2])
α21 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_21_1:SCC_21_2])

# %%
# import modules
import numpy as np
# import prices

B21 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D21 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F21 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
Y21 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α21 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_21 = []
st_21 = []
n = 1
while n < len(B21):
    sc_21 = ''
    if B21[n] > B21[n-1]:
        sc_21 = sc_21 + 'B'
    if D21[n] > D21[n-1]:
        sc_21 = sc_21 + 'D'
    if F21[n] > F21[n-1]:
        sc_21 = sc_21 + 'F'
    if Y21[n] > Y21[n-1]:
        sc_21 = sc_21 + 'R'
    if α21[n] > α21[n-1]:
        sc_21 = sc_21 + 'α'
    if len(sc_21) > 0:
        st_21.append(sc_21)
    else:
        STC_21.append(st_21)
        st_21 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_21 = STC_21.count([])
# keep only non-empty spatio-temporal sequences
STC_21 = [ st_21 for st_21 in STC_21 if len(st_21) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_21 = len(B21)
lmax_21 = 0
for st_21 in STC_21:
    if len(st_21) < lmin_21:
        lmin_21 = len(st_21)
    if len(st_21) > lmax_21:
        lmax_21 = len(st_21)
        
# restrict spatio-temporal sequences to length-5
STC5_21 = [ st_21 for st_21 in STC_21 if len(st_21) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_21 = []
for n in range(len(STC5_21)):
    tc_21 = [ u for u in STC5_21[n][0] ]
    for k in range(1, len(STC5_21[n])):
        tc_21 = [ u+v for u in tc_21 for v in STC5_21[n][k] ]
    TC5_21 = TC5_21 + tc_21
setTC5_21 = list(set(TC5_21))

# get empirical frequencies
fTC5_21 = [ TC5_21.count(setTC5_21[l]) for l in range(len(setTC5_21)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_21 = [ [] for l in range(len(setTC5_21)) ]
for s in range(100):
    STC5null_21 = [ list(st_21) for st_21 in STC5_21]
    for st_21 in STC5null_21:
        np.random.shuffle(st_21)
    TC5null_21= []
    for n in range(len(STC5null_21)):
        tc_21 = [ u for u in STC5null_21[n][0] ]
        for k in range(1, len(STC5null_21[n])):
            tc_21 = [ u+v for u in tc_21 for v in STC5null_21[n][k] ]
        TC5null_21= TC5null_21+ tc_21
    for l in range(len(setTC5_21)):
        if TC5null_21.count(setTC5_21[l]) > 0:
            fTC5null_21[l].append(TC5null_21.count(setTC5_21[l]))
        else:
            fTC5null_21[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_21)):
     if sum(freq >= fTC5_21[l] for freq in fTC5null_21[l]) < 5:
        print(setTC5_21[l], fTC5_21[l], sum(freq >= fTC5_21[l] for freq in fTC5null_21[l]))
#         print(setTC5_21[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# RRBαα
# RBBFα
# DRRR
# FRRB
# RRBBD
# αBBB
# DBBB
# ααFB
# FRDB
# FDBB
# RαFB
# RBFB
# BFRBB
# FBFBD
# FRRR
# FBRB
# DαFBD
# αDFB
# αDBB
# DDRDF
# αBFαD
# αRFBD
# FαRFB
# RBFFα
# FRFB
# RRRFα
# αFFBD
# FDαRB
# RRBDR
# DαDB
# DαFBα
# FBRαF
# FFRαD
# DBFBD
# FRBB
# ααBB
# DRRFα
# αBFBD
# FRBα
# DDDB
# ααDB
# FBFB
# FDDB
# ααFBD
# FαRαD
# RαDB
# RRBFα
# RFααα
# DDF
# FRRα
# FFααα
# RBBαα
# FαRB
# BDBBB
# FBDB
# αBFB
# FBRR
# RFFFα
# αDDB
# BFRBD
# FαFBD
# DRBB
# RRBDα
# RRFFα
# DRFFα
# FαDB
# FBRαD
# FRαRB
# BFRBF
# ααBDR
# RRFFR
# FαFB
# RFBαα
# DRFDα

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_21)):
     if sum(freq >= fTC5_21[l] for freq in fTC5null_21[l]) < 1:
        print(setTC5_21[l], fTC5_21[l], sum(freq >= fTC5_21[l] for freq in fTC5null_21[l]))
#         print(setTC5_21[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# ααFB
# FRDB
# FRRR
# DDRDF
# RRBDR
# DαDB
# FBRαF
# ααBB
# FBFB
# RαDB
# RRBFα
# αBFB
# αDDB
# FBRαD
# FαFB

# %% [markdown]
# # 3.22 (B) AP - (D) AC - (H) BLOOM - (J) FGEN - (M) ICT

# %%
#extract overlapping dates
start_22 = max(min(Date_AP), min(Date_AC), min(Date_BLOOM), min(Date_FGEN), min(Date_ICT))
end_22 = min(max(Date_AP), max(Date_AC), max(Date_BLOOM), max(Date_FGEN), max(Date_ICT))

# %%
#shorten the closing prices
AP_22_1 = Date_AP.index(start_22)
AP_22_2 = Date_AP.index(end_22)

AC_22_1 = Date_AC.index(start_22)
AC_22_2 = Date_AC.index(end_22)

BLOOM_22_1 = Date_BLOOM.index(start_22)
BLOOM_22_2 = Date_BLOOM.index(end_22)

FGEN_22_1 = Date_FGEN.index(start_22)
FGEN_22_2 = Date_FGEN.index(end_22)

ICT_22_1 = Date_ICT.index(start_22)
ICT_22_2 = Date_ICT.index(end_22)

# %%
#save the shortened versions of closing prices
B22 = np.save('APshortPrices.npy', ClosePrice_AP[AP_22_1:AP_22_2])
D22 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_22_1:AC_22_2])
H22 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_22_1:BLOOM_22_2])
J22 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_22_1:FGEN_22_2])
M22 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_22_1:ICT_22_2])

# %%
# import modules
import numpy as np
# import prices

B22 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D22 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H22 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J22 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M22 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_22 = []
st_22 = []
n = 1
while n < len(B22):
    sc_22 = ''
    if B22[n] > B22[n-1]:
        sc_22 = sc_22 + 'B'
    if D22[n] > D22[n-1]:
        sc_22 = sc_22 + 'D'
    if H22[n] > H22[n-1]:
        sc_22 = sc_22 + 'H'
    if J22[n] > J22[n-1]:
        sc_22 = sc_22 + 'J'
    if M22[n] > M22[n-1]:
        sc_22 = sc_22 + 'M'
    if len(sc_22) > 0:
        st_22.append(sc_22)
    else:
        STC_22.append(st_22)
        st_22 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_22 = STC_22.count([])
# keep only non-empty spatio-temporal sequences
STC_22 = [ st_22 for st_22 in STC_22 if len(st_22) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_22 = len(B22)
lmax_22 = 0
for st_22 in STC_22:
    if len(st_22) < lmin_22:
        lmin_22 = len(st_22)
    if len(st_22) > lmax_22:
        lmax_22 = len(st_22)
        
# restrict spatio-temporal sequences to length-5
STC5_22 = [ st_22 for st_22 in STC_22 if len(st_22) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_22 = []
for n in range(len(STC5_22)):
    tc_22 = [ u for u in STC5_22[n][0] ]
    for k in range(1, len(STC5_22[n])):
        tc_22 = [ u+v for u in tc_22 for v in STC5_22[n][k] ]
    TC5_22 = TC5_22 + tc_22
setTC5_22 = list(set(TC5_22))

# get empirical frequencies
fTC5_22 = [ TC5_22.count(setTC5_22[l]) for l in range(len(setTC5_22)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_22 = [ [] for l in range(len(setTC5_22)) ]
for s in range(100):
    STC5null_22 = [ list(st_22) for st_22 in STC5_22]
    for st_22 in STC5null_22:
        np.random.shuffle(st_22)
    TC5null_22= []
    for n in range(len(STC5null_22)):
        tc_22 = [ u for u in STC5null_22[n][0] ]
        for k in range(1, len(STC5null_22[n])):
            tc_22 = [ u+v for u in tc_22 for v in STC5null_22[n][k] ]
        TC5null_22= TC5null_22+ tc_22
    for l in range(len(setTC5_22)):
        if TC5null_22.count(setTC5_22[l]) > 0:
            fTC5null_22[l].append(TC5null_22.count(setTC5_22[l]))
        else:
            fTC5null_22[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_22)):
     if sum(freq >= fTC5_22[l] for freq in fTC5null_22[l]) < 5:
        print(setTC5_22[l], fTC5_22[l], sum(freq >= fTC5_22[l] for freq in fTC5null_22[l]))
#         print(setTC5_22[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# HBDJ
# JBMJD
# BJHHJ
# BBDBJ
# HMBJ
# BBJHJ
# BMMBM
# JDHHD
# DHBH
# MDDMB
# MDDDB
# JJBHJ
# JMBBD
# BMBBM
# BDDDB
# DMMH
# BDMBJ
# MDHMB
# JBDD
# DMBJ
# DJJDH
# JMHHM
# JDMHD
# MDHMD
# DJJMH
# HHBJD
# JDBHD
# JDHHM
# DJHHM
# DDHHM
# MDDMD
# DBDD
# HHHJ
# DJDMH
# JDHHB
# JMBBJ
# DMMBJ
# JDHBM
# BBDBH
# JMBBM
# MHHD
# JHMH
# BJHHM
# JMHBD
# JMHBM
# DMDH
# JMHHD
# JMMBM
# DBJMJ
# JMMBJ
# DBJMH
# JDBBM
# JMHBB
# HBJJ
# BJBHJ
# DHMH
# MDMBB
# JMMBD
# BBJHH
# MMJH
# JMHHB
# BJBBM
# BMMBJ
# JMHJD
# JMMBH
# BJBHM
# JDHJD
# HBBJ
# DMBH
# JDBHM
# DHDH
# DJBHM
# MDDBB
# JJD
# MDMBD
# JMHBJ
# JDBJD
# DMMBM
# MHD
# DDDH
# JDHBB

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_22)):
     if sum(freq >= fTC5_22[l] for freq in fTC5null_22[l]) < 1:
        print(setTC5_22[l], fTC5_22[l], sum(freq >= fTC5_22[l] for freq in fTC5null_22[l]))
#         print(setTC5_22[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# JDHHD
# BDDDB
# DJHHM
# JMBBM
# JMHHD
# HBJJ
# BBJHH
# DMBH
# JMHBJ

# %% [markdown]
# # 3.23 (B) AP - (D) AC - (H) BLOOM - (J) FGEN - (N) JGS

# %%
#extract overlapping dates
start_23 = max(min(Date_AP), min(Date_AC), min(Date_BLOOM), min(Date_FGEN), min(Date_JGS))
end_23 = min(max(Date_AP), max(Date_AC), max(Date_BLOOM), max(Date_FGEN), max(Date_JGS))

# %%
#shorten the closing prices
AP_23_1 = Date_AP.index(start_23)
AP_23_2 = Date_AP.index(end_23)

AC_23_1 = Date_AC.index(start_23)
AC_23_2 = Date_AC.index(end_23)

BLOOM_23_1 = Date_BLOOM.index(start_23)
BLOOM_23_2 = Date_BLOOM.index(end_23)

FGEN_23_1 = Date_FGEN.index(start_23)
FGEN_23_2 = Date_FGEN.index(end_23)

JGS_23_1 = Date_JGS.index(start_23)
JGS_23_2 = Date_JGS.index(end_23)

# %%
#save the shortened versions of closing prices
B23 = np.save('APshortPrices.npy', ClosePrice_AP[AP_23_1:AP_23_2])
D23 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_23_1:AC_23_2])
H23 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_23_1:BLOOM_23_2])
J23 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_23_1:FGEN_23_2])
N23 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_23_1:JGS_23_2])

# %%
# import modules
import numpy as np
# import prices

B23 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D23 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H23 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J23 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N23 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_23 = []
st_23 = []
n = 1
while n < len(B23):
    sc_23 = ''
    if B23[n] > B23[n-1]:
        sc_23 = sc_23 + 'B'
    if D23[n] > D23[n-1]:
        sc_23 = sc_23 + 'D'
    if H23[n] > H23[n-1]:
        sc_23 = sc_23 + 'H'
    if J23[n] > J23[n-1]:
        sc_23 = sc_23 + 'J'
    if N23[n] > N23[n-1]:
        sc_23 = sc_23 + 'N'
    if len(sc_23) > 0:
        st_23.append(sc_23)
    else:
        STC_23.append(st_23)
        st_23 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_23 = STC_23.count([])
# keep only non-empty spatio-temporal sequences
STC_23 = [ st_23 for st_23 in STC_23 if len(st_23) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_23 = len(B23)
lmax_23 = 0
for st_23 in STC_23:
    if len(st_23) < lmin_23:
        lmin_23 = len(st_23)
    if len(st_23) > lmax_23:
        lmax_23 = len(st_23)
        
# restrict spatio-temporal sequences to length-5
STC5_23 = [ st_23 for st_23 in STC_23 if len(st_23) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_23 = []
for n in range(len(STC5_23)):
    tc_23 = [ u for u in STC5_23[n][0] ]
    for k in range(1, len(STC5_23[n])):
        tc_23 = [ u+v for u in tc_23 for v in STC5_23[n][k] ]
    TC5_23 = TC5_23 + tc_23
setTC5_23 = list(set(TC5_23))

# get empirical frequencies
fTC5_23 = [ TC5_23.count(setTC5_23[l]) for l in range(len(setTC5_23)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_23 = [ [] for l in range(len(setTC5_23)) ]
for s in range(100):
    STC5null_23 = [ list(st_23) for st_23 in STC5_23]
    for st_23 in STC5null_23:
        np.random.shuffle(st_23)
    TC5null_23= []
    for n in range(len(STC5null_23)):
        tc_23 = [ u for u in STC5null_23[n][0] ]
        for k in range(1, len(STC5null_23[n])):
            tc_23 = [ u+v for u in tc_23 for v in STC5null_23[n][k] ]
        TC5null_23= TC5null_23+ tc_23
    for l in range(len(setTC5_23)):
        if TC5null_23.count(setTC5_23[l]) > 0:
            fTC5null_23[l].append(TC5null_23.count(setTC5_23[l]))
        else:
            fTC5null_23[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_23)):
     if sum(freq >= fTC5_23[l] for freq in fTC5null_23[l]) < 5:
        print(setTC5_23[l], fTC5_23[l], sum(freq >= fTC5_23[l] for freq in fTC5null_23[l]))
#         print(setTC5_23[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# BJDDB
# DBDDN
# DNNDH
# JJDJN
# NJJHJ
# HJJHH
# BJB
# HHDNB
# DHHHH
# NJJDH
# JJB
# BBNH
# DHJNH
# NNNDH
# NJBNH
# NDBJD
# NNDN
# NNNBH
# NBDDJ
# DJDHB
# DJBNB
# DNJNH
# BJJDB
# BDDDB
# BJJDH
# NDJJJ
# DHNH
# DJJHJ
# DBNDH
# NBNDN
# HJDBH
# DJNHH
# DJDDH
# DDNH
# DNDDH
# NJNNH
# HHDBJ
# DJJDH
# HHHNB
# JHHJ
# DBDDJ
# DJDNH
# HHDNJ
# DNDBH
# JBJN
# DJJDB
# HJBBB
# NJJNJ
# DBDDH
# JBDN
# NNNBJ
# DJDHH
# HJDBB
# JBDDN
# HNDDH
# NHJNH
# DDDN
# NJDHJ
# DJJHH
# DDDDH
# NJDNH
# JDDN
# DDDJ
# DBNH
# NJBBB
# DJNDH
# DDDB
# DDBH
# JBBN
# HNJHH
# NJBNB
# NHBHD
# NJDBH
# JDDJ
# DBJNH
# HNDBH
# BJDHJ
# JHJJ
# HJDNH
# DHHBH
# DJJHD
# BBDDB
# DBJDH
# HNDBB
# DJDBH
# NNDBH
# NJNDH
# NBJNH
# DHDNB
# NDBJJ
# DJBBH
# DJNNH
# JHDN
# NBDN
# DHHNB
# NHBJD
# HHDBH
# HHHNH
# NJJBH
# NJJNH
# DBJHH
# DJBBB
# DJJNH
# HJBNB
# HHDBB
# JJD
# BJJNH
# DNBJ
# NHHNH
# HNBBB
# BJBBB
# JDDH
# NJDHD
# NJJHH
# NNJNH
# DJDHJ
# DNJHH
# NJBBH
# BJJHH
# DDDH
# DHHNH
# ...

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_23)):
    if sum(freq >= fTC5_23[l] for freq in fTC5null_23[l]) < 1:
        print(setTC5_23[l], fTC5_23[l], sum(freq >= fTC5_23[l] for freq in fTC5null_23[l]))
#         print(setTC5_23[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# DBDDN
# DHHHH
# NJJDH
# DBNDH
# DJDDH
# DJJDH
# DJDNH
# HJBBB
# JBDN
# DJDHH
# DDDN
# NJDHJ
# DJJHH
# NJDNH
# DDDB
# NDBJJ
# DHHNB
# NJJNH
# DJJNH
# NJJHH
# DJDHJ
# DDDH
# DHHNH

# %% [markdown]
# # 3.24 (B) AP - (D) AC - (H) BLOOM - (J) FGEN - (R) MEG

# %%
#extract overlapping dates
start_24 = max(min(Date_AP), min(Date_AC), min(Date_BLOOM), min(Date_FGEN), min(Date_MEG))
end_24 = min(max(Date_AP), max(Date_AC), max(Date_BLOOM), max(Date_FGEN), max(Date_MEG))

# %%
#shorten the closing prices
AP_24_1 = Date_AP.index(start_24)
AP_24_2 = Date_AP.index(end_24)

AC_24_1 = Date_AC.index(start_24)
AC_24_2 = Date_AC.index(end_24)

BLOOM_24_1 = Date_BLOOM.index(start_24)
BLOOM_24_2 = Date_BLOOM.index(end_24)

FGEN_24_1 = Date_FGEN.index(start_24)
FGEN_24_2 = Date_FGEN.index(end_24)

MEG_24_1 = Date_MEG.index(start_24)
MEG_24_2 = Date_MEG.index(end_24)

# %%
#save the shortened versions of closing prices
B24 = np.save('APshortPrices.npy', ClosePrice_AP[AP_24_1:AP_24_2])
D24 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_24_1:AC_24_2])
H24 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_24_1:BLOOM_24_2])
J24 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_24_1:FGEN_24_2])
R24 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_24_1:MEG_24_2])

# %%
# import modules
import numpy as np
# import prices

B24 = np.load('APshortPrices.npy').tolist() 
D24 = np.load('ACshortPrices.npy').tolist() 
H24 = np.load('BLOOMshortPrices.npy').tolist() 
J24 = np.load('FGENshortPrices.npy').tolist() 
R24 = np.load('MEGshortPrices.npy').tolist()

# %%
# extract spatio-temporal sequences
STC_24 = []
st_24 = []
n = 1
while n < len(B24):
    sc_24 = ''
    if B24[n] > B24[n-1]:
        sc_24 = sc_24 + 'B'
    if D24[n] > D24[n-1]:
        sc_24 = sc_24 + 'D'
    if H24[n] > H24[n-1]:
        sc_24 = sc_24 + 'H'
    if J24[n] > J24[n-1]:
        sc_24 = sc_24 + 'J'
    if R24[n] > R24[n-1]:
        sc_24 = sc_24 + 'R'
    if len(sc_24) > 0:
        st_24.append(sc_24)
    else:
        STC_24.append(st_24)
        st_24 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_24 = STC_24.count([])
# keep only non-empty spatio-temporal sequences
STC_24 = [ st_24 for st_24 in STC_24 if len(st_24) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_24 = len(B24)
lmax_24 = 0
for st_24 in STC_24:
    if len(st_24) < lmin_24:
        lmin_24 = len(st_24)
    if len(st_24) > lmax_24:
        lmax_24 = len(st_24)
        
# restrict spatio-temporal sequences to length-5
STC5_24 = [ st_24 for st_24 in STC_24 if len(st_24) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_24 = []
for n in range(len(STC5_24)):
    tc_24 = [ u for u in STC5_24[n][0] ]
    for k in range(1, len(STC5_24[n])):
        tc_24 = [ u+v for u in tc_24 for v in STC5_24[n][k] ]
    TC5_24 = TC5_24 + tc_24
setTC5_24 = list(set(TC5_24))

# get empirical frequencies
fTC5_24 = [ TC5_24.count(setTC5_24[l]) for l in range(len(setTC5_24)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_24 = [ [] for l in range(len(setTC5_24)) ]
for s in range(100):
    STC5null_24 = [ list(st_24) for st_24 in STC5_24]
    for st_24 in STC5null_24:
        np.random.shuffle(st_24)
    TC5null_24= []
    for n in range(len(STC5null_24)):
        tc_24 = [ u for u in STC5null_24[n][0] ]
        for k in range(1, len(STC5null_24[n])):
            tc_24 = [ u+v for u in tc_24 for v in STC5null_24[n][k] ]
        TC5null_24= TC5null_24+ tc_24
    for l in range(len(setTC5_24)):
        if TC5null_24.count(setTC5_24[l]) > 0:
            fTC5null_24[l].append(TC5null_24.count(setTC5_24[l]))
        else:
            fTC5null_24[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_24)):
     if sum(freq >= fTC5_24[l] for freq in fTC5null_24[l]) < 5:
        print(setTC5_24[l], fTC5_24[l], sum(freq >= fTC5_24[l] for freq in fTC5null_24[l]))
#         print(setTC5_24[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# HJRHR
# BBJRH
# RJHHH
# BJJDR
# HHDRH
# BJJRR
# RHDBH
# DBDDB
# DRRR
# DBDRH
# BBDDD
# DBHB
# DDJH
# BBDBJ
# DJJDR
# BJDDJ
# RDDRH
# RJRBH
# RJJRR
# DJJRH
# DHDBH
# HHDRB
# BBJRJ
# BHDRJ
# RJJDR
# BDDDB
# JJJHR
# DJJHJ
# BDDRH
# BBDRR
# BJRHH
# HJDBH
# DJJHR
# RJBHD
# DJRDR
# HHDBJ
# DBDHH
# BDDBJ
# BJDBJ
# DJJDH
# DRRRR
# HB
# DBDDJ
# DHDRB
# BBDRH
# HJHHH
# BRBBR
# RJJHH
# BJDRR
# BHDBJ
# DBDDR
# HHDRD
# RJRHH
# DBJHR
# HHDRJ
# DBDDH
# DJDHH
# DDRH
# JDDDH
# HHHJ
# DJHBR
# HJHBR
# RHDBJ
# BDDDH
# RHDRJ
# BBDRJ
# DJJHH
# BBDBH
# DDDDH
# DJDHR
# RJHBR
# BBDHR
# BBJBJ
# DDBH
# BBDDJ
# RJBJR
# RJBHJ
# JDBH
# RJDHH
# BBJRR
# HJRHH
# DJDDR
# BBDDH
# RHDRH
# DJJHD
# BBDDB
# DJRHH
# DRBJR
# RJJH
# DHDRJ
# DJHHH
# DJJRR
# BDDRJ
# DHDBJ
# DJBHR
# RJJHR
# HHDBH
# HHDBD
# BJDRJ
# BJDDH
# BRDDH
# DJBJR
# DJDRR
# RJDHJ
# HJRDR
# RHDDH
# RJJHJ
# HHDDH
# RDDDH
# DJRHR
# DDDRH
# DDDH
# RJJHD

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_24)):
    if sum(freq >= fTC5_24[l] for freq in fTC5null_24[l]) < 1:
        print(setTC5_24[l], fTC5_24[l], sum(freq >= fTC5_24[l] for freq in fTC5null_24[l]))
#         print(setTC5_24[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# BJJRR
# BBDBJ
# BHDRJ
# DJJHJ
# DJJHR
# HHDBJ
# BBDRH
# BHDBJ
# DBDDR
# DBDDH
# DJDHH
# HJHBR
# RHDBJ
# RHDRJ
# BBDRJ
# DJJHH
# DJDHR
# BBJBJ
# BBJRR
# DJDDR
# RHDRH
# BBDDB
# DHDRJ
# DJHHH
# BDDRJ
# DHDBJ
# RJJHR
# RHDDH

# %% [markdown]
# # 3.25 (B) AP - (D) AC - (H) BLOOM - (J) FGEN - (Y) SMC

# %%
#extract overlapping dates
start_25 = max(min(Date_AP), min(Date_AC), min(Date_BLOOM), min(Date_FGEN), min(Date_SMC))
end_25 = min(max(Date_AP), max(Date_AC), max(Date_BLOOM), max(Date_FGEN), max(Date_SMC))

# %%
#shorten the closing prices
AP_25_1 = Date_AP.index(start_25)
AP_25_2 = Date_AP.index(end_25)

AC_25_1 = Date_AC.index(start_25)
AC_25_2 = Date_AC.index(end_25)

BLOOM_25_1 = Date_BLOOM.index(start_25)
BLOOM_25_2 = Date_BLOOM.index(end_25)

FGEN_25_1 = Date_FGEN.index(start_25)
FGEN_25_2 = Date_FGEN.index(end_25)

SMC_25_1 = Date_SMC.index(start_25)
SMC_25_2 = Date_SMC.index(end_25)

# %%
#save the shortened versions of closing prices
B25 = np.save('APshortPrices.npy', ClosePrice_AP[AP_25_1:AP_25_2])
D25 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_25_1:AC_25_2])
H25 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_25_1:BLOOM_25_2])
J25 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_25_1:FGEN_25_2])
Y25 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_25_1:SMC_25_2])

# %%
# import modules
import numpy as np
# import prices

B25 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D25 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H25 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J25 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
Y25 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_25 = []
st_25 = []
n = 1
while n < len(B25):
    sc_25 = ''
    if B25[n] > B25[n-1]:
        sc_25 = sc_25 + 'B'
    if D25[n] > D25[n-1]:
        sc_25 = sc_25 + 'D'
    if H25[n] > H25[n-1]:
        sc_25 = sc_25 + 'H'
    if J25[n] > J25[n-1]:
        sc_25 = sc_25 + 'J'
    if Y25[n] > Y25[n-1]:
        sc_25 = sc_25 + 'Y'
    if len(sc_25) > 0:
        st_25.append(sc_25)
    else:
        STC_25.append(st_25)
        st_25 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_25 = STC_25.count([])
# keep only non-empty spatio-temporal sequences
STC_25 = [ st_25 for st_25 in STC_25 if len(st_25) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_25 = len(B25)
lmax_25 = 0
for st_25 in STC_25:
    if len(st_25) < lmin_25:
        lmin_25 = len(st_25)
    if len(st_25) > lmax_25:
        lmax_25 = len(st_25)
        
# restrict spatio-temporal sequences to length-5
STC5_25 = [ st_25 for st_25 in STC_25 if len(st_25) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_25 = []
for n in range(len(STC5_25)):
    tc_25 = [ u for u in STC5_25[n][0] ]
    for k in range(1, len(STC5_25[n])):
        tc_25 = [ u+v for u in tc_25 for v in STC5_25[n][k] ]
    TC5_25 = TC5_25 + tc_25
setTC5_25 = list(set(TC5_25))

# get empirical frequencies
fTC5_25 = [ TC5_25.count(setTC5_25[l]) for l in range(len(setTC5_25)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_25 = [ [] for l in range(len(setTC5_25)) ]
for s in range(100):
    STC5null_25 = [ list(st_25) for st_25 in STC5_25]
    for st_25 in STC5null_25:
        np.random.shuffle(st_25)
    TC5null_25= []
    for n in range(len(STC5null_25)):
        tc_25 = [ u for u in STC5null_25[n][0] ]
        for k in range(1, len(STC5null_25[n])):
            tc_25 = [ u+v for u in tc_25 for v in STC5null_25[n][k] ]
        TC5null_25= TC5null_25+ tc_25
    for l in range(len(setTC5_25)):
        if TC5null_25.count(setTC5_25[l]) > 0:
            fTC5null_25[l].append(TC5null_25.count(setTC5_25[l]))
        else:
            fTC5null_25[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_25)):
     if sum(freq >= fTC5_25[l] for freq in fTC5null_25[l]) < 5:
        print(setTC5_25[l], fTC5_25[l], sum(freq >= fTC5_25[l] for freq in fTC5null_25[l]))
#         print(setTC5_25[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# BJDDB
# BBDHB
# DBDDB
# HBDB
# HJBBJ
# DBJHY
# HBHJ
# DJDHY
# HJBHY
# BJBBJ
# DJDHB
# BDYDB
# BJJDB
# BDDDB
# DHHHY
# YYBJ
# DBYBH
# DBYJH
# DBDHH
# DJJYH
# BJDBJ
# DYYH
# DBYHB
# HJDHY
# DBYY
# HBYH
# DJBHY
# DDDYB
# DHJHY
# DJJDB
# DBYJ
# JHJHY
# JJJHY
# DJDHH
# HHDHJ
# DJJHB
# BJJYH
# DHYHY
# HHBBJ
# BDDDH
# BBYJ
# DJJHH
# BJJBJ
# HJJHY
# HJBJY
# HJDBY
# DYYY
# DDBH
# DJJHY
# HJJYY
# HHJBY
# HJDYY
# BDJBJ
# YHBH
# HJBBY
# DDJJJ
# DJJHD
# BBDDB
# HBJ
# HBJJ
# JBBD
# HBYJ
# HBYD
# YBYHH
# JJBHY
# BBYHB
# BJDDH
# BJDHY
# YBYJH
# HY
# HJDHJ
# JJD
# DBYHH
# YBYHB
# HHDBY
# DBYHY
# YJDDY
# DDDH

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_25)):
     if sum(freq >= fTC5_25[l] for freq in fTC5null_25[l]) < 1:
        print(setTC5_25[l], fTC5_25[l], sum(freq >= fTC5_25[l] for freq in fTC5null_25[l]))
#         print(setTC5_25[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# DJDHY
# BJJDB
# DBYHB
# DHJHY
# DJJHB
# DHYHY
# DJJHY
# HBYJ
# HBYD
# BBYHB
# YBYJH
# HY
# JJD
# DBYHH
# DBYHY

# %% [markdown]
# # 3.26 (B) AP - (D) AC - (H) BLOOM - (J) FGEN - (α) SCC

# %%
#extract overlapping dates
start_26 = max(min(Date_AP), min(Date_AC), min(Date_BLOOM), min(Date_FGEN), min(Date_SCC))
end_26 = min(max(Date_AP), max(Date_AC), max(Date_BLOOM), max(Date_FGEN), max(Date_SCC))

# %%
#shorten the closing prices
AP_26_1 = Date_AP.index(start_26)
AP_26_2 = Date_AP.index(end_26)

AC_26_1 = Date_AC.index(start_26)
AC_26_2 = Date_AC.index(end_26)

BLOOM_26_1 = Date_BLOOM.index(start_26)
BLOOM_26_2 = Date_BLOOM.index(end_26)

FGEN_26_1 = Date_FGEN.index(start_26)
FGEN_26_2 = Date_FGEN.index(end_26)

SCC_26_1 = Date_SCC.index(start_26)
SCC_26_2 = Date_SCC.index(end_26)

# %%
#save the shortened versions of closing prices
B26 = np.save('APshortPrices.npy', ClosePrice_AP[AP_26_1:AP_26_2])
D26 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_26_1:AC_26_2])
H26 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_26_1:BLOOM_26_2])
J26 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_26_1:FGEN_26_2])
α26 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_26_1:SCC_26_2])

# %%
# import modules
import numpy as np
# import prices

B26 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D26 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H26 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J26 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
α26 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_26 = []
st_26 = []
n = 1
while n < len(B26):
    sc_26 = ''
    if B26[n] > B26[n-1]:
        sc_26 = sc_26 + 'B'
    if D26[n] > D26[n-1]:
        sc_26 = sc_26 + 'D'
    if H26[n] > H26[n-1]:
        sc_26 = sc_26 + 'H'
    if J26[n] > J26[n-1]:
        sc_26 = sc_26 + 'J'
    if α26[n] > α26[n-1]:
        sc_26 = sc_26 + 'Y'
    if len(sc_26) > 0:
        st_26.append(sc_26)
    else:
        STC_26.append(st_26)
        st_26 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_26 = STC_26.count([])
# keep only non-empty spatio-temporal sequences
STC_26 = [ st_26 for st_26 in STC_26 if len(st_26) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_26 = len(B26)
lmax_26 = 0
for st_26 in STC_26:
    if len(st_26) < lmin_26:
        lmin_26 = len(st_26)
    if len(st_26) > lmax_26:
        lmax_26 = len(st_26)
        
# restrict spatio-temporal sequences to length-5
STC5_26 = [ st_26 for st_26 in STC_26 if len(st_26) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_26 = []
for n in range(len(STC5_26)):
    tc_26 = [ u for u in STC5_26[n][0] ]
    for k in range(1, len(STC5_26[n])):
        tc_26 = [ u+v for u in tc_26 for v in STC5_26[n][k] ]
    TC5_26 = TC5_26 + tc_26
setTC5_26 = list(set(TC5_26))

# get empirical frequencies
fTC5_26 = [ TC5_26.count(setTC5_26[l]) for l in range(len(setTC5_26)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_26 = [ [] for l in range(len(setTC5_26)) ]
for s in range(100):
    STC5null_26 = [ list(st_26) for st_26 in STC5_26]
    for st_26 in STC5null_26:
        np.random.shuffle(st_26)
    TC5null_26= []
    for n in range(len(STC5null_26)):
        tc_26 = [ u for u in STC5null_26[n][0] ]
        for k in range(1, len(STC5null_26[n])):
            tc_26 = [ u+v for u in tc_26 for v in STC5null_26[n][k] ]
        TC5null_26= TC5null_26+ tc_26
    for l in range(len(setTC5_26)):
        if TC5null_26.count(setTC5_26[l]) > 0:
            fTC5null_26[l].append(TC5null_26.count(setTC5_26[l]))
        else:
            fTC5null_26[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_26)):
     if sum(freq >= fTC5_26[l] for freq in fTC5null_26[l]) < 5:
        print(setTC5_26[l], fTC5_26[l], sum(freq >= fTC5_26[l] for freq in fTC5null_26[l]))
#         print(setTC5_26[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# BJDDB
# HDYYY
# JBJD
# YDYBY
# DBHB
# JYBHB
# JDJHD
# DDYYJ
# JBJHD
# HYJHH
# DDYDB
# JDBHB
# JDHHD
# JJBHJ
# BDBYJ
# YBYBY
# JYBYJ
# HHYYH
# YDDBH
# BDYDB
# BJJDB
# DYDH
# BDDDB
# YYDH
# BJJDH
# JYBHJ
# BJBYJ
# DJDDH
# JYBHD
# BDDBJ
# HHYJJ
# JDBHJ
# HHYYJ
# DJJDH
# HHYBH
# HDYBY
# JDHYY
# HHYHJ
# BHDBJ
# JDBHD
# BJBYD
# DJJDB
# HJJY
# DJDHH
# YHHD
# JDBYD
# DHYYJ
# JDBYJ
# JDHHB
# JDHYD
# BHYYJ
# DJJHH
# DDDDH
# HHYBJ
# BJDHB
# JYHYJ
# BYY
# YHDH
# JJBHD
# YDDBJ
# JBJY
# HHYYY
# JDYYY
# YDDBY
# BBDDB
# YDBHD
# HHHYJ
# HHYYB
# YBDJ
# HHYBY
# BBJHH
# YYBHJ
# YDBHJ
# HYYYJ
# BJDDH
# YHHY
# JDHYJ
# YHJH
# HDYYJ
# JJDY
# JDDH
# JDJYY
# DBYDB
# DDYJJ
# HHYBB
# BJJHH
# DDDH
# JDHBB

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_26)):
     if sum(freq >= fTC5_26[l] for freq in fTC5null_26[l]) < 1:
        print(setTC5_26[l], fTC5_26[l], sum(freq >= fTC5_26[l] for freq in fTC5null_26[l]))
#         print(setTC5_26[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# JDHHD
# BJJDB
# JYBHJ
# BJBYJ
# HHYYJ
# JDBHD

# %% [markdown]
# # 3.27 (B) AP - (D) AC - (H) BLOOM - (M) ICT - (N) JGS

# %%
#extract overlapping dates
start_27 = max(min(Date_AP), min(Date_AC), min(Date_BLOOM), min(Date_ICT), min(Date_JGS))
end_27 = min(max(Date_AP), max(Date_AC), max(Date_BLOOM), max(Date_ICT), max(Date_JGS))

# %%
#shorten the closing prices
AP_27_1 = Date_AP.index(start_27)
AP_27_2 = Date_AP.index(end_27)

AC_27_1 = Date_AC.index(start_27)
AC_27_2 = Date_AC.index(end_27)

BLOOM_27_1 = Date_BLOOM.index(start_27)
BLOOM_27_2 = Date_BLOOM.index(end_27)

ICT_27_1 = Date_ICT.index(start_27)
ICT_27_2 = Date_ICT.index(end_27)

JGS_27_1 = Date_JGS.index(start_27)
JGS_27_2 = Date_JGS.index(end_27)

# %%
#save the shortened versions of closing prices
B27 = np.save('APshortPrices.npy', ClosePrice_AP[AP_27_1:AP_27_2])
D27 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_27_1:AC_27_2])
H27 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_27_1:BLOOM_27_2])
M27 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_27_1:ICT_27_2])
N27 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_27_1:JGS_27_2])

# %%
# import modules
import numpy as np
# import prices

B27 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D27 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H27 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M27 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N27 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_27 = []
st_27 = []
n = 1
while n < len(B27):
    sc_27 = ''
    if B27[n] > B27[n-1]:
        sc_27 = sc_27 + 'B'
    if D27[n] > D27[n-1]:
        sc_27 = sc_27 + 'D'
    if H27[n] > H27[n-1]:
        sc_27 = sc_27 + 'H'
    if M27[n] > M27[n-1]:
        sc_27 = sc_27 + 'M'
    if N27[n] > N27[n-1]:
        sc_27 = sc_27 + 'N'
    if len(sc_27) > 0:
        st_27.append(sc_27)
    else:
        STC_27.append(st_27)
        st_27 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_27 = STC_27.count([])
# keep only non-empty spatio-temporal sequences
STC_27 = [ st_27 for st_27 in STC_27 if len(st_27) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_27 = len(B27)
lmax_27 = 0
for st_27 in STC_27:
    if len(st_27) < lmin_27:
        lmin_27 = len(st_27)
    if len(st_27) > lmax_27:
        lmax_27 = len(st_27)
        
# restrict spatio-temporal sequences to length-5
STC5_27 = [ st_27 for st_27 in STC_27 if len(st_27) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_27 = []
for n in range(len(STC5_27)):
    tc_27 = [ u for u in STC5_27[n][0] ]
    for k in range(1, len(STC5_27[n])):
        tc_27 = [ u+v for u in tc_27 for v in STC5_27[n][k] ]
    TC5_27 = TC5_27 + tc_27
setTC5_27 = list(set(TC5_27))

# get empirical frequencies
fTC5_27 = [ TC5_27.count(setTC5_27[l]) for l in range(len(setTC5_27)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_27 = [ [] for l in range(len(setTC5_27)) ]
for s in range(100):
    STC5null_27 = [ list(st_27) for st_27 in STC5_27]
    for st_27 in STC5null_27:
        np.random.shuffle(st_27)
    TC5null_27= []
    for n in range(len(STC5null_27)):
        tc_27 = [ u for u in STC5null_27[n][0] ]
        for k in range(1, len(STC5null_27[n])):
            tc_27 = [ u+v for u in tc_27 for v in STC5null_27[n][k] ]
        TC5null_27= TC5null_27+ tc_27
    for l in range(len(setTC5_27)):
        if TC5null_27.count(setTC5_27[l]) > 0:
            fTC5null_27[l].append(TC5null_27.count(setTC5_27[l]))
        else:
            fTC5null_27[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_27)):
     if sum(freq >= fTC5_27[l] for freq in fTC5null_27[l]) < 5:
        print(setTC5_27[l], fTC5_27[l], sum(freq >= fTC5_27[l] for freq in fTC5null_27[l]))
#         print(setTC5_27[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# MDDMN
# MNDBH
# DBDDN
# MDDDN
# DNMDN
# HNMNM
# BHBH
# DNDH
# BNMBH
# BBNDB
# HHMNN
# HDMDN
# NNMBH
# MDDBN
# BBNH
# DBNDB
# MBNB
# BHMBB
# HNMNN
# NNDN
# BHMBD
# MBDB
# DBNB
# DHBH
# DBDBN
# BMNHH
# DHDBD
# BHMMN
# HHMNM
# HHDBN
# DHNH
# HHMND
# HNMDN
# DBNBN
# DBNHH
# DBNDH
# BDHMD
# NNMMN
# DDNH
# DBNMM
# HNHNN
# HMMM
# HHMBN
# NNMDN
# NMMBM
# DMNH
# MDHMD
# DNBH
# MMBH
# NMBN
# BNNDH
# MNMMN
# DBNDN
# MNMBH
# DBNH
# DDDB
# BMMBH
# MDHMN
# BHMMD
# BNNDB
# DNDDN
# NBNBN
# NBDBM
# NHNH
# DNN
# BHHMD
# DNMMN
# HBMMN
# BNMMN
# MHDM
# MBHMN
# NMDBM
# NBNH
# DMNB
# BDHMN
# MDMMN
# BMMBD
# DDDDN
# BDMMN
# NMMBH
# HHDBD
# NHBH
# DMBH
# DHDH
# HDMMN
# MMNH
# BNMDN
# NBMBM
# BDMDN
# NDDH
# NNDDN
# HHDNM
# BBNDM
# BHMMB
# BHMBN
# HNMMN
# BNBBH
# BHHMN
# DDDH
# BMBBD
# BHNDB

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_27)):
     if sum(freq >= fTC5_27[l] for freq in fTC5null_27[l]) < 1:
        print(setTC5_27[l], fTC5_27[l], sum(freq >= fTC5_27[l] for freq in fTC5null_27[l]))
#         print(setTC5_27[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# BHBH
# HHMNN
# MBNB
# HNMNN
# NNDN
# BHMBD
# DHBH
# BHMMN
# DHNH
# HNMDN
# DBNBN
# DBNDH
# HNHNN
# DBNDN
# MDHMN
# DNDDN
# BDHMN
# BMMBD
# BNMDN
# NBMBM
# BHHMN

# %% [markdown]
# # 3.28 (B) AP - (D) AC - (H) BLOOM - (M) ICT - (R) MEG

# %%
#extract overlapping dates
start_28 = max(min(Date_AP), min(Date_AC), min(Date_BLOOM), min(Date_ICT), min(Date_MEG))
end_28 = min(max(Date_AP), max(Date_AC), max(Date_BLOOM), max(Date_ICT), max(Date_MEG))

# %%
#shorten the closing prices
AP_28_1 = Date_AP.index(start_28)
AP_28_2 = Date_AP.index(end_28)

AC_28_1 = Date_AC.index(start_28)
AC_28_2 = Date_AC.index(end_28)

BLOOM_28_1 = Date_BLOOM.index(start_28)
BLOOM_28_2 = Date_BLOOM.index(end_28)

ICT_28_1 = Date_ICT.index(start_28)
ICT_28_2 = Date_ICT.index(end_28)

MEG_28_1 = Date_MEG.index(start_28)
MEG_28_2 = Date_MEG.index(end_28)

# %%
#save the shortened versions of closing prices
B28 = np.save('APshortPrices.npy', ClosePrice_AP[AP_28_1:AP_28_2])
D28 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_28_1:AC_28_2])
H28 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_28_1:BLOOM_28_2])
M28 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_28_1:ICT_28_2])
R28 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_28_1:MEG_28_2])

# %%
# import modules
import numpy as np
# import prices

B28 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D28 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H28 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M28 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R28 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_28 = []
st_28 = []
n = 1
while n < len(B28):
    sc_28 = ''
    if B28[n] > B28[n-1]:
        sc_28 = sc_28 + 'B'
    if D28[n] > D28[n-1]:
        sc_28 = sc_28 + 'D'
    if H28[n] > H28[n-1]:
        sc_28 = sc_28 + 'H'
    if M28[n] > M28[n-1]:
        sc_28 = sc_28 + 'M'
    if R28[n] > R28[n-1]:
        sc_28 = sc_28 + 'R'
    if len(sc_28) > 0:
        st_28.append(sc_28)
    else:
        STC_28.append(st_28)
        st_28 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_28 = STC_28.count([])
# keep only non-empty spatio-temporal sequences
STC_28 = [ st_28 for st_28 in STC_28 if len(st_28) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_28 = len(B28)
lmax_28 = 0
for st_28 in STC_28:
    if len(st_28) < lmin_28:
        lmin_28 = len(st_28)
    if len(st_28) > lmax_28:
        lmax_28 = len(st_28)
        
# restrict spatio-temporal sequences to length-5
STC5_28 = [ st_28 for st_28 in STC_28 if len(st_28) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_28 = []
for n in range(len(STC5_28)):
    tc_28 = [ u for u in STC5_28[n][0] ]
    for k in range(1, len(STC5_28[n])):
        tc_28 = [ u+v for u in tc_28 for v in STC5_28[n][k] ]
    TC5_28 = TC5_28 + tc_28
setTC5_28 = list(set(TC5_28))

# get empirical frequencies
fTC5_28 = [ TC5_28.count(setTC5_28[l]) for l in range(len(setTC5_28)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_28 = [ [] for l in range(len(setTC5_28)) ]
for s in range(100):
    STC5null_28 = [ list(st_28) for st_28 in STC5_28]
    for st_28 in STC5null_28:
        np.random.shuffle(st_28)
    TC5null_28= []
    for n in range(len(STC5null_28)):
        tc_28 = [ u for u in STC5null_28[n][0] ]
        for k in range(1, len(STC5null_28[n])):
            tc_28 = [ u+v for u in tc_28 for v in STC5null_28[n][k] ]
        TC5null_28= TC5null_28+ tc_28
    for l in range(len(setTC5_28)):
        if TC5null_28.count(setTC5_28[l]) > 0:
            fTC5null_28[l].append(TC5null_28.count(setTC5_28[l]))
        else:
            fTC5null_28[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_28)):
     if sum(freq >= fTC5_28[l] for freq in fTC5null_28[l]) < 5:
        print(setTC5_28[l], fTC5_28[l], sum(freq >= fTC5_28[l] for freq in fTC5null_28[l]))
#         print(setTC5_28[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# RRMMB
# DHBR
# BHBH
# RBHMM
# RRDDH
# DBHB
# RBMBM
# MRMBH
# RBHMB
# MRDDD
# RMBBH
# RBHHH
# DHBH
# BHHRB
# RBDDH
# RRMRB
# RBBHH
# DBBBH
# DMMH
# DBHR
# DMBB
# BDDRH
# RRHHH
# DMRH
# DBDHH
# DRDMB
# DMMR
# RBDBH
# BBDRH
# DMRR
# MDHMD
# MMBH
# RMMBH
# DRDRB
# RRMBH
# MBMHD
# RRDBH
# DMHBH
# DBDDH
# RRBBM
# BBBBH
# DDRH
# DMDB
# MBMMD
# MBMBH
# RDHBM
# BBDBH
# RBBBH
# RBHBH
# DDBH
# DMDR
# RMMBM
# RBHBM
# RRMMM
# RRDMR
# RRHBM
# DMDH
# RRBBH
# RBMMM
# MBRB
# DMBBH
# RRBH
# RMHBH
# RRHBH
# RDMMB
# RBRHD
# DRDMR
# RDHMM
# RDMBM
# RMBH
# RBDHH
# RMDBH
# RDMMM
# DBRB
# RMDBM
# RDHMB
# MBBBH
# MDMMD
# RRDRB
# DMBH
# BMBH
# RBMHD
# DHDH
# BBDHH
# RDMMD
# MBBHH
# RMHBM
# RMBBM
# RRHMM
# RMHMM
# RRBHH
# RDBBM
# MBDBH
# RBB
# DDDH

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_28)):
     if sum(freq >= fTC5_28[l] for freq in fTC5null_28[l]) < 1:
        print(setTC5_28[l], fTC5_28[l], sum(freq >= fTC5_28[l] for freq in fTC5null_28[l]))
#         print(setTC5_28[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# RBHMM
# RMBBH
# DMRH
# RRMBH
# RRDBH
# BBBBH
# RBHBH
# RMMBM
# RRBBH
# RMHBH
# RRHBH
# RDHMM
# DMBH
# MBDBH
# RBB

# %% [markdown]
# # 3.29 (B) AP - (D) AC - (H) BLOOM - (M) ICT - (Y) SMC

# %%
#extract overlapping dates
start_29 = max(min(Date_AP), min(Date_AC), min(Date_BLOOM), min(Date_ICT), min(Date_SMC))
end_29 = min(max(Date_AP), max(Date_AC), max(Date_BLOOM), max(Date_ICT), max(Date_SMC))

# %%
#shorten the closing prices
AP_29_1 = Date_AP.index(start_29)
AP_29_2 = Date_AP.index(end_29)

AC_29_1 = Date_AC.index(start_29)
AC_29_2 = Date_AC.index(end_29)

BLOOM_29_1 = Date_BLOOM.index(start_29)
BLOOM_29_2 = Date_BLOOM.index(end_29)

ICT_29_1 = Date_ICT.index(start_29)
ICT_29_2 = Date_ICT.index(end_29)

SMC_29_1 = Date_SMC.index(start_29)
SMC_29_2 = Date_SMC.index(end_29)

# %%
#save the shortened versions of closing prices
B29 = np.save('APshortPrices.npy', ClosePrice_AP[AP_29_1:AP_29_2])
D29 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_29_1:AC_29_2])
H29 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_29_1:BLOOM_29_2])
M29 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_29_1:ICT_29_2])
Y29 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_29_1:SMC_29_2])

# %%
# import modules
import numpy as np
# import prices

B29 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D29 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H29 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M29 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
Y29 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_29 = []
st_29 = []
n = 1
while n < len(B29):
    sc_29 = ''
    if B29[n] > B29[n-1]:
        sc_29 = sc_29 + 'B'
    if D29[n] > D29[n-1]:
        sc_29 = sc_29 + 'D'
    if H29[n] > H29[n-1]:
        sc_29 = sc_29 + 'H'
    if M29[n] > M29[n-1]:
        sc_29 = sc_29 + 'M'
    if Y29[n] > Y29[n-1]:
        sc_29 = sc_29 + 'Y'
    if len(sc_29) > 0:
        st_29.append(sc_29)
    else:
        STC_29.append(st_29)
        st_29 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_29 = STC_29.count([])
# keep only non-empty spatio-temporal sequences
STC_29 = [ st_29 for st_29 in STC_29 if len(st_29) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_29 = len(B29)
lmax_29 = 0
for st_29 in STC_29:
    if len(st_29) < lmin_29:
        lmin_29 = len(st_29)
    if len(st_29) > lmax_29:
        lmax_29 = len(st_29)
        
# restrict spatio-temporal sequences to length-5
STC5_29 = [ st_29 for st_29 in STC_29 if len(st_29) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_29 = []
for n in range(len(STC5_29)):
    tc_29 = [ u for u in STC5_29[n][0] ]
    for k in range(1, len(STC5_29[n])):
        tc_29 = [ u+v for u in tc_29 for v in STC5_29[n][k] ]
    TC5_29 = TC5_29 + tc_29
setTC5_29 = list(set(TC5_29))

# get empirical frequencies
fTC5_29 = [ TC5_29.count(setTC5_29[l]) for l in range(len(setTC5_29)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_29 = [ [] for l in range(len(setTC5_29)) ]
for s in range(100):
    STC5null_29 = [ list(st_29) for st_29 in STC5_29]
    for st_29 in STC5null_29:
        np.random.shuffle(st_29)
    TC5null_29= []
    for n in range(len(STC5null_29)):
        tc_29 = [ u for u in STC5null_29[n][0] ]
        for k in range(1, len(STC5null_29[n])):
            tc_29 = [ u+v for u in tc_29 for v in STC5null_29[n][k] ]
        TC5null_29= TC5null_29+ tc_29
    for l in range(len(setTC5_29)):
        if TC5null_29.count(setTC5_29[l]) > 0:
            fTC5null_29[l].append(TC5null_29.count(setTC5_29[l]))
        else:
            fTC5null_29[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_29)):
     if sum(freq >= fTC5_29[l] for freq in fTC5null_29[l]) < 5:
        print(setTC5_29[l], fTC5_29[l], sum(freq >= fTC5_29[l] for freq in fTC5null_29[l]))
#         print(setTC5_29[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# MBYDD
# HMYYD
# HMHYM
# YHHDY
# MBDB
# MHYYD
# MYDB
# MDDMB
# HDHMB
# YHYBD
# MBYMB
# HBBM
# BDHMD
# MBYHB
# MHYDD
# YHYDB
# MBYDB
# MDHMB
# YHYMD
# MDHDD
# HHYYD
# BBBM
# MDHMD
# MHYDB
# MDYMD
# MBMHD
# HHYBM
# HYYM
# MDYMB
# MBHDB
# YHDMD
# BHYDY
# MBHMB
# HBYM
# MMHMB
# MHH
# BBYYB
# YHYDD
# BHHDY
# MHHDY
# YHYYD
# BHYDB
# MDHMY
# YMBH
# MBYYB
# MDYHB
# YHBH
# BMDYD
# BDHMB
# BMBYD
# BHYDD
# YDDMB
# MBHMD
# HHHMD
# HHHMB
# HBYD
# YHHDB
# BBHYB
# MHYDY
# BBYDD
# YMBM
# MDMMD
# MMDB
# DHDH
# HHDBM
# YHYDY
# MHYMD
# HDMMM
# MMHYB
# DBYD
# MBHYB
# HHYBD
# MHYYB
# YDDDB
# BMYBB
# HHYMD

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_29)):
     if sum(freq >= fTC5_29[l] for freq in fTC5null_29[l]) < 1:
        print(setTC5_29[l], fTC5_29[l], sum(freq >= fTC5_29[l] for freq in fTC5null_29[l]))
#         print(setTC5_29[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# MHYYD
# MYDB
# MBYMB
# MDHMB
# YHYMD
# MDHMD
# MDYMB
# YHDMD
# MBHMB
# HBYM
# MMHMB
# YHYDD
# YHBH
# YDDDB
# HHYMD

# %% [markdown]
# # 3.30 (B) AP - (D) AC - (H) BLOOM - (M) ICT - (α) SCC

# %%
#extract overlapping dates
start_30 = max(min(Date_AP), min(Date_AC), min(Date_BLOOM), min(Date_ICT), min(Date_SCC))
end_30 = min(max(Date_AP), max(Date_AC), max(Date_BLOOM), max(Date_ICT), max(Date_SCC))

# %%
#shorten the closing prices
AP_30_1 = Date_AP.index(start_30)
AP_30_2 = Date_AP.index(end_30)

AC_30_1 = Date_AC.index(start_30)
AC_30_2 = Date_AC.index(end_30)

BLOOM_30_1 = Date_BLOOM.index(start_30)
BLOOM_30_2 = Date_BLOOM.index(end_30)

ICT_30_1 = Date_ICT.index(start_30)
ICT_30_2 = Date_ICT.index(end_30)

SCC_30_1 = Date_SCC.index(start_30)
SCC_30_2 = Date_SCC.index(end_30)

# %%
#save the shortened versions of closing prices
B30 = np.save('APshortPrices.npy', ClosePrice_AP[AP_30_1:AP_30_2])
D30 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_30_1:AC_30_2])
H30 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_30_1:BLOOM_30_2])
M30 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_30_1:ICT_30_2])
α30 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_30_1:SCC_30_2])

# %%
# import modules
import numpy as np
# import prices

B30 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
D30 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H30 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M30 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
α30 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_30 = []
st_30 = []
n = 1
while n < len(B30):
    sc_30 = ''
    if B30[n] > B30[n-1]:
        sc_30 = sc_30 + 'B'
    if D30[n] > D30[n-1]:
        sc_30 = sc_30 + 'D'
    if H30[n] > H30[n-1]:
        sc_30 = sc_30 + 'H'
    if M30[n] > M30[n-1]:
        sc_30 = sc_30 + 'M'
    if α30[n] > α30[n-1]:
        sc_30 = sc_30 + 'α'
    if len(sc_30) > 0:
        st_30.append(sc_30)
    else:
        STC_30.append(st_30)
        st_30 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_30 = STC_30.count([])
# keep only non-empty spatio-temporal sequences
STC_30 = [ st_30 for st_30 in STC_30 if len(st_30) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_30 = len(B30)
lmax_30 = 0
for st_30 in STC_30:
    if len(st_30) < lmin_30:
        lmin_30 = len(st_30)
    if len(st_30) > lmax_30:
        lmax_30 = len(st_30)
        
# restrict spatio-temporal sequences to length-5
STC5_30 = [ st_30 for st_30 in STC_30 if len(st_30) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_30 = []
for n in range(len(STC5_30)):
    tc_30 = [ u for u in STC5_30[n][0] ]
    for k in range(1, len(STC5_30[n])):
        tc_30 = [ u+v for u in tc_30 for v in STC5_30[n][k] ]
    TC5_30 = TC5_30 + tc_30
setTC5_30 = list(set(TC5_30))

# get empirical frequencies
fTC5_30 = [ TC5_30.count(setTC5_30[l]) for l in range(len(setTC5_30)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_30 = [ [] for l in range(len(setTC5_30)) ]
for s in range(100):
    STC5null_30 = [ list(st_30) for st_30 in STC5_30]
    for st_30 in STC5null_30:
        np.random.shuffle(st_30)
    TC5null_30= []
    for n in range(len(STC5null_30)):
        tc_30 = [ u for u in STC5null_30[n][0] ]
        for k in range(1, len(STC5null_30[n])):
            tc_30 = [ u+v for u in tc_30 for v in STC5null_30[n][k] ]
        TC5null_30= TC5null_30+ tc_30
    for l in range(len(setTC5_30)):
        if TC5null_30.count(setTC5_30[l]) > 0:
            fTC5null_30[l].append(TC5null_30.count(setTC5_30[l]))
        else:
            fTC5null_30[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_30)):
     if sum(freq >= fTC5_30[l] for freq in fTC5null_30[l]) < 5:
        print(setTC5_30[l], fTC5_30[l], sum(freq >= fTC5_30[l] for freq in fTC5null_30[l]))
#         print(setTC5_30[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# MDMDD
# DBDBα
# DDMHD
# αMMαM
# HBMα
# MHMMD
# αDαBα
# αBHαα
# DBααα
# MBDBα
# HHDαα
# MBMαD
# DBDαα
# HαHαM
# αMααα
# MBαHα
# αMHαα
# HBHαα
# MDDBα
# HDHαα
# MBDHα
# MMHαα
# MDHMB
# DMHαD
# MBDMα
# DαMαD
# BMαHH
# HBMM
# HHMMD
# MDHMD
# αMHαD
# αBααα
# MBMHD
# MBHαα
# MBDαα
# αMDαα
# αMHBD
# DDHHD
# αMααM
# MDMαα
# MBααα
# αMBαD
# MMHMB
# αBDBα
# HαD
# MHHD
# αBHBα
# MBHMα
# HαMαD
# BMBαD
# αMαBα
# BBMα
# DMααM
# MDHMα
# DBαBα
# DMDH
# αBαBα
# HBMBD
# αBDαα
# HBαBα
# DαHαD
# αMMαD
# DHMMD
# DMMαD
# HDαD
# MDMMα
# MBMBα
# BMMBD
# MDDMα
# MBHBα
# MBαBα
# HBMαα
# HDMαα
# MDMMD
# DMBH
# HBMαD
# BMMαD
# BMBHD
# HDHαM
# DMBαD
# MBHHα
# αMHBα
# MDDαα
# HαHαD
# BHBM
# MDMBD
# HαHαα
# HBααα
# MDαBα
# HBMαM
# MHD
# BMBBD
# MDMαD

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_30)):
     if sum(freq >= fTC5_30[l] for freq in fTC5null_30[l]) < 1:
        print(setTC5_30[l], fTC5_30[l], sum(freq >= fTC5_30[l] for freq in fTC5null_30[l]))
#         print(setTC5_30[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# MDMDD
# DBααα
# MBDBα
# DαMαD
# MDHMD
# αBααα
# αMDαα
# MBHMα
# MDHMα
# αBαBα
# MBαBα
# MDMMD
# HBααα
