# %% [markdown]
# # One-Letter Words

# %%
# open the csv files
AP = open('AP.csv')
AC = open('AC.csv')
BPI = open('BPI.csv')
BLOOM = open('BLOOM.csv')
FGEN = open('FGEN.csv')
ICT = open('ICT.csv')
JGS = open('JGS.csv')
MEG = open('MEG.csv')
SMC = open('SMC.csv')
SCC = open('SCC.csv')

#initiFGENze the lists
Date_AP = []
ClosePrice_AP = []
Date_AC = []
ClosePrice_AC = []
Date_BPI = []
ClosePrice_BPI = []
Date_BLOOM = []
ClosePrice_BLOOM = []
Date_FGEN = []
ClosePrice_FGEN = []
Date_ICT = []
ClosePrice_ICT = []
Date_JGS = []
ClosePrice_JGS = []
Date_MEG = []
ClosePrice_MEG = []
Date_SMC = []
ClosePrice_SMC = []
Date_SCC = []
ClosePrice_SCC = []

#skip the header line
AP.readline()
AC.readline()
BPI.readline()
BLOOM.readline()
FGEN.readline()
ICT.readline()
JGS.readline()
MEG.readline()
SMC.readline()
SCC.readline()

#go through the files line by line
for line in AP:
    sline = line.strip().split(',')
    Date_AP.append(sline[0])
    ClosePrice_AP.append(float(sline[1]))
    
for line in AC:
    sline = line.strip().split(',')
    Date_AC.append(sline[0])
    ClosePrice_AC.append(float(sline[1]))
    
for line in BPI:
    sline = line.strip().split(',')
    Date_BPI.append(sline[0])
    ClosePrice_BPI.append(float(sline[1]))
    
for line in BLOOM:
    sline = line.strip().split(',')
    Date_BLOOM.append(sline[0])
    ClosePrice_BLOOM.append(float(sline[1]))
    
for line in FGEN:
    sline = line.strip().split(',')
    Date_FGEN.append(sline[0])
    ClosePrice_FGEN.append(float(sline[1]))
    
for line in ICT:
    sline = line.strip().split(',')
    Date_ICT.append(sline[0])
    ClosePrice_ICT.append(float(sline[1]))
    
for line in JGS:
    sline = line.strip().split(',')
    Date_JGS.append(sline[0])
    ClosePrice_JGS.append(float(sline[1]))
    
for line in MEG:
    sline = line.strip().split(',')
    Date_MEG.append(sline[0])
    ClosePrice_MEG.append(float(sline[1]))
    
for line in SMC:
    sline = line.strip().split(',')
    Date_SMC.append(sline[0])
    ClosePrice_SMC.append(float(sline[1]))
        
for line in SCC:
    sline = line.strip().split(',')
    Date_SCC.append(sline[0])
    ClosePrice_SCC.append(float(sline[1]))


#close files
AP.close()
AC.close()
BPI.close()
BLOOM.close()
FGEN.close()
ICT.close()
JGS.close()
MEG.close()
SMC.close()
SCC.close()# One-Letter Words

# %%
import numpy as np
import datetime

# %%
# convert dates into datetime structure
for n in range(len(Date_AP)):
    Date_AP[n] = datetime.datetime.strptime(Date_AP[n], '%m/%d/%y').date()

for n in range(len(Date_AC)):
    Date_AC[n] = datetime.datetime.strptime(Date_AC[n], '%m/%d/%y').date()
    
for n in range(len(Date_BPI)):
    Date_BPI[n] = datetime.datetime.strptime(Date_BPI[n], '%m/%d/%y').date()

for n in range(len(Date_BLOOM)):
    Date_BLOOM[n] = datetime.datetime.strptime(Date_BLOOM[n], '%m/%d/%y').date()
    
for n in range(len(Date_FGEN)):
    Date_FGEN[n] = datetime.datetime.strptime(Date_FGEN[n], '%m/%d/%y').date()

for n in range(len(Date_ICT)):
    Date_ICT[n] = datetime.datetime.strptime(Date_ICT[n], '%m/%d/%y').date()
    
for n in range(len(Date_JGS)):
    Date_JGS[n] = datetime.datetime.strptime(Date_JGS[n], '%m/%d/%y').date()

for n in range(len(Date_MEG)):
    Date_MEG[n] = datetime.datetime.strptime(Date_MEG[n], '%m/%d/%y').date()
    
for n in range(len(Date_SMC)):
    Date_SMC[n] = datetime.datetime.strptime(Date_SMC[n], '%m/%d/%y').date()

for n in range(len(Date_SCC)):
    Date_SCC[n] = datetime.datetime.strptime(Date_SCC[n], '%m/%d/%y').date()
    
# save Date and ClosePrice
np.save('APDate.npy', Date_AP)
np.save('APClosePrice.npy', ClosePrice_AP)
np.save('ACDate.npy', Date_AC)
np.save('ACClosePrice.npy', ClosePrice_AC)
np.save('BPIDate.npy', Date_BPI)
np.save('BPIClosePrice.npy', ClosePrice_BPI)
np.save('BLOOMDate.npy', Date_BLOOM)
np.save('BLOOMClosePrice.npy', ClosePrice_BLOOM)
np.save('FGENDate.npy', Date_FGEN)
np.save('FGENClosePrice.npy', ClosePrice_FGEN)
np.save('ICTDate.npy', Date_ICT)
np.save('ICTClosePrice.npy', ClosePrice_ICT)
np.save('JGSDate.npy', Date_JGS)
np.save('JGSClosePrice.npy', ClosePrice_JGS)
np.save('MEGDate.npy', Date_MEG)
np.save('MEGClosePrice.npy', ClosePrice_MEG)
np.save('SMCDate.npy', Date_SMC)
np.save('SMCClosePrice.npy', ClosePrice_SMC)
np.save('SCCDate.npy', Date_SCC)
np.save('SCCClosePrice.npy', ClosePrice_SCC)

# %% [markdown]
# # Five-letter Words

# %% [markdown]
# # 3.91 (B) AP - (F) BPI - (R) MEG - (Y) SMC - (α) SMC

# %%
#extract overlapping dates
start_91 = max(min(Date_AP), min(Date_BPI), min(Date_MEG), min(Date_SMC), min(Date_SCC))
end_91 = min(max(Date_AP), max(Date_BPI), max(Date_MEG), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
AP_91_1 = Date_AP.index(start_91)
AP_91_2 = Date_AP.index(end_91)

BPI_91_1 = Date_BPI.index(start_91)
BPI_91_2 = Date_BPI.index(end_91)

MEG_91_1 = Date_MEG.index(start_91)
MEG_91_2 = Date_MEG.index(end_91)

SMC_91_1 = Date_SMC.index(start_91)
SMC_91_2 = Date_SMC.index(end_91)

SCC_91_1 = Date_SCC.index(start_91)
SCC_91_2 = Date_SCC.index(end_91)

# %%
#save the shortened versions of closing prices
B91 = np.save('APshortPrices.npy', ClosePrice_AP[AP_91_1:AP_91_2])
F91 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_91_1:BPI_91_2])
R91 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_91_1:MEG_91_2])
Y91 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_91_1:SMC_91_2])
α91 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_91_1:SCC_91_2])

# %%
# import modules
import numpy as np
# import prices

B91 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
F91 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
R91 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y91 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α91 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_91 = []
st_91 = []
n = 1
while n < len(B91):
    sc_91 = ''
    if B91[n] > B91[n-1]:
        sc_91 = sc_91 + 'B'
    if F91[n] > F91[n-1]:
        sc_91 = sc_91 + 'F'
    if R91[n] > R91[n-1]:
        sc_91 = sc_91 + 'R'
    if Y91[n] > Y91[n-1]:
        sc_91 = sc_91 + 'Y'
    if α91[n] > α91[n-1]:
        sc_91 = sc_91 + 'α'
    if len(sc_91) > 0:
        st_91.append(sc_91)
    else:
        STC_91.append(st_91)
        st_91 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_91 = STC_91.count([])
# keep only non-empty spatio-temporal sequences
STC_91 = [ st_91 for st_91 in STC_91 if len(st_91) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_91 = len(B91)
lmax_91 = 0
for st_91 in STC_91:
    if len(st_91) < lmin_91:
        lmin_91 = len(st_91)
    if len(st_91) > lmax_91:
        lmax_91 = len(st_91)
        
# restrict spatio-temporal sequences to length-5
STC5_91 = [ st_91 for st_91 in STC_91 if len(st_91) <= 5 ]

# unpackk spatio-temporal sequences to temporal sequences
TC5_91 = []
for n in range(len(STC5_91)):
    tc_91 = [ u for u in STC5_91[n][0] ]
    for k in range(1, len(STC5_91[n])):
        tc_91 = [ u+v for u in tc_91 for v in STC5_91[n][k] ]
    TC5_91 = TC5_91 + tc_91
setTC5_91 = list(set(TC5_91))

# get empirical frequencies
fTC5_91 = [ TC5_91.count(setTC5_91[l]) for l in range(len(setTC5_91)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_91 = [ [] for l in range(len(setTC5_91)) ]
for s in range(100):
    STC5null_91 = [ list(st_91) for st_91 in STC5_91]
    for st_91 in STC5null_91:
        np.random.shuffle(st_91)
    TC5null_91= []
    for n in range(len(STC5null_91)):
        tc_91 = [ u for u in STC5null_91[n][0] ]
        for k in range(1, len(STC5null_91[n])):
            tc_91 = [ u+v for u in tc_91 for v in STC5null_91[n][k] ]
        TC5null_91= TC5null_91+ tc_91
    for l in range(len(setTC5_91)):
        if TC5null_91.count(setTC5_91[l]) > 0:
            fTC5null_91[l].append(TC5null_91.count(setTC5_91[l]))
        else:
            fTC5null_91[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_91)):
     if sum(freq >= fTC5_91[l] for freq in fTC5null_91[l]) < 5:
#         print(setTC5_91[l], fTC5_91[l], sum(freq >= fTC5_91[l] for freq in fTC5null_91[l]))
        print(setTC5_91[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# BYαYB
# RααRB
# RBRYα
# BBRFB
# ααFR
# ααRB
# FαFB
# αααRB
# RBBYα
# FYBY
# RYBB
# FYαYB
# Bα
# RYFYα
# FααFα
# FRYFF
# αBBR
# YαFB
# RRF
# YαFR
# FYFB
# RYBα
# YYBB
# RFFFB
# FRαFB
# RYBY
# RYYY
# αBFR
# YFαFB
# RRBB
# FYαRB
# ααFFB
# αRFR
# FBFB
# RYFYY
# YαBB
# αBFB
# FYBα
# FBBB
# RααFF
# αBBB
# YFFFB
# YRαRB
# RαFR
# RBBB
# FαYFα
# YYYFα
# RαFB
# FRYY
# RYYαR
# αααYB
# BBBYR
# RααFB
# αRαYB
# αααFB
# FRαYB
# FRFR
# FRYFB
# αBBYR
# BBαFB
# FRYYB
# FRFB
# FRαRB
# RRFR
# FαFR
# αBRB
# ααFB
# RYB
# αYαYB
# ααBB
# YRFR
# YαBR
# FYYB
# αRYYB
# RBFB
# BααFB
# BYαFB
# ααBR
# αRBB
# FFαRB
# FαYFB
# FRBB
# RYFYR
# FααFF
# FYBB
# FαYY
# FYYY
# αYYYB
# BαFRY

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_91)):
     if sum(freq >= fTC5_91[l] for freq in fTC5null_91[l]) < 1:
#         print(setTC5_91[l], fTC5_91[l], sum(freq >= fTC5_91[l] for freq in fTC5null_91[l]))
        print(setTC5_91[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# ααFR
# ααRB
# FYBY
# FYαYB
# YαFR
# FYFB
# RYBY
# αRFR
# FBFB
# YαBB
# αααFB
# FRαYB
# FRαRB
# ααFB
# ααBB
# YRFR
# YαBR
# RYFYR
# FYBB

# %% [markdown]
# # 3.92 (B) AP - (H) BLOOM - (J) FGEN - (M) ICT - (N) JGS

# %%
#extract overlapping dates
start_92 = max(min(Date_AP), min(Date_BLOOM), min(Date_FGEN), min(Date_ICT), min(Date_JGS))
end_92 = min(max(Date_AP), max(Date_BLOOM), max(Date_FGEN), max(Date_ICT), max(Date_JGS))

# %%
#shorten the closing prices
AP_92_1 = Date_AP.index(start_92)
AP_92_2 = Date_AP.index(end_92)

BLOOM_92_1 = Date_BLOOM.index(start_92)
BLOOM_92_2 = Date_BLOOM.index(end_92)

FGEN_92_1 = Date_FGEN.index(start_92)
FGEN_92_2 = Date_FGEN.index(end_92)

ICT_92_1 = Date_ICT.index(start_92)
ICT_92_2 = Date_ICT.index(end_92)

JGS_92_1 = Date_JGS.index(start_92)
JGS_92_2 = Date_JGS.index(end_92)

# %%
#save the shortened versions of closing prices
B92 = np.save('APshortPrices.npy', ClosePrice_AP[AP_92_1:AP_92_2])
H92 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_92_1:BLOOM_92_2])
J92 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_92_1:FGEN_92_2])
M92 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_92_1:ICT_92_2])
N92 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_92_1:JGS_92_2])

# %%
# import modules
import numpy as np
# import prices

B92 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
H92 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J92 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M92 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N92 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_92 = []
st_92 = []
n = 1
while n < len(B92):
    sc_92 = ''
    if B92[n] > B92[n-1]:
        sc_92 = sc_92 + 'B'
    if H92[n] > H92[n-1]:
        sc_92 = sc_92 + 'H'
    if J92[n] > J92[n-1]:
        sc_92 = sc_92 + 'J'
    if M92[n] > M92[n-1]:
        sc_92 = sc_92 + 'M'
    if N92[n] > N92[n-1]:
        sc_92 = sc_92 + 'N'
    if len(sc_92) > 0:
        st_92.append(sc_92)
    else:
        STC_92.append(st_92)
        st_92 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_92 = STC_92.count([])
# keep only non-empty spatio-temporal sequences
STC_92 = [ st_92 for st_92 in STC_92 if len(st_92) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_92 = len(B92)
lmax_92 = 0
for st_92 in STC_92:
    if len(st_92) < lmin_92:
        lmin_92 = len(st_92)
    if len(st_92) > lmax_92:
        lmax_92 = len(st_92)
        
# restrict spatio-temporal sequences to length-5
STC5_92 = [ st_92 for st_92 in STC_92 if len(st_92) <= 5 ]

# unpackk spatio-temporal sequences to temporal sequences
TC5_92 = []
for n in range(len(STC5_92)):
    tc_92 = [ u for u in STC5_92[n][0] ]
    for k in range(1, len(STC5_92[n])):
        tc_92 = [ u+v for u in tc_92 for v in STC5_92[n][k] ]
    TC5_92 = TC5_92 + tc_92
setTC5_92 = list(set(TC5_92))

# get empirical frequencies
fTC5_92 = [ TC5_92.count(setTC5_92[l]) for l in range(len(setTC5_92)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_92 = [ [] for l in range(len(setTC5_92)) ]
for s in range(100):
    STC5null_92 = [ list(st_92) for st_92 in STC5_92]
    for st_92 in STC5null_92:
        np.random.shuffle(st_92)
    TC5null_92= []
    for n in range(len(STC5null_92)):
        tc_92 = [ u for u in STC5null_92[n][0] ]
        for k in range(1, len(STC5null_92[n])):
            tc_92 = [ u+v for u in tc_92 for v in STC5null_92[n][k] ]
        TC5null_92= TC5null_92+ tc_92
    for l in range(len(setTC5_92)):
        if TC5null_92.count(setTC5_92[l]) > 0:
            fTC5null_92[l].append(TC5null_92.count(setTC5_92[l]))
        else:
            fTC5null_92[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_92)):
     if sum(freq >= fTC5_92[l] for freq in fTC5null_92[l]) < 5:
#         print(setTC5_92[l], fTC5_92[l], sum(freq >= fTC5_92[l] for freq in fTC5null_92[l]))
        print(setTC5_92[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# NBJNJ
# MBNB
# BJJHM
# HHMH
# NBMBM
# BJJHH
# BHMH
# BMMBM
# HBHMM
# BBJHM
# JHHJ
# JMJB
# HMMH
# BMBBM
# NHBH
# HBMH
# NNNH
# HJMMM
# BBMH
# NMBJM
# BBNNH
# NMBBJ
# HJHMM
# NJJNJ
# NMNBM
# HHMNB
# JBNH
# NMJBM
# BBJHJ
# NMMBJ
# NBMBJ
# HJMMN
# BJNNH
# NBMN
# BJNHH
# NHMH
# JBMN
# NMMBM
# NBJMJ
# NHBJM
# HHMNM
# BJBHJ
# BBJMH
# BJJMH
# MMHMN
# BMM
# BBNH
# HJHMN
# NBNH
# MMHNN
# NBNBJ
# NMMH
# BBJNH
# BJJNH
# JHBH
# BJBBJ
# NBJMM
# NHNH
# HHMNN
# JBN
# JMJN
# JBMH
# BNBHJ
# JHJH
# NBJBJ
# NNBH
# HHMNJ
# BBJHH
# NHBJJ
# JJB
# NMBBM
# NBMH
# BJNNM
# BJJHJ
# BHBH
# NNBHJ
# NMJBJ
# NMJH
# JMJH
# JHMH
# JHNH
# NJJNM
# BJNMM
# JMMH

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_92)):
     if sum(freq >= fTC5_92[l] for freq in fTC5null_92[l]) < 1:
#         print(setTC5_92[l], fTC5_92[l], sum(freq >= fTC5_92[l] for freq in fTC5null_92[l]))
        print(setTC5_92[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# NBJNJ
# BJJHM
# HHMH
# BHMH
# NHBH
# HBMH
# HJMMM
# HJHMM
# JBNH
# NMJBM
# NBMBJ
# NMMBM
# BJBHJ
# BMM
# BJBBJ
# NHNH
# HHMNN
# NHBJJ
# NMBBM
# NBMH
# JHMH
# JHNH

# %% [markdown]
# # 3.93 (B) AP - (H) BLOOM - (J) FGEN - (M) ICT - (R) MEG

# %%
#extract overlapping dates
start_93 = max(min(Date_AP), min(Date_BLOOM), min(Date_FGEN), min(Date_ICT), min(Date_MEG))
end_93 = min(max(Date_AP), max(Date_BLOOM), max(Date_FGEN), max(Date_ICT), max(Date_MEG))

# %%
#shorten the closing prices
AP_93_1 = Date_AP.index(start_93)
AP_93_2 = Date_AP.index(end_93)

BLOOM_93_1 = Date_BLOOM.index(start_93)
BLOOM_93_2 = Date_BLOOM.index(end_93)

FGEN_93_1 = Date_FGEN.index(start_93)
FGEN_93_2 = Date_FGEN.index(end_93)

ICT_93_1 = Date_ICT.index(start_93)
ICT_93_2 = Date_ICT.index(end_93)

MEG_93_1 = Date_MEG.index(start_93)
MEG_93_2 = Date_MEG.index(end_93)

# %%
#save the shortened versions of closing prices
B93 = np.save('APshortPrices.npy', ClosePrice_AP[AP_93_1:AP_93_2])
H93 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_93_1:BLOOM_93_2])
J93 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_93_1:FGEN_93_2])
M93 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_93_1:ICT_93_2])
R93 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_93_1:MEG_93_2])

# %%
# import modules
import numpy as np
# import prices

B93 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
H93 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J93 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M93 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R93 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_93 = []
st_93 = []
n = 1
while n < len(B93):
    sc_93 = ''
    if B93[n] > B93[n-1]:
        sc_93 = sc_93 + 'B'
    if H93[n] > H93[n-1]:
        sc_93 = sc_93 + 'H'
    if J93[n] > J93[n-1]:
        sc_93 = sc_93 + 'J'
    if M93[n] > M93[n-1]:
        sc_93 = sc_93 + 'M'
    if R93[n] > R93[n-1]:
        sc_93 = sc_93 + 'R'
    if len(sc_93) > 0:
        st_93.append(sc_93)
    else:
        STC_93.append(st_93)
        st_93 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_93 = STC_93.count([])
# keep only non-empty spatio-temporal sequences
STC_93 = [ st_93 for st_93 in STC_93 if len(st_93) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_93 = len(B93)
lmax_93 = 0
for st_93 in STC_93:
    if len(st_93) < lmin_93:
        lmin_93 = len(st_93)
    if len(st_93) > lmax_93:
        lmax_93 = len(st_93)
        
# restrict spatio-temporal sequences to length-5
STC5_93 = [ st_93 for st_93 in STC_93 if len(st_93) <= 5 ]

# unpackk spatio-temporal sequences to temporal sequences
TC5_93 = []
for n in range(len(STC5_93)):
    tc_93 = [ u for u in STC5_93[n][0] ]
    for k in range(1, len(STC5_93[n])):
        tc_93 = [ u+v for u in tc_93 for v in STC5_93[n][k] ]
    TC5_93 = TC5_93 + tc_93
setTC5_93 = list(set(TC5_93))

# get empirical frequencies
fTC5_93 = [ TC5_93.count(setTC5_93[l]) for l in range(len(setTC5_93)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_93 = [ [] for l in range(len(setTC5_93)) ]
for s in range(100):
    STC5null_93 = [ list(st_93) for st_93 in STC5_93]
    for st_93 in STC5null_93:
        np.random.shuffle(st_93)
    TC5null_93= []
    for n in range(len(STC5null_93)):
        tc_93 = [ u for u in STC5null_93[n][0] ]
        for k in range(1, len(STC5null_93[n])):
            tc_93 = [ u+v for u in tc_93 for v in STC5null_93[n][k] ]
        TC5null_93= TC5null_93+ tc_93
    for l in range(len(setTC5_93)):
        if TC5null_93.count(setTC5_93[l]) > 0:
            fTC5null_93[l].append(TC5null_93.count(setTC5_93[l]))
        else:
            fTC5null_93[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_93)):
     if sum(freq >= fTC5_93[l] for freq in fTC5null_93[l]) < 5:
#         print(setTC5_93[l], fTC5_93[l], sum(freq >= fTC5_93[l] for freq in fTC5null_93[l]))
        print(setTC5_93[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# RMJH
# BJJHM
# HHMH
# RMMBH
# RMJBJ
# MMJH
# BJJHH
# JMJR
# BJJHR
# MMMH
# RBMBM
# BBJRH
# RJHMM
# RRJB
# RMBBM
# RBMBJ
# JMJB
# BBJHR
# RBMMB
# RJJHJ
# RBJRJ
# MRJB
# RMHBM
# RMMBJ
# JMJBH
# RJMMM
# BBJBJ
# JMJBM
# HBRHR
# BBJHJ
# JMJBJ
# RMMBM
# MJBBM
# BJJRH
# JM
# RBMBB
# MJBBR
# HJHHR
# RMRMJ
# JMMB
# RJJRJ
# BJBHJ
# BBJMH
# BJJMH
# RHMH
# BBRHR
# RBJB
# HJHMR
# RJBBR
# JMBJ
# RMRBH
# RBMMM
# BBJRJ
# RMJBM
# BMRB
# RJBHJ
# RMRBM
# JHJH
# RRMMM
# MBJBJ
# BBJHH
# JMRH
# RBHMM
# MMRB
# RMJBH
# RRMH
# JMBBM
# HMBJ
# BJJHJ
# RMMMJ
# MMJR
# JRMH
# MMBHM
# BRM
# JMJH
# RJBJR
# JHMH
# BBBRJ
# MBJRJ
# RMJMJ
# RMRBJ
# MMJB
# RM
# RMJB
# JMMH

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_93)):
     if sum(freq >= fTC5_93[l] for freq in fTC5null_93[l]) < 1:
#         print(setTC5_93[l], fTC5_93[l], sum(freq >= fTC5_93[l] for freq in fTC5null_93[l]))
        print(setTC5_93[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# RMMBH
# MMJH
# JMJR
# BBJRH
# JMJB
# RJJHJ
# MRJB
# RMMBJ
# JMJBH
# BBJBJ
# BBJHJ
# RMMBM
# BBJRJ
# JMJH
# JHMH
# RMRBJ
# MMJB
# JMMH

# %% [markdown]
# # 3.94 (B) AP - (H) BLOOM - (J) FGEN - (M) ICT - (Y) SMC

# %%
#extract overlapping dates
start_94 = max(min(Date_AP), min(Date_BLOOM), min(Date_FGEN), min(Date_ICT), min(Date_SMC))
end_94 = min(max(Date_AP), max(Date_BLOOM), max(Date_FGEN), max(Date_ICT), max(Date_SMC))

# %%
#shorten the closing prices
AP_94_1 = Date_AP.index(start_94)
AP_94_2 = Date_AP.index(end_94)

BLOOM_94_1 = Date_BLOOM.index(start_94)
BLOOM_94_2 = Date_BLOOM.index(end_94)

FGEN_94_1 = Date_FGEN.index(start_94)
FGEN_94_2 = Date_FGEN.index(end_94)

ICT_94_1 = Date_ICT.index(start_94)
ICT_94_2 = Date_ICT.index(end_94)

SMC_94_1 = Date_SMC.index(start_94)
SMC_94_2 = Date_SMC.index(end_94)

# %%
#save the shortened versions of closing prices
B94 = np.save('APshortPrices.npy', ClosePrice_AP[AP_94_1:AP_94_2])
H94 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_94_1:BLOOM_94_2])
J94 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_94_1:FGEN_94_2])
M94 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_94_1:ICT_94_2])
Y94 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_94_1:SMC_94_2])

# %%
# import modules
import numpy as np
# import prices

B94 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
H94 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J94 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M94 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
Y94 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_94 = []
st_94 = []
n = 1
while n < len(B94):
    sc_94 = ''
    if B94[n] > B94[n-1]:
        sc_94 = sc_94 + 'B'
    if H94[n] > H94[n-1]:
        sc_94 = sc_94 + 'H'
    if J94[n] > J94[n-1]:
        sc_94 = sc_94 + 'J'
    if M94[n] > M94[n-1]:
        sc_94 = sc_94 + 'M'
    if Y94[n] > Y94[n-1]:
        sc_94 = sc_94 + 'Y'
    if len(sc_94) > 0:
        st_94.append(sc_94)
    else:
        STC_94.append(st_94)
        st_94 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_94 = STC_94.count([])
# keep only non-empty spatio-temporal sequences
STC_94 = [ st_94 for st_94 in STC_94 if len(st_94) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_94 = len(B94)
lmax_94 = 0
for st_94 in STC_94:
    if len(st_94) < lmin_94:
        lmin_94 = len(st_94)
    if len(st_94) > lmax_94:
        lmax_94 = len(st_94)
        
# restrict spatio-temporal sequences to length-5
STC5_94 = [ st_94 for st_94 in STC_94 if len(st_94) <= 5 ]

# unpackk spatio-temporal sequences to temporal sequences
TC5_94 = []
for n in range(len(STC5_94)):
    tc_94 = [ u for u in STC5_94[n][0] ]
    for k in range(1, len(STC5_94[n])):
        tc_94 = [ u+v for u in tc_94 for v in STC5_94[n][k] ]
    TC5_94 = TC5_94 + tc_94
setTC5_94 = list(set(TC5_94))

# get empirical frequencies
fTC5_94 = [ TC5_94.count(setTC5_94[l]) for l in range(len(setTC5_94)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_94 = [ [] for l in range(len(setTC5_94)) ]
for s in range(100):
    STC5null_94 = [ list(st_94) for st_94 in STC5_94]
    for st_94 in STC5null_94:
        np.random.shuffle(st_94)
    TC5null_94= []
    for n in range(len(STC5null_94)):
        tc_94 = [ u for u in STC5null_94[n][0] ]
        for k in range(1, len(STC5null_94[n])):
            tc_94 = [ u+v for u in tc_94 for v in STC5null_94[n][k] ]
        TC5null_94= TC5null_94+ tc_94
    for l in range(len(setTC5_94)):
        if TC5null_94.count(setTC5_94[l]) > 0:
            fTC5null_94[l].append(TC5null_94.count(setTC5_94[l]))
        else:
            fTC5null_94[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_94)):
     if sum(freq >= fTC5_94[l] for freq in fTC5null_94[l]) < 5:
#         print(setTC5_94[l], fTC5_94[l], sum(freq >= fTC5_94[l] for freq in fTC5null_94[l]))
        print(setTC5_94[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# HBYJ
# YMBB
# YYJBM
# BMMBM
# BMBBM
# JMJYH
# HMMYJ
# JBMHM
# MHH
# JMJBH
# MBHYB
# HMHYM
# JMJBJ
# HBHMB
# HMMYM
# BYM
# HMHYJ
# HJYYJ
# MYJYM
# MBHYM
# MMHYB
# HBMMM
# BMJYH
# YHBH
# MYHY
# JMJYJ
# JHJH
# BYJYM
# HHHMB
# HHYMB
# JBHYM
# YYBJ
# MHHMB
# YBMBJ
# JMJH
# MYJYY
# JHMH
# YMBJ
# MHYMB

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_94)):
     if sum(freq >= fTC5_94[l] for freq in fTC5null_94[l]) < 1:
#         print(setTC5_94[l], fTC5_94[l], sum(freq >= fTC5_94[l] for freq in fTC5null_94[l]))
        print(setTC5_94[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# JMJYH
# MHH
# JMJBH
# HMHYM
# JMJBJ
# HMMYM
# HMHYJ
# HHHMB
# JBHYM

# %% [markdown]
# # 3.95 (B) AP - (H) BLOOM - (J) FGEN - (M) ICT - (α) SCC

# %%
#extract overlapping dates
start_95 = max(min(Date_AP), min(Date_BLOOM), min(Date_FGEN), min(Date_ICT), min(Date_SCC))
end_95 = min(max(Date_AP), max(Date_BLOOM), max(Date_FGEN), max(Date_ICT), max(Date_SCC))

# %%
#shorten the closing prices
AP_95_1 = Date_AP.index(start_95)
AP_95_2 = Date_AP.index(end_95)

BLOOM_95_1 = Date_BLOOM.index(start_95)
BLOOM_95_2 = Date_BLOOM.index(end_95)

FGEN_95_1 = Date_FGEN.index(start_95)
FGEN_95_2 = Date_FGEN.index(end_95)

ICT_95_1 = Date_ICT.index(start_95)
ICT_95_2 = Date_ICT.index(end_95)

SCC_95_1 = Date_SCC.index(start_95)
SCC_95_2 = Date_SCC.index(end_95)

# %%
#save the shortened versions of closing prices
B95 = np.save('APshortPrices.npy', ClosePrice_AP[AP_95_1:AP_95_2])
H95 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_95_1:BLOOM_95_2])
J95 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_95_1:FGEN_95_2])
M95 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_95_1:ICT_95_2])
α95 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_95_1:SCC_95_2])

# %%
# import modules
import numpy as np
# import prices

B95 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
H95 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J95 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M95 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
α95 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_95 = []
st_95 = []
n = 1
while n < len(B95):
    sc_95 = ''
    if B95[n] > B95[n-1]:
        sc_95 = sc_95 + 'B'
    if H95[n] > H95[n-1]:
        sc_95 = sc_95 + 'H'
    if J95[n] > J95[n-1]:
        sc_95 = sc_95 + 'J'
    if M95[n] > M95[n-1]:
        sc_95 = sc_95 + 'M'
    if α95[n] > α95[n-1]:
        sc_95 = sc_95 + 'α'
    if len(sc_95) > 0:
        st_95.append(sc_95)
    else:
        STC_95.append(st_95)
        st_95 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_95 = STC_95.count([])
# keep only non-empty spatio-temporal sequences
STC_95 = [ st_95 for st_95 in STC_95 if len(st_95) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_95 = len(B95)
lmax_95 = 0
for st_95 in STC_95:
    if len(st_95) < lmin_95:
        lmin_95 = len(st_95)
    if len(st_95) > lmax_95:
        lmax_95 = len(st_95)
        
# restrict spatio-temporal sequences to length-5
STC5_95 = [ st_95 for st_95 in STC_95 if len(st_95) <= 5 ]

# unpackk spatio-temporal sequences to temporal sequences
TC5_95 = []
for n in range(len(STC5_95)):
    tc_95 = [ u for u in STC5_95[n][0] ]
    for k in range(1, len(STC5_95[n])):
        tc_95 = [ u+v for u in tc_95 for v in STC5_95[n][k] ]
    TC5_95 = TC5_95 + tc_95
setTC5_95 = list(set(TC5_95))

# get empirical frequencies
fTC5_95 = [ TC5_95.count(setTC5_95[l]) for l in range(len(setTC5_95)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_95 = [ [] for l in range(len(setTC5_95)) ]
for s in range(100):
    STC5null_95 = [ list(st_95) for st_95 in STC5_95]
    for st_95 in STC5null_95:
        np.random.shuffle(st_95)
    TC5null_95= []
    for n in range(len(STC5null_95)):
        tc_95 = [ u for u in STC5null_95[n][0] ]
        for k in range(1, len(STC5null_95[n])):
            tc_95 = [ u+v for u in tc_95 for v in STC5null_95[n][k] ]
        TC5null_95= TC5null_95+ tc_95
    for l in range(len(setTC5_95)):
        if TC5null_95.count(setTC5_95[l]) > 0:
            fTC5null_95[l].append(TC5null_95.count(setTC5_95[l]))
        else:
            fTC5null_95[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_95)):
     if sum(freq >= fTC5_95[l] for freq in fTC5null_95[l]) < 5:
#         print(setTC5_95[l], fTC5_95[l], sum(freq >= fTC5_95[l] for freq in fTC5null_95[l]))
        print(setTC5_95[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# JMHBJ
# αMJB
# BJMBJ
# JMααM
# αMHαM
# JMBαJ
# BJBHM
# JMHHM
# JMBαM
# αHBJJ
# BMMBM
# JMBHM
# JBαHα
# JMJαM
# JMHαJ
# αMJH
# JJJα
# BMBBM
# αMHBM
# αJMBJ
# JJBHM
# MBαBα
# αMBBM
# JBMHM
# αMHαJ
# αMHBJ
# MHH
# JMJBH
# HαααJ
# JMMαJ
# HHMαB
# αMMBM
# BMBBJ
# αMBαM
# MHJ
# BMHαJ
# JHBJJ
# JMαBα
# αHHα
# JMHBM
# αMHαα
# αMHBα
# JMBBJ
# αJBBM
# HHααJ
# JBHαα
# ααJB
# MHHα
# αMJBM
# JMBHJ
# αMααα
# BJBHJ
# JαHαJ
# ααBBJ
# αMJαM
# HHMαJ
# αMMαJ
# JHBHM
# JJHHM
# MMHαα
# JMHJM
# JMBBα
# αMHHB
# JJHαJ
# ααBJJ
# αMJαJ
# JHBH
# BJBBJ
# αJBBJ
# ααααJ
# αMMBJ
# αMBαJ
# HJHαM
# BMBHJ
# JBHHα
# HHMαα
# JMMBM
# αMMαM
# JMHHB
# αHMα
# ααMBJ
# MMHMα
# JMHBα
# JJBHJ
# JMααα
# JMBBM
# JMHαM
# HMHαM
# MBHαα
# JMHαα
# αMBBJ
# MBHMα
# BαM
# JMMαM
# BJHHJ
# JαBαJ
# MHα
# JHHHM
# ααBHJ
# JJHαM
# BHααJ
# MMJB
# JBHMα
# JBHBα

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_95)):
     if sum(freq >= fTC5_95[l] for freq in fTC5null_95[l]) < 1:
#         print(setTC5_95[l], fTC5_95[l], sum(freq >= fTC5_95[l] for freq in fTC5null_95[l]))
        print(setTC5_95[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# αMHαM
# JMHHM
# JMBHM
# JMHαJ
# JJJα
# BMBBM
# αMMBM
# αHHα
# JMHBM
# αMHαα
# αMHBα
# HHααJ
# BJBHJ
# JαHαJ
# BJBBJ
# JBHHα
# JJBHJ
# JMBBM
# JMHαM
# JMHαα
# MMJB
# JBHBα

# %% [markdown]
# # 3.96 (B) AP - (H) BLOOM - (J) FGEN - (N) JGS - (R) MEG

# %%
#extract overlapping dates
start_96 = max(min(Date_AP), min(Date_BLOOM), min(Date_FGEN), min(Date_JGS), min(Date_MEG))
end_96 = min(max(Date_AP), max(Date_BLOOM), max(Date_FGEN), max(Date_JGS), max(Date_MEG))

# %%
#shorten the closing prices
AP_96_1 = Date_AP.index(start_96)
AP_96_2 = Date_AP.index(end_96)

BLOOM_96_1 = Date_BLOOM.index(start_96)
BLOOM_96_2 = Date_BLOOM.index(end_96)

FGEN_96_1 = Date_FGEN.index(start_96)
FGEN_96_2 = Date_FGEN.index(end_96)

JGS_96_1 = Date_JGS.index(start_96)
JGS_96_2 = Date_JGS.index(end_96)

MEG_96_1 = Date_MEG.index(start_96)
MEG_96_2 = Date_MEG.index(end_96)

# %%
#save the shortened versions of closing prices
B96 = np.save('APshortPrices.npy', ClosePrice_AP[AP_96_1:AP_96_2])
H96 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_96_1:BLOOM_96_2])
J96 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_96_1:FGEN_96_2])
N96 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_96_1:JGS_96_2])
R96 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_96_1:MEG_96_2])

# %%
# import modules
import numpy as np
# import prices

B96 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
H96 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J96 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N96 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R96 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_96 = []
st_96 = []
n = 1
while n < len(B96):
    sc_96 = ''
    if B96[n] > B96[n-1]:
        sc_96 = sc_96 + 'B'
    if H96[n] > H96[n-1]:
        sc_96 = sc_96 + 'H'
    if J96[n] > J96[n-1]:
        sc_96 = sc_96 + 'J'
    if N96[n] > N96[n-1]:
        sc_96 = sc_96 + 'N'
    if R96[n] > R96[n-1]:
        sc_96 = sc_96 + 'R'
    if len(sc_96) > 0:
        st_96.append(sc_96)
    else:
        STC_96.append(st_96)
        st_96 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_96 = STC_96.count([])
# keep only non-empty spatio-temporal sequences
STC_96 = [ st_96 for st_96 in STC_96 if len(st_96) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_96 = len(B96)
lmax_96 = 0
for st_96 in STC_96:
    if len(st_96) < lmin_96:
        lmin_96 = len(st_96)
    if len(st_96) > lmax_96:
        lmax_96 = len(st_96)
        
# restrJGS spatio-temporal sequences to length-5
STC5_96 = [ st_96 for st_96 in STC_96 if len(st_96) <= 5 ]

# unpackk spatio-temporal sequences to temporal sequences
TC5_96 = []
for n in range(len(STC5_96)):
    tc_96 = [ u for u in STC5_96[n][0] ]
    for k in range(1, len(STC5_96[n])):
        tc_96 = [ u+v for u in tc_96 for v in STC5_96[n][k] ]
    TC5_96 = TC5_96 + tc_96
setTC5_96 = list(set(TC5_96))

# get empirical frequencies
fTC5_96 = [ TC5_96.count(setTC5_96[l]) for l in range(len(setTC5_96)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_96 = [ [] for l in range(len(setTC5_96)) ]
for s in range(100):
    STC5null_96 = [ list(st_96) for st_96 in STC5_96]
    for st_96 in STC5null_96:
        np.random.shuffle(st_96)
    TC5null_96= []
    for n in range(len(STC5null_96)):
        tc_96 = [ u for u in STC5null_96[n][0] ]
        for k in range(1, len(STC5null_96[n])):
            tc_96 = [ u+v for u in tc_96 for v in STC5null_96[n][k] ]
        TC5null_96= TC5null_96+ tc_96
    for l in range(len(setTC5_96)):
        if TC5null_96.count(setTC5_96[l]) > 0:
            fTC5null_96[l].append(TC5null_96.count(setTC5_96[l]))
        else:
            fTC5null_96[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_96)):
     if sum(freq >= fTC5_96[l] for freq in fTC5null_96[l]) < 5:
#         print(setTC5_96[l], fTC5_96[l], sum(freq >= fTC5_96[l] for freq in fTC5null_96[l]))
        print(setTC5_96[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# NRHB
# HHJNJ
# RJJRR
# JJJN
# HJHNH
# NJJHH
# RHHNJ
# HHHNB
# NJBJR
# HRNRB
# RJHHH
# RBNRH
# RBJHR
# NJJHR
# NRBJJ
# RNBJR
# JRJH
# HHHNJ
# NNJHR
# RJJHJ
# RHJNR
# NJJNH
# HHJNR
# NJBBH
# NJBHJ
# BBNRB
# NJJNJ
# NBJNH
# BHR
# NRRB
# RHNRB
# RNBJN
# NBNRH
# RNHNJ
# RJBBB
# RJJNH
# NJJNR
# NJJHJ
# RNBBR
# BBJRB
# NJBBR
# HHHNH
# RJJNJ
# RJHNJ
# JRJB
# JJBJR
# RJJRJ
# RRRH
# NRBB
# RRHB
# HHJNB
# RHJNH
# RNBHJ
# RJBBR
# BBRRB
# NHBNJ
# RNNRH
# BRNRB
# JRJN
# RJBHJ
# NBJHR
# NJHBB
# RJJHR
# NJJJJ
# NNBHR
# JNBH
# JHBR
# JHBH
# JNBJR
# NHNH
# RNHHH
# RHHNH
# NRBJR
# NHBHJ
# HHJNH
# JHJH
# RRRN
# RJHBB
# NBNRJ
# NHBJJ
# JRBN
# RJJRB
# NNBJJ
# RBJHJ
# RJBJN
# NNBBR
# RJHNB
# RNJHJ
# RHBHJ
# HHJRR
# NNBHJ
# JNJH
# RHHNB
# RJBJR
# RJJHH
# RRJN
# JRRN
# NJJBH
# RJHRB
# NHBJR
# JHNH
# NNBJR
# HRRH
# NRJJJ
# NHJNH
# NRNH

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_96)):
     if sum(freq >= fTC5_96[l] for freq in fTC5null_96[l]) < 1:
#         print(setTC5_96[l], fTC5_96[l], sum(freq >= fTC5_96[l] for freq in fTC5null_96[l]))
        print(setTC5_96[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# NJBJR
# RJHHH
# RBNRH
# RBJHR
# NJJHR
# RJJHJ
# NJJNH
# BBNRB
# NJBBR
# RJJNJ
# RJHNJ
# RJJHR
# JHBH
# JHJH
# RRRN
# RJHBB
# RJHNB
# RJBJR
# HRRH

# %% [markdown]
# # 3.97 (B) AP - (H) BLOOM - (J) FGEN - (N) JGS - (Y) SMC

# %%
#extract overlapping dates
start_97 = max(min(Date_AP), min(Date_BLOOM), min(Date_FGEN), min(Date_JGS), min(Date_SMC))
end_97 = min(max(Date_AP), max(Date_BLOOM), max(Date_FGEN), max(Date_JGS), max(Date_SMC))

# %%
#shorten the closing prices
AP_97_1 = Date_AP.index(start_97)
AP_97_2 = Date_AP.index(end_97)

BLOOM_97_1 = Date_BLOOM.index(start_97)
BLOOM_97_2 = Date_BLOOM.index(end_97)

FGEN_97_1 = Date_FGEN.index(start_97)
FGEN_97_2 = Date_FGEN.index(end_97)

JGS_97_1 = Date_JGS.index(start_97)
JGS_97_2 = Date_JGS.index(end_97)

SMC_97_1 = Date_SMC.index(start_97)
SMC_97_2 = Date_SMC.index(end_97)

# %%
#save the shortened versions of closing prices
B97 = np.save('APshortPrices.npy', ClosePrice_AP[AP_97_1:AP_97_2])
H97 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_97_1:BLOOM_97_2])
J97 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_97_1:FGEN_97_2])
N97 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_97_1:JGS_97_2])
Y97 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_97_1:SMC_97_2])

# %%
# import modules
import numpy as np
# import prices

B97 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
H97 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J97 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N97 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y97 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_97 = []
st_97 = []
n = 1
while n < len(B97):
    sc_97 = ''
    if B97[n] > B97[n-1]:
        sc_97 = sc_97 + 'B'
    if H97[n] > H97[n-1]:
        sc_97 = sc_97 + 'H'
    if J97[n] > J97[n-1]:
        sc_97 = sc_97 + 'J'
    if N97[n] > N97[n-1]:
        sc_97 = sc_97 + 'N'
    if Y97[n] > Y97[n-1]:
        sc_97 = sc_97 + 'Y'
    if len(sc_97) > 0:
        st_97.append(sc_97)
    else:
        STC_97.append(st_97)
        st_97 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_97 = STC_97.count([])
# keep only non-empty spatio-temporal sequences
STC_97 = [ st_97 for st_97 in STC_97 if len(st_97) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_97 = len(B97)
lmax_97 = 0
for st_97 in STC_97:
    if len(st_97) < lmin_97:
        lmin_97 = len(st_97)
    if len(st_97) > lmax_97:
        lmax_97 = len(st_97)
        
# restrJGS spatio-temporal sequences to length-5
STC5_97 = [ st_97 for st_97 in STC_97 if len(st_97) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_97 = []
for n in range(len(STC5_97)):
    tc_97 = [ u for u in STC5_97[n][0] ]
    for k in range(1, len(STC5_97[n])):
        tc_97 = [ u+v for u in tc_97 for v in STC5_97[n][k] ]
    TC5_97 = TC5_97 + tc_97
setTC5_97 = list(set(TC5_97))

# get empirical frequencies
fTC5_97 = [ TC5_97.count(setTC5_97[l]) for l in range(len(setTC5_97)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_97 = [ [] for l in range(len(setTC5_97)) ]
for s in range(100):
    STC5null_97 = [ list(st_97) for st_97 in STC5_97]
    for st_97 in STC5null_97:
        np.random.shuffle(st_97)
    TC5null_97= []
    for n in range(len(STC5null_97)):
        tc_97 = [ u for u in STC5null_97[n][0] ]
        for k in range(1, len(STC5null_97[n])):
            tc_97 = [ u+v for u in tc_97 for v in STC5null_97[n][k] ]
        TC5null_97= TC5null_97+ tc_97
    for l in range(len(setTC5_97)):
        if TC5null_97.count(setTC5_97[l]) > 0:
            fTC5null_97[l].append(TC5null_97.count(setTC5_97[l]))
        else:
            fTC5null_97[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_97)):
     if sum(freq >= fTC5_97[l] for freq in fTC5null_97[l]) < 5:
#         print(setTC5_97[l], fTC5_97[l], sum(freq >= fTC5_97[l] for freq in fTC5null_97[l]))
        print(setTC5_97[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# NJBNH
# HNJYY
# HJJYY
# JYJN
# HBYJB
# HHYNY
# HJHNB
# NJJNB
# NNYH
# NJHBY
# NJBYH
# HHJNY
# YBYH
# NNJNY
# NBYH
# BJYJB
# HBYYB
# NJJNH
# NHJHY
# HHYJB
# NJBBH
# JBJHY
# HHJBY
# NJJNJ
# NJJBY
# YYYN
# YYBB
# HNHNB
# YBBN
# NNJHY
# NJBHB
# NNJH
# BJY
# YYBN
# NNBHY
# JNJ
# NNJNH
# NYNHY
# NHJH
# BJYJY
# NJJNY
# HBYNB
# NHJBH
# HNJNY
# HHYNB
# NBBJJ
# BJJYB
# NJJHY
# YJY
# BNY
# YHBH
# BJNYB
# NJHBB
# BBYHB
# NJJJJ
# JBJN
# HJYJB
# JHJH
# NNBH
# NJYJY
# JBJH
# NNBNH
# NJBHH
# YYBJ
# NHJNY
# NJBBY
# HJJNY
# JNJH
# NNHH
# HHHNY
# NJJBH
# NJJJY
# JYNHY
# NJBHY
# NHJNH

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_97)):
     if sum(freq >= fTC5_97[l] for freq in fTC5null_97[l]) < 1:
#         print(setTC5_97[l], fTC5_97[l], sum(freq >= fTC5_97[l] for freq in fTC5null_97[l]))
        print(setTC5_97[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# NJBNH
# HHYNY
# NJJNB
# NJJNH
# HHYJB
# HHJBY
# NJJBY
# NNJHY
# NNJH
# NJJNY
# BJJYB
# NJJHY
# BBYHB
# NJJJJ
# JHJH
# NNBH
# NJYJY
# YYBJ
# JNJH
# NJBHY
# NHJNH

# %% [markdown]
# # 3.98 (B) AP - (H) BLOOM - (J) FGEN - (N) JGS - (α) SCC

# %%
#extract overlapping dates
start_98 = max(min(Date_AP), min(Date_BLOOM), min(Date_FGEN), min(Date_JGS), min(Date_SCC))
end_98 = min(max(Date_AP), max(Date_BLOOM), max(Date_FGEN), max(Date_JGS), max(Date_SCC))

# %%
#shorten the closing prices
AP_98_1 = Date_AP.index(start_98)
AP_98_2 = Date_AP.index(end_98)

BLOOM_98_1 = Date_BLOOM.index(start_98)
BLOOM_98_2 = Date_BLOOM.index(end_98)

FGEN_98_1 = Date_FGEN.index(start_98)
FGEN_98_2 = Date_FGEN.index(end_98)

JGS_98_1 = Date_JGS.index(start_98)
JGS_98_2 = Date_JGS.index(end_98)

SCC_98_1 = Date_SCC.index(start_98)
SCC_98_2 = Date_SCC.index(end_98)

# %%
#save the shortened versions of closing prices
B98 = np.save('APshortPrices.npy', ClosePrice_AP[AP_98_1:AP_98_2])
H98 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_98_1:BLOOM_98_2])
J98 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_98_1:FGEN_98_2])
N98 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_98_1:JGS_98_2])
α98 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_98_1:SCC_98_2])

# %%
# import modules
import numpy as np
# import prices

B98 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
H98 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J98 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N98 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
α98 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_98 = []
st_98 = []
n = 1
while n < len(B98):
    sc_98 = ''
    if B98[n] > B98[n-1]:
        sc_98 = sc_98 + 'B'
    if H98[n] > H98[n-1]:
        sc_98 = sc_98 + 'H'
    if J98[n] > J98[n-1]:
        sc_98 = sc_98 + 'J'
    if N98[n] > N98[n-1]:
        sc_98 = sc_98 + 'N'
    if α98[n] > α98[n-1]:
        sc_98 = sc_98 + 'α'
    if len(sc_98) > 0:
        st_98.append(sc_98)
    else:
        STC_98.append(st_98)
        st_98 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_98 = STC_98.count([])
# keep only non-empty spatio-temporal sequences
STC_98 = [ st_98 for st_98 in STC_98 if len(st_98) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_98 = len(B98)
lmax_98 = 0
for st_98 in STC_98:
    if len(st_98) < lmin_98:
        lmin_98 = len(st_98)
    if len(st_98) > lmax_98:
        lmax_98 = len(st_98)
        
# restrict spatio-temporal sequences to length-5
STC5_98 = [ st_98 for st_98 in STC_98 if len(st_98) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_98 = []
for n in range(len(STC5_98)):
    tc_98 = [ u for u in STC5_98[n][0] ]
    for k in range(1, len(STC5_98[n])):
        tc_98 = [ u+v for u in tc_98 for v in STC5_98[n][k] ]
    TC5_98 = TC5_98 + tc_98
setTC5_98 = list(set(TC5_98))

# get empirical frequencies
fTC5_98 = [ TC5_98.count(setTC5_98[l]) for l in range(len(setTC5_98)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_98 = [ [] for l in range(len(setTC5_98)) ]
for s in range(100):
    STC5null_98 = [ list(st_98) for st_98 in STC5_98]
    for st_98 in STC5null_98:
        np.random.shuffle(st_98)
    TC5null_98= []
    for n in range(len(STC5null_98)):
        tc_98 = [ u for u in STC5null_98[n][0] ]
        for k in range(1, len(STC5null_98[n])):
            tc_98 = [ u+v for u in tc_98 for v in STC5null_98[n][k] ]
        TC5null_98= TC5null_98+ tc_98
    for l in range(len(setTC5_98)):
        if TC5null_98.count(setTC5_98[l]) > 0:
            fTC5null_98[l].append(TC5null_98.count(setTC5_98[l]))
        else:
            fTC5null_98[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_98)):
     if sum(freq >= fTC5_98[l] for freq in fTC5null_98[l]) < 5:
#         print(setTC5_98[l], fTC5_98[l], sum(freq >= fTC5_98[l] for freq in fTC5null_98[l]))
        print(setTC5_98[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# NNNBB
# HNBHH
# JJJN
# BNJHH
# HHHNB
# αNBHJ
# NNαH
# BJNBB
# BJJHH
# NαBJJ
# αHBJJ
# αHJH
# JJBα
# αJBHJ
# JJJα
# NHBH
# HHHNJ
# ααNαJ
# ααNH
# ααJH
# JBJα
# ααNBJ
# ααBNB
# ααHH
# NαBH
# JNJHH
# NαJJJ
# HαBHH
# NBBN
# ααJNB
# HBBHH
# BJNNH
# NNJH
# αNJH
# BJNHH
# HHααJ
# ααNJJ
# NαNαJ
# NαNα
# BNJHB
# JαNNB
# BJBBB
# ααJJJ
# BNBHα
# NBJH
# NHJH
# NαJH
# JαJH
# ααNJB
# HHHNα
# αHBHJ
# ααNNJ
# NNNαJ
# ααNNB
# αJNNJ
# αJJHJ
# JNBH
# ααBJJ
# BJJNH
# JHBH
# BJBBJ
# NJJH
# ααNBB
# JαJHH
# JαBH
# αBJN
# ααJJB
# HHHNN
# NHBHJ
# ααNαB
# NNBH
# BBJHH
# NαNJB
# NαNJJ
# NHBJJ
# αBBJJ
# NNBJJ
# HαJHH
# NαHH
# JNBHN
# αJJHH
# NNBHJ
# αNBJJ
# JαNH
# NJJN
# JNJH
# NNHH
# NαNH
# HNJHH
# NJNNH
# BJB
# ααJNJ
# HBJHH
# JαJHB
# NαJJB
# αJJHN
# JαJHN

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_98)):
     if sum(freq >= fTC5_98[l] for freq in fTC5null_98[l]) < 1:
#         print(setTC5_98[l], fTC5_98[l], sum(freq >= fTC5_98[l] for freq in fTC5null_98[l]))
        print(setTC5_98[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# JJJN
# BNJHH
# αNBHJ
# BJJHH
# αHBJJ
# JJJα
# NNJH
# NαNα
# NBJH
# NαJH
# ααNJB
# ααNNJ
# ααNNB
# ααBJJ
# ααNBB
# JNBHN
# NαNH

# %% [markdown]
# # 3.99 (B) AP - (H) BLOOM - (J) FGEN - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_99 = max(min(Date_AP), min(Date_BLOOM), min(Date_FGEN), min(Date_MEG), min(Date_SMC))
end_99 = min(max(Date_AP), max(Date_BLOOM), max(Date_FGEN), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
AP_99_1 = Date_AP.index(start_99)
AP_99_2 = Date_AP.index(end_99)

BLOOM_99_1 = Date_BLOOM.index(start_99)
BLOOM_99_2 = Date_BLOOM.index(end_99)

FGEN_99_1 = Date_FGEN.index(start_99)
FGEN_99_2 = Date_FGEN.index(end_99)

MEG_99_1 = Date_MEG.index(start_99)
MEG_99_2 = Date_MEG.index(end_99)

SMC_99_1 = Date_SMC.index(start_99)
SMC_99_2 = Date_SMC.index(end_99)

# %%
#save the shortened versions of closing prices
B99 = np.save('APshortPrices.npy', ClosePrice_AP[AP_99_1:AP_99_2])
H99 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_99_1:BLOOM_99_2])
J99 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_99_1:FGEN_99_2])
R99 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_99_1:MEG_99_2])
Y99 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_99_1:SMC_99_2])

# %%
# import modules
import numpy as np
# import prices

B99 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
H99 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J99 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
R99 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y99 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_99 = []
st_99 = []
n = 1
while n < len(B99):
    sc_99 = ''
    if B99[n] > B99[n-1]:
        sc_99 = sc_99 + 'B'
    if H99[n] > H99[n-1]:
        sc_99 = sc_99 + 'H'
    if J99[n] > J99[n-1]:
        sc_99 = sc_99 + 'J'
    if R99[n] > R99[n-1]:
        sc_99 = sc_99 + 'R'
    if Y99[n] > Y99[n-1]:
        sc_99 = sc_99 + 'Y'
    if len(sc_99) > 0:
        st_99.append(sc_99)
    else:
        STC_99.append(st_99)
        st_99 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_99 = STC_99.count([])
# keep only non-empty spatio-temporal sequences
STC_99 = [ st_99 for st_99 in STC_99 if len(st_99) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_99 = len(B99)
lmax_99 = 0
for st_99 in STC_99:
    if len(st_99) < lmin_99:
        lmin_99 = len(st_99)
    if len(st_99) > lmax_99:
        lmax_99 = len(st_99)
        
# restrict spatio-temporal sequences to length-5
STC5_99 = [ st_99 for st_99 in STC_99 if len(st_99) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_99 = []
for n in range(len(STC5_99)):
    tc_99 = [ u for u in STC5_99[n][0] ]
    for k in range(1, len(STC5_99[n])):
        tc_99 = [ u+v for u in tc_99 for v in STC5_99[n][k] ]
    TC5_99 = TC5_99 + tc_99
setTC5_99 = list(set(TC5_99))

# get empirical frequencies
fTC5_99 = [ TC5_99.count(setTC5_99[l]) for l in range(len(setTC5_99)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_99 = [ [] for l in range(len(setTC5_99)) ]
for s in range(100):
    STC5null_99 = [ list(st_99) for st_99 in STC5_99]
    for st_99 in STC5null_99:
        np.random.shuffle(st_99)
    TC5null_99= []
    for n in range(len(STC5null_99)):
        tc_99 = [ u for u in STC5null_99[n][0] ]
        for k in range(1, len(STC5null_99[n])):
            tc_99 = [ u+v for u in tc_99 for v in STC5null_99[n][k] ]
        TC5null_99= TC5null_99+ tc_99
    for l in range(len(setTC5_99)):
        if TC5null_99.count(setTC5_99[l]) > 0:
            fTC5null_99[l].append(TC5null_99.count(setTC5_99[l]))
        else:
            fTC5null_99[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_99)):
     if sum(freq >= fTC5_99[l] for freq in fTC5null_99[l]) < 5:
#         print(setTC5_99[l], fTC5_99[l], sum(freq >= fTC5_99[l] for freq in fTC5null_99[l]))
        print(setTC5_99[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# YBHRB
# RJHYJ
# RJHHY
# RRBHY
# RBBH
# HBYJB
# RJHHH
# HHYYB
# JYJB
# RBB
# JYYY
# RRJB
# HHBBY
# HJBJ
# JRJH
# RRJH
# YHRRY
# RJBBH
# YHH
# RJJHJ
# BJYJB
# RYJH
# RBYR
# HBYYB
# BBYHH
# RJYJY
# HHYJB
# JYJH
# RJHJY
# HBYHH
# YRRJY
# HBYRB
# BJYRB
# RHYRB
# RJBHH
# RRBHJ
# BBYJB
# RJYHY
# RYJY
# RYBY
# JBYR
# YJBBY
# YRRRY
# HHYJY
# RJHBY
# JRJB
# YHYRB
# YJYJB
# RHBHY
# RJJBB
# JYBY
# BHYRB
# RJBBY
# HHRRY
# YBYHB
# RJJHY
# HHYRY
# RJBHJ
# RJJJY
# BBYHB
# RJHYY
# RJBHY
# HYBY
# RHYJY
# RRBH
# YHYRY
# YRRBY
# HJYJB
# YRRJB
# JHJH
# YJJBY
# BBYRB
# RJHBB
# RYB
# JRJY
# YHYJB
# RJHBJ
# RJYRB
# YRRHJ
# RRB
# RJJBY
# BJJBJ
# RHYRY
# JYJY
# YJJJY
# BBBRJ
# HHYRB
# RHYYB
# YJRBY
# RJHYB
# YJRJY
# BBBBJ

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_99)):
     if sum(freq >= fTC5_99[l] for freq in fTC5null_99[l]) < 1:
#         print(setTC5_99[l], fTC5_99[l], sum(freq >= fTC5_99[l] for freq in fTC5null_99[l]))
        print(setTC5_99[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# RJHHY
# HBYJB
# RJHHH
# RBB
# JYYY
# RJJHJ
# BBYHH
# HHYJB
# HBYHH
# HBYRB
# RJHBY
# YHYRB
# YJYJB
# JYBY
# HHYRY
# RJBHJ
# RJJJY
# BBYHB
# RJBHY
# YHYRY
# RJHBB
# RJHBJ
# RJJBY
# HHYRB
# YJRBY

# %% [markdown]
# # 3.100 (B) AP - (H) BLOOM - (J) FGEN - (R) MEG - (α) SCC

# %%
#extract overlapping dates
start_100 = max(min(Date_AP), min(Date_BLOOM), min(Date_FGEN), min(Date_MEG), min(Date_SCC))
end_100 = min(max(Date_AP), max(Date_BLOOM), max(Date_FGEN), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
AP_100_1 = Date_AP.index(start_100)
AP_100_2 = Date_AP.index(end_100)

BLOOM_100_1 = Date_BLOOM.index(start_100)
BLOOM_100_2 = Date_BLOOM.index(end_100)

FGEN_100_1 = Date_FGEN.index(start_100)
FGEN_100_2 = Date_FGEN.index(end_100)

MEG_100_1 = Date_MEG.index(start_100)
MEG_100_2 = Date_MEG.index(end_100)

SCC_100_1 = Date_SCC.index(start_100)
SCC_100_2 = Date_SCC.index(end_100)

# %%
#save the shortened versions of closing prices
B100 = np.save('APshortPrices.npy', ClosePrice_AP[AP_100_1:AP_100_2])
H100 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_100_1:BLOOM_100_2])
J100 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_100_1:FGEN_100_2])
R100 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_100_1:MEG_100_2])
α100 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_100_1:SCC_100_2])

# %%
# import modules
import numpy as np
# import prices

B100 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
H100 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J100 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
R100 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α100 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_100 = []
st_100 = []
n = 1
while n < len(B100):
    sc_100 = ''
    if B100[n] > B100[n-1]:
        sc_100 = sc_100 + 'B'
    if H100[n] > H100[n-1]:
        sc_100 = sc_100 + 'H'
    if J100[n] > J100[n-1]:
        sc_100 = sc_100 + 'J'
    if R100[n] > R100[n-1]:
        sc_100 = sc_100 + 'R'
    if α100[n] > α100[n-1]:
        sc_100 = sc_100 + 'α'
    if len(sc_100) > 0:
        st_100.append(sc_100)
    else:
        STC_100.append(st_100)
        st_100 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_100 = STC_100.count([])
# keep only non-empty spatio-temporal sequences
STC_100 = [ st_100 for st_100 in STC_100 if len(st_100) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_100 = len(B100)
lmax_100 = 0
for st_100 in STC_100:
    if len(st_100) < lmin_100:
        lmin_100 = len(st_100)
    if len(st_100) > lmax_100:
        lmax_100 = len(st_100)
        
# restrict spatio-temporal sequences to length-5
STC5_100 = [ st_100 for st_100 in STC_100 if len(st_100) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_100 = []
for n in range(len(STC5_100)):
    tc_100 = [ u for u in STC5_100[n][0] ]
    for k in range(1, len(STC5_100[n])):
        tc_100 = [ u+v for u in tc_100 for v in STC5_100[n][k] ]
    TC5_100 = TC5_100 + tc_100
setTC5_100 = list(set(TC5_100))

# get empirical frequencies
fTC5_100 = [ TC5_100.count(setTC5_100[l]) for l in range(len(setTC5_100)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_100 = [ [] for l in range(len(setTC5_100)) ]
for s in range(100):
    STC5null_100 = [ list(st_100) for st_100 in STC5_100]
    for st_100 in STC5null_100:
        np.random.shuffle(st_100)
    TC5null_100= []
    for n in range(len(STC5null_100)):
        tc_100 = [ u for u in STC5null_100[n][0] ]
        for k in range(1, len(STC5null_100[n])):
            tc_100 = [ u+v for u in tc_100 for v in STC5null_100[n][k] ]
        TC5null_100= TC5null_100+ tc_100
    for l in range(len(setTC5_100)):
        if TC5null_100.count(setTC5_100[l]) > 0:
            fTC5null_100[l].append(TC5null_100.count(setTC5_100[l]))
        else:
            fTC5null_100[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_100)):
     if sum(freq >= fTC5_100[l] for freq in fTC5null_100[l]) < 5:
#         print(setTC5_100[l], fTC5_100[l], sum(freq >= fTC5_100[l] for freq in fTC5null_100[l]))
        print(setTC5_100[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# RBαRB
# RααRB
# RαBH
# JBH
# RBHαα
# HRαRB
# αHαRB
# RBHαB
# RBαBα
# αBJRJ
# αHBJJ
# BBJRH
# RJαRB
# αJBHJ
# JHBHJ
# αααRB
# JRJH
# RRJH
# αHαRJ
# BBαRH
# HαBB
# ααBH
# αBαBα
# RJJHJ
# αHBJR
# ααJH
# JαRH
# αHBHR
# HαHB
# HHαRB
# HHHRB
# BBJHJ
# HRαRα
# HαJB
# HHαRα
# αHBJα
# JBBR
# HJαJα
# RαRH
# αBJHJ
# HHααJ
# HHRRB
# RBααB
# RBHBα
# RαJB
# JαJB
# HHJRJ
# ααJB
# RRRH
# BJBHJ
# HJααR
# JαJH
# RRαRB
# BBRRB
# αHBHJ
# BBJRJ
# RJBHJ
# HHJRB
# JRBH
# RRαRα
# αJJHJ
# HHHαJ
# ααBJJ
# JRBB
# JHBR
# JHBH
# RRαBα
# ααRRB
# JαBH
# RRBH
# HααRB
# HHαRJ
# HJHαα
# HHαRH
# HRαBα
# BBJHH
# JαJR
# ααJR
# ααBB
# HJααα
# RBJHJ
# JJBHJ
# RαJH
# RαJR
# RJJJR
# BBαRB
# RJBJR
# JHH
# αJJHR
# ααBHJ
# ααRH

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_100)):
     if sum(freq >= fTC5_100[l] for freq in fTC5null_100[l]) < 1:
#         print(setTC5_100[l], fTC5_100[l], sum(freq >= fTC5_100[l] for freq in fTC5null_100[l]))
        print(setTC5_100[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# HRαRB
# RBHαB
# BBJRH
# JRJH
# ααBH
# RJJHJ
# ααJH
# αHBHR
# HαHB
# HHαRB
# HαJB
# HHRRB
# RαJB
# JαJH
# αHBHJ
# ααBJJ
# JαBH
# HHαRJ
# RBJHJ
# RαJH

# %% [markdown]
# # 3.101 (B) AP - (H) BLOOM - (J) FGEN - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_101 = max(min(Date_AP), min(Date_BLOOM), min(Date_FGEN), min(Date_SMC), min(Date_SCC))
end_101 = min(max(Date_AP), max(Date_BLOOM), max(Date_FGEN), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
AP_101_1 = Date_AP.index(start_101)
AP_101_2 = Date_AP.index(end_101)

BLOOM_101_1 = Date_BLOOM.index(start_101)
BLOOM_101_2 = Date_BLOOM.index(end_101)

FGEN_101_1 = Date_FGEN.index(start_101)
FGEN_101_2 = Date_FGEN.index(end_101)

SMC_101_1 = Date_SMC.index(start_101)
SMC_101_2 = Date_SMC.index(end_101)

SCC_101_1 = Date_SCC.index(start_101)
SCC_101_2 = Date_SCC.index(end_101)

# %%
#save the shortened versions of closing prices
B101 = np.save('APshortPrices.npy', ClosePrice_AP[AP_101_1:AP_101_2])
H101 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_101_1:BLOOM_101_2])
J101 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_101_1:FGEN_101_2])
Y101 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_101_1:SMC_101_2])
α101 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_101_1:SCC_101_2])

# %%
# import modules
import numpy as np
# import prices

B101 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
H101 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J101 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
Y101 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α101 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_101 = []
st_101 = []
n = 1
while n < len(B101):
    sc_101 = ''
    if B101[n] > B101[n-1]:
        sc_101 = sc_101 + 'B'
    if H101[n] > H101[n-1]:
        sc_101 = sc_101 + 'H'
    if J101[n] > J101[n-1]:
        sc_101 = sc_101 + 'J'
    if Y101[n] > Y101[n-1]:
        sc_101 = sc_101 + 'R'
    if α101[n] > α101[n-1]:
        sc_101 = sc_101 + 'α'
    if len(sc_101) > 0:
        st_101.append(sc_101)
    else:
        STC_101.append(st_101)
        st_101 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_101 = STC_101.count([])
# keep only non-empty spatio-temporal sequences
STC_101 = [ st_101 for st_101 in STC_101 if len(st_101) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_101 = len(B101)
lmax_101 = 0
for st_101 in STC_101:
    if len(st_101) < lmin_101:
        lmin_101 = len(st_101)
    if len(st_101) > lmax_101:
        lmax_101 = len(st_101)
        
# restrict spatio-temporal sequences to length-5
STC5_101 = [ st_101 for st_101 in STC_101 if len(st_101) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_101 = []
for n in range(len(STC5_101)):
    tc_101 = [ u for u in STC5_101[n][0] ]
    for k in range(1, len(STC5_101[n])):
        tc_101 = [ u+v for u in tc_101 for v in STC5_101[n][k] ]
    TC5_101 = TC5_101 + tc_101
setTC5_101 = list(set(TC5_101))

# get empirical frequencies
fTC5_101 = [ TC5_101.count(setTC5_101[l]) for l in range(len(setTC5_101)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_101 = [ [] for l in range(len(setTC5_101)) ]
for s in range(100):
    STC5null_101 = [ list(st_101) for st_101 in STC5_101]
    for st_101 in STC5null_101:
        np.random.shuffle(st_101)
    TC5null_101= []
    for n in range(len(STC5null_101)):
        tc_101 = [ u for u in STC5null_101[n][0] ]
        for k in range(1, len(STC5null_101[n])):
            tc_101 = [ u+v for u in tc_101 for v in STC5null_101[n][k] ]
        TC5null_101= TC5null_101+ tc_101
    for l in range(len(setTC5_101)):
        if TC5null_101.count(setTC5_101[l]) > 0:
            fTC5null_101[l].append(TC5null_101.count(setTC5_101[l]))
        else:
            fTC5null_101[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_101)):
     if sum(freq >= fTC5_101[l] for freq in fTC5null_101[l]) < 5:
#         print(setTC5_101[l], fTC5_101[l], sum(freq >= fTC5_101[l] for freq in fTC5null_101[l]))
        print(setTC5_101[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# αJBHR
# HαRRB
# BJJHH
# ααJHR
# RJJBR
# JRJH
# JαJJR
# ααBH
# ααBHR
# HJαBα
# RRHαR
# JJBHR
# HBRJ
# HBRRB
# αJBJR
# HJJRR
# RHαJB
# BJJRH
# αJJJR
# RRBB
# HHRRB
# RBααB
# HJRRB
# RαJB
# BαBHR
# ααJJJ
# HBRR
# BRαRB
# ααJB
# RHBH
# JαJHR
# JαJH
# RαHαR
# BBRRB
# ααBJR
# HHRαJ
# JRBH
# HHRJB
# αRJ
# JRBB
# JHBH
# HHRαα
# JBRRα
# JαBH
# ααJJB
# JBRH
# HJHαα
# JHJH
# RRααR
# JRRR
# ααJJR
# ααBB
# HJααα
# αBBJJ
# BJJHB
# αααR
# RHJH
# HJRαα
# JαBHR
# HBHαα
# BBαRB
# αHHR
# JHH
# HHαJB
# αJJHR
# RRBαR
# HHRαB

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_101)):
     if sum(freq >= fTC5_101[l] for freq in fTC5null_101[l]) < 1:
#         print(setTC5_101[l], fTC5_101[l], sum(freq >= fTC5_101[l] for freq in fTC5null_101[l]))
        print(setTC5_101[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# ααBHR
# RRHαR
# HBRRB
# HJRRB
# RHBH
# JRBH
# HHRJB
# JBRRα
# JαBH
# JHJH
# RRααR
# JαBHR
# BBαRB

# %% [markdown]
# # 3.102 (B) AP - (H) BLOOM - (M) ICT - (N) JGS - (R) MEG

# %%
#extract overlapping dates
start_102 = max(min(Date_AP), min(Date_BLOOM), min(Date_ICT), min(Date_JGS), min(Date_MEG))
end_102 = min(max(Date_AP), max(Date_BLOOM), max(Date_ICT), max(Date_JGS), max(Date_MEG))

# %%
#shorten the closing prices
AP_102_1 = Date_AP.index(start_102)
AP_102_2 = Date_AP.index(end_102)

BLOOM_102_1 = Date_BLOOM.index(start_102)
BLOOM_102_2 = Date_BLOOM.index(end_102)

ICT_102_1 = Date_ICT.index(start_102)
ICT_102_2 = Date_ICT.index(end_102)

JGS_102_1 = Date_JGS.index(start_102)
JGS_102_2 = Date_JGS.index(end_102)

MEG_102_1 = Date_MEG.index(start_102)
MEG_102_2 = Date_MEG.index(end_102)

# %%
#save the shortened versions of closing prices
B102 = np.save('APshortPrices.npy', ClosePrice_AP[AP_102_1:AP_102_2])
H102 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_102_1:BLOOM_102_2])
M102 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_102_1:ICT_102_2])
N102 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_102_1:JGS_102_2])
R102 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_102_1:MEG_102_2])

# %%
# import modules
import numpy as np
# import prices

B102 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
H102 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M102 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N102 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R102 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_102 = []
st_102 = []
n = 1
while n < len(B102):
    sc_102 = ''
    if B102[n] > B102[n-1]:
        sc_102 = sc_102 + 'B'
    if H102[n] > H102[n-1]:
        sc_102 = sc_102 + 'H'
    if M102[n] > M102[n-1]:
        sc_102 = sc_102 + 'M'
    if N102[n] > N102[n-1]:
        sc_102 = sc_102 + 'N'
    if R102[n] > R102[n-1]:
        sc_102 = sc_102 + 'R'
    if len(sc_102) > 0:
        st_102.append(sc_102)
    else:
        STC_102.append(st_102)
        st_102 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_102 = STC_102.count([])
# keep only non-empty spatio-temporal sequences
STC_102 = [ st_102 for st_102 in STC_102 if len(st_102) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_102 = len(B102)
lmax_102 = 0
for st_102 in STC_102:
    if len(st_102) < lmin_102:
        lmin_102 = len(st_102)
    if len(st_102) > lmax_102:
        lmax_102 = len(st_102)
        
# restrict spatio-temporal sequences to length-5
STC5_102 = [ st_102 for st_102 in STC_102 if len(st_102) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_102 = []
for n in range(len(STC5_102)):
    tc_102 = [ u for u in STC5_102[n][0] ]
    for k in range(1, len(STC5_102[n])):
        tc_102 = [ u+v for u in tc_102 for v in STC5_102[n][k] ]
    TC5_102 = TC5_102 + tc_102
setTC5_102 = list(set(TC5_102))

# get empirical frequencies
fTC5_102 = [ TC5_102.count(setTC5_102[l]) for l in range(len(setTC5_102)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_102 = [ [] for l in range(len(setTC5_102)) ]
for s in range(100):
    STC5null_102 = [ list(st_102) for st_102 in STC5_102]
    for st_102 in STC5null_102:
        np.random.shuffle(st_102)
    TC5null_102= []
    for n in range(len(STC5null_102)):
        tc_102 = [ u for u in STC5null_102[n][0] ]
        for k in range(1, len(STC5null_102[n])):
            tc_102 = [ u+v for u in tc_102 for v in STC5null_102[n][k] ]
        TC5null_102= TC5null_102+ tc_102
    for l in range(len(setTC5_102)):
        if TC5null_102.count(setTC5_102[l]) > 0:
            fTC5null_102[l].append(TC5null_102.count(setTC5_102[l]))
        else:
            fTC5null_102[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_102)):
     if sum(freq >= fTC5_102[l] for freq in fTC5null_102[l]) < 5:
#         print(setTC5_102[l], fTC5_102[l], sum(freq >= fTC5_102[l] for freq in fTC5null_102[l]))
        print(setTC5_102[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# RBMRN
# NRBNR
# MBNB
# HNNBN
# NMNH
# BHMRN
# BHMBB
# HHRNM
# HBMMN
# RH
# HNMBN
# RBB
# NBNMN
# NM
# HNMMM
# BHNRB
# HRHNM
# RNMRN
# RMRB
# BBNRB
# RMNB
# HNMNN
# RRMBN
# RBNB
# RMHBH
# RRMMN
# HHMNM
# MMNR
# BMM
# RBMMN
# BBRHR
# RMMMN
# NBNH
# HRMNM
# BRNRB
# NRMNR
# MMNB
# NMBBH
# HRMMM
# RNMMM
# MMBH
# HHMNN
# HRNRN
# MMNH
# RRBH
# RNMBN
# NRMBH
# HNHMM
# RRHH
# RNMBH
# MMRB
# RRMH
# NMBBM
# HRMRN
# MBRB
# RRMMB
# RBMBN
# MMRH
# BRNMB
# HRHMM
# BRM
# RNMRH
# BMNHH
# RRMBB
# HHMRN
# HRMBN
# NMRH
# RBNH
# NRNH

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_102)):
     if sum(freq >= fTC5_102[l] for freq in fTC5null_102[l]) < 1:
#         print(setTC5_102[l], fTC5_102[l], sum(freq >= fTC5_102[l] for freq in fTC5null_102[l]))
        print(setTC5_102[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# NRBNR
# RBB
# HNMMM
# BBNRB
# HHMNM
# MMNB
# NMBBH
# HRMMM
# HNHMM
# MMRB
# NMBBM
# HRMRN
# RBMBN
# BRNMB
# RBNH

# %% [markdown]
# # 3.103 (B) AP - (H) BLOOM - (M) ICT - (N) JGS - (Y) SMC

# %%
#extract overlapping dates
start_103 = max(min(Date_AP), min(Date_BLOOM), min(Date_ICT), min(Date_JGS), min(Date_SMC))
end_103 = min(max(Date_AP), max(Date_BLOOM), max(Date_ICT), max(Date_JGS), max(Date_SMC))

# %%
#shorten the closing prices
AP_103_1 = Date_AP.index(start_103)
AP_103_2 = Date_AP.index(end_103)

BLOOM_103_1 = Date_BLOOM.index(start_103)
BLOOM_103_2 = Date_BLOOM.index(end_103)

ICT_103_1 = Date_ICT.index(start_103)
ICT_103_2 = Date_ICT.index(end_103)

JGS_103_1 = Date_JGS.index(start_103)
JGS_103_2 = Date_JGS.index(end_103)

SMC_103_1 = Date_SMC.index(start_103)
SMC_103_2 = Date_SMC.index(end_103)

# %%
#save the shortened versions of closing prices
B103 = np.save('APshortPrices.npy', ClosePrice_AP[AP_103_1:AP_103_2])
H103 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_103_1:BLOOM_103_2])
M103 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_103_1:ICT_103_2])
N103 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_103_1:JGS_103_2])
Y103 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_103_1:SMC_103_2])

# %%
# import modules
import numpy as np
# import prices

B103 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
H103 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M103 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N103 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y103 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_103 = []
st_103 = []
n = 1
while n < len(B103):
    sc_103 = ''
    if B103[n] > B103[n-1]:
        sc_103 = sc_103 + 'B'
    if H103[n] > H103[n-1]:
        sc_103 = sc_103 + 'H'
    if M103[n] > M103[n-1]:
        sc_103 = sc_103 + 'M'
    if N103[n] > N103[n-1]:
        sc_103 = sc_103 + 'N'
    if Y103[n] > Y103[n-1]:
        sc_103 = sc_103 + 'Y'
    if len(sc_103) > 0:
        st_103.append(sc_103)
    else:
        STC_103.append(st_103)
        st_103 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_103 = STC_103.count([])
# keep only non-empty spatio-temporal sequences
STC_103 = [ st_103 for st_103 in STC_103 if len(st_103) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_103 = len(B103)
lmax_103 = 0
for st_103 in STC_103:
    if len(st_103) < lmin_103:
        lmin_103 = len(st_103)
    if len(st_103) > lmax_103:
        lmax_103 = len(st_103)
        
# restrict spatio-temporal sequences to length-5
STC5_103 = [ st_103 for st_103 in STC_103 if len(st_103) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_103 = []
for n in range(len(STC5_103)):
    tc_103 = [ u for u in STC5_103[n][0] ]
    for k in range(1, len(STC5_103[n])):
        tc_103 = [ u+v for u in tc_103 for v in STC5_103[n][k] ]
    TC5_103 = TC5_103 + tc_103
setTC5_103 = list(set(TC5_103))

# get empirical frequencies
fTC5_103 = [ TC5_103.count(setTC5_103[l]) for l in range(len(setTC5_103)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_103 = [ [] for l in range(len(setTC5_103)) ]
for s in range(100):
    STC5null_103 = [ list(st_103) for st_103 in STC5_103]
    for st_103 in STC5null_103:
        np.random.shuffle(st_103)
    TC5null_103= []
    for n in range(len(STC5null_103)):
        tc_103 = [ u for u in STC5null_103[n][0] ]
        for k in range(1, len(STC5null_103[n])):
            tc_103 = [ u+v for u in tc_103 for v in STC5null_103[n][k] ]
        TC5null_103= TC5null_103+ tc_103
    for l in range(len(setTC5_103)):
        if TC5null_103.count(setTC5_103[l]) > 0:
            fTC5null_103[l].append(TC5null_103.count(setTC5_103[l]))
        else:
            fTC5null_103[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_103)):
     if sum(freq >= fTC5_103[l] for freq in fTC5null_103[l]) < 5:
#         print(setTC5_103[l], fTC5_103[l], sum(freq >= fTC5_103[l] for freq in fTC5null_103[l]))
        print(setTC5_103[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# HNNBN
# MH
# NBMBM
# YYNYM
# HBMMN
# MMYYN
# HMYYM
# YHMBY
# HBHBM
# HNMMM
# BMMBM
# HBHMM
# BNNMH
# NHBH
# HHYBN
# NNNH
# BMNYM
# NHNM
# BBHMN
# HHHNM
# BYNMM
# HNYYM
# HBHMN
# HHYNM
# BNNHB
# MBHYB
# HMHYM
# YHYNM
# MBHYY
# HYBM
# YYYN
# YYBB
# HNMNN
# BBNMY
# HHYBM
# BNNYB
# HBHMB
# HMMYM
# NHMH
# YYNBM
# HHYBB
# YYBN
# BBNYY
# BMNMM
# HHMNM
# MNMNB
# YHMNN
# BYNYM
# HHYNB
# BNNMB
# HYN
# YHYHH
# MMNB
# HBMMM
# BBNMB
# HBBM
# BYNMB
# MNMNN
# NHNH
# HHMNN
# YHMNY
# HHHNN
# BBNMM
# HNHMB
# HBMBM
# HNHMM
# HNYMB
# NNBH
# BNNYH
# YBHBM
# HYYM
# MBHMN
# HNYMM
# NHBM
# YNYBN
# BNNHH
# NHYM
# BMNYH
# MBYMN
# BBNNB
# HMHYH
# NBBM
# YHYNN
# HHYNN
# HBMBN
# HNMMB

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_103)):
     if sum(freq >= fTC5_103[l] for freq in fTC5null_103[l]) < 1:
#         print(setTC5_103[l], fTC5_103[l], sum(freq >= fTC5_103[l] for freq in fTC5null_103[l]))
        print(setTC5_103[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# HMYYM
# HNMMM
# HBHMM
# NHBH
# BBHMN
# HHYNM
# BNNHB
# HMHYM
# HHYBM
# HMMYM
# YYBN
# BMNMM
# BYNYM
# HHYNB
# HYN
# BBNMB
# HBBM
# NHNH
# HHMNN
# NNBH
# MBHMN
# HNYMM
# BNNHH
# HHYNN

# %% [markdown]
# # 3.104 (B) AP - (H) BLOOM - (M) ICT - (N) JGS - (α) SCC

# %%
#extract overlapping dates
start_104 = max(min(Date_AP), min(Date_BLOOM), min(Date_ICT), min(Date_JGS), min(Date_SCC))
end_104 = min(max(Date_AP), max(Date_BLOOM), max(Date_ICT), max(Date_JGS), max(Date_SCC))

# %%
#shorten the closing prices
AP_104_1 = Date_AP.index(start_104)
AP_104_2 = Date_AP.index(end_104)

BLOOM_104_1 = Date_BLOOM.index(start_104)
BLOOM_104_2 = Date_BLOOM.index(end_104)

ICT_104_1 = Date_ICT.index(start_104)
ICT_104_2 = Date_ICT.index(end_104)

JGS_104_1 = Date_JGS.index(start_104)
JGS_104_2 = Date_JGS.index(end_104)

SCC_104_1 = Date_SCC.index(start_104)
SCC_104_2 = Date_SCC.index(end_104)

# %%
#save the shortened versions of closing prices
B104 = np.save('APshortPrices.npy', ClosePrice_AP[AP_104_1:AP_104_2])
H104 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_104_1:BLOOM_104_2])
M104 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_104_1:ICT_104_2])
N104 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_104_1:JGS_104_2])
α104 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_104_1:SCC_104_2])

# %%
# import modules
import numpy as np
# import prices

B104 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
H104 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M104 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N104 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
α104 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_104 = []
st_104 = []
n = 1
while n < len(B104):
    sc_104 = ''
    if B104[n] > B104[n-1]:
        sc_104 = sc_104 + 'B'
    if H104[n] > H104[n-1]:
        sc_104 = sc_104 + 'H'
    if M104[n] > M104[n-1]:
        sc_104 = sc_104 + 'M'
    if N104[n] > N104[n-1]:
        sc_104 = sc_104 + 'N'
    if α104[n] > α104[n-1]:
        sc_104 = sc_104 + 'α'
    if len(sc_104) > 0:
        st_104.append(sc_104)
    else:
        STC_104.append(st_104)
        st_104 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_104 = STC_104.count([])
# keep only non-empty spatio-temporal sequences
STC_104 = [ st_104 for st_104 in STC_104 if len(st_104) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_104 = len(B104)
lmax_104 = 0
for st_104 in STC_104:
    if len(st_104) < lmin_104:
        lmin_104 = len(st_104)
    if len(st_104) > lmax_104:
        lmax_104 = len(st_104)
        
# restrict spatio-temporal sequences to length-5
STC5_104 = [ st_104 for st_104 in STC_104 if len(st_104) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_104 = []
for n in range(len(STC5_104)):
    tc_104 = [ u for u in STC5_104[n][0] ]
    for k in range(1, len(STC5_104[n])):
        tc_104 = [ u+v for u in tc_104 for v in STC5_104[n][k] ]
    TC5_104 = TC5_104 + tc_104
setTC5_104 = list(set(TC5_104))

# get empirical frequencies
fTC5_104 = [ TC5_104.count(setTC5_104[l]) for l in range(len(setTC5_104)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_104 = [ [] for l in range(len(setTC5_104)) ]
for s in range(100):
    STC5null_104 = [ list(st_104) for st_104 in STC5_104]
    for st_104 in STC5null_104:
        np.random.shuffle(st_104)
    TC5null_104= []
    for n in range(len(STC5null_104)):
        tc_104 = [ u for u in STC5null_104[n][0] ]
        for k in range(1, len(STC5null_104[n])):
            tc_104 = [ u+v for u in tc_104 for v in STC5null_104[n][k] ]
        TC5null_104= TC5null_104+ tc_104
    for l in range(len(setTC5_104)):
        if TC5null_104.count(setTC5_104[l]) > 0:
            fTC5null_104[l].append(TC5null_104.count(setTC5_104[l]))
        else:
            fTC5null_104[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_104)):
     if sum(freq >= fTC5_104[l] for freq in fTC5null_104[l]) < 5:
#         print(setTC5_104[l], fTC5_104[l], sum(freq >= fTC5_104[l] for freq in fTC5null_104[l]))
        print(setTC5_104[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# BMMBH
# BNMBH
# MBNB
# HNHHH
# αBNMM
# BNN
# HHMαN
# HBMMN
# MMN
# HBHBα
# BMMBM
# NNMBH
# HBHMM
# BMBBM
# BMMBN
# BHBBN
# NNNH
# HNMHH
# HαMαN
# HBMBα
# BMMBB
# BNMBα
# HMBα
# HMNH
# HNMNN
# αBMBN
# NNMαH
# HBMαN
# HBMαα
# BNHBα
# NNMHα
# HαMαα
# BBN
# HNHαα
# HαN
# NαααN
# NNMαN
# BNBHα
# BMHMN
# αBNBN
# αBHBα
# NMMαM
# BMM
# MHMαN
# BHMBN
# HBαBα
# HMMM
# NBNH
# HBMαM
# MMNB
# HNHHα
# HBMMM
# HαααN
# NαMNN
# BBHBα
# αMNH
# HαMNM
# αBBN
# HBNH
# ααNBM
# ααNBB
# HNMHN
# NαMαN
# MMNH
# BαN
# BNMMN
# HBαBN
# HHMαα
# BHMMN
# NBααα
# MBHMN
# MNMBH
# BNHBH
# HMN
# HNMαN
# BNMαH
# BNNHH
# MNMMN
# HNMHα
# HNMαH
# HNHMα
# HNHαH
# HBααα
# HMMαM
# HNMMN
# HBHαα
# BNαHH
# BNMMH
# BMNHH
# BMHBH
# NαNH
# MNMαN
# HNMαα
# HBααN
# HBMBN
# αNBHα

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_104)):
     if sum(freq >= fTC5_104[l] for freq in fTC5null_104[l]) < 1:
#         print(setTC5_104[l], fTC5_104[l], sum(freq >= fTC5_104[l] for freq in fTC5null_104[l]))
        print(setTC5_104[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# BMMBH
# BNMBH
# MBNB
# αBNMM
# HBHBα
# HαMαN
# HMNH
# HBMαN
# HBMαα
# αBNBN
# BHMBN
# HBαBα
# MMNB
# MMNH
# BαN
# HNMαN
# HNMHα
# HBααα
# HNMMN
# HBHαα
# NαNH
# HNMαα

# %% [markdown]
# # 3.105 (B) AP - (H) BLOOM - (M) ICT - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_105 = max(min(Date_AP), min(Date_BLOOM), min(Date_ICT), min(Date_MEG), min(Date_SMC))
end_105 = min(max(Date_AP), max(Date_BLOOM), max(Date_ICT), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
AP_105_1 = Date_AP.index(start_105)
AP_105_2 = Date_AP.index(end_105)

BLOOM_105_1 = Date_BLOOM.index(start_105)
BLOOM_105_2 = Date_BLOOM.index(end_105)

ICT_105_1 = Date_ICT.index(start_105)
ICT_105_2 = Date_ICT.index(end_105)

MEG_105_1 = Date_MEG.index(start_105)
MEG_105_2 = Date_MEG.index(end_105)

SMC_105_1 = Date_SMC.index(start_105)
SMC_105_2 = Date_SMC.index(end_105)

# %%
#save the shortened versions of closing prices
B105 = np.save('APshortPrices.npy', ClosePrice_AP[AP_105_1:AP_105_2])
H105 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_105_1:BLOOM_105_2])
M105 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_105_1:ICT_105_2])
R105 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_105_1:MEG_105_2])
Y105 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_105_1:SMC_105_2])

# %%
# import modules
import numpy as np
# import prices

B105 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
H105 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M105 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R105 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y105 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_105 = []
st_105 = []
n = 1
while n < len(B105):
    sc_105 = ''
    if B105[n] > B105[n-1]:
        sc_105 = sc_105 + 'B'
    if H105[n] > H105[n-1]:
        sc_105 = sc_105 + 'H'
    if M105[n] > M105[n-1]:
        sc_105 = sc_105 + 'M'
    if R105[n] > R105[n-1]:
        sc_105 = sc_105 + 'R'
    if Y105[n] > Y105[n-1]:
        sc_105 = sc_105 + 'Y'
    if len(sc_105) > 0:
        st_105.append(sc_105)
    else:
        STC_105.append(st_105)
        st_105 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_105 = STC_105.count([])
# keep only non-empty spatio-temporal sequences
STC_105 = [ st_105 for st_105 in STC_105 if len(st_105) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_105 = len(B105)
lmax_105 = 0
for st_105 in STC_105:
    if len(st_105) < lmin_105:
        lmin_105 = len(st_105)
    if len(st_105) > lmax_105:
        lmax_105 = len(st_105)
        
# restrict spatio-temporal sequences to length-5
STC5_105 = [ st_105 for st_105 in STC_105 if len(st_105) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_105 = []
for n in range(len(STC5_105)):
    tc_105 = [ u for u in STC5_105[n][0] ]
    for k in range(1, len(STC5_105[n])):
        tc_105 = [ u+v for u in tc_105 for v in STC5_105[n][k] ]
    TC5_105 = TC5_105 + tc_105
setTC5_105 = list(set(TC5_105))

# get empirical frequencies
fTC5_105 = [ TC5_105.count(setTC5_105[l]) for l in range(len(setTC5_105)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_105 = [ [] for l in range(len(setTC5_105)) ]
for s in range(100):
    STC5null_105 = [ list(st_105) for st_105 in STC5_105]
    for st_105 in STC5null_105:
        np.random.shuffle(st_105)
    TC5null_105= []
    for n in range(len(STC5null_105)):
        tc_105 = [ u for u in STC5null_105[n][0] ]
        for k in range(1, len(STC5null_105[n])):
            tc_105 = [ u+v for u in tc_105 for v in STC5null_105[n][k] ]
        TC5null_105= TC5null_105+ tc_105
    for l in range(len(setTC5_105)):
        if TC5null_105.count(setTC5_105[l]) > 0:
            fTC5null_105[l].append(TC5null_105.count(setTC5_105[l]))
        else:
            fTC5null_105[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_105)):
     if sum(freq >= fTC5_105[l] for freq in fTC5null_105[l]) < 5:
#         print(setTC5_105[l], fTC5_105[l], sum(freq >= fTC5_105[l] for freq in fTC5null_105[l]))
        print(setTC5_105[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# HRYMM
# RYMY
# RBBH
# HMYYM
# HRYMB
# RBB
# HBHMM
# RYMH
# RMRYH
# MMRR
# MYRR
# BMRYH
# MYBBR
# MHYYR
# MHH
# HMHYM
# MRBBR
# HRMYB
# RHYRB
# HHYRR
# HHYBM
# HHBY
# HRMRM
# HBHMB
# HMMYM
# HMRYM
# HBMMB
# HRHMB
# HHYBB
# RRMMR
# YHYRB
# RMHYM
# HHYBR
# BHHRY
# MYMB
# HRYYM
# HRMYM
# HBYMB
# BHYRB
# YHYBM
# YHYRM
# BRRMH
# HBHBB
# HHYRM
# HBMMM
# BBHRY
# HHRRM
# BBHRB
# HRMMM
# MHYRR
# RBRB
# HRMMB
# RRMMM
# HHHMB
# HHMRM
# HHYRH
# RBHMM
# MHYRB
# MMRB
# RRHMM
# MBRB
# HMYRR
# YMBR
# RRMMB
# MHYRY
# MHHMB
# HBYMM
# HRHMM
# RHYYR
# BHHRB
# HBHY
# HYMH
# RHYRR
# HHYRB
# HRHRM
# HBYBB
# RM

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_105)):
     if sum(freq >= fTC5_105[l] for freq in fTC5null_105[l]) < 1:
#         print(setTC5_105[l], fTC5_105[l], sum(freq >= fTC5_105[l] for freq in fTC5null_105[l]))
        print(setTC5_105[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# HBHMM
# MHH
# HRMRM
# HMMYM
# HBMMB
# RRMMR
# BHHRY
# HHYRM
# HBMMM
# HRMMM
# MHYRR
# HRMMB
# HHYRH
# MHYRB
# YMBR
# RRMMB
# BHHRB
# HHYRB
