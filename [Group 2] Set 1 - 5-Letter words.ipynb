# %% [markdown]
# ##  One-letter Words

# %%
# open the csv files
GTCAP = open('GTCAP.csv')
AGI = open('AGI.csv')
SM = open('SM.csv')
MER = open('MER.csv')
ALI = open('ALI.csv')
SECB = open('SECB.csv')
MBT = open('MBT.csv')
TEL = open('TEL.csv')
URC = open('URC.csv')
PGOLD = open('PGOLD.csv')

#initialize the lists
Date_GTCAP = []
ClosePrice_GTCAP = []
Date_AGI = []
ClosePrice_AGI = []
Date_SM = []
ClosePrice_SM = []
Date_MER = []
ClosePrice_MER = []
Date_ALI = []
ClosePrice_ALI = []
Date_SECB = []
ClosePrice_SECB = []
Date_MBT = []
ClosePrice_MBT = []
Date_TEL = []
ClosePrice_TEL = []
Date_URC = []
ClosePrice_URC = []
Date_PGOLD = []
ClosePrice_PGOLD = []

#skip the header line
GTCAP.readline()
AGI.readline()
SM.readline()
MER.readline()
ALI.readline()
SECB.readline()
MBT.readline()
TEL.readline()
URC.readline()
PGOLD.readline()

#go through the files line by line
for line in GTCAP:
    sline = line.strip().split(',')
    Date_GTCAP.append(sline[0])
    ClosePrice_GTCAP.append(float(sline[1]))
    
for line in AGI:
    sline = line.strip().split(',')
    Date_AGI.append(sline[0])
    ClosePrice_AGI.append(float(sline[1]))
    
for line in SM:
    sline = line.strip().split(',')
    Date_SM.append(sline[0])
    ClosePrice_SM.append(float(sline[1]))
    
for line in MER:
    sline = line.strip().split(',')
    Date_MER.append(sline[0])
    ClosePrice_MER.append(float(sline[1]))
    
for line in ALI:
    sline = line.strip().split(',')
    Date_ALI.append(sline[0])
    ClosePrice_ALI.append(float(sline[1]))
    
for line in SECB:
    sline = line.strip().split(',')
    Date_SECB.append(sline[0])
    ClosePrice_SECB.append(float(sline[1]))
    
for line in MBT:
    sline = line.strip().split(',')
    Date_MBT.append(sline[0])
    ClosePrice_MBT.append(float(sline[1]))
    
for line in TEL:
    sline = line.strip().split(',')
    Date_TEL.append(sline[0])
    ClosePrice_TEL.append(float(sline[1]))
    
for line in URC:
    sline = line.strip().split(',')
    Date_URC.append(sline[0])
    ClosePrice_URC.append(float(sline[1]))
        
for line in PGOLD:
    sline = line.strip().split(',')
    Date_PGOLD.append(sline[0])
    ClosePrice_PGOLD.append(float(sline[1]))


#close files
GTCAP.close()
AGI.close()
SM.close()
MER.close()
ALI.close()
SECB.close()
MBT.close()
TEL.close()
URC.close()
PGOLD.close()

# %%
import numpy as np
import datetime

# %%
# convert dates into datetime structure
for n in range(len(Date_GTCAP)):
    Date_GTCAP[n] = datetime.datetime.strptime(Date_GTCAP[n], '%m/%d/%y').date()

for n in range(len(Date_AGI)):
    Date_AGI[n] = datetime.datetime.strptime(Date_AGI[n], '%m/%d/%y').date()
    
for n in range(len(Date_SM)):
    Date_SM[n] = datetime.datetime.strptime(Date_SM[n], '%m/%d/%y').date()

for n in range(len(Date_MER)):
    Date_MER[n] = datetime.datetime.strptime(Date_MER[n], '%m/%d/%y').date()
    
for n in range(len(Date_ALI)):
    Date_ALI[n] = datetime.datetime.strptime(Date_ALI[n], '%m/%d/%y').date()

for n in range(len(Date_SECB)):
    Date_SECB[n] = datetime.datetime.strptime(Date_SECB[n], '%m/%d/%y').date()
    
for n in range(len(Date_MBT)):
    Date_MBT[n] = datetime.datetime.strptime(Date_MBT[n], '%m/%d/%y').date()

for n in range(len(Date_TEL)):
    Date_TEL[n] = datetime.datetime.strptime(Date_TEL[n], '%m/%d/%y').date()
    
for n in range(len(Date_URC)):
    Date_URC[n] = datetime.datetime.strptime(Date_URC[n], '%m/%d/%y').date()

for n in range(len(Date_PGOLD)):
    Date_PGOLD[n] = datetime.datetime.strptime(Date_PGOLD[n], '%m/%d/%y').date()
    
# save Date and ClosePrice
np.save('GTCAPDate.npy', Date_GTCAP)
np.save('GTCAPClosePrice.npy', ClosePrice_GTCAP)
np.save('AGIDate.npy', Date_AGI)
np.save('AGIClosePrice.npy', ClosePrice_AGI)
np.save('SMDate.npy', Date_SM)
np.save('SMClosePrice.npy', ClosePrice_SM)
np.save('MERDate.npy', Date_MER)
np.save('MERClosePrice.npy', ClosePrice_MER)
np.save('ALIDate.npy', Date_ALI)
np.save('ALIClosePrice.npy', ClosePrice_ALI)
np.save('SECBDate.npy', Date_SECB)
np.save('SECBClosePrice.npy', ClosePrice_SECB)
np.save('MBTDate.npy', Date_MBT)
np.save('MBTClosePrice.npy', ClosePrice_MBT)
np.save('TELDate.npy', Date_TEL)
np.save('TELClosePrice.npy', ClosePrice_TEL)
np.save('URCDate.npy', Date_URC)
np.save('URCClosePrice.npy', ClosePrice_URC)
np.save('PGOLDDate.npy', Date_PGOLD)
np.save('PGOLDClosePrice.npy', ClosePrice_PGOLD)

# %% [markdown]
# # Five-letter words

# %% [markdown]
# Here, we use the shortened versions of the closing prices, all starting and ending on the same dates.

# %%
import numpy as nprd
import matplotlib.pyplot as plt
from datetime import *
from functions import *
import itertools

# %%
cluster_2 = ["L","C","β","Q","E","Z","T","V","ε","W"]

# %%
#getting all combinations of 5 stocks out of the 10 stocks; we expect to get 252 combinations

combinations = []

combinations = list(itertools.combinations(cluster_2,5))
print(*combinations, sep = "\n")
# Out:
# ('L', 'C', 'β', 'Q', 'E')
# ('L', 'C', 'β', 'Q', 'Z')
# ('L', 'C', 'β', 'Q', 'T')
# ('L', 'C', 'β', 'Q', 'V')
# ('L', 'C', 'β', 'Q', 'ε')
# ('L', 'C', 'β', 'Q', 'W')
# ('L', 'C', 'β', 'E', 'Z')
# ('L', 'C', 'β', 'E', 'T')
# ('L', 'C', 'β', 'E', 'V')
# ('L', 'C', 'β', 'E', 'ε')
# ('L', 'C', 'β', 'E', 'W')
# ('L', 'C', 'β', 'Z', 'T')
# ('L', 'C', 'β', 'Z', 'V')
# ('L', 'C', 'β', 'Z', 'ε')
# ('L', 'C', 'β', 'Z', 'W')
# ('L', 'C', 'β', 'T', 'V')
# ('L', 'C', 'β', 'T', 'ε')
# ('L', 'C', 'β', 'T', 'W')
# ('L', 'C', 'β', 'V', 'ε')
# ('L', 'C', 'β', 'V', 'W')
# ('L', 'C', 'β', 'ε', 'W')
# ('L', 'C', 'Q', 'E', 'Z')
# ('L', 'C', 'Q', 'E', 'T')
# ('L', 'C', 'Q', 'E', 'V')
# ('L', 'C', 'Q', 'E', 'ε')
# ('L', 'C', 'Q', 'E', 'W')
# ('L', 'C', 'Q', 'Z', 'T')
# ('L', 'C', 'Q', 'Z', 'V')
# ('L', 'C', 'Q', 'Z', 'ε')
# ('L', 'C', 'Q', 'Z', 'W')
# ('L', 'C', 'Q', 'T', 'V')
# ('L', 'C', 'Q', 'T', 'ε')
# ('L', 'C', 'Q', 'T', 'W')
# ('L', 'C', 'Q', 'V', 'ε')
# ('L', 'C', 'Q', 'V', 'W')
# ('L', 'C', 'Q', 'ε', 'W')
# ('L', 'C', 'E', 'Z', 'T')
# ('L', 'C', 'E', 'Z', 'V')
# ('L', 'C', 'E', 'Z', 'ε')
# ('L', 'C', 'E', 'Z', 'W')
# ('L', 'C', 'E', 'T', 'V')
# ('L', 'C', 'E', 'T', 'ε')
# ('L', 'C', 'E', 'T', 'W')
# ('L', 'C', 'E', 'V', 'ε')
# ('L', 'C', 'E', 'V', 'W')
# ('L', 'C', 'E', 'ε', 'W')
# ('L', 'C', 'Z', 'T', 'V')
# ('L', 'C', 'Z', 'T', 'ε')
# ('L', 'C', 'Z', 'T', 'W')
# ('L', 'C', 'Z', 'V', 'ε')
# ('L', 'C', 'Z', 'V', 'W')
# ('L', 'C', 'Z', 'ε', 'W')
# ('L', 'C', 'T', 'V', 'ε')
# ('L', 'C', 'T', 'V', 'W')
# ('L', 'C', 'T', 'ε', 'W')
# ('L', 'C', 'V', 'ε', 'W')
# ('L', 'β', 'Q', 'E', 'Z')
# ('L', 'β', 'Q', 'E', 'T')
# ('L', 'β', 'Q', 'E', 'V')
# ('L', 'β', 'Q', 'E', 'ε')
# ('L', 'β', 'Q', 'E', 'W')
# ('L', 'β', 'Q', 'Z', 'T')
# ('L', 'β', 'Q', 'Z', 'V')
# ('L', 'β', 'Q', 'Z', 'ε')
# ('L', 'β', 'Q', 'Z', 'W')
# ('L', 'β', 'Q', 'T', 'V')
# ('L', 'β', 'Q', 'T', 'ε')
# ('L', 'β', 'Q', 'T', 'W')
# ('L', 'β', 'Q', 'V', 'ε')
# ('L', 'β', 'Q', 'V', 'W')
# ('L', 'β', 'Q', 'ε', 'W')
# ('L', 'β', 'E', 'Z', 'T')
# ('L', 'β', 'E', 'Z', 'V')
# ('L', 'β', 'E', 'Z', 'ε')
# ('L', 'β', 'E', 'Z', 'W')
# ('L', 'β', 'E', 'T', 'V')
# ('L', 'β', 'E', 'T', 'ε')
# ('L', 'β', 'E', 'T', 'W')
# ('L', 'β', 'E', 'V', 'ε')
# ('L', 'β', 'E', 'V', 'W')
# ('L', 'β', 'E', 'ε', 'W')
# ('L', 'β', 'Z', 'T', 'V')
# ('L', 'β', 'Z', 'T', 'ε')
# ('L', 'β', 'Z', 'T', 'W')
# ('L', 'β', 'Z', 'V', 'ε')
# ('L', 'β', 'Z', 'V', 'W')
# ('L', 'β', 'Z', 'ε', 'W')
# ('L', 'β', 'T', 'V', 'ε')
# ('L', 'β', 'T', 'V', 'W')
# ('L', 'β', 'T', 'ε', 'W')
# ('L', 'β', 'V', 'ε', 'W')
# ('L', 'Q', 'E', 'Z', 'T')
# ('L', 'Q', 'E', 'Z', 'V')
# ('L', 'Q', 'E', 'Z', 'ε')
# ('L', 'Q', 'E', 'Z', 'W')
# ('L', 'Q', 'E', 'T', 'V')
# ('L', 'Q', 'E', 'T', 'ε')
# ('L', 'Q', 'E', 'T', 'W')
# ('L', 'Q', 'E', 'V', 'ε')
# ('L', 'Q', 'E', 'V', 'W')
# ('L', 'Q', 'E', 'ε', 'W')
# ('L', 'Q', 'Z', 'T', 'V')
# ('L', 'Q', 'Z', 'T', 'ε')
# ('L', 'Q', 'Z', 'T', 'W')
# ('L', 'Q', 'Z', 'V', 'ε')
# ('L', 'Q', 'Z', 'V', 'W')
# ('L', 'Q', 'Z', 'ε', 'W')
# ('L', 'Q', 'T', 'V', 'ε')
# ('L', 'Q', 'T', 'V', 'W')
# ('L', 'Q', 'T', 'ε', 'W')
# ('L', 'Q', 'V', 'ε', 'W')
# ('L', 'E', 'Z', 'T', 'V')
# ('L', 'E', 'Z', 'T', 'ε')
# ('L', 'E', 'Z', 'T', 'W')
# ('L', 'E', 'Z', 'V', 'ε')
# ('L', 'E', 'Z', 'V', 'W')
# ('L', 'E', 'Z', 'ε', 'W')
# ('L', 'E', 'T', 'V', 'ε')
# ('L', 'E', 'T', 'V', 'W')
# ('L', 'E', 'T', 'ε', 'W')
# ('L', 'E', 'V', 'ε', 'W')
# ('L', 'Z', 'T', 'V', 'ε')
# ('L', 'Z', 'T', 'V', 'W')
# ('L', 'Z', 'T', 'ε', 'W')
# ('L', 'Z', 'V', 'ε', 'W')
# ('L', 'T', 'V', 'ε', 'W')
# ('C', 'β', 'Q', 'E', 'Z')
# ('C', 'β', 'Q', 'E', 'T')
# ('C', 'β', 'Q', 'E', 'V')
# ('C', 'β', 'Q', 'E', 'ε')
# ('C', 'β', 'Q', 'E', 'W')
# ('C', 'β', 'Q', 'Z', 'T')
# ('C', 'β', 'Q', 'Z', 'V')
# ('C', 'β', 'Q', 'Z', 'ε')
# ('C', 'β', 'Q', 'Z', 'W')
# ('C', 'β', 'Q', 'T', 'V')
# ('C', 'β', 'Q', 'T', 'ε')
# ('C', 'β', 'Q', 'T', 'W')
# ('C', 'β', 'Q', 'V', 'ε')
# ('C', 'β', 'Q', 'V', 'W')
# ('C', 'β', 'Q', 'ε', 'W')
# ('C', 'β', 'E', 'Z', 'T')
# ('C', 'β', 'E', 'Z', 'V')
# ('C', 'β', 'E', 'Z', 'ε')
# ('C', 'β', 'E', 'Z', 'W')
# ('C', 'β', 'E', 'T', 'V')
# ('C', 'β', 'E', 'T', 'ε')
# ('C', 'β', 'E', 'T', 'W')
# ('C', 'β', 'E', 'V', 'ε')
# ('C', 'β', 'E', 'V', 'W')
# ('C', 'β', 'E', 'ε', 'W')
# ('C', 'β', 'Z', 'T', 'V')
# ('C', 'β', 'Z', 'T', 'ε')
# ('C', 'β', 'Z', 'T', 'W')
# ('C', 'β', 'Z', 'V', 'ε')
# ('C', 'β', 'Z', 'V', 'W')
# ('C', 'β', 'Z', 'ε', 'W')
# ('C', 'β', 'T', 'V', 'ε')
# ('C', 'β', 'T', 'V', 'W')
# ('C', 'β', 'T', 'ε', 'W')
# ('C', 'β', 'V', 'ε', 'W')
# ('C', 'Q', 'E', 'Z', 'T')
# ('C', 'Q', 'E', 'Z', 'V')
# ('C', 'Q', 'E', 'Z', 'ε')
# ('C', 'Q', 'E', 'Z', 'W')
# ('C', 'Q', 'E', 'T', 'V')
# ('C', 'Q', 'E', 'T', 'ε')
# ('C', 'Q', 'E', 'T', 'W')
# ('C', 'Q', 'E', 'V', 'ε')
# ('C', 'Q', 'E', 'V', 'W')
# ('C', 'Q', 'E', 'ε', 'W')
# ('C', 'Q', 'Z', 'T', 'V')
# ('C', 'Q', 'Z', 'T', 'ε')
# ('C', 'Q', 'Z', 'T', 'W')
# ('C', 'Q', 'Z', 'V', 'ε')
# ('C', 'Q', 'Z', 'V', 'W')
# ('C', 'Q', 'Z', 'ε', 'W')
# ('C', 'Q', 'T', 'V', 'ε')
# ('C', 'Q', 'T', 'V', 'W')
# ('C', 'Q', 'T', 'ε', 'W')
# ('C', 'Q', 'V', 'ε', 'W')
# ('C', 'E', 'Z', 'T', 'V')
# ('C', 'E', 'Z', 'T', 'ε')
# ('C', 'E', 'Z', 'T', 'W')
# ('C', 'E', 'Z', 'V', 'ε')
# ('C', 'E', 'Z', 'V', 'W')
# ('C', 'E', 'Z', 'ε', 'W')
# ('C', 'E', 'T', 'V', 'ε')
# ('C', 'E', 'T', 'V', 'W')
# ('C', 'E', 'T', 'ε', 'W')
# ('C', 'E', 'V', 'ε', 'W')
# ('C', 'Z', 'T', 'V', 'ε')
# ('C', 'Z', 'T', 'V', 'W')
# ('C', 'Z', 'T', 'ε', 'W')
# ('C', 'Z', 'V', 'ε', 'W')
# ('C', 'T', 'V', 'ε', 'W')
# ('β', 'Q', 'E', 'Z', 'T')
# ('β', 'Q', 'E', 'Z', 'V')
# ('β', 'Q', 'E', 'Z', 'ε')
# ('β', 'Q', 'E', 'Z', 'W')
# ('β', 'Q', 'E', 'T', 'V')
# ('β', 'Q', 'E', 'T', 'ε')
# ('β', 'Q', 'E', 'T', 'W')
# ('β', 'Q', 'E', 'V', 'ε')
# ('β', 'Q', 'E', 'V', 'W')
# ('β', 'Q', 'E', 'ε', 'W')
# ('β', 'Q', 'Z', 'T', 'V')
# ('β', 'Q', 'Z', 'T', 'ε')
# ('β', 'Q', 'Z', 'T', 'W')
# ('β', 'Q', 'Z', 'V', 'ε')
# ('β', 'Q', 'Z', 'V', 'W')
# ('β', 'Q', 'Z', 'ε', 'W')
# ('β', 'Q', 'T', 'V', 'ε')
# ('β', 'Q', 'T', 'V', 'W')
# ('β', 'Q', 'T', 'ε', 'W')
# ('β', 'Q', 'V', 'ε', 'W')
# ('β', 'E', 'Z', 'T', 'V')
# ('β', 'E', 'Z', 'T', 'ε')
# ('β', 'E', 'Z', 'T', 'W')
# ('β', 'E', 'Z', 'V', 'ε')
# ('β', 'E', 'Z', 'V', 'W')
# ('β', 'E', 'Z', 'ε', 'W')
# ('β', 'E', 'T', 'V', 'ε')
# ('β', 'E', 'T', 'V', 'W')
# ('β', 'E', 'T', 'ε', 'W')
# ('β', 'E', 'V', 'ε', 'W')
# ('β', 'Z', 'T', 'V', 'ε')
# ('β', 'Z', 'T', 'V', 'W')
# ('β', 'Z', 'T', 'ε', 'W')
# ('β', 'Z', 'V', 'ε', 'W')
# ('β', 'T', 'V', 'ε', 'W')
# ('Q', 'E', 'Z', 'T', 'V')
# ('Q', 'E', 'Z', 'T', 'ε')
# ('Q', 'E', 'Z', 'T', 'W')
# ('Q', 'E', 'Z', 'V', 'ε')
# ('Q', 'E', 'Z', 'V', 'W')
# ('Q', 'E', 'Z', 'ε', 'W')
# ('Q', 'E', 'T', 'V', 'ε')
# ('Q', 'E', 'T', 'V', 'W')
# ('Q', 'E', 'T', 'ε', 'W')
# ('Q', 'E', 'V', 'ε', 'W')
# ('Q', 'Z', 'T', 'V', 'ε')
# ('Q', 'Z', 'T', 'V', 'W')
# ('Q', 'Z', 'T', 'ε', 'W')
# ('Q', 'Z', 'V', 'ε', 'W')
# ('Q', 'T', 'V', 'ε', 'W')
# ('E', 'Z', 'T', 'V', 'ε')
# ('E', 'Z', 'T', 'V', 'W')
# ('E', 'Z', 'T', 'ε', 'W')
# ('E', 'Z', 'V', 'ε', 'W')
# ('E', 'T', 'V', 'ε', 'W')
# ('Z', 'T', 'V', 'ε', 'W')

# %% [markdown]
# # 1 (L) GTCAP - (C) AGI - (β) SM - (Q) MER - (E) ALI

# %%
#extract the overlapping dates

start_1 = max(min(Date_GTCAP), min(Date_AGI), min(Date_SM), min(Date_MER), min(Date_ALI))
end_1 = min(max(Date_GTCAP), max(Date_AGI), max(Date_SM), max(Date_MER), max(Date_ALI))

# %%
#shorten the closing prices
GTCAP_1_1 = Date_GTCAP.index(start_1)
GTCAP_1_2 = Date_GTCAP.index(end_1)

AGI_1_1 = Date_AGI.index(start_1)
AGI_1_2 = Date_AGI.index(end_1)

SM_1_1 = Date_SM.index(start_1)
SM_1_2 = Date_SM.index(end_1)

MER_1_1 = Date_MER.index(start_1)
MER_1_2 = Date_MER.index(end_1)

ALI_1_1 = Date_ALI.index(start_1)
ALI_1_2 = Date_ALI.index(end_1)

# %%
#save the shortened versions of closing prices
L1 = np.save('GTCAPshortPrices.npy', ClosePrice_GTCAP[GTCAP_1_1:GTCAP_1_2])
C1 = np.save('AGIshortPrices.npy', ClosePrice_AGI[AGI_1_1:AGI_1_2])
β1 = np.save('SMshortPrices.npy', ClosePrice_SM[SM_1_1:SM_1_2])
Q1 = np.save('MERshortPrices.npy', ClosePrice_MER[MER_1_1:MER_1_2])
E1 = np.save('ALIshortPrices.npy', ClosePrice_ALI[ALI_1_1:ALI_1_2])

# %%
# import modules
import numpy as np
# import prices
L1 = np.load('GTCAPshortPrices.npy', allow_pickle=True).tolist()
C1 = np.load('AGIshortPrices.npy', allow_pickle=True).tolist()
β1 = np.load('SMshortPrices.npy', allow_pickle=True).tolist()
Q1 = np.load('MERshortPrices.npy', allow_pickle=True).tolist()
E1 = np.load('ALIshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_1 = []
st_1 = []
n = 1
while n < len(L1):
    sc_1 = ''
    if L1[n] > L1[n-1]:
        sc_1 = sc_1 + 'L'
    if C1[n] > C1[n-1]:
        sc_1 = sc_1 + 'C'
    if β1[n] > β1[n-1]:
        sc_1 = sc_1 + 'β'
    if Q1[n] > Q1[n-1]:
        sc_1 = sc_1 + 'Q'
    if E1[n] > E1[n-1]:
        sc_1 = sc_1 + 'E'
    if len(sc_1) > 0:
        st_1.append(sc_1)
    else:
        STC_1.append(st_1)
        st_1 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_1 = STC_1.count([])
# keep only non-empty spatio-temporal sequences
STC_1 = [ st_1 for st_1 in STC_1 if len(st_1) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_1 = len(L1)
lmax_1 = 0
for st_1 in STC_1:
    if len(st_1) < lmin_1:
        lmin_1 = len(st_1)
    if len(st_1) > lmax_1:
        lmax_1 = len(st_1)
        
# restrict spatio-temporal sequences to length-5
STC5_1 = [ st_1 for st_1 in STC_1 if len(st_1) <= 10 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_1 = []
for n in range(len(STC5_1)):
    tc_1 = [ u for u in STC5_1[n][0] ]
    for k in range(1, len(STC5_1[n])):
        tc_1 = [ u+v for u in tc_1 for v in STC5_1[n][k] ]
    TC5_1 = TC5_1 + tc_1
setTC5_1 = list(set(TC5_1))

# get empirical frequencies
fTC5_1 = [ TC5_1.count(setTC5_1[l]) for l in range(len(setTC5_1)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_1 = [ [] for l in range(len(setTC5_1)) ]
for s in range(100):
    STC5null_1 = [ list(st_1) for st_1 in STC5_1]
    for st_1 in STC5null_1:
        np.random.shuffle(st_1)
    TC5null_1 = []
    for n in range(len(STC5null_1)):
        tc_1 = [ u for u in STC5null_1[n][0] ]
        for k in range(1, len(STC5null_1[n])):
            tc_1 = [ u+v for u in tc_1 for v in STC5null_1[n][k] ]
        TC5null_1 = TC5null_1 + tc_1
    for l in range(len(setTC5_1)):
        if TC5null_1.count(setTC5_1[l]) > 0:
            fTC5null_1[l].append(TC5null_1.count(setTC5_1[l]))
        else:
            fTC5null_1[l].append(0)

# %%
len(STC5_1)
# Out:
# 143

# %%
print("List of Statistically Significant Sequences at α = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_1)):
    if sum(freq >= fTC5_1[l] for freq in fTC5null_1[l]) < 5:
        #print(setTC5_1[l], fTC5_1[l], sum(freq >= fTC5_1[l] for freq in fTC5null_1[l]))
        print(setTC5_1[l])
# Out:
# List of Statistically Significant Sequences at α = 0.05
# ECCCE
# QLEQE
# ELCCβ
# βCCQ
# βQCQ
# CβQCβ
# βLLβE
# LβCQ
# ELLCβ
# βQQCβ
# CQCCβ
# CEEEβ
# LββC
# βLCCβ
# ECECβ
# βLLCβ
# CQLCQ
# CQEL
# LQCQ
# ELLCL
# βQβE
# CLLCβ
# CβEC
# ELEQβ
# CEQCβ
# QβQCβ
# ECECE
# ECLCL
# βQLQQ
# QEELE
# CQQCβ
# EQQEQ
# βLLββ
# ECQCβ
# ββLCβ
# CEEC
# LLLQE
# LQEL
# βLβCβ
# QCQ
# CβECβ
# CQECβ
# EQLCL
# ECLQE
# βQβQ
# CQLCL
# βLLQβ
# ECLCβ
# ELLEE
# ECCCL
# ELLQL
# QLβQE
# LCQCβ
# LLQCβ
# LQβQ
# CββC
# ELECβ
# ECEQE
# QβCCβ
# βLLQE
# ECCCβ
# ELLQE
# LLQEβ
# ELLCE
# LQQEQ
# CQLCβ
# CβLCβ
# LCCQ
# CLECβ
# EQLEQ
# βLLCL
# CLCCβ

# %%
print("List of Statistically Significant Sequences at α = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_1)):
    if sum(freq >= fTC5_1[l] for freq in fTC5null_1[l]) < 1:
        #print(setTC5_1[l], fTC5_1[l], sum(freq >= fTC5_1[l] for freq in fTC5null_1[l]))
        print(setTC5_1[l])
# Out:
# List of Statistically Significant Sequences at α = 0.01
# βCCQ
# βQCQ
# ELLCβ
# ECECβ
# LQCQ
# ELLCL
# QEELE
# βLLQE
# ELLQE

# %% [markdown]
# # 2 (L) GTCAP - (C) AGI - (β) SM - (Q) MER - (Z) SECB

# %%
#extract the overlapping dates

start_2 = max(min(Date_GTCAP), min(Date_AGI), min(Date_SM), min(Date_MER), min(Date_SECB))
end_2 = min(max(Date_GTCAP), max(Date_AGI), max(Date_SM), max(Date_MER), max(Date_SECB))

# %%
#shorten the closing prices
GTCAP_2_1 = Date_GTCAP.index(start_2)
GTCAP_2_2 = Date_GTCAP.index(end_2)

AGI_2_1 = Date_AGI.index(start_2)
AGI_2_2 = Date_AGI.index(end_2)

SM_2_1 = Date_SM.index(start_2)
SM_2_2 = Date_SM.index(end_2)

MER_2_1 = Date_MER.index(start_2)
MER_2_2 = Date_MER.index(end_2)

SECB_2_1 = Date_SECB.index(start_2)
SECB_2_2 = Date_SECB.index(end_2)

# %%
#save the shortened versions of closing prices
L2 = np.save('GTCAPshortPrices.npy', ClosePrice_GTCAP[GTCAP_2_1:GTCAP_2_2])
C2 = np.save('AGIshortPrices.npy', ClosePrice_AGI[AGI_2_1:AGI_2_2])
β2 = np.save('SMshortPrices.npy', ClosePrice_SM[SM_2_1:SM_2_2])
Q2 = np.save('MERshortPrices.npy', ClosePrice_MER[MER_2_1:MER_2_2])
Z2 = np.save('SECBshortPrices.npy', ClosePrice_SECB[SECB_2_1:SECB_2_2])

# %%
# import modules
import numpy as np
# import prices
L2 = np.load('GTCAPshortPrices.npy', allow_pickle=True).tolist()
C2 = np.load('AGIshortPrices.npy', allow_pickle=True).tolist()
β2 = np.load('SMshortPrices.npy', allow_pickle=True).tolist()
Q2 = np.load('MERshortPrices.npy', allow_pickle=True).tolist()
Z2 = np.load('SECBshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_2 = []
st_2 = []
n = 1
while n < len(L2):
    sc_2 = ''
    if L2[n] > L2[n-1]:
        sc_2 = sc_2 + 'L'
    if C2[n] > C2[n-1]:
        sc_2 = sc_2 + 'C'
    if β2[n] > β2[n-1]:
        sc_2 = sc_2 + 'β'
    if Q2[n] > Q2[n-1]:
        sc_2 = sc_2 + 'Q'
    if Z2[n] > Z2[n-1]:
        sc_2 = sc_2 + 'Z'
    if len(sc_2) > 0:
        st_2.append(sc_2)
    else:
        STC_2.append(st_2)
        st_2 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_2 = STC_2.count([])
# keep only non-empty spatio-temporal sequences
STC_2 = [ st_2 for st_2 in STC_2 if len(st_2) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_2 = len(L2)
lmax_2 = 0
for st_2 in STC_2:
    if len(st_2) < lmin_2:
        lmin_2 = len(st_2)
    if len(st_2) > lmax_2:
        lmax_2 = len(st_2)
        
# restrict spatio-temporal sequences to length-5
STC5_2 = [ st_2 for st_2 in STC_2 if len(st_2) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_2 = []
for n in range(len(STC5_2)):
    tc_2 = [ u for u in STC5_2[n][0] ]
    for k in range(1, len(STC5_2[n])):
        tc_2 = [ u+v for u in tc_2 for v in STC5_2[n][k] ]
    TC5_2 = TC5_2 + tc_2
setTC5_2 = list(set(TC5_2))

# get empirical frequencies
fTC5_2 = [ TC5_2.count(setTC5_2[l]) for l in range(len(setTC5_2)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_2 = [ [] for l in range(len(setTC5_2)) ]
for s in range(100):
    STC5null_2 = [ list(st_2) for st_2 in STC5_2]
    for st_2 in STC5null_2:
        np.random.shuffle(st_2)
    TC5null_2= []
    for n in range(len(STC5null_2)):
        tc_2 = [ u for u in STC5null_2[n][0] ]
        for k in range(1, len(STC5null_2[n])):
            tc_2 = [ u+v for u in tc_2 for v in STC5null_2[n][k] ]
        TC5null_2= TC5null_2+ tc_2
    for l in range(len(setTC5_2)):
        if TC5null_2.count(setTC5_2[l]) > 0:
            fTC5null_2[l].append(TC5null_2.count(setTC5_2[l]))
        else:
            fTC5null_2[l].append(0)

# %%
print("List of Statistically Significant Sequences at α = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_2)):
    if sum(freq >= fTC5_2[l] for freq in fTC5null_2[l]) < 5:
        #print(setTC5_2[l], fTC5_2[l], sum(freq >= fTC5_2[l] for freq in fTC5null_2[l]))
        print(setTC5_2[l])
# Out:
# List of Statistically Significant Sequences at α = 0.05
# ZQβZ
# βQQZQ
# βCCQ
# LCCQ
# CQLCQ
# ZCQZL
# ββQZQ
# ββZZβ
# ββZZL
# ZβQQβ
# LQβC
# βCZZL
# ZCQQL
# ββQQβ
# ZQLL
# βCQZL
# ZβZCβ
# LQLZ
# LQCQ
# βCZQL
# LQβL
# CββC
# ZβZQQ
# LQβZ
# LZβQ
# ZCZCL
# CLLCL
# ZLZCL
# βQLZβ
# ZβZCL
# βCCLQ
# CQLCβ
# βCZZQ
# βCZQQ
# ββQZβ
# βQLZQ
# ββZLL
# βQβLβ
# ZQCQ
# ZβZQL
# LZβC
# ZLQZQ
# CQLCL
# βCL
# ZβZQβ
# βCQCL
# LQQQ
# βQCZQ
# βCQZQ
# CQLQβ
# LββQ
# ββQCβ
# βQCQ
# ββQQQ
# QCZ
# ZβZLZ
# βQLQQ
# LββC
# LQLL
# CQLCZ
# LZβZ
# LZQC
# βCCZQ
# ZβQZZ
# LQβQ

# %%
print("List of Statistically Significant Sequences at α = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_2)):
    if sum(freq >= fTC5_2[l] for freq in fTC5null_2[l]) < 1:
        #print(setTC5_2[l], fTC5_2[l], sum(freq >= fTC5_2[l] for freq in fTC5null_2[l]))
        print(setTC5_2[l])
# Out:
# List of Statistically Significant Sequences at α = 0.01
# ββZZL
# LQβZ
# βCZZQ
# βQLZQ
# LQQQ
# βCQZQ
# ββQQQ
# LZβZ
# βCCZQ
# LQβQ

# %% [markdown]
# # 3 (L) GTCAP - (C) AGI - (β) SM - (Q) MER - (T) MBT

# %%
#extract the overlapping dates

start_3 = max(min(Date_GTCAP), min(Date_AGI), min(Date_SM), min(Date_MER), min(Date_MBT))
end_3 = min(max(Date_GTCAP), max(Date_AGI), max(Date_SM), max(Date_MER), max(Date_MBT))

# %%
#shorten the closing prices
GTCAP_3_1 = Date_GTCAP.index(start_3)
GTCAP_3_2 = Date_GTCAP.index(end_3)

AGI_3_1 = Date_AGI.index(start_3)
AGI_3_2 = Date_AGI.index(end_3)

SM_3_1 = Date_SM.index(start_3)
SM_3_2 = Date_SM.index(end_3)

MER_3_1 = Date_MER.index(start_3)
MER_3_2 = Date_MER.index(end_3)

MBT_3_1 = Date_MBT.index(start_3)
MBT_3_2 = Date_MBT.index(end_3)

# %%
#save the shortened versions of closing prices
L3 = np.save('GTCAPshortPrices.npy', ClosePrice_GTCAP[GTCAP_3_1:GTCAP_3_2])
C3 = np.save('AGIshortPrices.npy', ClosePrice_AGI[AGI_3_1:AGI_3_2])
β3 = np.save('SMshortPrices.npy', ClosePrice_SM[SM_3_1:SM_3_2])
Q3 = np.save('MERshortPrices.npy', ClosePrice_MER[MER_3_1:MER_3_2])
T3 = np.save('MBTshortPrices.npy', ClosePrice_MBT[MBT_3_1:MBT_3_2])

# %%
# import modules
import numpy as np
# import prices
L3 = np.load('GTCAPshortPrices.npy', allow_pickle=True).tolist()
C3 = np.load('AGIshortPrices.npy', allow_pickle=True).tolist()
β3 = np.load('SMshortPrices.npy', allow_pickle=True).tolist()
Q3 = np.load('MERshortPrices.npy', allow_pickle=True).tolist()
T3 = np.load('MBTshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_3 = []
st_3 = []
n = 1
while n < len(L3):
    sc_3 = ''
    if L3[n] > L3[n-1]:
        sc_3 = sc_3 + 'L'
    if C3[n] > C3[n-1]:
        sc_3 = sc_3 + 'C'
    if β3[n] > β3[n-1]:
        sc_3 = sc_3 + 'β'
    if Q3[n] > Q3[n-1]:
        sc_3 = sc_3 + 'Q'
    if T3[n] > T3[n-1]:
        sc_3 = sc_3 + 'T'
    if len(sc_3) > 0:
        st_3.append(sc_3)
    else:
        STC_3.append(st_3)
        st_3 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_3 = STC_3.count([])
# keep only non-empty spatio-temporal sequences
STC_3 = [ st_3 for st_3 in STC_3 if len(st_3) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_3 = len(L3)
lmax_3 = 0
for st_3 in STC_3:
    if len(st_3) < lmin_3:
        lmin_3 = len(st_3)
    if len(st_3) > lmax_3:
        lmax_3 = len(st_3)
        
# restrict spatio-temporal sequences to length-5
STC5_3 = [ st_3 for st_3 in STC_3 if len(st_3) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_3 = []
for n in range(len(STC5_3)):
    tc_3 = [ u for u in STC5_3[n][0] ]
    for k in range(1, len(STC5_3[n])):
        tc_3 = [ u+v for u in tc_3 for v in STC5_3[n][k] ]
    TC5_3 = TC5_3 + tc_3
setTC5_3 = list(set(TC5_3))

# get empirical frequencies
fTC5_3 = [ TC5_3.count(setTC5_3[l]) for l in range(len(setTC5_3)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_3 = [ [] for l in range(len(setTC5_3)) ]
for s in range(100):
    STC5null_3 = [ list(st_3) for st_3 in STC5_3]
    for st_3 in STC5null_3:
        np.random.shuffle(st_3)
    TC5null_3= []
    for n in range(len(STC5null_3)):
        tc_3 = [ u for u in STC5null_3[n][0] ]
        for k in range(1, len(STC5null_3[n])):
            tc_3 = [ u+v for u in tc_3 for v in STC5null_3[n][k] ]
        TC5null_3= TC5null_3+ tc_3
    for l in range(len(setTC5_3)):
        if TC5null_3.count(setTC5_3[l]) > 0:
            fTC5null_3[l].append(TC5null_3.count(setTC5_3[l]))
        else:
            fTC5null_3[l].append(0)

# %%
print("List of Statistically Significant Sequences at α = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_3)):
    if sum(freq >= fTC5_3[l] for freq in fTC5null_3[l]) < 5:
        #print(setTC5_3[l], fTC5_3[l], sum(freq >= fTC5_3[l] for freq in fTC5null_3[l]))
        print(setTC5_3[l])
# Out:
# List of Statistically Significant Sequences at α = 0.05
# βQTLβ
# βQQTβ
# βQQTT
# βTQTC
# βTQTT
# TLQTC
# LTQTC
# TTββC
# TLQTβ
# LTβQ
# βLQCβ
# LCCQ
# βLQLC
# βLβTβ
# βCTTC
# TQQLβ
# βLTCβ
# TQQTC
# βQTLC
# LQQTT
# TLβTβ
# QβCCQ
# βQQCβ
# βββC
# βCTLC
# TQQCL
# TQβTβ
# βLQTC
# LTβT
# βLQTT
# βQQTC
# βQTCL
# QβLTC
# CββL
# LβQTC
# TβQTC
# βQQβC
# βQQCL
# LLTTβ
# βLTTβ
# TLTCL
# TLQCβ
# QQL
# LQCQ
# LQβL
# CββC
# LQQTC
# LLQTT
# TLTCβ
# βQTCβ
# LLQTβ
# βTTLC
# TLQCL
# βLQCL
# βQβLβ
# TCQTC
# CβTC
# βQQLβ
# βQTLT
# TQCQ
# TQQTT
# βQβTβ
# βLQTβ
# LLQCβ
# TTQTC
# LLQTC
# ββQTC
# βCT
# TLLCL
# TQββC
# βQCQ
# LCQTC
# βββQ
# ββCT
# TLQTT
# TβQβC
# βCQTC
# TQβCβ
# βTTTC
# LLTCβ
# βQβQ
# TQQβC
# TLTTβ
# βQT
# TQTCβ
# QQT
# TQβLβ
# TQQCβ
# QβLTQ
# LQβQ

# %%
print("List of Statistically Significant Sequences at α = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_3)):
    if sum(freq >= fTC5_3[l] for freq in fTC5null_3[l]) < 1:
        #print(setTC5_3[l], fTC5_3[l], sum(freq >= fTC5_3[l] for freq in fTC5null_3[l]))
        print(setTC5_3[l])
# Out:
# List of Statistically Significant Sequences at α = 0.01
# TLQTC
# LTβQ
# βLβTβ
# βLTCβ
# TQQTC
# TLβTβ
# βQQTC
# LQCQ
# CββC
# LQQTC
# βQβLβ
# βQβTβ
# LLQTC
# βQCQ
# TLTTβ
# QβLTQ

# %% [markdown]
# # 4 (L) GTCAP - (C) AGI - (β) SM - (Q) MER - (V) TEL

# %%
#extract the overlapping dates

start_4 = max(min(Date_GTCAP), min(Date_AGI), min(Date_SM), min(Date_MER), min(Date_TEL))
end_4 = min(max(Date_GTCAP), max(Date_AGI), max(Date_SM), max(Date_MER), max(Date_TEL))

# %%
#shorten the closing prices
GTCAP_4_1 = Date_GTCAP.index(start_4)
GTCAP_4_2 = Date_GTCAP.index(end_4)

AGI_4_1 = Date_AGI.index(start_4)
AGI_4_2 = Date_AGI.index(end_4)

SM_4_1 = Date_SM.index(start_4)
SM_4_2 = Date_SM.index(end_4)

MER_4_1 = Date_MER.index(start_4)
MER_4_2 = Date_MER.index(end_4)

TEL_4_1 = Date_TEL.index(start_4)
TEL_4_2 = Date_TEL.index(end_4)

# %%
#save the shortened versions of closing prices
L4 = np.save('GTCAPshortPrices.npy', ClosePrice_GTCAP[GTCAP_4_1:GTCAP_4_2])
C4 = np.save('AGIshortPrices.npy', ClosePrice_AGI[AGI_4_1:AGI_4_2])
β4 = np.save('SMshortPrices.npy', ClosePrice_SM[SM_4_1:SM_4_2])
Q4 = np.save('MERshortPrices.npy', ClosePrice_MER[MER_4_1:MER_4_2])
V4 = np.save('TELshortPrices.npy', ClosePrice_TEL[TEL_4_1:TEL_4_2])

# %%
# import modules
import numpy as np
# import prices
L4 = np.load('GTCAPshortPrices.npy', allow_pickle=True).tolist()
C4 = np.load('AGIshortPrices.npy', allow_pickle=True).tolist()
β4 = np.load('SMshortPrices.npy', allow_pickle=True).tolist()
Q4 = np.load('MERshortPrices.npy', allow_pickle=True).tolist()
V4 = np.load('TELshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_4 = []
st_4 = []
n = 1
while n < len(L4):
    sc_4 = ''
    if L4[n] > L4[n-1]:
        sc_4 = sc_4 + 'L'
    if C4[n] > C4[n-1]:
        sc_4 = sc_4 + 'C'
    if β4[n] > β4[n-1]:
        sc_4 = sc_4 + 'β'
    if Q4[n] > Q4[n-1]:
        sc_4 = sc_4 + 'Q'
    if V4[n] > V4[n-1]:
        sc_4 = sc_4 + 'V'
    if len(sc_4) > 0:
        st_4.append(sc_4)
    else:
        STC_4.append(st_4)
        st_4 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_4 = STC_4.count([])
# keep only non-empty spatio-temporal sequences
STC_4 = [ st_4 for st_4 in STC_4 if len(st_4) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_4 = len(L4)
lmax_4 = 0
for st_4 in STC_4:
    if len(st_4) < lmin_4:
        lmin_4 = len(st_4)
    if len(st_4) > lmax_4:
        lmax_4 = len(st_4)
        
# restrict spatio-temporal sequences to length-5
STC5_4 = [ st_4 for st_4 in STC_4 if len(st_4) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_4 = []
for n in range(len(STC5_4)):
    tc_4 = [ u for u in STC5_4[n][0] ]
    for k in range(1, len(STC5_4[n])):
        tc_4 = [ u+v for u in tc_4 for v in STC5_4[n][k] ]
    TC5_4 = TC5_4 + tc_4
setTC5_4 = list(set(TC5_4))

# get empirical frequencies
fTC5_4 = [ TC5_4.count(setTC5_4[l]) for l in range(len(setTC5_4)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_4 = [ [] for l in range(len(setTC5_4)) ]
for s in range(100):
    STC5null_4 = [ list(st_4) for st_4 in STC5_4]
    for st_4 in STC5null_4:
        np.random.shuffle(st_4)
    TC5null_4= []
    for n in range(len(STC5null_4)):
        tc_4 = [ u for u in STC5null_4[n][0] ]
        for k in range(1, len(STC5null_4[n])):
            tc_4 = [ u+v for u in tc_4 for v in STC5null_4[n][k] ]
        TC5null_4= TC5null_4+ tc_4
    for l in range(len(setTC5_4)):
        if TC5null_4.count(setTC5_4[l]) > 0:
            fTC5null_4[l].append(TC5null_4.count(setTC5_4[l]))
        else:
            fTC5null_4[l].append(0)

# %%
print("List of Statistically Significant Sequences at α = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_4)):
    if sum(freq >= fTC5_4[l] for freq in fTC5null_4[l]) < 5:
        #print(setTC5_4[l], fTC5_4[l], sum(freq >= fTC5_4[l] for freq in fTC5null_4[l]))
        print(setTC5_4[l])
# Out:
# List of Statistically Significant Sequences at α = 0.05
# βQVQβ
# CLLLV
# CQQCQ
# VQVCβ
# CLVCL
# LQQCβ
# CQLCQ
# VVQCV
# βVLV
# ββLVQ
# βQQCβ
# CβCC
# βLLVQ
# βQQVC
# CQVCC
# CQVCβ
# LQQVC
# VQQCβ
# βQVQQ
# CLVCβ
# βQVCQ
# βLVVV
# LQCQ
# VVQCβ
# CββC
# βLβVβ
# CLLCL
# βLVCβ
# CLLVV
# CQVCL
# βLLQQ
# βVVCV
# βLVCL
# CQLCβ
# VLQCβ
# βLVVQ
# QVβQ
# βLLVV
# βVVβV
# CVQCβ
# CβQCβ
# βVVQV
# CVVCβ
# βQLVQ
# CLLVQ
# βQVCV
# βQLCQ
# LLQCβ
# CLVCQ
# βQVVQ
# CQVCV
# CLLQQ
# VVVβ
# βVVCβ
# βLVCQ
# VLLCQ
# βQCQ
# CLLCQ
# βQVβV
# CQVCQ
# βLβLβ
# βQLQQ
# CQQCβ
# βVVβL
# CQVQV
# βQVCβ
# CLβCβ
# VβQCβ

# %%
print("List of Statistically Significant Sequences at α = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_4)):
    if sum(freq >= fTC5_4[l] for freq in fTC5null_4[l]) < 1:
        #print(setTC5_4[l], fTC5_4[l], sum(freq >= fTC5_4[l] for freq in fTC5null_4[l]))
        print(setTC5_4[l])
# Out:
# List of Statistically Significant Sequences at α = 0.01
# βLLVQ
# CQVCβ
# VQQCβ
# CββC
# βVVCV
# βLVCL
# βLLVV
# CVVCβ
# βQLCQ
# CQVCQ
# CQQCβ
# βQVCβ

# %% [markdown]
# # 5 (L) GTCAP - (C) AGI - (β) SM - (Q) MER - (ε) URC

# %%
#extract the overlapping dates

start_5 = max(min(Date_GTCAP), min(Date_AGI), min(Date_SM), min(Date_MER), min(Date_URC))
end_5 = min(max(Date_GTCAP), max(Date_AGI), max(Date_SM), max(Date_MER), max(Date_URC))

# %%
#shorten the closing prices
GTCAP_5_1 = Date_GTCAP.index(start_5)
GTCAP_5_2 = Date_GTCAP.index(end_5)

AGI_5_1 = Date_AGI.index(start_5)
AGI_5_2 = Date_AGI.index(end_5)

SM_5_1 = Date_SM.index(start_5)
SM_5_2 = Date_SM.index(end_5)

MER_5_1 = Date_MER.index(start_5)
MER_5_2 = Date_MER.index(end_5)

URC_5_1 = Date_URC.index(start_5)
URC_5_2 = Date_URC.index(end_5)

# %%
#save the shortened versions of closing prices
L5 = np.save('GTCAPshortPrices.npy', ClosePrice_GTCAP[GTCAP_5_1:GTCAP_5_2])
C5 = np.save('AGIshortPrices.npy', ClosePrice_AGI[AGI_5_1:AGI_5_2])
β5 = np.save('SMshortPrices.npy', ClosePrice_SM[SM_5_1:SM_5_2])
Q5 = np.save('MERshortPrices.npy', ClosePrice_MER[MER_5_1:MER_5_2])
ε5 = np.save('URCshortPrices.npy', ClosePrice_URC[URC_5_1:URC_5_2])

# %%
# import modules
import numpy as np
# import prices
L5 = np.load('GTCAPshortPrices.npy', allow_pickle=True).tolist()
C5 = np.load('AGIshortPrices.npy', allow_pickle=True).tolist()
β5 = np.load('SMshortPrices.npy', allow_pickle=True).tolist()
Q5 = np.load('MERshortPrices.npy', allow_pickle=True).tolist()
ε5 = np.load('URCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_5 = []
st_5 = []
n = 1
while n < len(L5):
    sc_5 = ''
    if L5[n] > L5[n-1]:
        sc_5 = sc_5 + 'L'
    if C5[n] > C5[n-1]:
        sc_5 = sc_5 + 'C'
    if β5[n] > β5[n-1]:
        sc_5 = sc_5 + 'β'
    if Q5[n] > Q5[n-1]:
        sc_5 = sc_5 + 'Q'
    if ε5[n] > ε5[n-1]:
        sc_5 = sc_5 + 'ε'
    if len(sc_5) > 0:
        st_5.append(sc_5)
    else:
        STC_5.append(st_5)
        st_5 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_5 = STC_5.count([])
# keep only non-empty spatio-temporal sequences
STC_5 = [ st_5 for st_5 in STC_5 if len(st_5) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_5 = len(L5)
lmax_5 = 0
for st_5 in STC_5:
    if len(st_5) < lmin_5:
        lmin_5 = len(st_5)
    if len(st_5) > lmax_5:
        lmax_5 = len(st_5)
        
# restrict spatio-temporal sequences to length-5
STC5_5 = [ st_5 for st_5 in STC_5 if len(st_5) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_5 = []
for n in range(len(STC5_5)):
    tc_5 = [ u for u in STC5_5[n][0] ]
    for k in range(1, len(STC5_5[n])):
        tc_5 = [ u+v for u in tc_5 for v in STC5_5[n][k] ]
    TC5_5 = TC5_5 + tc_5
setTC5_5 = list(set(TC5_5))

# get empirical frequencies
fTC5_5 = [ TC5_5.count(setTC5_5[l]) for l in range(len(setTC5_5)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_5 = [ [] for l in range(len(setTC5_5)) ]
for s in range(100):
    STC5null_5 = [ list(st_5) for st_5 in STC5_5]
    for st_5 in STC5null_5:
        np.random.shuffle(st_5)
    TC5null_5= []
    for n in range(len(STC5null_5)):
        tc_5 = [ u for u in STC5null_5[n][0] ]
        for k in range(1, len(STC5null_5[n])):
            tc_5 = [ u+v for u in tc_5 for v in STC5null_5[n][k] ]
        TC5null_5= TC5null_5+ tc_5
    for l in range(len(setTC5_5)):
        if TC5null_5.count(setTC5_5[l]) > 0:
            fTC5null_5[l].append(TC5null_5.count(setTC5_5[l]))
        else:
            fTC5null_5[l].append(0)

# %%
print("List of Statistically Significant Sequences at α = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_5)):
    if sum(freq >= fTC5_5[l] for freq in fTC5null_5[l]) < 5:
        #print(setTC5_5[l], fTC5_5[l], sum(freq >= fTC5_5[l] for freq in fTC5null_5[l]))
        print(setTC5_5[l])
# Out:
# List of Statistically Significant Sequences at α = 0.05
# εLCCβ
# βLLεL
# εLεCβ
# ββεQ
# CLεLβ
# CβLCβ
# βLLLβ
# CLLQC
# εεLCL
# CQLCQ
# βεεC
# εεL
# εLεLβ
# βLεLQ
# βββC
# βCε
# CLLεβ
# εLεCC
# LQβC
# CLCCβ
# LεLεQ
# βLεεβ
# LQεQ
# βLCCβ
# εεLεL
# QCε
# βLLCβ
# QCQ
# βLLCL
# CεεC
# βLLεβ
# LQCQ
# βCCεQ
# CββC
# βQεQ
# βLεCβ
# CβQεβ
# εLεεC
# LεQεQ
# LCεQ
# CQLCβ
# εLεQC
# εεβCL
# βLεββ
# CβQCβ
# Cββεβ
# βLεQC
# βQLCQ
# βεεQ
# βLεβQ
# CLεCC
# CβLεQ
# βCεQ
# βLεLβ
# βLεLC
# CCCεQ
# CβεC
# ββεC
# βεLεQ
# βQLQQ
# βQLCβ
# βεLQQ
# LββC
# εLεLC
# βLεCC
# CQQCβ
# CLεCβ
# εεQCL
# CεCεQ
# ββLC
# LQβQ

# %%
print("List of Statistically Significant Sequences at α = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_5)):
    if sum(freq >= fTC5_5[l] for freq in fTC5null_5[l]) < 1:
        print(setTC5_5[l], fTC5_5[l], sum(freq >= fTC5_5[l] for freq in fTC5null_5[l]))
# Out:
# List of Statistically Significant Sequences at α = 0.01
# εLεCβ
# βββC
# εLεCC
# CLCCβ
# βLεεβ
# LQεQ
# βCCεQ
# βLεCβ
# βLεLβ
# LββC

# %% [markdown]
# # 6 (L) GTCAP - (C) AGI - (β) SM - (Q) MER - (W) PGOLD

# %%
#extract the overlapping dates

start_6 = max(min(Date_GTCAP), min(Date_AGI), min(Date_SM), min(Date_MER), min(Date_PGOLD))
end_6 = min(max(Date_GTCAP), max(Date_AGI), max(Date_SM), max(Date_MER), max(Date_PGOLD))

# %%
#shorten the closing prices
GTCAP_6_1 = Date_GTCAP.index(start_6)
GTCAP_6_2 = Date_GTCAP.index(end_6)

AGI_6_1 = Date_AGI.index(start_6)
AGI_6_2 = Date_AGI.index(end_6)

SM_6_1 = Date_SM.index(start_6)
SM_6_2 = Date_SM.index(end_6)

MER_6_1 = Date_MER.index(start_6)
MER_6_2 = Date_MER.index(end_6)

PGOLD_6_1 = Date_PGOLD.index(start_6)
PGOLD_6_2 = Date_PGOLD.index(end_6)

# %%
#save the shortened versions of closing prices
L6 = np.save('GTCAPshortPrices.npy', ClosePrice_GTCAP[GTCAP_6_1:GTCAP_6_2])
C6 = np.save('AGIshortPrices.npy', ClosePrice_AGI[AGI_6_1:AGI_6_2])
β6 = np.save('SMshortPrices.npy', ClosePrice_SM[SM_6_1:SM_6_2])
Q6 = np.save('MERshortPrices.npy', ClosePrice_MER[MER_6_1:MER_6_2])
W6 = np.save('PGOLDshortPrices.npy', ClosePrice_URC[PGOLD_6_1:PGOLD_6_2])

# %%
# import modules
import numpy as np
# import prices
L6 = np.load('GTCAPshortPrices.npy', allow_pickle=True).tolist()
C6 = np.load('AGIshortPrices.npy', allow_pickle=True).tolist()
β6 = np.load('SMshortPrices.npy', allow_pickle=True).tolist()
Q6 = np.load('MERshortPrices.npy', allow_pickle=True).tolist()
W6 = np.load('PGOLDshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_6 = []
st_6 = []
n = 1
while n < len(L6):
    sc_6 = ''
    if L6[n] > L6[n-1]:
        sc_6 = sc_6 + 'L'
    if C6[n] > C6[n-1]:
        sc_6 = sc_6 + 'C'
    if β6[n] > β6[n-1]:
        sc_6 = sc_6 + 'β'
    if Q6[n] > Q6[n-1]:
        sc_6 = sc_6 + 'Q'
    if W6[n] > W6[n-1]:
        sc_6 = sc_6 + 'V'
    if len(sc_6) > 0:
        st_6.append(sc_6)
    else:
        STC_6.append(st_6)
        st_6 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_6 = STC_6.count([])
# keep only non-empty spatio-temporal sequences
STC_6 = [ st_6 for st_6 in STC_6 if len(st_6) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_6 = len(L6)
lmax_6 = 0
for st_6 in STC_6:
    if len(st_6) < lmin_6:
        lmin_6 = len(st_6)
    if len(st_6) > lmax_6:
        lmax_6 = len(st_6)
        
# restrict spatio-temporal sequences to length-5
STC5_6 = [ st_6 for st_6 in STC_6 if len(st_6) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_6 = []
for n in range(len(STC5_6)):
    tc_6 = [ u for u in STC5_6[n][0] ]
    for k in range(1, len(STC5_6[n])):
        tc_6 = [ u+v for u in tc_6 for v in STC5_6[n][k] ]
    TC5_6 = TC5_6 + tc_6
setTC5_6 = list(set(TC5_6))

# get empirical frequencies
fTC5_6 = [ TC5_6.count(setTC5_6[l]) for l in range(len(setTC5_6)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_6 = [ [] for l in range(len(setTC5_6)) ]
for s in range(100):
    STC5null_6 = [ list(st_6) for st_6 in STC5_6]
    for st_6 in STC5null_6:
        np.random.shuffle(st_6)
    TC5null_6= []
    for n in range(len(STC5null_6)):
        tc_6 = [ u for u in STC5null_6[n][0] ]
        for k in range(1, len(STC5null_6[n])):
            tc_6 = [ u+v for u in tc_6 for v in STC5null_6[n][k] ]
        TC5null_6= TC5null_6+ tc_6
    for l in range(len(setTC5_6)):
        if TC5null_6.count(setTC5_6[l]) > 0:
            fTC5null_6[l].append(TC5null_6.count(setTC5_6[l]))
        else:
            fTC5null_6[l].append(0)

# %%
print("List of Statistically Significant Sequences at α = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_6)):
    if sum(freq >= fTC5_6[l] for freq in fTC5null_6[l]) < 5:
        print(setTC5_6[l], fTC5_6[l], sum(freq >= fTC5_6[l] for freq in fTC5null_6[l]))
# Out:
# List of Statistically Significant Sequences at α = 0.05
# VLVVL
# VQCL
# βLVLV
# βQVLC
# CLLQC
# CLVCL
# CLVCV
# βLVQC
# CLVCC
# βLQCβ
# VQVβC
# VQVCC
# βQVLβ
# VQVLC
# βLVLβ
# CLLCC
# VQLQC
# βLLQβ
# VQLLβ
# VCVβC
# VQLLL
# βLLLC
# βQQCβ
# βLLQC
# VLVCL
# βQVβL
# LQβC
# βLVLL
# βCQQβ
# ββQQβ
# βQL
# VQVCL
# βLVQβ
# VVLQQ
# VQLβC
# βCβQβ
# βQVCL
# βLVβV
# βLLCL
# QQL
# VCβCC
# LQCQ
# CββC
# VQVVC
# VLVLC
# ββVβC
# βLVCβ
# βQVβC
# VQβLL
# βLVCL
# CLVLC
# CQCβC
# VCVCC
# βLVVβ
# VQLQβ
# VLVVβ
# βLQQC
# βββQβ
# βLQCL
# βLVβC
# VLVCC
# βCQCβ
# βQβLβ
# VLVβC
# ββVCC
# VLVVC
# βQVVC
# βCQQC
# ββVLC
# βCL
# βLLLL
# VQVβL
# VQVLL
# QCL
# LLQCβ
# βQVCC
# VQQLL
# VVLVQ
# ββQCβ
# VβQLL
# βLVQL
# βCVCC
# VCQCC
# βQVββ
# βLVCC
# VCQβC
# VβVCC
# VQLCC
# ββQCC
# VβVβC
# βLVββ
# βLVCV
# LββC
# VQLLC
# βββCβ
# βQVVV
# βQVVβ
# βLVLC

# %%
print("List of Statistically Significant Sequences at α = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_6)):
    if sum(freq >= fTC5_6[l] for freq in fTC5null_6[l]) < 1:
        print(setTC5_6[l], fTC5_6[l], sum(freq >= fTC5_6[l] for freq in fTC5null_6[l]))
# Out:
# List of Statistically Significant Sequences at α = 0.01
# βLVLV
# βLVQC
# CLVCC
# VQVCC
# βLVLβ
# VQLLL
# βCQQβ
# ββQQβ
# VQVCL
# βLVQβ
# VVLQQ
# βQVCL
# LQCQ
# βLVCβ
# βQVβC
# βLVCL
# βLVβC
# VQVLL
# βQVCC
# ββQCβ
# βLVCC
# βLVββ
# βLVLC

# %% [markdown]
# # 7 (L) GTCAP - (C) AGI - (β) SM - (E) ALI - (Z) SECB

# %%
#extract the overlapping dates

start_7 = max(min(Date_GTCAP), min(Date_AGI), min(Date_SM), min(Date_ALI), min(Date_SECB))
end_7 = min(max(Date_GTCAP), max(Date_AGI), max(Date_SM), max(Date_ALI), max(Date_SECB))

# %%
#shorten the closing prices
GTCAP_7_1 = Date_GTCAP.index(start_7)
GTCAP_7_2 = Date_GTCAP.index(end_7)

AGI_7_1 = Date_AGI.index(start_7)
AGI_7_2 = Date_AGI.index(end_7)

SM_7_1 = Date_SM.index(start_7)
SM_7_2 = Date_SM.index(end_7)

ALI_7_1 = Date_ALI.index(start_7)
ALI_7_2 = Date_ALI.index(end_7)

SECB_7_1 = Date_SECB.index(start_7)
SECB_7_2 = Date_SECB.index(end_7)

# %%
#save the shortened versions of closing prices
L7 = np.save('GTCAPshortPrices.npy', ClosePrice_GTCAP[GTCAP_7_1:GTCAP_7_2])
C7 = np.save('AGIshortPrices.npy', ClosePrice_AGI[AGI_7_1:AGI_7_2])
β7 = np.save('SMshortPrices.npy', ClosePrice_SM[SM_7_1:SM_7_2])
E7 = np.save('ALIshortPrices.npy', ClosePrice_ALI[ALI_7_1:ALI_7_2])
Z7 = np.save('SECBshortPrices.npy', ClosePrice_URC[SECB_7_1:SECB_7_2])

# %%
# import modules
import numpy as np
# import prices
L7 = np.load('GTCAPshortPrices.npy', allow_pickle=True).tolist()
C7 = np.load('AGIshortPrices.npy', allow_pickle=True).tolist()
β7 = np.load('SMshortPrices.npy', allow_pickle=True).tolist()
E7 = np.load('ALIshortPrices.npy', allow_pickle=True).tolist()
Z7 = np.load('SECBshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_7 = []
st_7 = []
n = 1
while n < len(L7):
    sc_7 = ''
    if L7[n] > L7[n-1]:
        sc_7 = sc_7 + 'L'
    if C7[n] > C7[n-1]:
        sc_7 = sc_7 + 'C'
    if β7[n] > β7[n-1]:
        sc_7 = sc_7 + 'β'
    if E7[n] > E7[n-1]:
        sc_7 = sc_7 + 'E'
    if Z7[n] > Z7[n-1]:
        sc_7 = sc_7 + 'Z'
    if len(sc_7) > 0:
        st_7.append(sc_7)
    else:
        STC_7.append(st_7)
        st_7 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_7 = STC_7.count([])
# keep only non-empty spatio-temporal sequences
STC_7 = [ st_7 for st_7 in STC_7 if len(st_7) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_7 = len(L7)
lmax_7 = 0
for st_7 in STC_7:
    if len(st_7) < lmin_7:
        lmin_7 = len(st_7)
    if len(st_7) > lmax_7:
        lmax_7 = len(st_7)
        
# restrict spatio-temporal sequences to length-5
STC5_7 = [ st_7 for st_7 in STC_7 if len(st_7) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_7 = []
for n in range(len(STC5_7)):
    tc_7 = [ u for u in STC5_7[n][0] ]
    for k in range(1, len(STC5_7[n])):
        tc_7 = [ u+v for u in tc_7 for v in STC5_7[n][k] ]
    TC5_7 = TC5_7 + tc_7
setTC5_7 = list(set(TC5_7))

# get empirical frequencies
fTC5_7 = [ TC5_7.count(setTC5_7[l]) for l in range(len(setTC5_7)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_7 = [ [] for l in range(len(setTC5_7)) ]
for s in range(100):
    STC5null_7 = [ list(st_7) for st_7 in STC5_7]
    for st_7 in STC5null_7:
        np.random.shuffle(st_7)
    TC5null_7= []
    for n in range(len(STC5null_7)):
        tc_7 = [ u for u in STC5null_7[n][0] ]
        for k in range(1, len(STC5null_7[n])):
            tc_7 = [ u+v for u in tc_7 for v in STC5null_7[n][k] ]
        TC5null_7= TC5null_7+ tc_7
    for l in range(len(setTC5_7)):
        if TC5null_7.count(setTC5_7[l]) > 0:
            fTC5null_7[l].append(TC5null_7.count(setTC5_7[l]))
        else:
            fTC5null_7[l].append(0)

# %%
print("List of Statistically Significant Sequences at α = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_7)):
    if sum(freq >= fTC5_7[l] for freq in fTC5null_7[l]) < 5:
        print(setTC5_7[l], fTC5_7[l], sum(freq >= fTC5_7[l] for freq in fTC5null_7[l]))
# Out:
# List of Statistically Significant Sequences at α = 0.05
# βCZLC
# LCZE
# LLCE
# ZβCCZ
# ZβZCZ
# βZEβE
# βLZCE
# CZβZ
# ZLβCZ
# βLCE
# ZLZCZ
# βLECE
# ECZCL
# ZββCZ
# βLZβ
# ELβCβ
# βZECE
# βZECC
# βLECZ
# LCZβ
# LLZCL
# βLECC
# ββLCZ
# ZZβCE
# ββZCZ
# LZZZ
# βCCE
# ββZCβ
# βLEβC
# ββLCβ
# ZLCZZ
# ZCβCZ
# LLCβ
# LLββ
# βZELC
# βZELE
# ββECZ
# ββECβ
# ZLECE
# βCZE
# βCEEE
# ECCCE
# ZZCCE
# βLZE
# ZLECZ
# ZCCCZ
# ZZECE
# ZββCE
# ZβCCE
# ZLEβZ
# LLZβ
# βLEEE
# LCCE
# EZββE
# ECZCE
# LLβC
# βLEβE
# ZLELZ
# ZCZCZ
# βZEβC
# βZZLC
# ZCCCE
# βZEEE
# LCCCL
# CEZβ
# βEZE
# βZLβE
# ZCCZZ
# ZLCCZ
# LZβZ
# LCZCL
# βZZLE

# %%
print("List of Statistically Significant Sequences at α = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_7)):
    if sum(freq >= fTC5_7[l] for freq in fTC5null_7[l]) < 1:
        print(setTC5_7[l], fTC5_7[l], sum(freq >= fTC5_7[l] for freq in fTC5null_7[l]))
# Out:
# List of Statistically Significant Sequences at α = 0.01
# LLCE
# βLECE
# ZLECE
# βCZE
# ZZECE
# βLEEE
# LCCE
# LCZCL

# %% [markdown]
# # 8 (L) GTCAP - (C) AGI - (β) SM - (E) ALI - (T) MBT

# %%
#extract the overlapping dates

start_8 = max(min(Date_GTCAP), min(Date_AGI), min(Date_SM), min(Date_ALI), min(Date_MBT))
end_8 = min(max(Date_GTCAP), max(Date_AGI), max(Date_SM), max(Date_ALI), max(Date_MBT))

# %%
#shorten the closing prices
GTCAP_8_1 = Date_GTCAP.index(start_8)
GTCAP_8_2 = Date_GTCAP.index(end_8)

AGI_8_1 = Date_AGI.index(start_8)
AGI_8_2 = Date_AGI.index(end_8)

SM_8_1 = Date_SM.index(start_8)
SM_8_2 = Date_SM.index(end_8)

ALI_8_1 = Date_ALI.index(start_8)
ALI_8_2 = Date_ALI.index(end_8)

MBT_8_1 = Date_MBT.index(start_8)
MBT_8_2 = Date_MBT.index(end_8)

# %%
#save the shortened versions of closing prices
L8 = np.save('GTCAPshortPrices.npy', ClosePrice_GTCAP[GTCAP_8_1:GTCAP_8_2])
C8 = np.save('AGIshortPrices.npy', ClosePrice_AGI[AGI_8_1:AGI_8_2])
β8 = np.save('SMshortPrices.npy', ClosePrice_SM[SM_8_1:SM_8_2])
E8 = np.save('ALIshortPrices.npy', ClosePrice_ALI[ALI_8_1:ALI_8_2])
T8 = np.save('MBTshortPrices.npy', ClosePrice_URC[MBT_8_1:MBT_8_2])

# %%
# import modules
import numpy as np
# import prices
L8 = np.load('GTCAPshortPrices.npy', allow_pickle=True).tolist()
C8 = np.load('AGIshortPrices.npy', allow_pickle=True).tolist()
β8 = np.load('SMshortPrices.npy', allow_pickle=True).tolist()
E8 = np.load('ALIshortPrices.npy', allow_pickle=True).tolist()
T8 = np.load('MBTshortPrices.npy', allow_pickle=True).tolist()

# %%
# # extract spatio-temporal sequences
# STC_8 = []
# st_8 = []
# n = 1
# while n < len(L8):
#     sc_8 = ''
#     if L8[n] > L8[n-1]:
#         sc_8 = sc_8 + 'L'
#     if C8[n] > C8[n-1]:
#         sc_8 = sc_8 + 'C'
#     if β8[n] > β8[n-1]:
#         sc_8 = sc_8 + 'β'
#     if E8[n] > E8[n-1]:
#         sc_8 = sc_8 + 'E'
#     if T8[n] > T8[n-1]:
#         sc_8 = sc_8 + 'T'
#     if len(sc_8) > 0:
#         st_8.append(sc_8)
#     else:
#         STC_8.append(st_8)
#         st_8 = []
#     n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 15
#      13 if E8[n] > E8[n-1]:
#      14     sc_8 = sc_8 + 'E'
# ---> 15 if T8[n] > T8[n-1]:
#      16     sc_8 = sc_8 + 'T'
#      17 if len(sc_8) > 0:
#
# IndexError: list index out of range

# %%
# # record the number of empty spatio-temporal sequences
# nSTCempty_8 = STC_8.count([])
# # keep only non-empty spatio-temporal sequences
# STC_8 = [ st_8 for st_8 in STC_8 if len(st_8) > 0 ]

# # record the length of the longest spatio-temporal sequence
# lmin_8 = len(L8)
# lmax_8 = 0
# for st_8 in STC_8:
#     if len(st_8) < lmin_8:
#         lmin_8 = len(st_8)
#     if len(st_8) > lmax_8:
#         lmax_8 = len(st_8)
        
# # restrict spatio-temporal sequences to length-5
# STC5_8 = [ st_8 for st_8 in STC_8 if len(st_8) <= 5 ]

# # unpack spatio-temporal sequences to temporal sequences
# TC5_8 = []
# for n in range(len(STC5_8)):
#     tc_8 = [ u for u in STC5_8[n][0] ]
#     for k in range(1, len(STC5_8[n])):
#         tc_8 = [ u+v for u in tc_8 for v in STC5_8[n][k] ]
#     TC5_8 = TC5_8 + tc_8
# setTC5_8 = list(set(TC5_8))

# # get empirical frequencies
# fTC5_8 = [ TC5_8.count(setTC5_8[l]) for l in range(len(setTC5_8)) ]

# # statistical testing against null model
# fTC5null_8 = [ [] for l in range(len(setTC5_8)) ]
# for s in range(100):
#     STC5null_8 = [ list(st_8) for st_8 in STC5_8]
#     for st_8 in STC5null_8:
#         np.random.shuffle(st_8)
#     TC5null_8= []
#     for n in range(len(STC5null_8)):
#         tc_8 = [ u for u in STC5null_8[n][0] ]
#         for k in range(1, len(STC5null_8[n])):
#             tc_8 = [ u+v for u in tc_8 for v in STC5null_8[n][k] ]
#         TC5null_8= TC5null_8+ tc_8
#     for l in range(len(setTC5_8)):
#         if TC5null_8.count(setTC5_8[l]) > 0:
#             fTC5null_8[l].append(TC5null_8.count(setTC5_8[l]))
#         else:
#             fTC5null_8[l].append(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[97], line 2
#       1 # record the number of empty spatio-temporal sequences
# ----> 2 nSTCempty_8 = STC_8.count([])
#       3 # keep only non-empty spatio-temporal sequences
#       4 STC_8 = [ st_8 for st_8 in STC_8 if len(st_8) > 0 ]
#
# NameError: name 'STC_8' is not defined

# %%
# print("List of Statistically Significant Sequences at α = 0.05")

# #statistical significance testing at p < 0.05 level
# for l in range(len(setTC5_8)):
#     if sum(freq >= fTC5_8[l] for freq in fTC5null_8[l]) < 5:
#         print(setTC5_8[l], fTC5_8[l], sum(freq >= fTC5_8[l] for freq in fTC5null_8[l]))

# %%
# print("List of Statistically Significant Sequences at α = 0.01")

# #statistical significance testing at p < 0.01 level
# for l in range(len(setTC5_8)):
#     if sum(freq >= fTC5_8[l] for freq in fTC5null_8[l]) < 1:
#         print(setTC5_8[l], fTC5_8[l], sum(freq >= fTC5_8[l] for freq in fTC5null_8[l]))

# %% [markdown]
# # 9 (L) GTCAP - (C) AGI - (β) SM - (E) ALI - (V) TEL

# %%
#extract the overlapping dates

start_9 = max(min(Date_GTCAP), min(Date_AGI), min(Date_SM), min(Date_ALI), min(Date_TEL))
end_9 = min(max(Date_GTCAP), max(Date_AGI), max(Date_SM), max(Date_ALI), max(Date_TEL))

# %%
#shorten the closing prices
GTCAP_9_1 = Date_GTCAP.index(start_9)
GTCAP_9_2 = Date_GTCAP.index(end_9)

AGI_9_1 = Date_AGI.index(start_9)
AGI_9_2 = Date_AGI.index(end_9)

SM_9_1 = Date_SM.index(start_9)
SM_9_2 = Date_SM.index(end_9)

ALI_9_1 = Date_ALI.index(start_9)
ALI_9_2 = Date_ALI.index(end_9)

TEL_9_1 = Date_TEL.index(start_9)
TEL_9_2 = Date_TEL.index(end_9)

# %%
#save the shortened versions of closing prices
L9 = np.save('GTCAPshortPrices.npy', ClosePrice_GTCAP[GTCAP_9_1:GTCAP_9_2])
C9 = np.save('AGIshortPrices.npy', ClosePrice_AGI[AGI_9_1:AGI_9_2])
β9 = np.save('SMshortPrices.npy', ClosePrice_SM[SM_9_1:SM_9_2])
E9 = np.save('ALIshortPrices.npy', ClosePrice_ALI[ALI_9_1:ALI_9_2])
V9 = np.save('TELshortPrices.npy', ClosePrice_TEL[TEL_9_1:TEL_9_2])

# %%
# import modules
import numpy as np
# import prices
L9 = np.load('GTCAPshortPrices.npy', allow_pickle=True).tolist()
C9 = np.load('AGIshortPrices.npy', allow_pickle=True).tolist()
β9 = np.load('SMshortPrices.npy', allow_pickle=True).tolist()
E9 = np.load('ALIshortPrices.npy', allow_pickle=True).tolist()
V9 = np.load('TELshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_9 = []
st_9 = []
n = 1
while n < len(L9):
    sc_9 = ''
    if L9[n] > L9[n-1]:
        sc_9 = sc_9 + 'L'
    if C9[n] > C9[n-1]:
        sc_9 = sc_9 + 'C'
    if β9[n] > β9[n-1]:
        sc_9 = sc_9 + 'β'
    if E9[n] > E9[n-1]:
        sc_9 = sc_9 + 'E'
    if V9[n] > V9[n-1]:
        sc_9 = sc_9 + 'V'
    if len(sc_9) > 0:
        st_9.append(sc_9)
    else:
        STC_9.append(st_9)
        st_9 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_9 = STC_9.count([])
# keep only non-empty spatio-temporal sequences
STC_9 = [ st_9 for st_9 in STC_9 if len(st_9) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_9 = len(L9)
lmax_9 = 0
for st_9 in STC_9:
    if len(st_9) < lmin_9:
        lmin_9 = len(st_9)
    if len(st_9) > lmax_9:
        lmax_9 = len(st_9)
        
# restrict spatio-temporal sequences to length-5
STC5_9 = [ st_9 for st_9 in STC_9 if len(st_9) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_9 = []
for n in range(len(STC5_9)):
    tc_9 = [ u for u in STC5_9[n][0] ]
    for k in range(1, len(STC5_9[n])):
        tc_9 = [ u+v for u in tc_9 for v in STC5_9[n][k] ]
    TC5_9 = TC5_9 + tc_9
setTC5_9 = list(set(TC5_9))

# get empirical frequencies
fTC5_9 = [ TC5_9.count(setTC5_9[l]) for l in range(len(setTC5_9)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_9 = [ [] for l in range(len(setTC5_9)) ]
for s in range(100):
    STC5null_9 = [ list(st_9) for st_9 in STC5_9]
    for st_9 in STC5null_9:
        np.random.shuffle(st_9)
    TC5null_9= []
    for n in range(len(STC5null_9)):
        tc_9 = [ u for u in STC5null_9[n][0] ]
        for k in range(1, len(STC5null_9[n])):
            tc_9 = [ u+v for u in tc_9 for v in STC5null_9[n][k] ]
        TC5null_9= TC5null_9+ tc_9
    for l in range(len(setTC5_9)):
        if TC5null_9.count(setTC5_9[l]) > 0:
            fTC5null_9[l].append(TC5null_9.count(setTC5_9[l]))
        else:
            fTC5null_9[l].append(0)

# %%
print("List of Statistically Significant Sequences at α = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_9)):
    if sum(freq >= fTC5_9[l] for freq in fTC5null_9[l]) < 5:
        print(setTC5_9[l], fTC5_9[l], sum(freq >= fTC5_9[l] for freq in fTC5null_9[l]))
# Out:
# List of Statistically Significant Sequences at α = 0.05
# CEEC
# CECCβ
# βVEEV
# ELLLE
# CEEEβ
# VELE
# βEβE
# βVVCV
# CβVCβ
# VEVE
# ECLEE
# βLVCβ
# LLE
# βCβE
# VβEββ
# LEβE
# βVVEV
# βVVE
# βLββ
# VLβCV
# CLEC
# VLLLV
# EEVCβ
# βCVE
# βEββ
# βELL
# ELLEV
# ELLβV
# βEVβ
# CEVCβ
# CLVCβ
# CVVCβ
# EEEββ
# CVECβ
# EEVEC
# ELLLV
# βLCCβ
# ELLCL
# LVVE
# VLβLV
# CEVCL
# βLVC
# VLβEV
# VVEEV
# VβLCβ
# CLCCβ
# βVβE
# VLCEV
# ECCEV
# βLVLβ
# βVββ
# βVVCβ
# EβLββ
# CEββ
# ECCCL
# βEVCβ
# VECCβ
# βVVβV
# βEβL
# ELLEE
# βEVEβ
# LEVE
# CβECβ
# CLβCβ
# βECCβ
# VβLββ
# CVVCV
# EVLββ
# ELLβE
# βVELV
# EELEC
# βEVE
# ECβCL

# %%
print("List of Statistically Significant Sequences at α = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_9)):
    if sum(freq >= fTC5_9[l] for freq in fTC5null_9[l]) < 1:
        print(setTC5_9[l], fTC5_9[l], sum(freq >= fTC5_9[l] for freq in fTC5null_9[l]))
# Out:
# List of Statistically Significant Sequences at α = 0.01
# VELE
# βEβE
# βVVCV
# βVVE
# ELLEV
# CEVCβ
# CVECβ
# VLβLV
# VLβEV
# VLCEV
# βVββ
# βEVCβ

# %% [markdown]
# # 10 (L) GTCAP - (C) AGI - (β) SM - (E) ALI - (ε) URC

# %%
#extract the overlapping dates

start_10 = max(min(Date_GTCAP), min(Date_AGI), min(Date_SM), min(Date_ALI), min(Date_URC))
end_10 = min(max(Date_GTCAP), max(Date_AGI), max(Date_SM), max(Date_ALI), max(Date_URC))

# %%
#shorten the closing prices
GTCAP_10_1 = Date_GTCAP.index(start_10)
GTCAP_10_2 = Date_GTCAP.index(end_10)

AGI_10_1 = Date_AGI.index(start_10)
AGI_10_2 = Date_AGI.index(end_10)

SM_10_1 = Date_SM.index(start_10)
SM_10_2 = Date_SM.index(end_10)

ALI_10_1 = Date_ALI.index(start_10)
ALI_10_2 = Date_ALI.index(end_10)

URC_10_1 = Date_URC.index(start_10)
URC_10_2 = Date_URC.index(end_10)

# %%
#save the shortened versions of closing prices
L10 = np.save('GTCAPshortPrices.npy', ClosePrice_GTCAP[GTCAP_10_1:GTCAP_10_2])
C10 = np.save('AGIshortPrices.npy', ClosePrice_AGI[AGI_10_1:AGI_10_2])
β10 = np.save('SMshortPrices.npy', ClosePrice_SM[SM_10_1:SM_10_2])
E10 = np.save('ALIshortPrices.npy', ClosePrice_ALI[ALI_10_1:ALI_10_2])
ε10 = np.save('URCshortPrices.npy', ClosePrice_URC[URC_10_1:URC_10_2])

# %%
# import modules
import numpy as np
# import prices
L10 = np.load('GTCAPshortPrices.npy', allow_pickle=True).tolist()
C10 = np.load('AGIshortPrices.npy', allow_pickle=True).tolist()
β10 = np.load('SMshortPrices.npy', allow_pickle=True).tolist()
E10 = np.load('ALIshortPrices.npy', allow_pickle=True).tolist()
ε10 = np.load('URCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_10 = []
st_10 = []
n = 1
while n < len(L10):
    sc_10 = ''
    if L10[n] > L10[n-1]:
        sc_10 = sc_10 + 'L'
    if C10[n] > C10[n-1]:
        sc_10 = sc_10 + 'C'
    if β10[n] > β10[n-1]:
        sc_10 = sc_10 + 'β'
    if E10[n] > E10[n-1]:
        sc_10 = sc_10 + 'E'
    if ε10[n] > ε10[n-1]:
        sc_10 = sc_10 + 'ε'
    if len(sc_10) > 0:
        st_10.append(sc_10)
    else:
        STC_10.append(st_10)
        st_10 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_10 = STC_10.count([])
# keep only non-empty spatio-temporal sequences
STC_10 = [ st_10 for st_10 in STC_10 if len(st_10) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_10 = len(L10)
lmax_10 = 0
for st_10 in STC_10:
    if len(st_10) < lmin_10:
        lmin_10 = len(st_10)
    if len(st_10) > lmax_10:
        lmax_10 = len(st_10)
        
# restrict spatio-temporal sequences to length-5
STC5_10 = [ st_10 for st_10 in STC_10 if len(st_10) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_10 = []
for n in range(len(STC5_10)):
    tc_10 = [ u for u in STC5_10[n][0] ]
    for k in range(1, len(STC5_10[n])):
        tc_10 = [ u+v for u in tc_10 for v in STC5_10[n][k] ]
    TC5_10 = TC5_10 + tc_10
setTC5_10 = list(set(TC5_10))

# get empirical frequencies
fTC5_10 = [ TC5_10.count(setTC5_10[l]) for l in range(len(setTC5_10)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_10 = [ [] for l in range(len(setTC5_10)) ]
for s in range(100):
    STC5null_10 = [ list(st_10) for st_10 in STC5_10]
    for st_10 in STC5null_10:
        np.random.shuffle(st_10)
    TC5null_10= []
    for n in range(len(STC5null_10)):
        tc_10 = [ u for u in STC5null_10[n][0] ]
        for k in range(1, len(STC5null_10[n])):
            tc_10 = [ u+v for u in tc_10 for v in STC5null_10[n][k] ]
        TC5null_10= TC5null_10+ tc_10
    for l in range(len(setTC5_10)):
        if TC5null_10.count(setTC5_10[l]) > 0:
            fTC5null_10[l].append(TC5null_10.count(setTC5_10[l]))
        else:
            fTC5null_10[l].append(0)

# %%
print("List of Statistically Significant Sequences at α = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_10)):
    if sum(freq >= fTC5_10[l] for freq in fTC5null_10[l]) < 5:
        print(setTC5_10[l], fTC5_10[l], sum(freq >= fTC5_10[l] for freq in fTC5null_10[l]))
# Out:
# List of Statistically Significant Sequences at α = 0.05
# CEEC
# CECCβ
# ELLLE
# Lβε
# βEεEβ
# Lεβε
# βEβE
# LLββ
# ECLEE
# LLεE
# LEEC
# ELLεE
# LLβC
# CβLCβ
# βLεC
# LββC
# βεβE
# LEβE
# LεβE
# LLLC
# βLββ
# LEEE
# εLβC
# εEεE
# LεεE
# εεεE
# LEεE
# EεLεL
# εEβE
# ββεC
# LεβC
# LLβε
# LCε
# εεβC
# ECε
# βLεE
# βEεE
# βεLCL
# EεβCL
# LLβE
# CLβC
# LLEC
# CεβC
# εCCεL
# βCε
# βεεE
# LLEε
# EεβεL
# ELLEE
# LEβC
# βεβCL
# εCCCL
# LεβCL
# LεCE
# βεCE
# LLCC
# ELLβE
# βLβC
# CEβC
# LεEC
# βεβεL
# βLβE

# %%
print("List of Statistically Significant Sequences at α = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_10)):
    if sum(freq >= fTC5_10[l] for freq in fTC5null_10[l]) < 1:
        print(setTC5_10[l], fTC5_10[l], sum(freq >= fTC5_10[l] for freq in fTC5null_10[l]))
# Out:
# List of Statistically Significant Sequences at α = 0.01
# βEβE
# LEEC
# LLβC
# LββC
# LLLC
# LεεE
# LεβC
# βEεE
# LLEC
# EεβεL

# %% [markdown]
# # 11 (L) GTCAP - (C) AGI - (β) SM - (E) ALI - (W) PGOLD

# %%
#extract the overlapping dates

start_11 = max(min(Date_GTCAP), min(Date_AGI), min(Date_SM), min(Date_ALI), min(Date_PGOLD))
end_11 = min(max(Date_GTCAP), max(Date_AGI), max(Date_SM), max(Date_ALI), max(Date_PGOLD))

# %%
#shorten the closing prices
GTCAP_11_1 = Date_GTCAP.index(start_11)
GTCAP_11_2 = Date_GTCAP.index(end_11)

AGI_11_1 = Date_AGI.index(start_11)
AGI_11_2 = Date_AGI.index(end_11)

SM_11_1 = Date_SM.index(start_11)
SM_11_2 = Date_SM.index(end_11)

ALI_11_1 = Date_ALI.index(start_11)
ALI_11_2 = Date_ALI.index(end_11)

PGOLD_11_1 = Date_PGOLD.index(start_11)
PGOLD_11_2 = Date_PGOLD.index(end_11)

# %%
#save the shortened versions of closing prices
L11 = np.save('GTCAPshortPrices.npy', ClosePrice_GTCAP[GTCAP_11_1:GTCAP_11_2])
C11 = np.save('AGIshortPrices.npy', ClosePrice_AGI[AGI_11_1:AGI_11_2])
β11 = np.save('SMshortPrices.npy', ClosePrice_SM[SM_11_1:SM_11_2])
E11 = np.save('ALIshortPrices.npy', ClosePrice_ALI[ALI_11_1:ALI_11_2])
W11 = np.save('PGOLDshortPrices.npy', ClosePrice_PGOLD[PGOLD_11_1:PGOLD_11_2])

# %%
# import modules
import numpy as np
# import prices
L11 = np.load('GTCAPshortPrices.npy', allow_pickle=True).tolist()
C11 = np.load('AGIshortPrices.npy', allow_pickle=True).tolist()
β11 = np.load('SMshortPrices.npy', allow_pickle=True).tolist()
E11 = np.load('ALIshortPrices.npy', allow_pickle=True).tolist()
W11 = np.load('PGOLDshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_11 = []
st_11 = []
n = 1
while n < len(L11):
    sc_11 = ''
    if L11[n] > L11[n-1]:
        sc_11 = sc_11 + 'L'
    if C11[n] > C11[n-1]:
        sc_11 = sc_11 + 'C'
    if β11[n] > β11[n-1]:
        sc_11 = sc_11 + 'β'
    if E11[n] > E11[n-1]:
        sc_11 = sc_11 + 'E'
    if W11[n] > W11[n-1]:
        sc_11 = sc_11 + 'W'
    if len(sc_11) > 0:
        st_11.append(sc_11)
    else:
        STC_11.append(st_11)
        st_11 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_11 = STC_11.count([])
# keep only non-empty spatio-temporal sequences
STC_11 = [ st_11 for st_11 in STC_11 if len(st_11) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_11 = len(L11)
lmax_11 = 0
for st_11 in STC_11:
    if len(st_11) < lmin_11:
        lmin_11 = len(st_11)
    if len(st_11) > lmax_11:
        lmax_11 = len(st_11)
        
# restrict spatio-temporal sequences to length-5
STC5_11 = [ st_11 for st_11 in STC_11 if len(st_11) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_11 = []
for n in range(len(STC5_11)):
    tc_11 = [ u for u in STC5_11[n][0] ]
    for k in range(1, len(STC5_11[n])):
        tc_11 = [ u+v for u in tc_11 for v in STC5_11[n][k] ]
    TC5_11 = TC5_11 + tc_11
setTC5_11 = list(set(TC5_11))

# get empirical frequencies
fTC5_11 = [ TC5_11.count(setTC5_11[l]) for l in range(len(setTC5_11)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_11 = [ [] for l in range(len(setTC5_11)) ]
for s in range(100):
    STC5null_11 = [ list(st_11) for st_11 in STC5_11]
    for st_11 in STC5null_11:
        np.random.shuffle(st_11)
    TC5null_11= []
    for n in range(len(STC5null_11)):
        tc_11 = [ u for u in STC5null_11[n][0] ]
        for k in range(1, len(STC5null_11[n])):
            tc_11 = [ u+v for u in tc_11 for v in STC5null_11[n][k] ]
        TC5null_11= TC5null_11+ tc_11
    for l in range(len(setTC5_11)):
        if TC5null_11.count(setTC5_11[l]) > 0:
            fTC5null_11[l].append(TC5null_11.count(setTC5_11[l]))
        else:
            fTC5null_11[l].append(0)

# %%
print("List of Statistically Significant Sequences at α = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_11)):
    if sum(freq >= fTC5_11[l] for freq in fTC5null_11[l]) < 5:
        print(setTC5_11[l], fTC5_11[l], sum(freq >= fTC5_11[l] for freq in fTC5null_11[l]))
# Out:
# List of Statistically Significant Sequences at α = 0.05
# βLEWE
# ELLLE
# CLWLβ
# βEββW
# CEECW
# βCLE
# βCβE
# ELLLL
# CEEββ
# CLβLβ
# LLLβ
# βECCW
# βLββ
# CEβLW
# LLECW
# βLWEE
# βLCββ
# βLLβ
# CLWCW
# LLβCW
# WEEC
# βLLWE
# CWEβW
# LLLE
# CEECβ
# βWLβW
# LEEβW
# CLβCW
# ELCCE
# βLWEC
# EEECW
# βLLβC
# WLLβ
# WEβWW
# βLEβC
# CECCW
# LECCW
# ELWCE
# CβββW
# βLCCβ
# CWβLW
# βEEβW
# CLWCβ
# LEEWW
# βLWLC
# βWCβW
# βLLCC
# βELβW
# CLβLW
# βLLEC
# CLECW
# EEEβW
# βECββ
# βWCββ
# βECβW
# CEEβW
# βCCE
# ELWEE
# CLWEβ
# βLβββ
# WLLβE
# CLCCβ
# LEWW
# ELLCE
# βLWCE
# CLCCW
# βLWCC
# βEβCW
# CLCEβ
# EEβCW
# βEWCC
# βLLβE
# βLWEβ
# βLLLE
# CEβCW
# βLWCβ
# βLWLβ
# ELCEE
# βELβE
# LEECW
# βLWLE
# WEβCW
# βLWβE
# ELLEE
# βECWW
# WECWW
# WLCβE
# CLβCβ
# ELWβL
# βEβWW
# ELLEL
# WCWCE
# βELββ
# WWLβ
# CββCW
# WLLC
# ELWLL
# βLEβE
# ELWCL
# LEβCW
# βLLββ
# βEECW
# CLβEβ
# βLWβC

# %%
print("List of Statistically Significant Sequences at α = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_11)):
    if sum(freq >= fTC5_11[l] for freq in fTC5null_11[l]) < 1:
        print(setTC5_11[l], fTC5_11[l], sum(freq >= fTC5_11[l] for freq in fTC5null_11[l]))
# Out:
# List of Statistically Significant Sequences at α = 0.01
# CLWLβ
# CEECW
# CLβCW
# βELβW
# βECββ
# CEβCW
# βLWCβ
# βELβE
# LEECW
# βELββ
# WWLβ
# LEβCW
# βLWβC

# %% [markdown]
# # 12 (L) GTCAP - (C) AGI - (β) SM - (Z) SECB - (T) MBT

# %%
#extract the overlapping dates

start_12 = max(min(Date_GTCAP), min(Date_AGI), min(Date_SM), min(Date_SECB), min(Date_MBT))
end_12 = min(max(Date_GTCAP), max(Date_AGI), max(Date_SM), max(Date_SECB), max(Date_MBT))

# %%
#shorten the closing prices
GTCAP_12_1 = Date_GTCAP.index(start_12)
GTCAP_12_2 = Date_GTCAP.index(end_12)

AGI_12_1 = Date_AGI.index(start_12)
AGI_12_2 = Date_AGI.index(end_12)

SM_12_1 = Date_SM.index(start_12)
SM_12_2 = Date_SM.index(end_12)

SECB_12_1 = Date_SECB.index(start_12)
SECB_12_2 = Date_SECB.index(end_12)

MBT_12_1 = Date_MBT.index(start_12)
MBT_12_2 = Date_MBT.index(end_12)

# %%
#save the shortened versions of closing prices
L12 = np.save('GTCAPshortPrices.npy', ClosePrice_GTCAP[GTCAP_12_1:GTCAP_12_2])
C12 = np.save('AGIshortPrices.npy', ClosePrice_AGI[AGI_12_1:AGI_12_2])
β12 = np.save('SMshortPrices.npy', ClosePrice_SM[SM_12_1:SM_12_2])
Z12 = np.save('SECBshortPrices.npy', ClosePrice_SECB[SECB_12_1:SECB_12_2])
T12 = np.save('MBTshortPrices.npy', ClosePrice_MBT[MBT_12_1:MBT_12_2])

# %%
# import modules
import numpy as np
# import prices
L12 = np.load('GTCAPshortPrices.npy', allow_pickle=True).tolist()
C12 = np.load('AGIshortPrices.npy', allow_pickle=True).tolist()
β12 = np.load('SMshortPrices.npy', allow_pickle=True).tolist()
Z12 = np.load('SECBshortPrices.npy', allow_pickle=True).tolist()
T12 = np.load('MBTshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_12 = []
st_12 = []
n = 1
while n < len(L12):
    sc_12 = ''
    if L12[n] > L12[n-1]:
        sc_12 = sc_12 + 'L'
    if C12[n] > C12[n-1]:
        sc_12 = sc_12 + 'C'
    if β12[n] > β12[n-1]:
        sc_12 = sc_12 + 'β'
    if Z12[n] > Z12[n-1]:
        sc_12 = sc_12 + 'Z'
    if T12[n] > T12[n-1]:
        sc_12 = sc_12 + 'T'
    if len(sc_12) > 0:
        st_12.append(sc_12)
    else:
        STC_12.append(st_12)
        st_12 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_12 = STC_12.count([])
# keep only non-empty spatio-temporal sequences
STC_12 = [ st_12 for st_12 in STC_12 if len(st_12) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_12 = len(L12)
lmax_12 = 0
for st_12 in STC_12:
    if len(st_12) < lmin_12:
        lmin_12 = len(st_12)
    if len(st_12) > lmax_12:
        lmax_12 = len(st_12)
        
# restrict spatio-temporal sequences to length-5
STC5_12 = [ st_12 for st_12 in STC_12 if len(st_12) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_12 = []
for n in range(len(STC5_12)):
    tc_12 = [ u for u in STC5_12[n][0] ]
    for k in range(1, len(STC5_12[n])):
        tc_12 = [ u+v for u in tc_12 for v in STC5_12[n][k] ]
    TC5_12 = TC5_12 + tc_12
setTC5_12 = list(set(TC5_12))

# get empirical frequencies
fTC5_12 = [ TC5_12.count(setTC5_12[l]) for l in range(len(setTC5_12)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_12 = [ [] for l in range(len(setTC5_12)) ]
for s in range(100):
    STC5null_12 = [ list(st_12) for st_12 in STC5_12]
    for st_12 in STC5null_12:
        np.random.shuffle(st_12)
    TC5null_12= []
    for n in range(len(STC5null_12)):
        tc_12 = [ u for u in STC5null_12[n][0] ]
        for k in range(1, len(STC5null_12[n])):
            tc_12 = [ u+v for u in tc_12 for v in STC5null_12[n][k] ]
        TC5null_12= TC5null_12+ tc_12
    for l in range(len(setTC5_12)):
        if TC5null_12.count(setTC5_12[l]) > 0:
            fTC5null_12[l].append(TC5null_12.count(setTC5_12[l]))
        else:
            fTC5null_12[l].append(0)

# %%
print("List of Statistically Significant Sequences at α = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_12)):
    if sum(freq >= fTC5_12[l] for freq in fTC5null_12[l]) < 5:
        print(setTC5_12[l], fTC5_12[l], sum(freq >= fTC5_12[l] for freq in fTC5null_12[l]))
# Out:
# List of Statistically Significant Sequences at α = 0.05
# βCCZL
# CβCZL
# LLLT
# CββZC
# LLZZ
# ββTZT
# TLZTβ
# LZ
# βCTLL
# CCZZC
# βLTβ
# βLβTβ
# CTZZC
# LβZZL
# CβZZC
# βCTT
# LTZZC
# ββLLT
# TLβTβ
# LZβZ
# βCTZL
# ββTZL
# LZβ
# βCTLT
# CβTLL
# CβTZL
# LLZZL
# LβLZC
# CβZZZ
# TCCT
# βLTC
# ZLZTβ
# CZβZ
# ββTLL
# ββTZβ
# CβLZC
# LTZZ
# TLZZ
# βTTT
# CβZZL

# %%
print("List of Statistically Significant Sequences at α = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_12)):
    if sum(freq >= fTC5_12[l] for freq in fTC5null_12[l]) < 1:
        print(setTC5_12[l], fTC5_12[l], sum(freq >= fTC5_12[l] for freq in fTC5null_12[l]))
# Out:
# List of Statistically Significant Sequences at α = 0.01
# TLZTβ

# %% [markdown]
# # 13 (L) GTCAP - (C) AGI - (β) SM - (Z) SECB - (V) TEL

# %%
#extract the overlapping dates

start_13 = max(min(Date_GTCAP), min(Date_AGI), min(Date_SM), min(Date_SECB), min(Date_TEL))
end_13 = min(max(Date_GTCAP), max(Date_AGI), max(Date_SM), max(Date_SECB), max(Date_TEL))

# %%
#shorten the closing prices
GTCAP_13_1 = Date_GTCAP.index(start_13)
GTCAP_13_2 = Date_GTCAP.index(end_13)

AGI_13_1 = Date_AGI.index(start_13)
AGI_13_2 = Date_AGI.index(end_13)

SM_13_1 = Date_SM.index(start_13)
SM_13_2 = Date_SM.index(end_13)

SECB_13_1 = Date_SECB.index(start_13)
SECB_13_2 = Date_SECB.index(end_13)

TEL_13_1 = Date_TEL.index(start_13)
TEL_13_2 = Date_TEL.index(end_13)

# %%
#save the shortened versions of closing prices
L13 = np.save('GTCAPshortPrices.npy', ClosePrice_GTCAP[GTCAP_13_1:GTCAP_13_2])
C13 = np.save('AGIshortPrices.npy', ClosePrice_AGI[AGI_13_1:AGI_13_2])
β13 = np.save('SMshortPrices.npy', ClosePrice_SM[SM_13_1:SM_13_2])
Z13 = np.save('SECBshortPrices.npy', ClosePrice_SECB[SECB_13_1:SECB_13_2])
V13 = np.save('TELshortPrices.npy', ClosePrice_TEL[TEL_13_1:TEL_13_2])

# %%
# import modules
import numpy as np
# import prices
L13 = np.load('GTCAPshortPrices.npy', allow_pickle=True).tolist()
C13 = np.load('AGIshortPrices.npy', allow_pickle=True).tolist()
β13 = np.load('SMshortPrices.npy', allow_pickle=True).tolist()
Z13 = np.load('SECBshortPrices.npy', allow_pickle=True).tolist()
V13 = np.load('TELshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_13 = []
st_13 = []
n = 1
while n < len(L13):
    sc_13 = ''
    if L13[n] > L13[n-1]:
        sc_13 = sc_13 + 'L'
    if C13[n] > C13[n-1]:
        sc_13 = sc_13 + 'C'
    if β13[n] > β13[n-1]:
        sc_13 = sc_13 + 'β'
    if Z13[n] > Z13[n-1]:
        sc_13 = sc_13 + 'Z'
    if V13[n] > V13[n-1]:
        sc_13 = sc_13 + 'V'
    if len(sc_13) > 0:
        st_13.append(sc_13)
    else:
        STC_13.append(st_13)
        st_13 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_13 = STC_13.count([])
# keep only non-empty spatio-temporal sequences
STC_13 = [ st_13 for st_13 in STC_13 if len(st_13) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_13 = len(L13)
lmax_13 = 0
for st_13 in STC_13:
    if len(st_13) < lmin_13:
        lmin_13 = len(st_13)
    if len(st_13) > lmax_13:
        lmax_13 = len(st_13)
        
# restrict spatio-temporal sequences to length-5
STC5_13 = [ st_13 for st_13 in STC_13 if len(st_13) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_13 = []
for n in range(len(STC5_13)):
    tc_13 = [ u for u in STC5_13[n][0] ]
    for k in range(1, len(STC5_13[n])):
        tc_13 = [ u+v for u in tc_13 for v in STC5_13[n][k] ]
    TC5_13 = TC5_13 + tc_13
setTC5_13 = list(set(TC5_13))

# get empirical frequencies
fTC5_13 = [ TC5_13.count(setTC5_13[l]) for l in range(len(setTC5_13)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_13 = [ [] for l in range(len(setTC5_13)) ]
for s in range(100):
    STC5null_13 = [ list(st_13) for st_13 in STC5_13]
    for st_13 in STC5null_13:
        np.random.shuffle(st_13)
    TC5null_13= []
    for n in range(len(STC5null_13)):
        tc_13 = [ u for u in STC5null_13[n][0] ]
        for k in range(1, len(STC5null_13[n])):
            tc_13 = [ u+v for u in tc_13 for v in STC5null_13[n][k] ]
        TC5null_13= TC5null_13+ tc_13
    for l in range(len(setTC5_13)):
        if TC5null_13.count(setTC5_13[l]) > 0:
            fTC5null_13[l].append(TC5null_13.count(setTC5_13[l]))
        else:
            fTC5null_13[l].append(0)

# %%
print("List of Statistically Significant Sequences at α = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_13)):
    if sum(freq >= fTC5_13[l] for freq in fTC5null_13[l]) < 5:
        print(setTC5_13[l], fTC5_13[l], sum(freq >= fTC5_13[l] for freq in fTC5null_13[l]))
# Out:
# List of Statistically Significant Sequences at α = 0.05
# CVVZV
# ZCVCZ
# VCCL
# ZCβCZ
# βVVCV
# VCC
# LCVβZ
# VCCZ
# VLZβ
# LVVβZ
# VCLZ
# CVLZC
# βVLZC
# LZβC
# CLLβ
# VCZZ
# LZβZ
# βVβVβ
# LVVCZ
# LCVCZ
# βVVβL
# βCββZ
# CVVZβ
# βVVCβ
# βVVZV
# ZCββZ
# VVβLV
# ZVVCZ
# CCββZ
# βCC
# ZVβCZ
# βVVZβ
# βCZZ

# %%
print("List of Statistically Significant Sequences at α = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_13)):
    if sum(freq >= fTC5_13[l] for freq in fTC5null_13[l]) < 1:
        print(setTC5_13[l], fTC5_13[l], sum(freq >= fTC5_13[l] for freq in fTC5null_13[l]))
# Out:
# List of Statistically Significant Sequences at α = 0.01

# %% [markdown]
# # 14 (L) GTCAP - (C) AGI - (β) SM - (Z) SECB - (ε) URC

# %%
#extract the overlapping dates

start_14 = max(min(Date_GTCAP), min(Date_AGI), min(Date_SM), min(Date_SECB), min(Date_URC))
end_14 = min(max(Date_GTCAP), max(Date_AGI), max(Date_SM), max(Date_SECB), max(Date_URC))

# %%
#shorten the closing prices
GTCAP_14_1 = Date_GTCAP.index(start_14)
GTCAP_14_2 = Date_GTCAP.index(end_14)

AGI_14_1 = Date_AGI.index(start_14)
AGI_14_2 = Date_AGI.index(end_14)

SM_14_1 = Date_SM.index(start_14)
SM_14_2 = Date_SM.index(end_14)

SECB_14_1 = Date_SECB.index(start_14)
SECB_14_2 = Date_SECB.index(end_14)

URC_14_1 = Date_URC.index(start_14)
URC_14_2 = Date_URC.index(end_14)

# %%
#save the shortened versions of closing prices
L14 = np.save('GTCAPshortPrices.npy', ClosePrice_GTCAP[GTCAP_14_1:GTCAP_14_2])
C14 = np.save('AGIshortPrices.npy', ClosePrice_AGI[AGI_14_1:AGI_14_2])
β14 = np.save('SMshortPrices.npy', ClosePrice_SM[SM_14_1:SM_14_2])
Z14 = np.save('SECBshortPrices.npy', ClosePrice_SECB[SECB_14_1:SECB_14_2])
ε14 = np.save('URCshortPrices.npy', ClosePrice_URC[URC_14_1:URC_14_2])

# %%
# import modules
import numpy as np
# import prices
L14 = np.load('GTCAPshortPrices.npy', allow_pickle=True).tolist()
C14 = np.load('AGIshortPrices.npy', allow_pickle=True).tolist()
β14 = np.load('SMshortPrices.npy', allow_pickle=True).tolist()
Z14 = np.load('SECBshortPrices.npy', allow_pickle=True).tolist()
ε14 = np.load('URCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_14 = []
st_14 = []
n = 1
while n < len(L14):
    sc_14 = ''
    if L14[n] > L14[n-1]:
        sc_14 = sc_14 + 'L'
    if C14[n] > C14[n-1]:
        sc_14 = sc_14 + 'C'
    if β14[n] > β14[n-1]:
        sc_14 = sc_14 + 'β'
    if Z14[n] > Z14[n-1]:
        sc_14 = sc_14 + 'Z'
    if ε14[n] > ε14[n-1]:
        sc_14 = sc_14 + 'ε'
    if len(sc_14) > 0:
        st_14.append(sc_14)
    else:
        STC_14.append(st_14)
        st_14 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_14 = STC_14.count([])
# keep only non-empty spatio-temporal sequences
STC_14 = [ st_14 for st_14 in STC_14 if len(st_14) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_14 = len(L14)
lmax_14 = 0
for st_14 in STC_14:
    if len(st_14) < lmin_14:
        lmin_14 = len(st_14)
    if len(st_14) > lmax_14:
        lmax_14 = len(st_14)
        
# restrict spatio-temporal sequences to length-5
STC5_14 = [ st_14 for st_14 in STC_14 if len(st_14) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_14 = []
for n in range(len(STC5_14)):
    tc_14 = [ u for u in STC5_14[n][0] ]
    for k in range(1, len(STC5_14[n])):
        tc_14 = [ u+v for u in tc_14 for v in STC5_14[n][k] ]
    TC5_14 = TC5_14 + tc_14
setTC5_14 = list(set(TC5_14))

# get empirical frequencies
fTC5_14 = [ TC5_14.count(setTC5_14[l]) for l in range(len(setTC5_14)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_14 = [ [] for l in range(len(setTC5_14)) ]
for s in range(100):
    STC5null_14 = [ list(st_14) for st_14 in STC5_14]
    for st_14 in STC5null_14:
        np.random.shuffle(st_14)
    TC5null_14= []
    for n in range(len(STC5null_14)):
        tc_14 = [ u for u in STC5null_14[n][0] ]
        for k in range(1, len(STC5null_14[n])):
            tc_14 = [ u+v for u in tc_14 for v in STC5null_14[n][k] ]
        TC5null_14= TC5null_14+ tc_14
    for l in range(len(setTC5_14)):
        if TC5null_14.count(setTC5_14[l]) > 0:
            fTC5null_14[l].append(TC5null_14.count(setTC5_14[l]))
        else:
            fTC5null_14[l].append(0)

# %%
print("List of Statistically Significant Sequences at α = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_14)):
    if sum(freq >= fTC5_14[l] for freq in fTC5null_14[l]) < 5:
        print(setTC5_14[l])
# Out:
# List of Statistically Significant Sequences at α = 0.05
# βLβZβ
# CβLZε
# CββCZ
# LβεC
# Lεβε
# ZLZCβ
# LεZZ
# CβCCZ
# CβLCβ
# LββC
# βεβCZ
# βLZLβ
# Cββεβ
# εεLZ
# ZLZεε
# ZLZZε
# LZβCβ
# CβZCZ
# CεCCZ
# LZβC
# LεβC
# βLεZβ
# LεβZ
# εεβCZ
# CβLZβ
# CεβCZ
# LZβZ
# CββC
# βZβεβ
# εεβC
# LεCZ
# CβCLZ
# εεZZ
# LLZC
# ZLZLβ
# εεβZ
# LεZC
# ZεLCZ
# εZCZC
# ZLβZβ
# βLεLβ
# εLLC
# LZLCβ
# CβZLZ
# ZεβCZ
# βLβεβ
# ZLZZβ
# ZCε
# ZεZCZ
# βLεZε
# ZLβLβ
# CβLLZ
# ZLZεL
# LεβCZ

# %%
print("List of Statistically Significant Sequences at α = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_14)):
    if sum(freq >= fTC5_14[l] for freq in fTC5null_14[l]) < 1:
        print(setTC5_14[l])
# Out:
# List of Statistically Significant Sequences at α = 0.01
# CβCCZ
# CβLCβ
# LββC
# βLεZβ
# CεβCZ
# εεβZ
# ZεLCZ
# LεβCZ

# %% [markdown]
# # 15 (L) GTCAP - (C) AGI - (β) SM - (Z) SECB - (W) PGOLD

# %%
#extract the overlapping dates

start_15 = max(min(Date_GTCAP), min(Date_AGI), min(Date_SM), min(Date_SECB), min(Date_PGOLD))
end_15 = min(max(Date_GTCAP), max(Date_AGI), max(Date_SM), max(Date_SECB), max(Date_PGOLD))

# %%
#shorten the closing prices
GTCAP_15_1 = Date_GTCAP.index(start_15)
GTCAP_15_2 = Date_GTCAP.index(end_15)

AGI_15_1 = Date_AGI.index(start_15)
AGI_15_2 = Date_AGI.index(end_15)

SM_15_1 = Date_SM.index(start_15)
SM_15_2 = Date_SM.index(end_15)

SECB_15_1 = Date_SECB.index(start_15)
SECB_15_2 = Date_SECB.index(end_15)

PGOLD_15_1 = Date_PGOLD.index(start_15)
PGOLD_15_2 = Date_PGOLD.index(end_15)

# %%
#save the shortened versions of closing prices
L15 = np.save('GTCAPshortPrices.npy', ClosePrice_GTCAP[GTCAP_15_1:GTCAP_15_2])
C15 = np.save('AGIshortPrices.npy', ClosePrice_AGI[AGI_15_1:AGI_15_2])
β15 = np.save('SMshortPrices.npy', ClosePrice_SM[SM_15_1:SM_15_2])
Z15 = np.save('SECBshortPrices.npy', ClosePrice_SECB[SECB_15_1:SECB_15_2])
W15 = np.save('PGOLDshortPrices.npy', ClosePrice_PGOLD[PGOLD_15_1:PGOLD_15_2])

# %%
# import modules
import numpy as np
# import prices
L15 = np.load('GTCAPshortPrices.npy', allow_pickle=True).tolist()
C15 = np.load('AGIshortPrices.npy', allow_pickle=True).tolist()
β15 = np.load('SMshortPrices.npy', allow_pickle=True).tolist()
Z15 = np.load('SECBshortPrices.npy', allow_pickle=True).tolist()
W15 = np.load('PGOLDshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_15 = []
st_15 = []
n = 1
while n < len(L15):
    sc_15 = ''
    if L15[n] > L15[n-1]:
        sc_15 = sc_15 + 'L'
    if C15[n] > C15[n-1]:
        sc_15 = sc_15 + 'C'
    if β15[n] > β15[n-1]:
        sc_15 = sc_15 + 'β'
    if Z15[n] > Z15[n-1]:
        sc_15 = sc_15 + 'Z'
    if W15[n] > W15[n-1]:
        sc_15 = sc_15 + 'W'
    if len(sc_15) > 0:
        st_15.append(sc_15)
    else:
        STC_15.append(st_15)
        st_15 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_15 = STC_15.count([])
# keep only non-empty spatio-temporal sequences
STC_15 = [ st_15 for st_15 in STC_15 if len(st_15) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_15 = len(L15)
lmax_15 = 0
for st_15 in STC_15:
    if len(st_15) < lmin_15:
        lmin_15 = len(st_15)
    if len(st_15) > lmax_15:
        lmax_15 = len(st_15)
        
# restrict spatio-temporal sequences to length-5
STC5_15 = [ st_15 for st_15 in STC_15 if len(st_15) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_15 = []
for n in range(len(STC5_15)):
    tc_15 = [ u for u in STC5_15[n][0] ]
    for k in range(1, len(STC5_15[n])):
        tc_15 = [ u+v for u in tc_15 for v in STC5_15[n][k] ]
    TC5_15 = TC5_15 + tc_15
setTC5_15 = list(set(TC5_15))

# get empirical frequencies
fTC5_15 = [ TC5_15.count(setTC5_15[l]) for l in range(len(setTC5_15)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_15 = [ [] for l in range(len(setTC5_15)) ]
for s in range(100):
    STC5null_15 = [ list(st_15) for st_15 in STC5_15]
    for st_15 in STC5null_15:
        np.random.shuffle(st_15)
    TC5null_15= []
    for n in range(len(STC5null_15)):
        tc_15 = [ u for u in STC5null_15[n][0] ]
        for k in range(1, len(STC5null_15[n])):
            tc_15 = [ u+v for u in tc_15 for v in STC5null_15[n][k] ]
        TC5null_15= TC5null_15+ tc_15
    for l in range(len(setTC5_15)):
        if TC5null_15.count(setTC5_15[l]) > 0:
            fTC5null_15[l].append(TC5null_15.count(setTC5_15[l]))
        else:
            fTC5null_15[l].append(0)

# %%
print("List of Statistically Significant Sequences at α = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_15)):
    if sum(freq >= fTC5_15[l] for freq in fTC5null_15[l]) < 5:
        print(setTC5_15[l], fTC5_15[l], sum(freq >= fTC5_15[l] for freq in fTC5null_15[l]))
# Out:
# List of Statistically Significant Sequences at α = 0.05
# βLβZβ
# LZWW
# CββCZ
# LLCCW
# ZWCCZ
# βLβWL
# CLWLβ
# ZWβCZ
# ββWWZ
# CWZC
# CWβCZ
# CLZCW
# CLLZL
# CLWZL
# CLβCZ
# βLWCW
# CLCWZ
# βLWZW
# βLβWC
# CLWCW
# CLCCZ
# CLWCC
# βLWZL
# WLβZW
# βLLLL
# ZβCCZ
# ZLβCW
# βLZWZ
# βLWCL
# ZβWCL
# CLWZZ
# CLWZW
# CLβCW
# LZβCW
# WLLβ
# βCWW
# LWβCZ
# WLβCW
# βLWZβ
# CLWCβ
# ZWWCL
# CβCCW
# CLβWZ
# CLβWβ
# βWLβ
# CWZCZ
# CWCCZ
# CLZCZ
# βLWβL
# CLWWZ
# CLWCZ
# βLWWZ
# CLCCW
# βLWCC
# βLWLL
# βLWWL
# βLβWZ
# ZβZCL
# CLWZC
# βLWCβ
# LWCCZ
# βLWLβ
# βWβWW
# ZLβ
# ZβZCZ
# CLCCL
# βLβWβ
# WWLW
# CLWβC
# CLWZβ
# CLWCL
# ZLβZW
# CWCCW
# ZLCCW
# ZWβCW
# WWLβ
# CLWWL
# ZWZCZ
# βLWZZ
# ZLWCβ
# ZWZCL
# βLWβC

# %%
print("List of Statistically Significant Sequences at α = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_15)):
    if sum(freq >= fTC5_15[l] for freq in fTC5null_15[l]) < 1:
        print(setTC5_15[l], fTC5_15[l], sum(freq >= fTC5_15[l] for freq in fTC5null_15[l]))
# Out:
# List of Statistically Significant Sequences at α = 0.01
# CWZC
# CLWZL
# CLβCZ
# CLWCW
# CLCCZ
# βLWZL
# ZLβCW
# CLWZW
# βLWZβ
# CWCCZ
# CLCCW
# CLWZβ
# ZWβCW
