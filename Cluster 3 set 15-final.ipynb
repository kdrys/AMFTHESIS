# %% [markdown]
# # One-Letter Words

# %%
# open the csv files
AP = open('AP.csv')
AC = open('AC.csv')
BPI = open('BPI.csv')
BLOOM = open('BLOOM.csv')
FGEN = open('FGEN.csv')
ICT = open('ICT.csv')
JGS = open('JGS.csv')
MEG = open('MEG.csv')
SMC = open('SMC.csv')
SCC = open('SCC.csv')

#initiFGENze the lists
Date_AP = []
ClosePrice_AP = []
Date_AC = []
ClosePrice_AC = []
Date_BPI = []
ClosePrice_BPI = []
Date_BLOOM = []
ClosePrice_BLOOM = []
Date_FGEN = []
ClosePrice_FGEN = []
Date_ICT = []
ClosePrice_ICT = []
Date_JGS = []
ClosePrice_JGS = []
Date_MEG = []
ClosePrice_MEG = []
Date_SMC = []
ClosePrice_SMC = []
Date_SCC = []
ClosePrice_SCC = []

#skip the header line
AP.readline()
AC.readline()
BPI.readline()
BLOOM.readline()
FGEN.readline()
ICT.readline()
JGS.readline()
MEG.readline()
SMC.readline()
SCC.readline()

#go through the files line by line
for line in AP:
    sline = line.strip().split(',')
    Date_AP.append(sline[0])
    ClosePrice_AP.append(float(sline[1]))
    
for line in AC:
    sline = line.strip().split(',')
    Date_AC.append(sline[0])
    ClosePrice_AC.append(float(sline[1]))
    
for line in BPI:
    sline = line.strip().split(',')
    Date_BPI.append(sline[0])
    ClosePrice_BPI.append(float(sline[1]))
    
for line in BLOOM:
    sline = line.strip().split(',')
    Date_BLOOM.append(sline[0])
    ClosePrice_BLOOM.append(float(sline[1]))
    
for line in FGEN:
    sline = line.strip().split(',')
    Date_FGEN.append(sline[0])
    ClosePrice_FGEN.append(float(sline[1]))
    
for line in ICT:
    sline = line.strip().split(',')
    Date_ICT.append(sline[0])
    ClosePrice_ICT.append(float(sline[1]))
    
for line in JGS:
    sline = line.strip().split(',')
    Date_JGS.append(sline[0])
    ClosePrice_JGS.append(float(sline[1]))
    
for line in MEG:
    sline = line.strip().split(',')
    Date_MEG.append(sline[0])
    ClosePrice_MEG.append(float(sline[1]))
    
for line in SMC:
    sline = line.strip().split(',')
    Date_SMC.append(sline[0])
    ClosePrice_SMC.append(float(sline[1]))
        
for line in SCC:
    sline = line.strip().split(',')
    Date_SCC.append(sline[0])
    ClosePrice_SCC.append(float(sline[1]))


#close files
AP.close()
AC.close()
BPI.close()
BLOOM.close()
FGEN.close()
ICT.close()
JGS.close()
MEG.close()
SMC.close()
SCC.close()# One-Letter Words

# %%
import numpy as np
import datetime

# %%
# convert dates into datetime structure
for n in range(len(Date_AP)):
    Date_AP[n] = datetime.datetime.strptime(Date_AP[n], '%m/%d/%y').date()

for n in range(len(Date_AC)):
    Date_AC[n] = datetime.datetime.strptime(Date_AC[n], '%m/%d/%y').date()
    
for n in range(len(Date_BPI)):
    Date_BPI[n] = datetime.datetime.strptime(Date_BPI[n], '%m/%d/%y').date()

for n in range(len(Date_BLOOM)):
    Date_BLOOM[n] = datetime.datetime.strptime(Date_BLOOM[n], '%m/%d/%y').date()
    
for n in range(len(Date_FGEN)):
    Date_FGEN[n] = datetime.datetime.strptime(Date_FGEN[n], '%m/%d/%y').date()

for n in range(len(Date_ICT)):
    Date_ICT[n] = datetime.datetime.strptime(Date_ICT[n], '%m/%d/%y').date()
    
for n in range(len(Date_JGS)):
    Date_JGS[n] = datetime.datetime.strptime(Date_JGS[n], '%m/%d/%y').date()

for n in range(len(Date_MEG)):
    Date_MEG[n] = datetime.datetime.strptime(Date_MEG[n], '%m/%d/%y').date()
    
for n in range(len(Date_SMC)):
    Date_SMC[n] = datetime.datetime.strptime(Date_SMC[n], '%m/%d/%y').date()

for n in range(len(Date_SCC)):
    Date_SCC[n] = datetime.datetime.strptime(Date_SCC[n], '%m/%d/%y').date()
    
# save Date and ClosePrice
np.save('APDate.npy', Date_AP)
np.save('APClosePrice.npy', ClosePrice_AP)
np.save('ACDate.npy', Date_AC)
np.save('ACClosePrice.npy', ClosePrice_AC)
np.save('BPIDate.npy', Date_BPI)
np.save('BPIClosePrice.npy', ClosePrice_BPI)
np.save('BLOOMDate.npy', Date_BLOOM)
np.save('BLOOMClosePrice.npy', ClosePrice_BLOOM)
np.save('FGENDate.npy', Date_FGEN)
np.save('FGENClosePrice.npy', ClosePrice_FGEN)
np.save('ICTDate.npy', Date_ICT)
np.save('ICTClosePrice.npy', ClosePrice_ICT)
np.save('JGSDate.npy', Date_JGS)
np.save('JGSClosePrice.npy', ClosePrice_JGS)
np.save('MEGDate.npy', Date_MEG)
np.save('MEGClosePrice.npy', ClosePrice_MEG)
np.save('SMCDate.npy', Date_SMC)
np.save('SMCClosePrice.npy', ClosePrice_SMC)
np.save('SCCDate.npy', Date_SCC)
np.save('SCCClosePrice.npy', ClosePrice_SCC)

# %% [markdown]
# # Five-letter Words

# %% [markdown]
#  # 3.211 (F) BPI - (H) BLOOM- (M) ICT - (R) MEG - (α) SCC

# %%
#extract overlapping dates
start_211 = max(min(Date_BPI), min(Date_BLOOM), min(Date_ICT), min(Date_MEG), min(Date_SCC))
end_211 = min(max(Date_BPI), max(Date_BLOOM), max(Date_ICT), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
BPI_211_1 = Date_BPI.index(start_211)
BPI_211_2 = Date_BPI.index(end_211)

BLOOM_211_1 = Date_BLOOM.index(start_211)
BLOOM_211_2 = Date_BLOOM.index(end_211)

ICT_211_1 = Date_ICT.index(start_211)
ICT_211_2 = Date_ICT.index(end_211)

MEG_211_1 = Date_MEG.index(start_211)
MEG_211_2 = Date_MEG.index(end_211)

SCC_211_1 = Date_SCC.index(start_211)
SCC_211_2 = Date_SCC.index(end_211)

# %%
#save the shortened versions of closing prices
F211 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_211_1:BPI_211_2])
H211 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_211_1:BLOOM_211_2])
M211 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_211_1:ICT_211_2])
R211 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_211_1:MEG_211_2])
α211 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_211_1:SCC_211_2])

# %%
# import modules
import numpy as np
# import prices

F211 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H211 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M211 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R211 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α211 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_211 = []
st_211 = []
n = 1
while n < len(F211):
    sc_211 = ''
    if F211[n] > F211[n-1]:
        sc_211 = sc_211 + 'F'
    if H211[n] > H211[n-1]:
        sc_211 = sc_211 + 'H'
    if M211[n] > M211[n-1]:
        sc_211 = sc_211 + 'M'
    if R211[n] > R211[n-1]:
        sc_211 = sc_211 + 'R'
    if α211[n] > α211[n-1]:
        sc_211 = sc_211 + 'α'
    if len(sc_211) > 0:
        st_211.append(sc_211)
    else:
        STC_211.append(st_211)
        st_211 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_211 = STC_211.count([])
# keep only non-empty spatio-temporal sequences
STC_211 = [ st_211 for st_211 in STC_211 if len(st_211) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_211 = len(F211)
lmax_211 = 0
for st_211 in STC_211:
    if len(st_211) < lmin_211:
        lmin_211 = len(st_211)
    if len(st_211) > lmax_211:
        lmax_211 = len(st_211)
        
# restrict spatio-temporal sequences to length-5
STC5_211 = [ st_211 for st_211 in STC_211 if len(st_211) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_211 = []
for n in range(len(STC5_211)):
    tc_211 = [ u for u in STC5_211[n][0] ]
    for k in range(1, len(STC5_211[n])):
        tc_211 = [ u+v for u in tc_211 for v in STC5_211[n][k] ]
    TC5_211 = TC5_211 + tc_211
setTC5_211 = list(set(TC5_211))

# get empirical frequencies
fTC5_211 = [ TC5_211.count(setTC5_211[l]) for l in range(len(setTC5_211)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_211 = [ [] for l in range(len(setTC5_211)) ]
for s in range(100):
    STC5null_211 = [ list(st_211) for st_211 in STC5_211]
    for st_211 in STC5null_211:
        np.random.shuffle(st_211)
    TC5null_211= []
    for n in range(len(STC5null_211)):
        tc_211 = [ u for u in STC5null_211[n][0] ]
        for k in range(1, len(STC5null_211[n])):
            tc_211 = [ u+v for u in tc_211 for v in STC5null_211[n][k] ]
        TC5null_211= TC5null_211+ tc_211
    for l in range(len(setTC5_211)):
        if TC5null_211.count(setTC5_211[l]) > 0:
            fTC5null_211[l].append(TC5null_211.count(setTC5_211[l]))
        else:
            fTC5null_211[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_211)):
     if sum(freq >= fTC5_211[l] for freq in fTC5null_211[l]) < 5:
#         print(setTC5_211[l], fTC5_211[l], sum(freq >= fTC5_211[l] for freq in fTC5null_211[l]))
        print(setTC5_211[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# HHMMF
# RMHαM
# FMHαα
# HHMRF
# HRαRH
# RRFH
# MRFH
# αRFαM
# MRαRH
# HRααH
# RRHαM
# HαHH
# MRαRR
# αMRH
# FMHH
# MFRFR
# αRFRM
# HαFRR
# αRRRR
# MαFRH
# MRFRH
# MRHHH
# αRMαH
# HRαMR
# HRHαH
# MRMRH
# FFFH
# RMHαα
# HRMMF
# αRHαH
# FRMMF
# αMFR
# RM
# αRααα
# FRF
# FRFRH
# FRαFR
# MRRHH
# HFFRF
# MRMHH
# MRRRR
# MMFR
# FRαMR
# FM
# FRMMM
# RRMαH
# FMFH
# HHFRF
# HRHHH
# MMRH
# HαMαα
# HRFRH
# αRααR
# HHMαα
# HRMMα
# RRM
# RRααH
# RαFMF
# MMRR
# FRααR
# αFMαα
# MRMMM
# RMFH
# HRMαR
# FRαRH
# αRαRR
# HαFH
# FRαRR
# MRFFR
# HRMαH
# αRFRH
# HαFR
# HMHH
# RRF
# MRRFR
# αRααH
# FRRRR
# RHα
# MMMH
# MααFR
# HRMαα
# αRRFR
# MαMFM
# FHM
# RRMMF
# FRααH
# RMMαα
# αMRR
# HHMαF
# αMααM
# MRααR
# MMFH

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_211)):
     if sum(freq >= fTC5_211[l] for freq in fTC5null_211[l]) < 1:
#         print(setTC5_211[l], fTC5_211[l], sum(freq >= fTC5_211[l] for freq in fTC5null_211[l]))
        print(setTC5_211[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# RRFH
# MRHHH
# HRMMF
# MRRRR
# HHFRF
# MMRH
# MRMMM
# FRRRR
# HHMαF
# MMFH

# %% [markdown]
#  # 3.212 (F) BPI - (H) BLOOM- (M) ICT - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_212 = max(min(Date_BPI), min(Date_BLOOM), min(Date_ICT), min(Date_SMC), min(Date_SCC))
end_212 = min(max(Date_BPI), max(Date_BLOOM), max(Date_ICT), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
BPI_212_1 = Date_BPI.index(start_212)
BPI_212_2 = Date_BPI.index(end_212)

BLOOM_212_1 = Date_BLOOM.index(start_212)
BLOOM_212_2 = Date_BLOOM.index(end_212)

ICT_212_1 = Date_ICT.index(start_212)
ICT_212_2 = Date_ICT.index(end_212)

SMC_212_1 = Date_SMC.index(start_212)
SMC_212_2 = Date_SMC.index(end_212)

SCC_212_1 = Date_SCC.index(start_212)
SCC_212_2 = Date_SCC.index(end_212)

# %%
#save the shortened versions of closing prices
F212 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_212_1:BPI_212_2])
H212 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_212_1:BLOOM_212_2])
M212 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_212_1:ICT_212_2])
Y212 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_212_1:SMC_212_2])
α212 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_212_1:SCC_212_2])

# %%
# import modules
import numpy as np
# import prices

F212 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H212 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M212 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
Y212 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α212 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_212 = []
st_212 = []
n = 1
while n < len(F212):
    sc_212 = ''
    if F212[n] > F212[n-1]:
        sc_212 = sc_212 + 'F'
    if H212[n] > H212[n-1]:
        sc_212 = sc_212 + 'H'
    if M212[n] > M212[n-1]:
        sc_212 = sc_212 + 'M'
    if Y212[n] > Y212[n-1]:
        sc_212 = sc_212 + 'Y'
    if α212[n] > α212[n-1]:
        sc_212 = sc_212 + 'α'
    if len(sc_212) > 0:
        st_212.append(sc_212)
    else:
        STC_212.append(st_212)
        st_212 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_212 = STC_212.count([])
# keep only non-empty spatio-temporal sequences
STC_212 = [ st_212 for st_212 in STC_212 if len(st_212) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_212 = len(F212)
lmax_212 = 0
for st_212 in STC_212:
    if len(st_212) < lmin_212:
        lmin_212 = len(st_212)
    if len(st_212) > lmax_212:
        lmax_212 = len(st_212)
        
# restrict spatio-temporal sequences to length-5
STC5_212 = [ st_212 for st_212 in STC_212 if len(st_212) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_212 = []
for n in range(len(STC5_212)):
    tc_212 = [ u for u in STC5_212[n][0] ]
    for k in range(1, len(STC5_212[n])):
        tc_212 = [ u+v for u in tc_212 for v in STC5_212[n][k] ]
    TC5_212 = TC5_212 + tc_212
setTC5_212 = list(set(TC5_212))

# get empirical frequencies
fTC5_212 = [ TC5_212.count(setTC5_212[l]) for l in range(len(setTC5_212)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_212 = [ [] for l in range(len(setTC5_212)) ]
for s in range(100):
    STC5null_212 = [ list(st_212) for st_212 in STC5_212]
    for st_212 in STC5null_212:
        np.random.shuffle(st_212)
    TC5null_212= []
    for n in range(len(STC5null_212)):
        tc_212 = [ u for u in STC5null_212[n][0] ]
        for k in range(1, len(STC5null_212[n])):
            tc_212 = [ u+v for u in tc_212 for v in STC5null_212[n][k] ]
        TC5null_212= TC5null_212+ tc_212
    for l in range(len(setTC5_212)):
        if TC5null_212.count(setTC5_212[l]) > 0:
            fTC5null_212[l].append(TC5null_212.count(setTC5_212[l]))
        else:
            fTC5null_212[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_212)):
     if sum(freq >= fTC5_212[l] for freq in fTC5null_212[l]) < 5:
#         print(setTC5_212[l], fTC5_212[l], sum(freq >= fTC5_212[l] for freq in fTC5null_212[l]))
        print(setTC5_212[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FYYY
# MαHFα
# HαMYM
# HYFαM
# FYααH
# HαYαM
# FMHαα
# HYFHH
# YYααα
# HYMHH
# FαYFα
# MαMYM
# αααFM
# HαMαM
# FYααM
# YYαHH
# HαMYα
# YYHαM
# HαMFM
# FααHY
# FMYYY
# HMMαM
# FαHFα
# FαM
# MH
# HαFY
# YYααH
# FYYM
# HαHαα
# MMαY
# HYMαM
# FHαF
# MYα
# HFFFM
# HαMHH
# YYMMM
# HαFHH
# ααYYY
# HαMαα
# YYYMM
# FYαHH
# HαHFα
# MYMHF
# αYYMM
# FH
# HFFMF
# HYαHH
# MαMFM
# HYYαM
# αYααM
# HααHH
# MYYMM
# HαFFM
# YYαHM
# HαHFM

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_212)):
     if sum(freq >= fTC5_212[l] for freq in fTC5null_212[l]) < 1:
#         print(setTC5_212[l], fTC5_212[l], sum(freq >= fTC5_212[l] for freq in fTC5null_212[l]))
        print(setTC5_212[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# HYFαM
# FYααM
# HαMFM
# FαM
# HαMHH
# HαFHH
# HααHH

# %% [markdown]
#  # 3.213 (F) BPI - (H) BLOOM- (N) JGS - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_213 = max(min(Date_BPI), min(Date_BLOOM), min(Date_JGS), min(Date_MEG), min(Date_SMC))
end_213 = min(max(Date_BPI), max(Date_BLOOM), max(Date_JGS), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
BPI_213_1 = Date_BPI.index(start_213)
BPI_213_2 = Date_BPI.index(end_213)

BLOOM_213_1 = Date_BLOOM.index(start_213)
BLOOM_213_2 = Date_BLOOM.index(end_213)

JGS_213_1 = Date_JGS.index(start_213)
JGS_213_2 = Date_JGS.index(end_213)

MEG_213_1 = Date_MEG.index(start_213)
MEG_213_2 = Date_MEG.index(end_213)

SMC_213_1 = Date_SMC.index(start_213)
SMC_213_2 = Date_SMC.index(end_213)

# %%
#save the shortened versions of closing prices
F213 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_213_1:BPI_213_2])
H213 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_213_1:BLOOM_213_2])
N213 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_213_1:JGS_213_2])
R213 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_213_1:MEG_213_2])
Y213 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_213_1:SMC_213_2])

# %%
# import modules
import numpy as np
# import prices

F213 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H213 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
N213 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R213 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y213 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_213 = []
st_213 = []
n = 1
while n < len(F213):
    sc_213 = ''
    if F213[n] > F213[n-1]:
        sc_213 = sc_213 + 'F'
    if H213[n] > H213[n-1]:
        sc_213 = sc_213 + 'H'
    if N213[n] > N213[n-1]:
        sc_213 = sc_213 + 'N'
    if R213[n] > R213[n-1]:
        sc_213 = sc_213 + 'R'
    if Y213[n] > Y213[n-1]:
        sc_213 = sc_213 + 'Y'
    if len(sc_213) > 0:
        st_213.append(sc_213)
    else:
        STC_213.append(st_213)
        st_213 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_213 = STC_213.count([])
# keep only non-empty spatio-temporal sequences
STC_213 = [ st_213 for st_213 in STC_213 if len(st_213) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_213 = len(F213)
lmax_213 = 0
for st_213 in STC_213:
    if len(st_213) < lmin_213:
        lmin_213 = len(st_213)
    if len(st_213) > lmax_213:
        lmax_213 = len(st_213)
        
# restrict spatio-temporal sequences to length-5
STC5_213 = [ st_213 for st_213 in STC_213 if len(st_213) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_213 = []
for n in range(len(STC5_213)):
    tc_213 = [ u for u in STC5_213[n][0] ]
    for k in range(1, len(STC5_213[n])):
        tc_213 = [ u+v for u in tc_213 for v in STC5_213[n][k] ]
    TC5_213 = TC5_213 + tc_213
setTC5_213 = list(set(TC5_213))

# get empirical frequencies
fTC5_213 = [ TC5_213.count(setTC5_213[l]) for l in range(len(setTC5_213)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_213 = [ [] for l in range(len(setTC5_213)) ]
for s in range(100):
    STC5null_213 = [ list(st_213) for st_213 in STC5_213]
    for st_213 in STC5null_213:
        np.random.shuffle(st_213)
    TC5null_213= []
    for n in range(len(STC5null_213)):
        tc_213 = [ u for u in STC5null_213[n][0] ]
        for k in range(1, len(STC5null_213[n])):
            tc_213 = [ u+v for u in tc_213 for v in STC5null_213[n][k] ]
        TC5null_213= TC5null_213+ tc_213
    for l in range(len(setTC5_213)):
        if TC5null_213.count(setTC5_213[l]) > 0:
            fTC5null_213[l].append(TC5null_213.count(setTC5_213[l]))
        else:
            fTC5null_213[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_213)):
     if sum(freq >= fTC5_213[l] for freq in fTC5null_213[l]) < 5:
#         print(setTC5_213[l], fTC5_213[l], sum(freq >= fTC5_213[l] for freq in fTC5null_213[l]))
        print(setTC5_213[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FYYY
# RRYYN
# NRFFF
# YYFYN
# YRNYN
# FRFYY
# NRHRH
# HHYNF
# YHYNN
# HRF
# FRFYN
# NRFYF
# FYFYN
# YRNYH
# RHF
# NFY
# YYFFY
# RYRRH
# NRFYR
# YRYFN
# NRFNR
# NNFFR
# YNYYN
# FRNY
# NFFNR
# YFFR
# FRNYY
# YFYYH
# RYYY
# FYRRH
# FRFFY
# HNF
# NRFYN
# NFFRR
# FRNYN
# YRFYR
# FNFF
# YHNR
# YHFYN
# YRFYN
# RRFFY
# HRNFF
# HRN
# NRFFR
# HRRH
# YRFR
# YRFNN
# NFFFR
# YRFYY
# HRHH
# FRYY
# FRHYF
# NNFRR
# YRFFF
# NFRRH
# YRYFF
# HHRY
# YRRRN
# FRFYR
# YRRH
# YRNNN
# YRFFR
# YRFFN
# YRFFY
# FRFNR
# HRFYR
# HRFH
# YRFRN
# NFFRH
# HHN
# RRF
# NHFNR
# NRFRR
# YHFNN
# HHYNN
# NNRRH
# YRY
# FRNF
# YHNNN
# NNFRH
# YRHRN

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_213)):
     if sum(freq >= fTC5_213[l] for freq in fTC5null_213[l]) < 1:
#         print(setTC5_213[l], fTC5_213[l], sum(freq >= fTC5_213[l] for freq in fTC5null_213[l]))
        print(setTC5_213[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# NRFFF
# YYFYN
# NRFNR
# NFFNR
# YFFR
# FRNYY
# YRFYN
# HRN
# NRFFR
# YRFFY
# NRFRR

# %% [markdown]
#  # 3.214 (F) BPI - (H) BLOOM- (N) JGS - (R) MEG - (α) SCC

# %%
 # 3.211 (F) BPI - (H) BLOOM- (M) ICT - (R) MEG - (α) SCC #extract overlapping dates
start_214 = max(min(Date_BPI), min(Date_BLOOM), min(Date_JGS), min(Date_MEG), min(Date_SCC))
end_214 = min(max(Date_BPI), max(Date_BLOOM), max(Date_JGS), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
BPI_214_1 = Date_BPI.index(start_214)
BPI_214_2 = Date_BPI.index(end_214)

BLOOM_214_1 = Date_BLOOM.index(start_214)
BLOOM_214_2 = Date_BLOOM.index(end_214)

JGS_214_1 = Date_JGS.index(start_214)
JGS_214_2 = Date_JGS.index(end_214)

MEG_214_1 = Date_MEG.index(start_214)
MEG_214_2 = Date_MEG.index(end_214)

SCC_214_1 = Date_SCC.index(start_214)
SCC_214_2 = Date_SCC.index(end_214)

# %%
#save the shortened versions of closing prices
F214 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_214_1:BPI_214_2])
H214 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_214_1:BLOOM_214_2])
N214 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_214_1:JGS_214_2])
R214 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_214_1:MEG_214_2])
αSCC = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_214_1:SCC_214_2])

# %%
# import modules
import numpy as np
# import prices

F214 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H214 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
N214 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R214 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
αSCC = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_214 = []
st_214 = []
n = 1
while n < len(F214):
    sc_214 = ''
    if F214[n] > F214[n-1]:
        sc_214 = sc_214 + 'F'
    if H214[n] > H214[n-1]:
        sc_214 = sc_214 + 'H'
    if N214[n] > N214[n-1]:
        sc_214 = sc_214 + 'N'
    if R214[n] > R214[n-1]:
        sc_214 = sc_214 + 'R'
    if αSCC[n] > αSCC[n-1]:
        sc_214 = sc_214 + 'α'
    if len(sc_214) > 0:
        st_214.append(sc_214)
    else:
        STC_214.append(st_214)
        st_214 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_214 = STC_214.count([])
# keep only non-empty spatio-temporal sequences
STC_214 = [ st_214 for st_214 in STC_214 if len(st_214) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_214 = len(F214)
lmax_214 = 0
for st_214 in STC_214:
    if len(st_214) < lmin_214:
        lmin_214 = len(st_214)
    if len(st_214) > lmax_214:
        lmax_214 = len(st_214)
        
# restrict spatio-temporal sequences to length-5
STC5_214 = [ st_214 for st_214 in STC_214 if len(st_214) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_214 = []
for n in range(len(STC5_214)):
    tc_214 = [ u for u in STC5_214[n][0] ]
    for k in range(1, len(STC5_214[n])):
        tc_214 = [ u+v for u in tc_214 for v in STC5_214[n][k] ]
    TC5_214 = TC5_214 + tc_214
setTC5_214 = list(set(TC5_214))

# get empirical frequencies
fTC5_214 = [ TC5_214.count(setTC5_214[l]) for l in range(len(setTC5_214)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_214 = [ [] for l in range(len(setTC5_214)) ]
for s in range(100):
    STC5null_214 = [ list(st_214) for st_214 in STC5_214]
    for st_214 in STC5null_214:
        np.random.shuffle(st_214)
    TC5null_214= []
    for n in range(len(STC5null_214)):
        tc_214 = [ u for u in STC5null_214[n][0] ]
        for k in range(1, len(STC5null_214[n])):
            tc_214 = [ u+v for u in tc_214 for v in STC5null_214[n][k] ]
        TC5null_214= TC5null_214+ tc_214
    for l in range(len(setTC5_214)):
        if TC5null_214.count(setTC5_214[l]) > 0:
            fTC5null_214[l].append(TC5null_214.count(setTC5_214[l]))
        else:
            fTC5null_214[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_214)):
     if sum(freq >= fTC5_214[l] for freq in fTC5null_214[l]) < 5:
#         print(setTC5_214[l], fTC5_214[l], sum(freq >= fTC5_214[l] for freq in fTC5null_214[l]))
        print(setTC5_214[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# NαFH
# HRHFF
# NRNFα
# FFFRN
# HαNH
# HHHFα
# FαFR
# HRαRH
# RRFH
# FNNNH
# HRNH
# FαFH
# RRNR
# HαNα
# NRFR
# HαHH
# RαFN
# HαFFH
# FαNHα
# NNFFα
# HRNRα
# HRNHα
# FNNHH
# αRNFα
# FNαHH
# NRFNR
# HRNRH
# FRFR
# NNFFR
# FααH
# HαN
# HRαRα
# NNNNα
# HαHFH
# HRFR
# HαHFN
# FNFRH
# NFRFα
# HNNRH
# FααN
# RNFRH
# HαRH
# HNF
# HNαH
# NRRFR
# FαHFα
# HRFRα
# HRNFα
# RαFH
# FNNRH
# HRNαH
# NFFRα
# NFFFα
# NFRRR
# HRHFα
# FNRRH
# NRFFR
# HRRH
# NαFHF
# NNNRα
# FαFN
# FRHFα
# HHHFN
# NNFH
# HRHH
# HHHFF
# NFNFα
# HαFN
# RαFR
# HNFH
# NFRRH
# RRHFα
# HHFRF
# NRRNR
# HRHFH
# NRNHα
# NRRNα
# FRFH
# HRFRH
# NFHFα
# HαHFα
# HRFNH
# FRN
# HααH
# NNαNα
# RRN
# HRFH
# NRNRH
# HαFH
# NRFRα
# HRRNH
# FNαRH
# HRHFN
# HαFR
# NFFRH
# RRF
# HRFRF
# αRRFα
# HαF
# NNFRα
# αRRFR
# NNRRH
# NRFRH
# RRFRH
# NFFFH
# NNNRH
# NRHFα
# HRHRH
# NαFN
# NNFRH
# HαNFα

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_214)):
     if sum(freq >= fTC5_214[l] for freq in fTC5null_214[l]) < 1:
#         print(setTC5_214[l], fTC5_214[l], sum(freq >= fTC5_214[l] for freq in fTC5null_214[l]))
        print(setTC5_214[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# FαFR
# RαFN
# HRNHα
# αRNFα
# HRαRα
# FNFRH
# HNF
# NRRFR
# HRFRα
# HRHFα
# FαFN
# HαFN
# RαFR
# HRHFH
# HRFRH
# HαHFα
# FRN
# RRN
# HαFH
# NFFRH
# αRRFα
# NNRRH
# NNFRH

# %% [markdown]
#  # 3.215 (F) BPI - (H) BLOOM- (N) JGS - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_215 = max(min(Date_BPI), min(Date_BLOOM), min(Date_JGS), min(Date_SMC), min(Date_SCC))
end_215 = min(max(Date_BPI), max(Date_BLOOM), max(Date_JGS), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
BPI_215_1 = Date_BPI.index(start_215)
BPI_215_2 = Date_BPI.index(end_215)

BLOOM_215_1 = Date_BLOOM.index(start_215)
BLOOM_215_2 = Date_BLOOM.index(end_215)

JGS_215_1 = Date_JGS.index(start_215)
JGS_215_2 = Date_JGS.index(end_215)

SMC_215_1 = Date_SMC.index(start_215)
SMC_215_2 = Date_SMC.index(end_215)

SCC_215_1 = Date_SCC.index(start_215)
SCC_215_2 = Date_SCC.index(end_215)

# %%
#save the shortened versions of closing prices
F215 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_215_1:BPI_215_2])
H215 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_215_1:BLOOM_215_2])
N215 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_215_1:JGS_215_2])
Y215 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_215_1:SMC_215_2])
αSCC = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_215_1:SCC_215_2])

# %%
# import modules
import numpy as np
# import prices

F215 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H215 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
N215 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y215 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
αSCC = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_215 = []
st_215 = []
n = 1
while n < len(F215):
    sc_215 = ''
    if F215[n] > F215[n-1]:
        sc_215 = sc_215 + 'F'
    if H215[n] > H215[n-1]:
        sc_215 = sc_215 + 'H'
    if N215[n] > N215[n-1]:
        sc_215 = sc_215 + 'N'
    if Y215[n] > Y215[n-1]:
        sc_215 = sc_215 + 'Y'
    if αSCC[n] > αSCC[n-1]:
        sc_215 = sc_215 + 'α'
    if len(sc_215) > 0:
        st_215.append(sc_215)
    else:
        STC_215.append(st_215)
        st_215 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_215 = STC_215.count([])
# keep only non-empty spatio-temporal sequences
STC_215 = [ st_215 for st_215 in STC_215 if len(st_215) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_215 = len(F215)
lmax_215 = 0
for st_215 in STC_215:
    if len(st_215) < lmin_215:
        lmin_215 = len(st_215)
    if len(st_215) > lmax_215:
        lmax_215 = len(st_215)
        
# restrict spatio-temporal sequences to length-5
STC5_215 = [ st_215 for st_215 in STC_215 if len(st_215) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_215 = []
for n in range(len(STC5_215)):
    tc_215 = [ u for u in STC5_215[n][0] ]
    for k in range(1, len(STC5_215[n])):
        tc_215 = [ u+v for u in tc_215 for v in STC5_215[n][k] ]
    TC5_215 = TC5_215 + tc_215
setTC5_215 = list(set(TC5_215))

# get empirical frequencies
fTC5_215 = [ TC5_215.count(setTC5_215[l]) for l in range(len(setTC5_215)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_215 = [ [] for l in range(len(setTC5_215)) ]
for s in range(100):
    STC5null_215 = [ list(st_215) for st_215 in STC5_215]
    for st_215 in STC5null_215:
        np.random.shuffle(st_215)
    TC5null_215= []
    for n in range(len(STC5null_215)):
        tc_215 = [ u for u in STC5null_215[n][0] ]
        for k in range(1, len(STC5null_215[n])):
            tc_215 = [ u+v for u in tc_215 for v in STC5null_215[n][k] ]
        TC5null_215= TC5null_215+ tc_215
    for l in range(len(setTC5_215)):
        if TC5null_215.count(setTC5_215[l]) > 0:
            fTC5null_215[l].append(TC5null_215.count(setTC5_215[l]))
        else:
            fTC5null_215[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_215)):
     if sum(freq >= fTC5_215[l] for freq in fTC5null_215[l]) < 5:
#         print(setTC5_215[l], fTC5_215[l], sum(freq >= fTC5_215[l] for freq in fTC5null_215[l]))
        print(setTC5_215[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FYYY
# FYYα
# FNαFH
# HαNH
# FαNHY
# FαHH
# HFF
# YYαNα
# YYααα
# HαHH
# FYFYN
# HαYHH
# YHNHH
# FαYFα
# NNNFα
# αYNHY
# NNFFα
# NNHFα
# Hαα
# FαYFN
# NYFNN
# FαNFα
# FαYαα
# YNYYN
# HαYFα
# FNYYY
# FαYFF
# NYNFα
# FYαNα
# FααHY
# FHHYN
# FYYNα
# HNF
# FYYN
# FYFNα
# FαHFα
# FαHHY
# NYFFN
# NFFFα
# HαYN
# Yαα
# HαHαα
# FαFN
# NNFFH
# NNFH
# FαNαY
# FαYHY
# NFNFα
# HαFN
# NYαNα
# FαNαα
# HFNHY
# NαHFα
# NYHFN
# FNααH
# HαYFN
# HαHFα
# NNHFH
# FNNHY
# NNαNα
# NNFN
# FNNHN
# NYNNN
# HαFH
# FαFY
# HαHHH
# YHNFH
# FYFNN
# FNαNH
# FFNHY
# NYαNN
# FαYN
# HαF
# FαYFY
# FYαNN
# ααYFF

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_215)):
     if sum(freq >= fTC5_215[l] for freq in fTC5null_215[l]) < 1:
#         print(setTC5_215[l], fTC5_215[l], sum(freq >= fTC5_215[l] for freq in fTC5null_215[l]))
        print(setTC5_215[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# YYαNα
# HαHH
# FαYFα
# FYαNα
# HNF
# FYYN
# FαHFα
# NFFFα
# HαYN
# FαFN
# NNFFH
# HαFN
# HαHFα
# FNNHY
# HαFH
# FFNHY
# NYαNN
# HαF
# FYαNN

# %% [markdown]
#  # 3.216 (F) BPI - (H) BLOOM- (R) MEG - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_216 = max(min(Date_BPI), min(Date_BLOOM), min(Date_MEG), min(Date_SMC), min(Date_SCC))
end_216 = min(max(Date_BPI), max(Date_BLOOM), max(Date_MEG), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
BPI_216_1 = Date_BPI.index(start_216)
BPI_216_2 = Date_BPI.index(end_216)

BLOOM_216_1 = Date_BLOOM.index(start_216)
BLOOM_216_2 = Date_BLOOM.index(end_216)

MEG_216_1 = Date_MEG.index(start_216)
MEG_216_2 = Date_MEG.index(end_216)

SMC_216_1 = Date_SMC.index(start_216)
SMC_216_2 = Date_SMC.index(end_216)

SCC_216_1 = Date_SCC.index(start_216)
SCC_216_2 = Date_SCC.index(end_216)

# %%
#save the shortened versions of closing prices
F216 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_216_1:BPI_216_2])
H216 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_216_1:BLOOM_216_2])
R216 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_216_1:MEG_216_2])
Y216 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_216_1:SMC_216_2])
αSCC = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_216_1:SCC_216_2])

# %%
# import modules
import numpy as np
# import prices

F216 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H216 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
R216 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y216 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
αSCC = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_216 = []
st_216 = []
n = 1
while n < len(F216):
    sc_216 = ''
    if F216[n] > F216[n-1]:
        sc_216 = sc_216 + 'F'
    if H216[n] > H216[n-1]:
        sc_216 = sc_216 + 'H'
    if R216[n] > R216[n-1]:
        sc_216 = sc_216 + 'N'
    if Y216[n] > Y216[n-1]:
        sc_216 = sc_216 + 'Y'
    if αSCC[n] > αSCC[n-1]:
        sc_216 = sc_216 + 'α'
    if len(sc_216) > 0:
        st_216.append(sc_216)
    else:
        STC_216.append(st_216)
        st_216 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_216 = STC_216.count([])
# keep only non-empty spatio-temporal sequences
STC_216 = [ st_216 for st_216 in STC_216 if len(st_216) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_216 = len(F216)
lmax_216 = 0
for st_216 in STC_216:
    if len(st_216) < lmin_216:
        lmin_216 = len(st_216)
    if len(st_216) > lmax_216:
        lmax_216 = len(st_216)
        
# restrict spatio-temporal sequences to length-5
STC5_216 = [ st_216 for st_216 in STC_216 if len(st_216) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_216 = []
for n in range(len(STC5_216)):
    tc_216 = [ u for u in STC5_216[n][0] ]
    for k in range(1, len(STC5_216[n])):
        tc_216 = [ u+v for u in tc_216 for v in STC5_216[n][k] ]
    TC5_216 = TC5_216 + tc_216
setTC5_216 = list(set(TC5_216))

# get empirical frequencies
fTC5_216 = [ TC5_216.count(setTC5_216[l]) for l in range(len(setTC5_216)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_216 = [ [] for l in range(len(setTC5_216)) ]
for s in range(100):
    STC5null_216 = [ list(st_216) for st_216 in STC5_216]
    for st_216 in STC5null_216:
        np.random.shuffle(st_216)
    TC5null_216= []
    for n in range(len(STC5null_216)):
        tc_216 = [ u for u in STC5null_216[n][0] ]
        for k in range(1, len(STC5null_216[n])):
            tc_216 = [ u+v for u in tc_216 for v in STC5null_216[n][k] ]
        TC5null_216= TC5null_216+ tc_216
    for l in range(len(setTC5_216)):
        if TC5null_216.count(setTC5_216[l]) > 0:
            fTC5null_216[l].append(TC5null_216.count(setTC5_216[l]))
        else:
            fTC5null_216[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_216)):
     if sum(freq >= fTC5_216[l] for freq in fTC5null_216[l]) < 5:
#         print(setTC5_216[l], fTC5_216[l], sum(freq >= fTC5_216[l] for freq in fTC5null_216[l]))
        print(setTC5_216[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FYYY
# HNHFα
# FNαNN
# FNFYN
# FYααH
# HFF
# FNNαN
# HαHH
# HαFFH
# FαYFα
# FYαFN
# YNFαH
# HNNY
# FαFHY
# FYNNH
# HαFHF
# HNNH
# αYYαF
# YNYαH
# αYNHF
# FNYYY
# HαHFH
# YNYHH
# YFYYH
# HNHHH
# HααFH
# αNYYY
# FααHY
# HNF
# HFFNF
# αNNFα
# FαHFα
# FNFNN
# αFNFα
# HYYαN
# FYNNN
# αYααH
# FYNαH
# FYNαN
# FαYHα
# YH
# FYYαN
# FαFN
# NH
# NNYαN
# FαYHY
# HαFHH
# αNFFα
# HαFFF
# HNFH
# FNNYN
# αNNNN
# αYYαN
# ααYYY
# FNNNN
# FαααY
# αNFFN
# HαFNN
# HαHFα
# NYYαN
# FαFYN
# αYYαH
# FYααN
# FH
# HαFH
# HαFYN
# HαHHH
# HNHNH
# NNF
# YHNH
# αNFαN
# αNααN
# HFNY
# HFYNF
# YNNαH
# HYYNN
# HαF
# YNY
# HFFHF
# αYNαN
# HYYαH
# YαFN
# αYYFF
# FαYFY
# HααYN
# αYααN
# HααHH
# FYαNN

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_216)):
     if sum(freq >= fTC5_216[l] for freq in fTC5null_216[l]) < 1:
#         print(setTC5_216[l], fTC5_216[l], sum(freq >= fTC5_216[l] for freq in fTC5null_216[l]))
        print(setTC5_216[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# HNNH
# HNHHH
# FYNNN
# αYααH
# FYNαN
# FYYαN
# ααYYY
# FNNNN
# αYYαH
# HNHNH
# HαF
# αYNαN
# FYαNN

# %% [markdown]
#  # 3.217 (F) BPI - (J) FGEN- (M) ICT - (N) JGS - (R) MEG

# %%
#extract overlapping dates
start_217 = max(min(Date_BPI), min(Date_FGEN), min(Date_ICT), min(Date_JGS), min(Date_MEG))
end_217 = min(max(Date_BPI), max(Date_FGEN), max(Date_ICT), max(Date_JGS), max(Date_MEG))

# %%
#shorten the closing prices
BPI_217_1 = Date_BPI.index(start_217)
BPI_217_2 = Date_BPI.index(end_217)

FGEN_217_1 = Date_FGEN.index(start_217)
FGEN_217_2 = Date_FGEN.index(end_217)

ICT_217_1 = Date_ICT.index(start_217)
ICT_217_2 = Date_ICT.index(end_217)

JGS_217_1 = Date_JGS.index(start_217)
JGS_217_2 = Date_JGS.index(end_217)

MEG_217_1 = Date_MEG.index(start_217)
MEG_217_2 = Date_MEG.index(end_217)

# %%
#save the shortened versions of closing prices
F217 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_217_1:BPI_217_2])
J217 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_217_1:FGEN_217_2])
M217 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_217_1:ICT_217_2])
N217 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_217_1:JGS_217_2])
R217 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_217_1:MEG_217_2])

# %%
# import modules
import numpy as np
# import prices

F217 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J217 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M217 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N217 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R217 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_217 = []
st_217 = []
n = 1
while n < len(F217):
    sc_217 = ''
    if F217[n] > F217[n-1]:
        sc_217 = sc_217 + 'F'
    if J217[n] > J217[n-1]:
        sc_217 = sc_217 + 'J'
    if M217[n] > M217[n-1]:
        sc_217 = sc_217 + 'M'
    if N217[n] > N217[n-1]:
        sc_217 = sc_217 + 'N'
    if R217[n] > R217[n-1]:
        sc_217 = sc_217 + 'R'
    if len(sc_217) > 0:
        st_217.append(sc_217)
    else:
        STC_217.append(st_217)
        st_217 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[56], line 11
#       9 if J217[n] > J217[n-1]:
#      10     sc_217 = sc_217 + 'J'
# ---> 11 if M217[n] > M217[n-1]:
#      12     sc_217 = sc_217 + 'M'
#      13 if N217[n] > N217[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_217 = STC_217.count([])
# keep only non-empty spatio-temporal sequences
STC_217 = [ st_217 for st_217 in STC_217 if len(st_217) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_217 = len(F217)
lmax_217 = 0
for st_217 in STC_217:
    if len(st_217) < lmin_217:
        lmin_217 = len(st_217)
    if len(st_217) > lmax_217:
        lmax_217 = len(st_217)
        
# restrict spatio-temporal sequences to length-5
STC5_217 = [ st_217 for st_217 in STC_217 if len(st_217) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_217 = []
for n in range(len(STC5_217)):
    tc_217 = [ u for u in STC5_217[n][0] ]
    for k in range(1, len(STC5_217[n])):
        tc_217 = [ u+v for u in tc_217 for v in STC5_217[n][k] ]
    TC5_217 = TC5_217 + tc_217
setTC5_217 = list(set(TC5_217))

# get empirical frequencies
fTC5_217 = [ TC5_217.count(setTC5_217[l]) for l in range(len(setTC5_217)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_217 = [ [] for l in range(len(setTC5_217)) ]
for s in range(100):
    STC5null_217 = [ list(st_217) for st_217 in STC5_217]
    for st_217 in STC5null_217:
        np.random.shuffle(st_217)
    TC5null_217= []
    for n in range(len(STC5null_217)):
        tc_217 = [ u for u in STC5null_217[n][0] ]
        for k in range(1, len(STC5null_217[n])):
            tc_217 = [ u+v for u in tc_217 for v in STC5null_217[n][k] ]
        TC5null_217= TC5null_217+ tc_217
    for l in range(len(setTC5_217)):
        if TC5null_217.count(setTC5_217[l]) > 0:
            fTC5null_217[l].append(TC5null_217.count(setTC5_217[l]))
        else:
            fTC5null_217[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_217)):
     if sum(freq >= fTC5_217[l] for freq in fTC5null_217[l]) < 5:
#         print(setTC5_217[l], fTC5_217[l], sum(freq >= fTC5_217[l] for freq in fTC5null_217[l]))
        print(setTC5_217[l])

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_217)):
     if sum(freq >= fTC5_217[l] for freq in fTC5null_217[l]) < 1:
#         print(setTC5_217[l], fTC5_217[l], sum(freq >= fTC5_217[l] for freq in fTC5null_217[l]))
        print(setTC5_217[l])

# %% [markdown]
#  # 3.218 (F) BPI - (J) FGEN- (M) ICT - (N) JGS - (Y) SMC

# %%
#extract overlapping dates
start_218 = max(min(Date_BPI), min(Date_FGEN), min(Date_ICT), min(Date_JGS), min(Date_SMC))
end_218 = min(max(Date_BPI), max(Date_FGEN), max(Date_ICT), max(Date_JGS), max(Date_SMC))

# %%
#shorten the closing prices
BPI_218_1 = Date_BPI.index(start_218)
BPI_218_2 = Date_BPI.index(end_218)

FGEN_218_1 = Date_FGEN.index(start_218)
FGEN_218_2 = Date_FGEN.index(end_218)

ICT_218_1 = Date_ICT.index(start_218)
ICT_218_2 = Date_ICT.index(end_218)

JGS_218_1 = Date_JGS.index(start_218)
JGS_218_2 = Date_JGS.index(end_218)

SMC_218_1 = Date_SMC.index(start_218)
SMC_218_2 = Date_SMC.index(end_218)

# %%
#save the shortened versions of closing prices
F218 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_218_1:BPI_218_2])
J218 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_218_1:FGEN_218_2])
M218 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_218_1:ICT_218_2])
N218 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_218_1:JGS_218_2])
Y218 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_218_1:SMC_218_2])

# %%
# import modules
import numpy as np
# import prices

F218 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J218 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M218 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N218 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y218 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_218 = []
st_218 = []
n = 1
while n < len(F218):
    sc_218 = ''
    if F218[n] > F218[n-1]:
        sc_218 = sc_218 + 'F'
    if J218[n] > J218[n-1]:
        sc_218 = sc_218 + 'J'
    if M218[n] > M218[n-1]:
        sc_218 = sc_218 + 'M'
    if N218[n] > N218[n-1]:
        sc_218 = sc_218 + 'N'
    if Y218[n] > Y218[n-1]:
        sc_218 = sc_218 + 'Y'
    if len(sc_218) > 0:
        st_218.append(sc_218)
    else:
        STC_218.append(st_218)
        st_218 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[61], line 11
#       9 if J218[n] > J218[n-1]:
#      10     sc_218 = sc_218 + 'J'
# ---> 11 if M218[n] > M218[n-1]:
#      12     sc_218 = sc_218 + 'M'
#      13 if N218[n] > N218[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_218 = STC_218.count([])
# keep only non-empty spatio-temporal sequences
STC_218 = [ st_218 for st_218 in STC_218 if len(st_218) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_218 = len(F218)
lmax_218 = 0
for st_218 in STC_218:
    if len(st_218) < lmin_218:
        lmin_218 = len(st_218)
    if len(st_218) > lmax_218:
        lmax_218 = len(st_218)
        
# restrict spatio-temporal sequences to length-5
STC5_218 = [ st_218 for st_218 in STC_218 if len(st_218) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_218 = []
for n in range(len(STC5_218)):
    tc_218 = [ u for u in STC5_218[n][0] ]
    for k in range(1, len(STC5_218[n])):
        tc_218 = [ u+v for u in tc_218 for v in STC5_218[n][k] ]
    TC5_218 = TC5_218 + tc_218
setTC5_218 = list(set(TC5_218))

# get empirical frequencies
fTC5_218 = [ TC5_218.count(setTC5_218[l]) for l in range(len(setTC5_218)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_218 = [ [] for l in range(len(setTC5_218)) ]
for s in range(100):
    STC5null_218 = [ list(st_218) for st_218 in STC5_218]
    for st_218 in STC5null_218:
        np.random.shuffle(st_218)
    TC5null_218= []
    for n in range(len(STC5null_218)):
        tc_218 = [ u for u in STC5null_218[n][0] ]
        for k in range(1, len(STC5null_218[n])):
            tc_218 = [ u+v for u in tc_218 for v in STC5null_218[n][k] ]
        TC5null_218= TC5null_218+ tc_218
    for l in range(len(setTC5_218)):
        if TC5null_218.count(setTC5_218[l]) > 0:
            fTC5null_218[l].append(TC5null_218.count(setTC5_218[l]))
        else:
            fTC5null_218[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_218)):
     if sum(freq >= fTC5_218[l] for freq in fTC5null_218[l]) < 5:
#         print(setTC5_218[l], fTC5_218[l], sum(freq >= fTC5_218[l] for freq in fTC5null_218[l]))
        print(setTC5_218[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FYYY
# NJYM
# FFMYM
# FFM
# NJFFM
# FJFM
# FJMYM
# YYFYY
# FMMF
# FFMNM
# NNYM
# YYJJN
# YYFFY
# YNMJF
# FYFNY
# NJJJN
# JFJN
# JYYJ
# NJMNN
# YFMYN
# NJMJN
# YYFNY
# NJFM
# YNNM
# NNJM
# NMFNY
# YYJMY
# FMJM
# NFMNN
# FJFFM
# FJYJ
# YYJYN
# FYYN
# FYJNY
# NJFFY
# YYJFN
# YYJNJ
# NYJM
# JJMJM
# MFJFY
# FMJF
# YJMJM
# YMMJF
# YFMJM
# NMMNN
# YYJNY
# YJJJN
# YJJJF
# YNJNM
# NJFFF
# YMJFM
# YYJNF
# YYFNJ
# NJJFJ
# NYYM
# FFFNY
# MMJFM
# NFMFN
# NYYJ
# NJFFJ
# FNMYM
# YYJNM
# FYYJ
# FJM
# FJMFM
# YFMNM
# FJN
# NJYJ
# YMNM
# JYJNJ
# NJMFN
# FFNN
# YYJNN
# YFJNM
# NJJM
# JJYJ
# YNMJN
# YYJJF

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_218)):
     if sum(freq >= fTC5_218[l] for freq in fTC5null_218[l]) < 1:
#         print(setTC5_218[l], fTC5_218[l], sum(freq >= fTC5_218[l] for freq in fTC5null_218[l]))
        print(setTC5_218[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# JYYJ
# NJMNN
# NJMJN
# NFMNN
# YYJYN
# JJMJM
# YJMJM
# YJJJF
# NYYM
# NFMFN
# FYYJ
# YMNM
# NJMFN
# FFNN
# YYJNN

# %% [markdown]
#  # 3.219 (F) BPI - (J) FGEN- (M) ICT - (N) JGS - (α) SCC

# %%
#extract overlapping dates
start_219 = max(min(Date_BPI), min(Date_FGEN), min(Date_ICT), min(Date_JGS), min(Date_SCC))
end_219 = min(max(Date_BPI), max(Date_FGEN), max(Date_ICT), max(Date_JGS), max(Date_SCC))

# %%
#shorten the closing prices
BPI_219_1 = Date_BPI.index(start_219)
BPI_219_2 = Date_BPI.index(end_219)

FGEN_219_1 = Date_FGEN.index(start_219)
FGEN_219_2 = Date_FGEN.index(end_219)

ICT_219_1 = Date_ICT.index(start_219)
ICT_219_2 = Date_ICT.index(end_219)

JGS_219_1 = Date_JGS.index(start_219)
JGS_219_2 = Date_JGS.index(end_219)

SCC_219_1 = Date_SCC.index(start_219)
SCC_219_2 = Date_SCC.index(end_219)

# %%
#save the shortened versions of closing prices
F219 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_219_1:BPI_219_2])
J219 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_219_1:FGEN_219_2])
M219 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_219_1:ICT_219_2])
N219 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_219_1:JGS_219_2])
α219 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_219_1:SCC_219_2])

# %%
# import modules
import numpy as np
# import prices

F219 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J219 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M219 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N219 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
α219 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_219 = []
st_219 = []
n = 1
while n < len(F219):
    sc_219 = ''
    if F219[n] > F219[n-1]:
        sc_219 = sc_219 + 'F'
    if J219[n] > J219[n-1]:
        sc_219 = sc_219 + 'J'
    if M219[n] > M219[n-1]:
        sc_219 = sc_219 + 'M'
    if N219[n] > N219[n-1]:
        sc_219 = sc_219 + 'N'
    if α219[n] > α219[n-1]:
        sc_219 = sc_219 + 'α'
    if len(sc_219) > 0:
        st_219.append(sc_219)
    else:
        STC_219.append(st_219)
        st_219 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[69], line 11
#       9 if J219[n] > J219[n-1]:
#      10     sc_219 = sc_219 + 'J'
# ---> 11 if M219[n] > M219[n-1]:
#      12     sc_219 = sc_219 + 'M'
#      13 if N219[n] > N219[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_219 = STC_219.count([])
# keep only non-empty spatio-temporal sequences
STC_219 = [ st_219 for st_219 in STC_219 if len(st_219) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_219 = len(F219)
lmax_219 = 0
for st_219 in STC_219:
    if len(st_219) < lmin_219:
        lmin_219 = len(st_219)
    if len(st_219) > lmax_219:
        lmax_219 = len(st_219)
        
# restrict spatio-temporal sequences to length-5
STC5_219 = [ st_219 for st_219 in STC_219 if len(st_219) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_219 = []
for n in range(len(STC5_219)):
    tc_219 = [ u for u in STC5_219[n][0] ]
    for k in range(1, len(STC5_219[n])):
        tc_219 = [ u+v for u in tc_219 for v in STC5_219[n][k] ]
    TC5_219 = TC5_219 + tc_219
setTC5_219 = list(set(TC5_219))

# get empirical frequencies
fTC5_219 = [ TC5_219.count(setTC5_219[l]) for l in range(len(setTC5_219)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_219 = [ [] for l in range(len(setTC5_219)) ]
for s in range(100):
    STC5null_219 = [ list(st_219) for st_219 in STC5_219]
    for st_219 in STC5null_219:
        np.random.shuffle(st_219)
    TC5null_219= []
    for n in range(len(STC5null_219)):
        tc_219 = [ u for u in STC5null_219[n][0] ]
        for k in range(1, len(STC5null_219[n])):
            tc_219 = [ u+v for u in tc_219 for v in STC5null_219[n][k] ]
        TC5null_219= TC5null_219+ tc_219
    for l in range(len(setTC5_219)):
        if TC5null_219.count(setTC5_219[l]) > 0:
            fTC5null_219[l].append(TC5null_219.count(setTC5_219[l]))
        else:
            fTC5null_219[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_219)):
     if sum(freq >= fTC5_219[l] for freq in fTC5null_219[l]) < 5:
#         print(setTC5_219[l], fTC5_219[l], sum(freq >= fTC5_219[l] for freq in fTC5null_219[l]))
        print(setTC5_219[l])

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_219)):
     if sum(freq >= fTC5_219[l] for freq in fTC5null_219[l]) < 1:
#         print(setTC5_219[l], fTC5_219[l], sum(freq >= fTC5_219[l] for freq in fTC5null_219[l]))
        print(setTC5_219[l])

# %% [markdown]
#  # 3.220 (F) BPI - (J) FGEN- (M) ICT - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_220 = max(min(Date_BPI), min(Date_FGEN), min(Date_ICT), min(Date_MEG), min(Date_SMC))
end_220 = min(max(Date_BPI), max(Date_FGEN), max(Date_ICT), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
BPI_220_1 = Date_BPI.index(start_220)
BPI_220_2 = Date_BPI.index(end_220)

FGEN_220_1 = Date_FGEN.index(start_220)
FGEN_220_2 = Date_FGEN.index(end_220)

ICT_220_1 = Date_ICT.index(start_220)
ICT_220_2 = Date_ICT.index(end_220)

MEG_220_1 = Date_MEG.index(start_220)
MEG_220_2 = Date_MEG.index(end_220)

SMC_220_1 = Date_SMC.index(start_220)
SMC_220_2 = Date_SMC.index(end_220)

# %%
#save the shortened versions of closing prices
F220 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_220_1:BPI_220_2])
J220 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_220_1:FGEN_220_2])
M220 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_220_1:ICT_220_2])
R220 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_220_1:MEG_220_2])
Y220 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_220_1:SMC_220_2])

# %%
# import modules
import numpy as np
# import prices

F220 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J220 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M220 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R220 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y220 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_220 = []
st_220 = []
n = 1
while n < len(F220):
    sc_220 = ''
    if F220[n] > F220[n-1]:
        sc_220 = sc_220 + 'F'
    if J220[n] > J220[n-1]:
        sc_220 = sc_220 + 'J'
    if M220[n] > M220[n-1]:
        sc_220 = sc_220 + 'M'
    if R220[n] > R220[n-1]:
        sc_220 = sc_220 + 'R'
    if Y220[n] > Y220[n-1]:
        sc_220 = sc_220 + 'Y'
    if len(sc_220) > 0:
        st_220.append(sc_220)
    else:
        STC_220.append(st_220)
        st_220 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[74], line 11
#       9 if J220[n] > J220[n-1]:
#      10     sc_220 = sc_220 + 'J'
# ---> 11 if M220[n] > M220[n-1]:
#      12     sc_220 = sc_220 + 'M'
#      13 if R220[n] > R220[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_220 = STC_220.count([])
# keep only non-empty spatio-temporal sequences
STC_220 = [ st_220 for st_220 in STC_220 if len(st_220) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_220 = len(F220)
lmax_220 = 0
for st_220 in STC_220:
    if len(st_220) < lmin_220:
        lmin_220 = len(st_220)
    if len(st_220) > lmax_220:
        lmax_220 = len(st_220)
        
# restrict spatio-temporal sequences to length-5
STC5_220 = [ st_220 for st_220 in STC_220 if len(st_220) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_220 = []
for n in range(len(STC5_220)):
    tc_220 = [ u for u in STC5_220[n][0] ]
    for k in range(1, len(STC5_220[n])):
        tc_220 = [ u+v for u in tc_220 for v in STC5_220[n][k] ]
    TC5_220 = TC5_220 + tc_220
setTC5_220 = list(set(TC5_220))

# get empirical frequencies
fTC5_220 = [ TC5_220.count(setTC5_220[l]) for l in range(len(setTC5_220)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_220 = [ [] for l in range(len(setTC5_220)) ]
for s in range(100):
    STC5null_220 = [ list(st_220) for st_220 in STC5_220]
    for st_220 in STC5null_220:
        np.random.shuffle(st_220)
    TC5null_220= []
    for n in range(len(STC5null_220)):
        tc_220 = [ u for u in STC5null_220[n][0] ]
        for k in range(1, len(STC5null_220[n])):
            tc_220 = [ u+v for u in tc_220 for v in STC5null_220[n][k] ]
        TC5null_220= TC5null_220+ tc_220
    for l in range(len(setTC5_220)):
        if TC5null_220.count(setTC5_220[l]) > 0:
            fTC5null_220[l].append(TC5null_220.count(setTC5_220[l]))
        else:
            fTC5null_220[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_220)):
     if sum(freq >= fTC5_220[l] for freq in fTC5null_220[l]) < 5:
#         print(setTC5_220[l], fTC5_220[l], sum(freq >= fTC5_220[l] for freq in fTC5null_220[l]))
        print(setTC5_220[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# MMJRF
# MFRYY
# YYFYR
# RYJ
# FJFM
# FJMYM
# YYFYY
# FMMF
# YYRM
# FFMF
# RYFYR
# RJJM
# MYJJY
# YMFRF
# YYFFY
# RJJFY
# MJMFM
# YYJFR
# MYRJY
# RYFYY
# YYJM
# RJMF
# YJFM
# YYMM
# YFFYY
# YRJYY
# MYJJR
# YYJYY
# RJRF
# RJMM
# RJFFY
# FJFFM
# YJMJR
# YFFYR
# MRJJY
# MFMYY
# RMFRF
# MRRJY
# MJFFY
# FMRF
# YFMJR
# MYRJR
# FRMFM
# YFJYR
# MFJFY
# YMMJF
# YRJYR
# YFFFY
# YMRJF
# RMFFM
# RJRY
# YJJJF
# RJFM
# RMMRF
# YRJFR
# YYJYR
# MMJJM
# YMFJF
# MMYRF
# RMRJF
# YFJFY
# YFJYY
# MFJJY
# FJMYR
# MFJYY
# FRFYR
# MJJFY
# MFRJY
# MMFRF
# YRFFY
# YJJM
# MFFYY
# MMRRF
# MMRJM
# FJRY
# YMMRF
# RMRRF
# RFFFY
# RJJJF
# RMJFM
# YMRM
# MFMJR
# RMFJF

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_220)):
     if sum(freq >= fTC5_220[l] for freq in fTC5null_220[l]) < 1:
#         print(setTC5_220[l], fTC5_220[l], sum(freq >= fTC5_220[l] for freq in fTC5null_220[l]))
        print(setTC5_220[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# MYRJY
# RJMM
# RJFFY
# MRJJY
# FMRF
# MFJYY
# MFRJY
# MMRRF

# %% [markdown]
#  # 3.221 (F) BPI - (J) FGEN- (M) ICT - (R) MEG - (α) SCC

# %%
#extract overlapping dates
start_221 = max(min(Date_BPI), min(Date_FGEN), min(Date_ICT), min(Date_MEG), min(Date_SCC))
end_221 = min(max(Date_BPI), max(Date_FGEN), max(Date_ICT), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
BPI_221_1 = Date_BPI.index(start_221)
BPI_221_2 = Date_BPI.index(end_221)

FGEN_221_1 = Date_FGEN.index(start_221)
FGEN_221_2 = Date_FGEN.index(end_221)

ICT_221_1 = Date_ICT.index(start_221)
ICT_221_2 = Date_ICT.index(end_221)

MEG_221_1 = Date_MEG.index(start_221)
MEG_221_2 = Date_MEG.index(end_221)

SCC_221_1 = Date_SCC.index(start_221)
SCC_221_2 = Date_SCC.index(end_221)

# %%
#save the shortened versions of closing prices
F221 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_221_1:BPI_221_2])
J221 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_221_1:FGEN_221_2])
M221 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_221_1:ICT_221_2])
R221 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_221_1:MEG_221_2])
α221 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_221_1:SCC_221_2])

# %%
# import modules
import numpy as np
# import prices

F221 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J221 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M221 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R221 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α221 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_221 = []
st_221 = []
n = 1
while n < len(F221):
    sc_221 = ''
    if F221[n] > F221[n-1]:
        sc_221 = sc_221 + 'F'
    if J221[n] > J221[n-1]:
        sc_221 = sc_221 + 'J'
    if M221[n] > M221[n-1]:
        sc_221 = sc_221 + 'M'
    if R221[n] > R221[n-1]:
        sc_221 = sc_221 + 'R'
    if α221[n] > α221[n-1]:
        sc_221 = sc_221 + 'Y'
    if len(sc_221) > 0:
        st_221.append(sc_221)
    else:
        STC_221.append(st_221)
        st_221 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[82], line 11
#       9 if J221[n] > J221[n-1]:
#      10     sc_221 = sc_221 + 'J'
# ---> 11 if M221[n] > M221[n-1]:
#      12     sc_221 = sc_221 + 'M'
#      13 if R221[n] > R221[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_221 = STC_221.count([])
# keep only non-empty spatio-temporal sequences
STC_221 = [ st_221 for st_221 in STC_221 if len(st_221) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_221 = len(F221)
lmax_221 = 0
for st_221 in STC_221:
    if len(st_221) < lmin_221:
        lmin_221 = len(st_221)
    if len(st_221) > lmax_221:
        lmax_221 = len(st_221)
        
# restrict spatio-temporal sequences to length-5
STC5_221 = [ st_221 for st_221 in STC_221 if len(st_221) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_221 = []
for n in range(len(STC5_221)):
    tc_221 = [ u for u in STC5_221[n][0] ]
    for k in range(1, len(STC5_221[n])):
        tc_221 = [ u+v for u in tc_221 for v in STC5_221[n][k] ]
    TC5_221 = TC5_221 + tc_221
setTC5_221 = list(set(TC5_221))

# get empirical frequencies
fTC5_221 = [ TC5_221.count(setTC5_221[l]) for l in range(len(setTC5_221)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_221 = [ [] for l in range(len(setTC5_221)) ]
for s in range(100):
    STC5null_221 = [ list(st_221) for st_221 in STC5_221]
    for st_221 in STC5null_221:
        np.random.shuffle(st_221)
    TC5null_221= []
    for n in range(len(STC5null_221)):
        tc_221 = [ u for u in STC5null_221[n][0] ]
        for k in range(1, len(STC5null_221[n])):
            tc_221 = [ u+v for u in tc_221 for v in STC5null_221[n][k] ]
        TC5null_221= TC5null_221+ tc_221
    for l in range(len(setTC5_221)):
        if TC5null_221.count(setTC5_221[l]) > 0:
            fTC5null_221[l].append(TC5null_221.count(setTC5_221[l]))
        else:
            fTC5null_221[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_221)):
     if sum(freq >= fTC5_221[l] for freq in fTC5null_221[l]) < 5:
#         print(setTC5_221[l], fTC5_221[l], sum(freq >= fTC5_221[l] for freq in fTC5null_221[l]))
        print(setTC5_221[l])

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_221)):
     if sum(freq >= fTC5_221[l] for freq in fTC5null_221[l]) < 1:
#         print(setTC5_221[l], fTC5_221[l], sum(freq >= fTC5_221[l] for freq in fTC5null_221[l]))
        print(setTC5_221[l])

# %% [markdown]
#  # 3.222 (F) BPI - (J) FGEN- (M) ICT - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_222 = max(min(Date_BPI), min(Date_FGEN), min(Date_ICT), min(Date_SMC), min(Date_SCC))
end_222 = min(max(Date_BPI), max(Date_FGEN), max(Date_ICT), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
BPI_222_1 = Date_BPI.index(start_222)
BPI_222_2 = Date_BPI.index(end_222)

FGEN_222_1 = Date_FGEN.index(start_222)
FGEN_222_2 = Date_FGEN.index(end_222)

ICT_222_1 = Date_ICT.index(start_222)
ICT_222_2 = Date_ICT.index(end_222)

SMC_222_1 = Date_SMC.index(start_222)
SMC_222_2 = Date_SMC.index(end_222)

SCC_222_1 = Date_SCC.index(start_222)
SCC_222_2 = Date_SCC.index(end_222)

# %%
#save the shortened versions of closing prices
F222 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_222_1:BPI_222_2])
J222 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_222_1:FGEN_222_2])
M222 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_222_1:ICT_222_2])
Y222 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_222_1:SMC_222_2])
α222 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_222_1:SCC_222_2])

# %%
# import modules
import numpy as np
# import prices

F222 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J222 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M222 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
Y222 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α222 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_222 = []
st_222 = []
n = 1
while n < len(F222):
    sc_222 = ''
    if F222[n] > F222[n-1]:
        sc_222 = sc_222 + 'F'
    if J222[n] > J222[n-1]:
        sc_222 = sc_222 + 'J'
    if M222[n] > M222[n-1]:
        sc_222 = sc_222 + 'M'
    if Y222[n] > Y222[n-1]:
        sc_222 = sc_222 + 'Y'
    if α222[n] > α222[n-1]:
        sc_222 = sc_222 + 'α'
    if len(sc_222) > 0:
        st_222.append(sc_222)
    else:
        STC_222.append(st_222)
        st_222 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[87], line 11
#       9 if J222[n] > J222[n-1]:
#      10     sc_222 = sc_222 + 'J'
# ---> 11 if M222[n] > M222[n-1]:
#      12     sc_222 = sc_222 + 'M'
#      13 if Y222[n] > Y222[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_222 = STC_222.count([])
# keep only non-empty spatio-temporal sequences
STC_222 = [ st_222 for st_222 in STC_222 if len(st_222) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_222 = len(F222)
lmax_222 = 0
for st_222 in STC_222:
    if len(st_222) < lmin_222:
        lmin_222 = len(st_222)
    if len(st_222) > lmax_222:
        lmax_222 = len(st_222)
        
# restrict spatio-temporal sequences to length-5
STC5_222 = [ st_222 for st_222 in STC_222 if len(st_222) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_222 = []
for n in range(len(STC5_222)):
    tc_222 = [ u for u in STC5_222[n][0] ]
    for k in range(1, len(STC5_222[n])):
        tc_222 = [ u+v for u in tc_222 for v in STC5_222[n][k] ]
    TC5_222 = TC5_222 + tc_222
setTC5_222 = list(set(TC5_222))

# get empirical frequencies
fTC5_222 = [ TC5_222.count(setTC5_222[l]) for l in range(len(setTC5_222)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_222 = [ [] for l in range(len(setTC5_222)) ]
for s in range(100):
    STC5null_222 = [ list(st_222) for st_222 in STC5_222]
    for st_222 in STC5null_222:
        np.random.shuffle(st_222)
    TC5null_222= []
    for n in range(len(STC5null_222)):
        tc_222 = [ u for u in STC5null_222[n][0] ]
        for k in range(1, len(STC5null_222[n])):
            tc_222 = [ u+v for u in tc_222 for v in STC5null_222[n][k] ]
        TC5null_222= TC5null_222+ tc_222
    for l in range(len(setTC5_222)):
        if TC5null_222.count(setTC5_222[l]) > 0:
            fTC5null_222[l].append(TC5null_222.count(setTC5_222[l]))
        else:
            fTC5null_222[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_222)):
     if sum(freq >= fTC5_222[l] for freq in fTC5null_222[l]) < 5:
#         print(setTC5_222[l], fTC5_222[l], sum(freq >= fTC5_222[l] for freq in fTC5null_222[l]))
        print(setTC5_222[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# YαJFY
# YJJFY
# MJαJJ
# FYαMα
# YYαMα
# YFMMα
# JJYFα
# MJαFM
# αJαFF
# JYYα
# JJYFJ
# αMαMJ
# JYYJ
# JMFαF
# FYαMY
# MFFFα
# JYααY
# JJYα
# MMαFM
# YαMMα
# JαJα
# YJα
# FFααY
# αMααJ
# JαYJ
# JJYFF
# JMMα
# YMMJF
# αJαJJ
# YFFFα
# αJαFM
# MJFJF
# YJJJF
# YMFJF
# αJαFJ
# YJFJF
# MFJYY
# JαYα
# YJY
# JFYα
# FYYJ
# JJαFJ
# MFFYY
# MJαFJ
# JFFFα
# JFYFα
# JYαMY
# MMααJ
# YYαMY
# MJFFF
# JJYJ
# YJF
# JJααJ
# FJα
# JαYFJ

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_222)):
     if sum(freq >= fTC5_222[l] for freq in fTC5null_222[l]) < 1:
#         print(setTC5_222[l], fTC5_222[l], sum(freq >= fTC5_222[l] for freq in fTC5null_222[l]))
        print(setTC5_222[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# JMMα
# YFFFα
# MJFJF
# FYYJ
# JFYFα
# YJF

# %% [markdown]
#  # 3.223 (F) BPI - (J) FGEN- (N) JGS - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_223 = max(min(Date_BPI), min(Date_FGEN), min(Date_JGS), min(Date_MEG), min(Date_SMC))
end_223 = min(max(Date_BPI), max(Date_FGEN), max(Date_JGS), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
BPI_223_1 = Date_BPI.index(start_223)
BPI_223_2 = Date_BPI.index(end_223)

FGEN_223_1 = Date_FGEN.index(start_223)
FGEN_223_2 = Date_FGEN.index(end_223)

JGS_223_1 = Date_JGS.index(start_223)
JGS_223_2 = Date_JGS.index(end_223)

MEG_223_1 = Date_MEG.index(start_223)
MEG_223_2 = Date_MEG.index(end_223)

SMC_223_1 = Date_SMC.index(start_223)
SMC_223_2 = Date_SMC.index(end_223)

# %%
#save the shortened versions of closing prices
F223 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_223_1:BPI_223_2])
J223 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_223_1:FGEN_223_2])
N223 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_223_1:JGS_223_2])
R223 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_223_1:MEG_223_2])
Y223 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_223_1:SMC_223_2])

# %%
# import modules
import numpy as np
# import prices

F223 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J223 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N223 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R223 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y223 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_223 = []
st_223 = []
n = 1
while n < len(F223):
    sc_223 = ''
    if F223[n] > F223[n-1]:
        sc_223 = sc_223 + 'F'
    if J223[n] > J223[n-1]:
        sc_223 = sc_223 + 'J'
    if N223[n] > N223[n-1]:
        sc_223 = sc_223 + 'N'
    if R223[n] > R223[n-1]:
        sc_223 = sc_223 + 'R'
    if Y223[n] > Y223[n-1]:
        sc_223 = sc_223 + 'Y'
    if len(sc_223) > 0:
        st_223.append(sc_223)
    else:
        STC_223.append(st_223)
        st_223 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_223 = STC_223.count([])
# keep only non-empty spatio-temporal sequences
STC_223 = [ st_223 for st_223 in STC_223 if len(st_223) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_223 = len(F223)
lmax_223 = 0
for st_223 in STC_223:
    if len(st_223) < lmin_223:
        lmin_223 = len(st_223)
    if len(st_223) > lmax_223:
        lmax_223 = len(st_223)
        
# restrict spatio-temporal sequences to length-5
STC5_223 = [ st_223 for st_223 in STC_223 if len(st_223) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_223 = []
for n in range(len(STC5_223)):
    tc_223 = [ u for u in STC5_223[n][0] ]
    for k in range(1, len(STC5_223[n])):
        tc_223 = [ u+v for u in tc_223 for v in STC5_223[n][k] ]
    TC5_223 = TC5_223 + tc_223
setTC5_223 = list(set(TC5_223))

# get empirical frequencies
fTC5_223 = [ TC5_223.count(setTC5_223[l]) for l in range(len(setTC5_223)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_223 = [ [] for l in range(len(setTC5_223)) ]
for s in range(100):
    STC5null_223 = [ list(st_223) for st_223 in STC5_223]
    for st_223 in STC5null_223:
        np.random.shuffle(st_223)
    TC5null_223= []
    for n in range(len(STC5null_223)):
        tc_223 = [ u for u in STC5null_223[n][0] ]
        for k in range(1, len(STC5null_223[n])):
            tc_223 = [ u+v for u in tc_223 for v in STC5null_223[n][k] ]
        TC5null_223= TC5null_223+ tc_223
    for l in range(len(setTC5_223)):
        if TC5null_223.count(setTC5_223[l]) > 0:
            fTC5null_223[l].append(TC5null_223.count(setTC5_223[l]))
        else:
            fTC5null_223[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_223)):
     if sum(freq >= fTC5_223[l] for freq in fTC5null_223[l]) < 5:
#         print(setTC5_223[l], fTC5_223[l], sum(freq >= fTC5_223[l] for freq in fTC5null_223[l]))
        print(setTC5_223[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FYYY
# YNRNJ
# YYFYR
# RYJ
# RNFNJ
# YYFYY
# FYJNR
# RYN
# FJYY
# YYRYY
# RJYY
# FYFNJ
# YYFJN
# YNFNJ
# FRYJ
# FYFNR
# NJJJF
# FYFJJ
# RYYY
# YYFJF
# FYRRR
# YYJFN
# NNRN
# FYRNJ
# YRFNJ
# YYJRN
# FYRNR
# YYRRN
# FRYY
# YJJJF
# NYFJJ
# RYF
# FFFNJ
# YYFNJ
# NFFYJ
# YRYRN
# YYRFN
# FYFYJ
# YRRRN
# JNFJ
# FRFJ
# YYYRN
# FRN
# YYJRF
# RNFRJ
# NYFYJ
# YYRRF
# NYFJN
# YFFNJ
# RRF
# NRFYJ
# YYRJN
# NFFJJ
# RJJJF
# JRYJJ
# YYFRN
# NYNJJ
# RYFJN
# NFFNJ
# NJFJF
# YYJJF

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_223)):
     if sum(freq >= fTC5_223[l] for freq in fTC5null_223[l]) < 1:
#         print(setTC5_223[l], fTC5_223[l], sum(freq >= fTC5_223[l] for freq in fTC5null_223[l]))
        print(setTC5_223[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# YNRNJ
# RYJ
# RNFNJ
# YYFYY
# FYJNR
# YNFNJ
# FYRNR
# FRYY
# NYFYJ
# RRF

# %% [markdown]
#  # 3.224 (F) BPI - (J) FGEN- (N) JGS - (R) MEG - (α) SCC

# %%
#extract overlapping dates
start_224 = max(min(Date_BPI), min(Date_FGEN), min(Date_JGS), min(Date_MEG), min(Date_SCC))
end_224 = min(max(Date_BPI), max(Date_FGEN), max(Date_JGS), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
BPI_224_1 = Date_BPI.index(start_224)
BPI_224_2 = Date_BPI.index(end_224)

FGEN_224_1 = Date_FGEN.index(start_224)
FGEN_224_2 = Date_FGEN.index(end_224)

JGS_224_1 = Date_JGS.index(start_224)
JGS_224_2 = Date_JGS.index(end_224)

MEG_224_1 = Date_MEG.index(start_224)
MEG_224_2 = Date_MEG.index(end_224)

SCC_224_1 = Date_SCC.index(start_224)
SCC_224_2 = Date_SCC.index(end_224)

# %%
#save the shortened versions of closing prices
F224 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_224_1:BPI_224_2])
J224 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_224_1:FGEN_224_2])
N224 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_224_1:JGS_224_2])
R224 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_224_1:MEG_224_2])
α224 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_224_1:SCC_224_2])

# %%
# import modules
import numpy as np
# import prices

F224 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J224 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N224 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R224 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α224 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_224 = []
st_224 = []
n = 1
while n < len(F224):
    sc_224 = ''
    if F224[n] > F224[n-1]:
        sc_224 = sc_224 + 'F'
    if J224[n] > J224[n-1]:
        sc_224 = sc_224 + 'J'
    if N224[n] > N224[n-1]:
        sc_224 = sc_224 + 'N'
    if R224[n] > R224[n-1]:
        sc_224 = sc_224 + 'R'
    if α224[n] > α224[n-1]:
        sc_224 = sc_224 + 'α'
    if len(sc_224) > 0:
        st_224.append(sc_224)
    else:
        STC_224.append(st_224)
        st_224 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_224 = STC_224.count([])
# keep only non-empty spatio-temporal sequences
STC_224 = [ st_224 for st_224 in STC_224 if len(st_224) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_224 = len(F224)
lmax_224 = 0
for st_224 in STC_224:
    if len(st_224) < lmin_224:
        lmin_224 = len(st_224)
    if len(st_224) > lmax_224:
        lmax_224 = len(st_224)
        
# restrict spatio-temporal sequences to length-5
STC5_224 = [ st_224 for st_224 in STC_224 if len(st_224) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_224 = []
for n in range(len(STC5_224)):
    tc_224 = [ u for u in STC5_224[n][0] ]
    for k in range(1, len(STC5_224[n])):
        tc_224 = [ u+v for u in tc_224 for v in STC5_224[n][k] ]
    TC5_224 = TC5_224 + tc_224
setTC5_224 = list(set(TC5_224))

# get empirical frequencies
fTC5_224 = [ TC5_224.count(setTC5_224[l]) for l in range(len(setTC5_224)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_224 = [ [] for l in range(len(setTC5_224)) ]
for s in range(100):
    STC5null_224 = [ list(st_224) for st_224 in STC5_224]
    for st_224 in STC5null_224:
        np.random.shuffle(st_224)
    TC5null_224= []
    for n in range(len(STC5null_224)):
        tc_224 = [ u for u in STC5null_224[n][0] ]
        for k in range(1, len(STC5null_224[n])):
            tc_224 = [ u+v for u in tc_224 for v in STC5null_224[n][k] ]
        TC5null_224= TC5null_224+ tc_224
    for l in range(len(setTC5_224)):
        if TC5null_224.count(setTC5_224[l]) > 0:
            fTC5null_224[l].append(TC5null_224.count(setTC5_224[l]))
        else:
            fTC5null_224[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_224)):
     if sum(freq >= fTC5_224[l] for freq in fTC5null_224[l]) < 5:
#         print(setTC5_224[l], fTC5_224[l], sum(freq >= fTC5_224[l] for freq in fTC5null_224[l]))
        print(setTC5_224[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FJαNR
# NFJJF
# αNFRF
# αNJαJ
# FαFR
# FαFJ
# αNFRJ
# RJJRN
# RJJNJ
# αααRJ
# RRFN
# RαFN
# αJJFF
# FJαRR
# RNFαJ
# RJJFJ
# NJJJα
# NJFJα
# NJJJN
# RJJRF
# FRFR
# Fα
# FNFαF
# RαFRJ
# ααRR
# FNJ
# FJNF
# FNFRF
# ααFRJ
# NJJJF
# NRJJF
# FααN
# RJJFF
# αJJFJ
# RNαRF
# FNN
# FRF
# FNFRN
# αJJFN
# RNααJ
# RJJFN
# αJJRN
# NNFJα
# αNFαJ
# RαFR
# NNFαF
# αJFFJ
# αJJRF
# NJJFF
# αJJRJ
# FJ
# FN
# RJJFR
# FRFJ
# RRFR
# NJJRN
# NJJRF
# RRN
# RJJRJ
# RRF
# αJFRJ
# αJJNJ
# RJJJN
# ααJN
# αNααJ
# RJJJF
# NJJFN
# RNαRJ
# αNαRN
# NαFN
# αNαRJ
# RααRJ

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_224)):
     if sum(freq >= fTC5_224[l] for freq in fTC5null_224[l]) < 1:
#         print(setTC5_224[l], fTC5_224[l], sum(freq >= fTC5_224[l] for freq in fTC5null_224[l]))
        print(setTC5_224[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# FαFJ
# RJJRF
# FNJ
# ααFRJ
# NJJJF
# RJJFF
# FRF
# RJJFN
# RαFR
# FJ
# RRFR
# RRN
# RJJJF
# NJJFN
# RααRJ

# %% [markdown]
#  # 3.225 (F) BPI - (J) FGEN- (N) JGS - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_225 = max(min(Date_BPI), min(Date_FGEN), min(Date_JGS), min(Date_SMC), min(Date_SCC))
end_225 = min(max(Date_BPI), max(Date_FGEN), max(Date_JGS), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
BPI_225_1 = Date_BPI.index(start_225)
BPI_225_2 = Date_BPI.index(end_225)

FGEN_225_1 = Date_FGEN.index(start_225)
FGEN_225_2 = Date_FGEN.index(end_225)

JGS_225_1 = Date_JGS.index(start_225)
JGS_225_2 = Date_JGS.index(end_225)

SMC_225_1 = Date_SMC.index(start_225)
SMC_225_2 = Date_SMC.index(end_225)

SCC_225_1 = Date_SCC.index(start_225)
SCC_225_2 = Date_SCC.index(end_225)

# %%
#save the shortened versions of closing prices
F225 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_225_1:BPI_225_2])
J225 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_225_1:FGEN_225_2])
N225 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_225_1:JGS_225_2])
Y225 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_225_1:SMC_225_2])
α225 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_225_1:SCC_225_2])

# %%
# import modules
import numpy as np
# import prices

F225 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J225 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N225 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y225 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α225 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_225 = []
st_225 = []
n = 1
while n < len(F225):
    sc_225 = ''
    if F225[n] > F225[n-1]:
        sc_225 = sc_225 + 'F'
    if J225[n] > J225[n-1]:
        sc_225 = sc_225 + 'J'
    if N225[n] > N225[n-1]:
        sc_225 = sc_225 + 'N'
    if Y225[n] > Y225[n-1]:
        sc_225 = sc_225 + 'Y'
    if α225[n] > α225[n-1]:
        sc_225 = sc_225 + 'α'
    if len(sc_225) > 0:
        st_225.append(sc_225)
    else:
        STC_225.append(st_225)
        st_225 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_225 = STC_225.count([])
# keep only non-empty spatio-temporal sequences
STC_225 = [ st_225 for st_225 in STC_225 if len(st_225) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_225 = len(F225)
lmax_225 = 0
for st_225 in STC_225:
    if len(st_225) < lmin_225:
        lmin_225 = len(st_225)
    if len(st_225) > lmax_225:
        lmax_225 = len(st_225)
        
# restrict spatio-temporal sequences to length-5
STC5_225 = [ st_225 for st_225 in STC_225 if len(st_225) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_225 = []
for n in range(len(STC5_225)):
    tc_225 = [ u for u in STC5_225[n][0] ]
    for k in range(1, len(STC5_225[n])):
        tc_225 = [ u+v for u in tc_225 for v in STC5_225[n][k] ]
    TC5_225 = TC5_225 + tc_225
setTC5_225 = list(set(TC5_225))

# get empirical frequencies
fTC5_225 = [ TC5_225.count(setTC5_225[l]) for l in range(len(setTC5_225)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_225 = [ [] for l in range(len(setTC5_225)) ]
for s in range(100):
    STC5null_225 = [ list(st_225) for st_225 in STC5_225]
    for st_225 in STC5null_225:
        np.random.shuffle(st_225)
    TC5null_225= []
    for n in range(len(STC5null_225)):
        tc_225 = [ u for u in STC5null_225[n][0] ]
        for k in range(1, len(STC5null_225[n])):
            tc_225 = [ u+v for u in tc_225 for v in STC5null_225[n][k] ]
        TC5null_225= TC5null_225+ tc_225
    for l in range(len(setTC5_225)):
        if TC5null_225.count(setTC5_225[l]) > 0:
            fTC5null_225[l].append(TC5null_225.count(setTC5_225[l]))
        else:
            fTC5null_225[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_225)):
     if sum(freq >= fTC5_225[l] for freq in fTC5null_225[l]) < 5:
#         print(setTC5_225[l], fTC5_225[l], sum(freq >= fTC5_225[l] for freq in fTC5null_225[l]))
        print(setTC5_225[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FYYY
# NYJJF
# FαYαF
# αYFNJ
# FNF
# NYJFF
# FYYα
# YYFYJ
# NNJJF
# FαFJ
# NYJJN
# YYαNα
# NYJNN
# YYFYY
# NYαNJ
# NJFαF
# FJYY
# NYFJF
# FJYN
# αYFNα
# YYFNα
# αJJαJ
# αYFNF
# NJJJα
# NJFJα
# NFFJF
# NJJJN
# FYFYF
# NYFNN
# NYJαF
# FYJ
# YYFNY
# FYFNJ
# αJFαJ
# NYFFF
# NNααF
# FNJ
# FJNF
# NYαYJ
# NJJJF
# NαYαF
# NNααN
# NJααF
# FJYJ
# FJNY
# αYFNN
# FαYY
# αJJFJ
# NNJJα
# NYFNJ
# NYYY
# NYFNF
# JYJαF
# NYJNF
# FYJNN
# JαYαF
# αYJ
# NJJαF
# FYJNF
# FαF
# NNFJF
# FYαYJ
# JNYαF
# JFYαF
# NNFJα
# JNαFN
# NYFJα
# YJJJN
# YJJJF
# NYFYF
# NYFJJ
# αYJαF
# NJFFF
# αYFαF
# αJFFJ
# YYFNJ
# NYNJN
# NJJFJ
# αYFNY
# αN
# JNααF
# FYFYJ
# NYJYN
# JJααF
# FJYα
# αYJNN
# NYFYJ
# NJFFJ
# FYYJ
# NYαJF
# αYFYJ
# NYFNα
# NYFαF
# FYFNN
# NYJJJ
# NYαNN
# FYFNF
# FFYY
# FJYαF
# JJJJF
# FNYαF
# NYNJJ
# FαYJ
# JJYαF
# NJFJF
# FYNY
# NYJYF
# YYJJF
# NYFYN

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_225)):
     if sum(freq >= fTC5_225[l] for freq in fTC5null_225[l]) < 1:
#         print(setTC5_225[l], fTC5_225[l], sum(freq >= fTC5_225[l] for freq in fTC5null_225[l]))
        print(setTC5_225[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# FYYY
# NYJJF
# FYYα
# NNJJF
# FJYY
# NYFJF
# NJJJα
# NYFNN
# NYJαF
# NNααF
# NJJJF
# NJααF
# FJYJ
# FJNY
# NYFNF
# JNYαF
# YJJJF
# NYJYN
# FJYα
# FYYJ
# FYFNF
# FNYαF
# JJYαF
# NJFJF
