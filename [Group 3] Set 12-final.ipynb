# %% [markdown]
# # One-Letter Words

# %%
# open the csv files
AP = open('AP.csv')
AC = open('AC.csv')
BPI = open('BPI.csv')
BLOOM = open('BLOOM.csv')
FGEN = open('FGEN.csv')
ICT = open('ICT.csv')
JGS = open('JGS.csv')
MEG = open('MEG.csv')
SMC = open('SMC.csv')
SCC = open('SCC.csv')

#initiFGENze the lists
Date_AP = []
ClosePrice_AP = []
Date_AC = []
ClosePrice_AC = []
Date_BPI = []
ClosePrice_BPI = []
Date_BLOOM = []
ClosePrice_BLOOM = []
Date_FGEN = []
ClosePrice_FGEN = []
Date_ICT = []
ClosePrice_ICT = []
Date_JGS = []
ClosePrice_JGS = []
Date_MEG = []
ClosePrice_MEG = []
Date_SMC = []
ClosePrice_SMC = []
Date_SCC = []
ClosePrice_SCC = []

#skip the header line
AP.readline()
AC.readline()
BPI.readline()
BLOOM.readline()
FGEN.readline()
ICT.readline()
JGS.readline()
MEG.readline()
SMC.readline()
SCC.readline()

#go through the files line by line
for line in AP:
    sline = line.strip().split(',')
    Date_AP.append(sline[0])
    ClosePrice_AP.append(float(sline[1]))
    
for line in AC:
    sline = line.strip().split(',')
    Date_AC.append(sline[0])
    ClosePrice_AC.append(float(sline[1]))
    
for line in BPI:
    sline = line.strip().split(',')
    Date_BPI.append(sline[0])
    ClosePrice_BPI.append(float(sline[1]))
    
for line in BLOOM:
    sline = line.strip().split(',')
    Date_BLOOM.append(sline[0])
    ClosePrice_BLOOM.append(float(sline[1]))
    
for line in FGEN:
    sline = line.strip().split(',')
    Date_FGEN.append(sline[0])
    ClosePrice_FGEN.append(float(sline[1]))
    
for line in ICT:
    sline = line.strip().split(',')
    Date_ICT.append(sline[0])
    ClosePrice_ICT.append(float(sline[1]))
    
for line in JGS:
    sline = line.strip().split(',')
    Date_JGS.append(sline[0])
    ClosePrice_JGS.append(float(sline[1]))
    
for line in MEG:
    sline = line.strip().split(',')
    Date_MEG.append(sline[0])
    ClosePrice_MEG.append(float(sline[1]))
    
for line in SMC:
    sline = line.strip().split(',')
    Date_SMC.append(sline[0])
    ClosePrice_SMC.append(float(sline[1]))
        
for line in SCC:
    sline = line.strip().split(',')
    Date_SCC.append(sline[0])
    ClosePrice_SCC.append(float(sline[1]))


#close files
AP.close()
AC.close()
BPI.close()
BLOOM.close()
FGEN.close()
ICT.close()
JGS.close()
MEG.close()
SMC.close()
SCC.close()# One-Letter Words

# %%
import numpy as np
import datetime

# %%
# convert dates into datetime structure
for n in range(len(Date_AP)):
    Date_AP[n] = datetime.datetime.strptime(Date_AP[n], '%m/%d/%y').date()

for n in range(len(Date_AC)):
    Date_AC[n] = datetime.datetime.strptime(Date_AC[n], '%m/%d/%y').date()
    
for n in range(len(Date_BPI)):
    Date_BPI[n] = datetime.datetime.strptime(Date_BPI[n], '%m/%d/%y').date()

for n in range(len(Date_BLOOM)):
    Date_BLOOM[n] = datetime.datetime.strptime(Date_BLOOM[n], '%m/%d/%y').date()
    
for n in range(len(Date_FGEN)):
    Date_FGEN[n] = datetime.datetime.strptime(Date_FGEN[n], '%m/%d/%y').date()

for n in range(len(Date_ICT)):
    Date_ICT[n] = datetime.datetime.strptime(Date_ICT[n], '%m/%d/%y').date()
    
for n in range(len(Date_JGS)):
    Date_JGS[n] = datetime.datetime.strptime(Date_JGS[n], '%m/%d/%y').date()

for n in range(len(Date_MEG)):
    Date_MEG[n] = datetime.datetime.strptime(Date_MEG[n], '%m/%d/%y').date()
    
for n in range(len(Date_SMC)):
    Date_SMC[n] = datetime.datetime.strptime(Date_SMC[n], '%m/%d/%y').date()

for n in range(len(Date_SCC)):
    Date_SCC[n] = datetime.datetime.strptime(Date_SCC[n], '%m/%d/%y').date()
    
# save Date and ClosePrice
np.save('APDate.npy', Date_AP)
np.save('APClosePrice.npy', ClosePrice_AP)
np.save('ACDate.npy', Date_AC)
np.save('ACClosePrice.npy', ClosePrice_AC)
np.save('BPIDate.npy', Date_BPI)
np.save('BPIClosePrice.npy', ClosePrice_BPI)
np.save('BLOOMDate.npy', Date_BLOOM)
np.save('BLOOMClosePrice.npy', ClosePrice_BLOOM)
np.save('FGENDate.npy', Date_FGEN)
np.save('FGENClosePrice.npy', ClosePrice_FGEN)
np.save('ICTDate.npy', Date_ICT)
np.save('ICTClosePrice.npy', ClosePrice_ICT)
np.save('JGSDate.npy', Date_JGS)
np.save('JGSClosePrice.npy', ClosePrice_JGS)
np.save('MEGDate.npy', Date_MEG)
np.save('MEGClosePrice.npy', ClosePrice_MEG)
np.save('SMCDate.npy', Date_SMC)
np.save('SMCClosePrice.npy', ClosePrice_SMC)
np.save('SCCDate.npy', Date_SCC)
np.save('SCCClosePrice.npy', ClosePrice_SCC)

# %% [markdown]
# # Five-letter Words

# %% [markdown]
# # 3.166 (D) AC - (H) BLOOM - (J) FGEN - (N) JGS - (R) MEG

# %%
#extract overlapping dates
start_166 = max(min(Date_AC), min(Date_BLOOM), min(Date_FGEN), min(Date_JGS), min(Date_MEG))
end_166 = min(max(Date_AC), max(Date_BLOOM), max(Date_FGEN), max(Date_JGS), max(Date_MEG))

# %%
#shorten the closing prices
AC_166_1 = Date_AC.index(start_166)
AC_166_2 = Date_AC.index(end_166)

BLOOM_166_1 = Date_BLOOM.index(start_166)
BLOOM_166_2 = Date_BLOOM.index(end_166)

FGEN_166_1 = Date_FGEN.index(start_166)
FGEN_166_2 = Date_FGEN.index(end_166)

JGS_166_1 = Date_JGS.index(start_166)
JGS_166_2 = Date_JGS.index(end_166)

MEG_166_1 = Date_MEG.index(start_166)
MEG_166_2 = Date_MEG.index(end_166)

# %%
#save the shortened versions of closing prices
D166 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_166_1:AC_166_2])
H166 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_166_1:BLOOM_166_2])
J166 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_166_1:FGEN_166_2])
N166 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_166_1:JGS_166_2])
R166 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_166_1:MEG_166_2])

# %%
# import modules
import numpy as np
# import prices

D166 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H166 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J166 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N166 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R166 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_166 = []
st_166 = []
n = 1
while n < len(D166):
    sc_166 = ''
    if D166[n] > D166[n-1]:
        sc_166 = sc_166 + 'D'
    if H166[n] > H166[n-1]:
        sc_166 = sc_166 + 'H'
    if J166[n] > J166[n-1]:
        sc_166 = sc_166 + 'J'
    if N166[n] > N166[n-1]:
        sc_166 = sc_166 + 'N'
    if R166[n] > R166[n-1]:
        sc_166 = sc_166 + 'R'
    if len(sc_166) > 0:
        st_166.append(sc_166)
    else:
        STC_166.append(st_166)
        st_166 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_166 = STC_166.count([])
# keep only non-empty spatio-temporal sequences
STC_166 = [ st_166 for st_166 in STC_166 if len(st_166) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_166 = len(D166)
lmax_166 = 0
for st_166 in STC_166:
    if len(st_166) < lmin_166:
        lmin_166 = len(st_166)
    if len(st_166) > lmax_166:
        lmax_166 = len(st_166)
        
# restrict spatio-temporal sequences to length-5
STC5_166 = [ st_166 for st_166 in STC_166 if len(st_166) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_166 = []
for n in range(len(STC5_166)):
    tc_166 = [ u for u in STC5_166[n][0] ]
    for k in range(1, len(STC5_166[n])):
        tc_166 = [ u+v for u in tc_166 for v in STC5_166[n][k] ]
    TC5_166 = TC5_166 + tc_166
setTC5_166 = list(set(TC5_166))

# get empirical frequencies
fTC5_166 = [ TC5_166.count(setTC5_166[l]) for l in range(len(setTC5_166)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_166 = [ [] for l in range(len(setTC5_166)) ]
for s in range(100):
    STC5null_166 = [ list(st_166) for st_166 in STC5_166]
    for st_166 in STC5null_166:
        np.random.shuffle(st_166)
    TC5null_166= []
    for n in range(len(STC5null_166)):
        tc_166 = [ u for u in STC5null_166[n][0] ]
        for k in range(1, len(STC5null_166[n])):
            tc_166 = [ u+v for u in tc_166 for v in STC5null_166[n][k] ]
        TC5null_166= TC5null_166+ tc_166
    for l in range(len(setTC5_166)):
        if TC5null_166.count(setTC5_166[l]) > 0:
            fTC5null_166[l].append(TC5null_166.count(setTC5_166[l]))
        else:
            fTC5null_166[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_166)):
     if sum(freq >= fTC5_166[l] for freq in fTC5null_166[l]) < 5:
#         print(setTC5_166[l], fTC5_166[l], sum(freq >= fTC5_166[l] for freq in fTC5null_166[l]))
        print(setTC5_166[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# DHDRJ
# RHHNJ
# NJJHR
# HN
# DDNRH
# RDJJN
# DDDN
# DJJRH
# DRNRH
# DJJDJ
# HHJNJ
# DDDJ
# DRNRN
# RJJDR
# DJDHR
# DJJDR
# DRDRH
# DDDRH
# RJJHR
# DDRRH
# DJJHR
# DJRDR
# RHDRH
# NDRJ
# DJNNH
# JDDJ
# NHNH
# DNNRH
# RDRJ
# DJJDH
# NRJJR
# DHHRH
# DJDNH
# DJNDH
# DDHRH
# NDDN
# NJDHH
# DRDNR
# DJJJJ
# DRRRH
# DRNDH
# HHRNJ
# DJRDH
# DRHRH
# NNNDJ
# DJRRH
# DDDNR
# HHHNH
# DNNDH
# RJJJN
# JHHJ
# JDRJ
# DHRNJ
# DJJNH
# RRDRH
# DRDDH
# DJHRH
# DHNRH
# HJ
# NDDJ
# HHDRH
# DHDR
# NDJJN
# RJDHH
# NHRJ
# DHJNJ
# RJJRR
# RHHNH
# DJDRH
# NNNDH
# JHRN
# DDNDH
# JNHJ
# RJDDN
# DDRRR
# DHHNH
# RJHHH
# DJDDH
# DJHHH
# DJJHH
# DJDNR
# RJ
# DJDHH
# DDRJ
# NHDR
# JHDD
# HHDRJ
# DJDDR
# DNNRJ
# DHJJJ
# DRRDH
# NJDNH
# NJJNH
# DJNRH
# DDRDH
# DJJRR

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_166)):
     if sum(freq >= fTC5_166[l] for freq in fTC5null_166[l]) < 1:
#         print(setTC5_166[l], fTC5_166[l], sum(freq >= fTC5_166[l] for freq in fTC5null_166[l]))
        print(setTC5_166[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# DDDN
# DJJDR
# DDDRH
# DDRRH
# DJJHR
# DJJDH
# NRJJR
# DJDNH
# DRRRH
# DHRNJ
# RJJRR
# RHHNH
# DDRRR
# DHHNH
# DJDHH
# DDRJ
# DJDDR

# %% [markdown]
# # 3.167 (D) AC - (H) BLOOM - (J) FGEN - (N) JGS - (Y) SMC

# %%
#extract overlapping dates
start_167 = max(min(Date_AC), min(Date_BLOOM), min(Date_FGEN), min(Date_JGS), min(Date_SMC))
end_167 = min(max(Date_AC), max(Date_BLOOM), max(Date_FGEN), max(Date_JGS), max(Date_SMC))

# %%
#shorten the closing prices
AC_167_1 = Date_AC.index(start_167)
AC_167_2 = Date_AC.index(end_167)

BLOOM_167_1 = Date_BLOOM.index(start_167)
BLOOM_167_2 = Date_BLOOM.index(end_167)

FGEN_167_1 = Date_FGEN.index(start_167)
FGEN_167_2 = Date_FGEN.index(end_167)

JGS_167_1 = Date_JGS.index(start_167)
JGS_167_2 = Date_JGS.index(end_167)

SMC_167_1 = Date_SMC.index(start_167)
SMC_167_2 = Date_SMC.index(end_167)

# %%
#save the shortened versions of closing prices
D167 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_167_1:AC_167_2])
H167 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_167_1:BLOOM_167_2])
J167 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_167_1:FGEN_167_2])
N167 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_167_1:JGS_167_2])
Y167 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_167_1:SMC_167_2])

# %%
# import modules
import numpy as np
# import prices

D167 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H167 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J167 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N167 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y167 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_167 = []
st_167 = []
n = 1
while n < len(D167):
    sc_167 = ''
    if D167[n] > D167[n-1]:
        sc_167 = sc_167 + 'D'
    if H167[n] > H167[n-1]:
        sc_167 = sc_167 + 'H'
    if J167[n] > J167[n-1]:
        sc_167 = sc_167 + 'J'
    if N167[n] > N167[n-1]:
        sc_167 = sc_167 + 'N'
    if Y167[n] > Y167[n-1]:
        sc_167 = sc_167 + 'Y'
    if len(sc_167) > 0:
        st_167.append(sc_167)
    else:
        STC_167.append(st_167)
        st_167 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_167 = STC_167.count([])
# keep only non-empty spatio-temporal sequences
STC_167 = [ st_167 for st_167 in STC_167 if len(st_167) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_167 = len(D167)
lmax_167 = 0
for st_167 in STC_167:
    if len(st_167) < lmin_167:
        lmin_167 = len(st_167)
    if len(st_167) > lmax_167:
        lmax_167 = len(st_167)
        
# restrict spatio-temporal sequences to length-5
STC5_167 = [ st_167 for st_167 in STC_167 if len(st_167) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_167 = []
for n in range(len(STC5_167)):
    tc_167 = [ u for u in STC5_167[n][0] ]
    for k in range(1, len(STC5_167[n])):
        tc_167 = [ u+v for u in tc_167 for v in STC5_167[n][k] ]
    TC5_167 = TC5_167 + tc_167
setTC5_167 = list(set(TC5_167))

# get empirical frequencies
fTC5_167 = [ TC5_167.count(setTC5_167[l]) for l in range(len(setTC5_167)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_167 = [ [] for l in range(len(setTC5_167)) ]
for s in range(100):
    STC5null_167 = [ list(st_167) for st_167 in STC5_167]
    for st_167 in STC5null_167:
        np.random.shuffle(st_167)
    TC5null_167= []
    for n in range(len(STC5null_167)):
        tc_167 = [ u for u in STC5null_167[n][0] ]
        for k in range(1, len(STC5null_167[n])):
            tc_167 = [ u+v for u in tc_167 for v in STC5null_167[n][k] ]
        TC5null_167= TC5null_167+ tc_167
    for l in range(len(setTC5_167)):
        if TC5null_167.count(setTC5_167[l]) > 0:
            fTC5null_167[l].append(TC5null_167.count(setTC5_167[l]))
        else:
            fTC5null_167[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_167)):
     if sum(freq >= fTC5_167[l] for freq in fTC5null_167[l]) < 5:
#         print(setTC5_167[l], fTC5_167[l], sum(freq >= fTC5_167[l] for freq in fTC5null_167[l]))
        print(setTC5_167[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# DDNJJ
# HHHJ
# NYNDH
# JHYJJ
# NHYJJ
# DDYHN
# DHYNH
# DHYDH
# NJYN
# DJNJH
# DJNNH
# JJYJJ
# DHYHH
# DNDHH
# NNDN
# HJYY
# DJDNH
# DJNDH
# NDDN
# YDNDH
# JYDN
# YDYYH
# YYYDN
# DYNDH
# DNNDH
# HJYN
# JHHJ
# JJD
# NDNJJ
# JDYJJ
# JHDN
# DDHDN
# JDYHJ
# JHJJ
# DYHDH
# NDNYJ
# DHYHY
# JJY
# DYNN
# YYDDN
# HJDYY
# DDYJJ
# DDDHJ
# NDDYJ
# DDNDH
# DDYDH
# DDYHJ
# DJYHJ
# DHHNH
# NHDN
# DYJDH
# NDJJJ
# DDDYN
# DNDNH
# YYDN
# DJDHH
# JHDD
# DJNHH
# NJDYH

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_167)):
     if sum(freq >= fTC5_167[l] for freq in fTC5null_167[l]) < 1:
#         print(setTC5_167[l], fTC5_167[l], sum(freq >= fTC5_167[l] for freq in fTC5null_167[l]))
        print(setTC5_167[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# DHYHH
# HJYY
# DYNDH
# JHHJ
# JDYJJ
# DYHDH
# HJDYY
# NDDYJ

# %% [markdown]
# # 3.168 (D) AC - (H) BLOOM - (J) FGEN - (N) JGS - (α) SCC

# %%
#extract overlapping dates
start_168 = max(min(Date_AC), min(Date_BLOOM), min(Date_FGEN), min(Date_JGS), min(Date_SCC))
end_168 = min(max(Date_AC), max(Date_BLOOM), max(Date_FGEN), max(Date_JGS), max(Date_SCC))

# %%
#shorten the closing prices
AC_168_1 = Date_AC.index(start_168)
AC_168_2 = Date_AC.index(end_168)

BLOOM_168_1 = Date_BLOOM.index(start_168)
BLOOM_168_2 = Date_BLOOM.index(end_168)

FGEN_168_1 = Date_FGEN.index(start_168)
FGEN_168_2 = Date_FGEN.index(end_168)

JGS_168_1 = Date_JGS.index(start_168)
JGS_168_2 = Date_JGS.index(end_168)

SCC_168_1 = Date_SCC.index(start_168)
SCC_168_2 = Date_SCC.index(end_168)

# %%
#save the shortened versions of closing prices
D168 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_168_1:AC_168_2])
H168 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_168_1:BLOOM_168_2])
J168 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_168_1:FGEN_168_2])
N168 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_168_1:JGS_168_2])
α168 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_168_1:SCC_168_2])

# %%
# import modules
import numpy as np
# import prices

D168 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H168 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J168 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N168 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
α168 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_168 = []
st_168 = []
n = 1
while n < len(D168):
    sc_168 = ''
    if D168[n] > D168[n-1]:
        sc_168 = sc_168 + 'D'
    if H168[n] > H168[n-1]:
        sc_168 = sc_168 + 'H'
    if J168[n] > J168[n-1]:
        sc_168 = sc_168 + 'J'
    if N168[n] > N168[n-1]:
        sc_168 = sc_168 + 'N'
    if α168[n] > α168[n-1]:
        sc_168 = sc_168 + 'α'
    if len(sc_168) > 0:
        st_168.append(sc_168)
    else:
        STC_168.append(st_168)
        st_168 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_168 = STC_168.count([])
# keep only non-empty spatio-temporal sequences
STC_168 = [ st_168 for st_168 in STC_168 if len(st_168) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_168 = len(D168)
lmax_168 = 0
for st_168 in STC_168:
    if len(st_168) < lmin_168:
        lmin_168 = len(st_168)
    if len(st_168) > lmax_168:
        lmax_168 = len(st_168)
        
# restrict spatio-temporal sequences to length-5
STC5_168 = [ st_168 for st_168 in STC_168 if len(st_168) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_168 = []
for n in range(len(STC5_168)):
    tc_168 = [ u for u in STC5_168[n][0] ]
    for k in range(1, len(STC5_168[n])):
        tc_168 = [ u+v for u in tc_168 for v in STC5_168[n][k] ]
    TC5_168 = TC5_168 + tc_168
setTC5_168 = list(set(TC5_168))

# get empirical frequencies
fTC5_168 = [ TC5_168.count(setTC5_168[l]) for l in range(len(setTC5_168)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_168 = [ [] for l in range(len(setTC5_168)) ]
for s in range(100):
    STC5null_168 = [ list(st_168) for st_168 in STC5_168]
    for st_168 in STC5null_168:
        np.random.shuffle(st_168)
    TC5null_168= []
    for n in range(len(STC5null_168)):
        tc_168 = [ u for u in STC5null_168[n][0] ]
        for k in range(1, len(STC5null_168[n])):
            tc_168 = [ u+v for u in tc_168 for v in STC5null_168[n][k] ]
        TC5null_168= TC5null_168+ tc_168
    for l in range(len(setTC5_168)):
        if TC5null_168.count(setTC5_168[l]) > 0:
            fTC5null_168[l].append(TC5null_168.count(setTC5_168[l]))
        else:
            fTC5null_168[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_168)):
     if sum(freq >= fTC5_168[l] for freq in fTC5null_168[l]) < 5:
#         print(setTC5_168[l], fTC5_168[l], sum(freq >= fTC5_168[l] for freq in fTC5null_168[l]))
        print(setTC5_168[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# DJNDJ
# ααNDH
# JαDHJ
# DJJDJ
# HHJNJ
# DDJJN
# αDNHJ
# NDDα
# DHNαJ
# DJNJH
# DJNNH
# JαNHJ
# NHDH
# NNDN
# DJJDH
# ααNHJ
# αJJHJ
# ααNNH
# HαDDH
# JDJαα
# JDNH
# DJNDH
# JJJα
# HαHHJ
# NDDN
# JDJαD
# ααNH
# ααNNJ
# DJJJJ
# NHDJ
# αHJJJ
# NNNDJ
# αDDJ
# DJJJH
# NDα
# DDNH
# DNNDH
# HHDαJ
# αNααJ
# αHNDJ
# HDJαD
# JαNH
# ααNαJ
# NDNJJ
# DJJNH
# JαNHH
# NJDα
# NαNα
# NJNHH
# NαNDH
# NNNDα
# DHNNH
# NNDα
# HJ
# DHNDH
# NDDJ
# αJNNH
# NNDJ
# ααNJJ
# NDJJN
# NHDα
# ααDα
# DHNαH
# NJNDH
# NNNDH
# DαNH
# NDNDα
# NJNNH
# DJJαα
# ααNDJ
# DDNDH
# NNNαD
# DDNαH
# DJααH
# NαNαJ
# NαDα
# αNJJJ
# NαNDJ
# DJDDH
# DJJHH
# DJDHH
# αHααJ
# HαJHH
# JJDα
# DJNHH
# DHJJJ
# DαNNH
# αJNHH
# αHNαJ
# DJNαH

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_168)):
     if sum(freq >= fTC5_168[l] for freq in fTC5null_168[l]) < 1:
#         print(setTC5_168[l], fTC5_168[l], sum(freq >= fTC5_168[l] for freq in fTC5null_168[l]))
        print(setTC5_168[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# DJNJH
# DJNNH
# DJJDH
# DJNDH
# JJJα
# αHJJJ
# DNNDH
# DJJNH
# ααNDJ
# NαNDJ
# DJDHH
# JJDα
# DJNHH

# %% [markdown]
# # 3.169 (D) AC - (H) BLOOM - (J) FGEN - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_169 = max(min(Date_AC), min(Date_BLOOM), min(Date_FGEN), min(Date_MEG), min(Date_SMC))
end_169 = min(max(Date_AC), max(Date_BLOOM), max(Date_FGEN), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
AC_169_1 = Date_AC.index(start_169)
AC_169_2 = Date_AC.index(end_169)

BLOOM_169_1 = Date_BLOOM.index(start_169)
BLOOM_169_2 = Date_BLOOM.index(end_169)

FGEN_169_1 = Date_FGEN.index(start_169)
FGEN_169_2 = Date_FGEN.index(end_169)

MEG_169_1 = Date_MEG.index(start_169)
MEG_169_2 = Date_MEG.index(end_169)

SMC_169_1 = Date_SMC.index(start_169)
SMC_169_2 = Date_SMC.index(end_169)

# %%
#save the shortened versions of closing prices
D169 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_169_1:AC_169_2])
H169 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_169_1:BLOOM_169_2])
J169 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_169_1:FGEN_169_2])
R169 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_169_1:MEG_169_2])
Y169 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_169_1:SMC_169_2])

# %%
# import modules
import numpy as np
# import prices

D169 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H169 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J169 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
R169 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y169 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_169 = []
st_169 = []
n = 1
while n < len(D169):
    sc_169 = ''
    if D169[n] > D169[n-1]:
        sc_169 = sc_169 + 'D'
    if H169[n] > H169[n-1]:
        sc_169 = sc_169 + 'H'
    if J169[n] > J169[n-1]:
        sc_169 = sc_169 + 'J'
    if R169[n] > R169[n-1]:
        sc_169 = sc_169 + 'R'
    if Y169[n] > Y169[n-1]:
        sc_169 = sc_169 + 'Y'
    if len(sc_169) > 0:
        st_169.append(sc_169)
    else:
        STC_169.append(st_169)
        st_169 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_169 = STC_169.count([])
# keep only non-empty spatio-temporal sequences
STC_169 = [ st_169 for st_169 in STC_169 if len(st_169) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_169 = len(D169)
lmax_169 = 0
for st_169 in STC_169:
    if len(st_169) < lmin_169:
        lmin_169 = len(st_169)
    if len(st_169) > lmax_169:
        lmax_169 = len(st_169)
        
# restrict spatio-temporal sequences to length-5
STC5_169 = [ st_169 for st_169 in STC_169 if len(st_169) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_169 = []
for n in range(len(STC5_169)):
    tc_169 = [ u for u in STC5_169[n][0] ]
    for k in range(1, len(STC5_169[n])):
        tc_169 = [ u+v for u in tc_169 for v in STC5_169[n][k] ]
    TC5_169 = TC5_169 + tc_169
setTC5_169 = list(set(TC5_169))

# get empirical frequencies
fTC5_169 = [ TC5_169.count(setTC5_169[l]) for l in range(len(setTC5_169)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_169 = [ [] for l in range(len(setTC5_169)) ]
for s in range(100):
    STC5null_169 = [ list(st_169) for st_169 in STC5_169]
    for st_169 in STC5null_169:
        np.random.shuffle(st_169)
    TC5null_169= []
    for n in range(len(STC5null_169)):
        tc_169 = [ u for u in STC5null_169[n][0] ]
        for k in range(1, len(STC5null_169[n])):
            tc_169 = [ u+v for u in tc_169 for v in STC5null_169[n][k] ]
        TC5null_169= TC5null_169+ tc_169
    for l in range(len(setTC5_169)):
        if TC5null_169.count(setTC5_169[l]) > 0:
            fTC5null_169[l].append(TC5null_169.count(setTC5_169[l]))
        else:
            fTC5null_169[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_169)):
     if sum(freq >= fTC5_169[l] for freq in fTC5null_169[l]) < 5:
#         print(setTC5_169[l], fTC5_169[l], sum(freq >= fTC5_169[l] for freq in fTC5null_169[l]))
        print(setTC5_169[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# YHDDY
# DYRYH
# YHRRH
# RHYRH
# DYRRH
# YRDDY
# YHRDY
# DJJHR
# RHDRH
# HHYRY
# HR
# YHYRY
# RYJ
# JDJR
# YRRDD
# YHDDH
# YRJDY
# HHRRJ
# DDDDH
# DDJR
# DRRRR
# HHYRH
# YHDRH
# JHDYH
# DRRYH
# DRDYH
# DJRRR
# YJDDY
# HJDHJ
# YHRDJ
# JDYJJ
# DDRH
# RHDRJ
# YHRR
# RHDDH
# DYYY
# YYJDY
# RHDHJ
# YRRDJ
# HHRJJ
# DHDR
# DJHJH
# YRDRY
# YDDDY
# RJDHH
# DDDYH
# YHRDH
# YRHDJ
# YRRDY
# YYJYD
# HHDHJ
# DHDYH
# YHHRH
# DDRRR
# YRDYY
# RJHHH
# DYRJJ
# DJHHH
# HYY
# HHRRD
# DDRJ
# YHDR
# YHYRH
# HHRJ
# DDJH
# RHDYH

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_169)):
     if sum(freq >= fTC5_169[l] for freq in fTC5null_169[l]) < 1:
#         print(setTC5_169[l], fTC5_169[l], sum(freq >= fTC5_169[l] for freq in fTC5null_169[l]))
        print(setTC5_169[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# YRDDY
# YHRDY
# RHDDH
# YRRDY

# %% [markdown]
# # 3.170 (D) AC - (H) BLOOM - (J) FGEN - (R) MEG - (α) SCC

# %%
#extract overlapping dates
start_170 = max(min(Date_AC), min(Date_BLOOM), min(Date_FGEN), min(Date_MEG), min(Date_SCC))
end_170 = min(max(Date_AC), max(Date_BLOOM), max(Date_FGEN), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
AC_170_1 = Date_AC.index(start_170)
AC_170_2 = Date_AC.index(end_170)

BLOOM_170_1 = Date_BLOOM.index(start_170)
BLOOM_170_2 = Date_BLOOM.index(end_170)

FGEN_170_1 = Date_FGEN.index(start_170)
FGEN_170_2 = Date_FGEN.index(end_170)

MEG_170_1 = Date_MEG.index(start_170)
MEG_170_2 = Date_MEG.index(end_170)

SCC_170_1 = Date_SCC.index(start_170)
SCC_170_2 = Date_SCC.index(end_170)

# %%
#save the shortened versions of closing prices
D170 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_170_1:AC_170_2])
H170 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_170_1:BLOOM_170_2])
J170 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_170_1:FGEN_170_2])
R170 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_170_1:MEG_170_2])
α170 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_170_1:SCC_170_2])

# %%
# import modules
import numpy as np
# import prices

D170 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H170 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J170 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
R170 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α170 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_170 = []
st_170 = []
n = 1
while n < len(D170):
    sc_170 = ''
    if D170[n] > D170[n-1]:
        sc_170 = sc_170 + 'D'
    if H170[n] > H170[n-1]:
        sc_170 = sc_170 + 'H'
    if J170[n] > J170[n-1]:
        sc_170 = sc_170 + 'J'
    if R170[n] > R170[n-1]:
        sc_170 = sc_170 + 'R'
    if α170[n] > α170[n-1]:
        sc_170 = sc_170 + 'α'
    if len(sc_170) > 0:
        st_170.append(sc_170)
    else:
        STC_170.append(st_170)
        st_170 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_170 = STC_170.count([])
# keep only non-empty spatio-temporal sequences
STC_170 = [ st_170 for st_170 in STC_170 if len(st_170) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_170 = len(D170)
lmax_170 = 0
for st_170 in STC_170:
    if len(st_170) < lmin_170:
        lmin_170 = len(st_170)
    if len(st_170) > lmax_170:
        lmax_170 = len(st_170)
        
# restrict spatio-temporal sequences to length-5
STC5_170 = [ st_170 for st_170 in STC_170 if len(st_170) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_170 = []
for n in range(len(STC5_170)):
    tc_170 = [ u for u in STC5_170[n][0] ]
    for k in range(1, len(STC5_170[n])):
        tc_170 = [ u+v for u in tc_170 for v in STC5_170[n][k] ]
    TC5_170 = TC5_170 + tc_170
setTC5_170 = list(set(TC5_170))

# get empirical frequencies
fTC5_170 = [ TC5_170.count(setTC5_170[l]) for l in range(len(setTC5_170)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_170 = [ [] for l in range(len(setTC5_170)) ]
for s in range(100):
    STC5null_170 = [ list(st_170) for st_170 in STC5_170]
    for st_170 in STC5null_170:
        np.random.shuffle(st_170)
    TC5null_170= []
    for n in range(len(STC5null_170)):
        tc_170 = [ u for u in STC5null_170[n][0] ]
        for k in range(1, len(STC5null_170[n])):
            tc_170 = [ u+v for u in tc_170 for v in STC5null_170[n][k] ]
        TC5null_170= TC5null_170+ tc_170
    for l in range(len(setTC5_170)):
        if TC5null_170.count(setTC5_170[l]) > 0:
            fTC5null_170[l].append(TC5null_170.count(setTC5_170[l]))
        else:
            fTC5null_170[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_170)):
     if sum(freq >= fTC5_170[l] for freq in fTC5null_170[l]) < 5:
#         print(setTC5_170[l], fTC5_170[l], sum(freq >= fTC5_170[l] for freq in fTC5null_170[l]))
        print(setTC5_170[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# RRHαα
# ααJR
# DDJRD
# DHDRJ
# RHJJJ
# αJJHR
# DJαJR
# αDDRH
# DJJRH
# αDDRJ
# αDDR
# DJJDJ
# DDDJ
# JRJH
# αHDαH
# DDDRH
# HHHRR
# HRαRα
# DDRRH
# αHDDH
# αRααJ
# DJJDH
# RααRD
# JDααα
# JDJαα
# DRJRH
# HDDRH
# RDαRD
# DJJJJ
# JDRH
# HHHαJ
# αHJJJ
# αDDαH
# αJJJJ
# αRHDJ
# αDDJ
# DJRRH
# HHJJJ
# HHHαD
# HHDαJ
# RRHDα
# JDRJ
# RJD
# DDRH
# RHDRJ
# HHJRD
# ααJD
# HDαRα
# HHJRR
# αDRR
# RRHαJ
# αDRH
# HHJRJ
# RDHαα
# JDRR
# HHDRH
# RRD
# αJJDJ
# HDHRR
# HHαRJ
# DRαRD
# DDαRR
# HHJαJ
# αHDDJ
# αRJJR
# HHDRD
# RJJRR
# RαJH
# DJJRα
# DDRR
# DDαRD
# αDDDH
# JHDRJ
# HJαJα
# HHJαR
# ααJH
# JDαH
# DDRRR
# JDJHD
# αDRJ
# DDJRR
# HHDRα
# HHHRJ
# HHαRα
# DDRJ
# HHDRJ
# HJHαJ
# DHJJJ
# JDHαα
# DJJRR
# DJRJα
# HHDαD

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_170)):
     if sum(freq >= fTC5_170[l] for freq in fTC5null_170[l]) < 1:
#         print(setTC5_170[l], fTC5_170[l], sum(freq >= fTC5_170[l] for freq in fTC5null_170[l]))
        print(setTC5_170[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# αDDRH
# DJJRH
# JRJH
# αHDαH
# JDRH
# αHJJJ
# HHJJJ
# DDRH
# HHJRR
# αDRR
# HHJRJ
# DDαRR
# JHDRJ
# JDJHD
# αDRJ
# DDRJ
# HHDRJ

# %% [markdown]
# # 3.171 (D) AC - (H) BLOOM - (J) FGEN - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_171 = max(min(Date_AC), min(Date_BLOOM), min(Date_FGEN), min(Date_SMC), min(Date_SCC))
end_171 = min(max(Date_AC), max(Date_BLOOM), max(Date_FGEN), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
AC_171_1 = Date_AC.index(start_171)
AC_171_2 = Date_AC.index(end_171)

BLOOM_171_1 = Date_BLOOM.index(start_171)
BLOOM_171_2 = Date_BLOOM.index(end_171)

FGEN_171_1 = Date_FGEN.index(start_171)
FGEN_171_2 = Date_FGEN.index(end_171)

SMC_171_1 = Date_SMC.index(start_171)
SMC_171_2 = Date_SMC.index(end_171)

SCC_171_1 = Date_SCC.index(start_171)
SCC_171_2 = Date_SCC.index(end_171)

# %%
#save the shortened versions of closing prices
D171 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_171_1:AC_171_2])
H171 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_171_1:BLOOM_171_2])
J171 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_171_1:FGEN_171_2])
Y171 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_171_1:SMC_171_2])
α171 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_171_1:SCC_171_2])

# %%
# import modules
import numpy as np
# import prices

D171 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H171 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J171 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
Y171 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α171 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_171 = []
st_171 = []
n = 1
while n < len(D171):
    sc_171 = ''
    if D171[n] > D171[n-1]:
        sc_171 = sc_171 + 'D'
    if H171[n] > H171[n-1]:
        sc_171 = sc_171 + 'H'
    if J171[n] > J171[n-1]:
        sc_171 = sc_171 + 'J'
    if Y171[n] > Y171[n-1]:
        sc_171 = sc_171 + 'Y'
    if α171[n] > α171[n-1]:
        sc_171 = sc_171 + 'α'
    if len(sc_171) > 0:
        st_171.append(sc_171)
    else:
        STC_171.append(st_171)
        st_171 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_171 = STC_171.count([])
# keep only non-empty spatio-temporal sequences
STC_171 = [ st_171 for st_171 in STC_171 if len(st_171) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_171 = len(D171)
lmax_171 = 0
for st_171 in STC_171:
    if len(st_171) < lmin_171:
        lmin_171 = len(st_171)
    if len(st_171) > lmax_171:
        lmax_171 = len(st_171)
        
# restrict spatio-temporal sequences to length-5
STC5_171 = [ st_171 for st_171 in STC_171 if len(st_171) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_171 = []
for n in range(len(STC5_171)):
    tc_171 = [ u for u in STC5_171[n][0] ]
    for k in range(1, len(STC5_171[n])):
        tc_171 = [ u+v for u in tc_171 for v in STC5_171[n][k] ]
    TC5_171 = TC5_171 + tc_171
setTC5_171 = list(set(TC5_171))

# get empirical frequencies
fTC5_171 = [ TC5_171.count(setTC5_171[l]) for l in range(len(setTC5_171)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_171 = [ [] for l in range(len(setTC5_171)) ]
for s in range(100):
    STC5null_171 = [ list(st_171) for st_171 in STC5_171]
    for st_171 in STC5null_171:
        np.random.shuffle(st_171)
    TC5null_171= []
    for n in range(len(STC5null_171)):
        tc_171 = [ u for u in STC5null_171[n][0] ]
        for k in range(1, len(STC5null_171[n])):
            tc_171 = [ u+v for u in tc_171 for v in STC5null_171[n][k] ]
        TC5null_171= TC5null_171+ tc_171
    for l in range(len(setTC5_171)):
        if TC5null_171.count(setTC5_171[l]) > 0:
            fTC5null_171[l].append(TC5null_171.count(setTC5_171[l]))
        else:
            fTC5null_171[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_171)):
     if sum(freq >= fTC5_171[l] for freq in fTC5null_171[l]) < 5:
#         print(setTC5_171[l], fTC5_171[l], sum(freq >= fTC5_171[l] for freq in fTC5null_171[l]))
        print(setTC5_171[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# DDJHH
# αDYJJ
# DHYHJ
# DDαHH
# JαJHY
# DαYHJ
# DYJJD
# DJJJY
# JαDHJ
# ααDHJ
# ααYJJ
# αHDαH
# αDYHJ
# JαJJY
# ααJJY
# ααYYH
# JαDYH
# JαYHJ
# JαYαH
# ααDJ
# ααJHY
# DJJDH
# JYYY
# DαJHY
# JYDD
# HαHHJ
# JαHαY
# JYJα
# HJααα
# ααDHY
# JαDHY
# YHYαH
# ααYJY
# DJJJH
# JHYαH
# JαYYH
# αααY
# αJYHJ
# DαYJY
# JDYJJ
# αHHD
# HDHHJ
# DHYYH
# αHYHJ
# YαYJH
# YαYYH
# DYαYD
# HJDYY
# JYYα
# DαDHY
# DDJJJ
# DDJDH
# DαDYH
# YHYYH
# JHYHJ
# JαDαJ
# HD
# DYJDH
# αJJJY
# DJJHH
# DαJJY
# DJDHH
# DJJHY
# JHYYH
# DDDHH
# JYDJ
# JαJDH
# ααDαJ
# HJαDα
# DJJαH
# ααYHJ
# αJαJD
# ααDYH
# αJJHY
# DYJHH

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_171)):
     if sum(freq >= fTC5_171[l] for freq in fTC5null_171[l]) < 1:
#         print(setTC5_171[l], fTC5_171[l], sum(freq >= fTC5_171[l] for freq in fTC5null_171[l]))
        print(setTC5_171[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# DJJDH
# HαHHJ
# JYJα
# JαDHY
# DJJJH
# HDHHJ
# DJJHH
# JHYYH
# αJJHY

# %% [markdown]
# # 3.172 (D) AC - (H) BLOOM - (M) ICT - (N) JGS - (R) MEG

# %%
#extract overlapping dates
start_172 = max(min(Date_AC), min(Date_BLOOM), min(Date_ICT), min(Date_JGS), min(Date_MEG))
end_172 = min(max(Date_AC), max(Date_BLOOM), max(Date_ICT), max(Date_JGS), max(Date_MEG))

# %%
#shorten the closing prices
AC_172_1 = Date_AC.index(start_172)
AC_172_2 = Date_AC.index(end_172)

BLOOM_172_1 = Date_BLOOM.index(start_172)
BLOOM_172_2 = Date_BLOOM.index(end_172)

ICT_172_1 = Date_ICT.index(start_172)
ICT_172_2 = Date_ICT.index(end_172)

JGS_172_1 = Date_JGS.index(start_172)
JGS_172_2 = Date_JGS.index(end_172)

MEG_172_1 = Date_JGS.index(start_172)
MEG_172_2 = Date_JGS.index(end_172)

# %%
#save the shortened versions of closing prices
D172 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_172_1:AC_172_2])
H172 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_172_1:BLOOM_172_2])
M172 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_172_1:ICT_172_2])
N172 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_172_1:JGS_172_2])
R172 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_172_1:MEG_172_2])

# %%
# import modules
import numpy as np
# import prices

D172 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H172 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M172 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N172 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R172 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_172 = []
st_172 = []
n = 1
while n < len(D172):
    sc_172 = ''
    if D172[n] > D172[n-1]:
        sc_172 = sc_172 + 'D'
    if H172[n] > H172[n-1]:
        sc_172 = sc_172 + 'H'
    if M172[n] > M172[n-1]:
        sc_172 = sc_172 + 'M'
    if N172[n] > N172[n-1]:
        sc_172 = sc_172 + 'N'
    if R172[n] > R172[n-1]:
        sc_172 = sc_172 + 'R'
    if len(sc_172) > 0:
        st_172.append(sc_172)
    else:
        STC_172.append(st_172)
        st_172 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[56], line 15
#      13 if N172[n] > N172[n-1]:
#      14     sc_172 = sc_172 + 'N'
# ---> 15 if R172[n] > R172[n-1]:
#      16     sc_172 = sc_172 + 'R'
#      17 if len(sc_172) > 0:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_172 = STC_172.count([])
# keep only non-empty spatio-temporal sequences
STC_172 = [ st_172 for st_172 in STC_172 if len(st_172) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_172 = len(D172)
lmax_172 = 0
for st_172 in STC_172:
    if len(st_172) < lmin_172:
        lmin_172 = len(st_172)
    if len(st_172) > lmax_172:
        lmax_172 = len(st_172)
        
# restrict spatio-temporal sequences to length-5
STC5_172 = [ st_172 for st_172 in STC_172 if len(st_172) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_172 = []
for n in range(len(STC5_172)):
    tc_172 = [ u for u in STC5_172[n][0] ]
    for k in range(1, len(STC5_172[n])):
        tc_172 = [ u+v for u in tc_172 for v in STC5_172[n][k] ]
    TC5_172 = TC5_172 + tc_172
setTC5_172 = list(set(TC5_172))

# get empirical frequencies
fTC5_172 = [ TC5_172.count(setTC5_172[l]) for l in range(len(setTC5_172)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_172 = [ [] for l in range(len(setTC5_172)) ]
for s in range(100):
    STC5null_172 = [ list(st_172) for st_172 in STC5_172]
    for st_172 in STC5null_172:
        np.random.shuffle(st_172)
    TC5null_172= []
    for n in range(len(STC5null_172)):
        tc_172 = [ u for u in STC5null_172[n][0] ]
        for k in range(1, len(STC5null_172[n])):
            tc_172 = [ u+v for u in tc_172 for v in STC5null_172[n][k] ]
        TC5null_172= TC5null_172+ tc_172
    for l in range(len(setTC5_172)):
        if TC5null_172.count(setTC5_172[l]) > 0:
            fTC5null_172[l].append(TC5null_172.count(setTC5_172[l]))
        else:
            fTC5null_172[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_172)):
     if sum(freq >= fTC5_172[l] for freq in fTC5null_172[l]) < 5:
#         print(setTC5_172[l], fTC5_172[l], sum(freq >= fTC5_172[l] for freq in fTC5null_172[l]))
        print(setTC5_172[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# MNDR
# NMRNM
# NNRDR
# DNMDN
# HNRMR
# DDHR
# MMHHN
# DRNMD
# MHHDR
# NNDR
# RHHR
# MHDR
# MDHHN
# DMMD
# NDRND
# NNMDR
# MDHR
# RMHHH
# MDHDN
# DNRDN
# NHMNH
# DNRMN
# DMDDN
# NNDN
# MDHN
# DMMDN
# HDRMN
# RMHNN
# HHMNN
# MNHN
# RMHRH
# HDRDN
# NMRDR
# RRHRH
# MRRR
# RMHRD
# DRRRN
# DNRNN
# DRNDH
# DRNMN
# DRRNN
# MHHR
# DNNDH
# DDRDN
# HNRMN
# MNHR
# HDRMR
# MMHMN
# NMRN
# DRRMD
# MNRR
# MRRRN
# DDHDN
# RDHHH
# RNHHN
# DDMDN
# DNHR
# NNHN
# NDRMN
# RNHHH
# DRNHH
# MHDD
# RRHHN
# RRHNN
# RNHRH
# RDHHN
# MDHMN
# NNHR
# NHHR
# MDRMN
# HMRMM
# NDRNM
# RMHHN
# DMHHN
# RRHRD
# MDRDR
# MDRMR
# DRNMH
# MNRMR
# HNRDR
# RDD
# MDDDN
# RDHNN
# DDRMN
# NMRRR
# MNDN
# DHHR
# DRDMD
# HNRDN
# DNNMN
# DDRDH
# DNNDN
# NNRN

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_172)):
     if sum(freq >= fTC5_172[l] for freq in fTC5null_172[l]) < 1:
#         print(setTC5_172[l], fTC5_172[l], sum(freq >= fTC5_172[l] for freq in fTC5null_172[l]))
        print(setTC5_172[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# DRNMD
# RMHRH
# MHHR
# HNRMN
# MNHR
# DRRMD
# MDHMN
# RMHHN
# DDRMN
# DRDMD
# DDRDH

# %% [markdown]
# # 3.173 (D) AC - (H) BLOOM - (M) ICT - (N) JGS - (Y) SMC

# %%
#extract overlapping dates
start_173 = max(min(Date_AC), min(Date_BLOOM), min(Date_ICT), min(Date_JGS), min(Date_SMC))
end_173 = min(max(Date_AC), max(Date_BLOOM), max(Date_ICT), max(Date_JGS), max(Date_SMC))

# %%
#shorten the closing prices
AC_173_1 = Date_AC.index(start_173)
AC_173_2 = Date_AC.index(end_173)

BLOOM_173_1 = Date_BLOOM.index(start_173)
BLOOM_173_2 = Date_BLOOM.index(end_173)

ICT_173_1 = Date_ICT.index(start_173)
ICT_173_2 = Date_ICT.index(end_173)

JGS_173_1 = Date_JGS.index(start_173)
JGS_173_2 = Date_JGS.index(end_173)

SMC_173_1 = Date_JGS.index(start_173)
SMC_173_2 = Date_JGS.index(end_173)

# %%
#save the shortened versions of closing prices
D173 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_173_1:AC_173_2])
H173 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_173_1:BLOOM_173_2])
M173 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_173_1:ICT_173_2])
N173 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_173_1:JGS_173_2])
Y173 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_173_1:SMC_173_2])

# %%
# import modules
import numpy as np
# import prices

D173 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H173 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M173 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N173 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y173 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_173 = []
st_173 = []
n = 1
while n < len(D173):
    sc_173 = ''
    if D173[n] > D173[n-1]:
        sc_173 = sc_173 + 'D'
    if H173[n] > H173[n-1]:
        sc_173 = sc_173 + 'H'
    if M173[n] > M173[n-1]:
        sc_173 = sc_173 + 'M'
    if N173[n] > N173[n-1]:
        sc_173 = sc_173 + 'N'
    if Y173[n] > Y173[n-1]:
        sc_173 = sc_173 + 'Y'
    if len(sc_173) > 0:
        st_173.append(sc_173)
    else:
        STC_173.append(st_173)
        st_173 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_173 = STC_173.count([])
# keep only non-empty spatio-temporal sequences
STC_173 = [ st_173 for st_173 in STC_173 if len(st_173) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_173 = len(D173)
lmax_173 = 0
for st_173 in STC_173:
    if len(st_173) < lmin_173:
        lmin_173 = len(st_173)
    if len(st_173) > lmax_173:
        lmax_173 = len(st_173)
        
# restrict spatio-temporal sequences to length-5
STC5_173 = [ st_173 for st_173 in STC_173 if len(st_173) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_173 = []
for n in range(len(STC5_173)):
    tc_173 = [ u for u in STC5_173[n][0] ]
    for k in range(1, len(STC5_173[n])):
        tc_173 = [ u+v for u in tc_173 for v in STC5_173[n][k] ]
    TC5_173 = TC5_173 + tc_173
setTC5_173 = list(set(TC5_173))

# get empirical frequencies
fTC5_173 = [ TC5_173.count(setTC5_173[l]) for l in range(len(setTC5_173)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_173 = [ [] for l in range(len(setTC5_173)) ]
for s in range(100):
    STC5null_173 = [ list(st_173) for st_173 in STC5_173]
    for st_173 in STC5null_173:
        np.random.shuffle(st_173)
    TC5null_173= []
    for n in range(len(STC5null_173)):
        tc_173 = [ u for u in STC5null_173[n][0] ]
        for k in range(1, len(STC5null_173[n])):
            tc_173 = [ u+v for u in tc_173 for v in STC5null_173[n][k] ]
        TC5null_173= TC5null_173+ tc_173
    for l in range(len(setTC5_173)):
        if TC5null_173.count(setTC5_173[l]) > 0:
            fTC5null_173[l].append(TC5null_173.count(setTC5_173[l]))
        else:
            fTC5null_173[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_173)):
     if sum(freq >= fTC5_173[l] for freq in fTC5null_173[l]) < 5:
#         print(setTC5_173[l], fTC5_173[l], sum(freq >= fTC5_173[l] for freq in fTC5null_173[l]))
        print(setTC5_173[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# YHDDY
# MNMMN
# DHDH
# YDH
# DNMDN
# HNDMY
# YMDDD
# NMYH
# MNYY
# YHDMD
# YHHMD
# ND
# HYYMD
# HNMMY
# MMMN
# DYYDM
# HDYMY
# DMMD
# DHMMN
# NNYDN
# DDDH
# DNDMN
# NMMN
# YMDMD
# DHMMH
# YDMMD
# DDDMN
# MMYD
# YMHMD
# YMYNN
# NHDH
# NHMMN
# NHYH
# NNDN
# DHNMH
# HHMMN
# DMMDN
# MDMMH
# NNMMN
# MDMDN
# DHNH
# HNDMD
# HNHYN
# HMMY
# YDMDN
# DMD
# HNNYN
# DDYH
# HNYMY
# YNNDN
# MHMMN
# MNYDN
# NHDY
# NHNYD
# MHMMH
# DDMMN
# DHYH
# YMHDY
# DNMDY
# HNMDY
# NNNHD
# YNDDN
# HDMMY
# MHYD
# HYYMY
# DDMDN
# YMHDD
# DMYD
# NMYD
# YHHDD
# DMYDN
# YMMDN
# HNDDN
# DMYH
# HDYDY
# DNMMN
# DNYY
# YMMDD
# DHH
# NMYN
# DMYN
# YDDMD
# HHDDD
# DDYDN
# MMNH
# MNDMN
# DMDH
# MHNMH
# YHMDD
# NHYD
# YHMMD
# DYYNN
# DMNH
# DMND
# DYYDN
# HNHYM
# HNYDY
# DDDDN
# HYY
# HNMDN
# MHDH
# YNMDN
# DNYDN
# MMYN
# DMMN
# NHMMH
# YHHDY
# YMNDN
# MDMNN
# DNDDN
# YMMMD
# HNNYM
# MHYH
# YMYDN
# HMMN
# NNMDN
# MHYN

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_173)):
     if sum(freq >= fTC5_173[l] for freq in fTC5null_173[l]) < 1:
#         print(setTC5_173[l], fTC5_173[l], sum(freq >= fTC5_173[l] for freq in fTC5null_173[l]))
        print(setTC5_173[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# MNMMN
# DHDH
# DNMDN
# MNYY
# HDYMY
# DNDMN
# YMDMD
# DHMMH
# MDMMH
# DHNH
# DMD
# HNNYN
# YNNDN
# MHMMH
# NNNHD
# DDMDN
# DMYD
# YHHDD
# DNMMN
# NMYN
# DDYDN
# MNDMN
# DMNH
# DYYDN
# HNHYM
# DNYDN
# NHMMH
# DNDDN
# HNNYM

# %% [markdown]
# # 3.174 (D) AC - (H) BLOOM - (M) ICT - (N) JGS - (α) SCC

# %%
#extract overlapping dates
start_174 = max(min(Date_AC), min(Date_BLOOM), min(Date_ICT), min(Date_JGS), min(Date_SCC))
end_174 = min(max(Date_AC), max(Date_BLOOM), max(Date_ICT), max(Date_JGS), max(Date_SCC))

# %%
#shorten the closing prices
AC_174_1 = Date_AC.index(start_174)
AC_174_2 = Date_AC.index(end_174)

BLOOM_174_1 = Date_BLOOM.index(start_174)
BLOOM_174_2 = Date_BLOOM.index(end_174)

ICT_174_1 = Date_ICT.index(start_174)
ICT_174_2 = Date_ICT.index(end_174)

JGS_174_1 = Date_JGS.index(start_174)
JGS_174_2 = Date_JGS.index(end_174)

SCC_174_1 = Date_JGS.index(start_174)
SCC_174_2 = Date_JGS.index(end_174)

# %%
#save the shortened versions of closing prices
D174 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_174_1:AC_174_2])
H174 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_174_1:BLOOM_174_2])
M174 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_174_1:ICT_174_2])
N174 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_174_1:JGS_174_2])
α174 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_174_1:SCC_174_2])

# %%
# import modules
import numpy as np
# import prices

D174 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H174 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M174 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N174 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
α174 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_174 = []
st_174 = []
n = 1
while n < len(D174):
    sc_174 = ''
    if D174[n] > D174[n-1]:
        sc_174 = sc_174 + 'D'
    if H174[n] > H174[n-1]:
        sc_174 = sc_174 + 'H'
    if M174[n] > M174[n-1]:
        sc_174 = sc_174 + 'M'
    if N174[n] > N174[n-1]:
        sc_174 = sc_174 + 'N'
    if α174[n] > α174[n-1]:
        sc_174 = sc_174 + 'α'
    if len(sc_174) > 0:
        st_174.append(sc_174)
    else:
        STC_174.append(st_174)
        st_174 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[72], line 15
#      13 if N174[n] > N174[n-1]:
#      14     sc_174 = sc_174 + 'N'
# ---> 15 if α174[n] > α174[n-1]:
#      16     sc_174 = sc_174 + 'α'
#      17 if len(sc_174) > 0:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_174 = STC_174.count([])
# keep only non-empty spatio-temporal sequences
STC_174 = [ st_174 for st_174 in STC_174 if len(st_174) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_174 = len(D174)
lmax_174 = 0
for st_174 in STC_174:
    if len(st_174) < lmin_174:
        lmin_174 = len(st_174)
    if len(st_174) > lmax_174:
        lmax_174 = len(st_174)
        
# restrict spatio-temporal sequences to length-5
STC5_174 = [ st_174 for st_174 in STC_174 if len(st_174) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_174 = []
for n in range(len(STC5_174)):
    tc_174 = [ u for u in STC5_174[n][0] ]
    for k in range(1, len(STC5_174[n])):
        tc_174 = [ u+v for u in tc_174 for v in STC5_174[n][k] ]
    TC5_174 = TC5_174 + tc_174
setTC5_174 = list(set(TC5_174))

# get empirical frequencies
fTC5_174 = [ TC5_174.count(setTC5_174[l]) for l in range(len(setTC5_174)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_174 = [ [] for l in range(len(setTC5_174)) ]
for s in range(100):
    STC5null_174 = [ list(st_174) for st_174 in STC5_174]
    for st_174 in STC5null_174:
        np.random.shuffle(st_174)
    TC5null_174= []
    for n in range(len(STC5null_174)):
        tc_174 = [ u for u in STC5null_174[n][0] ]
        for k in range(1, len(STC5null_174[n])):
            tc_174 = [ u+v for u in tc_174 for v in STC5null_174[n][k] ]
        TC5null_174= TC5null_174+ tc_174
    for l in range(len(setTC5_174)):
        if TC5null_174.count(setTC5_174[l]) > 0:
            fTC5null_174[l].append(TC5null_174.count(setTC5_174[l]))
        else:
            fTC5null_174[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_174)):
     if sum(freq >= fTC5_174[l] for freq in fTC5null_174[l]) < 5:
#         print(setTC5_174[l], fTC5_174[l], sum(freq >= fTC5_174[l] for freq in fTC5null_174[l]))
        print(setTC5_174[l])

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_174)):
     if sum(freq >= fTC5_174[l] for freq in fTC5null_174[l]) < 1:
#         print(setTC5_174[l], fTC5_174[l], sum(freq >= fTC5_174[l] for freq in fTC5null_174[l]))
        print(setTC5_174[l])

# %% [markdown]
# # 3.175 (D) AC - (H) BLOOM - (M) ICT - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_175 = max(min(Date_AC), min(Date_BLOOM), min(Date_ICT), min(Date_MEG), min(Date_SMC))
end_175 = min(max(Date_AC), max(Date_BLOOM), max(Date_ICT), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
AC_175_1 = Date_AC.index(start_175)
AC_175_2 = Date_AC.index(end_175)

BLOOM_175_1 = Date_BLOOM.index(start_175)
BLOOM_175_2 = Date_BLOOM.index(end_175)

ICT_175_1 = Date_ICT.index(start_175)
ICT_175_2 = Date_ICT.index(end_175)

MEG_175_1 = Date_MEG.index(start_175)
MEG_175_2 = Date_MEG.index(end_175)

SMC_175_1 = Date_MEG.index(start_175)
SMC_175_2 = Date_MEG.index(end_175)

# %%
#save the shortened versions of closing prices
D175 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_175_1:AC_175_2])
H175 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_175_1:BLOOM_175_2])
M175 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_175_1:ICT_175_2])
R175 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_175_1:MEG_175_2])
Y175 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_175_1:SMC_175_2])

# %%
# import modules
import numpy as np
# import prices

D175 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H175 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M175 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R175 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y175 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_175 = []
st_175 = []
n = 1
while n < len(D175):
    sc_175 = ''
    if D175[n] > D175[n-1]:
        sc_175 = sc_175 + 'D'
    if H175[n] > H175[n-1]:
        sc_175 = sc_175 + 'H'
    if M175[n] > M175[n-1]:
        sc_175 = sc_175 + 'M'
    if R175[n] > R175[n-1]:
        sc_175 = sc_175 + 'R'
    if Y175[n] > Y175[n-1]:
        sc_175 = sc_175 + 'Y'
    if len(sc_175) > 0:
        st_175.append(sc_175)
    else:
        STC_175.append(st_175)
        st_175 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_175 = STC_175.count([])
# keep only non-empty spatio-temporal sequences
STC_175 = [ st_175 for st_175 in STC_175 if len(st_175) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_175 = len(D175)
lmax_175 = 0
for st_175 in STC_175:
    if len(st_175) < lmin_175:
        lmin_175 = len(st_175)
    if len(st_175) > lmax_175:
        lmax_175 = len(st_175)
        
# restrict spatio-temporal sequences to length-5
STC5_175 = [ st_175 for st_175 in STC_175 if len(st_175) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_175 = []
for n in range(len(STC5_175)):
    tc_175 = [ u for u in STC5_175[n][0] ]
    for k in range(1, len(STC5_175[n])):
        tc_175 = [ u+v for u in tc_175 for v in STC5_175[n][k] ]
    TC5_175 = TC5_175 + tc_175
setTC5_175 = list(set(TC5_175))

# get empirical frequencies
fTC5_175 = [ TC5_175.count(setTC5_175[l]) for l in range(len(setTC5_175)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_175 = [ [] for l in range(len(setTC5_175)) ]
for s in range(100):
    STC5null_175 = [ list(st_175) for st_175 in STC5_175]
    for st_175 in STC5null_175:
        np.random.shuffle(st_175)
    TC5null_175= []
    for n in range(len(STC5null_175)):
        tc_175 = [ u for u in STC5null_175[n][0] ]
        for k in range(1, len(STC5null_175[n])):
            tc_175 = [ u+v for u in tc_175 for v in STC5null_175[n][k] ]
        TC5null_175= TC5null_175+ tc_175
    for l in range(len(setTC5_175)):
        if TC5null_175.count(setTC5_175[l]) > 0:
            fTC5null_175[l].append(TC5null_175.count(setTC5_175[l]))
        else:
            fTC5null_175[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_175)):
     if sum(freq >= fTC5_175[l] for freq in fTC5null_175[l]) < 5:
#         print(setTC5_175[l], fTC5_175[l], sum(freq >= fTC5_175[l] for freq in fTC5null_175[l]))
        print(setTC5_175[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# YDHRM
# DRHRM
# DRRRM
# DRYRM
# RMYYM
# YRDHY
# DYYYY
# RRMYH
# MRMYH
# DRDMR
# YMMDY
# HHMDD
# YDDHM
# RMRR
# DRDRH
# DRYYM
# DDRRH
# RMYYH
# RYMD
# RRYYM
# HDHYH
# RYMR
# YDDHH
# RRDYH
# DRYRR
# RYYYM
# YRDHH
# MHMMD
# DDYMD
# YDHRH
# YRMHY
# HHR
# MHDYD
# MHRRD
# DHYYM
# DMD
# DRYDR
# RMYYY
# DHDYY
# YDRRM
# YMRD
# RMMYM
# HHDYD
# RRYYH
# RRDDH
# MHRRH
# RHDYD
# MDRRD
# DRDYY
# MHDRD
# YDDHY
# MRDYH
# DHRMH
# RRHYH
# RRYY
# HHMYM
# MHYM
# DRRYM
# HHDDH
# YRMDH
# MMDYD
# DRYMR
# YHHY
# YRRDH
# DHDR
# YRHDH
# MDDYH
# YRMHH
# DRHYM
# DRYMM
# YRMDY
# HDRYH
# HHDRD
# RHYYH
# HHDDD
# DRDMM
# YDRRH
# MMDYM
# DRDYR
# YMDDY
# DRDYM
# DMDH
# MMMD
# YRDDH
# RRMDH
# MHDYH
# HHHYM
# RDYY
# MRMYM
# RMDYM
# RYYYY
# MRDYD
# RDDYD
# RRHRM
# RMMDM
# MHRMH

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_175)):
     if sum(freq >= fTC5_175[l] for freq in fTC5null_175[l]) < 1:
#         print(setTC5_175[l], fTC5_175[l], sum(freq >= fTC5_175[l] for freq in fTC5null_175[l]))
        print(setTC5_175[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# RMYYM
# DRYYM
# RMYYH
# RRYYM
# RYMR
# RRDYH
# MHMMD
# MHDYD
# RRYYH
# DRDYY
# YRHDH
# DRYMM
# RMDYM

# %% [markdown]
# # 3.176 (D) AC - (H) BLOOM - (M) ICT - (R) MEG - (α) SCC

# %%
#extract overlapping dates
start_176 = max(min(Date_AC), min(Date_BLOOM), min(Date_ICT), min(Date_MEG), min(Date_SCC))
end_176 = min(max(Date_AC), max(Date_BLOOM), max(Date_ICT), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
AC_176_1 = Date_AC.index(start_176)
AC_176_2 = Date_AC.index(end_176)

BLOOM_176_1 = Date_BLOOM.index(start_176)
BLOOM_176_2 = Date_BLOOM.index(end_176)

ICT_176_1 = Date_ICT.index(start_176)
ICT_176_2 = Date_ICT.index(end_176)

MEG_176_1 = Date_MEG.index(start_176)
MEG_176_2 = Date_MEG.index(end_176)

SCC_176_1 = Date_MEG.index(start_176)
SCC_176_2 = Date_MEG.index(end_176)

# %%
#save the shortened versions of closing prices
D176 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_176_1:AC_176_2])
H176 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_176_1:BLOOM_176_2])
M176 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_176_1:ICT_176_2])
R176 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_176_1:MEG_176_2])
α176 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_176_1:SCC_176_2])

# %%
# import modules
import numpy as np
# import prices

D176 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H176 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M176 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R176 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α176 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_176 = []
st_176 = []
n = 1
while n < len(D176):
    sc_176 = ''
    if D176[n] > D176[n-1]:
        sc_176 = sc_176 + 'D'
    if H176[n] > H176[n-1]:
        sc_176 = sc_176 + 'H'
    if M176[n] > M176[n-1]:
        sc_176 = sc_176 + 'M'
    if R176[n] > R176[n-1]:
        sc_176 = sc_176 + 'R'
    if α176[n] > α176[n-1]:
        sc_176 = sc_176 + 'α'
    if len(sc_176) > 0:
        st_176.append(sc_176)
    else:
        STC_176.append(st_176)
        st_176 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_176 = STC_176.count([])
# keep only non-empty spatio-temporal sequences
STC_176 = [ st_176 for st_176 in STC_176 if len(st_176) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_176 = len(D176)
lmax_176 = 0
for st_176 in STC_176:
    if len(st_176) < lmin_176:
        lmin_176 = len(st_176)
    if len(st_176) > lmax_176:
        lmax_176 = len(st_176)
        
# restrict spatio-temporal sequences to length-5
STC5_176 = [ st_176 for st_176 in STC_176 if len(st_176) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_176 = []
for n in range(len(STC5_176)):
    tc_176 = [ u for u in STC5_176[n][0] ]
    for k in range(1, len(STC5_176[n])):
        tc_176 = [ u+v for u in tc_176 for v in STC5_176[n][k] ]
    TC5_176 = TC5_176 + tc_176
setTC5_176 = list(set(TC5_176))

# get empirical frequencies
fTC5_176 = [ TC5_176.count(setTC5_176[l]) for l in range(len(setTC5_176)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_176 = [ [] for l in range(len(setTC5_176)) ]
for s in range(100):
    STC5null_176 = [ list(st_176) for st_176 in STC5_176]
    for st_176 in STC5null_176:
        np.random.shuffle(st_176)
    TC5null_176= []
    for n in range(len(STC5null_176)):
        tc_176 = [ u for u in STC5null_176[n][0] ]
        for k in range(1, len(STC5null_176[n])):
            tc_176 = [ u+v for u in tc_176 for v in STC5null_176[n][k] ]
        TC5null_176= TC5null_176+ tc_176
    for l in range(len(setTC5_176)):
        if TC5null_176.count(setTC5_176[l]) > 0:
            fTC5null_176[l].append(TC5null_176.count(setTC5_176[l]))
        else:
            fTC5null_176[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_176)):
     if sum(freq >= fTC5_176[l] for freq in fTC5null_176[l]) < 5:
#         print(setTC5_176[l], fTC5_176[l], sum(freq >= fTC5_176[l] for freq in fTC5null_176[l]))
        print(setTC5_176[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# DRHRR
# MHααM
# DRHRM
# DRRRM
# DαHRM
# RαHMH
# HDMMD
# RDHRM
# DMMD
# DRDRH
# MHαRD
# DDRRH
# RRDαα
# DMDMH
# DαDHH
# αRααH
# DDαDM
# DDαRM
# RαHRM
# αHααH
# MαMMR
# HRMMR
# DαHMM
# RRHαH
# HMαR
# DαDRH
# RDαDM
# DHR
# RRMMM
# DDHRH
# RMDαα
# DHααH
# DRRRR
# RαHRH
# DRRRH
# MMDαD
# DαRMH
# αHDRD
# DαDRM
# RMDαM
# DRHRH
# αDααα
# RMDDα
# DRαRM
# DDHRM
# DRDMα
# DHDRD
# RD
# MαMMM
# RRHαM
# DαHαM
# DαRMM
# HRMMM
# αRHαH
# DMDHH
# αHRαH
# RαHαM
# DRDHH
# DαDHM
# RαDRM
# RαRMM
# DDRRM
# DM
# MRHRM
# αHRRD
# DMRH
# DαHHM
# αRαRR
# DRDHα
# RαMMM
# αMMDα
# DHDMD
# DαHRH
# DαHα
# αRαDM
# MHDαD
# DDαRR
# DHααM
# MRHRH
# DHH
# RαHHH
# RDMMD
# RαRRM
# MHααD
# DαHHH
# RMHαM
# DαHαH
# RRHRR
# MDαRM
# RαDHH
# HDMMM
# DDαDR
# HαMMM
# RDααM
# MMDH
# αMααH
# MαHα
# RDαRM
# DαDHR
# DαHMH
# MMMR
# RαHMM
# RαDαM
# RαHαH
# DαDMH
# MHααH
# DαRHH
# DHααR
# αHHRD
# RRHRM
# RαHHM

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_176)):
     if sum(freq >= fTC5_176[l] for freq in fTC5null_176[l]) < 1:
#         print(setTC5_176[l], fTC5_176[l], sum(freq >= fTC5_176[l] for freq in fTC5null_176[l]))
        print(setTC5_176[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# DRHRM
# DαDHH
# αRααH
# DDαRM
# αHααH
# DHααH
# DRRRH
# DRHRH
# DRDMα
# MαMMM
# RRHαM
# HRMMM
# DαDHM
# αRαRR
# αRαDM
# DHH
# RαHHH
# DαHHH
# RRHRR
# αMααH
# MαHα
# RRHRM

# %% [markdown]
# # 3.177 (D) AC - (H) BLOOM - (M) ICT - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_177 = max(min(Date_AC), min(Date_BLOOM), min(Date_ICT), min(Date_SMC), min(Date_SCC))
end_177 = min(max(Date_AC), max(Date_BLOOM), max(Date_ICT), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
AC_177_1 = Date_AC.index(start_177)
AC_177_2 = Date_AC.index(end_177)

BLOOM_177_1 = Date_BLOOM.index(start_177)
BLOOM_177_2 = Date_BLOOM.index(end_177)

ICT_177_1 = Date_ICT.index(start_177)
ICT_177_2 = Date_ICT.index(end_177)

SMC_177_1 = Date_SMC.index(start_177)
SMC_177_2 = Date_SMC.index(end_177)

SCC_177_1 = Date_SMC.index(start_177)
SCC_177_2 = Date_SMC.index(end_177)

# %%
#save the shortened versions of closing prices
D177 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_177_1:AC_177_2])
H177 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_177_1:BLOOM_177_2])
M177 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_177_1:ICT_177_2])
Y177 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_177_1:SMC_177_2])
α177 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_177_1:SCC_177_2])

# %%
# import modules
import numpy as np
# import prices

D177 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H177 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M177 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
Y177 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α177 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_177 = []
st_177 = []
n = 1
while n < len(D177):
    sc_177 = ''
    if D177[n] > D177[n-1]:
        sc_177 = sc_177 + 'D'
    if H177[n] > H177[n-1]:
        sc_177 = sc_177 + 'H'
    if M177[n] > M177[n-1]:
        sc_177 = sc_177 + 'M'
    if Y177[n] > Y177[n-1]:
        sc_177 = sc_177 + 'Y'
    if α177[n] > α177[n-1]:
        sc_177 = sc_177 + 'α'
    if len(sc_177) > 0:
        st_177.append(sc_177)
    else:
        STC_177.append(st_177)
        st_177 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[93], line 15
#      13 if Y177[n] > Y177[n-1]:
#      14     sc_177 = sc_177 + 'Y'
# ---> 15 if α177[n] > α177[n-1]:
#      16     sc_177 = sc_177 + 'α'
#      17 if len(sc_177) > 0:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_177 = STC_177.count([])
# keep only non-empty spatio-temporal sequences
STC_177 = [ st_177 for st_177 in STC_177 if len(st_177) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_177 = len(D177)
lmax_177 = 0
for st_177 in STC_177:
    if len(st_177) < lmin_177:
        lmin_177 = len(st_177)
    if len(st_177) > lmax_177:
        lmax_177 = len(st_177)
        
# restrict spatio-temporal sequences to length-5
STC5_177 = [ st_177 for st_177 in STC_177 if len(st_177) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_177 = []
for n in range(len(STC5_177)):
    tc_177 = [ u for u in STC5_177[n][0] ]
    for k in range(1, len(STC5_177[n])):
        tc_177 = [ u+v for u in tc_177 for v in STC5_177[n][k] ]
    TC5_177 = TC5_177 + tc_177
setTC5_177 = list(set(TC5_177))

# get empirical frequencies
fTC5_177 = [ TC5_177.count(setTC5_177[l]) for l in range(len(setTC5_177)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_177 = [ [] for l in range(len(setTC5_177)) ]
for s in range(100):
    STC5null_177 = [ list(st_177) for st_177 in STC5_177]
    for st_177 in STC5null_177:
        np.random.shuffle(st_177)
    TC5null_177= []
    for n in range(len(STC5null_177)):
        tc_177 = [ u for u in STC5null_177[n][0] ]
        for k in range(1, len(STC5null_177[n])):
            tc_177 = [ u+v for u in tc_177 for v in STC5null_177[n][k] ]
        TC5null_177= TC5null_177+ tc_177
    for l in range(len(setTC5_177)):
        if TC5null_177.count(setTC5_177[l]) > 0:
            fTC5null_177[l].append(TC5null_177.count(setTC5_177[l]))
        else:
            fTC5null_177[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_177)):
     if sum(freq >= fTC5_177[l] for freq in fTC5null_177[l]) < 5:
#         print(setTC5_177[l], fTC5_177[l], sum(freq >= fTC5_177[l] for freq in fTC5null_177[l]))
        print(setTC5_177[l])

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_177)):
     if sum(freq >= fTC5_177[l] for freq in fTC5null_177[l]) < 1:
#         print(setTC5_177[l], fTC5_177[l], sum(freq >= fTC5_177[l] for freq in fTC5null_177[l]))
        print(setTC5_177[l])

# %% [markdown]
# # 3.178 (D) AC - (H) BLOOM - (N) JGS - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_178 = max(min(Date_AC), min(Date_BLOOM), min(Date_JGS), min(Date_MEG), min(Date_SMC))
end_178 = min(max(Date_AC), max(Date_BLOOM), max(Date_JGS), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
AC_178_1 = Date_AC.index(start_178)
AC_178_2 = Date_AC.index(end_178)

BLOOM_178_1 = Date_BLOOM.index(start_178)
BLOOM_178_2 = Date_BLOOM.index(end_178)

JGS_178_1 = Date_JGS.index(start_178)
JGS_178_2 = Date_JGS.index(end_178)

MEG_178_1 = Date_MEG.index(start_178)
MEG_178_2 = Date_MEG.index(end_178)

SMC_178_1 = Date_MEG.index(start_178)
SMC_178_2 = Date_MEG.index(end_178)

# %%
#save the shortened versions of closing prices
D178 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_178_1:AC_178_2])
H178 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_178_1:BLOOM_178_2])
N178 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_178_1:JGS_178_2])
R178 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_178_1:MEG_178_2])
Y178 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_178_1:SMC_178_2])

# %%
# import modules
import numpy as np
# import prices

D178 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H178 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
N178 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R178 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y178 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_178 = []
st_178 = []
n = 1
while n < len(D178):
    sc_178 = ''
    if D178[n] > D178[n-1]:
        sc_178 = sc_178 + 'D'
    if H178[n] > H178[n-1]:
        sc_178 = sc_178 + 'H'
    if N178[n] > N178[n-1]:
        sc_178 = sc_178 + 'N'
    if R178[n] > R178[n-1]:
        sc_178 = sc_178 + 'R'
    if Y178[n] > Y178[n-1]:
        sc_178 = sc_178 + 'Y'
    if len(sc_178) > 0:
        st_178.append(sc_178)
    else:
        STC_178.append(st_178)
        st_178 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_178 = STC_178.count([])
# keep only non-empty spatio-temporal sequences
STC_178 = [ st_178 for st_178 in STC_178 if len(st_178) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_178 = len(D178)
lmax_178 = 0
for st_178 in STC_178:
    if len(st_178) < lmin_178:
        lmin_178 = len(st_178)
    if len(st_178) > lmax_178:
        lmax_178 = len(st_178)
        
# restrict spatio-temporal sequences to length-5
STC5_178 = [ st_178 for st_178 in STC_178 if len(st_178) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_178 = []
for n in range(len(STC5_178)):
    tc_178 = [ u for u in STC5_178[n][0] ]
    for k in range(1, len(STC5_178[n])):
        tc_178 = [ u+v for u in tc_178 for v in STC5_178[n][k] ]
    TC5_178 = TC5_178 + tc_178
setTC5_178 = list(set(TC5_178))

# get empirical frequencies
fTC5_178 = [ TC5_178.count(setTC5_178[l]) for l in range(len(setTC5_178)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_178 = [ [] for l in range(len(setTC5_178)) ]
for s in range(100):
    STC5null_178 = [ list(st_178) for st_178 in STC5_178]
    for st_178 in STC5null_178:
        np.random.shuffle(st_178)
    TC5null_178= []
    for n in range(len(STC5null_178)):
        tc_178 = [ u for u in STC5null_178[n][0] ]
        for k in range(1, len(STC5null_178[n])):
            tc_178 = [ u+v for u in tc_178 for v in STC5null_178[n][k] ]
        TC5null_178= TC5null_178+ tc_178
    for l in range(len(setTC5_178)):
        if TC5null_178.count(setTC5_178[l]) > 0:
            fTC5null_178[l].append(TC5null_178.count(setTC5_178[l]))
        else:
            fTC5null_178[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_178)):
     if sum(freq >= fTC5_178[l] for freq in fTC5null_178[l]) < 5:
#         print(setTC5_178[l], fTC5_178[l], sum(freq >= fTC5_178[l] for freq in fTC5null_178[l]))
        print(setTC5_178[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# HHDNR
# YNDNY
# YHDDY
# YRHRN
# YDDRH
# YRHRH
# YNNHY
# YNHHY
# YNHRY
# DDYND
# YDRHY
# YNRHY
# YNHDY
# DRNRH
# RYNR
# DDRRH
# HNNDN
# YHRDY
# YDDHH
# DNRRH
# YRDHH
# RNDYY
# HRNDN
# YHNY
# DNNRH
# YRRHY
# YRNY
# YDHRH
# YDHRN
# HRDRH
# HNDNR
# DRRDY
# DDDDH
# DHNH
# YDNDH
# HHDRR
# DRRRH
# YRDRH
# DRNDH
# DDYH
# YNDDY
# YNRRY
# YHRRY
# DRNH
# YNRDH
# DNNDH
# YDHRY
# YRNDH
# YDNHY
# YNNDH
# YDDHY
# DRDDY
# YDNRH
# DRDDH
# YDRDH
# HHDND
# NRNRH
# YHHY
# DDYRR
# YRRDH
# YRHDH
# YNNRH
# YRNRH
# YNDRY
# YRHHH
# HHDRD
# YNNDY
# YRRDY
# NHNY
# NNNDH
# HNNRN
# YDHDY
# YDRRH
# HHDNN
# DDNDH
# RRNH
# DDYDR
# NRNY
# DNRDH
# DDRRR
# HRDDN
# NNDYY
# YNDHY
# DNDNR
# HHDRN
# NRND
# YNRDY
# YNHDH
# YNYDH
# YDHHH
# YNNRY
# HNDNN
# DDRDH
# RYND
# YRHDY
# YRRRH
# YDHDH
# YNHRH
# YNRRH
# YRHRY
# DDYNR

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_178)):
     if sum(freq >= fTC5_178[l] for freq in fTC5null_178[l]) < 1:
#         print(setTC5_178[l], fTC5_178[l], sum(freq >= fTC5_178[l] for freq in fTC5null_178[l]))
        print(setTC5_178[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# HHDNR
# YRHRH
# YDRHY
# YNHDY
# DRNRH
# YHNY
# YDHRH
# DHNH
# HHDRR
# YNRDH
# YDRDH
# HHDND
# HHDRD
# YNNDY
# HNNRN
# YDHDY
# YDRRH
# HHDNN
# DDYDR
# DDRRR
# HHDRN
# YNHDH
# YNNRY
# DDRDH
# YRHDY
# YRRRH
# YNHRH
# YNRRH
# DDYNR

# %% [markdown]
# # 3.179 (D) AC - (H) BLOOM - (N) JGS - (R) MEG - (α) SCC

# %%
#extract overlapping dates
start_179 = max(min(Date_AC), min(Date_BLOOM), min(Date_JGS), min(Date_MEG), min(Date_SMC))
end_179 = min(max(Date_AC), max(Date_BLOOM), max(Date_JGS), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
AC_179_1 = Date_AC.index(start_179)
AC_179_2 = Date_AC.index(end_179)

BLOOM_179_1 = Date_BLOOM.index(start_179)
BLOOM_179_2 = Date_BLOOM.index(end_179)

JGS_179_1 = Date_JGS.index(start_179)
JGS_179_2 = Date_JGS.index(end_179)

MEG_179_1 = Date_MEG.index(start_179)
MEG_179_2 = Date_MEG.index(end_179)

SMC_179_1 = Date_MEG.index(start_179)
SMC_179_2 = Date_MEG.index(end_179)

# %%
#save the shortened versions of closing prices
D179 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_179_1:AC_179_2])
H179 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_179_1:BLOOM_179_2])
N179 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_179_1:JGS_179_2])
R179 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_179_1:MEG_179_2])
α179 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_179_1:SMC_179_2])

# %%
# import modules
import numpy as np
# import prices

D179 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H179 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
N179 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R179 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α179 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_179 = []
st_179 = []
n = 1
while n < len(D179):
    sc_179 = ''
    if D179[n] > D179[n-1]:
        sc_179 = sc_179 + 'D'
    if H179[n] > H179[n-1]:
        sc_179 = sc_179 + 'H'
    if N179[n] > N179[n-1]:
        sc_179 = sc_179 + 'N'
    if R179[n] > R179[n-1]:
        sc_179 = sc_179 + 'R'
    if α179[n] > α179[n-1]:
        sc_179 = sc_179 + 'α'
    if len(sc_179) > 0:
        st_179.append(sc_179)
    else:
        STC_179.append(st_179)
        st_179 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_179 = STC_179.count([])
# keep only non-empty spatio-temporal sequences
STC_179 = [ st_179 for st_179 in STC_179 if len(st_179) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_179 = len(D179)
lmax_179 = 0
for st_179 in STC_179:
    if len(st_179) < lmin_179:
        lmin_179 = len(st_179)
    if len(st_179) > lmax_179:
        lmax_179 = len(st_179)
        
# restrict spatio-temporal sequences to length-5
STC5_179 = [ st_179 for st_179 in STC_179 if len(st_179) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_179 = []
for n in range(len(STC5_179)):
    tc_179 = [ u for u in STC5_179[n][0] ]
    for k in range(1, len(STC5_179[n])):
        tc_179 = [ u+v for u in tc_179 for v in STC5_179[n][k] ]
    TC5_179 = TC5_179 + tc_179
setTC5_179 = list(set(TC5_179))

# get empirical frequencies
fTC5_179 = [ TC5_179.count(setTC5_179[l]) for l in range(len(setTC5_179)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_179 = [ [] for l in range(len(setTC5_179)) ]
for s in range(100):
    STC5null_179 = [ list(st_179) for st_179 in STC5_179]
    for st_179 in STC5null_179:
        np.random.shuffle(st_179)
    TC5null_179= []
    for n in range(len(STC5null_179)):
        tc_179 = [ u for u in STC5null_179[n][0] ]
        for k in range(1, len(STC5null_179[n])):
            tc_179 = [ u+v for u in tc_179 for v in STC5null_179[n][k] ]
        TC5null_179= TC5null_179+ tc_179
    for l in range(len(setTC5_179)):
        if TC5null_179.count(setTC5_179[l]) > 0:
            fTC5null_179[l].append(TC5null_179.count(setTC5_179[l]))
        else:
            fTC5null_179[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_179)):
     if sum(freq >= fTC5_179[l] for freq in fTC5null_179[l]) < 5:
#         print(setTC5_179[l], fTC5_179[l], sum(freq >= fTC5_179[l] for freq in fTC5null_179[l]))
        print(setTC5_179[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# HHDNR
# αRHRN
# αNNDH
# αRRRH
# αHDDα
# DDαH
# αRNRH
# αDDRH
# αNHRH
# NHNα
# DRNRH
# αRHDα
# αNNHα
# αHRDα
# αDRRH
# DDRRH
# HNNDN
# αDDHH
# DNRRH
# αNDDα
# αDRDH
# αRHHH
# αRRDα
# αNHHα
# HRNDN
# αDHDα
# DNNRH
# αNNDα
# αRRHα
# αNRDH
# RαND
# αNNRα
# αRHRα
# HRDRH
# HNDNR
# NRNα
# αNRRα
# DDDDH
# DHNH
# HHDRR
# RNDαα
# αDHRN
# DRRRH
# αNRRH
# DDαND
# DRNDH
# αNDNα
# DRNH
# DNNDH
# αHHα
# αDNHα
# αDDHα
# αNDHα
# αHRRα
# αNHDα
# DRDDH
# αDNDH
# DDαNR
# HHDND
# NNDαα
# NRNRH
# αDRHα
# αDHDH
# DDαRR
# HHDRD
# DRRDα
# NNNDH
# HNNRN
# HHDNN
# αNDRα
# DDNDH
# αNNRH
# RRNH
# RαNR
# DRDDα
# DDαDR
# DNRDH
# HRDDN
# DDRRR
# αNHDH
# αHNα
# DNDNR
# HHDRN
# αRDHH
# αRRDH
# αNRHα
# αRNDH
# NRND
# αNHRα
# αDHHH
# αRDRH
# αNαDH
# αDHRα
# αRHDH
# HNDNN
# DDRDH
# αDNRH
# αDHRH
# αNRDα
# αRHRH
# αRNα

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_179)):
     if sum(freq >= fTC5_179[l] for freq in fTC5null_179[l]) < 1:
#         print(setTC5_179[l], fTC5_179[l], sum(freq >= fTC5_179[l] for freq in fTC5null_179[l]))
        print(setTC5_179[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# HHDNR
# αRRRH
# αNHRH
# DRNRH
# αRHDα
# αDRRH
# αDRDH
# αDHDα
# αNNDα
# αNRDH
# αNNRα
# DHNH
# HHDRR
# αNRRH
# αNHDα
# DDαNR
# HHDND
# αDRHα
# HHDRD
# HNNRN
# HHDNN
# DDαDR
# DDRRR
# αNHDH
# αHNα
# HHDRN
# DDRDH
# αDHRH
# αRHRH

# %% [markdown]
# # 3.180 (D) AC - (H) BLOOM - (N) JGS - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_180 = max(min(Date_AC), min(Date_BLOOM), min(Date_JGS), min(Date_SMC), min(Date_SCC))
end_180 = min(max(Date_AC), max(Date_BLOOM), max(Date_JGS), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
AC_180_1 = Date_AC.index(start_180)
AC_180_2 = Date_AC.index(end_180)

BLOOM_180_1 = Date_BLOOM.index(start_180)
BLOOM_180_2 = Date_BLOOM.index(end_180)

JGS_180_1 = Date_JGS.index(start_180)
JGS_180_2 = Date_JGS.index(end_180)

SMC_180_1 = Date_SMC.index(start_180)
SMC_180_2 = Date_SMC.index(end_180)

SCC_180_1 = Date_SCC.index(start_180)
SCC_180_2 = Date_SCC.index(end_180)

# %%
#save the shortened versions of closing prices
D180 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_180_1:AC_180_2])
H180 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_180_1:BLOOM_180_2])
N180 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_180_1:JGS_180_2])
Y180 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_180_1:SMC_180_2])
α180 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_180_1:SCC_180_2])

# %%
# import modules
import numpy as np
# import prices

D180 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
H180 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
N180 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y180 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α180 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_180 = []
st_180 = []
n = 1
while n < len(D180):
    sc_180 = ''
    if D180[n] > D180[n-1]:
        sc_180 = sc_180 + 'D'
    if H180[n] > H180[n-1]:
        sc_180 = sc_180 + 'H'
    if N180[n] > N180[n-1]:
        sc_180 = sc_180 + 'N'
    if Y180[n] > Y180[n-1]:
        sc_180 = sc_180 + 'Y'
    if α180[n] > α180[n-1]:
        sc_180 = sc_180 + 'α'
    if len(sc_180) > 0:
        st_180.append(sc_180)
    else:
        STC_180.append(st_180)
        st_180 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_180 = STC_180.count([])
# keep only non-empty spatio-temporal sequences
STC_180 = [ st_180 for st_180 in STC_180 if len(st_180) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_180 = len(D180)
lmax_180 = 0
for st_180 in STC_180:
    if len(st_180) < lmin_180:
        lmin_180 = len(st_180)
    if len(st_180) > lmax_180:
        lmax_180 = len(st_180)
        
# restrict spatio-temporal sequences to length-5
STC5_180 = [ st_180 for st_180 in STC_180 if len(st_180) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_180 = []
for n in range(len(STC5_180)):
    tc_180 = [ u for u in STC5_180[n][0] ]
    for k in range(1, len(STC5_180[n])):
        tc_180 = [ u+v for u in tc_180 for v in STC5_180[n][k] ]
    TC5_180 = TC5_180 + tc_180
setTC5_180 = list(set(TC5_180))

# get empirical frequencies
fTC5_180 = [ TC5_180.count(setTC5_180[l]) for l in range(len(setTC5_180)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_180 = [ [] for l in range(len(setTC5_180)) ]
for s in range(100):
    STC5null_180 = [ list(st_180) for st_180 in STC5_180]
    for st_180 in STC5null_180:
        np.random.shuffle(st_180)
    TC5null_180= []
    for n in range(len(STC5null_180)):
        tc_180 = [ u for u in STC5null_180[n][0] ]
        for k in range(1, len(STC5null_180[n])):
            tc_180 = [ u+v for u in tc_180 for v in STC5null_180[n][k] ]
        TC5null_180= TC5null_180+ tc_180
    for l in range(len(setTC5_180)):
        if TC5null_180.count(setTC5_180[l]) > 0:
            fTC5null_180[l].append(TC5null_180.count(setTC5_180[l]))
        else:
            fTC5null_180[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_180)):
     if sum(freq >= fTC5_180[l] for freq in fTC5null_180[l]) < 5:
#         print(setTC5_180[l], fTC5_180[l], sum(freq >= fTC5_180[l] for freq in fTC5null_180[l]))
        print(setTC5_180[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# YYNN
# YDNNH
# DαN
# HDY
# YYDα
# NYαNN
# YαDN
# YYNDH
# NYNNα
# YYαDH
# YHDN
# DYαNN
# NYDND
# YYNαY
# DYDαD
# NYNαα
# DDαNH
# DDααH
# DNNNH
# αYNαD
# αYNαY
# YααN
# YHNHH
# HαNH
# YDNαH
# DYDαY
# DNNHH
# HαHH
# DDNYH
# YYDNα
# HNN
# YHDH
# HαND
# NYYND
# αYDαD
# DHNH
# NYHαD
# αHDα
# NYαND
# αYNDY
# αYDαY
# DDαDH
# αYDDY
# αDNH
# DDNH
# DNNDH
# DYNDN
# NαDHY
# HHNH
# NDYHD
# DYDN
# DYNND
# YαNN
# DDNNH
# DαNHH
# NNYHD
# DYDND
# NDYN
# NYYαD
# HαYN
# HDN
# YYDND
# YYDD
# DYNDY
# DDNDH
# DDNαH
# YYNNα
# DYNαY
# YαNH
# YHNH
# DYαND
# YYDN
# DYYND
# DDαNN
# DYNDD
# DαNNH
# HHNHY
# HNNDY

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_180)):
     if sum(freq >= fTC5_180[l] for freq in fTC5null_180[l]) < 1:
#         print(setTC5_180[l], fTC5_180[l], sum(freq >= fTC5_180[l] for freq in fTC5null_180[l]))
        print(setTC5_180[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# DαN
# YYαDH
# NYDND
# DDααH
# DNNNH
# HNN
# αYDαD
# αDNH
# NDYHD
# DYDN
# DYDND
# YYDD
# DDNDH
# DDNαH
# YYDN
# DαNNH
