# %% [markdown]
# # One-Letter Words

# %%
# open the csv files
AP = open('AP.csv')
AC = open('AC.csv')
BPI = open('BPI.csv')
BLOOM = open('BLOOM.csv')
FGEN = open('FGEN.csv')
ICT = open('ICT.csv')
JGS = open('JGS.csv')
MEG = open('MEG.csv')
SMC = open('SMC.csv')
SCC = open('SCC.csv')

#initiFGENze the lists
Date_AP = []
ClosePrice_AP = []
Date_AC = []
ClosePrice_AC = []
Date_BPI = []
ClosePrice_BPI = []
Date_BLOOM = []
ClosePrice_BLOOM = []
Date_FGEN = []
ClosePrice_FGEN = []
Date_ICT = []
ClosePrice_ICT = []
Date_JGS = []
ClosePrice_JGS = []
Date_MEG = []
ClosePrice_MEG = []
Date_SMC = []
ClosePrice_SMC = []
Date_SCC = []
ClosePrice_SCC = []

#skip the header line
AP.readline()
AC.readline()
BPI.readline()
BLOOM.readline()
FGEN.readline()
ICT.readline()
JGS.readline()
MEG.readline()
SMC.readline()
SCC.readline()

#go through the files line by line
for line in AP:
    sline = line.strip().split(',')
    Date_AP.append(sline[0])
    ClosePrice_AP.append(float(sline[1]))
    
for line in AC:
    sline = line.strip().split(',')
    Date_AC.append(sline[0])
    ClosePrice_AC.append(float(sline[1]))
    
for line in BPI:
    sline = line.strip().split(',')
    Date_BPI.append(sline[0])
    ClosePrice_BPI.append(float(sline[1]))
    
for line in BLOOM:
    sline = line.strip().split(',')
    Date_BLOOM.append(sline[0])
    ClosePrice_BLOOM.append(float(sline[1]))
    
for line in FGEN:
    sline = line.strip().split(',')
    Date_FGEN.append(sline[0])
    ClosePrice_FGEN.append(float(sline[1]))
    
for line in ICT:
    sline = line.strip().split(',')
    Date_ICT.append(sline[0])
    ClosePrice_ICT.append(float(sline[1]))
    
for line in JGS:
    sline = line.strip().split(',')
    Date_JGS.append(sline[0])
    ClosePrice_JGS.append(float(sline[1]))
    
for line in MEG:
    sline = line.strip().split(',')
    Date_MEG.append(sline[0])
    ClosePrice_MEG.append(float(sline[1]))
    
for line in SMC:
    sline = line.strip().split(',')
    Date_SMC.append(sline[0])
    ClosePrice_SMC.append(float(sline[1]))
        
for line in SCC:
    sline = line.strip().split(',')
    Date_SCC.append(sline[0])
    ClosePrice_SCC.append(float(sline[1]))


#close files
AP.close()
AC.close()
BPI.close()
BLOOM.close()
FGEN.close()
ICT.close()
JGS.close()
MEG.close()
SMC.close()
SCC.close()# One-Letter Words

# %%
import numpy as np
import datetime

# %%
# convert dates into datetime structure
for n in range(len(Date_AP)):
    Date_AP[n] = datetime.datetime.strptime(Date_AP[n], '%m/%d/%y').date()

for n in range(len(Date_AC)):
    Date_AC[n] = datetime.datetime.strptime(Date_AC[n], '%m/%d/%y').date()
    
for n in range(len(Date_BPI)):
    Date_BPI[n] = datetime.datetime.strptime(Date_BPI[n], '%m/%d/%y').date()

for n in range(len(Date_BLOOM)):
    Date_BLOOM[n] = datetime.datetime.strptime(Date_BLOOM[n], '%m/%d/%y').date()
    
for n in range(len(Date_FGEN)):
    Date_FGEN[n] = datetime.datetime.strptime(Date_FGEN[n], '%m/%d/%y').date()

for n in range(len(Date_ICT)):
    Date_ICT[n] = datetime.datetime.strptime(Date_ICT[n], '%m/%d/%y').date()
    
for n in range(len(Date_JGS)):
    Date_JGS[n] = datetime.datetime.strptime(Date_JGS[n], '%m/%d/%y').date()

for n in range(len(Date_MEG)):
    Date_MEG[n] = datetime.datetime.strptime(Date_MEG[n], '%m/%d/%y').date()
    
for n in range(len(Date_SMC)):
    Date_SMC[n] = datetime.datetime.strptime(Date_SMC[n], '%m/%d/%y').date()

for n in range(len(Date_SCC)):
    Date_SCC[n] = datetime.datetime.strptime(Date_SCC[n], '%m/%d/%y').date()
    
# save Date and ClosePrice
np.save('APDate.npy', Date_AP)
np.save('APClosePrice.npy', ClosePrice_AP)
np.save('ACDate.npy', Date_AC)
np.save('ACClosePrice.npy', ClosePrice_AC)
np.save('BPIDate.npy', Date_BPI)
np.save('BPIClosePrice.npy', ClosePrice_BPI)
np.save('BLOOMDate.npy', Date_BLOOM)
np.save('BLOOMClosePrice.npy', ClosePrice_BLOOM)
np.save('FGENDate.npy', Date_FGEN)
np.save('FGENClosePrice.npy', ClosePrice_FGEN)
np.save('ICTDate.npy', Date_ICT)
np.save('ICTClosePrice.npy', ClosePrice_ICT)
np.save('JGSDate.npy', Date_JGS)
np.save('JGSClosePrice.npy', ClosePrice_JGS)
np.save('MEGDate.npy', Date_MEG)
np.save('MEGClosePrice.npy', ClosePrice_MEG)
np.save('SMCDate.npy', Date_SMC)
np.save('SMCClosePrice.npy', ClosePrice_SMC)
np.save('SCCDate.npy', Date_SCC)
np.save('SCCClosePrice.npy', ClosePrice_SCC)

# %% [markdown]
# # Five-letter Words

# %% [markdown]
# # 3.196 (D) AC - (N) JGS- (R) MEG - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_196 = max(min(Date_AC), min(Date_JGS), min(Date_MEG), min(Date_SMC), min(Date_SCC))
end_196 = min(max(Date_AC), max(Date_JGS), max(Date_MEG), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
AC_196_1 = Date_AC.index(start_196)
AC_196_2 = Date_AC.index(end_196)

JGS_196_1 = Date_JGS.index(start_196)
JGS_196_2 = Date_JGS.index(end_196)

MEG_196_1 = Date_MEG.index(start_196)
MEG_196_2 = Date_MEG.index(end_196)

SMC_196_1 = Date_SMC.index(start_196)
SMC_196_2 = Date_SMC.index(end_196)

SCC_196_1 = Date_SCC.index(start_196)
SCC_196_2 = Date_SCC.index(end_196)

# %%
#save the shortened versions of closing prices
D196 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_196_1:AC_196_2])
N196 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_196_1:JGS_196_2])
R196 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_196_1:MEG_196_2])
Y196 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_196_1:SMC_196_2])
α196 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_196_1:SCC_196_2])

# %%
# import modules
import numpy as np
# import prices

D196 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
N196 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R196 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y196 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α196 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_196 = []
st_196 = []
n = 1
while n < len(D196):
    sc_196 = ''
    if D196[n] > D196[n-1]:
        sc_196 = sc_196 + 'D'
    if N196[n] > N196[n-1]:
        sc_196 = sc_196 + 'N'
    if R196[n] > R196[n-1]:
        sc_196 = sc_196 + 'R'
    if Y196[n] > Y196[n-1]:
        sc_196 = sc_196 + 'Y'
    if α196[n] > α196[n-1]:
        sc_196 = sc_196 + 'α'
    if len(sc_196) > 0:
        st_196.append(sc_196)
    else:
        STC_196.append(st_196)
        st_196 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_196 = STC_196.count([])
# keep only non-empty spatio-temporal sequences
STC_196 = [ st_196 for st_196 in STC_196 if len(st_196) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_196 = len(D196)
lmax_196 = 0
for st_196 in STC_196:
    if len(st_196) < lmin_196:
        lmin_196 = len(st_196)
    if len(st_196) > lmax_196:
        lmax_196 = len(st_196)
        
# restrict spatio-temporal sequences to length-5
STC5_196 = [ st_196 for st_196 in STC_196 if len(st_196) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_196 = []
for n in range(len(STC5_196)):
    tc_196 = [ u for u in STC5_196[n][0] ]
    for k in range(1, len(STC5_196[n])):
        tc_196 = [ u+v for u in tc_196 for v in STC5_196[n][k] ]
    TC5_196 = TC5_196 + tc_196
setTC5_196 = list(set(TC5_196))

# get empirical frequencies
fTC5_196 = [ TC5_196.count(setTC5_196[l]) for l in range(len(setTC5_196)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_196 = [ [] for l in range(len(setTC5_196)) ]
for s in range(100):
    STC5null_196 = [ list(st_196) for st_196 in STC5_196]
    for st_196 in STC5null_196:
        np.random.shuffle(st_196)
    TC5null_196= []
    for n in range(len(STC5null_196)):
        tc_196 = [ u for u in STC5null_196[n][0] ]
        for k in range(1, len(STC5null_196[n])):
            tc_196 = [ u+v for u in tc_196 for v in STC5null_196[n][k] ]
        TC5null_196= TC5null_196+ tc_196
    for l in range(len(setTC5_196)):
        if TC5null_196.count(setTC5_196[l]) > 0:
            fTC5null_196[l].append(TC5null_196.count(setTC5_196[l]))
        else:
            fTC5null_196[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_196)):
     if sum(freq >= fTC5_196[l] for freq in fTC5null_196[l]) < 5:
#         print(setTC5_196[l], fTC5_196[l], sum(freq >= fTC5_196[l] for freq in fTC5null_196[l]))
        print(setTC5_196[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# DYNYR
# DDαRR
# DYYY
# NYNDR
# RYNDD
# YαDαY
# RDαRα
# DYRNR
# NRNN
# RYNDR
# NYDN
# YRαR
# DNNDY
# αDDR
# RαDαY
# DDNαR
# NDRR
# RαYY
# DYNDR
# DRNDR
# DDRRR
# DDαDR
# NYαYD
# DNNαR
# NYNNα
# DYαRR
# RYNYα
# YααYD
# NDNR
# ααDDY
# YYDN
# RYD
# DNN
# YDαR
# DYDNR
# αNDDD
# YNRαY
# RDααN
# RYYαα
# NYNNN
# RNYαY
# DYRRR
# NαRα
# DNNDN
# RYYDα
# RNYYα
# DYNDα
# RRD
# RαYαD
# RYα
# RYYRα
# αDRR
# RYYYα
# YYDD
# NYαα
# DYNRR
# RYN
# RYNNα
# DYNDN
# NYNYN
# RDNαα
# DYαNR
# DYNDD
# DYDN
# DNNDR
# RYYαR
# RNYαα
# DRNDN
# YDDαN
# DDRNR
# RααRY
# RDααα
# RDYYα
# YYRN
# RDYαα
# DDαRD
# RYNRR
# DYNRD
# DDRDR
# DYYαR
# YRRαR
# YααR
# RDYDα

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_196)):
     if sum(freq >= fTC5_196[l] for freq in fTC5null_196[l]) < 1:
#         print(setTC5_196[l], fTC5_196[l], sum(freq >= fTC5_196[l] for freq in fTC5null_196[l]))
        print(setTC5_196[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# DYYY
# DYRNR
# NYDN
# DNNDY
# DYNDR
# DYαRR
# RYNYα
# NDNR
# YYDN
# RYD
# NαRα
# RNYYα
# DYNRR
# RYN
# RNYαα
# RDααα
# RDYYα
# RDYαα

# %% [markdown]
#  # 3.197 (F) BPI - (H) BLOOM- (J) FGEN - (M) ICT - (N) JGS

# %%
#extract overlapping dates
start_197 = max(min(Date_BPI), min(Date_BLOOM), min(Date_FGEN), min(Date_ICT), min(Date_JGS))
end_197 = min(max(Date_BPI), max(Date_BLOOM), max(Date_FGEN), max(Date_ICT), max(Date_JGS))

# %%
#shorten the closing prices
BPI_197_1 = Date_BPI.index(start_197)
BPI_197_2 = Date_BPI.index(end_197)

BLOOM_197_1 = Date_BLOOM.index(start_197)
BLOOM_197_2 = Date_BLOOM.index(end_197)

FGEN_197_1 = Date_FGEN.index(start_197)
FGEN_197_2 = Date_FGEN.index(end_197)

ICT_197_1 = Date_ICT.index(start_197)
ICT_197_2 = Date_ICT.index(end_197)

JGS_197_1 = Date_JGS.index(start_197)
JGS_197_2 = Date_JGS.index(end_197)

# %%
#save the shortened versions of closing prices
F197 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_197_1:BPI_197_2])
H197 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_197_1:BLOOM_197_2])
J197 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_197_1:FGEN_197_2])
M197 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_197_1:ICT_197_2])
N197 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_197_1:JGS_197_2])

# %%
# import modules
import numpy as np
# import prices

F197 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H197 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J197 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M197 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N197 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_197 = []
st_197 = []
n = 1
while n < len(F197):
    sc_197 = ''
    if F197[n] > F197[n-1]:
        sc_197 = sc_197 + 'F'
    if H197[n] > H197[n-1]:
        sc_197 = sc_197 + 'H'
    if J197[n] > J197[n-1]:
        sc_197 = sc_197 + 'J'
    if M197[n] > M197[n-1]:
        sc_197 = sc_197 + 'M'
    if N197[n] > N197[n-1]:
        sc_197 = sc_197 + 'N'
    if len(sc_197) > 0:
        st_197.append(sc_197)
    else:
        STC_197.append(st_197)
        st_197 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 13
#      11 if J197[n] > J197[n-1]:
#      12     sc_197 = sc_197 + 'J'
# ---> 13 if M197[n] > M197[n-1]:
#      14     sc_197 = sc_197 + 'M'
#      15 if N197[n] > N197[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_197 = STC_197.count([])
# keep only non-empty spatio-temporal sequences
STC_197 = [ st_197 for st_197 in STC_197 if len(st_197) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_197 = len(F197)
lmax_197 = 0
for st_197 in STC_197:
    if len(st_197) < lmin_197:
        lmin_197 = len(st_197)
    if len(st_197) > lmax_197:
        lmax_197 = len(st_197)
        
# restrict spatio-temporal sequences to length-5
STC5_197 = [ st_197 for st_197 in STC_197 if len(st_197) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_197 = []
for n in range(len(STC5_197)):
    tc_197 = [ u for u in STC5_197[n][0] ]
    for k in range(1, len(STC5_197[n])):
        tc_197 = [ u+v for u in tc_197 for v in STC5_197[n][k] ]
    TC5_197 = TC5_197 + tc_197
setTC5_197 = list(set(TC5_197))

# get empirical frequencies
fTC5_197 = [ TC5_197.count(setTC5_197[l]) for l in range(len(setTC5_197)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_197 = [ [] for l in range(len(setTC5_197)) ]
for s in range(100):
    STC5null_197 = [ list(st_197) for st_197 in STC5_197]
    for st_197 in STC5null_197:
        np.random.shuffle(st_197)
    TC5null_197= []
    for n in range(len(STC5null_197)):
        tc_197 = [ u for u in STC5null_197[n][0] ]
        for k in range(1, len(STC5null_197[n])):
            tc_197 = [ u+v for u in tc_197 for v in STC5null_197[n][k] ]
        TC5null_197= TC5null_197+ tc_197
    for l in range(len(setTC5_197)):
        if TC5null_197.count(setTC5_197[l]) > 0:
            fTC5null_197[l].append(TC5null_197.count(setTC5_197[l]))
        else:
            fTC5null_197[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_197)):
     if sum(freq >= fTC5_197[l] for freq in fTC5null_197[l]) < 5:
#         print(setTC5_197[l], fTC5_197[l], sum(freq >= fTC5_197[l] for freq in fTC5null_197[l]))
        print(setTC5_197[l])

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_197)):
     if sum(freq >= fTC5_197[l] for freq in fTC5null_197[l]) < 1:
#         print(setTC5_197[l], fTC5_197[l], sum(freq >= fTC5_197[l] for freq in fTC5null_197[l]))
        print(setTC5_197[l])

# %% [markdown]
#  # 3.198 (F) BPI - (H) BLOOM- (J) FGEN - (M) ICT - (R) MEG

# %%
#extract overlapping dates
start_198 = max(min(Date_BPI), min(Date_BLOOM), min(Date_FGEN), min(Date_ICT), min(Date_MEG))
end_198 = min(max(Date_BPI), max(Date_BLOOM), max(Date_FGEN), max(Date_ICT), max(Date_MEG))

# %%
#shorten the closing prices
BPI_198_1 = Date_BPI.index(start_198)
BPI_198_2 = Date_BPI.index(end_198)

BLOOM_198_1 = Date_BLOOM.index(start_198)
BLOOM_198_2 = Date_BLOOM.index(end_198)

FGEN_198_1 = Date_FGEN.index(start_198)
FGEN_198_2 = Date_FGEN.index(end_198)

ICT_198_1 = Date_ICT.index(start_198)
ICT_198_2 = Date_ICT.index(end_198)

MEG_198_1 = Date_MEG.index(start_198)
MEG_198_2 = Date_MEG.index(end_198)

# %%
#save the shortened versions of closing prices
F198 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_198_1:BPI_198_2])
H198 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_198_1:BLOOM_198_2])
J198 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_198_1:FGEN_198_2])
M198 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_198_1:ICT_198_2])
R198 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_198_1:MEG_198_2])

# %%
# import modules
import numpy as np
# import prices

F198 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H198 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J198 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M198 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R198 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_198 = []
st_198 = []
n = 1
while n < len(F198):
    sc_198 = ''
    if F198[n] > F198[n-1]:
        sc_198 = sc_198 + 'F'
    if H198[n] > H198[n-1]:
        sc_198 = sc_198 + 'H'
    if J198[n] > J198[n-1]:
        sc_198 = sc_198 + 'J'
    if M198[n] > M198[n-1]:
        sc_198 = sc_198 + 'M'
    if R198[n] > R198[n-1]:
        sc_198 = sc_198 + 'R'
    if len(sc_198) > 0:
        st_198.append(sc_198)
    else:
        STC_198.append(st_198)
        st_198 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 13
#      11 if J198[n] > J198[n-1]:
#      12     sc_198 = sc_198 + 'J'
# ---> 13 if M198[n] > M198[n-1]:
#      14     sc_198 = sc_198 + 'M'
#      15 if R198[n] > R198[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_198 = STC_198.count([])
# keep only non-empty spatio-temporal sequences
STC_198 = [ st_198 for st_198 in STC_198 if len(st_198) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_198 = len(F198)
lmax_198 = 0
for st_198 in STC_198:
    if len(st_198) < lmin_198:
        lmin_198 = len(st_198)
    if len(st_198) > lmax_198:
        lmax_198 = len(st_198)
        
# restrict spatio-temporal sequences to length-5
STC5_198 = [ st_198 for st_198 in STC_198 if len(st_198) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_198 = []
for n in range(len(STC5_198)):
    tc_198 = [ u for u in STC5_198[n][0] ]
    for k in range(1, len(STC5_198[n])):
        tc_198 = [ u+v for u in tc_198 for v in STC5_198[n][k] ]
    TC5_198 = TC5_198 + tc_198
setTC5_198 = list(set(TC5_198))

# get empirical frequencies
fTC5_198 = [ TC5_198.count(setTC5_198[l]) for l in range(len(setTC5_198)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_198 = [ [] for l in range(len(setTC5_198)) ]
for s in range(100):
    STC5null_198 = [ list(st_198) for st_198 in STC5_198]
    for st_198 in STC5null_198:
        np.random.shuffle(st_198)
    TC5null_198= []
    for n in range(len(STC5null_198)):
        tc_198 = [ u for u in STC5null_198[n][0] ]
        for k in range(1, len(STC5null_198[n])):
            tc_198 = [ u+v for u in tc_198 for v in STC5null_198[n][k] ]
        TC5null_198= TC5null_198+ tc_198
    for l in range(len(setTC5_198)):
        if TC5null_198.count(setTC5_198[l]) > 0:
            fTC5null_198[l].append(TC5null_198.count(setTC5_198[l]))
        else:
            fTC5null_198[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_198)):
     if sum(freq >= fTC5_198[l] for freq in fTC5null_198[l]) < 5:
#         print(setTC5_198[l], fTC5_198[l], sum(freq >= fTC5_198[l] for freq in fTC5null_198[l]))
        print(setTC5_198[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# RJFHR
# HFFHR
# RJJHR
# HMFRF
# FJJHR
# JFMFH
# MFMFM
# MRMFM
# RJJM
# JJMFM
# JFMFM
# HFFHH
# HHHJ
# JJMJM
# RFMF
# HMMRR
# FJMFM
# RFMFM
# RJMM
# JRHFJ
# FJFHH
# HMRH
# JHMFM
# FJJHH
# RJJHH
# FFMFM
# RHJFM
# FJFHR
# MJJHH
# HHFMJ
# HMRF
# HHHF
# JHMMM
# MJMFM
# JRMFM
# RFHFJ
# HMMRF
# RJRM
# FRMFM
# MJJHM
# RJMF
# MFMJR
# RJJHM
# JFMF
# FFH
# JFHFJ
# MFMJM
# HMFHR
# FJJHM
# HFFRH
# RJMFM
# HJMJ
# RFJFJ
# RRJ

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_198)):
     if sum(freq >= fTC5_198[l] for freq in fTC5null_198[l]) < 1:
#         print(setTC5_198[l], fTC5_198[l], sum(freq >= fTC5_198[l] for freq in fTC5null_198[l]))
        print(setTC5_198[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# HMFRF
# JJMJM
# FJMFM
# JRHFJ
# MJMFM
# MFMJR
# JFMF

# %% [markdown]
#  # 3.199 (F) BPI - (H) BLOOM- (J) FGEN - (M) ICT - (Y) SMC

# %%
#extract overlapping dates
start_199 = max(min(Date_BPI), min(Date_BLOOM), min(Date_FGEN), min(Date_ICT), min(Date_SMC))
end_199 = min(max(Date_BPI), max(Date_BLOOM), max(Date_FGEN), max(Date_ICT), max(Date_SMC))

# %%
#shorten the closing prices
BPI_199_1 = Date_BPI.index(start_199)
BPI_199_2 = Date_BPI.index(end_199)

BLOOM_199_1 = Date_BLOOM.index(start_199)
BLOOM_199_2 = Date_BLOOM.index(end_199)

FGEN_199_1 = Date_FGEN.index(start_199)
FGEN_199_2 = Date_FGEN.index(end_199)

ICT_199_1 = Date_ICT.index(start_199)
ICT_199_2 = Date_ICT.index(end_199)

SMC_199_1 = Date_SMC.index(start_199)
SMC_199_2 = Date_SMC.index(end_199)

# %%
#save the shortened versions of closing prices
F199 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_199_1:BPI_199_2])
H199 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_199_1:BLOOM_199_2])
J199 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_199_1:FGEN_199_2])
M199 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_199_1:ICT_199_2])
Y199 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_199_1:SMC_199_2])

# %%
# import modules
import numpy as np
# import prices

F199 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H199 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J199 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M199 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
Y199 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_199 = []
st_199 = []
n = 1
while n < len(F199):
    sc_199 = ''
    if F199[n] > F199[n-1]:
        sc_199 = sc_199 + 'F'
    if H199[n] > H199[n-1]:
        sc_199 = sc_199 + 'H'
    if J199[n] > J199[n-1]:
        sc_199 = sc_199 + 'J'
    if M199[n] > M199[n-1]:
        sc_199 = sc_199 + 'M'
    if Y199[n] > Y199[n-1]:
        sc_199 = sc_199 + 'Y'
    if len(sc_199) > 0:
        st_199.append(sc_199)
    else:
        STC_199.append(st_199)
        st_199 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[29], line 13
#      11 if J199[n] > J199[n-1]:
#      12     sc_199 = sc_199 + 'J'
# ---> 13 if M199[n] > M199[n-1]:
#      14     sc_199 = sc_199 + 'M'
#      15 if Y199[n] > Y199[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_199 = STC_199.count([])
# keep only non-empty spatio-temporal sequences
STC_199 = [ st_199 for st_199 in STC_199 if len(st_199) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_199 = len(F199)
lmax_199 = 0
for st_199 in STC_199:
    if len(st_199) < lmin_199:
        lmin_199 = len(st_199)
    if len(st_199) > lmax_199:
        lmax_199 = len(st_199)
        
# restrict spatio-temporal sequences to length-5
STC5_199 = [ st_199 for st_199 in STC_199 if len(st_199) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_199 = []
for n in range(len(STC5_199)):
    tc_199 = [ u for u in STC5_199[n][0] ]
    for k in range(1, len(STC5_199[n])):
        tc_199 = [ u+v for u in tc_199 for v in STC5_199[n][k] ]
    TC5_199 = TC5_199 + tc_199
setTC5_199 = list(set(TC5_199))

# get empirical frequencies
fTC5_199 = [ TC5_199.count(setTC5_199[l]) for l in range(len(setTC5_199)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_199 = [ [] for l in range(len(setTC5_199)) ]
for s in range(100):
    STC5null_199 = [ list(st_199) for st_199 in STC5_199]
    for st_199 in STC5null_199:
        np.random.shuffle(st_199)
    TC5null_199= []
    for n in range(len(STC5null_199)):
        tc_199 = [ u for u in STC5null_199[n][0] ]
        for k in range(1, len(STC5null_199[n])):
            tc_199 = [ u+v for u in tc_199 for v in STC5null_199[n][k] ]
        TC5null_199= TC5null_199+ tc_199
    for l in range(len(setTC5_199)):
        if TC5null_199.count(setTC5_199[l]) > 0:
            fTC5null_199[l].append(TC5null_199.count(setTC5_199[l]))
        else:
            fTC5null_199[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_199)):
     if sum(freq >= fTC5_199[l] for freq in fTC5null_199[l]) < 5:
#         print(setTC5_199[l], fTC5_199[l], sum(freq >= fTC5_199[l] for freq in fTC5null_199[l]))
        print(setTC5_199[l])

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_199)):
     if sum(freq >= fTC5_199[l] for freq in fTC5null_199[l]) < 1:
#         print(setTC5_199[l], fTC5_199[l], sum(freq >= fTC5_199[l] for freq in fTC5null_199[l]))
        print(setTC5_199[l])

# %% [markdown]
#  # 3.200 (F) BPI - (H) BLOOM- (J) FGEN - (M) ICT - (α) SCC

# %%
#extract overlapping dates
start_200 = max(min(Date_BPI), min(Date_BLOOM), min(Date_FGEN), min(Date_ICT), min(Date_SCC))
end_200 = min(max(Date_BPI), max(Date_BLOOM), max(Date_FGEN), max(Date_ICT), max(Date_SCC))

# %%
#shorten the closing prices
BPI_200_1 = Date_BPI.index(start_200)
BPI_200_2 = Date_BPI.index(end_200)

BLOOM_200_1 = Date_BLOOM.index(start_200)
BLOOM_200_2 = Date_BLOOM.index(end_200)

FGEN_200_1 = Date_FGEN.index(start_200)
FGEN_200_2 = Date_FGEN.index(end_200)

ICT_200_1 = Date_ICT.index(start_200)
ICT_200_2 = Date_ICT.index(end_200)

SCC_200_1 = Date_SCC.index(start_200)
SCC_200_2 = Date_SCC.index(end_200)

# %%
#save the shortened versions of closing prices
F200 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_200_1:BPI_200_2])
H200 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_200_1:BLOOM_200_2])
J200 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_200_1:FGEN_200_2])
M200 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_200_1:ICT_200_2])
α200 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_200_1:SCC_200_2])

# %%
# import modules
import numpy as np
# import prices

F200 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H200 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J200 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M200 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
α200 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_200 = []
st_200 = []
n = 1
while n < len(F200):
    sc_200 = ''
    if F200[n] > F200[n-1]:
        sc_200 = sc_200 + 'F'
    if H200[n] > H200[n-1]:
        sc_200 = sc_200 + 'H'
    if J200[n] > J200[n-1]:
        sc_200 = sc_200 + 'J'
    if M200[n] > M200[n-1]:
        sc_200 = sc_200 + 'M'
    if α200[n] > α200[n-1]:
        sc_200 = sc_200 + 'α'
    if len(sc_200) > 0:
        st_200.append(sc_200)
    else:
        STC_200.append(st_200)
        st_200 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 13
#      11 if J200[n] > J200[n-1]:
#      12     sc_200 = sc_200 + 'J'
# ---> 13 if M200[n] > M200[n-1]:
#      14     sc_200 = sc_200 + 'M'
#      15 if α200[n] > α200[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_200 = STC_200.count([])
# keep only non-empty spatio-temporal sequences
STC_200 = [ st_200 for st_200 in STC_200 if len(st_200) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_200 = len(F200)
lmax_200 = 0
for st_200 in STC_200:
    if len(st_200) < lmin_200:
        lmin_200 = len(st_200)
    if len(st_200) > lmax_200:
        lmax_200 = len(st_200)
        
# restrict spatio-temporal sequences to length-5
STC5_200 = [ st_200 for st_200 in STC_200 if len(st_200) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_200 = []
for n in range(len(STC5_200)):
    tc_200 = [ u for u in STC5_200[n][0] ]
    for k in range(1, len(STC5_200[n])):
        tc_200 = [ u+v for u in tc_200 for v in STC5_200[n][k] ]
    TC5_200 = TC5_200 + tc_200
setTC5_200 = list(set(TC5_200))

# get empirical frequencies
fTC5_200 = [ TC5_200.count(setTC5_200[l]) for l in range(len(setTC5_200)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_200 = [ [] for l in range(len(setTC5_200)) ]
for s in range(100):
    STC5null_200 = [ list(st_200) for st_200 in STC5_200]
    for st_200 in STC5null_200:
        np.random.shuffle(st_200)
    TC5null_200= []
    for n in range(len(STC5null_200)):
        tc_200 = [ u for u in STC5null_200[n][0] ]
        for k in range(1, len(STC5null_200[n])):
            tc_200 = [ u+v for u in tc_200 for v in STC5null_200[n][k] ]
        TC5null_200= TC5null_200+ tc_200
    for l in range(len(setTC5_200)):
        if TC5null_200.count(setTC5_200[l]) > 0:
            fTC5null_200[l].append(TC5null_200.count(setTC5_200[l]))
        else:
            fTC5null_200[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_200)):
     if sum(freq >= fTC5_200[l] for freq in fTC5null_200[l]) < 5:
#         print(setTC5_200[l], fTC5_200[l], sum(freq >= fTC5_200[l] for freq in fTC5null_200[l]))
        print(setTC5_200[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FFM
# MFMMM
# HHααJ
# MJMMM
# αJHJα
# FαFJ
# MJMα
# JFHFα
# HαJα
# MJαJJ
# HHαMJ
# αJαJH
# MFM
# HHFMα
# HHFαα
# ααJM
# MFJMM
# JFFFα
# FFααH
# HHFMF
# JαFMM
# HHFαJ
# HαMα
# FFHα
# JJMJM
# αFHFJ
# HHαMF
# JFHα
# MαJMM
# MHα
# MααMM
# HJMα
# JHMFM
# αJHJJ
# αFαFJ
# HHFαF
# JFMα
# αFJFα
# HHFMJ
# JHMMM
# JFJαα
# MHMFM
# FMαMF
# MJMFM
# MHMMM
# JJMα
# HHααF
# MFα
# FJHFF
# FJHJJ
# FMFJ
# αFHFα
# MHJ
# HHααα
# MJαFJ
# HHαMα
# JFHαα
# JFHFJ
# αJαJJ
# αJαFJ
# αJαJF
# αMαMH
# FMFF

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_200)):
     if sum(freq >= fTC5_200[l] for freq in fTC5null_200[l]) < 1:
#         print(setTC5_200[l], fTC5_200[l], sum(freq >= fTC5_200[l] for freq in fTC5null_200[l]))
        print(setTC5_200[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# HHααJ
# JFHFα
# HαJα
# HHαMJ
# HHFαJ
# αFHFJ
# JFMα
# HHFMJ
# FMαMF
# JJMα
# JFHFJ
# αJαJJ
# αMαMH

# %% [markdown]
#  # 3.201 (F) BPI - (H) BLOOM- (J) FGEN - (N) JGS - (R) MEG

# %%
#extract overlapping dates
start_201 = max(min(Date_BPI), min(Date_BLOOM), min(Date_FGEN), min(Date_JGS), min(Date_MEG))
end_201 = min(max(Date_BPI), max(Date_BLOOM), max(Date_FGEN), max(Date_JGS), max(Date_MEG))

# %%
#shorten the closing prices
BPI_201_1 = Date_BPI.index(start_201)
BPI_201_2 = Date_BPI.index(end_201)

BLOOM_201_1 = Date_BLOOM.index(start_201)
BLOOM_201_2 = Date_BLOOM.index(end_201)

FGEN_201_1 = Date_FGEN.index(start_201)
FGEN_201_2 = Date_FGEN.index(end_201)

JGS_201_1 = Date_JGS.index(start_201)
JGS_201_2 = Date_JGS.index(end_201)

MEG_201_1 = Date_MEG.index(start_201)
MEG_201_2 = Date_MEG.index(end_201)

# %%
#save the shortened versions of closing prices
F201 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_201_1:BPI_201_2])
H201 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_201_1:BLOOM_201_2])
J201 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_201_1:FGEN_201_2])
N201 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_201_1:JGS_201_2])
R201 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_201_1:MEG_201_2])

# %%
# import modules
import numpy as np
# import prices

F201 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H201 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J201 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N201 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R201 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_201 = []
st_201 = []
n = 1
while n < len(F201):
    sc_201 = ''
    if F201[n] > F201[n-1]:
        sc_201 = sc_201 + 'F'
    if H201[n] > H201[n-1]:
        sc_201 = sc_201 + 'H'
    if J201[n] > J201[n-1]:
        sc_201 = sc_201 + 'J'
    if N201[n] > N201[n-1]:
        sc_201 = sc_201 + 'N'
    if R201[n] > R201[n-1]:
        sc_201 = sc_201 + 'R'
    if len(sc_201) > 0:
        st_201.append(sc_201)
    else:
        STC_201.append(st_201)
        st_201 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_201 = STC_201.count([])
# keep only non-empty spatio-temporal sequences
STC_201 = [ st_201 for st_201 in STC_201 if len(st_201) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_201 = len(F201)
lmax_201 = 0
for st_201 in STC_201:
    if len(st_201) < lmin_201:
        lmin_201 = len(st_201)
    if len(st_201) > lmax_201:
        lmax_201 = len(st_201)
        
# restrJGS spatio-temporal sequences to length-5
STC5_201 = [ st_201 for st_201 in STC_201 if len(st_201) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_201 = []
for n in range(len(STC5_201)):
    tc_201 = [ u for u in STC5_201[n][0] ]
    for k in range(1, len(STC5_201[n])):
        tc_201 = [ u+v for u in tc_201 for v in STC5_201[n][k] ]
    TC5_201 = TC5_201 + tc_201
setTC5_201 = list(set(TC5_201))

# get empirical frequencies
fTC5_201 = [ TC5_201.count(setTC5_201[l]) for l in range(len(setTC5_201)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_201 = [ [] for l in range(len(setTC5_201)) ]
for s in range(100):
    STC5null_201 = [ list(st_201) for st_201 in STC5_201]
    for st_201 in STC5null_201:
        np.random.shuffle(st_201)
    TC5null_201= []
    for n in range(len(STC5null_201)):
        tc_201 = [ u for u in STC5null_201[n][0] ]
        for k in range(1, len(STC5null_201[n])):
            tc_201 = [ u+v for u in tc_201 for v in STC5null_201[n][k] ]
        TC5null_201= TC5null_201+ tc_201
    for l in range(len(setTC5_201)):
        if TC5null_201.count(setTC5_201[l]) > 0:
            fTC5null_201[l].append(TC5null_201.count(setTC5_201[l]))
        else:
            fTC5null_201[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_201)):
     if sum(freq >= fTC5_201[l] for freq in fTC5null_201[l]) < 5:
#         print(setTC5_201[l], fTC5_201[l], sum(freq >= fTC5_201[l] for freq in fTC5null_201[l]))
        print(setTC5_201[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# NFFNH
# JNFH
# RJHNH
# RJHHH
# RRFJ
# FJJHR
# NFJJR
# FFJNR
# RJJRF
# FJRJN
# RRF
# JNFJ
# FFRJN
# FFFHJ
# RHHNH
# FFNRN
# JRFH
# HHFRJ
# JNRH
# NRFJ
# RHHNJ
# FFFNR
# FFFRN
# HFFHH
# NFFNJ
# RFFHJ
# RJJFF
# NFNRH
# FNHNH
# NFFJJ
# FJFNH
# FRNRN
# NJFRH
# HJHNH
# NNFH
# RJFHH
# RJJNJ
# RJJHJ
# NFNRN
# HHHNH
# RJHNJ
# HHJNJ
# FJHNJ
# HHJNR
# NJJJF
# RRFRH
# NJJNH
# FFFRH
# HHN
# NJJFH
# HRFJ
# JNJH
# NFFJH
# FFFHH
# FJJNH
# FJHNH
# FFNNH
# FRFJ
# RJJFR
# RJFNH
# NJNRN
# NNFNH
# NFJNR
# HFFRH
# NJFHH
# NJFNH
# RJJJF
# RJFHJ
# HHFNJ
# FFFNH
# NFJJF
# NJJFR
# NFFRH
# NRFRH
# FJHFJ

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_201)):
     if sum(freq >= fTC5_201[l] for freq in fTC5null_201[l]) < 1:
#         print(setTC5_201[l], fTC5_201[l], sum(freq >= fTC5_201[l] for freq in fTC5null_201[l]))
        print(setTC5_201[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# NFFNH
# JNFH
# FFRJN
# JRFH
# RJJHJ
# HRFJ
# JNJH
# NJFNH
# RJFHJ
# FFFNH

# %% [markdown]
#  # 3.202 (F) BPI - (H) BLOOM- (J) FGEN - (N) SMC - (Y) JGS

# %%
#extract overlapping dates
start_202 = max(min(Date_BPI), min(Date_BLOOM), min(Date_FGEN), min(Date_JGS), min(Date_SMC))
end_202 = min(max(Date_BPI), max(Date_BLOOM), max(Date_FGEN), max(Date_JGS), max(Date_SMC))

# %%
#shorten the closing prices
BPI_202_1 = Date_BPI.index(start_202)
BPI_202_2 = Date_BPI.index(end_202)

BLOOM_202_1 = Date_BLOOM.index(start_202)
BLOOM_202_2 = Date_BLOOM.index(end_202)

FGEN_202_1 = Date_FGEN.index(start_202)
FGEN_202_2 = Date_FGEN.index(end_202)

JGS_202_1 = Date_JGS.index(start_202)
JGS_202_2 = Date_JGS.index(end_202)

SMC_202_1 = Date_SMC.index(start_202)
SMC_202_2 = Date_SMC.index(end_202)

# %%
#save the shortened versions of closing prices
F202 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_202_1:BPI_202_2])
H202 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_202_1:BLOOM_202_2])
J202 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_202_1:FGEN_202_2])
N202 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_202_1:JGS_202_2])
Y202 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_202_1:SMC_202_2])

# %%
# import modules
import numpy as np
# import prices

F202 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H202 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J202 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N202 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y202 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_202 = []
st_202 = []
n = 1
while n < len(F202):
    sc_202 = ''
    if F202[n] > F202[n-1]:
        sc_202 = sc_202 + 'F'
    if H202[n] > H202[n-1]:
        sc_202 = sc_202 + 'H'
    if J202[n] > J202[n-1]:
        sc_202 = sc_202 + 'J'
    if N202[n] > N202[n-1]:
        sc_202 = sc_202 + 'N'
    if Y202[n] > Y202[n-1]:
        sc_202 = sc_202 + 'Y'
    if len(sc_202) > 0:
        st_202.append(sc_202)
    else:
        STC_202.append(st_202)
        st_202 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_202 = STC_202.count([])
# keep only non-empty spatio-temporal sequences
STC_202 = [ st_202 for st_202 in STC_202 if len(st_202) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_202 = len(F202)
lmax_202 = 0
for st_202 in STC_202:
    if len(st_202) < lmin_202:
        lmin_202 = len(st_202)
    if len(st_202) > lmax_202:
        lmax_202 = len(st_202)
        
# restrJGS spatio-temporal sequences to length-5
STC5_202 = [ st_202 for st_202 in STC_202 if len(st_202) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_202 = []
for n in range(len(STC5_202)):
    tc_202 = [ u for u in STC5_202[n][0] ]
    for k in range(1, len(STC5_202[n])):
        tc_202 = [ u+v for u in tc_202 for v in STC5_202[n][k] ]
    TC5_202 = TC5_202 + tc_202
setTC5_202 = list(set(TC5_202))

# get empirical frequencies
fTC5_202 = [ TC5_202.count(setTC5_202[l]) for l in range(len(setTC5_202)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_202 = [ [] for l in range(len(setTC5_202)) ]
for s in range(100):
    STC5null_202 = [ list(st_202) for st_202 in STC5_202]
    for st_202 in STC5null_202:
        np.random.shuffle(st_202)
    TC5null_202= []
    for n in range(len(STC5null_202)):
        tc_202 = [ u for u in STC5null_202[n][0] ]
        for k in range(1, len(STC5null_202[n])):
            tc_202 = [ u+v for u in tc_202 for v in STC5null_202[n][k] ]
        TC5null_202= TC5null_202+ tc_202
    for l in range(len(setTC5_202)):
        if TC5null_202.count(setTC5_202[l]) > 0:
            fTC5null_202[l].append(TC5null_202.count(setTC5_202[l]))
        else:
            fTC5null_202[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_202)):
     if sum(freq >= fTC5_202[l] for freq in fTC5null_202[l]) < 5:
#         print(setTC5_202[l], fTC5_202[l], sum(freq >= fTC5_202[l] for freq in fTC5null_202[l]))
        print(setTC5_202[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# NFFNH
# JNFH
# HHYNN
# FYFJ
# YFJFY
# YNHNJ
# YYJFN
# FYFNN
# YYYJ
# FYYN
# HJHNJ
# YNNH
# FJF
# HHYNF
# FFJFY
# YFNYH
# NYNJJ
# YFHHJ
# FNFH
# FFHFY
# FFNYN
# NNJH
# YNFH
# NFFNJ
# FYYJ
# FJYY
# JYHHJ
# HNHNJ
# FYFNJ
# NFFJJ
# FJYN
# NJFFF
# NYFNJ
# HJHNH
# NNFH
# FJYJ
# YNHNH
# FNYH
# YFJYY
# FJHNJ
# NHFNJ
# FYYY
# NFFJF
# HHHNJ
# HNHNH
# FFFNJ
# NHJNJ
# HNFJ
# YFJFN
# NJFJJ
# JNJH
# YYJFY
# NFFJH
# FYNNH
# HJFJ
# NYFJJ
# HYYJ
# HNFH
# NNYH
# NJFFJ
# FJNY
# YFHNJ

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_202)):
     if sum(freq >= fTC5_202[l] for freq in fTC5null_202[l]) < 1:
#         print(setTC5_202[l], fTC5_202[l], sum(freq >= fTC5_202[l] for freq in fTC5null_202[l]))
        print(setTC5_202[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# JNFH
# FJF
# NFFNJ
# FYYJ
# NFFJJ
# NNFH
# FJYJ
# FYYY
# NFFJH
# HNFH

# %% [markdown]
#  # 3.203 (F) BPI - (H) BLOOM- (J) FGEN - (N) SMC - (α) SCC

# %%
#extract overlapping dates
start_203 = max(min(Date_BPI), min(Date_BLOOM), min(Date_FGEN), min(Date_JGS), min(Date_SCC))
end_203 = min(max(Date_BPI), max(Date_BLOOM), max(Date_FGEN), max(Date_JGS), max(Date_SCC))

# %%
#shorten the closing prices
BPI_203_1 = Date_BPI.index(start_203)
BPI_203_2 = Date_BPI.index(end_203)

BLOOM_203_1 = Date_BLOOM.index(start_203)
BLOOM_203_2 = Date_BLOOM.index(end_203)

FGEN_203_1 = Date_FGEN.index(start_203)
FGEN_203_2 = Date_FGEN.index(end_203)

JGS_203_1 = Date_JGS.index(start_203)
JGS_203_2 = Date_JGS.index(end_203)

SCC_203_1 = Date_SCC.index(start_203)
SCC_203_2 = Date_SCC.index(end_203)

# %%
#save the shortened versions of closing prices
F203 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_203_1:BPI_203_2])
H203 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_203_1:BLOOM_203_2])
J203 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_203_1:FGEN_203_2])
N203 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_203_1:JGS_203_2])
α203 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_203_1:SCC_203_2])

# %%
# import modules
import numpy as np
# import prices

F203 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H203 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J203 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N203 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
α203 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_203 = []
st_203 = []
n = 1
while n < len(F203):
    sc_203 = ''
    if F203[n] > F203[n-1]:
        sc_203 = sc_203 + 'F'
    if H203[n] > H203[n-1]:
        sc_203 = sc_203 + 'H'
    if J203[n] > J203[n-1]:
        sc_203 = sc_203 + 'J'
    if N203[n] > N203[n-1]:
        sc_203 = sc_203 + 'N'
    if α203[n] > α203[n-1]:
        sc_203 = sc_203 + 'α'
    if len(sc_203) > 0:
        st_203.append(sc_203)
    else:
        STC_203.append(st_203)
        st_203 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_203 = STC_203.count([])
# keep only non-empty spatio-temporal sequences
STC_203 = [ st_203 for st_203 in STC_203 if len(st_203) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_203 = len(F203)
lmax_203 = 0
for st_203 in STC_203:
    if len(st_203) < lmin_203:
        lmin_203 = len(st_203)
    if len(st_203) > lmax_203:
        lmax_203 = len(st_203)
        
# restrJGS spatio-temporal sequences to length-5
STC5_203 = [ st_203 for st_203 in STC_203 if len(st_203) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_203 = []
for n in range(len(STC5_203)):
    tc_203 = [ u for u in STC5_203[n][0] ]
    for k in range(1, len(STC5_203[n])):
        tc_203 = [ u+v for u in tc_203 for v in STC5_203[n][k] ]
    TC5_203 = TC5_203 + tc_203
setTC5_203 = list(set(TC5_203))

# get empirical frequencies
fTC5_203 = [ TC5_203.count(setTC5_203[l]) for l in range(len(setTC5_203)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_203 = [ [] for l in range(len(setTC5_203)) ]
for s in range(100):
    STC5null_203 = [ list(st_203) for st_203 in STC5_203]
    for st_203 in STC5null_203:
        np.random.shuffle(st_203)
    TC5null_203= []
    for n in range(len(STC5null_203)):
        tc_203 = [ u for u in STC5null_203[n][0] ]
        for k in range(1, len(STC5null_203[n])):
            tc_203 = [ u+v for u in tc_203 for v in STC5null_203[n][k] ]
        TC5null_203= TC5null_203+ tc_203
    for l in range(len(setTC5_203)):
        if TC5null_203.count(setTC5_203[l]) > 0:
            fTC5null_203[l].append(TC5null_203.count(setTC5_203[l]))
        else:
            fTC5null_203[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_203)):
     if sum(freq >= fTC5_203[l] for freq in fTC5null_203[l]) < 5:
#         print(setTC5_203[l], fTC5_203[l], sum(freq >= fTC5_203[l] for freq in fTC5null_203[l]))
        print(setTC5_203[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# JNFH
# αJNNJ
# αFN
# NαJH
# HHJFF
# FNHFF
# FJHNF
# ααJN
# αHJNJ
# HHααJ
# FJαNα
# αJNFF
# HHHFN
# JJJα
# HJJα
# αJHJα
# FαFJ
# FHHFα
# αJJNJ
# JαFH
# FJNJN
# HJFα
# FNNαH
# αJαJH
# HHαNJ
# HHJFH
# HHFNN
# NJJFF
# NNJH
# JJNα
# HαHFJ
# αJNFN
# FJαFH
# HHFNF
# αJNNN
# αJNNF
# HHHFF
# FJ
# HHHNF
# NNFH
# HHJNN
# HHHNN
# FJHFα
# NαNα
# HHHFJ
# HHJNJ
# FNαNH
# FJαNH
# αJNFα
# FJNNH
# JαJH
# FαFαJ
# ααJH
# αJJFN
# HHHNJ
# NJJJF
# FHNα
# HαHNJ
# HJJH
# HJFH
# FFααα
# FJHFF
# αJNNH
# HHHFα
# NJJFH
# HHJJF
# αHJNN
# αJNFJ
# ααHH
# αHJNF
# FJααH
# FNNNH
# αHJNα
# FJHFJ
# HHJJJ

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_203)):
     if sum(freq >= fTC5_203[l] for freq in fTC5null_203[l]) < 1:
#         print(setTC5_203[l], fTC5_203[l], sum(freq >= fTC5_203[l] for freq in fTC5null_203[l]))
        print(setTC5_203[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# JNFH
# αHJNJ
# HHHFN
# FNNαH
# NNJH
# HHHFF
# HHHNF
# NNFH
# HHHNN
# HHJNJ
# FJαNH
# HHHNJ
# FJHFF
# αHJNN
# αJNFJ
# FNNNH

# %% [markdown]
#  # 3.204 (F) BPI - (H) BLOOM- (J) FGEN - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_204 = max(min(Date_BPI), min(Date_BLOOM), min(Date_FGEN), min(Date_MEG), min(Date_SMC))
end_204 = min(max(Date_BPI), max(Date_BLOOM), max(Date_FGEN), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
BPI_204_1 = Date_BPI.index(start_204)
BPI_204_2 = Date_BPI.index(end_204)

BLOOM_204_1 = Date_BLOOM.index(start_204)
BLOOM_204_2 = Date_BLOOM.index(end_204)

FGEN_204_1 = Date_FGEN.index(start_204)
FGEN_204_2 = Date_FGEN.index(end_204)

MEG_204_1 = Date_MEG.index(start_204)
MEG_204_2 = Date_MEG.index(end_204)

SMC_204_1 = Date_SMC.index(start_204)
SMC_204_2 = Date_SMC.index(end_204)

# %%
#save the shortened versions of closing prices
F204 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_204_1:BPI_204_2])
H204 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_204_1:BLOOM_204_2])
J204 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_204_1:FGEN_204_2])
R204 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_204_1:MEG_204_2])
Y204 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_204_1:SMC_204_2])

# %%
# import modules
import numpy as np
# import prices

F204 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H204 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J204 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
R204 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y204 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_204 = []
st_204 = []
n = 1
while n < len(F204):
    sc_204 = ''
    if F204[n] > F204[n-1]:
        sc_204 = sc_204 + 'F'
    if H204[n] > H204[n-1]:
        sc_204 = sc_204 + 'H'
    if J204[n] > J204[n-1]:
        sc_204 = sc_204 + 'J'
    if R204[n] > R204[n-1]:
        sc_204 = sc_204 + 'R'
    if Y204[n] > Y204[n-1]:
        sc_204 = sc_204 + 'Y'
    if len(sc_204) > 0:
        st_204.append(sc_204)
    else:
        STC_204.append(st_204)
        st_204 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_204 = STC_204.count([])
# keep only non-empty spatio-temporal sequences
STC_204 = [ st_204 for st_204 in STC_204 if len(st_204) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_204 = len(F204)
lmax_204 = 0
for st_204 in STC_204:
    if len(st_204) < lmin_204:
        lmin_204 = len(st_204)
    if len(st_204) > lmax_204:
        lmax_204 = len(st_204)
        
# restrict spatio-temporal sequences to length-5
STC5_204 = [ st_204 for st_204 in STC_204 if len(st_204) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_204 = []
for n in range(len(STC5_204)):
    tc_204 = [ u for u in STC5_204[n][0] ]
    for k in range(1, len(STC5_204[n])):
        tc_204 = [ u+v for u in tc_204 for v in STC5_204[n][k] ]
    TC5_204 = TC5_204 + tc_204
setTC5_204 = list(set(TC5_204))

# get empirical frequencies
fTC5_204 = [ TC5_204.count(setTC5_204[l]) for l in range(len(setTC5_204)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_204 = [ [] for l in range(len(setTC5_204)) ]
for s in range(100):
    STC5null_204 = [ list(st_204) for st_204 in STC5_204]
    for st_204 in STC5null_204:
        np.random.shuffle(st_204)
    TC5null_204= []
    for n in range(len(STC5null_204)):
        tc_204 = [ u for u in STC5null_204[n][0] ]
        for k in range(1, len(STC5null_204[n])):
            tc_204 = [ u+v for u in tc_204 for v in STC5null_204[n][k] ]
        TC5null_204= TC5null_204+ tc_204
    for l in range(len(setTC5_204)):
        if TC5null_204.count(setTC5_204[l]) > 0:
            fTC5null_204[l].append(TC5null_204.count(setTC5_204[l]))
        else:
            fTC5null_204[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_204)):
     if sum(freq >= fTC5_204[l] for freq in fTC5null_204[l]) < 5:
#         print(setTC5_204[l], fTC5_204[l], sum(freq >= fTC5_204[l] for freq in fTC5null_204[l]))
        print(setTC5_204[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# RHFF
# YJFRJ
# RHYRH
# YYJFF
# FJH
# RFFRH
# FRF
# YFFRY
# JRFH
# YRFRH
# HJFJJ
# RFFHH
# RJRHJ
# HFFHH
# HFFJH
# RFFHJ
# YFRRJ
# YHFRH
# YJRRJ
# RFHHJ
# FJYY
# HFFFY
# RFRRH
# YHFRY
# YFRRH
# FYJYR
# YJYJH
# RHRRH
# HHYRF
# YYFFY
# HHRRY
# FRFYR
# YFRRY
# YYFYY
# HRFJH
# YHRRY
# YHRR
# HHYRY
# RJFHH
# YJFHJ
# RRRHJ
# FRFJJ
# FYRJJ
# YRRRJ
# YRF
# HJFHJ
# RHYYJ
# HHFRY
# YHRH
# YHYRH
# YJRHJ
# RFRHJ
# HRFJJ
# HRYYJ
# FYYY
# YHRRH
# YFFHJ
# YRFHJ
# HJYYJ
# YFFFY
# FYFJJ
# YFRHJ
# YHYRY
# FYRRR
# RHFRH
# HHYRH
# HFFRF
# YRRHJ
# HFFJJ
# YFYRH
# YJFFY
# FRFJR
# YFFRH
# FJYRH
# HJRJJ
# YYJFY
# YRFRJ
# HFFHJ
# YJRJ
# HHRRJ
# FRYY
# RJHHJ
# YRFFY
# YRY
# HFFRH
# YFFRJ
# HHRJJ
# YRFFR
# RJFHJ
# HHYJY
# YHRJ
# RRFHJ
# RHYRY

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_204)):
     if sum(freq >= fTC5_204[l] for freq in fTC5null_204[l]) < 1:
#         print(setTC5_204[l], fTC5_204[l], sum(freq >= fTC5_204[l] for freq in fTC5null_204[l]))
        print(setTC5_204[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# YJFRJ
# RHYRH
# RFFHJ
# YJRRJ
# RFRRH
# YFRRH
# HHRRY
# YHRR
# HHYRY
# YJFHJ
# RRRHJ
# YHYRH
# YHRRH
# YFFHJ
# YRFHJ
# YFFFY
# YFRHJ
# YHYRY
# YRRHJ
# YFYRH
# RJFHJ
# YHRJ

# %% [markdown]
#  # 3.205 (F) BPI - (H) BLOOM- (J) FGEN - (R) MEG - (α) SCC

# %%
#extract overlapping dates
start_205 = max(min(Date_BPI), min(Date_BLOOM), min(Date_FGEN), min(Date_MEG), min(Date_SCC))
end_205 = min(max(Date_BPI), max(Date_BLOOM), max(Date_FGEN), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
BPI_205_1 = Date_BPI.index(start_205)
BPI_205_2 = Date_BPI.index(end_205)

BLOOM_205_1 = Date_BLOOM.index(start_205)
BLOOM_205_2 = Date_BLOOM.index(end_205)

FGEN_205_1 = Date_FGEN.index(start_205)
FGEN_205_2 = Date_FGEN.index(end_205)

MEG_205_1 = Date_MEG.index(start_205)
MEG_205_2 = Date_MEG.index(end_205)

SCC_205_1 = Date_SCC.index(start_205)
SCC_205_2 = Date_SCC.index(end_205)

# %%
#save the shortened versions of closing prices
F205 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_205_1:BPI_205_2])
H205 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_205_1:BLOOM_205_2])
J205 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_205_1:FGEN_205_2])
R205 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_205_1:MEG_205_2])
α205 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_205_1:SCC_205_2])

# %%
# import modules
import numpy as np
# import prices

F205 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H205 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J205 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
R205 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α205 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_205 = []
st_205 = []
n = 1
while n < len(F205):
    sc_205 = ''
    if F205[n] > F205[n-1]:
        sc_205 = sc_205 + 'F'
    if H205[n] > H205[n-1]:
        sc_205 = sc_205 + 'H'
    if J205[n] > J205[n-1]:
        sc_205 = sc_205 + 'J'
    if R205[n] > R205[n-1]:
        sc_205 = sc_205 + 'R'
    if α205[n] > α205[n-1]:
        sc_205 = sc_205 + 'α'
    if len(sc_205) > 0:
        st_205.append(sc_205)
    else:
        STC_205.append(st_205)
        st_205 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_205 = STC_205.count([])
# keep only non-empty spatio-temporal sequences
STC_205 = [ st_205 for st_205 in STC_205 if len(st_205) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_205 = len(F205)
lmax_205 = 0
for st_205 in STC_205:
    if len(st_205) < lmin_205:
        lmin_205 = len(st_205)
    if len(st_205) > lmax_205:
        lmax_205 = len(st_205)
        
# restrict spatio-temporal sequences to length-5
STC5_205 = [ st_205 for st_205 in STC_205 if len(st_205) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_205 = []
for n in range(len(STC5_205)):
    tc_205 = [ u for u in STC5_205[n][0] ]
    for k in range(1, len(STC5_205[n])):
        tc_205 = [ u+v for u in tc_205 for v in STC5_205[n][k] ]
    TC5_205 = TC5_205 + tc_205
setTC5_205 = list(set(TC5_205))

# get empirical frequencies
fTC5_205 = [ TC5_205.count(setTC5_205[l]) for l in range(len(setTC5_205)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_205 = [ [] for l in range(len(setTC5_205)) ]
for s in range(100):
    STC5null_205 = [ list(st_205) for st_205 in STC5_205]
    for st_205 in STC5null_205:
        np.random.shuffle(st_205)
    TC5null_205= []
    for n in range(len(STC5null_205)):
        tc_205 = [ u for u in STC5null_205[n][0] ]
        for k in range(1, len(STC5null_205[n])):
            tc_205 = [ u+v for u in tc_205 for v in STC5null_205[n][k] ]
        TC5null_205= TC5null_205+ tc_205
    for l in range(len(setTC5_205)):
        if TC5null_205.count(setTC5_205[l]) > 0:
            fTC5null_205[l].append(TC5null_205.count(setTC5_205[l]))
        else:
            fTC5null_205[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_205)):
     if sum(freq >= fTC5_205[l] for freq in fTC5null_205[l]) < 5:
#         print(setTC5_205[l], fTC5_205[l], sum(freq >= fTC5_205[l] for freq in fTC5null_205[l]))
        print(setTC5_205[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# RRFH
# HRαRJ
# αFJαα
# HHααJ
# FRαRJ
# JJJα
# FRFR
# JJJH
# αRRFα
# HHαRH
# JFHFα
# RRF
# αRHFJ
# JαFH
# RRJFα
# RαJH
# HHFRα
# ααFH
# FRF
# JRFH
# JαRH
# ααRH
# HHFRJ
# αRJFJ
# αRαFJ
# αRJFα
# αRJαJ
# αFHFJ
# RJJFF
# RRHαJ
# RRHFJ
# RHαRJ
# HHFRF
# JRHFJ
# HHJRJ
# HααRJ
# JFααα
# HHHFF
# αJJFF
# RFJαα
# FJ
# αRαRJ
# HHFRH
# HHαRF
# HHαRα
# HRHFα
# RJJHJ
# RFHFα
# HHHFJ
# RRJFH
# RRHFα
# RRFR
# HRHFJ
# JFJαα
# JαJH
# ααJH
# RFJHα
# RFHFJ
# αRJFH
# FFαRJ
# HHαRJ
# JRHFα
# αRααJ
# JRJH
# HFFRF
# RRJH
# αRHFα
# FαFR
# HHHFα
# HRFRF
# αFHFα
# RαFH
# FRFJ
# RJJFR
# RαHFα
# HFFαF
# JFHαα
# HHRRJ
# JFHFJ
# HHJRα
# JHJH
# RFHHα
# HHRJJ
# RJJRR
# αRFFJ
# RJJJF
# RJFHJ
# HαHFα
# JJFH
# HHJJJ
# RRHRJ

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_205)):
     if sum(freq >= fTC5_205[l] for freq in fTC5null_205[l]) < 1:
#         print(setTC5_205[l], fTC5_205[l], sum(freq >= fTC5_205[l] for freq in fTC5null_205[l]))
        print(setTC5_205[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# FRFR
# JFHFα
# αRHFJ
# JαFH
# RαJH
# HHFRJ
# αRJFα
# RJJFF
# RRHFJ
# HHFRF
# RFJαα
# αRαRJ
# RJJHJ
# HHHFJ
# RRHFα
# JFJαα
# JαJH
# HHαRJ
# JRHFα
# αRHFα
# HRFRF
# JFHαα
# JFHFJ

# %% [markdown]
#  # 3.206 (F) BPI - (H) BLOOM- (J) FGEN - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_206 = max(min(Date_BPI), min(Date_BLOOM), min(Date_FGEN), min(Date_SMC), min(Date_SCC))
end_206 = min(max(Date_BPI), max(Date_BLOOM), max(Date_FGEN), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
BPI_206_1 = Date_BPI.index(start_206)
BPI_206_2 = Date_BPI.index(end_206)

BLOOM_206_1 = Date_BLOOM.index(start_206)
BLOOM_206_2 = Date_BLOOM.index(end_206)

FGEN_206_1 = Date_FGEN.index(start_206)
FGEN_206_2 = Date_FGEN.index(end_206)

SMC_206_1 = Date_SMC.index(start_206)
SMC_206_2 = Date_SMC.index(end_206)

SCC_206_1 = Date_SCC.index(start_206)
SCC_206_2 = Date_SCC.index(end_206)

# %%
#save the shortened versions of closing prices
F206 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_206_1:BPI_206_2])
H206 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_206_1:BLOOM_206_2])
J206 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_206_1:FGEN_206_2])
Y206 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_206_1:SMC_206_2])
α206 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_206_1:SCC_206_2])

# %%
# import modules
import numpy as np
# import prices

F206 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H206 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J206 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
Y206 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α206 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_206 = []
st_206 = []
n = 1
while n < len(F206):
    sc_206 = ''
    if F206[n] > F206[n-1]:
        sc_206 = sc_206 + 'F'
    if H206[n] > H206[n-1]:
        sc_206 = sc_206 + 'H'
    if J206[n] > J206[n-1]:
        sc_206 = sc_206 + 'J'
    if Y206[n] > Y206[n-1]:
        sc_206 = sc_206 + 'Y'
    if α206[n] > α206[n-1]:
        sc_206 = sc_206 + 'α'
    if len(sc_206) > 0:
        st_206.append(sc_206)
    else:
        STC_206.append(st_206)
        st_206 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_206 = STC_206.count([])
# keep only non-empty spatio-temporal sequences
STC_206 = [ st_206 for st_206 in STC_206 if len(st_206) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_206 = len(F206)
lmax_206 = 0
for st_206 in STC_206:
    if len(st_206) < lmin_206:
        lmin_206 = len(st_206)
    if len(st_206) > lmax_206:
        lmax_206 = len(st_206)
        
# restrict spatio-temporal sequences to length-5
STC5_206 = [ st_206 for st_206 in STC_206 if len(st_206) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_206 = []
for n in range(len(STC5_206)):
    tc_206 = [ u for u in STC5_206[n][0] ]
    for k in range(1, len(STC5_206[n])):
        tc_206 = [ u+v for u in tc_206 for v in STC5_206[n][k] ]
    TC5_206 = TC5_206 + tc_206
setTC5_206 = list(set(TC5_206))

# get empirical frequencies
fTC5_206 = [ TC5_206.count(setTC5_206[l]) for l in range(len(setTC5_206)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_206 = [ [] for l in range(len(setTC5_206)) ]
for s in range(100):
    STC5null_206 = [ list(st_206) for st_206 in STC5_206]
    for st_206 in STC5null_206:
        np.random.shuffle(st_206)
    TC5null_206= []
    for n in range(len(STC5null_206)):
        tc_206 = [ u for u in STC5null_206[n][0] ]
        for k in range(1, len(STC5null_206[n])):
            tc_206 = [ u+v for u in tc_206 for v in STC5null_206[n][k] ]
        TC5null_206= TC5null_206+ tc_206
    for l in range(len(setTC5_206)):
        if TC5null_206.count(setTC5_206[l]) > 0:
            fTC5null_206[l].append(TC5null_206.count(setTC5_206[l]))
        else:
            fTC5null_206[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_206)):
     if sum(freq >= fTC5_206[l] for freq in fTC5null_206[l]) < 5:
#         print(setTC5_206[l], fTC5_206[l], sum(freq >= fTC5_206[l] for freq in fTC5null_206[l]))
        print(setTC5_206[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# YHHHF
# FHFF
# YJYFα
# HαFJ
# FYYJ
# JYYα
# FFαHY
# FYαJJ
# JFHHY
# YJYJα
# FJYα
# JFαHY
# YFFFα
# JαJH
# JHFF
# FYYY
# YJJJF
# FFααY
# FYJ
# JHJH
# HHYαJ
# HYJα
# αFαHY
# FYααH
# FJYαF
# FYFJJ
# JFYαF
# HHHYα
# FJααH
# HHYαα
# JαJαH
# HHYαF
# FYYα
# YYFYY
# FYJYJ
# ααFJ
# FJYJ
# FHαF
# FHYFF
# FYJJJ
# JJJHF
# FFααα
# JYHHY
# HHαF
# JYαHY
# αYαJJ
# αFααY

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_206)):
     if sum(freq >= fTC5_206[l] for freq in fTC5null_206[l]) < 1:
#         print(setTC5_206[l], fTC5_206[l], sum(freq >= fTC5_206[l] for freq in fTC5null_206[l]))
        print(setTC5_206[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# FYαJJ
# JFαHY
# FYYY
# FJYαF
# JFYαF
# FYJJJ
# JYαHY

# %% [markdown]
#  # 3.207 (F) BPI - (H) BLOOM- (M) ICT - (N) JGS - (R) MEG

# %%
#extract overlapping dates
start_207 = max(min(Date_BPI), min(Date_BLOOM), min(Date_ICT), min(Date_JGS), min(Date_MEG))
end_207 = min(max(Date_BPI), max(Date_BLOOM), max(Date_ICT), max(Date_JGS), max(Date_MEG))

# %%
#shorten the closing prices
BPI_207_1 = Date_BPI.index(start_207)
BPI_207_2 = Date_BPI.index(end_207)

BLOOM_207_1 = Date_BLOOM.index(start_207)
BLOOM_207_2 = Date_BLOOM.index(end_207)

ICT_207_1 = Date_ICT.index(start_207)
ICT_207_2 = Date_ICT.index(end_207)

JGS_207_1 = Date_JGS.index(start_207)
JGS_207_2 = Date_JGS.index(end_207)

MEG_207_1 = Date_MEG.index(start_207)
MEG_207_2 = Date_MEG.index(end_207)

# %%
#save the shortened versions of closing prices
F207 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_207_1:BPI_207_2])
H207 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_207_1:BLOOM_207_2])
M207 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_207_1:ICT_207_2])
N207 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_207_1:JGS_207_2])
R207 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_207_1:MEG_207_2])

# %%
# import modules
import numpy as np
# import prices

F207 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H207 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M207 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N207 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R207 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_207 = []
st_207 = []
n = 1
while n < len(F207):
    sc_207 = ''
    if F207[n] > F207[n-1]:
        sc_207 = sc_207 + 'F'
    if H207[n] > H207[n-1]:
        sc_207 = sc_207 + 'H'
    if M207[n] > M207[n-1]:
        sc_207 = sc_207 + 'M'
    if N207[n] > N207[n-1]:
        sc_207 = sc_207 + 'N'
    if R207[n] > R207[n-1]:
        sc_207 = sc_207 + 'R'
    if len(sc_207) > 0:
        st_207.append(sc_207)
    else:
        STC_207.append(st_207)
        st_207 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_207 = STC_207.count([])
# keep only non-empty spatio-temporal sequences
STC_207 = [ st_207 for st_207 in STC_207 if len(st_207) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_207 = len(F207)
lmax_207 = 0
for st_207 in STC_207:
    if len(st_207) < lmin_207:
        lmin_207 = len(st_207)
    if len(st_207) > lmax_207:
        lmax_207 = len(st_207)
        
# restrict spatio-temporal sequences to length-5
STC5_207 = [ st_207 for st_207 in STC_207 if len(st_207) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_207 = []
for n in range(len(STC5_207)):
    tc_207 = [ u for u in STC5_207[n][0] ]
    for k in range(1, len(STC5_207[n])):
        tc_207 = [ u+v for u in tc_207 for v in STC5_207[n][k] ]
    TC5_207 = TC5_207 + tc_207
setTC5_207 = list(set(TC5_207))

# get empirical frequencies
fTC5_207 = [ TC5_207.count(setTC5_207[l]) for l in range(len(setTC5_207)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_207 = [ [] for l in range(len(setTC5_207)) ]
for s in range(100):
    STC5null_207 = [ list(st_207) for st_207 in STC5_207]
    for st_207 in STC5null_207:
        np.random.shuffle(st_207)
    TC5null_207= []
    for n in range(len(STC5null_207)):
        tc_207 = [ u for u in STC5null_207[n][0] ]
        for k in range(1, len(STC5null_207[n])):
            tc_207 = [ u+v for u in tc_207 for v in STC5null_207[n][k] ]
        TC5null_207= TC5null_207+ tc_207
    for l in range(len(setTC5_207)):
        if TC5null_207.count(setTC5_207[l]) > 0:
            fTC5null_207[l].append(TC5null_207.count(setTC5_207[l]))
        else:
            fTC5null_207[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_207)):
     if sum(freq >= fTC5_207[l] for freq in fTC5null_207[l]) < 5:
#         print(setTC5_207[l], fTC5_207[l], sum(freq >= fTC5_207[l] for freq in fTC5null_207[l]))
        print(setTC5_207[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FRNF
# NRFNR
# FMNH
# NRFRR
# RNFH
# HRMFN
# NMFR
# HRMFM
# RRFH
# NNNH
# HHMRN
# NNFR
# NFNRM
# HHMFN
# MRMMF
# MRMMR
# NNFN
# HRMMF
# HNHFM
# HMRN
# HRFH
# HHHFN
# NRRFR
# MRMFR
# RRF
# NMFN
# MMHH
# HRHH
# HMHH
# FRF
# NRFNM
# NFFNR
# MRMMM
# HRRRM
# HRHFM
# RNFMR
# FMN
# HNMNM
# MMNN
# NMFH
# FMNF
# MNMFN
# MFRRR
# NFRFR
# NRRRN
# FRFH
# HHFRF
# NRNRM
# NFFFR
# HFFRR
# MMFR
# MRRRH
# MMRR
# NMN
# MMNR
# FRMMF
# HRNFH
# HHHFF
# NRRRR
# MRNR
# HRMFF
# MFMFR
# HRHFF
# HNHNM
# MRRRR
# NNFH
# MFMRR
# NRFMR
# MRFH
# HRHFN
# FRN
# MRMMN
# MNFNR
# MRRFR
# HRNNM
# RMFH
# MRFR
# NRFR
# HHFRN
# MRMRR
# NRNRH
# NRF
# MNMFR
# MMRH
# NRNRN
# FRNH
# NRFH
# HNMFM
# HRNFM
# FMFH
# HHMNF
# MMFH
# NRFFM
# NRFFR
# MMFN
# HRMNM
# RMHH
# NRFN
# MMFM
# HHMNN
# MRMFN
# FMHH
# HRNFF
# MMNH
# NRRRM
# HHMNM
# RRMMF
# MNFFR
# NMNH
# HRHNM
# NRRNR
# HRHFH
# RMF
# HFFRH
# MRFN
# HHMFF
# NNFFR
# MRFFR
# NRHRR
# FMF
# HHHMN
# HHMRF
# RRHH
# MNFMR
# ...

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_207)):
     if sum(freq >= fTC5_207[l] for freq in fTC5null_207[l]) < 1:
#         print(setTC5_207[l], fTC5_207[l], sum(freq >= fTC5_207[l] for freq in fTC5null_207[l]))
        print(setTC5_207[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# NRFNR
# NMFR
# RRFH
# HHMFN
# HRMMF
# MRMFR
# RRF
# NMFN
# MMHH
# MRMMM
# MMNN
# NMFH
# NRNRM
# NFFFR
# MMFR
# MMRR
# MMNR
# HRNFH
# NRRRR
# MRRRR
# MRFH
# MRMMN
# RMFH
# MMRH
# NRNRN
# FMFH
# MMFH
# NRFFR
# MMFN
# HRMNM
# FMHH
# MMNH
# NRRRM
# HHMNM
# NMNH
# HHMFF
# NNFFR

# %% [markdown]
#  # 3.208 (F) BPI - (H) BLOOM- (M) ICT - (N) JGS - (Y) SMC

# %%
#extract overlapping dates
start_208 = max(min(Date_BPI), min(Date_BLOOM), min(Date_ICT), min(Date_JGS), min(Date_SMC))
end_208 = min(max(Date_BPI), max(Date_BLOOM), max(Date_ICT), max(Date_JGS), max(Date_SMC))

# %%
#shorten the closing prices
BPI_208_1 = Date_BPI.index(start_208)
BPI_208_2 = Date_BPI.index(end_208)

BLOOM_208_1 = Date_BLOOM.index(start_208)
BLOOM_208_2 = Date_BLOOM.index(end_208)

ICT_208_1 = Date_ICT.index(start_208)
ICT_208_2 = Date_ICT.index(end_208)

JGS_208_1 = Date_JGS.index(start_208)
JGS_208_2 = Date_JGS.index(end_208)

SMC_208_1 = Date_SMC.index(start_208)
SMC_208_2 = Date_SMC.index(end_208)

# %%
#save the shortened versions of closing prices
F208 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_208_1:BPI_208_2])
H208 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_208_1:BLOOM_208_2])
M208 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_208_1:ICT_208_2])
N208 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_208_1:JGS_208_2])
Y208 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_208_1:SMC_208_2])

# %%
# import modules
import numpy as np
# import prices

F208 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H208 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M208 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N208 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y208 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_208 = []
st_208 = []
n = 1
while n < len(F208):
    sc_208 = ''
    if F208[n] > F208[n-1]:
        sc_208 = sc_208 + 'F'
    if H208[n] > H208[n-1]:
        sc_208 = sc_208 + 'H'
    if M208[n] > M208[n-1]:
        sc_208 = sc_208 + 'M'
    if N208[n] > N208[n-1]:
        sc_208 = sc_208 + 'N'
    if Y208[n] > Y208[n-1]:
        sc_208 = sc_208 + 'Y'
    if len(sc_208) > 0:
        st_208.append(sc_208)
    else:
        STC_208.append(st_208)
        st_208 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_208 = STC_208.count([])
# keep only non-empty spatio-temporal sequences
STC_208 = [ st_208 for st_208 in STC_208 if len(st_208) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_208 = len(F208)
lmax_208 = 0
for st_208 in STC_208:
    if len(st_208) < lmin_208:
        lmin_208 = len(st_208)
    if len(st_208) > lmax_208:
        lmax_208 = len(st_208)
        
# restrict spatio-temporal sequences to length-5
STC5_208 = [ st_208 for st_208 in STC_208 if len(st_208) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_208 = []
for n in range(len(STC5_208)):
    tc_208 = [ u for u in STC5_208[n][0] ]
    for k in range(1, len(STC5_208[n])):
        tc_208 = [ u+v for u in tc_208 for v in STC5_208[n][k] ]
    TC5_208 = TC5_208 + tc_208
setTC5_208 = list(set(TC5_208))

# get empirical frequencies
fTC5_208 = [ TC5_208.count(setTC5_208[l]) for l in range(len(setTC5_208)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_208 = [ [] for l in range(len(setTC5_208)) ]
for s in range(100):
    STC5null_208 = [ list(st_208) for st_208 in STC5_208]
    for st_208 in STC5null_208:
        np.random.shuffle(st_208)
    TC5null_208= []
    for n in range(len(STC5null_208)):
        tc_208 = [ u for u in STC5null_208[n][0] ]
        for k in range(1, len(STC5null_208[n])):
            tc_208 = [ u+v for u in tc_208 for v in STC5null_208[n][k] ]
        TC5null_208= TC5null_208+ tc_208
    for l in range(len(setTC5_208)):
        if TC5null_208.count(setTC5_208[l]) > 0:
            fTC5null_208[l].append(TC5null_208.count(setTC5_208[l]))
        else:
            fTC5null_208[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_208)):
     if sum(freq >= fTC5_208[l] for freq in fTC5null_208[l]) < 5:
#         print(setTC5_208[l], fTC5_208[l], sum(freq >= fTC5_208[l] for freq in fTC5null_208[l]))
        print(setTC5_208[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# NFMNM
# YFMMY
# NYFFN
# FFNYM
# NNNH
# HMNYM
# MHFM
# HYF
# HHYNN
# HHYFN
# YNYYN
# YHMNY
# FYFF
# HNHFM
# NHMYH
# YFNFH
# MYFM
# HMHYM
# FYYN
# MMHH
# NMMYH
# HHYNF
# HYFM
# YFNYH
# YNMFN
# YYMN
# NFFNF
# FYYM
# FMHYM
# FYMN
# HNMNM
# NHFM
# HMHYF
# HMYN
# MHFF
# NYNFN
# HHHFM
# MNMYM
# YMNH
# MH
# HFNFM
# HHHFF
# MMMN
# FMNYH
# HNHNM
# MYMFN
# FMNYM
# NNFH
# HNHFF
# NFHFM
# FNYMY
# FYYY
# HHYNM
# YHNHH
# HYYM
# YYHFM
# NHFYH
# HNMFM
# YMNN
# HHMNF
# YFMN
# YFNNH
# MMFN
# HHMFM
# MYFFN
# FYNYM
# MYMN
# MMFM
# HHMNN
# NFNNM
# NFFNM
# HHMNM
# YYMFN
# NYHFN
# HMMYM
# HHYFF
# YMMN
# HMMYF
# YFMMF
# NFMYH
# HHHNM

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_208)):
     if sum(freq >= fTC5_208[l] for freq in fTC5null_208[l]) < 1:
#         print(setTC5_208[l], fTC5_208[l], sum(freq >= fTC5_208[l] for freq in fTC5null_208[l]))
        print(setTC5_208[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# HHYNN
# FYYN
# HHYNF
# HNMNM
# FMNYH
# HHYNM
# YFMN

# %% [markdown]
#  # 3.209 (F) BPI - (H) BLOOM- (M) ICT - (N) JGS - (α) SMC

# %%
#extract overlapping dates
start_209 = max(min(Date_BPI), min(Date_BLOOM), min(Date_ICT), min(Date_JGS), min(Date_SCC))
end_209 = min(max(Date_BPI), max(Date_BLOOM), max(Date_ICT), max(Date_JGS), max(Date_SCC))

# %%
#shorten the closing prices
BPI_209_1 = Date_BPI.index(start_209)
BPI_209_2 = Date_BPI.index(end_209)

BLOOM_209_1 = Date_BLOOM.index(start_209)
BLOOM_209_2 = Date_BLOOM.index(end_209)

ICT_209_1 = Date_ICT.index(start_209)
ICT_209_2 = Date_ICT.index(end_209)

JGS_209_1 = Date_JGS.index(start_209)
JGS_209_2 = Date_JGS.index(end_209)

SCC_209_1 = Date_SCC.index(start_209)
SCC_209_2 = Date_SCC.index(end_209)

# %%
#save the shortened versions of closing prices
F209 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_209_1:BPI_209_2])
H209 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_209_1:BLOOM_209_2])
M209 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_209_1:ICT_209_2])
N209 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_209_1:JGS_209_2])
α209 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_209_1:SCC_209_2])

# %%
# import modules
import numpy as np
# import prices

F209 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H209 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M209 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N209 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
α209 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_209 = []
st_209 = []
n = 1
while n < len(F209):
    sc_209 = ''
    if F209[n] > F209[n-1]:
        sc_209 = sc_209 + 'F'
    if H209[n] > H209[n-1]:
        sc_209 = sc_209 + 'H'
    if M209[n] > M209[n-1]:
        sc_209 = sc_209 + 'M'
    if N209[n] > N209[n-1]:
        sc_209 = sc_209 + 'N'
    if α209[n] > α209[n-1]:
        sc_209 = sc_209 + 'α'
    if len(sc_209) > 0:
        st_209.append(sc_209)
    else:
        STC_209.append(st_209)
        st_209 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_209 = STC_209.count([])
# keep only non-empty spatio-temporal sequences
STC_209 = [ st_209 for st_209 in STC_209 if len(st_209) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_209 = len(F209)
lmax_209 = 0
for st_209 in STC_209:
    if len(st_209) < lmin_209:
        lmin_209 = len(st_209)
    if len(st_209) > lmax_209:
        lmax_209 = len(st_209)
        
# restrict spatio-temporal sequences to length-5
STC5_209 = [ st_209 for st_209 in STC_209 if len(st_209) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_209 = []
for n in range(len(STC5_209)):
    tc_209 = [ u for u in STC5_209[n][0] ]
    for k in range(1, len(STC5_209[n])):
        tc_209 = [ u+v for u in tc_209 for v in STC5_209[n][k] ]
    TC5_209 = TC5_209 + tc_209
setTC5_209 = list(set(TC5_209))

# get empirical frequencies
fTC5_209 = [ TC5_209.count(setTC5_209[l]) for l in range(len(setTC5_209)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_209 = [ [] for l in range(len(setTC5_209)) ]
for s in range(100):
    STC5null_209 = [ list(st_209) for st_209 in STC5_209]
    for st_209 in STC5null_209:
        np.random.shuffle(st_209)
    TC5null_209= []
    for n in range(len(STC5null_209)):
        tc_209 = [ u for u in STC5null_209[n][0] ]
        for k in range(1, len(STC5null_209[n])):
            tc_209 = [ u+v for u in tc_209 for v in STC5null_209[n][k] ]
        TC5null_209= TC5null_209+ tc_209
    for l in range(len(setTC5_209)):
        if TC5null_209.count(setTC5_209[l]) > 0:
            fTC5null_209[l].append(TC5null_209.count(setTC5_209[l]))
        else:
            fTC5null_209[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_209)):
     if sum(freq >= fTC5_209[l] for freq in fTC5null_209[l]) < 5:
#         print(setTC5_209[l], fTC5_209[l], sum(freq >= fTC5_209[l] for freq in fTC5null_209[l]))
        print(setTC5_209[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FMHFN
# HNHNα
# FNHFF
# HNMNN
# HαHαα
# HαMαH
# HαααN
# NNHNN
# FαHH
# FαM
# HNMαα
# NFααα
# HαMαα
# HHMMα
# HαMFα
# FααH
# HMHH
# HHMMN
# FNNαH
# HαHαN
# HMMMF
# HHFαα
# FαHFF
# HNMNα
# αMNH
# FHHFF
# FNFH
# NαFH
# HαMNM
# HHMαF
# HNFαα
# NαMαα
# FMN
# MMNN
# NMFH
# MNMFN
# HMNH
# HαFN
# NNHHα
# FMMMN
# HHMαN
# NNMHα
# FαFH
# MH
# NNHHH
# FNααH
# NNHαH
# NNHNα
# MNMαH
# HNMMα
# HαMNα
# NNMNα
# HαMαF
# HFMαα
# MMMN
# HαHNα
# HFFαα
# MNHNN
# NNFH
# NNHFα
# MNMαN
# FNαFH
# HαNH
# FMMMF
# MNMMN
# HHFαN
# FHNH
# HNMαN
# FNαNH
# MHMαN
# MαFN
# Hαααα
# HαHNM
# NNFFα
# NNMHH
# HαMFN
# HFFFM
# HNFαH
# HHMαα
# HαMαM
# NFαNM
# NNMNH
# MMFH
# HαMαN
# FFHH
# NNαNM
# MMαF
# HFHH
# HHHFα
# MMFN
# HMMαM
# NNααH
# HαMMF
# HNMαH
# HαHαM
# NNMαH
# NNHαα
# MMNH
# MαHH
# NNFFH
# HαFH
# MHHMN
# HαHH
# FαNαα
# MNMNα
# NMNH
# NFαNα
# HNMMN
# HHMFF
# NNHFH
# FNNNH
# HαMMN
# MNMFα
# NNHNH
# MNMαα
# HHHMN
# HαHFα
# αNMMF
# FαHFα
# NNMαα

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_209)):
     if sum(freq >= fTC5_209[l] for freq in fTC5null_209[l]) < 1:
#         print(setTC5_209[l], fTC5_209[l], sum(freq >= fTC5_209[l] for freq in fTC5null_209[l]))
        print(setTC5_209[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# HαHαα
# HαααN
# HNMαα
# HαMαα
# HHFαα
# HHMαN
# NNHHH
# NNHαH
# HFMαα
# NNHFα
# Hαααα
# HαHNM
# NNFFα
# NNMHH
# HHMαα
# NFαNM
# MMFH
# HαMαN
# NNMαH
# MMNH
# HαHH
# HαMMN
# HαHFα

# %% [markdown]
#  # 3.210 (F) BPI - (H) BLOOM- (M) ICT - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_210 = max(min(Date_BPI), min(Date_BLOOM), min(Date_ICT), min(Date_MEG), min(Date_SMC))
end_210 = min(max(Date_BPI), max(Date_BLOOM), max(Date_ICT), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
BPI_210_1 = Date_BPI.index(start_210)
BPI_210_2 = Date_BPI.index(end_210)

BLOOM_210_1 = Date_BLOOM.index(start_210)
BLOOM_210_2 = Date_BLOOM.index(end_210)

ICT_210_1 = Date_ICT.index(start_210)
ICT_210_2 = Date_ICT.index(end_210)

MEG_210_1 = Date_MEG.index(start_210)
MEG_210_2 = Date_MEG.index(end_210)

SMC_210_1 = Date_SMC.index(start_210)
SMC_210_2 = Date_SMC.index(end_210)

# %%
#save the shortened versions of closing prices
F210 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_210_1:BPI_210_2])
H210 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_210_1:BLOOM_210_2])
M210 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_210_1:ICT_210_2])
R210 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_210_1:MEG_210_2])
Y210 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_210_1:SMC_210_2])

# %%
# import modules
import numpy as np
# import prices

F210 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H210 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M210 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R210 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y210 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_210 = []
st_210 = []
n = 1
while n < len(F210):
    sc_210 = ''
    if F210[n] > F210[n-1]:
        sc_210 = sc_210 + 'F'
    if H210[n] > H210[n-1]:
        sc_210 = sc_210 + 'H'
    if M210[n] > M210[n-1]:
        sc_210 = sc_210 + 'M'
    if R210[n] > R210[n-1]:
        sc_210 = sc_210 + 'R'
    if Y210[n] > Y210[n-1]:
        sc_210 = sc_210 + 'Y'
    if len(sc_210) > 0:
        st_210.append(sc_210)
    else:
        STC_210.append(st_210)
        st_210 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_210 = STC_210.count([])
# keep only non-empty spatio-temporal sequences
STC_210 = [ st_210 for st_210 in STC_210 if len(st_210) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_210 = len(F210)
lmax_210 = 0
for st_210 in STC_210:
    if len(st_210) < lmin_210:
        lmin_210 = len(st_210)
    if len(st_210) > lmax_210:
        lmax_210 = len(st_210)
        
# restrict spatio-temporal sequences to length-5
STC5_210 = [ st_210 for st_210 in STC_210 if len(st_210) <= 5 ]

# unpBPIk spatio-temporal sequences to temporal sequences
TC5_210 = []
for n in range(len(STC5_210)):
    tc_210 = [ u for u in STC5_210[n][0] ]
    for k in range(1, len(STC5_210[n])):
        tc_210 = [ u+v for u in tc_210 for v in STC5_210[n][k] ]
    TC5_210 = TC5_210 + tc_210
setTC5_210 = list(set(TC5_210))

# get empirical frequencies
fTC5_210 = [ TC5_210.count(setTC5_210[l]) for l in range(len(setTC5_210)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_210 = [ [] for l in range(len(setTC5_210)) ]
for s in range(100):
    STC5null_210 = [ list(st_210) for st_210 in STC5_210]
    for st_210 in STC5null_210:
        np.random.shuffle(st_210)
    TC5null_210= []
    for n in range(len(STC5null_210)):
        tc_210 = [ u for u in STC5null_210[n][0] ]
        for k in range(1, len(STC5null_210[n])):
            tc_210 = [ u+v for u in tc_210 for v in STC5null_210[n][k] ]
        TC5null_210= TC5null_210+ tc_210
    for l in range(len(setTC5_210)):
        if TC5null_210.count(setTC5_210[l]) > 0:
            fTC5null_210[l].append(TC5null_210.count(setTC5_210[l]))
        else:
            fTC5null_210[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_210)):
     if sum(freq >= fTC5_210[l] for freq in fTC5null_210[l]) < 5:
#         print(setTC5_210[l], fTC5_210[l], sum(freq >= fTC5_210[l] for freq in fTC5null_210[l]))
        print(setTC5_210[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# MMFF
# YMRH
# HRMFM
# RRFH
# MHMMF
# MRMMF
# YRFMM
# RHYFF
# FRRRH
# HMRY
# RRF
# MHFRF
# MMHH
# YFYFH
# YRFMR
# HFMY
# MRFMR
# HHRRF
# YYMMM
# MRFRH
# FRMMM
# YYFMR
# MYMRR
# MRMMM
# HRHFM
# HYM
# RFFMF
# HRMRM
# FYRRH
# MHYFF
# RRFMR
# HHFRF
# MMFR
# MYYMM
# MMRR
# HMMY
# HHYRF
# MRHRM
# YRFYM
# YRFR
# YYFYY
# MYRRR
# MRRRR
# HHYRR
# MFFMF
# HHYRY
# YMMR
# HHRY
# MRMRH
# MRMYM
# YYFMM
# FRRRR
# HYYMR
# FRFYM
# YHYFF
# YRYHH
# MMMH
# FHFH
# RHFRF
# FYRRR
# MMFH
# MRFRR
# HFFRF
# HHYFH
# MYMMM
# YRYFF
# FRYYY
# YRFH
# MRFMM
# HHMY
# YFFFH
# HRFMR
# YRFMY
# HHYFF
# YRMFF
# MRFFR
# YRFYY
# FM
# HHMRF
# MYRRM

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_210)):
     if sum(freq >= fTC5_210[l] for freq in fTC5null_210[l]) < 1:
#         print(setTC5_210[l], fTC5_210[l], sum(freq >= fTC5_210[l] for freq in fTC5null_210[l]))
        print(setTC5_210[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# YRFMM
# YRFMR
# YYMMM
# MRMMM
# MMMH
# FYRRR
# MMFH
# YRFH
# YRFMY
# MRFFR
