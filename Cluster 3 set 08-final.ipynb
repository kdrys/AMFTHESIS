# %% [markdown]
# # One-Letter Words

# %%
# open the csv files
AP = open('AP.csv')
AC = open('AC.csv')
BPI = open('BPI.csv')
BLOOM = open('BLOOM.csv')
FGEN = open('FGEN.csv')
ICT = open('ICT.csv')
JGS = open('JGS.csv')
MEG = open('MEG.csv')
SMC = open('SMC.csv')
SCC = open('SCC.csv')

#initiFGENze the lists
Date_AP = []
ClosePrice_AP = []
Date_AC = []
ClosePrice_AC = []
Date_BPI = []
ClosePrice_BPI = []
Date_BLOOM = []
ClosePrice_BLOOM = []
Date_FGEN = []
ClosePrice_FGEN = []
Date_ICT = []
ClosePrice_ICT = []
Date_JGS = []
ClosePrice_JGS = []
Date_MEG = []
ClosePrice_MEG = []
Date_SMC = []
ClosePrice_SMC = []
Date_SCC = []
ClosePrice_SCC = []

#skip the header line
AP.readline()
AC.readline()
BPI.readline()
BLOOM.readline()
FGEN.readline()
ICT.readline()
JGS.readline()
MEG.readline()
SMC.readline()
SCC.readline()

#go through the files line by line
for line in AP:
    sline = line.strip().split(',')
    Date_AP.append(sline[0])
    ClosePrice_AP.append(float(sline[1]))
    
for line in AC:
    sline = line.strip().split(',')
    Date_AC.append(sline[0])
    ClosePrice_AC.append(float(sline[1]))
    
for line in BPI:
    sline = line.strip().split(',')
    Date_BPI.append(sline[0])
    ClosePrice_BPI.append(float(sline[1]))
    
for line in BLOOM:
    sline = line.strip().split(',')
    Date_BLOOM.append(sline[0])
    ClosePrice_BLOOM.append(float(sline[1]))
    
for line in FGEN:
    sline = line.strip().split(',')
    Date_FGEN.append(sline[0])
    ClosePrice_FGEN.append(float(sline[1]))
    
for line in ICT:
    sline = line.strip().split(',')
    Date_ICT.append(sline[0])
    ClosePrice_ICT.append(float(sline[1]))
    
for line in JGS:
    sline = line.strip().split(',')
    Date_JGS.append(sline[0])
    ClosePrice_JGS.append(float(sline[1]))
    
for line in MEG:
    sline = line.strip().split(',')
    Date_MEG.append(sline[0])
    ClosePrice_MEG.append(float(sline[1]))
    
for line in SMC:
    sline = line.strip().split(',')
    Date_SMC.append(sline[0])
    ClosePrice_SMC.append(float(sline[1]))
        
for line in SCC:
    sline = line.strip().split(',')
    Date_SCC.append(sline[0])
    ClosePrice_SCC.append(float(sline[1]))


#close files
AP.close()
AC.close()
BPI.close()
BLOOM.close()
FGEN.close()
ICT.close()
JGS.close()
MEG.close()
SMC.close()
SCC.close()# One-Letter Words

# %%
import numpy as np
import datetime

# %%
# convert dates into datetime structure
for n in range(len(Date_AP)):
    Date_AP[n] = datetime.datetime.strptime(Date_AP[n], '%m/%d/%y').date()

for n in range(len(Date_AC)):
    Date_AC[n] = datetime.datetime.strptime(Date_AC[n], '%m/%d/%y').date()
    
for n in range(len(Date_BPI)):
    Date_BPI[n] = datetime.datetime.strptime(Date_BPI[n], '%m/%d/%y').date()

for n in range(len(Date_BLOOM)):
    Date_BLOOM[n] = datetime.datetime.strptime(Date_BLOOM[n], '%m/%d/%y').date()
    
for n in range(len(Date_FGEN)):
    Date_FGEN[n] = datetime.datetime.strptime(Date_FGEN[n], '%m/%d/%y').date()

for n in range(len(Date_ICT)):
    Date_ICT[n] = datetime.datetime.strptime(Date_ICT[n], '%m/%d/%y').date()
    
for n in range(len(Date_JGS)):
    Date_JGS[n] = datetime.datetime.strptime(Date_JGS[n], '%m/%d/%y').date()

for n in range(len(Date_MEG)):
    Date_MEG[n] = datetime.datetime.strptime(Date_MEG[n], '%m/%d/%y').date()
    
for n in range(len(Date_SMC)):
    Date_SMC[n] = datetime.datetime.strptime(Date_SMC[n], '%m/%d/%y').date()

for n in range(len(Date_SCC)):
    Date_SCC[n] = datetime.datetime.strptime(Date_SCC[n], '%m/%d/%y').date()
    
# save Date and ClosePrice
np.save('APDate.npy', Date_AP)
np.save('APClosePrice.npy', ClosePrice_AP)
np.save('ACDate.npy', Date_AC)
np.save('ACClosePrice.npy', ClosePrice_AC)
np.save('BPIDate.npy', Date_BPI)
np.save('BPIClosePrice.npy', ClosePrice_BPI)
np.save('BLOOMDate.npy', Date_BLOOM)
np.save('BLOOMClosePrice.npy', ClosePrice_BLOOM)
np.save('FGENDate.npy', Date_FGEN)
np.save('FGENClosePrice.npy', ClosePrice_FGEN)
np.save('ICTDate.npy', Date_ICT)
np.save('ICTClosePrice.npy', ClosePrice_ICT)
np.save('JGSDate.npy', Date_JGS)
np.save('JGSClosePrice.npy', ClosePrice_JGS)
np.save('MEGDate.npy', Date_MEG)
np.save('MEGClosePrice.npy', ClosePrice_MEG)
np.save('SMCDate.npy', Date_SMC)
np.save('SMCClosePrice.npy', ClosePrice_SMC)
np.save('SCCDate.npy', Date_SCC)
np.save('SCCClosePrice.npy', ClosePrice_SCC)

# %% [markdown]
# # Five-letter Words

# %% [markdown]
# # 3.106 (B) AP - (H) BLOOM - (M) ICT - (R) MEG - (α) SCC

# %%
#extract overlapping dates
start_106 = max(min(Date_AP), min(Date_BLOOM), min(Date_ICT), min(Date_MEG), min(Date_SCC))
end_106 = min(max(Date_AP), max(Date_BLOOM), max(Date_ICT), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
AP_106_1 = Date_AP.index(start_106)
AP_106_2 = Date_AP.index(end_106)

BLOOM_106_1 = Date_BLOOM.index(start_106)
BLOOM_106_2 = Date_BLOOM.index(end_106)

ICT_106_1 = Date_ICT.index(start_106)
ICT_106_2 = Date_ICT.index(end_106)

MEG_106_1 = Date_MEG.index(start_106)
MEG_106_2 = Date_MEG.index(end_106)

SCC_106_1 = Date_SCC.index(start_106)
SCC_106_2 = Date_SCC.index(end_106)

# %%
#save the shortened versions of closing prices
B106 = np.save('APshortPrices.npy', ClosePrice_AP[AP_106_1:AP_106_2])
H106 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_106_1:BLOOM_106_2])
M106 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_106_1:ICT_106_2])
R106 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_106_1:MEG_106_2])
α106 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_106_1:SCC_106_2])

# %%
# import modules
import numpy as np
# import prices

B106 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
H106 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M106 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R106 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α106 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_106 = []
st_106 = []
n = 1
while n < len(B106):
    sc_106 = ''
    if B106[n] > B106[n-1]:
        sc_106 = sc_106 + 'B'
    if H106[n] > H106[n-1]:
        sc_106 = sc_106 + 'H'
    if M106[n] > M106[n-1]:
        sc_106 = sc_106 + 'M'
    if R106[n] > R106[n-1]:
        sc_106 = sc_106 + 'R'
    if α106[n] > α106[n-1]:
        sc_106 = sc_106 + 'α'
    if len(sc_106) > 0:
        st_106.append(sc_106)
    else:
        STC_106.append(st_106)
        st_106 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_106 = STC_106.count([])
# keep only non-empty spatio-temporal sequences
STC_106 = [ st_106 for st_106 in STC_106 if len(st_106) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_106 = len(B106)
lmax_106 = 0
for st_106 in STC_106:
    if len(st_106) < lmin_106:
        lmin_106 = len(st_106)
    if len(st_106) > lmax_106:
        lmax_106 = len(st_106)
        
# restrict spatio-temporal sequences to length-5
STC5_106 = [ st_106 for st_106 in STC_106 if len(st_106) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_106 = []
for n in range(len(STC5_106)):
    tc_106 = [ u for u in STC5_106[n][0] ]
    for k in range(1, len(STC5_106[n])):
        tc_106 = [ u+v for u in tc_106 for v in STC5_106[n][k] ]
    TC5_106 = TC5_106 + tc_106
setTC5_106 = list(set(TC5_106))

# get empirical frequencies
fTC5_106 = [ TC5_106.count(setTC5_106[l]) for l in range(len(setTC5_106)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_106 = [ [] for l in range(len(setTC5_106)) ]
for s in range(100):
    STC5null_106 = [ list(st_106) for st_106 in STC5_106]
    for st_106 in STC5null_106:
        np.random.shuffle(st_106)
    TC5null_106= []
    for n in range(len(STC5null_106)):
        tc_106 = [ u for u in STC5null_106[n][0] ]
        for k in range(1, len(STC5null_106[n])):
            tc_106 = [ u+v for u in tc_106 for v in STC5null_106[n][k] ]
        TC5null_106= TC5null_106+ tc_106
    for l in range(len(setTC5_106)):
        if TC5null_106.count(setTC5_106[l]) > 0:
            fTC5null_106[l].append(TC5null_106.count(setTC5_106[l]))
        else:
            fTC5null_106[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_106)):
     if sum(freq >= fTC5_106[l] for freq in fTC5null_106[l]) < 5:
#         print(setTC5_106[l], fTC5_106[l], sum(freq >= fTC5_106[l] for freq in fTC5null_106[l]))
        print(setTC5_106[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# RRRHα
# RBMMα
# αBBB
# RBBBα
# RRαRα
# RRαRB
# RBRBα
# BMRαH
# HHBM
# RMMBH
# BαM
# RRBHα
# αHBH
# MRMBα
# RBMBB
# RMHαα
# RRMαM
# RBMαα
# HBRH
# αMBR
# αMMαα
# RBBHα
# RBRHα
# HMαH
# HBHMM
# RMRBH
# HBαBα
# RMRαα
# RRHαM
# RRαBH
# αRααH
# RMMBα
# RRMMB
# αMHαα
# RMMBM
# MBαBH
# αMRR
# αMBBM
# RBαBα
# αMαR
# RRMHα
# HBBB
# αRααα
# MMRR
# MRαBα
# HRMαα
# RBHHH
# RRMMα
# RBHBα
# HBMαα
# RMHαH
# RRMRB
# RRMBH
# RRMMM
# RBHMM
# MBRB
# MRMBH
# RRBBα
# RBMαM
# αHBR
# MBαBα
# RBRB
# αBRHα
# RMBBM
# HBMBB
# HBMBα
# RRMαα
# RBMαB
# RRBBH
# RMHBα
# αBαBα
# HRαBα
# MMBBα
# RMMαM
# αMHBα
# αMBH
# αMααα
# RMαBα
# αMRB
# αRαBα
# αMBBα
# αRMBα
# RRHBα
# αMBαα
# RBB
# MMRB
# RBMBH
# RRMBα
# MRHHH
# RMBBα
# RMHBH
# RBHHα
# HRHMM
# RBHMα
# αBαHα
# RRHαα
# RBMHα
# αMRH
# HRHαα
# HBBH
# RRMαH
# MBMαα
# HRααα
# RMHMM
# RRHBH
# RBααα
# RMααα
# BBRRB
# BHα
# RRααH
# MHBM
# RRααα
# RMBαα
# RMHαM
# αMMBα
# RMMMB
# RBHαα
# RRαBα
# RMHBM
# RBMBα
# αBMBα
# RRMRα
# RRHHα
# RMMαH
# RMMαα
# RRHHH
# MHα

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_106)):
     if sum(freq >= fTC5_106[l] for freq in fTC5null_106[l]) < 1:
#         print(setTC5_106[l], fTC5_106[l], sum(freq >= fTC5_106[l] for freq in fTC5null_106[l]))
        print(setTC5_106[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# RRRHα
# RMHαα
# αMBR
# RBRHα
# HBHMM
# RMMBα
# αMRR
# HBBB
# HRMαα
# RBHBα
# RMHαH
# RRMBH
# RRBBα
# MBαBα
# RBRB
# RRMαα
# RRBBH
# RMHBα
# αBαBα
# RMMαM
# RRHBα
# RRMBα
# RBHHα
# RRHαα
# HRHαα
# RRMαH
# RMHMM
# RRααα
# RMHαM
# RBHαα
# RRαBα
# RMHBM
# RBMBα
# RRHHα
# RMMαα

# %% [markdown]
# # 3.107 (B) AP - (H) BLOOM - (M) ICT - (Y) SCC - (α) SCC

# %%
#extract overlapping dates
start_107 = max(min(Date_AP), min(Date_BLOOM), min(Date_ICT), min(Date_SMC), min(Date_SCC))
end_107 = min(max(Date_AP), max(Date_BLOOM), max(Date_ICT), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
AP_107_1 = Date_AP.index(start_107)
AP_107_2 = Date_AP.index(end_107)

BLOOM_107_1 = Date_BLOOM.index(start_107)
BLOOM_107_2 = Date_BLOOM.index(end_107)

ICT_107_1 = Date_ICT.index(start_107)
ICT_107_2 = Date_ICT.index(end_107)

SMC_107_1 = Date_SMC.index(start_107)
SMC_107_2 = Date_SMC.index(end_107)

SCC_107_1 = Date_SCC.index(start_107)
SCC_107_2 = Date_SCC.index(end_107)

# %%
#save the shortened versions of closing prices
B107 = np.save('APshortPrices.npy', ClosePrice_AP[AP_107_1:AP_107_2])
H107 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_107_1:BLOOM_107_2])
M107 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_107_1:ICT_107_2])
Y107 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_107_1:SMC_107_2])
α107 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_107_1:SCC_107_2])

# %%
# import modules
import numpy as np
# import prices

B107 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
H107 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M107 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
Y107 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α107 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_107 = []
st_107 = []
n = 1
while n < len(B107):
    sc_107 = ''
    if B107[n] > B107[n-1]:
        sc_107 = sc_107 + 'B'
    if H107[n] > H107[n-1]:
        sc_107 = sc_107 + 'H'
    if M107[n] > M107[n-1]:
        sc_107 = sc_107 + 'M'
    if Y107[n] > Y107[n-1]:
        sc_107 = sc_107 + 'Y'
    if α107[n] > α107[n-1]:
        sc_107 = sc_107 + 'α'
    if len(sc_107) > 0:
        st_107.append(sc_107)
    else:
        STC_107.append(st_107)
        st_107 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_107 = STC_107.count([])
# keep only non-empty spatio-temporal sequences
STC_107 = [ st_107 for st_107 in STC_107 if len(st_107) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_107 = len(B107)
lmax_107 = 0
for st_107 in STC_107:
    if len(st_107) < lmin_107:
        lmin_107 = len(st_107)
    if len(st_107) > lmax_107:
        lmax_107 = len(st_107)
        
# restrict spatio-temporal sequences to length-5
STC5_107 = [ st_107 for st_107 in STC_107 if len(st_107) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_107 = []
for n in range(len(STC5_107)):
    tc_107 = [ u for u in STC5_107[n][0] ]
    for k in range(1, len(STC5_107[n])):
        tc_107 = [ u+v for u in tc_107 for v in STC5_107[n][k] ]
    TC5_107 = TC5_107 + tc_107
setTC5_107 = list(set(TC5_107))

# get empirical frequencies
fTC5_107 = [ TC5_107.count(setTC5_107[l]) for l in range(len(setTC5_107)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_107 = [ [] for l in range(len(setTC5_107)) ]
for s in range(100):
    STC5null_107 = [ list(st_107) for st_107 in STC5_107]
    for st_107 in STC5null_107:
        np.random.shuffle(st_107)
    TC5null_107= []
    for n in range(len(STC5null_107)):
        tc_107 = [ u for u in STC5null_107[n][0] ]
        for k in range(1, len(STC5null_107[n])):
            tc_107 = [ u+v for u in tc_107 for v in STC5null_107[n][k] ]
        TC5null_107= TC5null_107+ tc_107
    for l in range(len(setTC5_107)):
        if TC5null_107.count(setTC5_107[l]) > 0:
            fTC5null_107[l].append(TC5null_107.count(setTC5_107[l]))
        else:
            fTC5null_107[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_107)):
     if sum(freq >= fTC5_107[l] for freq in fTC5null_107[l]) < 5:
#         print(setTC5_107[l], fTC5_107[l], sum(freq >= fTC5_107[l] for freq in fTC5null_107[l]))
        print(setTC5_107[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# HαYMY
# HαMHH
# YMBH
# MMYMM
# HHYαB
# YMYMB
# YYYBα
# YαYBM
# YHαHH
# HBHMB
# YBYBB
# YαYHM
# YBHBα
# BMαHB
# BYαHM
# HαYMM
# BYαHH
# HBBα
# BMBBM
# HBMMM
# HBHαM
# BHBα
# YYYBM
# YBMBα
# HBHMM
# YYααα
# YMYMM
# MBYMB
# αHMα
# HBYHB
# YBYBM
# YBαBα
# HBMBM
# YHYHH
# YBYHM
# YαYHY
# YαYMB
# YαYHα
# αBYBB
# MαYMα
# MMYMB
# YYBBM
# YYYMM
# HBBM
# YMYMα
# αYHα
# αBYMB
# YYYMB
# HBMMB
# YMYMH
# MYHα
# MBHMα
# HBYMM
# HYYα
# BMαHH
# YYMBα
# BHMα
# YBYHY
# YBYMM
# YαYMα
# HBHBα
# MHMα
# HHYαα
# HBYHM
# YBααα
# HBYMB
# HBHBM
# HBYMY
# YYYMα
# HαBHY
# HHYMB
# MMHMB
# ααYBM
# YαYMM
# YBYHB
# HαYMα
# HαBHH
# αBαHα
# MHMY
# HαYMB
# MBYMα
# YBBBM
# YYYBB
# HαMBM
# HBYMα
# YαYMY
# YBYMH
# αBYBM
# HBHMα
# MMYMα
# YBYHα
# YαYHB
# HBMαM
# BHBM
# MHH
# YBYMB
# HBBHY
# αYMα

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_107)):
     if sum(freq >= fTC5_107[l] for freq in fTC5null_107[l]) < 1:
#         print(setTC5_107[l], fTC5_107[l], sum(freq >= fTC5_107[l] for freq in fTC5null_107[l]))
        print(setTC5_107[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# YMBH
# YYYBα
# HαYMM
# BYαHH
# HBBα
# YYYBM
# YBMBα
# HBHMM
# MBYMB
# MMYMB
# YYYMM
# HBYMM
# BMαHH
# YBYMM
# MHMα
# YαYMM
# MBYMα
# HBYMα
# MMYMα
# YBYHα
# HBMαM

# %% [markdown]
# # 3.108 (B) AP - (H) BLOOM - (N) JGS - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_108 = max(min(Date_AP), min(Date_BLOOM), min(Date_JGS), min(Date_MEG), min(Date_SMC))
end_108 = min(max(Date_AP), max(Date_BLOOM), max(Date_JGS), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
AP_108_1 = Date_AP.index(start_108)
AP_108_2 = Date_AP.index(end_108)

BLOOM_108_1 = Date_BLOOM.index(start_108)
BLOOM_108_2 = Date_BLOOM.index(end_108)

JGS_108_1 = Date_JGS.index(start_108)
JGS_108_2 = Date_JGS.index(end_108)

MEG_108_1 = Date_MEG.index(start_108)
MEG_108_2 = Date_MEG.index(end_108)

SMC_108_1 = Date_SMC.index(start_108)
SMC_108_2 = Date_SMC.index(end_108)

# %%
#save the shortened versions of closing prices
B108 = np.save('APshortPrices.npy', ClosePrice_AP[AP_108_1:AP_108_2])
H108 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_108_1:BLOOM_108_2])
N108 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_108_1:JGS_108_2])
R108 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_108_1:MEG_108_2])
Y108 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_108_1:SMC_108_2])

# %%
# import modules
import numpy as np
# import prices

B108 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
H108 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
N108 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R108 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y108 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_108 = []
st_108 = []
n = 1
while n < len(B108):
    sc_108 = ''
    if B108[n] > B108[n-1]:
        sc_108 = sc_108 + 'B'
    if H108[n] > H108[n-1]:
        sc_108 = sc_108 + 'H'
    if N108[n] > N108[n-1]:
        sc_108 = sc_108 + 'N'
    if R108[n] > R108[n-1]:
        sc_108 = sc_108 + 'R'
    if Y108[n] > Y108[n-1]:
        sc_108 = sc_108 + 'Y'
    if len(sc_108) > 0:
        st_108.append(sc_108)
    else:
        STC_108.append(st_108)
        st_108 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_108 = STC_108.count([])
# keep only non-empty spatio-temporal sequences
STC_108 = [ st_108 for st_108 in STC_108 if len(st_108) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_108 = len(B108)
lmax_108 = 0
for st_108 in STC_108:
    if len(st_108) < lmin_108:
        lmin_108 = len(st_108)
    if len(st_108) > lmax_108:
        lmax_108 = len(st_108)
        
# restrict spatio-temporal sequences to length-5
STC5_108 = [ st_108 for st_108 in STC_108 if len(st_108) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_108 = []
for n in range(len(STC5_108)):
    tc_108 = [ u for u in STC5_108[n][0] ]
    for k in range(1, len(STC5_108[n])):
        tc_108 = [ u+v for u in tc_108 for v in STC5_108[n][k] ]
    TC5_108 = TC5_108 + tc_108
setTC5_108 = list(set(TC5_108))

# get empirical frequencies
fTC5_108 = [ TC5_108.count(setTC5_108[l]) for l in range(len(setTC5_108)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_108 = [ [] for l in range(len(setTC5_108)) ]
for s in range(100):
    STC5null_108 = [ list(st_108) for st_108 in STC5_108]
    for st_108 in STC5null_108:
        np.random.shuffle(st_108)
    TC5null_108= []
    for n in range(len(STC5null_108)):
        tc_108 = [ u for u in STC5null_108[n][0] ]
        for k in range(1, len(STC5null_108[n])):
            tc_108 = [ u+v for u in tc_108 for v in STC5null_108[n][k] ]
        TC5null_108= TC5null_108+ tc_108
    for l in range(len(setTC5_108)):
        if TC5null_108.count(setTC5_108[l]) > 0:
            fTC5null_108[l].append(TC5null_108.count(setTC5_108[l]))
        else:
            fTC5null_108[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_108)):
     if sum(freq >= fTC5_108[l] for freq in fTC5null_108[l]) < 5:
#         print(setTC5_108[l], fTC5_108[l], sum(freq >= fTC5_108[l] for freq in fTC5null_108[l]))
        print(setTC5_108[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# BBYRB
# NRNY
# HHHNB
# NBBY
# BBHRY
# RHYYB
# HHYNN
# BNNYB
# YNBNN
# HHYRN
# NNBNR
# YNYNN
# NNBN
# YRBBR
# NRNNR
# NYNYR
# NBB
# BBNNB
# BHHRB
# HNN
# YRBNN
# YRBB
# HRYYB
# YNBBR
# YBRN
# NNBHR
# NNBH
# RRHH
# BHYRB
# HHYRB
# YHYHH
# HHYNB
# YHYNH
# HRHRN
# NHBBR
# RNBBR
# YRBR
# RYRYR
# BBHRB
# YYBYN
# YNBBN
# RHYRY
# YBBB
# YBYRB
# RNHHH
# RHYYR
# HNHNB
# NRBNR
# NRBBR
# RBYRB
# RBB
# BBNRB
# BBNYB
# HNNBN
# YHYRB
# YBBN
# YRYNN
# YHYNN
# HNBBB
# RHYRB
# NNBY
# NNBBR
# NRHH
# BYNYB
# YYRYN
# HBN
# NYRYR
# YBBR
# YYRYY
# YNYBN
# HRYRN
# YNNBN
# BYRYB
# YRBN
# RNHNB

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_108)):
     if sum(freq >= fTC5_108[l] for freq in fTC5null_108[l]) < 1:
#         print(setTC5_108[l], fTC5_108[l], sum(freq >= fTC5_108[l] for freq in fTC5null_108[l]))
        print(setTC5_108[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# YBRN
# RRHH
# BHYRB
# HHYRB
# YHYHH
# HRHRN
# YRBR
# BBHRB
# YBBB
# NRBNR
# BBNRB
# YHYRB
# YBBN
# RHYRB
# RNHNB

# %% [markdown]
# # 3.109 (B) AP - (H) BLOOM - (N) JGS - (R) MEG - (α) SCC

# %%
#extract overlapping dates
start_109 = max(min(Date_AP), min(Date_BLOOM), min(Date_JGS), min(Date_MEG), min(Date_SCC))
end_109 = min(max(Date_AP), max(Date_BLOOM), max(Date_JGS), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
AP_109_1 = Date_AP.index(start_109)
AP_109_2 = Date_AP.index(end_109)

BLOOM_109_1 = Date_BLOOM.index(start_109)
BLOOM_109_2 = Date_BLOOM.index(end_109)

JGS_109_1 = Date_JGS.index(start_109)
JGS_109_2 = Date_JGS.index(end_109)

MEG_109_1 = Date_MEG.index(start_109)
MEG_109_2 = Date_MEG.index(end_109)

SCC_109_1 = Date_SCC.index(start_109)
SCC_109_2 = Date_SCC.index(end_109)

# %%
#save the shortened versions of closing prices
B109 = np.save('APshortPrices.npy', ClosePrice_AP[AP_109_1:AP_109_2])
H109 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_109_1:BLOOM_109_2])
N109 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_109_1:JGS_109_2])
R109 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_109_1:MEG_109_2])
α109 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_109_1:SCC_109_2])

# %%
# import modules
import numpy as np
# import prices

B109 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
H109 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
N109 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R109 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α109 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_109 = []
st_109 = []
n = 1
while n < len(B109):
    sc_109 = ''
    if B109[n] > B109[n-1]:
        sc_109 = sc_109 + 'B'
    if H109[n] > H109[n-1]:
        sc_109 = sc_109 + 'H'
    if N109[n] > N109[n-1]:
        sc_109 = sc_109 + 'N'
    if R109[n] > R109[n-1]:
        sc_109 = sc_109 + 'R'
    if α109[n] > α109[n-1]:
        sc_109 = sc_109 + 'α'
    if len(sc_109) > 0:
        st_109.append(sc_109)
    else:
        STC_109.append(st_109)
        st_109 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_109 = STC_109.count([])
# keep only non-empty spatio-temporal sequences
STC_109 = [ st_109 for st_109 in STC_109 if len(st_109) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_109 = len(B109)
lmax_109 = 0
for st_109 in STC_109:
    if len(st_109) < lmin_109:
        lmin_109 = len(st_109)
    if len(st_109) > lmax_109:
        lmax_109 = len(st_109)
        
# restrict spatio-temporal sequences to length-5
STC5_109 = [ st_109 for st_109 in STC_109 if len(st_109) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_109 = []
for n in range(len(STC5_109)):
    tc_109 = [ u for u in STC5_109[n][0] ]
    for k in range(1, len(STC5_109[n])):
        tc_109 = [ u+v for u in tc_109 for v in STC5_109[n][k] ]
    TC5_109 = TC5_109 + tc_109
setTC5_109 = list(set(TC5_109))

# get empirical frequencies
fTC5_109 = [ TC5_109.count(setTC5_109[l]) for l in range(len(setTC5_109)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_109 = [ [] for l in range(len(setTC5_109)) ]
for s in range(100):
    STC5null_109 = [ list(st_109) for st_109 in STC5_109]
    for st_109 in STC5null_109:
        np.random.shuffle(st_109)
    TC5null_109= []
    for n in range(len(STC5null_109)):
        tc_109 = [ u for u in STC5null_109[n][0] ]
        for k in range(1, len(STC5null_109[n])):
            tc_109 = [ u+v for u in tc_109 for v in STC5null_109[n][k] ]
        TC5null_109= TC5null_109+ tc_109
    for l in range(len(setTC5_109)):
        if TC5null_109.count(setTC5_109[l]) > 0:
            fTC5null_109[l].append(TC5null_109.count(setTC5_109[l]))
        else:
            fTC5null_109[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_109)):
     if sum(freq >= fTC5_109[l] for freq in fTC5null_109[l]) < 5:
#         print(setTC5_109[l], fTC5_109[l], sum(freq >= fTC5_109[l] for freq in fTC5null_109[l]))
        print(setTC5_109[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# BRαRH
# RRαRN
# RRRRα
# RRαRα
# ααBHB
# ααBHR
# BNαHH
# RRαRB
# NRBHα
# BRNRH
# αNBHR
# NNBHα
# HRαRα
# BRNRα
# RRHNα
# HRNRH
# RHNRB
# BRNRB
# NRNHα
# NNNHα
# αRNRN
# HRHH
# NRNNR
# BNRHα
# HHRRB
# HBαBα
# NNBHR
# NNBH
# RRNRH
# αNBHα
# αRNRB
# HBααα
# HRHRN
# RααRB
# RBNH
# ααNRB
# HRNRB
# αRαRB
# HRHRB
# αNNBα
# NαNH
# RαNH
# RNRHα
# BNNRH
# HHNRB
# NαNN
# HRαBα
# BRRNα
# αNBHN
# RNBHα
# RRNRB
# BBNRB
# BRRHH
# RRRNα
# NαNα
# BRαRB
# BRBHα
# HHR
# BNNHH
# HHαRB
# HRαRB
# NαBH
# RNBBα
# HRNRα
# RBααα
# BBRRB
# HRαH
# RRααα
# BRRHα
# RRNRα
# RBHαα
# BBNRH
# HHααα
# RBNB
# ααBH
# αBNRN
# NNαH

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_109)):
     if sum(freq >= fTC5_109[l] for freq in fTC5null_109[l]) < 1:
#         print(setTC5_109[l], fTC5_109[l], sum(freq >= fTC5_109[l] for freq in fTC5null_109[l]))
        print(setTC5_109[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# RRαRα
# RRαRB
# αNBHR
# HRαRα
# BRNRB
# NRNHα
# αNBHα
# RBNH
# αNBHN
# HHαRB
# RNBBα
# BBNRH
# RBNB

# %% [markdown]
# # 3.110 (B) AP - (H) BLOOM - (N) JGS - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_110 = max(min(Date_AP), min(Date_BLOOM), min(Date_JGS), min(Date_SMC), min(Date_SCC))
end_110 = min(max(Date_AP), max(Date_BLOOM), max(Date_JGS), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
AP_110_1 = Date_AP.index(start_110)
AP_110_2 = Date_AP.index(end_110)

BLOOM_110_1 = Date_BLOOM.index(start_110)
BLOOM_110_2 = Date_BLOOM.index(end_110)

JGS_110_1 = Date_JGS.index(start_110)
JGS_110_2 = Date_JGS.index(end_110)

SMC_110_1 = Date_SMC.index(start_110)
SMC_110_2 = Date_SMC.index(end_110)

SCC_110_1 = Date_SCC.index(start_110)
SCC_110_2 = Date_SCC.index(end_110)

# %%
#save the shortened versions of closing prices
B110 = np.save('APshortPrices.npy', ClosePrice_AP[AP_110_1:AP_110_2])
H110 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_110_1:BLOOM_110_2])
N110 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_110_1:JGS_110_2])
R110 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_110_1:SMC_110_2])
α110 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_110_1:SCC_110_2])

# %%
# import modules
import numpy as np
# import prices

B110 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
H110 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
N110 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R110 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α110 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_110 = []
st_110 = []
n = 1
while n < len(B110):
    sc_110 = ''
    if B110[n] > B110[n-1]:
        sc_110 = sc_110 + 'B'
    if H110[n] > H110[n-1]:
        sc_110 = sc_110 + 'H'
    if N110[n] > N110[n-1]:
        sc_110 = sc_110 + 'N'
    if R110[n] > R110[n-1]:
        sc_110 = sc_110 + 'Y'
    if α110[n] > α110[n-1]:
        sc_110 = sc_110 + 'α'
    if len(sc_110) > 0:
        st_110.append(sc_110)
    else:
        STC_110.append(st_110)
        st_110 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_110 = STC_110.count([])
# keep only non-empty spatio-temporal sequences
STC_110 = [ st_110 for st_110 in STC_110 if len(st_110) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_110 = len(B110)
lmax_110 = 0
for st_110 in STC_110:
    if len(st_110) < lmin_110:
        lmin_110 = len(st_110)
    if len(st_110) > lmax_110:
        lmax_110 = len(st_110)
        
# restrict spatio-temporal sequences to length-5
STC5_110 = [ st_110 for st_110 in STC_110 if len(st_110) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_110 = []
for n in range(len(STC5_110)):
    tc_110 = [ u for u in STC5_110[n][0] ]
    for k in range(1, len(STC5_110[n])):
        tc_110 = [ u+v for u in tc_110 for v in STC5_110[n][k] ]
    TC5_110 = TC5_110 + tc_110
setTC5_110 = list(set(TC5_110))

# get empirical frequencies
fTC5_110 = [ TC5_110.count(setTC5_110[l]) for l in range(len(setTC5_110)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_110 = [ [] for l in range(len(setTC5_110)) ]
for s in range(100):
    STC5null_110 = [ list(st_110) for st_110 in STC5_110]
    for st_110 in STC5null_110:
        np.random.shuffle(st_110)
    TC5null_110= []
    for n in range(len(STC5null_110)):
        tc_110 = [ u for u in STC5null_110[n][0] ]
        for k in range(1, len(STC5null_110[n])):
            tc_110 = [ u+v for u in tc_110 for v in STC5null_110[n][k] ]
        TC5null_110= TC5null_110+ tc_110
    for l in range(len(setTC5_110)):
        if TC5null_110.count(setTC5_110[l]) > 0:
            fTC5null_110[l].append(TC5null_110.count(setTC5_110[l]))
        else:
            fTC5null_110[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_110)):
     if sum(freq >= fTC5_110[l] for freq in fTC5null_110[l]) < 5:
#         print(setTC5_110[l], fTC5_110[l], sum(freq >= fTC5_110[l] for freq in fTC5null_110[l]))
        print(setTC5_110[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# ααNBB
# HBHHB
# ααNBN
# NBBα
# YYYBα
# NαBHY
# HαHBα
# HBHαα
# YHαHH
# YBHBα
# YαBHY
# αBYHN
# HBBα
# NNBN
# αNYHY
# αBBN
# αBBα
# NYYα
# NYα
# HHHYN
# ααNHY
# αNBHY
# NNBH
# HHαYB
# HBααα
# HαNHY
# αBYBN
# YYBNα
# HHHYB
# BBαYB
# αBYYB
# YYαNα
# HαYBY
# HαN
# HBYYB
# HBHNN
# HBHYB
# NαNHY
# YYBYN
# YαNHY
# NYYαα
# αNBN
# ααBHY
# NBBN
# HαBHY
# HBHαN
# BBHNα
# YBNBN
# NNHH
# BαBHY
# YBYBN
# YHNHH
# BNNHH
# BαNHY
# YYYNα
# HαYBα
# ααYBN
# HHHYα
# HHYYB
# HBHNα
# αNBH
# HNBHB
# HαYBN
# YαNB
# NBBH
# YYBα
# BYBα

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_110)):
     if sum(freq >= fTC5_110[l] for freq in fTC5null_110[l]) < 1:
#         print(setTC5_110[l], fTC5_110[l], sum(freq >= fTC5_110[l] for freq in fTC5null_110[l]))
        print(setTC5_110[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# NαBHY
# HBHαα
# HBBα
# αBBN
# YYαNα
# αNBN
# NBBN
# HBHαN
# YHNHH
# HαYBα
# YYBα

# %% [markdown]
# # 3.111 (B) AP - (H) BLOOM - (R) MEG - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_111 = max(min(Date_AP), min(Date_BLOOM), min(Date_MEG), min(Date_SMC), min(Date_SCC))
end_111 = min(max(Date_AP), max(Date_BLOOM), max(Date_MEG), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
AP_111_1 = Date_AP.index(start_111)
AP_111_2 = Date_AP.index(end_111)

BLOOM_111_1 = Date_BLOOM.index(start_111)
BLOOM_111_2 = Date_BLOOM.index(end_111)

MEG_111_1 = Date_MEG.index(start_111)
MEG_111_2 = Date_MEG.index(end_111)

SMC_111_1 = Date_SMC.index(start_111)
SMC_111_2 = Date_SMC.index(end_111)

SCC_111_1 = Date_SCC.index(start_111)
SCC_111_2 = Date_SCC.index(end_111)

# %%
#save the shortened versions of closing prices
B111 = np.save('APshortPrices.npy', ClosePrice_AP[AP_111_1:AP_111_2])
H111 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_111_1:BLOOM_111_2])
R111 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_111_1:MEG_111_2])
Y111 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_111_1:SMC_111_2])
α111 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_111_1:SCC_111_2])

# %%
# import modules
import numpy as np
# import prices

B111 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
H111 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
R111 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y111 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α111 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_111 = []
st_111 = []
n = 1
while n < len(B111):
    sc_111 = ''
    if B111[n] > B111[n-1]:
        sc_111 = sc_111 + 'B'
    if H111[n] > H111[n-1]:
        sc_111 = sc_111 + 'H'
    if R111[n] > R111[n-1]:
        sc_111 = sc_111 + 'R'
    if Y111[n] > Y111[n-1]:
        sc_111 = sc_111 + 'Y'
    if α111[n] > α111[n-1]:
        sc_111 = sc_111 + 'α'
    if len(sc_111) > 0:
        st_111.append(sc_111)
    else:
        STC_111.append(st_111)
        st_111 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_111 = STC_111.count([])
# keep only non-empty spatio-temporal sequences
STC_111 = [ st_111 for st_111 in STC_111 if len(st_111) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_111 = len(B111)
lmax_111 = 0
for st_111 in STC_111:
    if len(st_111) < lmin_111:
        lmin_111 = len(st_111)
    if len(st_111) > lmax_111:
        lmax_111 = len(st_111)
        
# restrict spatio-temporal sequences to length-5
STC5_111 = [ st_111 for st_111 in STC_111 if len(st_111) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_111 = []
for n in range(len(STC5_111)):
    tc_111 = [ u for u in STC5_111[n][0] ]
    for k in range(1, len(STC5_111[n])):
        tc_111 = [ u+v for u in tc_111 for v in STC5_111[n][k] ]
    TC5_111 = TC5_111 + tc_111
setTC5_111 = list(set(TC5_111))

# get empirical frequencies
fTC5_111 = [ TC5_111.count(setTC5_111[l]) for l in range(len(setTC5_111)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_111 = [ [] for l in range(len(setTC5_111)) ]
for s in range(100):
    STC5null_111 = [ list(st_111) for st_111 in STC5_111]
    for st_111 in STC5null_111:
        np.random.shuffle(st_111)
    TC5null_111= []
    for n in range(len(STC5null_111)):
        tc_111 = [ u for u in STC5null_111[n][0] ]
        for k in range(1, len(STC5null_111[n])):
            tc_111 = [ u+v for u in tc_111 for v in STC5null_111[n][k] ]
        TC5null_111= TC5null_111+ tc_111
    for l in range(len(setTC5_111)):
        if TC5null_111.count(setTC5_111[l]) > 0:
            fTC5null_111[l].append(TC5null_111.count(setTC5_111[l]))
        else:
            fTC5null_111[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_111)):
     if sum(freq >= fTC5_111[l] for freq in fTC5null_111[l]) < 5:
#         print(setTC5_111[l], fTC5_111[l], sum(freq >= fTC5_111[l] for freq in fTC5null_111[l]))
        print(setTC5_111[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# YRαRB
# HRYαα
# ααBB
# YRαBα
# RRBH
# HααHα
# RBBH
# RHYYB
# HαYαR
# YHαHH
# YHαRB
# HRHBB
# YBHBα
# ααYHY
# HBHBR
# YαBHY
# RRB
# RαBH
# RYB
# HαBHR
# HααBR
# HRααR
# HααBα
# HHRRB
# αRBB
# HRYYB
# ααBR
# HαYHR
# YαBα
# BYYαR
# HαBBR
# RYYαR
# YBαBα
# HααHR
# YRYBα
# HHYRB
# HαYαα
# HαBHα
# HRYRα
# αRBR
# RYBH
# HαYBY
# YRBR
# HBYYB
# HαHHY
# αYBR
# HαYHY
# HBHBB
# αHBR
# RBRB
# YαBHα
# αBBHY
# RYBY
# YHBR
# αBYHY
# ααBHY
# HαYHα
# HααYB
# RBB
# YBHHα
# HαYRα
# HααBB
# HBRHR
# HαBHB
# HαYBα
# HαYRR
# YYRαY
# YHRR
# HHYYB
# YαBR
# HRYRB
# HRYHα
# HαRHR
# YYRYY
# YBRHR
# ααBH
# HααRR

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_111)):
     if sum(freq >= fTC5_111[l] for freq in fTC5null_111[l]) < 1:
#         print(setTC5_111[l], fTC5_111[l], sum(freq >= fTC5_111[l] for freq in fTC5null_111[l]))
        print(setTC5_111[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# HRYαα
# RHYYB
# HααBR
# HααHR
# HBYYB
# HαYBα
# YYRαY
# HHYYB
# YαBR
# HRYHα
# ααBH

# %% [markdown]
# # 3.112 (B) AP - (J) FGEN - (M) ICT - (N) JGS - (R) MEG

# %%
#extract overlapping dates
start_112 = max(min(Date_AP), min(Date_FGEN), min(Date_ICT), min(Date_JGS), min(Date_MEG))
end_112 = min(max(Date_AP), max(Date_FGEN), max(Date_ICT), max(Date_JGS), max(Date_MEG))

# %%
#shorten the closing prices
AP_112_1 = Date_AP.index(start_112)
AP_112_2 = Date_AP.index(end_112)

FGEN_112_1 = Date_FGEN.index(start_112)
FGEN_112_2 = Date_FGEN.index(end_112)

ICT_112_1 = Date_ICT.index(start_112)
ICT_112_2 = Date_ICT.index(end_112)

JGS_112_1 = Date_JGS.index(start_112)
JGS_112_2 = Date_JGS.index(end_112)

MEG_112_1 = Date_MEG.index(start_112)
MEG_112_2 = Date_MEG.index(end_112)

# %%
#save the shortened versions of closing prices
B112 = np.save('APshortPrices.npy', ClosePrice_AP[AP_112_1:AP_112_2])
J112 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_112_1:FGEN_112_2])
M112 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_112_1:ICT_112_2])
N112 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_112_1:JGS_112_2])
R112 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_112_1:MEG_112_2])

# %%
# import modules
import numpy as np
# import prices

B112 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
J112 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M112 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N112 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R112 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_112 = []
st_112 = []
n = 1
while n < len(B112):
    sc_112 = ''
    if B112[n] > B112[n-1]:
        sc_112 = sc_112 + 'B'
    if J112[n] > J112[n-1]:
        sc_112 = sc_112 + 'J'
    if M112[n] > M112[n-1]:
        sc_112 = sc_112 + 'M'
    if N112[n] > N112[n-1]:
        sc_112 = sc_112 + 'N'
    if R112[n] > R112[n-1]:
        sc_112 = sc_112 + 'R'
    if len(sc_112) > 0:
        st_112.append(sc_112)
    else:
        STC_112.append(st_112)
        st_112 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_112 = STC_112.count([])
# keep only non-empty spatio-temporal sequences
STC_112 = [ st_112 for st_112 in STC_112 if len(st_112) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_112 = len(B112)
lmax_112 = 0
for st_112 in STC_112:
    if len(st_112) < lmin_112:
        lmin_112 = len(st_112)
    if len(st_112) > lmax_112:
        lmax_112 = len(st_112)
        
# restrict spatio-temporal sequences to length-5
STC5_112 = [ st_112 for st_112 in STC_112 if len(st_112) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_112 = []
for n in range(len(STC5_112)):
    tc_112 = [ u for u in STC5_112[n][0] ]
    for k in range(1, len(STC5_112[n])):
        tc_112 = [ u+v for u in tc_112 for v in STC5_112[n][k] ]
    TC5_112 = TC5_112 + tc_112
setTC5_112 = list(set(TC5_112))

# get empirical frequencies
fTC5_112 = [ TC5_112.count(setTC5_112[l]) for l in range(len(setTC5_112)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_112 = [ [] for l in range(len(setTC5_112)) ]
for s in range(100):
    STC5null_112 = [ list(st_112) for st_112 in STC5_112]
    for st_112 in STC5null_112:
        np.random.shuffle(st_112)
    TC5null_112= []
    for n in range(len(STC5null_112)):
        tc_112 = [ u for u in STC5null_112[n][0] ]
        for k in range(1, len(STC5null_112[n])):
            tc_112 = [ u+v for u in tc_112 for v in STC5null_112[n][k] ]
        TC5null_112= TC5null_112+ tc_112
    for l in range(len(setTC5_112)):
        if TC5null_112.count(setTC5_112[l]) > 0:
            fTC5null_112[l].append(TC5null_112.count(setTC5_112[l]))
        else:
            fTC5null_112[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_112)):
     if sum(freq >= fTC5_112[l] for freq in fTC5null_112[l]) < 5:
#         print(setTC5_112[l], fTC5_112[l], sum(freq >= fTC5_112[l] for freq in fTC5null_112[l]))
        print(setTC5_112[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# BBRRJ
# BBJNJ
# BRN
# BBNNJ
# BRNRB
# BMBBM
# MBNRB
# RBNBN
# RMJB
# BRM
# MRJMN
# BNMBJ
# JJNN
# RMRB
# RBMBN
# NMBBM
# MMBBM
# BRJMM
# BBBNJ
# MBRB
# NMMBM
# BMRJ
# BBRNJ
# BBMNJ
# JNNMN
# NMRR
# MBNBB
# RBMRM
# BBNRJ
# BJB
# BBMRJ
# NM
# MMRB
# BMM
# BBM
# BBMBJ
# NBNRJ
# RBMRJ
# MRJMM
# NBJRJ
# BBJRJ
# RJJR
# MBNB

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_112)):
     if sum(freq >= fTC5_112[l] for freq in fTC5null_112[l]) < 1:
#         print(setTC5_112[l], fTC5_112[l], sum(freq >= fTC5_112[l] for freq in fTC5null_112[l]))
        print(setTC5_112[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# BBJNJ
# BRM
# RMRB
# NMRR
# MMRB
# BBJRJ

# %% [markdown]
# # 3.113 (B) AP - (J) FGEN - (M) ICT - (N) JGS - (Y) SMC

# %%
#extract overlapping dates
start_113 = max(min(Date_AP), min(Date_FGEN), min(Date_ICT), min(Date_JGS), min(Date_SMC))
end_113 = min(max(Date_AP), max(Date_FGEN), max(Date_ICT), max(Date_JGS), max(Date_SMC))

# %%
#shorten the closing prices
AP_113_1 = Date_AP.index(start_113)
AP_113_2 = Date_AP.index(end_113)

FGEN_113_1 = Date_FGEN.index(start_113)
FGEN_113_2 = Date_FGEN.index(end_113)

ICT_113_1 = Date_ICT.index(start_113)
ICT_113_2 = Date_ICT.index(end_113)

JGS_113_1 = Date_JGS.index(start_113)
JGS_113_2 = Date_JGS.index(end_113)

SMC_113_1 = Date_SMC.index(start_113)
SMC_113_2 = Date_SMC.index(end_113)

# %%
#save the shortened versions of closing prices
B113 = np.save('APshortPrices.npy', ClosePrice_AP[AP_113_1:AP_113_2])
J113 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_113_1:FGEN_113_2])
M113 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_113_1:ICT_113_2])
N113 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_113_1:JGS_113_2])
Y113 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_113_1:SMC_113_2])

# %%
# import modules
import numpy as np
# import prices

B113 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
J113 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M113 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N113 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y113 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_113 = []
st_113 = []
n = 1
while n < len(B113):
    sc_113 = ''
    if B113[n] > B113[n-1]:
        sc_113 = sc_113 + 'B'
    if J113[n] > J113[n-1]:
        sc_113 = sc_113 + 'J'
    if M113[n] > M113[n-1]:
        sc_113 = sc_113 + 'M'
    if N113[n] > N113[n-1]:
        sc_113 = sc_113 + 'N'
    if Y113[n] > Y113[n-1]:
        sc_113 = sc_113 + 'Y'
    if len(sc_113) > 0:
        st_113.append(sc_113)
    else:
        STC_113.append(st_113)
        st_113 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_113 = STC_113.count([])
# keep only non-empty spatio-temporal sequences
STC_113 = [ st_113 for st_113 in STC_113 if len(st_113) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_113 = len(B113)
lmax_113 = 0
for st_113 in STC_113:
    if len(st_113) < lmin_113:
        lmin_113 = len(st_113)
    if len(st_113) > lmax_113:
        lmax_113 = len(st_113)
        
# restrict spatio-temporal sequences to length-5
STC5_113 = [ st_113 for st_113 in STC_113 if len(st_113) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_113 = []
for n in range(len(STC5_113)):
    tc_113 = [ u for u in STC5_113[n][0] ]
    for k in range(1, len(STC5_113[n])):
        tc_113 = [ u+v for u in tc_113 for v in STC5_113[n][k] ]
    TC5_113 = TC5_113 + tc_113
setTC5_113 = list(set(TC5_113))

# get empirical frequencies
fTC5_113 = [ TC5_113.count(setTC5_113[l]) for l in range(len(setTC5_113)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_113 = [ [] for l in range(len(setTC5_113)) ]
for s in range(100):
    STC5null_113 = [ list(st_113) for st_113 in STC5_113]
    for st_113 in STC5null_113:
        np.random.shuffle(st_113)
    TC5null_113= []
    for n in range(len(STC5null_113)):
        tc_113 = [ u for u in STC5null_113[n][0] ]
        for k in range(1, len(STC5null_113[n])):
            tc_113 = [ u+v for u in tc_113 for v in STC5null_113[n][k] ]
        TC5null_113= TC5null_113+ tc_113
    for l in range(len(setTC5_113)):
        if TC5null_113.count(setTC5_113[l]) > 0:
            fTC5null_113[l].append(TC5null_113.count(setTC5_113[l]))
        else:
            fTC5null_113[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_113)):
     if sum(freq >= fTC5_113[l] for freq in fTC5null_113[l]) < 5:
#         print(setTC5_113[l], fTC5_113[l], sum(freq >= fTC5_113[l] for freq in fTC5null_113[l]))
        print(setTC5_113[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# BNNMN
# JJNMJ
# MYJMN
# MNNMJ
# JNYMB
# MBYNN
# MYBN
# MJMMM
# BBJYM
# YYJJB
# YMBB
# JNNMJ
# NMBYJ
# MYJJB
# MNYNJ
# BYJMB
# MJMMN
# YNNJB
# MBYMB
# MBYNB
# BNJMB
# YYNNB
# MYNJN
# YNNNB
# MNYMN
# MNNNN
# JNNMB
# MMYMB
# MJNMN
# YNNJN
# YYBN
# MNNMN
# BBMJM
# MMYYB
# MYBYN
# MMYYJ
# BBBNJ
# YYMM
# JBJJJ
# YYBM
# MYJYN
# MBNMN
# MBYMN
# NYMYJ
# YYJJN
# JBYMB
# YYMJ
# JNNMN
# MNYNM
# MMYYN
# JMNBJ
# MNYMB
# YNNNN
# YYJMN
# NYBYJ
# MNNNB
# MBMNM
# BNM
# NBMN
# NYNYJ
# MBNMJ
# BBM
# MYJJN
# MJMJM
# BYNMB
# MNYNB
# YYNJN
# JBBYN
# MNYMJ
# MYMN
# BNNMB
# MYMYB
# YYBB
# NMMYJ
# MNYNN
# YYBJ
# MMYMN

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_113)):
     if sum(freq >= fTC5_113[l] for freq in fTC5null_113[l]) < 1:
#         print(setTC5_113[l], fTC5_113[l], sum(freq >= fTC5_113[l] for freq in fTC5null_113[l]))
        print(setTC5_113[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# MYJMN
# BBJYM
# YNNNB
# MMYMB
# YYJJN
# JNNMN
# MNYMB
# MYJJN
# YYBB

# %% [markdown]
# # 3.114 (B) AP - (J) FGEN - (M) ICT - (N) JGS - (α) SCC

# %%
#extract overlapping dates
start_114 = max(min(Date_AP), min(Date_FGEN), min(Date_ICT), min(Date_JGS), min(Date_SCC))
end_114 = min(max(Date_AP), max(Date_FGEN), max(Date_ICT), max(Date_JGS), max(Date_SCC))

# %%
#shorten the closing prices
AP_114_1 = Date_AP.index(start_114)
AP_114_2 = Date_AP.index(end_114)

FGEN_114_1 = Date_FGEN.index(start_114)
FGEN_114_2 = Date_FGEN.index(end_114)

ICT_114_1 = Date_ICT.index(start_114)
ICT_114_2 = Date_ICT.index(end_114)

JGS_114_1 = Date_JGS.index(start_114)
JGS_114_2 = Date_JGS.index(end_114)

SCC_114_1 = Date_SCC.index(start_114)
SCC_114_2 = Date_SCC.index(end_114)

# %%
#save the shortened versions of closing prices
B114 = np.save('APshortPrices.npy', ClosePrice_AP[AP_114_1:AP_114_2])
J114 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_114_1:FGEN_114_2])
M114 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_114_1:ICT_114_2])
N114 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_114_1:JGS_114_2])
α114 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_114_1:SCC_114_2])

# %%
# import modules
import numpy as np
# import prices

B114 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
J114 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M114 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N114 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
α114 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_114 = []
st_114 = []
n = 1
while n < len(B114):
    sc_114 = ''
    if B114[n] > B114[n-1]:
        sc_114 = sc_114 + 'B'
    if J114[n] > J114[n-1]:
        sc_114 = sc_114 + 'J'
    if M114[n] > M114[n-1]:
        sc_114 = sc_114 + 'M'
    if N114[n] > N114[n-1]:
        sc_114 = sc_114 + 'N'
    if α114[n] > α114[n-1]:
        sc_114 = sc_114 + 'α'
    if len(sc_114) > 0:
        st_114.append(sc_114)
    else:
        STC_114.append(st_114)
        st_114 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_114 = STC_114.count([])
# keep only non-empty spatio-temporal sequences
STC_114 = [ st_114 for st_114 in STC_114 if len(st_114) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_114 = len(B114)
lmax_114 = 0
for st_114 in STC_114:
    if len(st_114) < lmin_114:
        lmin_114 = len(st_114)
    if len(st_114) > lmax_114:
        lmax_114 = len(st_114)
        
# restrict spatio-temporal sequences to length-5
STC5_114 = [ st_114 for st_114 in STC_114 if len(st_114) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_114 = []
for n in range(len(STC5_114)):
    tc_114 = [ u for u in STC5_114[n][0] ]
    for k in range(1, len(STC5_114[n])):
        tc_114 = [ u+v for u in tc_114 for v in STC5_114[n][k] ]
    TC5_114 = TC5_114 + tc_114
setTC5_114 = list(set(TC5_114))

# get empirical frequencies
fTC5_114 = [ TC5_114.count(setTC5_114[l]) for l in range(len(setTC5_114)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_114 = [ [] for l in range(len(setTC5_114)) ]
for s in range(100):
    STC5null_114 = [ list(st_114) for st_114 in STC5_114]
    for st_114 in STC5null_114:
        np.random.shuffle(st_114)
    TC5null_114= []
    for n in range(len(STC5null_114)):
        tc_114 = [ u for u in STC5null_114[n][0] ]
        for k in range(1, len(STC5null_114[n])):
            tc_114 = [ u+v for u in tc_114 for v in STC5null_114[n][k] ]
        TC5null_114= TC5null_114+ tc_114
    for l in range(len(setTC5_114)):
        if TC5null_114.count(setTC5_114[l]) > 0:
            fTC5null_114[l].append(TC5null_114.count(setTC5_114[l]))
        else:
            fTC5null_114[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_114)):
     if sum(freq >= fTC5_114[l] for freq in fTC5null_114[l]) < 5:
#         print(setTC5_114[l], fTC5_114[l], sum(freq >= fTC5_114[l] for freq in fTC5null_114[l]))
        print(setTC5_114[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# αJJNJ
# ααNBB
# JMNB
# BMMBM
# BBJNJ
# ααJJJ
# ααJB
# BJBBJ
# BαM
# ααMN
# JαBN
# BBNMM
# αMBNJ
# ααNNJ
# αNNJM
# JαNα
# MJMMM
# NαNJB
# BMBBM
# MJBJM
# ααNJJ
# ααNJB
# NJBJM
# NαBJJ
# ααNJM
# ααJNJ
# ααNBJ
# JαNB
# ααJαJ
# ααBBJ
# MJMMN
# MMNB
# NαNJJ
# JJJN
# αJBNM
# ααMBJ
# NJNNM
# NBJN
# JJNB
# ααBMJ
# αJMMJ
# ααNαB
# αBNB
# JBNB
# ααNαJ
# αJBNJ
# BBMJM
# ααBJB
# NJNMM
# ααNB
# αJNMM
# JMJN
# NαNJM
# αBJJJ
# αJBMM
# JαMα
# ααJN
# NαNBB
# BJNNM
# JJM
# JBJN
# αNBJJ
# BαN
# JBNN
# NNNJM
# αBααN
# ααααJ
# ααJMJ
# NαNαB
# BJNMM
# BNM
# NαBJM
# NBMN
# αBJN
# αBJNM
# NαNα
# αMNB
# NJJN
# BBJNM
# αBMJM
# αMJαJ
# NJBNM
# MαNB
# αJBBM
# αJNMJ
# ααBJJ
# JαMN
# NBNN
# αJNNM
# αNBNJ
# αJJMJ
# ααBNJ
# NαMN
# JJJα
# αBJNJ
# αNBJM
# MBNB

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_114)):
     if sum(freq >= fTC5_114[l] for freq in fTC5null_114[l]) < 1:
#         print(setTC5_114[l], fTC5_114[l], sum(freq >= fTC5_114[l] for freq in fTC5null_114[l]))
        print(setTC5_114[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# ααNBB
# ααNJB
# MMNB
# JJJN
# ααNαB
# ααNαJ
# αJBNJ
# JMJN
# NαNJM
# BJNNM
# αMNB
# MαNB
# αJBBM
# αJNMJ
# JJJα
# αBJNJ
# MBNB

# %% [markdown]
# # 3.115 (B) AP - (J) FGEN - (M) ICT - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_115 = max(min(Date_AP), min(Date_FGEN), min(Date_ICT), min(Date_MEG), min(Date_SMC))
end_115 = min(max(Date_AP), max(Date_FGEN), max(Date_ICT), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
AP_115_1 = Date_AP.index(start_115)
AP_115_2 = Date_AP.index(end_115)

FGEN_115_1 = Date_FGEN.index(start_115)
FGEN_115_2 = Date_FGEN.index(end_115)

ICT_115_1 = Date_ICT.index(start_115)
ICT_115_2 = Date_ICT.index(end_115)

MEG_115_1 = Date_MEG.index(start_115)
MEG_115_2 = Date_MEG.index(end_115)

SMC_115_1 = Date_SMC.index(start_115)
SMC_115_2 = Date_SMC.index(end_115)

# %%
#save the shortened versions of closing prices
B115 = np.save('APshortPrices.npy', ClosePrice_AP[AP_115_1:AP_115_2])
J115 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_115_1:FGEN_115_2])
M115 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_115_1:ICT_115_2])
R115 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_115_1:MEG_115_2])
Y115 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_115_1:SMC_115_2])

# %%
# import modules
import numpy as np
# import prices

B115 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
J115 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M115 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R115 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y115 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_115 = []
st_115 = []
n = 1
while n < len(B115):
    sc_115 = ''
    if B115[n] > B115[n-1]:
        sc_115 = sc_115 + 'B'
    if J115[n] > J115[n-1]:
        sc_115 = sc_115 + 'J'
    if M115[n] > M115[n-1]:
        sc_115 = sc_115 + 'M'
    if R115[n] > R115[n-1]:
        sc_115 = sc_115 + 'R'
    if Y115[n] > Y115[n-1]:
        sc_115 = sc_115 + 'Y'
    if len(sc_115) > 0:
        st_115.append(sc_115)
    else:
        STC_115.append(st_115)
        st_115 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_115 = STC_115.count([])
# keep only non-empty spatio-temporal sequences
STC_115 = [ st_115 for st_115 in STC_115 if len(st_115) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_115 = len(B115)
lmax_115 = 0
for st_115 in STC_115:
    if len(st_115) < lmin_115:
        lmin_115 = len(st_115)
    if len(st_115) > lmax_115:
        lmax_115 = len(st_115)
        
# restrict spatio-temporal sequences to length-5
STC5_115 = [ st_115 for st_115 in STC_115 if len(st_115) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_115 = []
for n in range(len(STC5_115)):
    tc_115 = [ u for u in STC5_115[n][0] ]
    for k in range(1, len(STC5_115[n])):
        tc_115 = [ u+v for u in tc_115 for v in STC5_115[n][k] ]
    TC5_115 = TC5_115 + tc_115
setTC5_115 = list(set(TC5_115))

# get empirical frequencies
fTC5_115 = [ TC5_115.count(setTC5_115[l]) for l in range(len(setTC5_115)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_115 = [ [] for l in range(len(setTC5_115)) ]
for s in range(100):
    STC5null_115 = [ list(st_115) for st_115 in STC5_115]
    for st_115 in STC5null_115:
        np.random.shuffle(st_115)
    TC5null_115= []
    for n in range(len(STC5null_115)):
        tc_115 = [ u for u in STC5null_115[n][0] ]
        for k in range(1, len(STC5null_115[n])):
            tc_115 = [ u+v for u in tc_115 for v in STC5null_115[n][k] ]
        TC5null_115= TC5null_115+ tc_115
    for l in range(len(setTC5_115)):
        if TC5null_115.count(setTC5_115[l]) > 0:
            fTC5null_115[l].append(TC5null_115.count(setTC5_115[l]))
        else:
            fTC5null_115[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_115)):
     if sum(freq >= fTC5_115[l] for freq in fTC5null_115[l]) < 5:
#         print(setTC5_115[l], fTC5_115[l], sum(freq >= fTC5_115[l] for freq in fTC5null_115[l]))
        print(setTC5_115[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# MBRBB
# JMRBJ
# YJYBB
# YRYJB
# MBRJM
# BBJYM
# YYJJB
# YMBB
# YMJB
# BBBRJ
# JMJBJ
# MYJJB
# YRBB
# MBYMB
# MBBJJ
# MRMYB
# JYYY
# RRJB
# YYYJB
# RBYM
# JBJJJ
# RBJB
# RRMB
# MBJJJ
# RJMMM
# JYBB
# RBB
# YMBR
# JBRJM
# MRYYB
# YMJR

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_115)):
     if sum(freq >= fTC5_115[l] for freq in fTC5null_115[l]) < 1:
#         print(setTC5_115[l], fTC5_115[l], sum(freq >= fTC5_115[l] for freq in fTC5null_115[l]))
        print(setTC5_115[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# YRYJB
# JYYY
# YMJR

# %% [markdown]
# # 3.116 (B) AP - (J) FGEN - (M) ICT - (R) MEG - (α) SCC

# %%
#extract overlapping dates
start_116 = max(min(Date_AP), min(Date_FGEN), min(Date_ICT), min(Date_MEG), min(Date_SCC))
end_116 = min(max(Date_AP), max(Date_FGEN), max(Date_ICT), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
AP_116_1 = Date_AP.index(start_116)
AP_116_2 = Date_AP.index(end_116)

FGEN_116_1 = Date_FGEN.index(start_116)
FGEN_116_2 = Date_FGEN.index(end_116)

ICT_116_1 = Date_ICT.index(start_116)
ICT_116_2 = Date_ICT.index(end_116)

MEG_116_1 = Date_MEG.index(start_116)
MEG_116_2 = Date_MEG.index(end_116)

SCC_116_1 = Date_SCC.index(start_116)
SCC_116_2 = Date_SCC.index(end_116)

# %%
#save the shortened versions of closing prices
B116 = np.save('APshortPrices.npy', ClosePrice_AP[AP_116_1:AP_116_2])
J116 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_116_1:FGEN_116_2])
M116 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_116_1:ICT_116_2])
R116 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_116_1:MEG_116_2])
α116 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_116_1:SCC_116_2])

# %%
# import modules
import numpy as np
# import prices

B116 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
J116 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M116 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R116 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α116 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_116 = []
st_116 = []
n = 1
while n < len(B116):
    sc_116 = ''
    if B116[n] > B116[n-1]:
        sc_116 = sc_116 + 'B'
    if J116[n] > J116[n-1]:
        sc_116 = sc_116 + 'J'
    if M116[n] > M116[n-1]:
        sc_116 = sc_116 + 'M'
    if R116[n] > R116[n-1]:
        sc_116 = sc_116 + 'R'
    if α116[n] > α116[n-1]:
        sc_116 = sc_116 + 'α'
    if len(sc_116) > 0:
        st_116.append(sc_116)
    else:
        STC_116.append(st_116)
        st_116 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_116 = STC_116.count([])
# keep only non-empty spatio-temporal sequences
STC_116 = [ st_116 for st_116 in STC_116 if len(st_116) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_116 = len(B116)
lmax_116 = 0
for st_116 in STC_116:
    if len(st_116) < lmin_116:
        lmin_116 = len(st_116)
    if len(st_116) > lmax_116:
        lmax_116 = len(st_116)
        
# restrict spatio-temporal sequences to length-5
STC5_116 = [ st_116 for st_116 in STC_116 if len(st_116) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_116 = []
for n in range(len(STC5_116)):
    tc_116 = [ u for u in STC5_116[n][0] ]
    for k in range(1, len(STC5_116[n])):
        tc_116 = [ u+v for u in tc_116 for v in STC5_116[n][k] ]
    TC5_116 = TC5_116 + tc_116
setTC5_116 = list(set(TC5_116))

# get empirical frequencies
fTC5_116 = [ TC5_116.count(setTC5_116[l]) for l in range(len(setTC5_116)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_116 = [ [] for l in range(len(setTC5_116)) ]
for s in range(100):
    STC5null_116 = [ list(st_116) for st_116 in STC5_116]
    for st_116 in STC5null_116:
        np.random.shuffle(st_116)
    TC5null_116= []
    for n in range(len(STC5null_116)):
        tc_116 = [ u for u in STC5null_116[n][0] ]
        for k in range(1, len(STC5null_116[n])):
            tc_116 = [ u+v for u in tc_116 for v in STC5null_116[n][k] ]
        TC5null_116= TC5null_116+ tc_116
    for l in range(len(setTC5_116)):
        if TC5null_116.count(setTC5_116[l]) > 0:
            fTC5null_116[l].append(TC5null_116.count(setTC5_116[l]))
        else:
            fTC5null_116[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_116)):
     if sum(freq >= fTC5_116[l] for freq in fTC5null_116[l]) < 5:
#         print(setTC5_116[l], fTC5_116[l], sum(freq >= fTC5_116[l] for freq in fTC5null_116[l]))
        print(setTC5_116[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# MJBBR
# ααBB
# ααMR
# JMJR
# αMJB
# RMααM
# RMJαα
# ααJB
# JMBαα
# MαMM
# RRαRJ
# JMRR
# αMJR
# ααRB
# RBMBB
# RRMαM
# RBMαα
# αMBR
# JαMM
# ααMB
# αJBJR
# αMMBM
# RRMRJ
# RMJB
# JMααα
# RRMαJ
# JMBJM
# RMMBα
# JMαBα
# ααJR
# RαMM
# αBJRJ
# MJBJR
# RRMMR
# RαJB
# JMJBM
# αMRR
# αMBBM
# RαJα
# JMJBα
# BBMRα
# MBMαB
# MMBBM
# Rα
# RRJB
# RRMMα
# RαJR
# JMααJ
# αMJBM
# αMMR
# RRMMM
# JMBBM
# JJJB
# RJJB
# MRJ
# RBMαM
# RBRB
# RMBBM
# RRMαα
# RBMαB
# αBαBα
# RJBJR
# RMMαM
# JMMαM
# RMαBα
# αMRB
# JBM
# αMαBα
# JMMBα
# αMBBα
# MMRB
# RMMαJ
# RJJRJ
# RMJαM
# RRMBα
# JMJαM
# RMBBα
# αMBJM
# MMJB
# RRMBJ
# RRααJ
# RRMRR
# αBMJM
# MMJR
# αJBBM
# JMBBα
# JMMαα
# ααBJJ
# RBααα
# RMααα
# RMJBM
# BBJRJ
# BMRB
# RMBαα
# RMJBα
# αMMBα
# JJJα
# RRαBα
# RBMBα
# αMBBJ
# JMJαα
# αMJαα
# RRMRM
# RRMRα
# RMMαα
# RBMRα
# RαMR

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_116)):
     if sum(freq >= fTC5_116[l] for freq in fTC5null_116[l]) < 1:
#         print(setTC5_116[l], fTC5_116[l], sum(freq >= fTC5_116[l] for freq in fTC5null_116[l]))
        print(setTC5_116[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# JMBαα
# αMJR
# ααJR
# αBJRJ
# αMRR
# αMBBM
# RαJR
# RRMMM
# RBMαM
# RMBBM
# RMMαM
# RMBBα
# MMJB
# JMBBα
# BBJRJ
# RMBαα
# RRMRα
# RMMαα
# RαMR

# %% [markdown]
# # 3.117 (B) AP - (J) FGEN - (M) ICT - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_117 = max(min(Date_AP), min(Date_FGEN), min(Date_ICT), min(Date_SMC), min(Date_SCC))
end_117 = min(max(Date_AP), max(Date_FGEN), max(Date_ICT), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
AP_117_1 = Date_AP.index(start_117)
AP_117_2 = Date_AP.index(end_117)

FGEN_117_1 = Date_FGEN.index(start_117)
FGEN_117_2 = Date_FGEN.index(end_117)

ICT_117_1 = Date_ICT.index(start_117)
ICT_117_2 = Date_ICT.index(end_117)

SMC_117_1 = Date_SMC.index(start_117)
SMC_117_2 = Date_SMC.index(end_117)

SCC_117_1 = Date_SCC.index(start_117)
SCC_117_2 = Date_SCC.index(end_117)

# %%
#save the shortened versions of closing prices
B117 = np.save('APshortPrices.npy', ClosePrice_AP[AP_117_1:AP_117_2])
J117 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_117_1:FGEN_117_2])
M117 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_117_1:ICT_117_2])
Y117 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_117_1:SMC_117_2])
α117 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_117_1:SCC_117_2])

# %%
# import modules
import numpy as np
# import prices

B117 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
J117 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M117 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
Y117 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α117 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_117 = []
st_117 = []
n = 1
while n < len(B117):
    sc_117 = ''
    if B117[n] > B117[n-1]:
        sc_117 = sc_117 + 'B'
    if J117[n] > J117[n-1]:
        sc_117 = sc_117 + 'J'
    if M117[n] > M117[n-1]:
        sc_117 = sc_117 + 'M'
    if Y117[n] > Y117[n-1]:
        sc_117 = sc_117 + 'Y'
    if α117[n] > α117[n-1]:
        sc_117 = sc_117 + 'α'
    if len(sc_117) > 0:
        st_117.append(sc_117)
    else:
        STC_117.append(st_117)
        st_117 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_117 = STC_117.count([])
# keep only non-empty spatio-temporal sequences
STC_117 = [ st_117 for st_117 in STC_117 if len(st_117) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_117 = len(B117)
lmax_117 = 0
for st_117 in STC_117:
    if len(st_117) < lmin_117:
        lmin_117 = len(st_117)
    if len(st_117) > lmax_117:
        lmax_117 = len(st_117)
        
# restrict spatio-temporal sequences to length-5
STC5_117 = [ st_117 for st_117 in STC_117 if len(st_117) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_117 = []
for n in range(len(STC5_117)):
    tc_117 = [ u for u in STC5_117[n][0] ]
    for k in range(1, len(STC5_117[n])):
        tc_117 = [ u+v for u in tc_117 for v in STC5_117[n][k] ]
    TC5_117 = TC5_117 + tc_117
setTC5_117 = list(set(TC5_117))

# get empirical frequencies
fTC5_117 = [ TC5_117.count(setTC5_117[l]) for l in range(len(setTC5_117)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_117 = [ [] for l in range(len(setTC5_117)) ]
for s in range(100):
    STC5null_117 = [ list(st_117) for st_117 in STC5_117]
    for st_117 in STC5null_117:
        np.random.shuffle(st_117)
    TC5null_117= []
    for n in range(len(STC5null_117)):
        tc_117 = [ u for u in STC5null_117[n][0] ]
        for k in range(1, len(STC5null_117[n])):
            tc_117 = [ u+v for u in tc_117 for v in STC5null_117[n][k] ]
        TC5null_117= TC5null_117+ tc_117
    for l in range(len(setTC5_117)):
        if TC5null_117.count(setTC5_117[l]) > 0:
            fTC5null_117[l].append(TC5null_117.count(setTC5_117[l]))
        else:
            fTC5null_117[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_117)):
     if sum(freq >= fTC5_117[l] for freq in fTC5null_117[l]) < 5:
#         print(setTC5_117[l], fTC5_117[l], sum(freq >= fTC5_117[l] for freq in fTC5null_117[l]))
        print(setTC5_117[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# JααYJ
# BYαYB
# JBBYα
# ααMα
# ααJB
# JMJYJ
# YBααB
# MMYαα
# YαJM
# MBYYB
# BMαYJ
# MJMMM
# BMBBM
# YMBB
# MBYαα
# αMMYJ
# JMJBJ
# BMαYα
# αMαYJ
# MYY
# JYBα
# JMαYJ
# JMααα
# JMαBα
# YαJB
# MαMYJ
# BMJαM
# αMαYB
# MαYYB
# MBMJM
# MMYMB
# αMYYB
# BBMJM
# MMYYB
# JMαYα
# YMBJ
# BMααα
# MYMα
# JJM
# αMααα
# αMαBα
# BMYBB
# BαMα
# BMYYB
# MBYMα
# MMYYα
# JMαYB
# MαYYJ
# JBYBα
# BMYαB
# JBMYα
# MJM
# JBYYα
# YαJJ
# αMαYα
# MYα
# YYBB
# MBYYα
# MJMYM
# MMYMα
# BMαYB
# JBYMα
# αYMα

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_117)):
     if sum(freq >= fTC5_117[l] for freq in fTC5null_117[l]) < 1:
#         print(setTC5_117[l], fTC5_117[l], sum(freq >= fTC5_117[l] for freq in fTC5null_117[l]))
        print(setTC5_117[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# MJMMM
# JMαYJ
# MMYYB
# YMBJ
# JJM
# JBYYα
# αMαYα
# MMYMα
# BMαYB

# %% [markdown]
# # 3.118 (B) AP - (J) FGEN - (N) JGS - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_118 = max(min(Date_AP), min(Date_FGEN), min(Date_JGS), min(Date_MEG), min(Date_SMC))
end_118 = min(max(Date_AP), max(Date_FGEN), max(Date_JGS), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
AP_118_1 = Date_AP.index(start_118)
AP_118_2 = Date_AP.index(end_118)

FGEN_118_1 = Date_FGEN.index(start_118)
FGEN_118_2 = Date_FGEN.index(end_118)

JGS_118_1 = Date_JGS.index(start_118)
JGS_118_2 = Date_JGS.index(end_118)

MEG_118_1 = Date_MEG.index(start_118)
MEG_118_2 = Date_MEG.index(end_118)

SMC_118_1 = Date_SMC.index(start_118)
SMC_118_2 = Date_SMC.index(end_118)

# %%
#save the shortened versions of closing prices
B118 = np.save('APshortPrices.npy', ClosePrice_AP[AP_118_1:AP_118_2])
J118 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_118_1:FGEN_118_2])
N118 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_118_1:JGS_118_2])
R118 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_118_1:MEG_118_2])
Y118 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_118_1:SMC_118_2])

# %%
# import modules
import numpy as np
# import prices

B118 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
J118 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N118 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R118 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y118 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_118 = []
st_118 = []
n = 1
while n < len(B118):
    sc_118 = ''
    if B118[n] > B118[n-1]:
        sc_118 = sc_118 + 'B'
    if J118[n] > J118[n-1]:
        sc_118 = sc_118 + 'J'
    if N118[n] > N118[n-1]:
        sc_118 = sc_118 + 'N'
    if R118[n] > R118[n-1]:
        sc_118 = sc_118 + 'R'
    if Y118[n] > Y118[n-1]:
        sc_118 = sc_118 + 'Y'
    if len(sc_118) > 0:
        st_118.append(sc_118)
    else:
        STC_118.append(st_118)
        st_118 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_118 = STC_118.count([])
# keep only non-empty spatio-temporal sequences
STC_118 = [ st_118 for st_118 in STC_118 if len(st_118) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_118 = len(B118)
lmax_118 = 0
for st_118 in STC_118:
    if len(st_118) < lmin_118:
        lmin_118 = len(st_118)
    if len(st_118) > lmax_118:
        lmax_118 = len(st_118)
        
# restrict spatio-temporal sequences to length-5
STC5_118 = [ st_118 for st_118 in STC_118 if len(st_118) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_118 = []
for n in range(len(STC5_118)):
    tc_118 = [ u for u in STC5_118[n][0] ]
    for k in range(1, len(STC5_118[n])):
        tc_118 = [ u+v for u in tc_118 for v in STC5_118[n][k] ]
    TC5_118 = TC5_118 + tc_118
setTC5_118 = list(set(TC5_118))

# get empirical frequencies
fTC5_118 = [ TC5_118.count(setTC5_118[l]) for l in range(len(setTC5_118)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_118 = [ [] for l in range(len(setTC5_118)) ]
for s in range(100):
    STC5null_118 = [ list(st_118) for st_118 in STC5_118]
    for st_118 in STC5null_118:
        np.random.shuffle(st_118)
    TC5null_118= []
    for n in range(len(STC5null_118)):
        tc_118 = [ u for u in STC5null_118[n][0] ]
        for k in range(1, len(STC5null_118[n])):
            tc_118 = [ u+v for u in tc_118 for v in STC5null_118[n][k] ]
        TC5null_118= TC5null_118+ tc_118
    for l in range(len(setTC5_118)):
        if TC5null_118.count(setTC5_118[l]) > 0:
            fTC5null_118[l].append(TC5null_118.count(setTC5_118[l]))
        else:
            fTC5null_118[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_118)):
     if sum(freq >= fTC5_118[l] for freq in fTC5null_118[l]) < 5:
#         print(setTC5_118[l], fTC5_118[l], sum(freq >= fTC5_118[l] for freq in fTC5null_118[l]))
        print(setTC5_118[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# BJYRB
# RJYJJ
# YNBNJ
# RNYRB
# YYBYY
# JRJN
# YNRNJ
# RYJ
# NYBNJ
# RJBBY
# YNYNJ
# RNYJR
# RNJNJ
# RNYNJ
# RRB
# RNYJB
# RNBBB
# BNJRB
# BNYRB
# JYJB
# RYB
# NYBYR
# YRBB
# RJJBB
# YNNJB
# YNYJJ
# YYRJR
# NRJB
# JYJN
# YBYJB
# YNYRJ
# YNYNB
# RYBYR
# YNNNB
# BJYJB
# RJJBJ
# RJYNB
# RYJRN
# RNNNN
# NYBB
# BNYNB
# YJJN
# RJJNY
# RYRYY
# JYYY
# YNYJR
# YRBR
# RJYRB
# YYRYR
# RJJBY
# RYBYN
# BYJNB
# RNBNJ
# YNYRB
# YJYJB
# RNYJJ
# RJBBB
# NRBB
# JYBB
# JNYJR
# YNYJB
# RBYRB
# NYBYJ
# JYNB
# YYJB
# YNNRB
# RJYJB
# RNYNB
# BNBNJ
# BBRRB
# YNNJJ
# YYRJN
# YYRYN
# JRNY
# YJYRB
# YYBB
# YYRYY
# BNNNB
# RNNNB

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_118)):
     if sum(freq >= fTC5_118[l] for freq in fTC5null_118[l]) < 1:
#         print(setTC5_118[l], fTC5_118[l], sum(freq >= fTC5_118[l] for freq in fTC5null_118[l]))
        print(setTC5_118[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# YNYNB
# YNNNB
# BJYJB
# RJYRB
# YNYRB
# YJYJB
# RNYJJ
# RJBBB
# NRBB
# YNYJB
# RNYNB

# %% [markdown]
# # 3.119 (B) AP - (J) FGEN - (N) JGS - (R) MEG - (α) SCC

# %%
#extract overlapping dates
start_119 = max(min(Date_AP), min(Date_FGEN), min(Date_JGS), min(Date_MEG), min(Date_SCC))
end_119 = min(max(Date_AP), max(Date_FGEN), max(Date_JGS), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
AP_119_1 = Date_AP.index(start_119)
AP_119_2 = Date_AP.index(end_119)

FGEN_119_1 = Date_FGEN.index(start_119)
FGEN_119_2 = Date_FGEN.index(end_119)

JGS_119_1 = Date_JGS.index(start_119)
JGS_119_2 = Date_JGS.index(end_119)

MEG_119_1 = Date_MEG.index(start_119)
MEG_119_2 = Date_MEG.index(end_119)

SCC_119_1 = Date_SCC.index(start_119)
SCC_119_2 = Date_SCC.index(end_119)

# %%
#save the shortened versions of closing prices
B119 = np.save('APshortPrices.npy', ClosePrice_AP[AP_119_1:AP_119_2])
J119 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_119_1:FGEN_119_2])
N119 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_119_1:JGS_119_2])
R119 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_119_1:MEG_119_2])
α119 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_119_1:SCC_119_2])

# %%
# import modules
import numpy as np
# import prices

B119 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
J119 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N119 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R119 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α119 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_119 = []
st_119 = []
n = 1
while n < len(B119):
    sc_119 = ''
    if B119[n] > B119[n-1]:
        sc_119 = sc_119 + 'B'
    if J119[n] > J119[n-1]:
        sc_119 = sc_119 + 'J'
    if N119[n] > N119[n-1]:
        sc_119 = sc_119 + 'N'
    if R119[n] > R119[n-1]:
        sc_119 = sc_119 + 'R'
    if α119[n] > α119[n-1]:
        sc_119 = sc_119 + 'α'
    if len(sc_119) > 0:
        st_119.append(sc_119)
    else:
        STC_119.append(st_119)
        st_119 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_119 = STC_119.count([])
# keep only non-empty spatio-temporal sequences
STC_119 = [ st_119 for st_119 in STC_119 if len(st_119) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_119 = len(B119)
lmax_119 = 0
for st_119 in STC_119:
    if len(st_119) < lmin_119:
        lmin_119 = len(st_119)
    if len(st_119) > lmax_119:
        lmax_119 = len(st_119)
        
# restrict spatio-temporal sequences to length-5
STC5_119 = [ st_119 for st_119 in STC_119 if len(st_119) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_119 = []
for n in range(len(STC5_119)):
    tc_119 = [ u for u in STC5_119[n][0] ]
    for k in range(1, len(STC5_119[n])):
        tc_119 = [ u+v for u in tc_119 for v in STC5_119[n][k] ]
    TC5_119 = TC5_119 + tc_119
setTC5_119 = list(set(TC5_119))

# get empirical frequencies
fTC5_119 = [ TC5_119.count(setTC5_119[l]) for l in range(len(setTC5_119)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_119 = [ [] for l in range(len(setTC5_119)) ]
for s in range(100):
    STC5null_119 = [ list(st_119) for st_119 in STC5_119]
    for st_119 in STC5null_119:
        np.random.shuffle(st_119)
    TC5null_119= []
    for n in range(len(STC5null_119)):
        tc_119 = [ u for u in STC5null_119[n][0] ]
        for k in range(1, len(STC5null_119[n])):
            tc_119 = [ u+v for u in tc_119 for v in STC5null_119[n][k] ]
        TC5null_119= TC5null_119+ tc_119
    for l in range(len(setTC5_119)):
        if TC5null_119.count(setTC5_119[l]) > 0:
            fTC5null_119[l].append(TC5null_119.count(setTC5_119[l]))
        else:
            fTC5null_119[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_119)):
     if sum(freq >= fTC5_119[l] for freq in fTC5null_119[l]) < 5:
#         print(setTC5_119[l], fTC5_119[l], sum(freq >= fTC5_119[l] for freq in fTC5null_119[l]))
        print(setTC5_119[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# BJBBα
# RαRB
# RJBNα
# ααBB
# RRαRN
# RNαBB
# BαB
# BBαRB
# RRαRα
# BBJNJ
# RRαRB
# RααRJ
# RJBJα
# RJBBα
# ααJB
# BJBBJ
# RRαRJ
# RJJNJ
# BααRJ
# JNBBN
# ααRB
# JJRN
# NαBB
# RBRNα
# JNNRN
# ααNJJ
# αRNRN
# ααNJB
# RααRα
# ααJNJ
# ααJRJ
# ααJαJ
# RNNBN
# RRRB
# RαNBα
# JJJN
# JαJN
# RJJRR
# JαJB
# BαNαJ
# RJαRB
# αBJRJ
# JRNRN
# ααNRJ
# RBαRB
# BαNRB
# RααNJ
# RααRB
# RJααB
# NNBNα
# Rα
# ααNRB
# BBJRR
# BBBNJ
# NRαRJ
# αNNBN
# αααRJ
# αNBJα
# RNBNJ
# ααJN
# BNααJ
# αNBJR
# BNBBJ
# BBRNJ
# BNαRB
# αααRB
# RRJRα
# BαNα
# RNαRB
# BJαRB
# RαNNα
# RNBNα
# JαRB
# RJBJR
# NRBB
# RRJNα
# NRNα
# RNBRα
# RRJ
# BJBNJ
# ααRN
# ααααJ
# RJBNJ
# BBNRB
# BααRB
# RJJRJ
# αJRB
# αBRB
# RNααJ
# NαNα
# NJRN
# NRBJR
# BNααB
# αNJBN
# RαααJ
# BBRRR
# RαNRB
# RNBBα
# ααBN
# JNNBN
# NαRB
# BNBNJ
# ααBJJ
# BBRRB
# RNBBJ
# αRNRα
# BBJRJ
# BαααJ
# RJBBJ
# RRNRα
# JJJα
# ααRR
# αBJNJ
# RαNRα
# ααNRα

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_119)):
     if sum(freq >= fTC5_119[l] for freq in fTC5null_119[l]) < 1:
#         print(setTC5_119[l], fTC5_119[l], sum(freq >= fTC5_119[l] for freq in fTC5null_119[l]))
        print(setTC5_119[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# RJBNα
# ααBB
# RRαRN
# RRαRB
# RααRJ
# RJBBα
# ααJB
# BJBBJ
# ααRB
# ααJNJ
# ααJRJ
# RJαRB
# RBαRB
# RααRB
# RNBNJ
# BNαRB
# RNαRB
# RNBNα
# BNBNJ
# BαααJ
# JJJα
# RαNRα

# %% [markdown]
# # 3.120 (B) AP - (J) FGEN - (N) JGS - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_120 = max(min(Date_AP), min(Date_FGEN), min(Date_JGS), min(Date_SMC), min(Date_SCC))
end_120 = min(max(Date_AP), max(Date_FGEN), max(Date_JGS), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
AP_120_1 = Date_AP.index(start_120)
AP_120_2 = Date_AP.index(end_120)

FGEN_120_1 = Date_FGEN.index(start_120)
FGEN_120_2 = Date_FGEN.index(end_120)

JGS_120_1 = Date_JGS.index(start_120)
JGS_120_2 = Date_JGS.index(end_120)

SMC_120_1 = Date_SMC.index(start_120)
SMC_120_2 = Date_SMC.index(end_120)

SCC_120_1 = Date_SCC.index(start_120)
SCC_120_2 = Date_SCC.index(end_120)

# %%
#save the shortened versions of closing prices
B120 = np.save('APshortPrices.npy', ClosePrice_AP[AP_120_1:AP_120_2])
J120 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_120_1:FGEN_120_2])
N120 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_120_1:JGS_120_2])
Y120 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_120_1:SMC_120_2])
α120 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_120_1:SCC_120_2])

# %%
# import modules
import numpy as np
# import prices

B120 = np.load('APshortPrices.npy', allow_pickle=True).tolist() 
J120 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N120 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y120 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α120 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_120 = []
st_120 = []
n = 1
while n < len(B120):
    sc_120 = ''
    if B120[n] > B120[n-1]:
        sc_120 = sc_120 + 'B'
    if J120[n] > J120[n-1]:
        sc_120 = sc_120 + 'J'
    if N120[n] > N120[n-1]:
        sc_120 = sc_120 + 'N'
    if Y120[n] > Y120[n-1]:
        sc_120 = sc_120 + 'Y'
    if α120[n] > α120[n-1]:
        sc_120 = sc_120 + 'α'
    if len(sc_120) > 0:
        st_120.append(sc_120)
    else:
        STC_120.append(st_120)
        st_120 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_120 = STC_120.count([])
# keep only non-empty spatio-temporal sequences
STC_120 = [ st_120 for st_120 in STC_120 if len(st_120) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_120 = len(B120)
lmax_120 = 0
for st_120 in STC_120:
    if len(st_120) < lmin_120:
        lmin_120 = len(st_120)
    if len(st_120) > lmax_120:
        lmax_120 = len(st_120)
        
# restrict spatio-temporal sequences to length-5
STC5_120 = [ st_120 for st_120 in STC_120 if len(st_120) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_120 = []
for n in range(len(STC5_120)):
    tc_120 = [ u for u in STC5_120[n][0] ]
    for k in range(1, len(STC5_120[n])):
        tc_120 = [ u+v for u in tc_120 for v in STC5_120[n][k] ]
    TC5_120 = TC5_120 + tc_120
setTC5_120 = list(set(TC5_120))

# get empirical frequencies
fTC5_120 = [ TC5_120.count(setTC5_120[l]) for l in range(len(setTC5_120)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_120 = [ [] for l in range(len(setTC5_120)) ]
for s in range(100):
    STC5null_120 = [ list(st_120) for st_120 in STC5_120]
    for st_120 in STC5null_120:
        np.random.shuffle(st_120)
    TC5null_120= []
    for n in range(len(STC5null_120)):
        tc_120 = [ u for u in STC5null_120[n][0] ]
        for k in range(1, len(STC5null_120[n])):
            tc_120 = [ u+v for u in tc_120 for v in STC5null_120[n][k] ]
        TC5null_120= TC5null_120+ tc_120
    for l in range(len(setTC5_120)):
        if TC5null_120.count(setTC5_120[l]) > 0:
            fTC5null_120[l].append(TC5null_120.count(setTC5_120[l]))
        else:
            fTC5null_120[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_120)):
     if sum(freq >= fTC5_120[l] for freq in fTC5null_120[l]) < 5:
#         print(setTC5_120[l], fTC5_120[l], sum(freq >= fTC5_120[l] for freq in fTC5null_120[l]))
        print(setTC5_120[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# JYBN
# YNBNJ
# ααBB
# JBYα
# BYαYB
# BNαNB
# BNB
# ααJJJ
# ααJB
# NαBB
# NYBNJ
# BNBNY
# NYNYN
# NJYJY
# YBBNα
# BBBNα
# ααJαJ
# αNBNY
# YNBNα
# BNY
# BNJ
# YαJB
# YJαNα
# YJBNα
# JYNN
# NYBB
# BBαYB
# NYαB
# YαBB
# JBJJJ
# αBJJJ
# JYYN
# NYNαY
# JαBB
# NBBN
# JYBB
# NYBYJ
# JJYα
# JYNB
# NYNYJ
# NYJYN
# NYBYN
# JYBYN
# NYαYJ
# BNBNJ
# BαBNB
# YYBB
# αBBJJ
# BJNYB
# BNNNB
# ααJNB
# JYYα

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_120)):
     if sum(freq >= fTC5_120[l] for freq in fTC5null_120[l]) < 1:
#         print(setTC5_120[l], fTC5_120[l], sum(freq >= fTC5_120[l] for freq in fTC5null_120[l]))
        print(setTC5_120[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# ααBB
# YBBNα
# YNBNα
# BNY
# YJBNα
# JYNN
# NYBB
# JBJJJ
# NYBYJ
# NYαYJ
# JYYα
