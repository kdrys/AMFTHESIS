# %% [markdown]
# # One-Letter Words

# %%
# open the csv files
AP = open('AP.csv')
AC = open('AC.csv')
BPI = open('BPI.csv')
BLOOM = open('BLOOM.csv')
FGEN = open('FGEN.csv')
ICT = open('ICT.csv')
JGS = open('JGS.csv')
MEG = open('MEG.csv')
SMC = open('SMC.csv')
SCC = open('SCC.csv')

#initiFGENze the lists
Date_AP = []
ClosePrice_AP = []
Date_AC = []
ClosePrice_AC = []
Date_BPI = []
ClosePrice_BPI = []
Date_BLOOM = []
ClosePrice_BLOOM = []
Date_FGEN = []
ClosePrice_FGEN = []
Date_ICT = []
ClosePrice_ICT = []
Date_JGS = []
ClosePrice_JGS = []
Date_MEG = []
ClosePrice_MEG = []
Date_SMC = []
ClosePrice_SMC = []
Date_SCC = []
ClosePrice_SCC = []

#skip the header line
AP.readline()
AC.readline()
BPI.readline()
BLOOM.readline()
FGEN.readline()
ICT.readline()
JGS.readline()
MEG.readline()
SMC.readline()
SCC.readline()

#go through the files line by line
for line in AP:
    sline = line.strip().split(',')
    Date_AP.append(sline[0])
    ClosePrice_AP.append(float(sline[1]))
    
for line in AC:
    sline = line.strip().split(',')
    Date_AC.append(sline[0])
    ClosePrice_AC.append(float(sline[1]))
    
for line in BPI:
    sline = line.strip().split(',')
    Date_BPI.append(sline[0])
    ClosePrice_BPI.append(float(sline[1]))
    
for line in BLOOM:
    sline = line.strip().split(',')
    Date_BLOOM.append(sline[0])
    ClosePrice_BLOOM.append(float(sline[1]))
    
for line in FGEN:
    sline = line.strip().split(',')
    Date_FGEN.append(sline[0])
    ClosePrice_FGEN.append(float(sline[1]))
    
for line in ICT:
    sline = line.strip().split(',')
    Date_ICT.append(sline[0])
    ClosePrice_ICT.append(float(sline[1]))
    
for line in JGS:
    sline = line.strip().split(',')
    Date_JGS.append(sline[0])
    ClosePrice_JGS.append(float(sline[1]))
    
for line in MEG:
    sline = line.strip().split(',')
    Date_MEG.append(sline[0])
    ClosePrice_MEG.append(float(sline[1]))
    
for line in SMC:
    sline = line.strip().split(',')
    Date_SMC.append(sline[0])
    ClosePrice_SMC.append(float(sline[1]))
        
for line in SCC:
    sline = line.strip().split(',')
    Date_SCC.append(sline[0])
    ClosePrice_SCC.append(float(sline[1]))


#close files
AP.close()
AC.close()
BPI.close()
BLOOM.close()
FGEN.close()
ICT.close()
JGS.close()
MEG.close()
SMC.close()
SCC.close()# One-Letter Words

# %%
import numpy as np
import datetime

# %%
# convert dates into datetime structure
for n in range(len(Date_AP)):
    Date_AP[n] = datetime.datetime.strptime(Date_AP[n], '%m/%d/%y').date()

for n in range(len(Date_AC)):
    Date_AC[n] = datetime.datetime.strptime(Date_AC[n], '%m/%d/%y').date()
    
for n in range(len(Date_BPI)):
    Date_BPI[n] = datetime.datetime.strptime(Date_BPI[n], '%m/%d/%y').date()

for n in range(len(Date_BLOOM)):
    Date_BLOOM[n] = datetime.datetime.strptime(Date_BLOOM[n], '%m/%d/%y').date()
    
for n in range(len(Date_FGEN)):
    Date_FGEN[n] = datetime.datetime.strptime(Date_FGEN[n], '%m/%d/%y').date()

for n in range(len(Date_ICT)):
    Date_ICT[n] = datetime.datetime.strptime(Date_ICT[n], '%m/%d/%y').date()
    
for n in range(len(Date_JGS)):
    Date_JGS[n] = datetime.datetime.strptime(Date_JGS[n], '%m/%d/%y').date()

for n in range(len(Date_MEG)):
    Date_MEG[n] = datetime.datetime.strptime(Date_MEG[n], '%m/%d/%y').date()
    
for n in range(len(Date_SMC)):
    Date_SMC[n] = datetime.datetime.strptime(Date_SMC[n], '%m/%d/%y').date()

for n in range(len(Date_SCC)):
    Date_SCC[n] = datetime.datetime.strptime(Date_SCC[n], '%m/%d/%y').date()
    
# save Date and ClosePrice
np.save('APDate.npy', Date_AP)
np.save('APClosePrice.npy', ClosePrice_AP)
np.save('ACDate.npy', Date_AC)
np.save('ACClosePrice.npy', ClosePrice_AC)
np.save('BPIDate.npy', Date_BPI)
np.save('BPIClosePrice.npy', ClosePrice_BPI)
np.save('BLOOMDate.npy', Date_BLOOM)
np.save('BLOOMClosePrice.npy', ClosePrice_BLOOM)
np.save('FGENDate.npy', Date_FGEN)
np.save('FGENClosePrice.npy', ClosePrice_FGEN)
np.save('ICTDate.npy', Date_ICT)
np.save('ICTClosePrice.npy', ClosePrice_ICT)
np.save('JGSDate.npy', Date_JGS)
np.save('JGSClosePrice.npy', ClosePrice_JGS)
np.save('MEGDate.npy', Date_MEG)
np.save('MEGClosePrice.npy', ClosePrice_MEG)
np.save('SMCDate.npy', Date_SMC)
np.save('SMCClosePrice.npy', ClosePrice_SMC)
np.save('SCCDate.npy', Date_SCC)
np.save('SCCClosePrice.npy', ClosePrice_SCC)

# %% [markdown]
# # Five-letter Words

# %% [markdown]
# # 3.136 (D) AC - (F) BPI - (H) BLOOM - (N) JGS - (R) MEG

# %%
#extract overlapping dates
start_136 = max(min(Date_AC), min(Date_BPI), min(Date_BLOOM), min(Date_JGS), min(Date_MEG))
end_136 = min(max(Date_AC), max(Date_BPI), max(Date_BLOOM), max(Date_JGS), max(Date_MEG))

# %%
#shorten the closing prices
AC_136_1 = Date_AC.index(start_136)
AC_136_2 = Date_AC.index(end_136)

BPI_136_1 = Date_BPI.index(start_136)
BPI_136_2 = Date_BPI.index(end_136)

BLOOM_136_1 = Date_BLOOM.index(start_136)
BLOOM_136_2 = Date_BLOOM.index(end_136)

JGS_136_1 = Date_JGS.index(start_136)
JGS_136_2 = Date_JGS.index(end_136)

MEG_136_1 = Date_MEG.index(start_136)
MEG_136_2 = Date_MEG.index(end_136)

# %%
#save the shortened versions of closing prices
D136 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_136_1:AC_136_2])
F136 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_136_1:BPI_136_2])
H136 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_136_1:BLOOM_136_2])
N136 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_136_1:JGS_136_2])
R136 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_136_1:MEG_136_2])

# %%
# import modules
import numpy as np
# import prices

D136 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F136 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H136 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
N136 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R136 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_136 = []
st_136 = []
n = 1
while n < len(D136):
    sc_136 = ''
    if D136[n] > D136[n-1]:
        sc_136 = sc_136 + 'D'
    if F136[n] > F136[n-1]:
        sc_136 = sc_136 + 'F'
    if H136[n] > H136[n-1]:
        sc_136 = sc_136 + 'H'
    if N136[n] > N136[n-1]:
        sc_136 = sc_136 + 'N'
    if R136[n] > R136[n-1]:
        sc_136 = sc_136 + 'R'
    if len(sc_136) > 0:
        st_136.append(sc_136)
    else:
        STC_136.append(st_136)
        st_136 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_136 = STC_136.count([])
# keep only non-empty spatio-temporal sequences
STC_136 = [ st_136 for st_136 in STC_136 if len(st_136) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_136 = len(D136)
lmax_136 = 0
for st_136 in STC_136:
    if len(st_136) < lmin_136:
        lmin_136 = len(st_136)
    if len(st_136) > lmax_136:
        lmax_136 = len(st_136)
        
# restrJGS spatio-temporal sequences to length-5
STC5_136 = [ st_136 for st_136 in STC_136 if len(st_136) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_136 = []
for n in range(len(STC5_136)):
    tc_136 = [ u for u in STC5_136[n][0] ]
    for k in range(1, len(STC5_136[n])):
        tc_136 = [ u+v for u in tc_136 for v in STC5_136[n][k] ]
    TC5_136 = TC5_136 + tc_136
setTC5_136 = list(set(TC5_136))

# get empirical frequencies
fTC5_136 = [ TC5_136.count(setTC5_136[l]) for l in range(len(setTC5_136)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_136 = [ [] for l in range(len(setTC5_136)) ]
for s in range(100):
    STC5null_136 = [ list(st_136) for st_136 in STC5_136]
    for st_136 in STC5null_136:
        np.random.shuffle(st_136)
    TC5null_136= []
    for n in range(len(STC5null_136)):
        tc_136 = [ u for u in STC5null_136[n][0] ]
        for k in range(1, len(STC5null_136[n])):
            tc_136 = [ u+v for u in tc_136 for v in STC5null_136[n][k] ]
        TC5null_136= TC5null_136+ tc_136
    for l in range(len(setTC5_136)):
        if TC5null_136.count(setTC5_136[l]) > 0:
            fTC5null_136[l].append(TC5null_136.count(setTC5_136[l]))
        else:
            fTC5null_136[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_136)):
     if sum(freq >= fTC5_136[l] for freq in fTC5null_136[l]) < 5:
#         print(setTC5_136[l], fTC5_136[l], sum(freq >= fTC5_136[l] for freq in fTC5null_136[l]))
        print(setTC5_136[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# DHDRR
# FRDDH
# HHFNN
# FDDF
# HHFRN
# NFFNR
# NNFDH
# HRDDH
# FNDNH
# FFFRH
# FNNNH
# FRNF
# RHDNR
# DFFFR
# HHDND
# HHHFF
# HRNRH
# NRNR
# NNFRH
# DNFRH
# DRNRH
# HRNRN
# FFFRN
# FDFF
# DDFDH
# NHFNR
# DRDNR
# HNF
# DDNDH
# FFDNR
# DRNDH
# FNDRH
# FRFRH
# DHNRH
# DDDRH
# HHFRF
# DRFNR
# FDDRH
# DRRRH
# HRHFN
# FDDN
# FNNDH
# DNNRH
# RNFN
# HHRD
# NFFDH
# DDDDH
# RRFRH
# NRFNR
# DDRRR
# FNFNH
# DFFDH
# HHDRD
# FHFN
# FNNHH
# HHDRR
# HRDFN
# FFFNH
# DFFRH
# FRFN
# DHDRD
# FDDDH
# RRF
# FNNRH
# HHDNR
# FRDRH
# FFFDH
# DDRRH
# DDFRH
# RDFDN
# HRDRN
# HDDRH
# HHDRN
# DDRDH
# NRFN
# NFFNH
# HHDNF
# FNDHH
# RNFRH
# DDRNH
# FRFH
# FNFRH
# DRFH
# FNFDH
# DFFNR
# FDNDH
# DHDNR
# HHDNN
# DDNRH
# DHDRN
# RNNDH
# FRNDH
# FRND
# DHDH
# NRFDH
# DFDNR
# DRFRH
# FRDRN
# NRFRH
# HHDRF
# HRDRH
# DHDRF
# NFFRH
# HFFD
# HHDFR
# DNRDH
# FDNRH
# HHFNR
# DNFNR
# FRDHH
# NNFFD
# FNRRH
# DNNDH
# FNDDH
# DNFDH
# DHFNR
# FRNRH
# HRFRF
# HRDRF
# NNNDH

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_136)):
     if sum(freq >= fTC5_136[l] for freq in fTC5null_136[l]) < 1:
#         print(setTC5_136[l], fTC5_136[l], sum(freq >= fTC5_136[l] for freq in fTC5null_136[l]))
        print(setTC5_136[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# FRDDH
# FDDF
# NNFRH
# DNFRH
# FDFF
# FNNDH
# DNNRH
# NRFNR
# FNNHH
# FRFN
# FNNRH
# HHDNR
# FRDRH
# DDFRH
# FNFRH
# DDNRH
# DFDNR
# HRFRF

# %% [markdown]
# # 3.137 (D) AC - (F) BPI - (H) BLOOM - (N) JGS - (Y) SMC

# %%
#extract overlapping dates
start_137 = max(min(Date_AC), min(Date_BPI), min(Date_BLOOM), min(Date_JGS), min(Date_SMC))
end_137 = min(max(Date_AC), max(Date_BPI), max(Date_BLOOM), max(Date_JGS), max(Date_SMC))

# %%
#shorten the closing prices
AC_137_1 = Date_AC.index(start_137)
AC_137_2 = Date_AC.index(end_137)

BPI_137_1 = Date_BPI.index(start_137)
BPI_137_2 = Date_BPI.index(end_137)

BLOOM_137_1 = Date_BLOOM.index(start_137)
BLOOM_137_2 = Date_BLOOM.index(end_137)

JGS_137_1 = Date_JGS.index(start_137)
JGS_137_2 = Date_JGS.index(end_137)

SMC_137_1 = Date_SMC.index(start_137)
SMC_137_2 = Date_SMC.index(end_137)

# %%
#save the shortened versions of closing prices
D137 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_137_1:AC_137_2])
F137 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_137_1:BPI_137_2])
H137 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_137_1:BLOOM_137_2])
N137 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_137_1:JGS_137_2])
Y137 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_137_1:SMC_137_2])

# %%
# import modules
import numpy as np
# import prices

D137 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F137 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H137 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
N137 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y137 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_137 = []
st_137 = []
n = 1
while n < len(D137):
    sc_137 = ''
    if D137[n] > D137[n-1]:
        sc_137 = sc_137 + 'D'
    if F137[n] > F137[n-1]:
        sc_137 = sc_137 + 'F'
    if H137[n] > H137[n-1]:
        sc_137 = sc_137 + 'H'
    if N137[n] > N137[n-1]:
        sc_137 = sc_137 + 'N'
    if Y137[n] > Y137[n-1]:
        sc_137 = sc_137 + 'Y'
    if len(sc_137) > 0:
        st_137.append(sc_137)
    else:
        STC_137.append(st_137)
        st_137 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_137 = STC_137.count([])
# keep only non-empty spatio-temporal sequences
STC_137 = [ st_137 for st_137 in STC_137 if len(st_137) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_137 = len(D137)
lmax_137 = 0
for st_137 in STC_137:
    if len(st_137) < lmin_137:
        lmin_137 = len(st_137)
    if len(st_137) > lmax_137:
        lmax_137 = len(st_137)
        
# restrJGS spatio-temporal sequences to length-5
STC5_137 = [ st_137 for st_137 in STC_137 if len(st_137) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_137 = []
for n in range(len(STC5_137)):
    tc_137 = [ u for u in STC5_137[n][0] ]
    for k in range(1, len(STC5_137[n])):
        tc_137 = [ u+v for u in tc_137 for v in STC5_137[n][k] ]
    TC5_137 = TC5_137 + tc_137
setTC5_137 = list(set(TC5_137))

# get empirical frequencies
fTC5_137 = [ TC5_137.count(setTC5_137[l]) for l in range(len(setTC5_137)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_137 = [ [] for l in range(len(setTC5_137)) ]
for s in range(100):
    STC5null_137 = [ list(st_137) for st_137 in STC5_137]
    for st_137 in STC5null_137:
        np.random.shuffle(st_137)
    TC5null_137= []
    for n in range(len(STC5null_137)):
        tc_137 = [ u for u in STC5null_137[n][0] ]
        for k in range(1, len(STC5null_137[n])):
            tc_137 = [ u+v for u in tc_137 for v in STC5null_137[n][k] ]
        TC5null_137= TC5null_137+ tc_137
    for l in range(len(setTC5_137)):
        if TC5null_137.count(setTC5_137[l]) > 0:
            fTC5null_137[l].append(TC5null_137.count(setTC5_137[l]))
        else:
            fTC5null_137[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_137)):
     if sum(freq >= fTC5_137[l] for freq in fTC5null_137[l]) < 5:
#         print(setTC5_137[l], fTC5_137[l], sum(freq >= fTC5_137[l] for freq in fTC5null_137[l]))
        print(setTC5_137[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# HHDHY
# FYFY
# YYFYY
# HHYNN
# HHFNN
# FHHHY
# DDNDN
# FNDNH
# YFFYN
# NFFNF
# FYDDH
# FHDHY
# HYFD
# FYFN
# DFDND
# NYNFN
# HNF
# HYDF
# DDNDH
# HHHNF
# FFFND
# YYNDH
# YYDFN
# YYFYN
# DDDH
# FNNDH
# DYYY
# DFFFD
# NHDN
# HHY
# DFY
# NFFND
# FYFF
# FYNNN
# FNNHN
# DYNFD
# DFDHY
# FYDNN
# DDY
# NDYFY
# DFDNN
# NFFNN
# DFFNN
# DHNH
# YFFYD
# NFYNN
# DYNDH
# FYDN
# HFFFD
# NNYN
# FDNDH
# YYDN
# HHDNN
# DFFND
# NYYN
# FDDY
# FFDHY
# YYDYY
# HHYNF
# DNNDN
# DYNFN
# FYFD
# FYYN
# FDNNH
# YHFFF
# DNNDH
# HYYF
# HYFF
# FYNY
# HYFN
# DYNDN
# DHDHY
# FFFYN

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_137)):
     if sum(freq >= fTC5_137[l] for freq in fTC5null_137[l]) < 1:
#         print(setTC5_137[l], fTC5_137[l], sum(freq >= fTC5_137[l] for freq in fTC5null_137[l]))
        print(setTC5_137[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# HHDHY
# FHDHY
# HYFD
# HYDF
# YYFYN
# DHNH
# DYNDH
# DFFND
# FFDHY
# HYFF

# %% [markdown]
# # 3.138 (D) AC - (F) BPI - (H) BLOOM - (N) JGS - (α) SCC

# %%
#extract overlapping dates
start_138 = max(min(Date_AC), min(Date_BPI), min(Date_BLOOM), min(Date_JGS), min(Date_SCC))
end_138 = min(max(Date_AC), max(Date_BPI), max(Date_BLOOM), max(Date_JGS), max(Date_SCC))

# %%
#shorten the closing prices
AC_138_1 = Date_AC.index(start_138)
AC_138_2 = Date_AC.index(end_138)

BPI_138_1 = Date_BPI.index(start_138)
BPI_138_2 = Date_BPI.index(end_138)

BLOOM_138_1 = Date_BLOOM.index(start_138)
BLOOM_138_2 = Date_BLOOM.index(end_138)

JGS_138_1 = Date_JGS.index(start_138)
JGS_138_2 = Date_JGS.index(end_138)

SCC_138_1 = Date_SCC.index(start_138)
SCC_138_2 = Date_SCC.index(end_138)

# %%
#save the shortened versions of closing prices
D138 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_138_1:AC_138_2])
F138 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_138_1:BPI_138_2])
H138 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_138_1:BLOOM_138_2])
N138 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_138_1:JGS_138_2])
α138 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_138_1:SCC_138_2])

# %%
# import modules
import numpy as np
# import prices

D138 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F138 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H138 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
N138 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
α138 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_138 = []
st_138 = []
n = 1
while n < len(D138):
    sc_138 = ''
    if D138[n] > D138[n-1]:
        sc_138 = sc_138 + 'D'
    if F138[n] > F138[n-1]:
        sc_138 = sc_138 + 'F'
    if H138[n] > H138[n-1]:
        sc_138 = sc_138 + 'H'
    if N138[n] > N138[n-1]:
        sc_138 = sc_138 + 'N'
    if α138[n] > α138[n-1]:
        sc_138 = sc_138 + 'α'
    if len(sc_138) > 0:
        st_138.append(sc_138)
    else:
        STC_138.append(st_138)
        st_138 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_138 = STC_138.count([])
# keep only non-empty spatio-temporal sequences
STC_138 = [ st_138 for st_138 in STC_138 if len(st_138) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_138 = len(D138)
lmax_138 = 0
for st_138 in STC_138:
    if len(st_138) < lmin_138:
        lmin_138 = len(st_138)
    if len(st_138) > lmax_138:
        lmax_138 = len(st_138)
        
# restrJGS spatio-temporal sequences to length-5
STC5_138 = [ st_138 for st_138 in STC_138 if len(st_138) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_138 = []
for n in range(len(STC5_138)):
    tc_138 = [ u for u in STC5_138[n][0] ]
    for k in range(1, len(STC5_138[n])):
        tc_138 = [ u+v for u in tc_138 for v in STC5_138[n][k] ]
    TC5_138 = TC5_138 + tc_138
setTC5_138 = list(set(TC5_138))

# get empirical frequencies
fTC5_138 = [ TC5_138.count(setTC5_138[l]) for l in range(len(setTC5_138)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_138 = [ [] for l in range(len(setTC5_138)) ]
for s in range(100):
    STC5null_138 = [ list(st_138) for st_138 in STC5_138]
    for st_138 in STC5null_138:
        np.random.shuffle(st_138)
    TC5null_138= []
    for n in range(len(STC5null_138)):
        tc_138 = [ u for u in STC5null_138[n][0] ]
        for k in range(1, len(STC5null_138[n])):
            tc_138 = [ u+v for u in tc_138 for v in STC5null_138[n][k] ]
        TC5null_138= TC5null_138+ tc_138
    for l in range(len(setTC5_138)):
        if TC5null_138.count(setTC5_138[l]) > 0:
            fTC5null_138[l].append(TC5null_138.count(setTC5_138[l]))
        else:
            fTC5null_138[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_138)):
     if sum(freq >= fTC5_138[l] for freq in fTC5null_138[l]) < 5:
#         print(setTC5_138[l], fTC5_138[l], sum(freq >= fTC5_138[l] for freq in fTC5null_138[l]))
        print(setTC5_138[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# DαNH
# HHHFN
# HαHαN
# FNNDD
# HHααα
# HHDαN
# FαDH
# HDFαα
# FαNDH
# FNNNH
# DDααH
# HDHNα
# HHHFF
# HHHFD
# Dαααα
# HαααD
# HNF
# NHFN
# HαHNα
# FNαNH
# DFFD
# FαHFN
# FDαDH
# HαHαD
# HDHαα
# HαNFα
# DDααα
# HαN
# HαHαα
# NFDα
# NαααN
# FααDH
# HDHHα
# FFαNα
# FNNDH
# NFαND
# HαHFα
# DαFN
# HαHFN
# DFND
# FNNαH
# NHDN
# FDαNH
# FαFN
# FDααH
# HαHFD
# FNNHH
# HDDαα
# HDHFα
# FHHFF
# DαααN
# DFNH
# FNNHN
# HαHFF
# FNHFF
# FαHFF
# FNαDH
# DFHH
# FDNαD
# ααNH
# NDHFα
# HHHFα
# DFNN
# NNFN
# FNαHH
# HαDFN
# DHNH
# DαααD
# FNNαD
# HHHαα
# HαHH
# HαFN
# FFNαα
# FαHH
# FDHFF
# HDααα
# NFααα
# FFHH
# NFαNα
# FDNDH
# HαNH
# FNNHD
# HαFD
# DDNH
# HαDFD
# DHDH
# HHDαα
# HHFαα
# HαF
# HαααN
# DαDH
# DαHH
# FFααα
# FαHFα
# DNααH
# FαHFD
# NFFFα
# HαHNN
# FNααH
# HαFH
# HHDαD
# HDDHα
# Hαααα

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_138)):
     if sum(freq >= fTC5_138[l] for freq in fTC5null_138[l]) < 1:
#         print(setTC5_138[l], fTC5_138[l], sum(freq >= fTC5_138[l] for freq in fTC5null_138[l]))
        print(setTC5_138[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# DαNH
# HHααα
# HHDαN
# FαDH
# FNNNH
# HHHFF
# FαHFN
# NFDα
# FNNDH
# HαHFα
# FDααH
# FNNHH
# HDHFα
# FNαDH
# ααNH
# HHHFα
# FFNαα
# DDNH
# HHDαα
# HHFαα
# HαF
# HαααN
# FαHFα
# FαHFD
# HHDαD

# %% [markdown]
# # 3.139 (D) AC - (F) BPI - (H) BLOOM - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_139 = max(min(Date_AC), min(Date_BPI), min(Date_BLOOM), min(Date_MEG), min(Date_SMC))
end_139 = min(max(Date_AC), max(Date_BPI), max(Date_BLOOM), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
AC_139_1 = Date_AC.index(start_139)
AC_139_2 = Date_AC.index(end_139)

BPI_139_1 = Date_BPI.index(start_139)
BPI_139_2 = Date_BPI.index(end_139)

BLOOM_139_1 = Date_BLOOM.index(start_139)
BLOOM_139_2 = Date_BLOOM.index(end_139)

MEG_139_1 = Date_MEG.index(start_139)
MEG_139_2 = Date_MEG.index(end_139)

SMC_139_1 = Date_SMC.index(start_139)
SMC_139_2 = Date_SMC.index(end_139)

# %%
#save the shortened versions of closing prices
D139 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_139_1:AC_139_2])
F139 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_139_1:BPI_139_2])
H139 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_139_1:BLOOM_139_2])
R139 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_139_1:MEG_139_2])
Y139 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_139_1:SMC_139_2])

# %%
# import modules
import numpy as np
# import prices

D139 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F139 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H139 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
R139 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y139 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_139 = []
st_139 = []
n = 1
while n < len(D139):
    sc_139 = ''
    if D139[n] > D139[n-1]:
        sc_139 = sc_139 + 'D'
    if F139[n] > F139[n-1]:
        sc_139 = sc_139 + 'F'
    if H139[n] > H139[n-1]:
        sc_139 = sc_139 + 'H'
    if R139[n] > R139[n-1]:
        sc_139 = sc_139 + 'R'
    if Y139[n] > Y139[n-1]:
        sc_139 = sc_139 + 'Y'
    if len(sc_139) > 0:
        st_139.append(sc_139)
    else:
        STC_139.append(st_139)
        st_139 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_139 = STC_139.count([])
# keep only non-empty spatio-temporal sequences
STC_139 = [ st_139 for st_139 in STC_139 if len(st_139) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_139 = len(D139)
lmax_139 = 0
for st_139 in STC_139:
    if len(st_139) < lmin_139:
        lmin_139 = len(st_139)
    if len(st_139) > lmax_139:
        lmax_139 = len(st_139)
        
# restrMEG spatio-temporal sequences to length-5
STC5_139 = [ st_139 for st_139 in STC_139 if len(st_139) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_139 = []
for n in range(len(STC5_139)):
    tc_139 = [ u for u in STC5_139[n][0] ]
    for k in range(1, len(STC5_139[n])):
        tc_139 = [ u+v for u in tc_139 for v in STC5_139[n][k] ]
    TC5_139 = TC5_139 + tc_139
setTC5_139 = list(set(TC5_139))

# get empirical frequencies
fTC5_139 = [ TC5_139.count(setTC5_139[l]) for l in range(len(setTC5_139)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_139 = [ [] for l in range(len(setTC5_139)) ]
for s in range(100):
    STC5null_139 = [ list(st_139) for st_139 in STC5_139]
    for st_139 in STC5null_139:
        np.random.shuffle(st_139)
    TC5null_139= []
    for n in range(len(STC5null_139)):
        tc_139 = [ u for u in STC5null_139[n][0] ]
        for k in range(1, len(STC5null_139[n])):
            tc_139 = [ u+v for u in tc_139 for v in STC5null_139[n][k] ]
        TC5null_139= TC5null_139+ tc_139
    for l in range(len(setTC5_139)):
        if TC5null_139.count(setTC5_139[l]) > 0:
            fTC5null_139[l].append(TC5null_139.count(setTC5_139[l]))
        else:
            fTC5null_139[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_139)):
     if sum(freq >= fTC5_139[l] for freq in fTC5null_139[l]) < 5:
#         print(setTC5_139[l], fTC5_139[l], sum(freq >= fTC5_139[l] for freq in fTC5null_139[l]))
        print(setTC5_139[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# YDDFF
# FYDRR
# YYFYY
# YRDYD
# FDDF
# HHRRD
# DRFYR
# HFRF
# FDD
# YRYRF
# YDYDF
# YRYFF
# YFFRH
# DFFFR
# DYRRH
# HFFDD
# HFFRF
# RYRRH
# FYDRH
# YDDR
# DYHRH
# FRF
# YFDRY
# DRDYR
# YYDRR
# HFRY
# HFDHH
# HYF
# RHDDH
# HHFRF
# YFDDD
# YHHRF
# FDDRH
# DRRRH
# YFFDD
# YRDYR
# FHHD
# YFDFF
# DDDH
# YRYDF
# FYRRR
# YRDRF
# YFYRF
# HHFRY
# DFFFD
# YRYD
# DDDDH
# FRD
# YRDDF
# YHDDD
# YFFDY
# HHFRD
# YDDDY
# YDDDF
# YRDRY
# DRFFR
# YRFYY
# RRF
# RRRRH
# YFDRD
# RFFDD
# YRFFR
# FRDRH
# DDRRH
# YRFFF
# YRDFY
# YRDFF
# RHFDD
# DDRDH
# DDRH
# FDDD
# YFFYD
# YRDRR
# YYFYD
# YYRRF
# RHFFY
# DYRRR
# YRFRF
# YFDDY
# HHRRF
# HFFRD
# YFFFY
# DDDYH
# HHFDD
# DYDRH
# YDDRY
# FYFRH
# DYFRH
# YFYFF
# YRFYD
# YYDYY
# YHYRF
# RDDDF
# YDDFY
# HHYRF
# YDYRF
# YDYFF
# YDDRF
# RFFFD
# YFRDH
# HHRY
# YRDDY
# YDRH
# DRFRR
# YHFFF
# FRDHH
# FYRRH
# YRDYY
# HFFHD
# YFFRY
# HRF
# YRFRR
# RYFRH
# YDRR
# HDYFD
# YHYFF
# YRDFR
# HFDRD

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_139)):
     if sum(freq >= fTC5_139[l] for freq in fTC5null_139[l]) < 1:
#         print(setTC5_139[l], fTC5_139[l], sum(freq >= fTC5_139[l] for freq in fTC5null_139[l]))
        print(setTC5_139[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# FYDRH
# FDDRH
# YFFDD
# FHHD
# YRYDF
# FYRRR
# YRDRF
# YDDDY
# YDDDF
# YRDRY
# YRFYY
# RFFDD
# YRDFY
# YRDFF
# YFDDY
# DYFRH
# YDYRF
# RFFFD
# FYRRH
# RYFRH
# YRDFR

# %% [markdown]
# # 3.140 (D) AC - (F) BPI - (H) BLOOM - (R) MEG - (α) SMC

# %%
#extract overlapping dates
start_140 = max(min(Date_AC), min(Date_BPI), min(Date_BLOOM), min(Date_MEG), min(Date_SCC))
end_140 = min(max(Date_AC), max(Date_BPI), max(Date_BLOOM), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
AC_140_1 = Date_AC.index(start_140)
AC_140_2 = Date_AC.index(end_140)

BPI_140_1 = Date_BPI.index(start_140)
BPI_140_2 = Date_BPI.index(end_140)

BLOOM_140_1 = Date_BLOOM.index(start_140)
BLOOM_140_2 = Date_BLOOM.index(end_140)

MEG_140_1 = Date_MEG.index(start_140)
MEG_140_2 = Date_MEG.index(end_140)

SCC_140_1 = Date_SCC.index(start_140)
SCC_140_2 = Date_SCC.index(end_140)

# %%
#save the shortened versions of closing prices
D140 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_140_1:AC_140_2])
F140 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_140_1:BPI_140_2])
H140 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_140_1:BLOOM_140_2])
R140 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_140_1:MEG_140_2])
α140 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_140_1:SCC_140_2])

# %%
# import modules
import numpy as np
# import prices

D140 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F140 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H140 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
R140 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α140 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_140 = []
st_140 = []
n = 1
while n < len(D140):
    sc_140 = ''
    if D140[n] > D140[n-1]:
        sc_140 = sc_140 + 'D'
    if F140[n] > F140[n-1]:
        sc_140 = sc_140 + 'F'
    if H140[n] > H140[n-1]:
        sc_140 = sc_140 + 'H'
    if R140[n] > R140[n-1]:
        sc_140 = sc_140 + 'R'
    if α140[n] > α140[n-1]:
        sc_140 = sc_140 + 'α'
    if len(sc_140) > 0:
        st_140.append(sc_140)
    else:
        STC_140.append(st_140)
        st_140 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_140 = STC_140.count([])
# keep only non-empty spatio-temporal sequences
STC_140 = [ st_140 for st_140 in STC_140 if len(st_140) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_140 = len(D140)
lmax_140 = 0
for st_140 in STC_140:
    if len(st_140) < lmin_140:
        lmin_140 = len(st_140)
    if len(st_140) > lmax_140:
        lmax_140 = len(st_140)
        
# restrMEG spatio-temporal sequences to length-5
STC5_140 = [ st_140 for st_140 in STC_140 if len(st_140) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_140 = []
for n in range(len(STC5_140)):
    tc_140 = [ u for u in STC5_140[n][0] ]
    for k in range(1, len(STC5_140[n])):
        tc_140 = [ u+v for u in tc_140 for v in STC5_140[n][k] ]
    TC5_140 = TC5_140 + tc_140
setTC5_140 = list(set(TC5_140))

# get empirical frequencies
fTC5_140 = [ TC5_140.count(setTC5_140[l]) for l in range(len(setTC5_140)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_140 = [ [] for l in range(len(setTC5_140)) ]
for s in range(100):
    STC5null_140 = [ list(st_140) for st_140 in STC5_140]
    for st_140 in STC5null_140:
        np.random.shuffle(st_140)
    TC5null_140= []
    for n in range(len(STC5null_140)):
        tc_140 = [ u for u in STC5null_140[n][0] ]
        for k in range(1, len(STC5null_140[n])):
            tc_140 = [ u+v for u in tc_140 for v in STC5null_140[n][k] ]
        TC5null_140= TC5null_140+ tc_140
    for l in range(len(setTC5_140)):
        if TC5null_140.count(setTC5_140[l]) > 0:
            fTC5null_140[l].append(TC5null_140.count(setTC5_140[l]))
        else:
            fTC5null_140[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_140)):
     if sum(freq >= fTC5_140[l] for freq in fTC5null_140[l]) < 5:
#         print(setTC5_140[l], fTC5_140[l], sum(freq >= fTC5_140[l] for freq in fTC5null_140[l]))
        print(setTC5_140[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# HαDRH
# RRHFα
# FDDF
# HHRRD
# FRαRD
# RDHαα
# HHααα
# HFFDF
# HHααD
# HHHFF
# HFFRF
# HRHFα
# RHFRD
# RRDRH
# HHHFD
# HHFRα
# HRFRH
# FDFF
# HDFRF
# FRF
# RRαRD
# RRαDH
# RRD
# HααFF
# RRααD
# HHFRF
# HRDRα
# DDαR
# FDDRH
# HFFαF
# FHHD
# DRRRR
# HRαRH
# HHHFH
# HαHFα
# HαHFH
# FDαRH
# DDαRD
# αRRRR
# DDαRH
# HαDFH
# FRD
# RRFRH
# RRαRH
# FDααα
# RDαRD
# RααRD
# RDαR
# DRαRD
# DHFRF
# RαFRD
# HααFH
# HαHFD
# DRαRH
# HααRH
# HHFRD
# αDDF
# HαHFF
# RRF
# DHFRD
# HRFRα
# DDFRD
# αRαα
# FRDRH
# DDRRH
# DDFRH
# HRHFD
# HHHFα
# FDααD
# RDDF
# Rαα
# FDα
# FRαRH
# DDRH
# DDRR
# FDDαD
# DHRRF
# RDααD
# HαFRF
# FDαR
# DHRRα
# HHRRF
# HαFD
# RRαDα
# HαDFD
# FRααD
# HHαRF
# RDααα
# HHDαα
# RDαFH
# HRDHH
# HRDRH
# DHDRF
# HαF
# DHRRD
# HRHFH
# HRααH
# αHFRF
# FRDHH
# HRF
# αDDRH
# HαFFF
# FHDα
# HαDRD
# RFαDH
# HRFRF

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_140)):
     if sum(freq >= fTC5_140[l] for freq in fTC5null_140[l]) < 1:
#         print(setTC5_140[l], fTC5_140[l], sum(freq >= fTC5_140[l] for freq in fTC5null_140[l]))
        print(setTC5_140[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# HHααα
# HHHFF
# HRFRH
# FRF
# HHFRF
# HαDFH
# FRD
# RRFRH
# RRαRH
# HαHFD
# HαHFF
# FDα
# HHRRF
# HRDRH
# HαF

# %% [markdown]
# # 3.141 (D) AC - (F) BPI - (H) BLOOM - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_141 = max(min(Date_AC), min(Date_BPI), min(Date_BLOOM), min(Date_SMC), min(Date_SCC))
end_141 = min(max(Date_AC), max(Date_BPI), max(Date_BLOOM), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
AC_141_1 = Date_AC.index(start_141)
AC_141_2 = Date_AC.index(end_141)

BPI_141_1 = Date_BPI.index(start_141)
BPI_141_2 = Date_BPI.index(end_141)

BLOOM_141_1 = Date_BLOOM.index(start_141)
BLOOM_141_2 = Date_BLOOM.index(end_141)

SMC_141_1 = Date_SMC.index(start_141)
SMC_141_2 = Date_SMC.index(end_141)

SCC_141_1 = Date_SCC.index(start_141)
SCC_141_2 = Date_SCC.index(end_141)

# %%
#save the shortened versions of closing prices
D141 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_141_1:AC_141_2])
F141 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_141_1:BPI_141_2])
H141 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_141_1:BLOOM_141_2])
Y141 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_141_1:SMC_141_2])
α141 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_141_1:SCC_141_2])

# %%
# import modules
import numpy as np
# import prices

D141 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F141 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
H141 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
Y141 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α141 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_141 = []
st_141 = []
n = 1
while n < len(D141):
    sc_141 = ''
    if D141[n] > D141[n-1]:
        sc_141 = sc_141 + 'D'
    if F141[n] > F141[n-1]:
        sc_141 = sc_141 + 'F'
    if H141[n] > H141[n-1]:
        sc_141 = sc_141 + 'H'
    if Y141[n] > Y141[n-1]:
        sc_141 = sc_141 + 'R'
    if α141[n] > α141[n-1]:
        sc_141 = sc_141 + 'α'
    if len(sc_141) > 0:
        st_141.append(sc_141)
    else:
        STC_141.append(st_141)
        st_141 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_141 = STC_141.count([])
# keep only non-empty spatio-temporal sequences
STC_141 = [ st_141 for st_141 in STC_141 if len(st_141) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_141 = len(D141)
lmax_141 = 0
for st_141 in STC_141:
    if len(st_141) < lmin_141:
        lmin_141 = len(st_141)
    if len(st_141) > lmax_141:
        lmax_141 = len(st_141)
        
# restrict spatio-temporal sequences to length-5
STC5_141 = [ st_141 for st_141 in STC_141 if len(st_141) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_141 = []
for n in range(len(STC5_141)):
    tc_141 = [ u for u in STC5_141[n][0] ]
    for k in range(1, len(STC5_141[n])):
        tc_141 = [ u+v for u in tc_141 for v in STC5_141[n][k] ]
    TC5_141 = TC5_141 + tc_141
setTC5_141 = list(set(TC5_141))

# get empirical frequencies
fTC5_141 = [ TC5_141.count(setTC5_141[l]) for l in range(len(setTC5_141)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_141 = [ [] for l in range(len(setTC5_141)) ]
for s in range(100):
    STC5null_141 = [ list(st_141) for st_141 in STC5_141]
    for st_141 in STC5null_141:
        np.random.shuffle(st_141)
    TC5null_141= []
    for n in range(len(STC5null_141)):
        tc_141 = [ u for u in STC5null_141[n][0] ]
        for k in range(1, len(STC5null_141[n])):
            tc_141 = [ u+v for u in tc_141 for v in STC5null_141[n][k] ]
        TC5null_141= TC5null_141+ tc_141
    for l in range(len(setTC5_141)):
        if TC5null_141.count(setTC5_141[l]) > 0:
            fTC5null_141[l].append(TC5null_141.count(setTC5_141[l]))
        else:
            fTC5null_141[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_141)):
     if sum(freq >= fTC5_141[l] for freq in fTC5null_141[l]) < 5:
#         print(setTC5_141[l], fTC5_141[l], sum(freq >= fTC5_141[l] for freq in fTC5null_141[l]))
        print(setTC5_141[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FDαHH
# DDRDF
# FαHHR
# HDRFD
# FRDαH
# HRHFα
# RFHFD
# Dαααα
# FRHFα
# FRDαR
# RRααH
# FRαHH
# RRαDH
# FDHFα
# FDαDH
# HDHFF
# DRDHH
# FRααH
# HαHαα
# DDRFF
# HDRHD
# DRDHR
# HαHFα
# HFFHF
# FDRαD
# FDααH
# HαHFD
# HDHFα
# DRHFF
# HαHFF
# DRααH
# FαRFD
# FDDαH
# HRDαD
# FαRFα
# FRFα
# HDHFD
# HHRαF
# HαDHH
# RRDαH
# RRRFα
# HαRFα
# FRDHR
# HDF
# DFFFα
# αRDαR
# HαFD
# DRHFα
# RRαHH
# HRFαD
# HαDFD
# DRαHH
# FFαHR
# HαF
# FRDα
# HαRFD
# FRRR
# FFααα
# αRDHR
# FRDHH
# FαHFα
# FαHFD
# DRRR
# FHDα
# RRFRD

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_141)):
     if sum(freq >= fTC5_141[l] for freq in fTC5null_141[l]) < 1:
#         print(setTC5_141[l], fTC5_141[l], sum(freq >= fTC5_141[l] for freq in fTC5null_141[l]))
        print(setTC5_141[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# DDRFF
# HαHFα
# HαHFD
# HαRFα
# FRDHR
# HαDFD
# αRDHR
# FαHFα
# FαHFD
# DRRR

# %% [markdown]
# # 3.142 (D) AC - (F) BPI - (J) FGEN - (M) ICT - (N) JGS

# %%
#extract overlapping dates
start_142 = max(min(Date_AC), min(Date_BPI), min(Date_FGEN), min(Date_ICT), min(Date_JGS))
end_142 = min(max(Date_AC), max(Date_BPI), max(Date_FGEN), max(Date_ICT), max(Date_JGS))

# %%
#shorten the closing prices
AC_142_1 = Date_AC.index(start_142)
AC_142_2 = Date_AC.index(end_142)

BPI_142_1 = Date_BPI.index(start_142)
BPI_142_2 = Date_BPI.index(end_142)

FGEN_142_1 = Date_FGEN.index(start_142)
FGEN_142_2 = Date_FGEN.index(end_142)

ICT_142_1 = Date_ICT.index(start_142)
ICT_142_2 = Date_ICT.index(end_142)

JGS_142_1 = Date_JGS.index(start_142)
JGS_142_2 = Date_JGS.index(end_142)

# %%
#save the shortened versions of closing prices
D142 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_142_1:AC_142_2])
F142 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_142_1:BPI_142_2])
J142 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_142_1:FGEN_142_2])
M142 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_142_1:ICT_142_2])
N142 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_142_1:JGS_142_2])

# %%
# import modules
import numpy as np
# import prices

D142 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F142 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J142 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M142 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N142 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_142 = []
st_142 = []
n = 1
while n < len(D142):
    sc_142 = ''
    if D142[n] > D142[n-1]:
        sc_142 = sc_142 + 'D'
    if F142[n] > F142[n-1]:
        sc_142 = sc_142 + 'F'
    if J142[n] > J142[n-1]:
        sc_142 = sc_142 + 'J'
    if M142[n] > M142[n-1]:
        sc_142 = sc_142 + 'M'
    if N142[n] > N142[n-1]:
        sc_142 = sc_142 + 'N'
    if len(sc_142) > 0:
        st_142.append(sc_142)
    else:
        STC_142.append(st_142)
        st_142 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[56], line 13
#      11 if J142[n] > J142[n-1]:
#      12     sc_142 = sc_142 + 'J'
# ---> 13 if M142[n] > M142[n-1]:
#      14     sc_142 = sc_142 + 'M'
#      15 if N142[n] > N142[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_142 = STC_142.count([])
# keep only non-empty spatio-temporal sequences
STC_142 = [ st_142 for st_142 in STC_142 if len(st_142) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_142 = len(D142)
lmax_142 = 0
for st_142 in STC_142:
    if len(st_142) < lmin_142:
        lmin_142 = len(st_142)
    if len(st_142) > lmax_142:
        lmax_142 = len(st_142)
        
# restrict spatio-temporal sequences to length-5
STC5_142 = [ st_142 for st_142 in STC_142 if len(st_142) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_142 = []
for n in range(len(STC5_142)):
    tc_142 = [ u for u in STC5_142[n][0] ]
    for k in range(1, len(STC5_142[n])):
        tc_142 = [ u+v for u in tc_142 for v in STC5_142[n][k] ]
    TC5_142 = TC5_142 + tc_142
setTC5_142 = list(set(TC5_142))

# get empirical frequencies
fTC5_142 = [ TC5_142.count(setTC5_142[l]) for l in range(len(setTC5_142)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_142 = [ [] for l in range(len(setTC5_142)) ]
for s in range(100):
    STC5null_142 = [ list(st_142) for st_142 in STC5_142]
    for st_142 in STC5null_142:
        np.random.shuffle(st_142)
    TC5null_142= []
    for n in range(len(STC5null_142)):
        tc_142 = [ u for u in STC5null_142[n][0] ]
        for k in range(1, len(STC5null_142[n])):
            tc_142 = [ u+v for u in tc_142 for v in STC5null_142[n][k] ]
        TC5null_142= TC5null_142+ tc_142
    for l in range(len(setTC5_142)):
        if TC5null_142.count(setTC5_142[l]) > 0:
            fTC5null_142[l].append(TC5null_142.count(setTC5_142[l]))
        else:
            fTC5null_142[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_142)):
     if sum(freq >= fTC5_142[l] for freq in fTC5null_142[l]) < 5:
#         print(setTC5_142[l], fTC5_142[l], sum(freq >= fTC5_142[l] for freq in fTC5null_142[l]))
        print(setTC5_142[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FDMD
# MFJNM
# MFDND
# JFDD
# FFDDD
# FJJJJ
# FNJDN
# MJJJJ
# FFJND
# MJDFD
# FMFFD
# FNJJN
# FFM
# FNNJN
# FJN
# NMDFJ
# FJMM
# NJFM
# JJJN
# FNNDF
# FFDD
# FFJDD
# FDMN
# FFND
# MJJJN
# MDJMM
# MJNN
# MJDJN
# DNNDF
# MMJFM
# FNNDN
# FFDN
# FMFJD
# FNJDD
# MJDJJ
# FFNN
# FFMN
# MJJFD
# FFMD
# FFDJ
# JMMJD
# DNNDN
# NMJFJ
# NMDMJ
# NMFMJ
# MFDNM
# FFFFJ
# FMFDF
# FMFMD

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_142)):
     if sum(freq >= fTC5_142[l] for freq in fTC5null_142[l]) < 1:
#         print(setTC5_142[l], fTC5_142[l], sum(freq >= fTC5_142[l] for freq in fTC5null_142[l]))
        print(setTC5_142[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# NJFM
# FNNDN
# FFMD

# %% [markdown]
# # 3.143 (D) AC - (F) BPI - (J) FGEN - (M) ICT - (R) MEG

# %%
#extract overlapping dates
start_143 = max(min(Date_AC), min(Date_BPI), min(Date_FGEN), min(Date_ICT), min(Date_MEG))
end_143 = min(max(Date_AC), max(Date_BPI), max(Date_FGEN), max(Date_ICT), max(Date_MEG))

# %%
#shorten the closing prices
AC_143_1 = Date_AC.index(start_143)
AC_143_2 = Date_AC.index(end_143)

BPI_143_1 = Date_BPI.index(start_143)
BPI_143_2 = Date_BPI.index(end_143)

FGEN_143_1 = Date_FGEN.index(start_143)
FGEN_143_2 = Date_FGEN.index(end_143)

ICT_143_1 = Date_ICT.index(start_143)
ICT_143_2 = Date_ICT.index(end_143)

MEG_143_1 = Date_MEG.index(start_143)
MEG_143_2 = Date_MEG.index(end_143)

# %%
#save the shortened versions of closing prices
D143 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_143_1:AC_143_2])
F143 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_143_1:BPI_143_2])
J143 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_143_1:FGEN_143_2])
M143 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_143_1:ICT_143_2])
R143 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_143_1:MEG_143_2])

# %%
# import modules
import numpy as np
# import prices

D143 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F143 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J143 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M143 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R143 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_143 = []
st_143 = []
n = 1
while n < len(D143):
    sc_143 = ''
    if D143[n] > D143[n-1]:
        sc_143 = sc_143 + 'D'
    if F143[n] > F143[n-1]:
        sc_143 = sc_143 + 'F'
    if J143[n] > J143[n-1]:
        sc_143 = sc_143 + 'J'
    if M143[n] > M143[n-1]:
        sc_143 = sc_143 + 'M'
    if R143[n] > R143[n-1]:
        sc_143 = sc_143 + 'R'
    if len(sc_143) > 0:
        st_143.append(sc_143)
    else:
        STC_143.append(st_143)
        st_143 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[61], line 13
#      11 if J143[n] > J143[n-1]:
#      12     sc_143 = sc_143 + 'J'
# ---> 13 if M143[n] > M143[n-1]:
#      14     sc_143 = sc_143 + 'M'
#      15 if R143[n] > R143[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_143 = STC_143.count([])
# keep only non-empty spatio-temporal sequences
STC_143 = [ st_143 for st_143 in STC_143 if len(st_143) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_143 = len(D143)
lmax_143 = 0
for st_143 in STC_143:
    if len(st_143) < lmin_143:
        lmin_143 = len(st_143)
    if len(st_143) > lmax_143:
        lmax_143 = len(st_143)
        
# restrict spatio-temporal sequences to length-5
STC5_143 = [ st_143 for st_143 in STC_143 if len(st_143) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_143 = []
for n in range(len(STC5_143)):
    tc_143 = [ u for u in STC5_143[n][0] ]
    for k in range(1, len(STC5_143[n])):
        tc_143 = [ u+v for u in tc_143 for v in STC5_143[n][k] ]
    TC5_143 = TC5_143 + tc_143
setTC5_143 = list(set(TC5_143))

# get empirical frequencies
fTC5_143 = [ TC5_143.count(setTC5_143[l]) for l in range(len(setTC5_143)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_143 = [ [] for l in range(len(setTC5_143)) ]
for s in range(100):
    STC5null_143 = [ list(st_143) for st_143 in STC5_143]
    for st_143 in STC5null_143:
        np.random.shuffle(st_143)
    TC5null_143= []
    for n in range(len(STC5null_143)):
        tc_143 = [ u for u in STC5null_143[n][0] ]
        for k in range(1, len(STC5null_143[n])):
            tc_143 = [ u+v for u in tc_143 for v in STC5null_143[n][k] ]
        TC5null_143= TC5null_143+ tc_143
    for l in range(len(setTC5_143)):
        if TC5null_143.count(setTC5_143[l]) > 0:
            fTC5null_143[l].append(TC5null_143.count(setTC5_143[l]))
        else:
            fTC5null_143[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_143)):
     if sum(freq >= fTC5_143[l] for freq in fTC5null_143[l]) < 5:
#         print(setTC5_143[l], fTC5_143[l], sum(freq >= fTC5_143[l] for freq in fTC5null_143[l]))
        print(setTC5_143[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# RJDFF
# RMDRF
# DRRD
# RMDDF
# RJJFM
# RJDFR
# DJFM
# JFDD
# DJJFD
# RJJMD
# MJDFD
# JFRD
# FFJFD
# RMJDF
# RJFFD
# DFJFD
# MD
# RMFRM
# MJMFM
# RJMM
# RMFRF
# DMFRF
# RFDFD
# MJFFD
# FJJFM
# RJJRD
# RJDFJ
# MJJM
# RMFDF
# FFMF
# FMMM
# DJMFM
# DRMR
# DJDFM
# RFFDD
# FMFRF
# RJJFD
# RJDJR
# JFFD
# RMF
# DJMM
# FD
# RFFRD
# MJFRD
# DJDFJ
# FFRD
# MJDRD
# FFRF
# MJJFD
# FFMD
# RJDFM
# FJJFD
# RMJRF
# MJDFM
# DJMR
# JJJMD
# RJDFD
# RFFFD
# RMFRD
# MJJR
# RFDFJ
# RJDJF
# RMRJF
# DJDFD
# RMRRF
# RRFRD

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_143)):
     if sum(freq >= fTC5_143[l] for freq in fTC5null_143[l]) < 1:
#         print(setTC5_143[l], fTC5_143[l], sum(freq >= fTC5_143[l] for freq in fTC5null_143[l]))
        print(setTC5_143[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# RMDRF
# MD
# RMFRF
# FFMF
# FFRD
# RMFRD
# RJDJF

# %% [markdown]
# # 3.144 (D) AC - (F) BPI - (J) FGEN - (M) ICT - (Y) SMC

# %%
#extract overlapping dates
start_144 = max(min(Date_AC), min(Date_BPI), min(Date_FGEN), min(Date_ICT), min(Date_SMC))
end_144 = min(max(Date_AC), max(Date_BPI), max(Date_FGEN), max(Date_ICT), max(Date_SMC))

# %%
#shorten the closing prices
AC_144_1 = Date_AC.index(start_144)
AC_144_2 = Date_AC.index(end_144)

BPI_144_1 = Date_BPI.index(start_144)
BPI_144_2 = Date_BPI.index(end_144)

FGEN_144_1 = Date_FGEN.index(start_144)
FGEN_144_2 = Date_FGEN.index(end_144)

ICT_144_1 = Date_ICT.index(start_144)
ICT_144_2 = Date_ICT.index(end_144)

SMC_144_1 = Date_SMC.index(start_144)
SMC_144_2 = Date_SMC.index(end_144)

# %%
#save the shortened versions of closing prices
D144 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_144_1:AC_144_2])
F144 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_144_1:BPI_144_2])
J144 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_144_1:FGEN_144_2])
M144 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_144_1:ICT_144_2])
Y144 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_144_1:SMC_144_2])

# %%
# import modules
import numpy as np
# import prices

D144 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F144 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J144 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M144 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
Y144 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_144 = []
st_144 = []
n = 1
while n < len(D144):
    sc_144 = ''
    if D144[n] > D144[n-1]:
        sc_144 = sc_144 + 'D'
    if F144[n] > F144[n-1]:
        sc_144 = sc_144 + 'F'
    if J144[n] > J144[n-1]:
        sc_144 = sc_144 + 'J'
    if M144[n] > M144[n-1]:
        sc_144 = sc_144 + 'M'
    if Y144[n] > Y144[n-1]:
        sc_144 = sc_144 + 'Y'
    if len(sc_144) > 0:
        st_144.append(sc_144)
    else:
        STC_144.append(st_144)
        st_144 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[69], line 13
#      11 if J144[n] > J144[n-1]:
#      12     sc_144 = sc_144 + 'J'
# ---> 13 if M144[n] > M144[n-1]:
#      14     sc_144 = sc_144 + 'M'
#      15 if Y144[n] > Y144[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_144 = STC_144.count([])
# keep only non-empty spatio-temporal sequences
STC_144 = [ st_144 for st_144 in STC_144 if len(st_144) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_144 = len(D144)
lmax_144 = 0
for st_144 in STC_144:
    if len(st_144) < lmin_144:
        lmin_144 = len(st_144)
    if len(st_144) > lmax_144:
        lmax_144 = len(st_144)
        
# restrict spatio-temporal sequences to length-5
STC5_144 = [ st_144 for st_144 in STC_144 if len(st_144) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_144 = []
for n in range(len(STC5_144)):
    tc_144 = [ u for u in STC5_144[n][0] ]
    for k in range(1, len(STC5_144[n])):
        tc_144 = [ u+v for u in tc_144 for v in STC5_144[n][k] ]
    TC5_144 = TC5_144 + tc_144
setTC5_144 = list(set(TC5_144))

# get empirical frequencies
fTC5_144 = [ TC5_144.count(setTC5_144[l]) for l in range(len(setTC5_144)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_144 = [ [] for l in range(len(setTC5_144)) ]
for s in range(100):
    STC5null_144 = [ list(st_144) for st_144 in STC5_144]
    for st_144 in STC5null_144:
        np.random.shuffle(st_144)
    TC5null_144= []
    for n in range(len(STC5null_144)):
        tc_144 = [ u for u in STC5null_144[n][0] ]
        for k in range(1, len(STC5null_144[n])):
            tc_144 = [ u+v for u in tc_144 for v in STC5null_144[n][k] ]
        TC5null_144= TC5null_144+ tc_144
    for l in range(len(setTC5_144)):
        if TC5null_144.count(setTC5_144[l]) > 0:
            fTC5null_144[l].append(TC5null_144.count(setTC5_144[l]))
        else:
            fTC5null_144[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_144)):
     if sum(freq >= fTC5_144[l] for freq in fTC5null_144[l]) < 5:
#         print(setTC5_144[l], fTC5_144[l], sum(freq >= fTC5_144[l] for freq in fTC5null_144[l]))
        print(setTC5_144[l])

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_144)):
     if sum(freq >= fTC5_144[l] for freq in fTC5null_144[l]) < 1:
#         print(setTC5_144[l], fTC5_144[l], sum(freq >= fTC5_144[l] for freq in fTC5null_144[l]))
        print(setTC5_144[l])

# %% [markdown]
# # 3.145 (D) AC - (F) BPI - (J) FGEN - (M) ICT - (α) SCC

# %%
#extract overlapping dates
start_145 = max(min(Date_AC), min(Date_BPI), min(Date_FGEN), min(Date_ICT), min(Date_SCC))
end_145 = min(max(Date_AC), max(Date_BPI), max(Date_FGEN), max(Date_ICT), max(Date_SCC))

# %%
#shorten the closing prices
AC_145_1 = Date_AC.index(start_145)
AC_145_2 = Date_AC.index(end_145)

BPI_145_1 = Date_BPI.index(start_145)
BPI_145_2 = Date_BPI.index(end_145)

FGEN_145_1 = Date_FGEN.index(start_145)
FGEN_145_2 = Date_FGEN.index(end_145)

ICT_145_1 = Date_ICT.index(start_145)
ICT_145_2 = Date_ICT.index(end_145)

SCC_145_1 = Date_SCC.index(start_145)
SCC_145_2 = Date_SCC.index(end_145)

# %%
#save the shortened versions of closing prices
D145 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_145_1:AC_145_2])
F145 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_145_1:BPI_145_2])
J145 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_145_1:FGEN_145_2])
M145 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_145_1:ICT_145_2])
α145 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_145_1:SCC_145_2])

# %%
# import modules
import numpy as np
# import prices

D145 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F145 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J145 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M145 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
α145 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_145 = []
st_145 = []
n = 1
while n < len(D145):
    sc_145 = ''
    if D145[n] > D145[n-1]:
        sc_145 = sc_145 + 'D'
    if F145[n] > F145[n-1]:
        sc_145 = sc_145 + 'F'
    if J145[n] > J145[n-1]:
        sc_145 = sc_145 + 'J'
    if M145[n] > M145[n-1]:
        sc_145 = sc_145 + 'M'
    if α145[n] > α145[n-1]:
        sc_145 = sc_145 + 'α'
    if len(sc_145) > 0:
        st_145.append(sc_145)
    else:
        STC_145.append(st_145)
        st_145 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[74], line 13
#      11 if J145[n] > J145[n-1]:
#      12     sc_145 = sc_145 + 'J'
# ---> 13 if M145[n] > M145[n-1]:
#      14     sc_145 = sc_145 + 'M'
#      15 if α145[n] > α145[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_145 = STC_145.count([])
# keep only non-empty spatio-temporal sequences
STC_145 = [ st_145 for st_145 in STC_145 if len(st_145) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_145 = len(D145)
lmax_145 = 0
for st_145 in STC_145:
    if len(st_145) < lmin_145:
        lmin_145 = len(st_145)
    if len(st_145) > lmax_145:
        lmax_145 = len(st_145)
        
# restrict spatio-temporal sequences to length-5
STC5_145 = [ st_145 for st_145 in STC_145 if len(st_145) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_145 = []
for n in range(len(STC5_145)):
    tc_145 = [ u for u in STC5_145[n][0] ]
    for k in range(1, len(STC5_145[n])):
        tc_145 = [ u+v for u in tc_145 for v in STC5_145[n][k] ]
    TC5_145 = TC5_145 + tc_145
setTC5_145 = list(set(TC5_145))

# get empirical frequencies
fTC5_145 = [ TC5_145.count(setTC5_145[l]) for l in range(len(setTC5_145)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_145 = [ [] for l in range(len(setTC5_145)) ]
for s in range(100):
    STC5null_145 = [ list(st_145) for st_145 in STC5_145]
    for st_145 in STC5null_145:
        np.random.shuffle(st_145)
    TC5null_145= []
    for n in range(len(STC5null_145)):
        tc_145 = [ u for u in STC5null_145[n][0] ]
        for k in range(1, len(STC5null_145[n])):
            tc_145 = [ u+v for u in tc_145 for v in STC5null_145[n][k] ]
        TC5null_145= TC5null_145+ tc_145
    for l in range(len(setTC5_145)):
        if TC5null_145.count(setTC5_145[l]) > 0:
            fTC5null_145[l].append(TC5null_145.count(setTC5_145[l]))
        else:
            fTC5null_145[l].append(0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[75], line 45
#      43 for l in range(len(setTC5_145)):
#      44     if TC5null_145.count(setTC5_145[l]) > 0:
# ---> 45         fTC5null_145[l].append(TC5null_145.count(setTC5_145[l]))
#      46     else:
#      47         fTC5null_145[l].append(0)
#
# KeyboardInterrupt:

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_145)):
     if sum(freq >= fTC5_145[l] for freq in fTC5null_145[l]) < 5:
#         print(setTC5_145[l], fTC5_145[l], sum(freq >= fTC5_145[l] for freq in fTC5null_145[l]))
        print(setTC5_145[l])

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_145)):
     if sum(freq >= fTC5_145[l] for freq in fTC5null_145[l]) < 1:
#         print(setTC5_145[l], fTC5_145[l], sum(freq >= fTC5_145[l] for freq in fTC5null_145[l]))
        print(setTC5_145[l])

# %% [markdown]
# # 3.146 (D) AC - (F) BPI - (J) FGEN - (N) JGS - (R) MEG

# %%
#extract overlapping dates
start_146 = max(min(Date_AC), min(Date_BPI), min(Date_FGEN), min(Date_JGS), min(Date_MEG))
end_146 = min(max(Date_AC), max(Date_BPI), max(Date_FGEN), max(Date_JGS), max(Date_MEG))

# %%
#shorten the closing prices
AC_146_1 = Date_AC.index(start_146)
AC_146_2 = Date_AC.index(end_146)

BPI_146_1 = Date_BPI.index(start_146)
BPI_146_2 = Date_BPI.index(end_146)

FGEN_146_1 = Date_FGEN.index(start_146)
FGEN_146_2 = Date_FGEN.index(end_146)

JGS_146_1 = Date_JGS.index(start_146)
JGS_146_2 = Date_JGS.index(end_146)

MEG_146_1 = Date_MEG.index(start_146)
MEG_146_2 = Date_MEG.index(end_146)

# %%
#save the shortened versions of closing prices
D146 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_146_1:AC_146_2])
F146 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_146_1:BPI_146_2])
J146 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_146_1:FGEN_146_2])
N146 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_146_1:JGS_146_2])
R146 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_146_1:MEG_146_2])

# %%
# import modules
import numpy as np
# import prices

D146 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F146 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J146 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N146 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R146 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_146 = []
st_146 = []
n = 1
while n < len(D146):
    sc_146 = ''
    if D146[n] > D146[n-1]:
        sc_146 = sc_146 + 'D'
    if F146[n] > F146[n-1]:
        sc_146 = sc_146 + 'F'
    if J146[n] > J146[n-1]:
        sc_146 = sc_146 + 'J'
    if N146[n] > N146[n-1]:
        sc_146 = sc_146 + 'N'
    if R146[n] > R146[n-1]:
        sc_146 = sc_146 + 'R'
    if len(sc_146) > 0:
        st_146.append(sc_146)
    else:
        STC_146.append(st_146)
        st_146 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_146 = STC_146.count([])
# keep only non-empty spatio-temporal sequences
STC_146 = [ st_146 for st_146 in STC_146 if len(st_146) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_146 = len(D146)
lmax_146 = 0
for st_146 in STC_146:
    if len(st_146) < lmin_146:
        lmin_146 = len(st_146)
    if len(st_146) > lmax_146:
        lmax_146 = len(st_146)
        
# restrJGS spatio-temporal sequences to length-5
STC5_146 = [ st_146 for st_146 in STC_146 if len(st_146) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_146 = []
for n in range(len(STC5_146)):
    tc_146 = [ u for u in STC5_146[n][0] ]
    for k in range(1, len(STC5_146[n])):
        tc_146 = [ u+v for u in tc_146 for v in STC5_146[n][k] ]
    TC5_146 = TC5_146 + tc_146
setTC5_146 = list(set(TC5_146))

# get empirical frequencies
fTC5_146 = [ TC5_146.count(setTC5_146[l]) for l in range(len(setTC5_146)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_146 = [ [] for l in range(len(setTC5_146)) ]
for s in range(100):
    STC5null_146 = [ list(st_146) for st_146 in STC5_146]
    for st_146 in STC5null_146:
        np.random.shuffle(st_146)
    TC5null_146= []
    for n in range(len(STC5null_146)):
        tc_146 = [ u for u in STC5null_146[n][0] ]
        for k in range(1, len(STC5null_146[n])):
            tc_146 = [ u+v for u in tc_146 for v in STC5null_146[n][k] ]
        TC5null_146= TC5null_146+ tc_146
    for l in range(len(setTC5_146)):
        if TC5null_146.count(setTC5_146[l]) > 0:
            fTC5null_146[l].append(TC5null_146.count(setTC5_146[l]))
        else:
            fTC5null_146[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_146)):
     if sum(freq >= fTC5_146[l] for freq in fTC5null_146[l]) < 5:
#         print(setTC5_146[l], fTC5_146[l], sum(freq >= fTC5_146[l] for freq in fTC5null_146[l]))
        print(setTC5_146[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FFDDD
# DJJFD
# NFNRN
# NDNJN
# FJRJN
# DDDFR
# FRF
# DJF
# FNDDN
# NNFJ
# FFDNR
# FRN
# FJRDN
# DJJDJ
# DJJFJ
# DJRJJ
# FNFRN
# NFNJN
# FFRJN
# RJJFR
# DDRRR
# RJJFF
# RJJFJ
# DJJRR
# RJJRF
# RRF
# DJJDR
# RRFJ
# NRFJ
# FJ
# RJRJN
# DRF
# NRFN
# JDFJ
# FD
# JNFJ
# FFDJN
# RJDJN
# DJJFF
# FNFDN
# FJDJN
# FFDDN
# NFFJ
# DRN
# RRN
# DJJFR
# NFNRJ
# DJRDR
# NDNRN
# DNFJ
# FJDDN

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_146)):
     if sum(freq >= fTC5_146[l] for freq in fTC5null_146[l]) < 1:
#         print(setTC5_146[l], fTC5_146[l], sum(freq >= fTC5_146[l] for freq in fTC5null_146[l]))
        print(setTC5_146[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# NFNRN
# FJRJN
# DJJDJ
# DJJFJ
# RJJFF
# FFDDN
# DRN

# %% [markdown]
# # 3.147 (D) AC - (F) BPI - (J) FGEN - (N) JGS - (Y) SMC

# %%
#extract overlapping dates
start_147 = max(min(Date_AC), min(Date_BPI), min(Date_FGEN), min(Date_JGS), min(Date_SMC))
end_147 = min(max(Date_AC), max(Date_BPI), max(Date_FGEN), max(Date_JGS), max(Date_SMC))

# %%
#shorten the closing prices
AC_147_1 = Date_AC.index(start_147)
AC_147_2 = Date_AC.index(end_147)

BPI_147_1 = Date_BPI.index(start_147)
BPI_147_2 = Date_BPI.index(end_147)

FGEN_147_1 = Date_FGEN.index(start_147)
FGEN_147_2 = Date_FGEN.index(end_147)

JGS_147_1 = Date_JGS.index(start_147)
JGS_147_2 = Date_JGS.index(end_147)

SMC_147_1 = Date_SMC.index(start_147)
SMC_147_2 = Date_SMC.index(end_147)

# %%
#save the shortened versions of closing prices
D147 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_147_1:AC_147_2])
F147 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_147_1:BPI_147_2])
J147 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_147_1:FGEN_147_2])
N147 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_147_1:JGS_147_2])
Y147 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_147_1:SMC_147_2])

# %%
# import modules
import numpy as np
# import prices

D147 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F147 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J147 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N147 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y147 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_147 = []
st_147 = []
n = 1
while n < len(D147):
    sc_147 = ''
    if D147[n] > D147[n-1]:
        sc_147 = sc_147 + 'D'
    if F147[n] > F147[n-1]:
        sc_147 = sc_147 + 'F'
    if J147[n] > J147[n-1]:
        sc_147 = sc_147 + 'J'
    if N147[n] > N147[n-1]:
        sc_147 = sc_147 + 'N'
    if Y147[n] > Y147[n-1]:
        sc_147 = sc_147 + 'Y'
    if len(sc_147) > 0:
        st_147.append(sc_147)
    else:
        STC_147.append(st_147)
        st_147 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_147 = STC_147.count([])
# keep only non-empty spatio-temporal sequences
STC_147 = [ st_147 for st_147 in STC_147 if len(st_147) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_147 = len(D147)
lmax_147 = 0
for st_147 in STC_147:
    if len(st_147) < lmin_147:
        lmin_147 = len(st_147)
    if len(st_147) > lmax_147:
        lmax_147 = len(st_147)
        
# restrJGS spatio-temporal sequences to length-5
STC5_147 = [ st_147 for st_147 in STC_147 if len(st_147) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_147 = []
for n in range(len(STC5_147)):
    tc_147 = [ u for u in STC5_147[n][0] ]
    for k in range(1, len(STC5_147[n])):
        tc_147 = [ u+v for u in tc_147 for v in STC5_147[n][k] ]
    TC5_147 = TC5_147 + tc_147
setTC5_147 = list(set(TC5_147))

# get empirical frequencies
fTC5_147 = [ TC5_147.count(setTC5_147[l]) for l in range(len(setTC5_147)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_147 = [ [] for l in range(len(setTC5_147)) ]
for s in range(100):
    STC5null_147 = [ list(st_147) for st_147 in STC5_147]
    for st_147 in STC5null_147:
        np.random.shuffle(st_147)
    TC5null_147= []
    for n in range(len(STC5null_147)):
        tc_147 = [ u for u in STC5null_147[n][0] ]
        for k in range(1, len(STC5null_147[n])):
            tc_147 = [ u+v for u in tc_147 for v in STC5null_147[n][k] ]
        TC5null_147= TC5null_147+ tc_147
    for l in range(len(setTC5_147)):
        if TC5null_147.count(setTC5_147[l]) > 0:
            fTC5null_147[l].append(TC5null_147.count(setTC5_147[l]))
        else:
            fTC5null_147[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_147)):
     if sum(freq >= fTC5_147[l] for freq in fTC5null_147[l]) < 5:
#         print(setTC5_147[l], fTC5_147[l], sum(freq >= fTC5_147[l] for freq in fTC5null_147[l]))
        print(setTC5_147[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# NJDJ
# FYYY
# YYFYY
# YYNJN
# FJYJ
# YFJJF
# FJF
# YYJYD
# DYNJD
# DYFJJ
# NJYN
# JDDJ
# DYNJN
# FYFYD
# FYYJ
# YYYJ
# DYJYD
# DYJJD
# DDDN
# YYDJN
# YYFYN
# DYNYN
# DYYY
# DFFFD
# DYNJJ
# DFJJN
# NNDN
# FJYN
# DYNN
# DYNJF
# YYJJN
# FYNYN
# YYJDF
# DYJJF
# DYJJN
# YYJND
# FJYY
# FNDN
# YNNJN
# DJYY
# FYNN
# NFDYJ
# NYNJJ
# YYFYD
# FD
# FDYY
# NDFYJ
# NYYN
# FYDJ
# YYJFD
# FYFYJ
# YYJFN
# NYFYJ
# NFFJ
# DFJND
# NDDYJ
# DNNDN
# YYJJF
# NYFJJ
# DFJJF
# JFDJ
# FYYN
# YYJDN
# YDJFD
# JYDJ
# DNFJ
# YYJDD
# YFJFD
# YFJYD
# DFFJ
# YFJDD
# DYNNN
# DFNJN
# FYNY
# FYJYD

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_147)):
     if sum(freq >= fTC5_147[l] for freq in fTC5null_147[l]) < 1:
#         print(setTC5_147[l], fTC5_147[l], sum(freq >= fTC5_147[l] for freq in fTC5null_147[l]))
        print(setTC5_147[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# FYYY
# FJYJ
# DYNJN
# FYYJ
# DYYY
# DYNJF
# YYJJN
# YYJND
# FJYY
# NFDYJ
# YYFYD
# YYJDD

# %% [markdown]
# # 3.148 (D) AC - (F) BPI - (J) FGEN - (N) JGS - (α) SCC

# %%
#extract overlapping dates
start_148 = max(min(Date_AC), min(Date_BPI), min(Date_FGEN), min(Date_JGS), min(Date_SCC))
end_148 = min(max(Date_AC), max(Date_BPI), max(Date_FGEN), max(Date_JGS), max(Date_SCC))

# %%
#shorten the closing prices
AC_148_1 = Date_AC.index(start_148)
AC_148_2 = Date_AC.index(end_148)

BPI_148_1 = Date_BPI.index(start_148)
BPI_148_2 = Date_BPI.index(end_148)

FGEN_148_1 = Date_FGEN.index(start_148)
FGEN_148_2 = Date_FGEN.index(end_148)

JGS_148_1 = Date_JGS.index(start_148)
JGS_148_2 = Date_JGS.index(end_148)

SCC_148_1 = Date_SCC.index(start_148)
SCC_148_2 = Date_SCC.index(end_148)

# %%
#save the shortened versions of closing prices
D148 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_148_1:AC_148_2])
F148 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_148_1:BPI_148_2])
J148 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_148_1:FGEN_148_2])
N148 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_148_1:JGS_148_2])
α148 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_148_1:SCC_148_2])

# %%
# import modules
import numpy as np
# import prices

D148 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F148 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J148 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N148 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
α148 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_148 = []
st_148 = []
n = 1
while n < len(D148):
    sc_148 = ''
    if D148[n] > D148[n-1]:
        sc_148 = sc_148 + 'D'
    if F148[n] > F148[n-1]:
        sc_148 = sc_148 + 'F'
    if J148[n] > J148[n-1]:
        sc_148 = sc_148 + 'J'
    if N148[n] > N148[n-1]:
        sc_148 = sc_148 + 'N'
    if α148[n] > α148[n-1]:
        sc_148 = sc_148 + 'α'
    if len(sc_148) > 0:
        st_148.append(sc_148)
    else:
        STC_148.append(st_148)
        st_148 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_148 = STC_148.count([])
# keep only non-empty spatio-temporal sequences
STC_148 = [ st_148 for st_148 in STC_148 if len(st_148) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_148 = len(D148)
lmax_148 = 0
for st_148 in STC_148:
    if len(st_148) < lmin_148:
        lmin_148 = len(st_148)
    if len(st_148) > lmax_148:
        lmax_148 = len(st_148)
        
# restrJGS spatio-temporal sequences to length-5
STC5_148 = [ st_148 for st_148 in STC_148 if len(st_148) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_148 = []
for n in range(len(STC5_148)):
    tc_148 = [ u for u in STC5_148[n][0] ]
    for k in range(1, len(STC5_148[n])):
        tc_148 = [ u+v for u in tc_148 for v in STC5_148[n][k] ]
    TC5_148 = TC5_148 + tc_148
setTC5_148 = list(set(TC5_148))

# get empirical frequencies
fTC5_148 = [ TC5_148.count(setTC5_148[l]) for l in range(len(setTC5_148)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_148 = [ [] for l in range(len(setTC5_148)) ]
for s in range(100):
    STC5null_148 = [ list(st_148) for st_148 in STC5_148]
    for st_148 in STC5null_148:
        np.random.shuffle(st_148)
    TC5null_148= []
    for n in range(len(STC5null_148)):
        tc_148 = [ u for u in STC5null_148[n][0] ]
        for k in range(1, len(STC5null_148[n])):
            tc_148 = [ u+v for u in tc_148 for v in STC5null_148[n][k] ]
        TC5null_148= TC5null_148+ tc_148
    for l in range(len(setTC5_148)):
        if TC5null_148.count(setTC5_148[l]) > 0:
            fTC5null_148[l].append(TC5null_148.count(setTC5_148[l]))
        else:
            fTC5null_148[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_148)):
     if sum(freq >= fTC5_148[l] for freq in fTC5null_148[l]) < 5:
#         print(setTC5_148[l], fTC5_148[l], sum(freq >= fTC5_148[l] for freq in fTC5null_148[l]))
        print(setTC5_148[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FNNDD
# NJJFN
# FNFDD
# FDαF
# FNDDD
# DJJFD
# FNF
# FJDN
# FNFαD
# DJJDF
# DNαDD
# ND
# NJJDF
# DDDN
# αJDFF
# αJJFF
# DJJDJ
# DJJFJ
# NNFJα
# FDDN
# NFNJN
# DJJJJ
# Fα
# αJJFN
# FNNDF
# FαFJD
# NFNα
# NJJJF
# αNJDJ
# αJJDJ
# αJJDF
# FαFDD
# FJ
# JDF
# αNααJ
# NJJFF
# FNNDN
# DJJFα
# FαNJD
# FαFJ
# FNNαD
# αJDDJ
# DJJFN
# αJJNJ
# αNFαJ
# αNDDD
# DJFJα
# αNαDJ
# DJJFF
# αJFFJ
# αJFDJ
# FNJ
# NJFN
# FFααα
# DJJJα
# NNNαD
# FαFαD
# NJFJα
# αJJFJ

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_148)):
     if sum(freq >= fTC5_148[l] for freq in fTC5null_148[l]) < 1:
#         print(setTC5_148[l], fTC5_148[l], sum(freq >= fTC5_148[l] for freq in fTC5null_148[l]))
        print(setTC5_148[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# FαFJD
# αJJDJ
# FαFDD
# FJ
# NJJFF
# DJJFF

# %% [markdown]
# # 3.149 (D) AC - (F) BPI - (J) FGEN - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_149 = max(min(Date_AC), min(Date_BPI), min(Date_FGEN), min(Date_MEG), min(Date_SMC))
end_149 = min(max(Date_AC), max(Date_BPI), max(Date_FGEN), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
AC_149_1 = Date_AC.index(start_149)
AC_149_2 = Date_AC.index(end_149)

BPI_149_1 = Date_BPI.index(start_149)
BPI_149_2 = Date_BPI.index(end_149)

FGEN_149_1 = Date_FGEN.index(start_149)
FGEN_149_2 = Date_FGEN.index(end_149)

MEG_149_1 = Date_MEG.index(start_149)
MEG_149_2 = Date_MEG.index(end_149)

SMC_149_1 = Date_SMC.index(start_149)
SMC_149_2 = Date_SMC.index(end_149)

# %%
#save the shortened versions of closing prices
D149 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_149_1:AC_149_2])
F149 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_149_1:BPI_149_2])
J149 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_149_1:FGEN_149_2])
R149 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_149_1:MEG_149_2])
Y149 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_149_1:SMC_149_2])

# %%
# import modules
import numpy as np
# import prices

D149 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F149 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J149 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
R149 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y149 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_149 = []
st_149 = []
n = 1
while n < len(D149):
    sc_149 = ''
    if D149[n] > D149[n-1]:
        sc_149 = sc_149 + 'D'
    if F149[n] > F149[n-1]:
        sc_149 = sc_149 + 'F'
    if J149[n] > J149[n-1]:
        sc_149 = sc_149 + 'J'
    if R149[n] > R149[n-1]:
        sc_149 = sc_149 + 'R'
    if Y149[n] > Y149[n-1]:
        sc_149 = sc_149 + 'Y'
    if len(sc_149) > 0:
        st_149.append(sc_149)
    else:
        STC_149.append(st_149)
        st_149 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_149 = STC_149.count([])
# keep only non-empty spatio-temporal sequences
STC_149 = [ st_149 for st_149 in STC_149 if len(st_149) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_149 = len(D149)
lmax_149 = 0
for st_149 in STC_149:
    if len(st_149) < lmin_149:
        lmin_149 = len(st_149)
    if len(st_149) > lmax_149:
        lmax_149 = len(st_149)
        
# restrMEG spatio-temporal sequences to length-5
STC5_149 = [ st_149 for st_149 in STC_149 if len(st_149) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_149 = []
for n in range(len(STC5_149)):
    tc_149 = [ u for u in STC5_149[n][0] ]
    for k in range(1, len(STC5_149[n])):
        tc_149 = [ u+v for u in tc_149 for v in STC5_149[n][k] ]
    TC5_149 = TC5_149 + tc_149
setTC5_149 = list(set(TC5_149))

# get empirical frequencies
fTC5_149 = [ TC5_149.count(setTC5_149[l]) for l in range(len(setTC5_149)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_149 = [ [] for l in range(len(setTC5_149)) ]
for s in range(100):
    STC5null_149 = [ list(st_149) for st_149 in STC5_149]
    for st_149 in STC5null_149:
        np.random.shuffle(st_149)
    TC5null_149= []
    for n in range(len(STC5null_149)):
        tc_149 = [ u for u in STC5null_149[n][0] ]
        for k in range(1, len(STC5null_149[n])):
            tc_149 = [ u+v for u in tc_149 for v in STC5null_149[n][k] ]
        TC5null_149= TC5null_149+ tc_149
    for l in range(len(setTC5_149)):
        if TC5null_149.count(setTC5_149[l]) > 0:
            fTC5null_149[l].append(TC5null_149.count(setTC5_149[l]))
        else:
            fTC5null_149[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_149)):
     if sum(freq >= fTC5_149[l] for freq in fTC5null_149[l]) < 5:
#         print(setTC5_149[l], fTC5_149[l], sum(freq >= fTC5_149[l] for freq in fTC5null_149[l]))
        print(setTC5_149[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# FYYY
# FDYYJ
# FDDYJ
# FJYJ
# DYJJJ
# RYF
# DJJFD
# FJFJJ
# FRRRR
# DYFJJ
# YDDR
# RJDJJ
# DDDFR
# RJYY
# FRF
# FRJYR
# DRDYR
# FJDJJ
# FRRYR
# RYJ
# FJDYJ
# YDDD
# FFFD
# YFRDJ
# DJRJJ
# RJRJJ
# DYYY
# FRRJJ
# FRDYJ
# FDDYR
# YFFDY
# FDJYR
# FJRYJ
# FRFYR
# DRRJJ
# FJYJJ
# FJYY
# RRRYY
# YDJJ
# YDDJ
# DRF
# DYRJJ
# FFFJ
# YDRJ
# FRYYJ
# DYRRR
# FD
# FDFYJ
# YFDDY
# YJ
# FJYYJ
# DRRYY
# YRFD
# DRRYJ
# FRFYJ
# FRFJ
# DYRRJ
# JJRJJ
# DJJFR
# FRRYJ
# YRDDY
# FJRJJ
# RJRY
# YDFJ
# YFFRY
# DFFJ
# FRDYR
# FRRYY
# YDRR
# RFFJ

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_149)):
     if sum(freq >= fTC5_149[l] for freq in fTC5null_149[l]) < 1:
#         print(setTC5_149[l], fTC5_149[l], sum(freq >= fTC5_149[l] for freq in fTC5null_149[l]))
        print(setTC5_149[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# FDYYJ
# DYFJJ
# DDDFR
# FJDJJ
# FFFD
# FRRJJ
# YDRJ
# FRYYJ
# FRRYJ
# FJRJJ

# %% [markdown]
# # 3.149 (D) AC - (F) BPI - (J) FGEN - (R) MEG - (α) SCC

# %%
#extract overlapping dates
start_150 = max(min(Date_AC), min(Date_BPI), min(Date_FGEN), min(Date_MEG), min(Date_SCC))
end_150 = min(max(Date_AC), max(Date_BPI), max(Date_FGEN), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
AC_150_1 = Date_AC.index(start_150)
AC_150_2 = Date_AC.index(end_150)

BPI_150_1 = Date_BPI.index(start_150)
BPI_150_2 = Date_BPI.index(end_150)

FGEN_150_1 = Date_FGEN.index(start_150)
FGEN_150_2 = Date_FGEN.index(end_150)

MEG_150_1 = Date_MEG.index(start_150)
MEG_150_2 = Date_MEG.index(end_150)

SCC_150_1 = Date_SCC.index(start_150)
SCC_150_2 = Date_SCC.index(end_150)

# %%
#save the shortened versions of closing prices
D150 = np.save('ACshortPrices.npy', ClosePrice_AC[AC_150_1:AC_150_2])
F150 = np.save('BPIshortPrices.npy', ClosePrice_BPI[BPI_150_1:BPI_150_2])
J150 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_150_1:FGEN_150_2])
R150 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_150_1:MEG_150_2])
α150 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_150_1:SCC_150_2])

# %%
# import modules
import numpy as np
# import prices

D150 = np.load('ACshortPrices.npy', allow_pickle=True).tolist() 
F150 = np.load('BPIshortPrices.npy', allow_pickle=True).tolist() 
J150 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
R150 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α150 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_150 = []
st_150 = []
n = 1
while n < len(D150):
    sc_150 = ''
    if D150[n] > D150[n-1]:
        sc_150 = sc_150 + 'D'
    if F150[n] > F150[n-1]:
        sc_150 = sc_150 + 'F'
    if J150[n] > J150[n-1]:
        sc_150 = sc_150 + 'J'
    if R150[n] > R150[n-1]:
        sc_150 = sc_150 + 'R'
    if α150[n] > α150[n-1]:
        sc_150 = sc_150 + 'α'
    if len(sc_150) > 0:
        st_150.append(sc_150)
    else:
        STC_150.append(st_150)
        st_150 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_150 = STC_150.count([])
# keep only non-empty spatio-temporal sequences
STC_150 = [ st_150 for st_150 in STC_150 if len(st_150) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_150 = len(D150)
lmax_150 = 0
for st_150 in STC_150:
    if len(st_150) < lmin_150:
        lmin_150 = len(st_150)
    if len(st_150) > lmax_150:
        lmax_150 = len(st_150)
        
# restrMEG spatio-temporal sequences to length-5
STC5_150 = [ st_150 for st_150 in STC_150 if len(st_150) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_150 = []
for n in range(len(STC5_150)):
    tc_150 = [ u for u in STC5_150[n][0] ]
    for k in range(1, len(STC5_150[n])):
        tc_150 = [ u+v for u in tc_150 for v in STC5_150[n][k] ]
    TC5_150 = TC5_150 + tc_150
setTC5_150 = list(set(TC5_150))

# get empirical frequencies
fTC5_150 = [ TC5_150.count(setTC5_150[l]) for l in range(len(setTC5_150)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_150 = [ [] for l in range(len(setTC5_150)) ]
for s in range(100):
    STC5null_150 = [ list(st_150) for st_150 in STC5_150]
    for st_150 in STC5null_150:
        np.random.shuffle(st_150)
    TC5null_150= []
    for n in range(len(STC5null_150)):
        tc_150 = [ u for u in STC5null_150[n][0] ]
        for k in range(1, len(STC5null_150[n])):
            tc_150 = [ u+v for u in tc_150 for v in STC5null_150[n][k] ]
        TC5null_150= TC5null_150+ tc_150
    for l in range(len(setTC5_150)):
        if TC5null_150.count(setTC5_150[l]) > 0:
            fTC5null_150[l].append(TC5null_150.count(setTC5_150[l]))
        else:
            fTC5null_150[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_150)):
     if sum(freq >= fTC5_150[l] for freq in fTC5null_150[l]) < 5:
#         print(setTC5_150[l], fTC5_150[l], sum(freq >= fTC5_150[l] for freq in fTC5null_150[l]))
        print(setTC5_150[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# RJDFF
# ααFFJ
# RααFJ
# RJ
# FJFJ
# FRαRD
# FFαF
# ααJR
# DJJFD
# Fαα
# αααRJ
# FRF
# αJDFJ
# RRαRD
# αJDFF
# αJJFF
# FFαRJ
# RRD
# FRFJD
# DJJDJ
# DJJFJ
# DRRRR
# FDFJ
# DJJJJ
# RJJRD
# DDαRD
# FRD
# DααRD
# RααRD
# FRFRD
# FαFJD
# DRαRD
# RαFRD
# RJJFF
# αDFR
# FRFR
# αDDαJ
# αJJDJ
# RJαFJ
# αααFJ
# RJJRF
# RRF
# FαFDD
# RαD
# FJ
# FDααD
# Rα
# JDJαD
# αDDR
# FDα
# RαDαJ
# ααRR
# RJJFD
# RααFD
# DDαFR
# RDααD
# αDRR
# RDDαJ
# DRFRD
# ααDRJ
# JRFRD
# FRFJR
# αDαRJ
# DJJFF
# αDαFJ
# DRαRJ
# FαFRD
# FRFJ
# αJFFJ
# DDαRR
# FFααD
# RαFRJ
# FDFR
# FDJαD
# FRαRR
# RααRJ
# RDαFJ
# FαFαD
# JαFRD
# RαDRJ
# αRFDα
# αJJFJ
# DαFRD
# DJJRF
# ααFRJ
# αDDRJ
# αJαFJ

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_150)):
     if sum(freq >= fTC5_150[l] for freq in fTC5null_150[l]) < 1:
#         print(setTC5_150[l], fTC5_150[l], sum(freq >= fTC5_150[l] for freq in fTC5null_150[l]))
        print(setTC5_150[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# RααFJ
# ααJR
# FRF
# DDαRD
# DααRD
# RαFRD
# αααFJ
# RRF
# RαD
# FJ
# FαFRD
# DαFRD
