# %% [markdown]
# # One-Letter Words

# %%
# open the csv files
AP = open('AP.csv')
AC = open('AC.csv')
BPI = open('BPI.csv')
BLOOM = open('BLOOM.csv')
FGEN = open('FGEN.csv')
ICT = open('ICT.csv')
JGS = open('JGS.csv')
MEG = open('MEG.csv')
SMC = open('SMC.csv')
SCC = open('SCC.csv')

#initiFGENze the lists
Date_AP = []
ClosePrice_AP = []
Date_AC = []
ClosePrice_AC = []
Date_BPI = []
ClosePrice_BPI = []
Date_BLOOM = []
ClosePrice_BLOOM = []
Date_FGEN = []
ClosePrice_FGEN = []
Date_ICT = []
ClosePrice_ICT = []
Date_JGS = []
ClosePrice_JGS = []
Date_MEG = []
ClosePrice_MEG = []
Date_SMC = []
ClosePrice_SMC = []
Date_SCC = []
ClosePrice_SCC = []

#skip the header line
AP.readline()
AC.readline()
BPI.readline()
BLOOM.readline()
FGEN.readline()
ICT.readline()
JGS.readline()
MEG.readline()
SMC.readline()
SCC.readline()

#go through the files line by line
for line in AP:
    sline = line.strip().split(',')
    Date_AP.append(sline[0])
    ClosePrice_AP.append(float(sline[1]))
    
for line in AC:
    sline = line.strip().split(',')
    Date_AC.append(sline[0])
    ClosePrice_AC.append(float(sline[1]))
    
for line in BPI:
    sline = line.strip().split(',')
    Date_BPI.append(sline[0])
    ClosePrice_BPI.append(float(sline[1]))
    
for line in BLOOM:
    sline = line.strip().split(',')
    Date_BLOOM.append(sline[0])
    ClosePrice_BLOOM.append(float(sline[1]))
    
for line in FGEN:
    sline = line.strip().split(',')
    Date_FGEN.append(sline[0])
    ClosePrice_FGEN.append(float(sline[1]))
    
for line in ICT:
    sline = line.strip().split(',')
    Date_ICT.append(sline[0])
    ClosePrice_ICT.append(float(sline[1]))
    
for line in JGS:
    sline = line.strip().split(',')
    Date_JGS.append(sline[0])
    ClosePrice_JGS.append(float(sline[1]))
    
for line in MEG:
    sline = line.strip().split(',')
    Date_MEG.append(sline[0])
    ClosePrice_MEG.append(float(sline[1]))
    
for line in SMC:
    sline = line.strip().split(',')
    Date_SMC.append(sline[0])
    ClosePrice_SMC.append(float(sline[1]))
        
for line in SCC:
    sline = line.strip().split(',')
    Date_SCC.append(sline[0])
    ClosePrice_SCC.append(float(sline[1]))


#close files
AP.close()
AC.close()
BPI.close()
BLOOM.close()
FGEN.close()
ICT.close()
JGS.close()
MEG.close()
SMC.close()
SCC.close()# One-Letter Words

# %%
import numpy as np
import datetime

# %%
# convert dates into datetime structure
for n in range(len(Date_AP)):
    Date_AP[n] = datetime.datetime.strptime(Date_AP[n], '%m/%d/%y').date()

for n in range(len(Date_AC)):
    Date_AC[n] = datetime.datetime.strptime(Date_AC[n], '%m/%d/%y').date()
    
for n in range(len(Date_BPI)):
    Date_BPI[n] = datetime.datetime.strptime(Date_BPI[n], '%m/%d/%y').date()

for n in range(len(Date_BLOOM)):
    Date_BLOOM[n] = datetime.datetime.strptime(Date_BLOOM[n], '%m/%d/%y').date()
    
for n in range(len(Date_FGEN)):
    Date_FGEN[n] = datetime.datetime.strptime(Date_FGEN[n], '%m/%d/%y').date()

for n in range(len(Date_ICT)):
    Date_ICT[n] = datetime.datetime.strptime(Date_ICT[n], '%m/%d/%y').date()
    
for n in range(len(Date_JGS)):
    Date_JGS[n] = datetime.datetime.strptime(Date_JGS[n], '%m/%d/%y').date()

for n in range(len(Date_MEG)):
    Date_MEG[n] = datetime.datetime.strptime(Date_MEG[n], '%m/%d/%y').date()
    
for n in range(len(Date_SMC)):
    Date_SMC[n] = datetime.datetime.strptime(Date_SMC[n], '%m/%d/%y').date()

for n in range(len(Date_SCC)):
    Date_SCC[n] = datetime.datetime.strptime(Date_SCC[n], '%m/%d/%y').date()
    
# save Date and ClosePrice
np.save('APDate.npy', Date_AP)
np.save('APClosePrice.npy', ClosePrice_AP)
np.save('ACDate.npy', Date_AC)
np.save('ACClosePrice.npy', ClosePrice_AC)
np.save('BPIDate.npy', Date_BPI)
np.save('BPIClosePrice.npy', ClosePrice_BPI)
np.save('BLOOMDate.npy', Date_BLOOM)
np.save('BLOOMClosePrice.npy', ClosePrice_BLOOM)
np.save('FGENDate.npy', Date_FGEN)
np.save('FGENClosePrice.npy', ClosePrice_FGEN)
np.save('ICTDate.npy', Date_ICT)
np.save('ICTClosePrice.npy', ClosePrice_ICT)
np.save('JGSDate.npy', Date_JGS)
np.save('JGSClosePrice.npy', ClosePrice_JGS)
np.save('MEGDate.npy', Date_MEG)
np.save('MEGClosePrice.npy', ClosePrice_MEG)
np.save('SMCDate.npy', Date_SMC)
np.save('SMCClosePrice.npy', ClosePrice_SMC)
np.save('SCCDate.npy', Date_SCC)
np.save('SCCClosePrice.npy', ClosePrice_SCC)

# %% [markdown]
# # Five-letter Words

# %% [markdown]
#  # 3.241 (H) BLOOM - (J) FGEN - (R) MEG - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_241 = max(min(Date_BLOOM), min(Date_FGEN), min(Date_MEG), min(Date_SMC), min(Date_SCC))
end_241 = min(max(Date_BLOOM), max(Date_FGEN), max(Date_MEG), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
BLOOM_241_1 = Date_BLOOM.index(start_241)
BLOOM_241_2 = Date_BLOOM.index(end_241)

FGEN_241_1 = Date_FGEN.index(start_241)
FGEN_241_2 = Date_FGEN.index(end_241)

MEG_241_1 = Date_MEG.index(start_241)
MEG_241_2 = Date_MEG.index(end_241)

SMC_241_1 = Date_SMC.index(start_241)
SMC_241_2 = Date_SMC.index(end_241)

SCC_241_1 = Date_SCC.index(start_241)
SCC_241_2 = Date_SCC.index(end_241)

# %%
#save the shortened versions of closing prices
H241 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_241_1:BLOOM_241_2])
J241 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_241_1:FGEN_241_2])
R241 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_241_1:MEG_241_2])
Y241 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_241_1:SMC_241_2])
α241 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_241_1:SCC_241_2])

# %%
# import modules
import numpy as np
# import prices

H241 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
J241 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
R241 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y241 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α241 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_241 = []
st_241 = []
n = 1
while n < len(H241):
    sc_241 = ''
    if H241[n] > H241[n-1]:
        sc_241 = sc_241 + 'H'
    if J241[n] > J241[n-1]:
        sc_241 = sc_241 + 'J'
    if R241[n] > R241[n-1]:
        sc_241 = sc_241 + 'R'
    if Y241[n] > Y241[n-1]:
        sc_241 = sc_241 + 'Y'
    if α241[n] > α241[n-1]:
        sc_241 = sc_241 + 'α'
    if len(sc_241) > 0:
        st_241.append(sc_241)
    else:
        STC_241.append(st_241)
        st_241 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_241 = STC_241.count([])
# keep only non-empty spatio-temporal sequences
STC_241 = [ st_241 for st_241 in STC_241 if len(st_241) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_241 = len(H241)
lmax_241 = 0
for st_241 in STC_241:
    if len(st_241) < lmin_241:
        lmin_241 = len(st_241)
    if len(st_241) > lmax_241:
        lmax_241 = len(st_241)
        
# restrict spatio-temporal sequences to length-5
STC5_241 = [ st_241 for st_241 in STC_241 if len(st_241) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_241 = []
for n in range(len(STC5_241)):
    tc_241 = [ u for u in STC5_241[n][0] ]
    for k in range(1, len(STC5_241[n])):
        tc_241 = [ u+v for u in tc_241 for v in STC5_241[n][k] ]
    TC5_241 = TC5_241 + tc_241
setTC5_241 = list(set(TC5_241))

# get empirical frequencies
fTC5_241 = [ TC5_241.count(setTC5_241[l]) for l in range(len(setTC5_241)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_241 = [ [] for l in range(len(setTC5_241)) ]
for s in range(100):
    STC5null_241 = [ list(st_241) for st_241 in STC5_241]
    for st_241 in STC5null_241:
        np.random.shuffle(st_241)
    TC5null_241= []
    for n in range(len(STC5null_241)):
        tc_241 = [ u for u in STC5null_241[n][0] ]
        for k in range(1, len(STC5null_241[n])):
            tc_241 = [ u+v for u in tc_241 for v in STC5null_241[n][k] ]
        TC5null_241= TC5null_241+ tc_241
    for l in range(len(setTC5_241)):
        if TC5null_241.count(setTC5_241[l]) > 0:
            fTC5null_241[l].append(TC5null_241.count(setTC5_241[l]))
        else:
            fTC5null_241[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_241)):
     if sum(freq >= fTC5_241[l] for freq in fTC5null_241[l]) < 5:
#         print(setTC5_241[l], fTC5_241[l], sum(freq >= fTC5_241[l] for freq in fTC5null_241[l]))
        print(setTC5_241[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# RHYαH
# JHJH
# αRYαJ
# αHHαJ
# RHHαH
# αRJJR
# αHHαY
# RαHYJ
# αYα
# JαHYR
# RRJJY
# αHJJY
# RRHαα
# αHHαH
# HJHαα
# JαJH
# αJHαJ
# JJJα
# RRYYH
# JααYR
# RHHαJ
# YJJJY
# αHα
# αRYJJ
# RJHYJ
# JRαH
# HJαRR
# αRααR
# RαHαJ
# ααYHJ
# YααR
# HJαRα
# RRYαJ
# RαYHJ
# RJHαJ
# YRααY
# RαYαJ
# RRHYJ
# ααYJY
# αYαY
# RHYαJ
# HHHαJ
# JRYH
# HJααα
# JYJY
# JYYY
# RRYαH
# αHYJJ
# JYJα
# RHYJJ
# RJYαJ
# JYαY
# RHYYH
# JRJH
# HRHαα
# YHRH
# αRRαR
# RJHαH
# JYHYR
# RHHJH
# HJααR
# αRYYJ
# RHJJY
# RJHαα
# YHααY
# RJYYJ
# αJHαH
# RYJH
# RJJJY
# YαJR
# αRHαJ
# YHRR
# RJJJR
# RJJRα
# YYRYR
# YHααJ
# RRJH
# RαYYH
# αRYHJ
# HHYαJ
# JαRH
# αJYJJ

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_241)):
     if sum(freq >= fTC5_241[l] for freq in fTC5null_241[l]) < 1:
#         print(setTC5_241[l], fTC5_241[l], sum(freq >= fTC5_241[l] for freq in fTC5null_241[l]))
        print(setTC5_241[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# RHHαH
# RHHαJ
# JRαH
# HJαRR
# HJαRα
# RRYαJ
# RJHαJ
# HJααα
# JYJY
# JYJα
# RJYαJ
# JRJH

# %% [markdown]
#  # 3.242 (H) BLOOM - (M) ICT - (N) JGS - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_242 = max(min(Date_BLOOM), min(Date_ICT), min(Date_JGS), min(Date_MEG), min(Date_SMC))
end_242 = min(max(Date_BLOOM), max(Date_ICT), max(Date_JGS), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
BLOOM_242_1 = Date_BLOOM.index(start_242)
BLOOM_242_2 = Date_BLOOM.index(end_242)

ICT_242_1 = Date_ICT.index(start_242)
ICT_242_2 = Date_ICT.index(end_242)

JGS_242_1 = Date_JGS.index(start_242)
JGS_242_2 = Date_JGS.index(end_242)

MEG_242_1 = Date_MEG.index(start_242)
MEG_242_2 = Date_MEG.index(end_242)

SMC_242_1 = Date_SMC.index(start_242)
SMC_242_2 = Date_SMC.index(end_242)

# %%
#save the shortened versions of closing prices
H242 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_242_1:BLOOM_242_2])
M242 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_242_1:ICT_242_2])
N242 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_242_1:JGS_242_2])
R242 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_242_1:MEG_242_2])
Y242 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_242_1:SMC_242_2])

# %%
# import modules
import numpy as np
# import prices

H242 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M242 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N242 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R242 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y242 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_242 = []
st_242 = []
n = 1
while n < len(H242):
    sc_242 = ''
    if H242[n] > H242[n-1]:
        sc_242 = sc_242 + 'H'
    if M242[n] > M242[n-1]:
        sc_242 = sc_242 + 'M'
    if N242[n] > N242[n-1]:
        sc_242 = sc_242 + 'N'
    if R242[n] > R242[n-1]:
        sc_242 = sc_242 + 'R'
    if Y242[n] > Y242[n-1]:
        sc_242 = sc_242 + 'Y'
    if len(sc_242) > 0:
        st_242.append(sc_242)
    else:
        STC_242.append(st_242)
        st_242 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_242 = STC_242.count([])
# keep only non-empty spatio-temporal sequences
STC_242 = [ st_242 for st_242 in STC_242 if len(st_242) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_242 = len(H242)
lmax_242 = 0
for st_242 in STC_242:
    if len(st_242) < lmin_242:
        lmin_242 = len(st_242)
    if len(st_242) > lmax_242:
        lmax_242 = len(st_242)
        
# restrict spatio-temporal sequences to length-5
STC5_242 = [ st_242 for st_242 in STC_242 if len(st_242) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_242 = []
for n in range(len(STC5_242)):
    tc_242 = [ u for u in STC5_242[n][0] ]
    for k in range(1, len(STC5_242[n])):
        tc_242 = [ u+v for u in tc_242 for v in STC5_242[n][k] ]
    TC5_242 = TC5_242 + tc_242
setTC5_242 = list(set(TC5_242))

# get empirical frequencies
fTC5_242 = [ TC5_242.count(setTC5_242[l]) for l in range(len(setTC5_242)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_242 = [ [] for l in range(len(setTC5_242)) ]
for s in range(100):
    STC5null_242 = [ list(st_242) for st_242 in STC5_242]
    for st_242 in STC5null_242:
        np.random.shuffle(st_242)
    TC5null_242= []
    for n in range(len(STC5null_242)):
        tc_242 = [ u for u in STC5null_242[n][0] ]
        for k in range(1, len(STC5null_242[n])):
            tc_242 = [ u+v for u in tc_242 for v in STC5null_242[n][k] ]
        TC5null_242= TC5null_242+ tc_242
    for l in range(len(setTC5_242)):
        if TC5null_242.count(setTC5_242[l]) > 0:
            fTC5null_242[l].append(TC5null_242.count(setTC5_242[l]))
        else:
            fTC5null_242[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_242)):
     if sum(freq >= fTC5_242[l] for freq in fTC5null_242[l]) < 5:
#         print(setTC5_242[l], fTC5_242[l], sum(freq >= fTC5_242[l] for freq in fTC5null_242[l]))
        print(setTC5_242[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# MRHYM
# HMHYM
# HRRYM
# YRMMR
# NRNYM
# YHYNN
# YNMMY
# NNNH
# RHYRR
# MYY
# HHYNM
# HRYYM
# HRMMM
# RHYYR
# HNYYM
# YRNYH
# NYRRM
# HRHMM
# HHYNN
# YYNN
# HHYRN
# HHYRR
# HHYRM
# YHYYR
# HHMNN
# MRMYN
# MMNH
# MHYYR
# MHYRR
# HRHYM
# HRHRM
# HRMNM
# HRHNM
# HMMYM
# HNY
# YNYMN
# RRYYR
# MMNR
# HNHYM
# HMNYH
# RRMYN
# MNMYM
# NHYYR
# NHYRR
# HNMMM
# HMYYM
# MRMYM
# HNYMM
# HNHMM
# HMNYM
# RNYYN
# HRNNM
# RRHH
# RRMMM
# MMMH
# YHYRM
# NRRRR
# YNMMR
# MRMMM
# RRMMN
# NRMYM
# YYMMM
# YRMMY
# MRRRR
# HYY
# HRMYM
# NRYYR
# YHMMY
# MMRR
# YNYYN
# NRNRM
# HNMYM
# RHMMY
# NYNRM
# YRMYN
# HRMRM
# YHYRR
# NRYYY
# HNHNM
# NRMNR
# RNYMN
# HYR
# MRMMN
# HRNYM
# YNYMY
# HMRN
# MRMRR
# YHYHH
# HNMNM
# HRNYH
# HRYMM
# RRMYM

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_242)):
     if sum(freq >= fTC5_242[l] for freq in fTC5null_242[l]) < 1:
#         print(setTC5_242[l], fTC5_242[l], sum(freq >= fTC5_242[l] for freq in fTC5null_242[l]))
        print(setTC5_242[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# HMHYM
# YRMMR
# YHYNN
# NNNH
# RHYRR
# HRYYM
# MHYYR
# HRHYM
# HRHRM
# HRMNM
# HMMYM
# MRMYM
# MMMH
# YNMMR
# MRMMM
# YRMMY
# YNYYN
# NRNRM
# HRMRM
# HNMNM

# %% [markdown]
#  # 3.243 (H) BLOOM - (M) ICT - (N) JGS - (R) MEG - (α) SCC

# %%
#extract overlapping dates
start_243 = max(min(Date_BLOOM), min(Date_ICT), min(Date_JGS), min(Date_MEG), min(Date_SCC))
end_243 = min(max(Date_BLOOM), max(Date_ICT), max(Date_JGS), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
BLOOM_243_1 = Date_BLOOM.index(start_243)
BLOOM_243_2 = Date_BLOOM.index(end_243)

ICT_243_1 = Date_ICT.index(start_243)
ICT_243_2 = Date_ICT.index(end_243)

JGS_243_1 = Date_JGS.index(start_243)
JGS_243_2 = Date_JGS.index(end_243)

MEG_243_1 = Date_MEG.index(start_243)
MEG_243_2 = Date_MEG.index(end_243)

SCC_243_1 = Date_SCC.index(start_243)
SCC_243_2 = Date_SCC.index(end_243)

# %%
#save the shortened versions of closing prices
H243 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_243_1:BLOOM_243_2])
M243 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_243_1:ICT_243_2])
N243 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_243_1:JGS_243_2])
R243 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_243_1:MEG_243_2])
α243 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_243_1:SCC_243_2])

# %%
# import modules
import numpy as np
# import prices

H243 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M243 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N243 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R243 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α243 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_243 = []
st_243 = []
n = 1
while n < len(H243):
    sc_243 = ''
    if H243[n] > H243[n-1]:
        sc_243 = sc_243 + 'H'
    if M243[n] > M243[n-1]:
        sc_243 = sc_243 + 'M'
    if N243[n] > N243[n-1]:
        sc_243 = sc_243 + 'N'
    if R243[n] > R243[n-1]:
        sc_243 = sc_243 + 'R'
    if α243[n] > α243[n-1]:
        sc_243 = sc_243 + 'α'
    if len(sc_243) > 0:
        st_243.append(sc_243)
    else:
        STC_243.append(st_243)
        st_243 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_243 = STC_243.count([])
# keep only non-empty spatio-temporal sequences
STC_243 = [ st_243 for st_243 in STC_243 if len(st_243) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_243 = len(H243)
lmax_243 = 0
for st_243 in STC_243:
    if len(st_243) < lmin_243:
        lmin_243 = len(st_243)
    if len(st_243) > lmax_243:
        lmax_243 = len(st_243)
        
# restrict spatio-temporal sequences to length-5
STC5_243 = [ st_243 for st_243 in STC_243 if len(st_243) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_243 = []
for n in range(len(STC5_243)):
    tc_243 = [ u for u in STC5_243[n][0] ]
    for k in range(1, len(STC5_243[n])):
        tc_243 = [ u+v for u in tc_243 for v in STC5_243[n][k] ]
    TC5_243 = TC5_243 + tc_243
setTC5_243 = list(set(TC5_243))

# get empirical frequencies
fTC5_243 = [ TC5_243.count(setTC5_243[l]) for l in range(len(setTC5_243)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_243 = [ [] for l in range(len(setTC5_243)) ]
for s in range(100):
    STC5null_243 = [ list(st_243) for st_243 in STC5_243]
    for st_243 in STC5null_243:
        np.random.shuffle(st_243)
    TC5null_243= []
    for n in range(len(STC5null_243)):
        tc_243 = [ u for u in STC5null_243[n][0] ]
        for k in range(1, len(STC5null_243[n])):
            tc_243 = [ u+v for u in tc_243 for v in STC5null_243[n][k] ]
        TC5null_243= TC5null_243+ tc_243
    for l in range(len(setTC5_243)):
        if TC5null_243.count(setTC5_243[l]) > 0:
            fTC5null_243[l].append(TC5null_243.count(setTC5_243[l]))
        else:
            fTC5null_243[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_243)):
     if sum(freq >= fTC5_243[l] for freq in fTC5null_243[l]) < 5:
#         print(setTC5_243[l], fTC5_243[l], sum(freq >= fTC5_243[l] for freq in fTC5null_243[l]))
        print(setTC5_243[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# NRNH
# NαNR
# RHMαN
# αMNR
# NNNαH
# HαN
# αNNαH
# HRMαH
# HRMMα
# NNNH
# αRRRR
# HMNH
# HRMαα
# RRNR
# αNNαα
# MH
# NRαNR
# MRNαH
# HMMαα
# αMRR
# MRRHH
# MRNRα
# αRRMα
# NαRα
# αRNαα
# MNNRα
# NRRNR
# HRMMN
# RMM
# MRNαα
# MRRαH
# MNNRM
# αNRMN
# MNMαα
# MNαNα
# MMNH
# αNRRR
# MNNNα
# HHMαN
# RMNH
# MRRR
# αRNαH
# MRNRH
# MMRH
# MNNαH
# αNRHα
# MMNR
# αMNH
# αMRH
# MHNαH
# MHRMH
# MNNRH
# HNMαα
# NαNα
# MRNH
# αRRαα
# HαMMα
# RMMαα
# HRNαH
# MRRαα
# HHMαα
# HMRH
# MRMαα
# MMN
# HMHH
# RRM
# αRRHH
# RRNH
# NRNRH
# MαHH
# RRMMM
# NRRRR
# HRHH
# HRHαα
# HRMαN
# NαRH
# MRMMM
# RRMMN
# MRRRR
# MRNR
# HαMαα
# MRRNα
# MMRR
# HαHH
# αNNHM
# αNNHα
# MNNαα
# MHNMH
# αRNHα
# RMHαα
# RRMαα
# HRααα
# MRRRα
# HRααH
# NNNRH
# MRMMN
# NMNH
# RMNR
# NRNαα
# MαRH
# NαNH
# αNNHR
# HRNαα
# αNRMα
# αNMMR
# αNRMR
# HMNN
# RNMαα
# MNRNα
# RNMNα
# NαHH

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_243)):
     if sum(freq >= fTC5_243[l] for freq in fTC5null_243[l]) < 1:
#         print(setTC5_243[l], fTC5_243[l], sum(freq >= fTC5_243[l] for freq in fTC5null_243[l]))
        print(setTC5_243[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# HRMMα
# NNNH
# HMNH
# HRMαα
# HMMαα
# MRNαα
# MMNH
# HHMαN
# MMRH
# MMNR
# αMNH
# αMRH
# MRMαα
# NRRRR
# HRHαα
# HαHH
# αNNHα
# NαNH
# αNNHR
# αNRMR

# %% [markdown]
#  # 3.244 (H) BLOOM - (M) ICT - (N) JGS - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_244 = max(min(Date_BLOOM), min(Date_ICT), min(Date_JGS), min(Date_SMC), min(Date_SCC))
end_244 = min(max(Date_BLOOM), max(Date_ICT), max(Date_JGS), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
BLOOM_244_1 = Date_BLOOM.index(start_244)
BLOOM_244_2 = Date_BLOOM.index(end_244)

ICT_244_1 = Date_ICT.index(start_244)
ICT_244_2 = Date_ICT.index(end_244)

JGS_244_1 = Date_JGS.index(start_244)
JGS_244_2 = Date_JGS.index(end_244)

SMC_244_1 = Date_SMC.index(start_244)
SMC_244_2 = Date_SMC.index(end_244)

SCC_244_1 = Date_SCC.index(start_244)
SCC_244_2 = Date_SCC.index(end_244)

# %%
#save the shortened versions of closing prices
H244 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_244_1:BLOOM_244_2])
M244 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_244_1:ICT_244_2])
N244 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_244_1:JGS_244_2])
Y244 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_244_1:SMC_244_2])
α244 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_244_1:SCC_244_2])

# %%
# import modules
import numpy as np
# import prices

H244 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M244 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N244 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y244 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α244 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_244 = []
st_244 = []
n = 1
while n < len(H244):
    sc_244 = ''
    if H244[n] > H244[n-1]:
        sc_244 = sc_244 + 'H'
    if M244[n] > M244[n-1]:
        sc_244 = sc_244 + 'M'
    if N244[n] > N244[n-1]:
        sc_244 = sc_244 + 'N'
    if Y244[n] > Y244[n-1]:
        sc_244 = sc_244 + 'Y'
    if α244[n] > α244[n-1]:
        sc_244 = sc_244 + 'α'
    if len(sc_244) > 0:
        st_244.append(sc_244)
    else:
        STC_244.append(st_244)
        st_244 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_244 = STC_244.count([])
# keep only non-empty spatio-temporal sequences
STC_244 = [ st_244 for st_244 in STC_244 if len(st_244) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_244 = len(H244)
lmax_244 = 0
for st_244 in STC_244:
    if len(st_244) < lmin_244:
        lmin_244 = len(st_244)
    if len(st_244) > lmax_244:
        lmax_244 = len(st_244)
        
# restrict spatio-temporal sequences to length-5
STC5_244 = [ st_244 for st_244 in STC_244 if len(st_244) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_244 = []
for n in range(len(STC5_244)):
    tc_244 = [ u for u in STC5_244[n][0] ]
    for k in range(1, len(STC5_244[n])):
        tc_244 = [ u+v for u in tc_244 for v in STC5_244[n][k] ]
    TC5_244 = TC5_244 + tc_244
setTC5_244 = list(set(TC5_244))

# get empirical frequencies
fTC5_244 = [ TC5_244.count(setTC5_244[l]) for l in range(len(setTC5_244)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_244 = [ [] for l in range(len(setTC5_244)) ]
for s in range(100):
    STC5null_244 = [ list(st_244) for st_244 in STC5_244]
    for st_244 in STC5null_244:
        np.random.shuffle(st_244)
    TC5null_244= []
    for n in range(len(STC5null_244)):
        tc_244 = [ u for u in STC5null_244[n][0] ]
        for k in range(1, len(STC5null_244[n])):
            tc_244 = [ u+v for u in tc_244 for v in STC5null_244[n][k] ]
        TC5null_244= TC5null_244+ tc_244
    for l in range(len(setTC5_244)):
        if TC5null_244.count(setTC5_244[l]) > 0:
            fTC5null_244[l].append(TC5null_244.count(setTC5_244[l]))
        else:
            fTC5null_244[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_244)):
     if sum(freq >= fTC5_244[l] for freq in fTC5null_244[l]) < 5:
#         print(setTC5_244[l], fTC5_244[l], sum(freq >= fTC5_244[l] for freq in fTC5null_244[l]))
        print(setTC5_244[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# HαN
# NNNH
# YHYαH
# MαMYM
# MH
# αN
# YYNN
# NαMα
# MHMMH
# αHαY
# HMN
# αYYNα
# αYYNN
# MMNH
# YHYNH
# NYαNN
# NNNα
# αNMMα
# YHYYH
# HMMYM
# YHMYH
# YMNH
# HMMαM
# NαNα
# αYYMN
# HYN
# HNMMα
# YYYMN
# MMN
# YYαNα
# NNαNα
# NYαMN
# MMHMN
# MαHH
# αNMMM
# MMHYN
# YHNHH
# YαYMN
# NYMNN
# NHαMN
# HαHH
# NYNNN
# YYααα
# NHMHH
# NNNY
# NαNH
# ααMα
# NYYNN
# YHYHH
# NαHH
# MMHNN

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_244)):
     if sum(freq >= fTC5_244[l] for freq in fTC5null_244[l]) < 1:
#         print(setTC5_244[l], fTC5_244[l], sum(freq >= fTC5_244[l] for freq in fTC5null_244[l]))
        print(setTC5_244[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# NNNH
# HMN
# NYαNN
# YHYYH
# HMMαM
# NαNα
# YYYMN
# MMN
# NYMNN

# %% [markdown]
#  # 3.245 (H) BLOOM - (M) ICT - (R) MEG - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_245 = max(min(Date_BLOOM), min(Date_ICT), min(Date_MEG), min(Date_SMC), min(Date_SCC))
end_245 = min(max(Date_BLOOM), max(Date_ICT), max(Date_MEG), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
BLOOM_245_1 = Date_BLOOM.index(start_245)
BLOOM_245_2 = Date_BLOOM.index(end_245)

ICT_245_1 = Date_ICT.index(start_245)
ICT_245_2 = Date_ICT.index(end_245)

MEG_245_1 = Date_MEG.index(start_245)
MEG_245_2 = Date_MEG.index(end_245)

SMC_245_1 = Date_SMC.index(start_245)
SMC_245_2 = Date_SMC.index(end_245)

SCC_245_1 = Date_SCC.index(start_245)
SCC_245_2 = Date_SCC.index(end_245)

# %%
#save the shortened versions of closing prices
H245 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_245_1:BLOOM_245_2])
M245 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_245_1:ICT_245_2])
R245 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_245_1:MEG_245_2])
Y245 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_245_1:SMC_245_2])
α245 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_245_1:SCC_245_2])

# %%
# import modules
import numpy as np
# import prices

H245 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
M245 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R245 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y245 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α245 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_245 = []
st_245 = []
n = 1
while n < len(H245):
    sc_245 = ''
    if H245[n] > H245[n-1]:
        sc_245 = sc_245 + 'H'
    if M245[n] > M245[n-1]:
        sc_245 = sc_245 + 'M'
    if R245[n] > R245[n-1]:
        sc_245 = sc_245 + 'R'
    if Y245[n] > Y245[n-1]:
        sc_245 = sc_245 + 'Y'
    if α245[n] > α245[n-1]:
        sc_245 = sc_245 + 'α'
    if len(sc_245) > 0:
        st_245.append(sc_245)
    else:
        STC_245.append(st_245)
        st_245 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_245 = STC_245.count([])
# keep only non-empty spatio-temporal sequences
STC_245 = [ st_245 for st_245 in STC_245 if len(st_245) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_245 = len(H245)
lmax_245 = 0
for st_245 in STC_245:
    if len(st_245) < lmin_245:
        lmin_245 = len(st_245)
    if len(st_245) > lmax_245:
        lmax_245 = len(st_245)
        
# restrict spatio-temporal sequences to length-5
STC5_245 = [ st_245 for st_245 in STC_245 if len(st_245) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_245 = []
for n in range(len(STC5_245)):
    tc_245 = [ u for u in STC5_245[n][0] ]
    for k in range(1, len(STC5_245[n])):
        tc_245 = [ u+v for u in tc_245 for v in STC5_245[n][k] ]
    TC5_245 = TC5_245 + tc_245
setTC5_245 = list(set(TC5_245))

# get empirical frequencies
fTC5_245 = [ TC5_245.count(setTC5_245[l]) for l in range(len(setTC5_245)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_245 = [ [] for l in range(len(setTC5_245)) ]
for s in range(100):
    STC5null_245 = [ list(st_245) for st_245 in STC5_245]
    for st_245 in STC5null_245:
        np.random.shuffle(st_245)
    TC5null_245= []
    for n in range(len(STC5null_245)):
        tc_245 = [ u for u in STC5null_245[n][0] ]
        for k in range(1, len(STC5null_245[n])):
            tc_245 = [ u+v for u in tc_245 for v in STC5null_245[n][k] ]
        TC5null_245= TC5null_245+ tc_245
    for l in range(len(setTC5_245)):
        if TC5null_245.count(setTC5_245[l]) > 0:
            fTC5null_245[l].append(TC5null_245.count(setTC5_245[l]))
        else:
            fTC5null_245[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_245)):
     if sum(freq >= fTC5_245[l] for freq in fTC5null_245[l]) < 5:
#         print(setTC5_245[l], fTC5_245[l], sum(freq >= fTC5_245[l] for freq in fTC5null_245[l]))
        print(setTC5_245[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# αRRHM
# YRMMR
# YHRYH
# HRMMα
# αRRRR
# MRMMR
# RRYαM
# YαMM
# HRαMM
# MαMYM
# YHMαY
# HRMMM
# MYYαR
# αMRR
# HRMαM
# αRRHR
# HRHMM
# HαMHR
# MRHMM
# RMM
# YRRαH
# MRHαM
# MRYMM
# αRYYY
# YYαHM
# HRαRR
# HRHRR
# HRHRM
# αRRMY
# αRααR
# HRMαR
# YRYYH
# YHYYH
# YRRYH
# αRαRM
# YααR
# HαMYM
# αRRMR
# MYRRR
# HαMHM
# HαMMα
# YRααY
# YYYMM
# MRMYM
# RRHMM
# RRM
# HRHαM
# HYYMR
# αRRHH
# YRYαH
# MMMR
# HRHαR
# MαHH
# RRMMM
# αYRαR
# αYYMM
# MRMMM
# RYYαR
# αRRαR
# RRHαM
# YαMR
# HRMHM
# YYMMM
# YRMMY
# MRRRR
# YYRRM
# RRYαR
# HRαMR
# HαHH
# YHααY
# HRααM
# HRMRM
# RYMR
# HRαRM
# ααYYY
# αYMMM
# RYMMM
# αYααR
# YRRMR
# ααMα
# MRMRR
# HRMRR

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_245)):
     if sum(freq >= fTC5_245[l] for freq in fTC5null_245[l]) < 1:
#         print(setTC5_245[l], fTC5_245[l], sum(freq >= fTC5_245[l] for freq in fTC5null_245[l]))
        print(setTC5_245[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# MαMYM
# HRMMM
# HRMαM
# HRHMM
# HRHRR
# YRYYH
# αRRMR
# HRHαM
# RRMMM
# MRMMM
# αRRαR
# YαMR
# YYMMM
# HαHH
# HRMRM
# ααYYY

# %% [markdown]
#  # 3.246 (H) BLOOM - (N) JGS - (R) MEG - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_246 = max(min(Date_BLOOM), min(Date_JGS), min(Date_MEG), min(Date_SMC), min(Date_SCC))
end_246 = min(max(Date_BLOOM), max(Date_JGS), max(Date_MEG), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
BLOOM_246_1 = Date_BLOOM.index(start_246)
BLOOM_246_2 = Date_BLOOM.index(end_246)

JGS_246_1 = Date_JGS.index(start_246)
JGS_246_2 = Date_JGS.index(end_246)

MEG_246_1 = Date_MEG.index(start_246)
MEG_246_2 = Date_MEG.index(end_246)

SMC_246_1 = Date_SMC.index(start_246)
SMC_246_2 = Date_SMC.index(end_246)

SCC_246_1 = Date_SCC.index(start_246)
SCC_246_2 = Date_SCC.index(end_246)

# %%
#save the shortened versions of closing prices
H246 = np.save('BLOOMshortPrices.npy', ClosePrice_BLOOM[BLOOM_246_1:BLOOM_246_2])
N246 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_246_1:JGS_246_2])
R246 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_246_1:MEG_246_2])
Y246 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_246_1:SMC_246_2])
α246 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_246_1:SCC_246_2])

# %%
# import modules
import numpy as np
# import prices

H246 = np.load('BLOOMshortPrices.npy', allow_pickle=True).tolist() 
N246 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R246 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y246 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α246 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_246 = []
st_246 = []
n = 1
while n < len(H246):
    sc_246 = ''
    if H246[n] > H246[n-1]:
        sc_246 = sc_246 + 'H'
    if N246[n] > N246[n-1]:
        sc_246 = sc_246 + 'N'
    if R246[n] > R246[n-1]:
        sc_246 = sc_246 + 'R'
    if Y246[n] > Y246[n-1]:
        sc_246 = sc_246 + 'Y'
    if α246[n] > α246[n-1]:
        sc_246 = sc_246 + 'α'
    if len(sc_246) > 0:
        st_246.append(sc_246)
    else:
        STC_246.append(st_246)
        st_246 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_246 = STC_246.count([])
# keep only non-empty spatio-temporal sequences
STC_246 = [ st_246 for st_246 in STC_246 if len(st_246) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_246 = len(H246)
lmax_246 = 0
for st_246 in STC_246:
    if len(st_246) < lmin_246:
        lmin_246 = len(st_246)
    if len(st_246) > lmax_246:
        lmax_246 = len(st_246)
        
# restrict spatio-temporal sequences to length-5
STC5_246 = [ st_246 for st_246 in STC_246 if len(st_246) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_246 = []
for n in range(len(STC5_246)):
    tc_246 = [ u for u in STC5_246[n][0] ]
    for k in range(1, len(STC5_246[n])):
        tc_246 = [ u+v for u in tc_246 for v in STC5_246[n][k] ]
    TC5_246 = TC5_246 + tc_246
setTC5_246 = list(set(TC5_246))

# get empirical frequencies
fTC5_246 = [ TC5_246.count(setTC5_246[l]) for l in range(len(setTC5_246)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_246 = [ [] for l in range(len(setTC5_246)) ]
for s in range(100):
    STC5null_246 = [ list(st_246) for st_246 in STC5_246]
    for st_246 in STC5null_246:
        np.random.shuffle(st_246)
    TC5null_246= []
    for n in range(len(STC5null_246)):
        tc_246 = [ u for u in STC5null_246[n][0] ]
        for k in range(1, len(STC5null_246[n])):
            tc_246 = [ u+v for u in tc_246 for v in STC5null_246[n][k] ]
        TC5null_246= TC5null_246+ tc_246
    for l in range(len(setTC5_246)):
        if TC5null_246.count(setTC5_246[l]) > 0:
            fTC5null_246[l].append(TC5null_246.count(setTC5_246[l]))
        else:
            fTC5null_246[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_246)):
     if sum(freq >= fTC5_246[l] for freq in fTC5null_246[l]) < 5:
#         print(setTC5_246[l], fTC5_246[l], sum(freq >= fTC5_246[l] for freq in fTC5null_246[l]))
        print(setTC5_246[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# αNRαY
# NRNH
# NNαH
# HαN
# NRRRα
# αHHαY
# RYN
# HRHRα
# YRαR
# NNNH
# YHNR
# HαRH
# YRNYH
# RαYYR
# NRNY
# YαNR
# NRRNR
# RHHαN
# YNRαY
# NRαH
# YNNHN
# YαNHY
# NαYHY
# αNNαY
# RNNαY
# YααR
# RαNαY
# NααH
# NαNα
# HNN
# YRααY
# YαYHY
# αNYHY
# NNαNα
# RNYYN
# NYαNR
# ααYHY
# RNNαα
# NRHH
# HRHH
# YNYHN
# NRYHY
# NYαNα
# YHNHH
# RRαR
# YHαY
# YαNH
# YHNYH
# YNYYN
# HαHH
# RαYYN
# NRHRH
# YHααY
# NRHRα
# HRRH
# αH
# NRYYY
# NNRRH
# NαNH
# RRYYN
# NαHH

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_246)):
     if sum(freq >= fTC5_246[l] for freq in fTC5null_246[l]) < 1:
#         print(setTC5_246[l], fTC5_246[l], sum(freq >= fTC5_246[l] for freq in fTC5null_246[l]))
        print(setTC5_246[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# HαN
# YαNR
# αNNαY
# YααR
# RNYYN
# YαNH
# HαHH
# NRHRH
# NNRRH

# %% [markdown]
#  # 3.247 (J) BLOOM - (M) ICT - (N) JGS - (R) MEG - (Y) SMC

# %%
#extract overlapping dates
start_247 = max(min(Date_FGEN), min(Date_ICT), min(Date_JGS), min(Date_MEG), min(Date_SMC))
end_247 = min(max(Date_FGEN), max(Date_ICT), max(Date_JGS), max(Date_MEG), max(Date_SMC))

# %%
#shorten the closing prices
FGEN_247_1 = Date_FGEN.index(start_247)
FGEN_247_2 = Date_FGEN.index(end_247)

ICT_247_1 = Date_ICT.index(start_247)
ICT_247_2 = Date_ICT.index(end_247)

JGS_247_1 = Date_JGS.index(start_247)
JGS_247_2 = Date_JGS.index(end_247)

MEG_247_1 = Date_MEG.index(start_247)
MEG_247_2 = Date_MEG.index(end_247)

SMC_247_1 = Date_SMC.index(start_247)
SMC_247_2 = Date_SMC.index(end_247)

# %%
#save the shortened versions of closing prices
J247 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_247_1:FGEN_247_2])
M247 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_247_1:ICT_247_2])
N247 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_247_1:JGS_247_2])
R247 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_247_1:MEG_247_2])
Y247 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_247_1:SMC_247_2])

# %%
# import modules
import numpy as np
# import prices

J247 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M247 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N247 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R247 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y247 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_247 = []
st_247 = []
n = 1
while n < len(J247):
    sc_247 = ''
    if J247[n] > J247[n-1]:
        sc_247 = sc_247 + 'J'
    if M247[n] > M247[n-1]:
        sc_247 = sc_247 + 'M'
    if N247[n] > N247[n-1]:
        sc_247 = sc_247 + 'N'
    if R247[n] > R247[n-1]:
        sc_247 = sc_247 + 'R'
    if Y247[n] > Y247[n-1]:
        sc_247 = sc_247 + 'Y'
    if len(sc_247) > 0:
        st_247.append(sc_247)
    else:
        STC_247.append(st_247)
        st_247 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[56], line 9
#       7 if J247[n] > J247[n-1]:
#       8     sc_247 = sc_247 + 'J'
# ----> 9 if M247[n] > M247[n-1]:
#      10     sc_247 = sc_247 + 'M'
#      11 if N247[n] > N247[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_247 = STC_247.count([])
# keep only non-empty spatio-temporal sequences
STC_247 = [ st_247 for st_247 in STC_247 if len(st_247) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_247 = len(J247)
lmax_247 = 0
for st_247 in STC_247:
    if len(st_247) < lmin_247:
        lmin_247 = len(st_247)
    if len(st_247) > lmax_247:
        lmax_247 = len(st_247)
        
# restrict spatio-temporal sequences to length-5
STC5_247 = [ st_247 for st_247 in STC_247 if len(st_247) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_247 = []
for n in range(len(STC5_247)):
    tc_247 = [ u for u in STC5_247[n][0] ]
    for k in range(1, len(STC5_247[n])):
        tc_247 = [ u+v for u in tc_247 for v in STC5_247[n][k] ]
    TC5_247 = TC5_247 + tc_247
setTC5_247 = list(set(TC5_247))

# get empirical frequencies
fTC5_247 = [ TC5_247.count(setTC5_247[l]) for l in range(len(setTC5_247)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_247 = [ [] for l in range(len(setTC5_247)) ]
for s in range(100):
    STC5null_247 = [ list(st_247) for st_247 in STC5_247]
    for st_247 in STC5null_247:
        np.random.shuffle(st_247)
    TC5null_247= []
    for n in range(len(STC5null_247)):
        tc_247 = [ u for u in STC5null_247[n][0] ]
        for k in range(1, len(STC5null_247[n])):
            tc_247 = [ u+v for u in tc_247 for v in STC5null_247[n][k] ]
        TC5null_247= TC5null_247+ tc_247
    for l in range(len(setTC5_247)):
        if TC5null_247.count(setTC5_247[l]) > 0:
            fTC5null_247[l].append(TC5null_247.count(setTC5_247[l]))
        else:
            fTC5null_247[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_247)):
     if sum(freq >= fTC5_247[l] for freq in fTC5null_247[l]) < 5:
#         print(setTC5_247[l], fTC5_247[l], sum(freq >= fTC5_247[l] for freq in fTC5null_247[l]))
        print(setTC5_247[l])

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_247)):
     if sum(freq >= fTC5_247[l] for freq in fTC5null_247[l]) < 1:
#         print(setTC5_247[l], fTC5_247[l], sum(freq >= fTC5_247[l] for freq in fTC5null_247[l]))
        print(setTC5_247[l])

# %% [markdown]
#  # 3.248 (J) BLOOM - (M) ICT - (N) JGS - (R) MEG - (α) SCC

# %%
#extract overlapping dates
start_248 = max(min(Date_FGEN), min(Date_ICT), min(Date_JGS), min(Date_MEG), min(Date_SCC))
end_248 = min(max(Date_FGEN), max(Date_ICT), max(Date_JGS), max(Date_MEG), max(Date_SCC))

# %%
#shorten the closing prices
FGEN_248_1 = Date_FGEN.index(start_248)
FGEN_248_2 = Date_FGEN.index(end_248)

ICT_248_1 = Date_ICT.index(start_248)
ICT_248_2 = Date_ICT.index(end_248)

JGS_248_1 = Date_JGS.index(start_248)
JGS_248_2 = Date_JGS.index(end_248)

MEG_248_1 = Date_MEG.index(start_248)
MEG_248_2 = Date_MEG.index(end_248)

SCC_248_1 = Date_SCC.index(start_248)
SCC_248_2 = Date_SCC.index(end_248)

# %%
#save the shortened versions of closing prices
J248 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_248_1:FGEN_248_2])
M248 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_248_1:ICT_248_2])
N248 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_248_1:JGS_248_2])
R248 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_248_1:MEG_248_2])
α248 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_248_1:SCC_248_2])

# %%
# import modules
import numpy as np
# import prices

J248 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M248 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N248 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R248 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
α248 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_248 = []
st_248 = []
n = 1
while n < len(J248):
    sc_248 = ''
    if J248[n] > J248[n-1]:
        sc_248 = sc_248 + 'J'
    if M248[n] > M248[n-1]:
        sc_248 = sc_248 + 'M'
    if N248[n] > N248[n-1]:
        sc_248 = sc_248 + 'N'
    if R248[n] > R248[n-1]:
        sc_248 = sc_248 + 'R'
    if α248[n] > α248[n-1]:
        sc_248 = sc_248 + 'α'
    if len(sc_248) > 0:
        st_248.append(sc_248)
    else:
        STC_248.append(st_248)
        st_248 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[61], line 9
#       7 if J248[n] > J248[n-1]:
#       8     sc_248 = sc_248 + 'J'
# ----> 9 if M248[n] > M248[n-1]:
#      10     sc_248 = sc_248 + 'M'
#      11 if N248[n] > N248[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_248 = STC_248.count([])
# keep only non-empty spatio-temporal sequences
STC_248 = [ st_248 for st_248 in STC_248 if len(st_248) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_248 = len(J248)
lmax_248 = 0
for st_248 in STC_248:
    if len(st_248) < lmin_248:
        lmin_248 = len(st_248)
    if len(st_248) > lmax_248:
        lmax_248 = len(st_248)
        
# restrict spatio-temporal sequences to length-5
STC5_248 = [ st_248 for st_248 in STC_248 if len(st_248) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_248 = []
for n in range(len(STC5_248)):
    tc_248 = [ u for u in STC5_248[n][0] ]
    for k in range(1, len(STC5_248[n])):
        tc_248 = [ u+v for u in tc_248 for v in STC5_248[n][k] ]
    TC5_248 = TC5_248 + tc_248
setTC5_248 = list(set(TC5_248))

# get empirical frequencies
fTC5_248 = [ TC5_248.count(setTC5_248[l]) for l in range(len(setTC5_248)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_248 = [ [] for l in range(len(setTC5_248)) ]
for s in range(100):
    STC5null_248 = [ list(st_248) for st_248 in STC5_248]
    for st_248 in STC5null_248:
        np.random.shuffle(st_248)
    TC5null_248= []
    for n in range(len(STC5null_248)):
        tc_248 = [ u for u in STC5null_248[n][0] ]
        for k in range(1, len(STC5null_248[n])):
            tc_248 = [ u+v for u in tc_248 for v in STC5null_248[n][k] ]
        TC5null_248= TC5null_248+ tc_248
    for l in range(len(setTC5_248)):
        if TC5null_248.count(setTC5_248[l]) > 0:
            fTC5null_248[l].append(TC5null_248.count(setTC5_248[l]))
        else:
            fTC5null_248[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_248)):
     if sum(freq >= fTC5_248[l] for freq in fTC5null_248[l]) < 5:
#         print(setTC5_248[l], fTC5_248[l], sum(freq >= fTC5_248[l] for freq in fTC5null_248[l]))
        print(setTC5_248[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# RRαRN
# JNαJN
# RRMαR
# MMαRα
# MJJRN
# JRMαR
# JJMαJ
# αJα
# RMααM
# MJJJN
# JJMαN
# RJJJN
# MJMαR
# MJJα
# MNαRJ
# JRJα
# RαJM
# MNJRJ
# RNααJ
# RαRN
# RNαRM
# MNJRN
# RMαRM
# ααRN
# JRNα
# MNαRN
# NαNα
# JJMαR
# NJJJα
# ααMN
# NJJαα
# RJMαR
# RJRRJ
# MJJR
# RMNαα
# αMααα
# RJRJN
# RNαRN
# MNααN
# NRNα
# RNαRJ
# MNαJN
# JNMαR
# RMαRJ
# αJJαα
# RMαRN
# RNNRM
# JNαRN
# ααRM
# ααJα
# NJJJN
# RJαRM
# RNNRN
# Rα
# MMαJM
# ααMR
# RNRRN
# JNRRN
# RJααM
# ααJR
# RNMαR
# αNαRN
# NαJM
# RJαRJ
# RαJN
# RNαRα
# RRαRM
# RMααJ
# MNJJN

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_248)):
     if sum(freq >= fTC5_248[l] for freq in fTC5null_248[l]) < 1:
#         print(setTC5_248[l], fTC5_248[l], sum(freq >= fTC5_248[l] for freq in fTC5null_248[l]))
        print(setTC5_248[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# JRJα
# RNαRM
# MNJRN
# RMαRM
# JJMαR
# RNαRN
# RNαRJ
# JNMαR
# RNNRM
# ααMR

# %% [markdown]
#  # 3.249 (J) BLOOM - (M) ICT - (N) JGS - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_249 = max(min(Date_FGEN), min(Date_ICT), min(Date_JGS), min(Date_SMC), min(Date_SCC))
end_249 = min(max(Date_FGEN), max(Date_ICT), max(Date_JGS), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
FGEN_249_1 = Date_FGEN.index(start_249)
FGEN_249_2 = Date_FGEN.index(end_249)

ICT_249_1 = Date_ICT.index(start_249)
ICT_249_2 = Date_ICT.index(end_249)

JGS_249_1 = Date_JGS.index(start_249)
JGS_249_2 = Date_JGS.index(end_249)

SMC_249_1 = Date_SMC.index(start_249)
SMC_249_2 = Date_SMC.index(end_249)

SCC_249_1 = Date_SCC.index(start_249)
SCC_249_2 = Date_SCC.index(end_249)

# %%
#save the shortened versions of closing prices
J249 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_249_1:FGEN_249_2])
M249 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_249_1:ICT_249_2])
N249 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_249_1:JGS_249_2])
Y249 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_249_1:SMC_249_2])
α249 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_249_1:SCC_249_2])

# %%
# import modules
import numpy as np
# import prices

J249 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M249 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N249 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
Y249 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α249 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_249 = []
st_249 = []
n = 1
while n < len(J249):
    sc_249 = ''
    if J249[n] > J249[n-1]:
        sc_249 = sc_249 + 'J'
    if M249[n] > M249[n-1]:
        sc_249 = sc_249 + 'M'
    if N249[n] > N249[n-1]:
        sc_249 = sc_249 + 'N'
    if Y249[n] > Y249[n-1]:
        sc_249 = sc_249 + 'Y'
    if α249[n] > α249[n-1]:
        sc_249 = sc_249 + 'α'
    if len(sc_249) > 0:
        st_249.append(sc_249)
    else:
        STC_249.append(st_249)
        st_249 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[69], line 9
#       7 if J249[n] > J249[n-1]:
#       8     sc_249 = sc_249 + 'J'
# ----> 9 if M249[n] > M249[n-1]:
#      10     sc_249 = sc_249 + 'M'
#      11 if N249[n] > N249[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_249 = STC_249.count([])
# keep only non-empty spatio-temporal sequences
STC_249 = [ st_249 for st_249 in STC_249 if len(st_249) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_249 = len(J249)
lmax_249 = 0
for st_249 in STC_249:
    if len(st_249) < lmin_249:
        lmin_249 = len(st_249)
    if len(st_249) > lmax_249:
        lmax_249 = len(st_249)
        
# restrict spatio-temporal sequences to length-5
STC5_249 = [ st_249 for st_249 in STC_249 if len(st_249) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_249 = []
for n in range(len(STC5_249)):
    tc_249 = [ u for u in STC5_249[n][0] ]
    for k in range(1, len(STC5_249[n])):
        tc_249 = [ u+v for u in tc_249 for v in STC5_249[n][k] ]
    TC5_249 = TC5_249 + tc_249
setTC5_249 = list(set(TC5_249))

# get empirical frequencies
fTC5_249 = [ TC5_249.count(setTC5_249[l]) for l in range(len(setTC5_249)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_249 = [ [] for l in range(len(setTC5_249)) ]
for s in range(100):
    STC5null_249 = [ list(st_249) for st_249 in STC5_249]
    for st_249 in STC5null_249:
        np.random.shuffle(st_249)
    TC5null_249= []
    for n in range(len(STC5null_249)):
        tc_249 = [ u for u in STC5null_249[n][0] ]
        for k in range(1, len(STC5null_249[n])):
            tc_249 = [ u+v for u in tc_249 for v in STC5null_249[n][k] ]
        TC5null_249= TC5null_249+ tc_249
    for l in range(len(setTC5_249)):
        if TC5null_249.count(setTC5_249[l]) > 0:
            fTC5null_249[l].append(TC5null_249.count(setTC5_249[l]))
        else:
            fTC5null_249[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_249)):
     if sum(freq >= fTC5_249[l] for freq in fTC5null_249[l]) < 5:
#         print(setTC5_249[l], fTC5_249[l], sum(freq >= fTC5_249[l] for freq in fTC5null_249[l]))
        print(setTC5_249[l])

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_249)):
     if sum(freq >= fTC5_249[l] for freq in fTC5null_249[l]) < 1:
#         print(setTC5_249[l], fTC5_249[l], sum(freq >= fTC5_249[l] for freq in fTC5null_249[l]))
        print(setTC5_249[l])

# %% [markdown]
#  # 3.250 (J) BLOOM - (M) ICT - (R) MEG - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_250 = max(min(Date_FGEN), min(Date_ICT), min(Date_MEG), min(Date_SMC), min(Date_SCC))
end_250 = min(max(Date_FGEN), max(Date_ICT), max(Date_MEG), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
FGEN_250_1 = Date_FGEN.index(start_250)
FGEN_250_2 = Date_FGEN.index(end_250)

ICT_250_1 = Date_ICT.index(start_250)
ICT_250_2 = Date_ICT.index(end_250)

MEG_250_1 = Date_MEG.index(start_250)
MEG_250_2 = Date_MEG.index(end_250)

SMC_250_1 = Date_SMC.index(start_250)
SMC_250_2 = Date_SMC.index(end_250)

SCC_250_1 = Date_SCC.index(start_250)
SCC_250_2 = Date_SCC.index(end_250)

# %%
#save the shortened versions of closing prices
J250 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_250_1:FGEN_250_2])
M250 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_250_1:ICT_250_2])
R250 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_250_1:MEG_250_2])
Y250 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_250_1:SMC_250_2])
α250 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_250_1:SCC_250_2])

# %%
# import modules
import numpy as np
# import prices

J250 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
M250 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
R250 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y250 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α250 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_250 = []
st_250 = []
n = 1
while n < len(J250):
    sc_250 = ''
    if J250[n] > J250[n-1]:
        sc_250 = sc_250 + 'J'
    if M250[n] > M250[n-1]:
        sc_250 = sc_250 + 'M'
    if R250[n] > R250[n-1]:
        sc_250 = sc_250 + 'R'
    if Y250[n] > Y250[n-1]:
        sc_250 = sc_250 + 'Y'
    if α250[n] > α250[n-1]:
        sc_250 = sc_250 + 'α'
    if len(sc_250) > 0:
        st_250.append(sc_250)
    else:
        STC_250.append(st_250)
        st_250 = []
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[74], line 9
#       7 if J250[n] > J250[n-1]:
#       8     sc_250 = sc_250 + 'J'
# ----> 9 if M250[n] > M250[n-1]:
#      10     sc_250 = sc_250 + 'M'
#      11 if R250[n] > R250[n-1]:
#
# IndexError: list index out of range

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_250 = STC_250.count([])
# keep only non-empty spatio-temporal sequences
STC_250 = [ st_250 for st_250 in STC_250 if len(st_250) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_250 = len(J250)
lmax_250 = 0
for st_250 in STC_250:
    if len(st_250) < lmin_250:
        lmin_250 = len(st_250)
    if len(st_250) > lmax_250:
        lmax_250 = len(st_250)
        
# restrict spatio-temporal sequences to length-5
STC5_250 = [ st_250 for st_250 in STC_250 if len(st_250) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_250 = []
for n in range(len(STC5_250)):
    tc_250 = [ u for u in STC5_250[n][0] ]
    for k in range(1, len(STC5_250[n])):
        tc_250 = [ u+v for u in tc_250 for v in STC5_250[n][k] ]
    TC5_250 = TC5_250 + tc_250
setTC5_250 = list(set(TC5_250))

# get empirical frequencies
fTC5_250 = [ TC5_250.count(setTC5_250[l]) for l in range(len(setTC5_250)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_250 = [ [] for l in range(len(setTC5_250)) ]
for s in range(100):
    STC5null_250 = [ list(st_250) for st_250 in STC5_250]
    for st_250 in STC5null_250:
        np.random.shuffle(st_250)
    TC5null_250= []
    for n in range(len(STC5null_250)):
        tc_250 = [ u for u in STC5null_250[n][0] ]
        for k in range(1, len(STC5null_250[n])):
            tc_250 = [ u+v for u in tc_250 for v in STC5null_250[n][k] ]
        TC5null_250= TC5null_250+ tc_250
    for l in range(len(setTC5_250)):
        if TC5null_250.count(setTC5_250[l]) > 0:
            fTC5null_250[l].append(TC5null_250.count(setTC5_250[l]))
        else:
            fTC5null_250[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_250)):
     if sum(freq >= fTC5_250[l] for freq in fTC5null_250[l]) < 5:
#         print(setTC5_250[l], fTC5_250[l], sum(freq >= fTC5_250[l] for freq in fTC5null_250[l]))
        print(setTC5_250[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# αMMαR
# RMRYα
# RJRRM
# MJMJM
# RMYRM
# RRMαR
# MMαRα
# YMY
# YMJM
# RαYRM
# YJJJM
# YMRYα
# RαYJM
# RJRRα
# RMYJM
# RαMαY
# αααYR
# YαYRM
# RJYJα
# MαMJM
# YMMM
# RJJJM
# JJJα
# MααM
# YJYJα
# YMJJM
# YJRM
# RMMαY
# YαYJM
# RMJRM
# YJMJM
# RRJR
# RMαRM
# RMJJM
# RJMJM
# YαJM
# MMαRY
# RJMαY
# YMYJM
# MMααα
# MYJRR
# RMαJJ
# YJYYα
# αMα
# MYRRR
# αMααY
# RJMαR
# RJRRJ
# ααRR
# MJαJM
# YMJRM
# RJRJα
# RMαRJ
# RJYRM
# YJYJM
# RJααJ
# RMαJM
# RMRRM
# YMRM
# RαMαJ
# αMMαY
# YJYRM
# YMα
# MααJ
# RJαRM
# RMYJα
# RMRαJ
# RJαJJ
# MJRM
# MMαJM
# YYJM
# YMYJα
# YJMJα
# ααMR
# YMRJM
# MααY
# YMYRM
# YYRYY
# RJαJM
# αJαJJ
# RJααM
# ααJR
# MYJYY
# RJαRJ
# MJJY
# RMRJM
# RJYJM
# YMYYα
# RMααJ
# MJJM
# MMαRM
# RJαRα
# YMαJM
# αMRYα

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_250)):
     if sum(freq >= fTC5_250[l] for freq in fTC5null_250[l]) < 1:
#         print(setTC5_250[l], fTC5_250[l], sum(freq >= fTC5_250[l] for freq in fTC5null_250[l]))
        print(setTC5_250[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# αMMαR
# MMαRα
# YJJJM
# YMRYα
# RJYJα
# YMMM
# YJYJα
# YJMJM
# RMαRM
# YMYJM
# αMα
# RJααJ
# YMRM
# YMα
# RMYJα
# RJαJJ
# YMYJα
# YJMJα
# YMYRM
# RMααJ

# %% [markdown]
#  # 3.251 (J) BLOOM - (N) JGS - (R) MEG - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_251 = max(min(Date_FGEN), min(Date_JGS), min(Date_MEG), min(Date_SMC), min(Date_SCC))
end_251 = min(max(Date_FGEN), max(Date_JGS), max(Date_MEG), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
FGEN_251_1 = Date_FGEN.index(start_251)
FGEN_251_2 = Date_FGEN.index(end_251)

JGS_251_1 = Date_JGS.index(start_251)
JGS_251_2 = Date_JGS.index(end_251)

MEG_251_1 = Date_MEG.index(start_251)
MEG_251_2 = Date_MEG.index(end_251)

SMC_251_1 = Date_SMC.index(start_251)
SMC_251_2 = Date_SMC.index(end_251)

SCC_251_1 = Date_SCC.index(start_251)
SCC_251_2 = Date_SCC.index(end_251)

# %%
#save the shortened versions of closing prices
J251 = np.save('FGENshortPrices.npy', ClosePrice_FGEN[FGEN_251_1:FGEN_251_2])
N251 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_251_1:JGS_251_2])
R251 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_251_1:MEG_251_2])
Y251 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_251_1:SMC_251_2])
α251 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_251_1:SCC_251_2])

# %%
# import modules
import numpy as np
# import prices

J251 = np.load('FGENshortPrices.npy', allow_pickle=True).tolist() 
N251 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R251 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y251 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α251 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_251 = []
st_251 = []
n = 1
while n < len(J251):
    sc_251 = ''
    if J251[n] > J251[n-1]:
        sc_251 = sc_251 + 'J'
    if N251[n] > N251[n-1]:
        sc_251 = sc_251 + 'N'
    if R251[n] > R251[n-1]:
        sc_251 = sc_251 + 'R'
    if Y251[n] > Y251[n-1]:
        sc_251 = sc_251 + 'Y'
    if α251[n] > α251[n-1]:
        sc_251 = sc_251 + 'α'
    if len(sc_251) > 0:
        st_251.append(sc_251)
    else:
        STC_251.append(st_251)
        st_251 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_251 = STC_251.count([])
# keep only non-empty spatio-temporal sequences
STC_251 = [ st_251 for st_251 in STC_251 if len(st_251) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_251 = len(J251)
lmax_251 = 0
for st_251 in STC_251:
    if len(st_251) < lmin_251:
        lmin_251 = len(st_251)
    if len(st_251) > lmax_251:
        lmax_251 = len(st_251)
        
# restrict spatio-temporal sequences to length-5
STC5_251 = [ st_251 for st_251 in STC_251 if len(st_251) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_251 = []
for n in range(len(STC5_251)):
    tc_251 = [ u for u in STC5_251[n][0] ]
    for k in range(1, len(STC5_251[n])):
        tc_251 = [ u+v for u in tc_251 for v in STC5_251[n][k] ]
    TC5_251 = TC5_251 + tc_251
setTC5_251 = list(set(TC5_251))

# get empirical frequencies
fTC5_251 = [ TC5_251.count(setTC5_251[l]) for l in range(len(setTC5_251)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_251 = [ [] for l in range(len(setTC5_251)) ]
for s in range(100):
    STC5null_251 = [ list(st_251) for st_251 in STC5_251]
    for st_251 in STC5null_251:
        np.random.shuffle(st_251)
    TC5null_251= []
    for n in range(len(STC5null_251)):
        tc_251 = [ u for u in STC5null_251[n][0] ]
        for k in range(1, len(STC5null_251[n])):
            tc_251 = [ u+v for u in tc_251 for v in STC5null_251[n][k] ]
        TC5null_251= TC5null_251+ tc_251
    for l in range(len(setTC5_251)):
        if TC5null_251.count(setTC5_251[l]) > 0:
            fTC5null_251[l].append(TC5null_251.count(setTC5_251[l]))
        else:
            fTC5null_251[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_251)):
     if sum(freq >= fTC5_251[l] for freq in fTC5null_251[l]) < 5:
#         print(setTC5_251[l], fTC5_251[l], sum(freq >= fTC5_251[l] for freq in fTC5null_251[l]))
        print(setTC5_251[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# YRJYN
# αYNYN
# YJJJα
# YRRRα
# RYN
# NYJYN
# YαYαα
# NYαYJ
# RJRRα
# RJJYN
# RJYJα
# RNJRα
# RYRJN
# NYNYN
# αNααJ
# RJJJN
# RJYαα
# NαRα
# RRJRα
# RαYαα
# JJJα
# NYRJJ
# NYαNJ
# RNααJ
# NYNRR
# YJYJα
# RYNYN
# NYNRN
# YαYYN
# RRJYα
# NYNJJ
# RNNRα
# YYRYα
# RJYYN
# RααNJ
# YYJYN
# RJYNα
# RYRYN
# YααR
# RαYαN
# NYNYJ
# YJYYα
# RJααα
# NαNα
# JJJJN
# YJYYN
# RYRYR
# YRααY
# YJJYN
# YRααα
# ααRR
# NYRNJ
# RαYRα
# RJRJN
# RJRJα
# αNR
# RαYYα
# RYRYY
# RαYNα
# NαYY
# RYJ
# RRJYN
# YRJRα
# NJJJN
# JRYJR
# RJYYα
# RJNRα
# αNααα
# NYRYJ
# YJJJN
# RαYYN
# RαNRα
# RJJRN
# RJJJα
# NNJJN
# RJJJY
# YαJR
# YYRJN
# YYRYN
# YYRYY
# RJYY
# RJRYN
# RRJNα
# NRαYJ
# YJYNα
# NJJRN
# RJJRα
# YYRYR
# YJRYN
# RαYY
# RJJαN
# JYNYN
# RJαRα

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_251)):
     if sum(freq >= fTC5_251[l] for freq in fTC5null_251[l]) < 1:
#         print(setTC5_251[l], fTC5_251[l], sum(freq >= fTC5_251[l] for freq in fTC5null_251[l]))
        print(setTC5_251[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# YαYαα
# NYαYJ
# RJJJN
# RRJRα
# YJYJα
# RJYYN
# NYNYJ
# RYJ
# NJJJN
# RJYYα
# YJJJN
# RαYYN
# RαNRα
# RJJRα
# YJRYN
# JYNYN

# %% [markdown]
#  # 3.252 (M) ICT - (N) JGS - (R) MEG - (Y) SMC - (α) SCC

# %%
#extract overlapping dates
start_252 = max(min(Date_ICT), min(Date_JGS), min(Date_MEG), min(Date_SMC), min(Date_SCC))
end_252 = min(max(Date_ICT), max(Date_JGS), max(Date_MEG), max(Date_SMC), max(Date_SCC))

# %%
#shorten the closing prices
ICT_252_1 = Date_ICT.index(start_252)
ICT_252_2 = Date_ICT.index(end_252)

JGS_252_1 = Date_JGS.index(start_252)
JGS_252_2 = Date_JGS.index(end_252)

MEG_252_1 = Date_MEG.index(start_252)
MEG_252_2 = Date_MEG.index(end_252)

SMC_252_1 = Date_SMC.index(start_252)
SMC_252_2 = Date_SMC.index(end_252)

SCC_252_1 = Date_SCC.index(start_252)
SCC_252_2 = Date_SCC.index(end_252)

# %%
#save the shortened versions of closing prices
M252 = np.save('ICTshortPrices.npy', ClosePrice_ICT[ICT_252_1:ICT_252_2])
N252 = np.save('JGSshortPrices.npy', ClosePrice_JGS[JGS_252_1:JGS_252_2])
R252 = np.save('MEGshortPrices.npy', ClosePrice_MEG[MEG_252_1:MEG_252_2])
Y252 = np.save('SMCshortPrices.npy', ClosePrice_SMC[SMC_252_1:SMC_252_2])
α252 = np.save('SCCshortPrices.npy', ClosePrice_SCC[SCC_252_1:SCC_252_2])

# %%
# import modules
import numpy as np
# import prices

M252 = np.load('ICTshortPrices.npy', allow_pickle=True).tolist() 
N252 = np.load('JGSshortPrices.npy', allow_pickle=True).tolist() 
R252 = np.load('MEGshortPrices.npy', allow_pickle=True).tolist() 
Y252 = np.load('SMCshortPrices.npy', allow_pickle=True).tolist() 
α252 = np.load('SCCshortPrices.npy', allow_pickle=True).tolist()

# %%
# extract spatio-temporal sequences
STC_252 = []
st_252 = []
n = 1
while n < len(M252):
    sc_252 = ''
    if M252[n] > M252[n-1]:
        sc_252 = sc_252 + 'M'
    if N252[n] > N252[n-1]:
        sc_252 = sc_252 + 'N'
    if R252[n] > R252[n-1]:
        sc_252 = sc_252 + 'R'
    if Y252[n] > Y252[n-1]:
        sc_252 = sc_252 + 'Y'
    if α252[n] > α252[n-1]:
        sc_252 = sc_252 + 'α'
    if len(sc_252) > 0:
        st_252.append(sc_252)
    else:
        STC_252.append(st_252)
        st_252 = []
    n = n + 1

# %%
# record the number of empty spatio-temporal sequences
nSTCempty_252 = STC_252.count([])
# keep only non-empty spatio-temporal sequences
STC_252 = [ st_252 for st_252 in STC_252 if len(st_252) > 0 ]

# record the length of the longest spatio-temporal sequence
lmin_252 = len(M252)
lmax_252 = 0
for st_252 in STC_252:
    if len(st_252) < lmin_252:
        lmin_252 = len(st_252)
    if len(st_252) > lmax_252:
        lmax_252 = len(st_252)
        
# restrict spatio-temporal sequences to length-5
STC5_252 = [ st_252 for st_252 in STC_252 if len(st_252) <= 5 ]

# unpack spatio-temporal sequences to temporal sequences
TC5_252 = []
for n in range(len(STC5_252)):
    tc_252 = [ u for u in STC5_252[n][0] ]
    for k in range(1, len(STC5_252[n])):
        tc_252 = [ u+v for u in tc_252 for v in STC5_252[n][k] ]
    TC5_252 = TC5_252 + tc_252
setTC5_252 = list(set(TC5_252))

# get empirical frequencies
fTC5_252 = [ TC5_252.count(setTC5_252[l]) for l in range(len(setTC5_252)) ]

# statistical testing against null model
np.random.seed(0)
fTC5null_252 = [ [] for l in range(len(setTC5_252)) ]
for s in range(100):
    STC5null_252 = [ list(st_252) for st_252 in STC5_252]
    for st_252 in STC5null_252:
        np.random.shuffle(st_252)
    TC5null_252= []
    for n in range(len(STC5null_252)):
        tc_252 = [ u for u in STC5null_252[n][0] ]
        for k in range(1, len(STC5null_252[n])):
            tc_252 = [ u+v for u in tc_252 for v in STC5null_252[n][k] ]
        TC5null_252= TC5null_252+ tc_252
    for l in range(len(setTC5_252)):
        if TC5null_252.count(setTC5_252[l]) > 0:
            fTC5null_252[l].append(TC5null_252.count(setTC5_252[l]))
        else:
            fTC5null_252[l].append(0)

# %%
print("List of Statistically Significant Sequences at R = 0.05")

#statistical significance testing at p < 0.05 level
for l in range(len(setTC5_252)):
     if sum(freq >= fTC5_252[l] for freq in fTC5null_252[l]) < 5:
#         print(setTC5_252[l], fTC5_252[l], sum(freq >= fTC5_252[l] for freq in fTC5null_252[l]))
        print(setTC5_252[l])
# Out:
# List of Statistically Significant Sequences at R = 0.05
# RRYαα
# RM
# YRMMR
# MNMMN
# NNYα
# RαYMR
# NRNYM
# MNαRα
# RYN
# YNMMY
# ααYMY
# RNN
# RYαNα
# MYY
# MRMYR
# αNYMN
# MαMYM
# YRMNα
# NαRα
# RαYYR
# YαMMN
# NRRNR
# YYRN
# αNRMM
# αNYMM
# RMMYα
# MNαNα
# NYαNN
# YRMRα
# MRRR
# NYRNα
# MNRRα
# YNYMN
# MMNR
# NYNNα
# MNMYM
# NαRR
# MNRNR
# YRααY
# RMMαα
# YRααα
# MRMYM
# YYMYN
# RRMMα
# NNRRα
# NNαNα
# RNYYN
# RRMMM
# NRRRR
# αNMMY
# NYαNα
# MRMMM
# NRRYM
# YαMMY
# RRMMN
# YαMR
# αNYMR
# RαMR
# YαYMN
# YRMMY
# MRRRR
# NYRNN
# αNααα
# RRYαR
# YNYYN
# NNαRα
# RαYYN
# YRMYN
# NRYYY
# YRMαα
# MNαMM
# MRMMN
# RMMNN
# MYYNR
# YNYMY
# αNRMα
# MRMRR
# RRYYN
# αNMMR
# αNRMR
# RYRNα
# RRMYM

# %%
print("List of Statistically Significant Sequences at R = 0.01")

#statistical significance testing at p < 0.01 level
for l in range(len(setTC5_252)):
     if sum(freq >= fTC5_252[l] for freq in fTC5null_252[l]) < 1:
#         print(setTC5_252[l], fTC5_252[l], sum(freq >= fTC5_252[l] for freq in fTC5null_252[l]))
        print(setTC5_252[l])
# Out:
# List of Statistically Significant Sequences at R = 0.01
# RYαNα
# NαRα
# MMNR
# MRMYM
# RRMMα
# RRMMM
# MRMMM
# RRMMN
# YαMR
# MRRRR
# αNααα
# MRMRR
# αNMMR
# αNRMR
# RRMYM
